# %% [markdown]
# <a href="https://colab.research.google.com/github/wedexyz/eeg-/blob/main/SBJEK2CNN%2BReduceLe%2BCrossVall%2BROc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.0.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.19.4)

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM, BatchNormalization, Conv2D, Flatten, MaxPooling2D, Dropout
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.optimizers import Adam
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
import pandas as pd
import os
import random
import time
import os
from keras.callbacks import ModelCheckpoint, EarlyStopping
#from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator

from scipy import signal
from scipy.fft import fftshift

# %%
'''
idle = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/idle/1604315006.npy")
kanan = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kanan/1604315180.npy")
kiri = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kiri/1604315126.npy")
maju = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/maju/1604315069.npy")

kelas1=idle[0][16]
kelas2=maju[0][16]
kelas3=kanan[0][16]
kelas4=kiri[0][16]

kelas1a=idle[175]
kelas2a=maju[175]
kelas3a=kanan[175]
kelas4a=kiri[175]

#print(idlea.shape)


f1, t1,Sxx= signal.spectrogram(kelas1,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )
dbs1 = 10*np.log10(Sxx)
f2, t2,Sxx= signal.spectrogram(kelas2,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd',
                            )
dbs2 = 10*np.log10(Sxx)
f3, t3,Sxx= signal.spectrogram(kelas3,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )
dbs3 = 10*np.log10(Sxx)
f4, t4,Sxx= signal.spectrogram(kelas4,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )  
dbs4 = 10*np.log10(Sxx)



fig, axs = plt.subplots(nrows=4, ncols=4)
axs = axs.flatten()

axs[0].set_title("siggle")
axs[0].plot(kelas1)

axs[1].set_title("global")
axs[1].plot(kelas1a)

axs[2].set_title("Spectogram")
axs[2].pcolormesh(t1, f1,dbs1,  
                  shading='gouraud',
                  cmap='nipy_spectral')

cwt1 = signal.cwt(kelas1,signal.ricker,widths=np.arange(1,50))
cwt2 = signal.cwt(kelas2,signal.ricker,widths=np.arange(1,50))
cwt3 = signal.cwt(kelas3,signal.ricker,widths=np.arange(1,50))
cwt4 = signal.cwt(kelas4,signal.ricker,widths=np.arange(1,50))
axs[3].set_title("wavelet")
axs[3].imshow(cwt1,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt1).max(),vmin=-abs(cwt1).max())

axs[4].plot(kelas2)
axs[5].plot(kelas2a)
axs[6].pcolormesh(t2, f2,dbs2,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[7].imshow(cwt2,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt2).max(),vmin=-abs(cwt2).max())

axs[8].plot(kelas3)
axs[9].plot(kelas3a)
axs[10].pcolormesh(t3, f3,dbs3,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[11].imshow(cwt3,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt3).max(),vmin=-abs(cwt3).max())

axs[12].plot(kelas4)
axs[13].plot(kelas4a)
axs[14].pcolormesh(t4, f4,dbs4,  
                  shading='gouraud',
                  cmap='viridis')
axs[15].imshow(cwt4,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt4).max(),vmin=-abs(cwt4).max())
plt.show()
'''
# Out:
# '\nidle = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/idle/1604315006.npy")\nkanan = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kanan/1604315180.npy")\nkiri = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kiri/1604315126.npy")\nmaju = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/maju/1604315069.npy")\n\nkelas1=idle[0][16]\nkelas2=maju[0][16]\nkelas3=kanan[0][16]\nkelas4=kiri[0][16]\n\nkelas1a=idle[175]\nkelas2a=maju[175]\nkelas3a=kanan[175]\nkelas4a=kiri[175]\n\n#print(idlea.shape)\n\n\nf1, t1,Sxx= signal.spectrogram(kelas1,fs=120, window=(\'tukey\', 0.25),\n                             nperseg=11,\n                             noverlap=10,\n                             nfft=None, \n                             detrend=\'constant\',\n                             return_onesided=True, \n                             scaling=\'density\', \n                             axis=-1,\n                             mode=\'psd\'\n                            )\ndbs1 = 10*np.log10(Sxx)\nf2, t2,Sxx= signal.spectrogram(kelas2,fs=120, window=(\'tukey\', 0.25),\n                             nperseg=11,\n                             noverlap=10,\n                             nfft=None, \n                             detrend=\'constant\',\n                             return_onesided=True, \n                             scaling=\'density\', \n                             axis=-1,\n                             mode=\'psd\',\n                            )\ndbs2 = 10*np.log10(Sxx)\nf3, t3,Sxx= signal.spectrogram(kelas3,fs=120, window=(\'tukey\', 0.25),\n                             nperseg=11,\n                             noverlap=10,\n                             nfft=None, \n                             detrend=\'constant\',\n                             return_onesided=True, \n                             scaling=\'density\', \n                             axis=-1,\n                             mode=\'psd\'\n                            )\ndbs3 = 10*np.log10(Sxx)\nf4, t4,Sxx= signal.spectrogram(kelas4,fs=120, window=(\'tukey\', 0.25),\n                             nperseg=11,\n                             noverlap=10,\n                             nfft=None, \n                             detrend=\'constant\',\n                             return_onesided=True, \n                             scaling=\'density\', \n                             axis=-1,\n                             mode=\'psd\'\n                            )  \ndbs4 = 10*np.log10(Sxx)\n\n\n\nfig, axs = plt.subplots(nrows=4, ncols=4)\naxs = axs.flatten()\n\naxs[0].set_title("siggle")\naxs[0].plot(kelas1)\n\naxs[1].set_title("global")\naxs[1].plot(kelas1a)\n\naxs[2].set_title("Spectogram")\naxs[2].pcolormesh(t1, f1,dbs1,  \n                  shading=\'gouraud\',\n                  cmap=\'nipy_spectral\')\n\ncwt1 = signal.cwt(kelas1,signal.ricker,widths=np.arange(1,50))\ncwt2 = signal.cwt(kelas2,signal.ricker,widths=np.arange(1,50))\ncwt3 = signal.cwt(kelas3,signal.ricker,widths=np.arange(1,50))\ncwt4 = signal.cwt(kelas4,signal.ricker,widths=np.arange(1,50))\naxs[3].set_title("wavelet")\naxs[3].imshow(cwt1,extent=[0,16,0,60],cmap=\'jet\',aspect=\'auto\',vmax=abs(cwt1).max(),vmin=-abs(cwt1).max())\n\naxs[4].plot(kelas2)\naxs[5].plot(kelas2a)\naxs[6].pcolormesh(t2, f2,dbs2,  \n                  shading=\'gouraud\',\n                  cmap=\'nipy_spectral\')\naxs[7].imshow(cwt2,extent=[0,16,0,60],cmap=\'jet\',aspect=\'auto\',vmax=abs(cwt2).max(),vmin=-abs(cwt2).max())\n\naxs[8].plot(kelas3)\naxs[9].plot(kelas3a)\naxs[10].pcolormesh(t3, f3,dbs3,  \n                  shading=\'gouraud\',\n                  cmap=\'nipy_spectral\')\naxs[11].imshow(cwt3,extent=[0,16,0,60],cmap=\'jet\',aspect=\'auto\',vmax=abs(cwt3).max(),vmin=-abs(cwt3).max())\n\naxs[12].plot(kelas4)\naxs[13].plot(kelas4a)\naxs[14].pcolormesh(t4, f4,dbs4,  \n                  shading=\'gouraud\',\n                  cmap=\'viridis\')\naxs[15].imshow(cwt4,extent=[0,16,0, ...

# %%
ACTIONS = ["kiri", "maju","idle","kanan"]
reshape = (-1,16, 60,1)
#reshape(-1,28,28,1)

# %%
def create_data(starting_dir="=/content/drive/MyDrive/Colab Notebooks/rizky_subjek2"):
    training_data = {}
    for action in ACTIONS:
        if action not in training_data:
            training_data[action] = []
        data_dir = os.path.join(starting_dir,action)
        for item in os.listdir(data_dir):
            data = np.load(os.path.join(data_dir, item))
            for item in data:
                training_data[action].append(item)

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)

    for action in ACTIONS:
        np.random.shuffle(training_data[action])  
        training_data[action] = training_data[action][:min(lengths)]

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)
    combined_data = []
    for action in ACTIONS:
        for data in training_data[action]:
            if action == "kiri":
                combined_data.append([data, [1, 0, 0,0]])
            elif action == "maju":
                combined_data.append([data, [0, 1, 0, 0]])
            elif action == "idle":
                combined_data.append([data, [0, 0, 1, 0]])
            elif action == "kanan":
                combined_data.append([data, [0, 0, 0, 1]])

    np.random.shuffle(combined_data)
    print("length:",len(combined_data))
    return combined_data

# %%
print("creating training data")
traindata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/rizky_subjek2")
train_X = []
train_y = []
for X, y in traindata:
    train_X.append(X)
    train_y.append(y)
# Out:
# creating training data
# [1000, 1000, 1000, 1000]
# [1000, 1000, 1000, 1000]
# length: 4000

# %%
print("creating testing data")
testdata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/subjek2tes")
test_X = []
test_y = []

for X, y in testdata:
    test_X.append(X)
    test_y.append(y)
train_X = np.array(train_X).reshape(reshape)
test_X = np.array(test_X).reshape(reshape)

train_y = np.array(train_y)
test_y = np.array(test_y)
# Out:
# creating testing data
# [250, 250, 250, 250]
# [250, 250, 250, 250]
# length: 1000

# %%
import seaborn as sns
ye=pd.DataFrame(train_y)

ye.columns=["kiri", "maju","idle","kanan"]
categories = list(ye.columns.values)
sns.set(font_scale = 1)
plt.figure(figsize=(10,8))
ax= sns.barplot(categories, ye.iloc[:,0:].sum().values)
plt.title("Number of samples labeled as active (1) out of {0} length data".format((ye.shape[0])),fontsize=20)

plt.ylabel('Number of events', fontsize=18)
plt.xlabel('Event Type ', fontsize=12)
#adding the text labels
rects = ax.patches
labels = ye.iloc[:,0:].sum().values

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom', fontsize=10)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
IMAGE_SIZE = (32,16, 60)

# %%
# With data augmentation to prevent overfitting
'''
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(train_X)
'''
# Out:
# '\ndatagen = ImageDataGenerator(\n        featurewise_center=False,  # set input mean to 0 over the dataset\n        samplewise_center=False,  # set each sample mean to 0\n        featurewise_std_normalization=False,  # divide inputs by std of the dataset\n        samplewise_std_normalization=False,  # divide each input by its std\n        zca_whitening=False,  # apply ZCA whitening\n        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)\n        zoom_range = 0.1, # Randomly zoom image \n        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)\n        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)\n        horizontal_flip=False,  # randomly flip images\n        vertical_flip=False)  # randomly flip images\n\n\ndatagen.fit(train_X)\n'

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1,factor=0.5, min_lr=0.0001)

# %%
def cnn_model():
    

    model = Sequential()
    
    model.add(Conv2D(filters = 64, kernel_size = (7,7), padding = "same", activation = "relu", input_shape=train_X.shape[1:]))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Conv2D(filters = 64, kernel_size = (5,5), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (5,5)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Conv2D(filters = 64, kernel_size = (3,3), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (3,3)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Flatten())
    
    model.add(Dense(32, activation = "relu"))
    model.add(BatchNormalization())

    model.add(Dense(4, activation = "sigmoid"))
   
    #adam = Adam(lr = 0.0001)
    model.compile(optimizer ="adam", loss = "binary_crossentropy", metrics = ['accuracy'])
    #model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
 
    
    return model

# %%
model = cnn_model()
model.summary()
# Out:
# Model: "sequential_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_146 (Conv2D)          (None, 16, 60, 64)        3200
# _________________________________________________________________
# batch_normalization_193 (Bat (None, 16, 60, 64)        256
# _________________________________________________________________
# dropout_145 (Dropout)        (None, 16, 60, 64)        0
# _________________________________________________________________
# conv2d_147 (Conv2D)          (None, 16, 60, 64)        102464
# _________________________________________________________________
# max_pooling2d_96 (MaxPooling (None, 3, 12, 64)         0
# _________________________________________________________________
# dropout_146 (Dropout)        (None, 3, 12, 64)         0
# _________________________________________________________________
# batch_normalization_194 (Bat (None, 3, 12, 64)         256
# _________________________________________________________________
# conv2d_148 (Conv2D)          (None, 3, 12, 64)         36928
# _________________________________________________________________
# max_pooling2d_97 (MaxPooling (None, 1, 4, 64)          0
# _________________________________________________________________
# dropout_147 (Dropout)        (None, 1, 4, 64)          0
# _________________________________________________________________
# batch_normalization_195 (Bat (None, 1, 4, 64)          256
# _________________________________________________________________
# flatten_48 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_96 (Dense)             (None, 32)                8224
# _________________________________________________________________
# batch_normalization_196 (Bat (None, 32)                128
# _________________________________________________________________
# dense_97 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 151,844
# Trainable params: 151,396
# Non-trainable params: 448
# _________________________________________________________________

# %%
#set early stopping criteria
pat = 5
#this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='loss', patience=pat, verbose=1)

#define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('subjek2.h5', verbose=1, save_best_only=True)

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=100, BATCH_SIZE=32):
    model = None
    model = cnn_model()
    #Model = model
   # results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[early_stopping, model_checkpoint], 
   #           verbose=1, validation_split=0.1) 
    results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[learning_rate_reduction,
                                                                                   early_stopping, 
                                                                                   model_checkpoint], 
              verbose=1, validation_split=0.1)   
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs=100
batch_size=32

#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(train_X, train_y, test_size=0.1, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
   
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 102/102 [==============================] - 2s 12ms/step - loss: 0.7760 - accuracy: 0.2399 - val_loss: 0.6396 - val_accuracy: 0.2500
#
# Epoch 00001: val_loss improved from inf to 0.63960, saving model to subjek2.h5
# Epoch 2/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.6347 - accuracy: 0.2510 - val_loss: 0.5855 - val_accuracy: 0.2306
#
# Epoch 00002: val_loss improved from 0.63960 to 0.58550, saving model to subjek2.h5
# Epoch 3/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5939 - accuracy: 0.2313 - val_loss: 0.5696 - val_accuracy: 0.2417
#
# Epoch 00003: val_loss improved from 0.58550 to 0.56965, saving model to subjek2.h5
# Epoch 4/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5760 - accuracy: 0.2383 - val_loss: 0.5660 - val_accuracy: 0.2111
#
# Epoch 00004: val_loss improved from 0.56965 to 0.56604, saving model to subjek2.h5
# Epoch 5/100
# 102/102 [==============================] - 1s 12ms/step - loss: 0.5702 - accuracy: 0.2297 - val_loss: 0.5672 - val_accuracy: 0.2417
#
# Epoch 00005: val_loss did not improve from 0.56604
# Epoch 6/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5689 - accuracy: 0.2430 - val_loss: 0.5666 - val_accuracy: 0.2417
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.56604
# Epoch 7/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5644 - accuracy: 0.2586 - val_loss: 0.5652 - val_accuracy: 0.2444
#
# Epoch 00007: val_loss improved from 0.56604 to 0.56522, saving model to subjek2.h5
# Epoch 8/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5643 - accuracy: 0.2584 - val_loss: 0.5655 - val_accuracy: 0.2306
#
# Epoch 00008: val_loss did not improve from 0.56522
# Epoch 9/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5638 - accuracy: 0.2694 - val_loss: 0.5649 - val_accuracy: 0.2444
#
# Epoch 00009: val_loss improved from 0.56522 to 0.56485, saving model to subjek2.h5
# Epoch 10/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5638 - accuracy: 0.2685 - val_loss: 0.5649 - val_accuracy: 0.2361
#
# Epoch 00010: val_loss did not improve from 0.56485
# Epoch 11/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5642 - accuracy: 0.2693 - val_loss: 0.5652 - val_accuracy: 0.2194
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00011: val_loss did not improve from 0.56485
# Epoch 12/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5651 - accuracy: 0.2539 - val_loss: 0.5644 - val_accuracy: 0.2361
#
# Epoch 00012: val_loss improved from 0.56485 to 0.56435, saving model to subjek2.h5
# Epoch 13/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5645 - accuracy: 0.2721 - val_loss: 0.5644 - val_accuracy: 0.2444
#
# Epoch 00013: val_loss did not improve from 0.56435
# Epoch 14/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5641 - accuracy: 0.2494 - val_loss: 0.5643 - val_accuracy: 0.2500
#
# Epoch 00014: val_loss improved from 0.56435 to 0.56428, saving model to subjek2.h5
# Epoch 15/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5631 - accuracy: 0.2562 - val_loss: 0.5645 - val_accuracy: 0.2389
#
# Epoch 00015: val_loss did not improve from 0.56428
# Epoch 16/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5633 - accuracy: 0.2640 - val_loss: 0.5642 - val_accuracy: 0.2389
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00016: val_loss improved from 0.56428 to 0.56423, saving model to subjek2.h5
# Epoch 17/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5636 - accuracy: 0.2605 - val_loss: 0.5641 - val_accuracy: 0.2444
#
# Epoch 00017: val_loss improved from 0.56423 to 0.56412, saving model to subjek2.h5
# Epoch 18/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5639 - accuracy: 0.2388 - val_loss: 0.5641 - val_accuracy: 0.2361
#
# Epoch 00018: val_loss improved from 0.56412 to 0.56408, saving model to subjek2.h5
# Epoch 19/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5625 - accuracy: 0.2539 - val_loss: 0.5640 - val_accuracy: 0.2278
#
# Epoch 00019: val_loss improved from 0.56408 to 0.56404, saving model to subjek2.h5
# Epoch 20/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5629 - accuracy: 0.2608 - val_loss: 0.5639 - val_accuracy: 0.2333
#
# Epoch 00020: val_loss improved from 0.56404 to 0.56393, saving model to subjek2.h5
# Epoch 21/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5639 - accuracy: 0.2644 - val_loss: 0.5639 - val_accuracy: 0.2583
#
# Epoch 00021: val_loss improved from 0.56393 to 0.56390, saving model to subjek2.h5
# Epoch 22/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5612 - accuracy: 0.2827 - val_loss: 0.5638 - val_accuracy: 0.2472
#
# Epoch 00022: val_loss improved from 0.56390 to 0.56378, saving model to subjek2.h5
# Epoch 23/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5617 - accuracy: 0.2815 - val_loss: 0.5641 - val_accuracy: 0.2444
#
# Epoch 00023: val_loss did not improve from 0.56378
# Epoch 24/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5628 - accuracy: 0.2599 - val_loss: 0.5642 - val_accuracy: 0.2500
#
# Epoch 00024: val_loss did not improve from 0.56378
# Epoch 25/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5630 - accuracy: 0.2644 - val_loss: 0.5644 - val_accuracy: 0.2556
#
# Epoch 00025: val_loss did not improve from 0.56378
# Epoch 26/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5631 - accuracy: 0.2583 - val_loss: 0.5641 - val_accuracy: 0.2472
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00026: val_loss did not improve from 0.56378
# Epoch 27/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5619 - accuracy: 0.2731 - val_loss: 0.5643 - val_accuracy: 0.2556
#
# Epoch 00027: val_loss did not improve from 0.56378
# Epoch 28/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5609 - accuracy: 0.2851 - val_loss: 0.5641 - val_accuracy: 0.2556
#
# Epoch 00028: val_loss did not improve from 0.56378
# Epoch 29/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5620 - accuracy: 0.2724 - val_loss: 0.5641 - val_accuracy: 0.2556
#
# Epoch 00029: val_loss did not improve from 0.56378
# Epoch 30/100
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5621 - accuracy: 0.2642 - val_loss: 0.5645 - val_accuracy: 0.2500
#
# Epoch 00030: val_loss did not improve from 0.56378
# Epoch 31/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.5621 - accuracy: 0.2503 - val_loss: 0.5642 - val_accuracy: 0.2472
#
# Epoch 00031: val_loss did not improve from 0.56378
# Epoch 32/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5611 - accuracy: 0.2766 - val_loss: 0.5636 - val_accuracy: 0.2583
#
# Epoch 00032: val_loss improved from 0.56378 to 0.56359, saving model to subjek2.h5
# Epoch 33/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5625 - accuracy: 0.2730 - val_loss: 0.5638 - val_accuracy: 0.2444
#
# Epoch 00033: val_loss did not improve from 0.56359
# Epoch 34/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5595 - accuracy: 0.2903 - val_loss: 0.5631 - val_accuracy: 0.2528
#
# Epoch 00034: val_loss improved from 0.56359 to 0.56315, saving model to subjek2.h5
# Epoch 35/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5626 - accuracy: 0.2665 - val_loss: 0.5626 - val_accuracy: 0.2694
#
# Epoch 00035: val_loss improved from 0.56315 to 0.56256, saving model to subjek2.h5
# Epoch 36/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5619 - accuracy: 0.2672 - val_loss: 0.5622 - val_accuracy: 0.2583
#
# Epoch 00036: val_loss improved from 0.56256 to 0.56217, saving model to subjek2.h5
# Epoch 37/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5614 - accuracy: 0.2593 - val_loss: 0.5623 - val_accuracy: 0.2556
#
# Epoch 00037: val_loss did not improve from 0.56217
# Epoch 38/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5616 - accuracy: 0.2801 - val_loss: 0.5622 - val_accuracy: 0.2611
#
# Epoch 00038: val_loss did not improve from 0.56217
# Epoch 39/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5601 - accuracy: 0.2864 - val_loss: 0.5616 - val_accuracy: 0.2556
#
# Epoch 00039: val_loss improved from 0.56217 to 0.56162, saving model to subjek2.h5
# Epoch 00039: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5622 - accuracy: 0.2225
# Val Score:  [0.5621789693832397, 0.2224999964237213]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
# 102/102 [==============================] - 2s 11ms/step - loss: 0.7625 - accuracy: 0.2365 - val_loss: 0.6281 - val_accuracy: 0.2528
#
# Epoch 00001: val_loss did not improve from 0.56162
# Epoch 2/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.6293 - accuracy: 0.2585 - val_loss: 0.5897 - val_accuracy: 0.2611
#
# Epoch 00002: val_loss did not improve from 0.56162
# Epoch 3/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5842 - accuracy: 0.2597 - val_loss: 0.5675 - val_accuracy: 0.2417
#
# Epoch 00003: val_loss did not improve from 0.56162
# Epoch 4/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5724 - accuracy: 0.2500 - val_loss: 0.5630 - val_accuracy: 0.2500
#
# Epoch 00004: val_loss did not improve from 0.56162
# Epoch 5/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5679 - accuracy: 0.2503 - val_loss: 0.5640 - val_accuracy: 0.2500
#
# Epoch 00005: val_loss did not improve from 0.56162
# Epoch 6/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5693 - accuracy: 0.2506 - val_loss: 0.5640 - val_accuracy: 0.2167
#
# Epoch 00006: val_loss did not improve from 0.56162
# Epoch 7/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5659 - accuracy: 0.2618 - val_loss: 0.5638 - val_accuracy: 0.2167
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00007: val_loss did not improve from 0.56162
# Epoch 8/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5652 - accuracy: 0.2722 - val_loss: 0.5659 - val_accuracy: 0.2194
#
# Epoch 00008: val_loss did not improve from 0.56162
# Epoch 9/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5647 - accuracy: 0.2465 - val_loss: 0.5657 - val_accuracy: 0.2222
#
# Epoch 00009: val_loss did not improve from 0.56162
# Epoch 10/100
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5652 - accuracy: 0.2391 - val_loss: 0.5651 - val_accuracy: 0.2333
#
# Epoch 00010: val_loss did not improve from 0.56162
# Epoch 11/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5633 - accuracy: 0.2719 - val_loss: 0.5637 - val_accuracy: 0.2333
#
# Epoch 00011: val_loss did not improve from 0.56162
# Epoch 12/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5642 - accuracy: 0.2411 - val_loss: 0.5648 - val_accuracy: 0.2333
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00012: val_loss did not improve from 0.56162
# Epoch 13/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5632 - accuracy: 0.2762 - val_loss: 0.5641 - val_accuracy: 0.2250
#
# Epoch 00013: val_loss did not improve from 0.56162
# Epoch 14/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5623 - accuracy: 0.2740 - val_loss: 0.5637 - val_accuracy: 0.2222
#
# Epoch 00014: val_loss did not improve from 0.56162
# Epoch 15/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5631 - accuracy: 0.2594 - val_loss: 0.5647 - val_accuracy: 0.2139
#
# Epoch 00015: val_loss did not improve from 0.56162
# Epoch 16/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5611 - accuracy: 0.2878 - val_loss: 0.5649 - val_accuracy: 0.2111
#
# Epoch 00016: val_loss did not improve from 0.56162
# Epoch 17/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5632 - accuracy: 0.2686 - val_loss: 0.5652 - val_accuracy: 0.2083
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00017: val_loss did not improve from 0.56162
# Epoch 18/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5637 - accuracy: 0.2646 - val_loss: 0.5648 - val_accuracy: 0.2167
#
# Epoch 00018: val_loss did not improve from 0.56162
# Epoch 19/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5607 - accuracy: 0.2702 - val_loss: 0.5644 - val_accuracy: 0.2139
#
# Epoch 00019: val_loss did not improve from 0.56162
# Epoch 20/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5625 - accuracy: 0.2772 - val_loss: 0.5648 - val_accuracy: 0.2167
#
# Epoch 00020: val_loss did not improve from 0.56162
# Epoch 21/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5621 - accuracy: 0.2845 - val_loss: 0.5645 - val_accuracy: 0.2306
#
# Epoch 00021: val_loss did not improve from 0.56162
# Epoch 22/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5621 - accuracy: 0.2516 - val_loss: 0.5647 - val_accuracy: 0.2194
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00022: val_loss did not improve from 0.56162
# Epoch 23/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5621 - accuracy: 0.2566 - val_loss: 0.5645 - val_accuracy: 0.2333
#
# Epoch 00023: val_loss did not improve from 0.56162
# Epoch 24/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5620 - accuracy: 0.2690 - val_loss: 0.5645 - val_accuracy: 0.2250
#
# Epoch 00024: val_loss did not improve from 0.56162
# Epoch 00024: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5636 - accuracy: 0.2225
# Val Score:  [0.5636175274848938, 0.2224999964237213]
# ====================================================================================
#
#
# Training on Fold:  3
# Epoch 1/100
# 102/102 [==============================] - 2s 12ms/step - loss: 0.7689 - accuracy: 0.2392 - val_loss: 0.6312 - val_accuracy: 0.2722
#
# Epoch 00001: val_loss did not improve from 0.56162
# Epoch 2/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.6316 - accuracy: 0.2566 - val_loss: 0.5839 - val_accuracy: 0.2361
#
# Epoch 00002: val_loss did not improve from 0.56162
# Epoch 3/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5837 - accuracy: 0.2682 - val_loss: 0.5687 - val_accuracy: 0.2583
#
# Epoch 00003: val_loss did not improve from 0.56162
# Epoch 4/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5703 - accuracy: 0.2751 - val_loss: 0.5659 - val_accuracy: 0.2333
#
# Epoch 00004: val_loss did not improve from 0.56162
# Epoch 5/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5688 - accuracy: 0.2692 - val_loss: 0.5650 - val_accuracy: 0.2444
#
# Epoch 00005: val_loss did not improve from 0.56162
# Epoch 6/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5691 - accuracy: 0.2451 - val_loss: 0.5642 - val_accuracy: 0.2444
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.56162
# Epoch 7/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5679 - accuracy: 0.2596 - val_loss: 0.5652 - val_accuracy: 0.2278
#
# Epoch 00007: val_loss did not improve from 0.56162
# Epoch 8/100
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5660 - accuracy: 0.2675 - val_loss: 0.5655 - val_accuracy: 0.2306
#
# Epoch 00008: val_loss did not improve from 0.56162
# Epoch 9/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5665 - accuracy: 0.2504 - val_loss: 0.5644 - val_accuracy: 0.2167
#
# Epoch 00009: val_loss did not improve from 0.56162
# Epoch 10/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5677 - accuracy: 0.2566 - val_loss: 0.5654 - val_accuracy: 0.2278
#
# Epoch 00010: val_loss did not improve from 0.56162
# Epoch 11/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5655 - accuracy: 0.2428 - val_loss: 0.5665 - val_accuracy: 0.2111
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00011: val_loss did not improve from 0.56162
# Epoch 12/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5636 - accuracy: 0.2594 - val_loss: 0.5665 - val_accuracy: 0.1889
#
# Epoch 00012: val_loss did not improve from 0.56162
# Epoch 13/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5640 - accuracy: 0.2580 - val_loss: 0.5664 - val_accuracy: 0.1917
#
# Epoch 00013: val_loss did not improve from 0.56162
# Epoch 14/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5647 - accuracy: 0.2560 - val_loss: 0.5657 - val_accuracy: 0.2139
#
# Epoch 00014: val_loss did not improve from 0.56162
# Epoch 15/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5638 - accuracy: 0.2656 - val_loss: 0.5667 - val_accuracy: 0.1944
#
# Epoch 00015: val_loss did not improve from 0.56162
# Epoch 16/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5630 - accuracy: 0.2556 - val_loss: 0.5658 - val_accuracy: 0.1750
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00016: val_loss did not improve from 0.56162
# Epoch 17/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5623 - accuracy: 0.2671 - val_loss: 0.5654 - val_accuracy: 0.1833
#
# Epoch 00017: val_loss did not improve from 0.56162
# Epoch 18/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5631 - accuracy: 0.2557 - val_loss: 0.5657 - val_accuracy: 0.1972
#
# Epoch 00018: val_loss did not improve from 0.56162
# Epoch 19/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5650 - accuracy: 0.2569 - val_loss: 0.5652 - val_accuracy: 0.1944
#
# Epoch 00019: val_loss did not improve from 0.56162
# Epoch 20/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5651 - accuracy: 0.2524 - val_loss: 0.5655 - val_accuracy: 0.1889
#
# Epoch 00020: val_loss did not improve from 0.56162
# Epoch 21/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5625 - accuracy: 0.2735 - val_loss: 0.5650 - val_accuracy: 0.2306
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00021: val_loss did not improve from 0.56162
# Epoch 22/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5628 - accuracy: 0.2702 - val_loss: 0.5651 - val_accuracy: 0.2111
#
# Epoch 00022: val_loss did not improve from 0.56162
# Epoch 23/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5637 - accuracy: 0.2756 - val_loss: 0.5653 - val_accuracy: 0.2000
#
# Epoch 00023: val_loss did not improve from 0.56162
# Epoch 00023: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5648 - accuracy: 0.2425
# Val Score:  [0.5648403167724609, 0.24250000715255737]
# ====================================================================================
#
#
# Training on Fold:  4
# Epoch 1/100
# 102/102 [==============================] - 2s 11ms/step - loss: 0.7606 - accuracy: 0.2532 - val_loss: 0.6216 - val_accuracy: 0.2583
#
# Epoch 00001: val_loss did not improve from 0.56162
# Epoch 2/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.6305 - accuracy: 0.2368 - val_loss: 0.5743 - val_accuracy: 0.2556
#
# Epoch 00002: val_loss did not improve from 0.56162
# Epoch 3/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5828 - accuracy: 0.2586 - val_loss: 0.5651 - val_accuracy: 0.2556
#
# Epoch 00003: val_loss did not improve from 0.56162
# Epoch 4/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5728 - accuracy: 0.2380 - val_loss: 0.5657 - val_accuracy: 0.2167
#
# Epoch 00004: val_loss did not improve from 0.56162
# Epoch 5/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5679 - accuracy: 0.2495 - val_loss: 0.5648 - val_accuracy: 0.2639
#
# Epoch 00005: val_loss did not improve from 0.56162
# Epoch 6/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5696 - accuracy: 0.2364 - val_loss: 0.5644 - val_accuracy: 0.2556
#
# Epoch 00006: val_loss did not improve from 0.56162
# Epoch 7/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5662 - accuracy: 0.2551 - val_loss: 0.5658 - val_accuracy: 0.2250
#
# Epoch 00007: val_loss did not improve from 0.56162
# Epoch 8/100
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5657 - accuracy: 0.2503 - val_loss: 0.5667 - val_accuracy: 0.2111
#
# Epoch 00008: val_loss did not improve from 0.56162
# Epoch 9/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5664 - accuracy: 0.2434 - val_loss: 0.5661 - val_accuracy: 0.2111
#
# Epoch 00009: val_loss did not improve from 0.56162
# Epoch 10/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5657 - accuracy: 0.2491 - val_loss: 0.5671 - val_accuracy: 0.2167
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00010: val_loss did not improve from 0.56162
# Epoch 11/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5636 - accuracy: 0.2437 - val_loss: 0.5660 - val_accuracy: 0.2333
#
# Epoch 00011: val_loss did not improve from 0.56162
# Epoch 12/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5625 - accuracy: 0.2638 - val_loss: 0.5649 - val_accuracy: 0.2694
#
# Epoch 00012: val_loss did not improve from 0.56162
# Epoch 13/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5643 - accuracy: 0.2628 - val_loss: 0.5649 - val_accuracy: 0.2472
#
# Epoch 00013: val_loss did not improve from 0.56162
# Epoch 14/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5652 - accuracy: 0.2459 - val_loss: 0.5638 - val_accuracy: 0.2556
#
# Epoch 00014: val_loss did not improve from 0.56162
# Epoch 15/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5618 - accuracy: 0.2759 - val_loss: 0.5632 - val_accuracy: 0.2694
#
# Epoch 00015: val_loss did not improve from 0.56162
# Epoch 16/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5641 - accuracy: 0.2626 - val_loss: 0.5650 - val_accuracy: 0.2306
#
# Epoch 00016: val_loss did not improve from 0.56162
# Epoch 17/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5621 - accuracy: 0.2839 - val_loss: 0.5656 - val_accuracy: 0.2417
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00017: val_loss did not improve from 0.56162
# Epoch 18/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5609 - accuracy: 0.2675 - val_loss: 0.5653 - val_accuracy: 0.2389
#
# Epoch 00018: val_loss did not improve from 0.56162
# Epoch 19/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5629 - accuracy: 0.2634 - val_loss: 0.5650 - val_accuracy: 0.2417
#
# Epoch 00019: val_loss did not improve from 0.56162
# Epoch 20/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5615 - accuracy: 0.2748 - val_loss: 0.5644 - val_accuracy: 0.2528
#
# Epoch 00020: val_loss did not improve from 0.56162
# Epoch 21/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5627 - accuracy: 0.2621 - val_loss: 0.5646 - val_accuracy: 0.2611
#
# Epoch 00021: val_loss did not improve from 0.56162
# Epoch 22/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5629 - accuracy: 0.2699 - val_loss: 0.5644 - val_accuracy: 0.2528
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00022: val_loss did not improve from 0.56162
# Epoch 23/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5620 - accuracy: 0.2795 - val_loss: 0.5648 - val_accuracy: 0.2500
#
# Epoch 00023: val_loss did not improve from 0.56162
# Epoch 00023: early stopping
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5640 - accuracy: 0.2275
# Val Score:  [0.5639631152153015, 0.22750000655651093]
# ====================================================================================
#
#
# Training on Fold:  5
# Epoch 1/100
# 102/102 [==============================] - 2s 12ms/step - loss: 0.7726 - accuracy: 0.2501 - val_loss: 0.6206 - val_accuracy: 0.2556
#
# Epoch 00001: val_loss did not improve from 0.56162
# Epoch 2/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.6304 - accuracy: 0.2530 - val_loss: 0.5851 - val_accuracy: 0.2750
#
# Epoch 00002: val_loss did not improve from 0.56162
# Epoch 3/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5919 - accuracy: 0.2510 - val_loss: 0.5675 - val_accuracy: 0.2639
#
# Epoch 00003: val_loss did not improve from 0.56162
# Epoch 4/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5708 - accuracy: 0.2555 - val_loss: 0.5650 - val_accuracy: 0.2111
#
# Epoch 00004: val_loss did not improve from 0.56162
# Epoch 5/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5683 - accuracy: 0.2598 - val_loss: 0.5663 - val_accuracy: 0.2000
#
# Epoch 00005: val_loss did not improve from 0.56162
# Epoch 6/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5648 - accuracy: 0.2724 - val_loss: 0.5665 - val_accuracy: 0.2361
#
# Epoch 00006: val_loss did not improve from 0.56162
# Epoch 7/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5637 - accuracy: 0.2644 - val_loss: 0.5663 - val_accuracy: 0.2139
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00007: val_loss did not improve from 0.56162
# Epoch 8/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5648 - accuracy: 0.2584 - val_loss: 0.5670 - val_accuracy: 0.2167
#
# Epoch 00008: val_loss did not improve from 0.56162
# Epoch 9/100
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5643 - accuracy: 0.2604 - val_loss: 0.5681 - val_accuracy: 0.1861
#
# Epoch 00009: val_loss did not improve from 0.56162
# Epoch 10/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5638 - accuracy: 0.2660 - val_loss: 0.5676 - val_accuracy: 0.1944
#
# Epoch 00010: val_loss did not improve from 0.56162
# Epoch 11/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5619 - accuracy: 0.2730 - val_loss: 0.5652 - val_accuracy: 0.2389
#
# Epoch 00011: val_loss did not improve from 0.56162
# Epoch 12/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5642 - accuracy: 0.2568 - val_loss: 0.5662 - val_accuracy: 0.2083
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00012: val_loss did not improve from 0.56162
# Epoch 13/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5643 - accuracy: 0.2538 - val_loss: 0.5662 - val_accuracy: 0.1972
#
# Epoch 00013: val_loss did not improve from 0.56162
# Epoch 14/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5634 - accuracy: 0.2732 - val_loss: 0.5663 - val_accuracy: 0.1972
#
# Epoch 00014: val_loss did not improve from 0.56162
# Epoch 15/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5640 - accuracy: 0.2506 - val_loss: 0.5666 - val_accuracy: 0.1694
#
# Epoch 00015: val_loss did not improve from 0.56162
# Epoch 16/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5631 - accuracy: 0.2633 - val_loss: 0.5659 - val_accuracy: 0.1750
#
# Epoch 00016: val_loss did not improve from 0.56162
# Epoch 17/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5614 - accuracy: 0.2721 - val_loss: 0.5666 - val_accuracy: 0.1917
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00017: val_loss did not improve from 0.56162
# Epoch 18/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5625 - accuracy: 0.2614 - val_loss: 0.5658 - val_accuracy: 0.2139
#
# Epoch 00018: val_loss did not improve from 0.56162
# Epoch 19/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5607 - accuracy: 0.2803 - val_loss: 0.5659 - val_accuracy: 0.2083
#
# Epoch 00019: val_loss did not improve from 0.56162
# Epoch 20/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5622 - accuracy: 0.2744 - val_loss: 0.5657 - val_accuracy: 0.2083
#
# Epoch 00020: val_loss did not improve from 0.56162
# Epoch 21/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5617 - accuracy: 0.2752 - val_loss: 0.5660 - val_accuracy: 0.2083
#
# Epoch 00021: val_loss did not improve from 0.56162
# Epoch 22/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5635 - accuracy: 0.2664 - val_loss: 0.5663 - val_accuracy: 0.1833
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00022: val_loss did not improve from 0.56162
# Epoch 23/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5621 - accuracy: 0.2674 - val_loss: 0.5656 - val_accuracy: 0.2028
#
# Epoch 00023: val_loss did not improve from 0.56162
# Epoch 24/100
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5618 - accuracy: 0.2778 - val_loss: 0.5656 - val_accuracy: 0.2056
#
# Epoch 00024: val_loss did not improve from 0.56162
# Epoch 00024: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5659 - accuracy: 0.2050
# Val Score:  [0.5658660531044006, 0.20499999821186066]
# ====================================================================================

# %%
#Load the model that was saved by ModelCheckpoint
model = load_model('subjek2.h5')

# %%
model.evaluate(test_X, test_y)
#print("Accuracy of the model is - " , model.evaluate(test_X,test_y)[1]*100 , "%")
#plt.bar( model.evaluate(test_X)[1].index,  model.evaluate(test_y)[1])
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5584 - accuracy: 0.2780
# [0.5583935976028442, 0.27799999713897705]

# %%
fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)

ax1.plot(model_history[0].history['accuracy'], label='Training Fold 1 accuration')
ax1.plot(model_history[1].history['accuracy'], label='Training Fold 2 accuration')
ax1.plot(model_history[2].history['accuracy'], label='Training Fold 3 accuration')
ax1.plot(model_history[3].history['accuracy'], label='Training Fold 4 accuration')
ax1.plot(model_history[4].history['accuracy'], label='Training Fold 5 accuration')
ax1.legend()
ax2.plot(model_history[1].history['loss'], label='Training Fold 1 loss')
ax2.plot(model_history[1].history['loss'], label='Training Fold 2 loss')
ax2.plot(model_history[2].history['loss'], label='Training Fold 3 loss')
ax2.plot(model_history[3].history['loss'], label='Training Fold 4 loss ')
ax2.plot(model_history[4].history['loss'], label='Training Fold 5 loss')
ax2.legend()
plt.show()

# %%
fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt1.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[0].history['loss'], label='Train Loss Fold 1', color='black')
plt2.plot(model_history[0].history['val_loss'], label='Val Loss Fold 1', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red')
plt1.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[1].history['loss'], label='Train Loss Fold 2', color='red')
plt2.plot(model_history[1].history['val_loss'], label='Val Loss Fold 2', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green')
plt1.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[2].history['loss'], label='Train Loss Fold 3', color='green')
plt2.plot(model_history[2].history['val_loss'], label='Val Loss Fold 3', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()


fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue')
plt1.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[3].history['loss'], label='Train Loss Fold 4', color='blue')
plt2.plot(model_history[3].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='purple')
plt1.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[4].history['loss'], label='Train Loss Fold 4', color='purple')
plt2.plot(model_history[4].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

# %%
MODEL_NAME ='/content/subjek2.h5' 

#CLIP = True # if your model was trained with np.clip to clip  values
CLIP = False
CLIP_VAL = 8  # if above, what was the value +/-

model = tf.keras.models.load_model(MODEL_NAME)

VALDIR = '/content/drive/MyDrive/Colab Notebooks/tes_data'
ACTIONS =  ["idle","maju","kiri", "kanan"]
PRED_BATCH = 32


def get_val_data(valdir, action, batch_size):

   # argmax_dict = {0: 0, 1: 0, 2: 0,3:0}
    argmax_dict = {2: 0, 0: 0, 1: 0,3:0}
    raw_pred_dict = {0: 0, 1: 0, 2: 0,3:0}

    action_dir = os.path.join(valdir, action)
    for session_file in os.listdir(action_dir):
        filepath = os.path.join(action_dir,session_file)
        if CLIP:
            data = np.clip(np.load(filepath), -CLIP_VAL, CLIP_VAL) / CLIP_VAL
            #print(data)
        else:
            data = np.load(filepath) 
        preds = model.predict([data.reshape(-1, 16, 60,1)], batch_size=batch_size)
        
        for pred in preds:
            argmax = np.argmax(pred)
            argmax_dict[argmax] += 1
            for idx,value in enumerate(pred):
                raw_pred_dict[idx] += value
    
    argmax_pct_dict = {}
    for i in argmax_dict:
        total = 0
        correct = argmax_dict[i]
        for ii in argmax_dict:
            total += argmax_dict[ii]
        argmax_pct_dict[i] = round(correct/total, 4)
    return argmax_dict, raw_pred_dict, argmax_pct_dict


def make_conf_mat(none,left,forward, right):
    action_dict = {"idle":none,"maju": forward, "kiri": left, "kanan": right}
    action_conf_mat = pd.DataFrame(action_dict)
    actions = [i for i in action_dict]

    fig = plt.figure(figsize=(15, 6))
    ax = fig.add_subplot(111)
    ax.matshow(action_conf_mat, cmap=plt.cm.RdYlGn)
    ax.set_xticklabels([""]+actions)
    ax.set_yticklabels([""]+actions)

    for idx, i in enumerate(action_dict):
        for idx2, ii in enumerate(action_dict[i]):
            ax.text(idx, idx2, f"{round(float(action_dict[i][ii]),2)}", va='center', ha='center')
    # Rotate the tick labels and set their alignment.
    
    plt.title("Matrik data")
    plt.ylabel("Predicted Action")
    fig.tight_layout()
    plt.show()



forward_argmax_dict, forward_raw_pred_dict, forward_argmax_pct_dict = get_val_data(VALDIR, "maju", PRED_BATCH)
none_argmax_dict, none_raw_pred_dict, none_argmax_pct_dict = get_val_data(VALDIR, "idle", PRED_BATCH)
left_argmax_dict, left_raw_pred_dict, left_argmax_pct_dict = get_val_data(VALDIR, "kiri", PRED_BATCH)
right_argmax_dict, right_raw_pred_dict, right_argmax_pct_dict = get_val_data(VALDIR, "kanan", PRED_BATCH)
make_conf_mat(none_argmax_pct_dict,forward_argmax_pct_dict,left_argmax_pct_dict,  right_argmax_pct_dict)

# %%
from sklearn.metrics import roc_curve, auc
#y_score = clf.decision_function(xval)
y_score = model.predict(test_X)

#Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()


# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(test_y[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
    
    
print("roc_auc:",sum(roc_auc.values())/4)
ACTIONS =  ["idle","maju","kiri", "kanan"]
for i in range(0,4):
    plt.figure()
    fig, ax = plt.subplots(figsize=(5,5))
    plt.plot(fpr[i], tpr[i],linewidth=3)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    #plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % ACTIONS[i])
    plt.title('%s -ROC curve (area = %0.2f)' % (ACTIONS[i],roc_auc[i]))
    
    plt.legend(loc="lower right")
    plt.show()
# Out:
# roc_auc: 0.56243

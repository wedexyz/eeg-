# %% [markdown]
# <a href="https://colab.research.google.com/github/wedexyz/eeg-/blob/main/CNN%2BReduceLe%2BCrossVall%2BROcVS4_8chanel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.19.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.0.0)

# %%
pip install --user --upgrade tensorflow-model-optimization
# Out:
# Collecting tensorflow-model-optimization
#   Downloading https://files.pythonhosted.org/packages/55/38/4fd48ea1bfcb0b6e36d949025200426fe9c3a8bfae029f0973d85518fa5a/tensorflow_model_optimization-0.5.0-py2.py3-none-any.whl (172kB)
#      |████████████████████████████████| 174kB 9.1MB/s
# Requirement already satisfied, skipping upgrade: six~=1.10 in /usr/local/lib/python3.6/dist-packages (from tensorflow-model-optimization) (1.15.0)
# Requirement already satisfied, skipping upgrade: numpy~=1.14 in /usr/local/lib/python3.6/dist-packages (from tensorflow-model-optimization) (1.19.4)
# Requirement already satisfied, skipping upgrade: dm-tree~=0.1.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-model-optimization) (0.1.5)
# Installing collected packages: tensorflow-model-optimization
# Successfully installed tensorflow-model-optimization-0.5.0

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.models import Sequential,load_model
#from keras.layers import Dense, Dropout
#from keras.layers import Embedding
#from keras.layers import LSTM, BatchNormalization, Conv2D, Flatten, MaxPooling2D, Dropout
#from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Conv2D , MaxPooling2D , Flatten , Dropout , BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping


import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
import pandas as pd
import os
import random
import time
import os

#from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau


from scipy import signal
from scipy.fft import fftshift

# %%
idle = np.load("/content/drive/MyDrive/Colab Notebooks/data8/idle/1608706768.npy")
kanan = np.load("/content/drive/MyDrive/Colab Notebooks/data8/kanan/1608707012.npy")
kiri = np.load("/content/drive/MyDrive/Colab Notebooks/data8/kiri/1608707050.npy")
maju = np.load("/content/drive/MyDrive/Colab Notebooks/data8/maju/1608706976.npy")

kelas1=idle[0][16]
kelas2=maju[0][16]
kelas3=kanan[0][16]
kelas4=kiri[0][16]

kelas1a=idle[175]
kelas2a=maju[175]
kelas3a=kanan[175]
kelas4a=kiri[175]

#print(idlea.shape)



f1, t1,Sxx= signal.spectrogram(kelas1,fs=60, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd',
                            )
dbs1 = 10*np.log10(Sxx)
f2, t2,Sxx= signal.spectrogram(kelas2,fs=120, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd',
                            )
dbs2 = 10*np.log10(Sxx)
f3, t3,Sxx= signal.spectrogram(kelas3,fs=120, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )
dbs3 = 10*np.log10(Sxx)
f4, t4,Sxx= signal.spectrogram(kelas4,fs=120, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )  
dbs4 = 10*np.log10(Sxx)



fig, axs = plt.subplots(nrows=4, ncols=4,figsize=(20,10))
axs = axs.flatten()

axs[0].set_title("siggle")
axs[0].plot(kelas1)

axs[1].set_title("global")
axs[1].plot(kelas1a)

axs[2].set_title("Spectogram")
axs[2].pcolormesh(t1, f1,dbs1,  
                  shading='gouraud',
                  cmap='nipy_spectral')

cwt1 = signal.cwt(kelas1,signal.ricker,widths=np.arange(1,50))
cwt2 = signal.cwt(kelas2,signal.ricker,widths=np.arange(1,50))
cwt3 = signal.cwt(kelas3,signal.ricker,widths=np.arange(1,50))
cwt4 = signal.cwt(kelas4,signal.ricker,widths=np.arange(1,50))
axs[3].set_title("wavelet")
axs[3].imshow(cwt1,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt1).max(),vmin=-abs(cwt1).max())

axs[4].plot(kelas2)
axs[5].plot(kelas2a)
axs[6].pcolormesh(t2, f2,dbs2,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[7].imshow(cwt2,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt2).max(),vmin=-abs(cwt2).max())

axs[8].plot(kelas3)
axs[9].plot(kelas3a)
axs[10].pcolormesh(t3, f3,dbs3,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[11].imshow(cwt3,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt3).max(),vmin=-abs(cwt3).max())

axs[12].plot(kelas4)
axs[13].plot(kelas4a)
axs[14].pcolormesh(t4, f4,dbs4,  
                  shading='gouraud',
                  cmap='viridis')
axs[15].imshow(cwt4,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt4).max(),vmin=-abs(cwt4).max())
plt.show()

# %%
ACTIONS = ["kiri", "maju","idle","kanan"]
#reshape = (-1,16, 60,1)
reshape = (-1,8, 60,1)

#reshape(-1,28,28,1)

# %%
def create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/data8"):
    training_data = {}
    for action in ACTIONS:
        if action not in training_data:
            training_data[action] = []
        data_dir = os.path.join(starting_dir,action)
        for item in os.listdir(data_dir):
            data = np.load(os.path.join(data_dir, item))
            for item in data:
                training_data[action].append(item)

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)

    for action in ACTIONS:
        np.random.shuffle(training_data[action])  
        training_data[action] = training_data[action][:min(lengths)]

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)
    combined_data = []
    for action in ACTIONS:
        for data in training_data[action]:
            if action == "kiri":
                combined_data.append([data, [1, 0, 0,0]])
            elif action == "maju":
                combined_data.append([data, [0, 1, 0, 0]])
            elif action == "idle":
                combined_data.append([data, [0, 0, 1, 0]])
            elif action == "kanan":
                combined_data.append([data, [0, 0, 0, 1]])

    np.random.shuffle(combined_data)
    print("length:",len(combined_data))
    return combined_data

# %%
print("creating training data")
traindata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/data8")
train_X = []
train_y = []

for X, y in traindata:
    train_X.append(X)
    train_y.append(y)
# Out:
# creating training data
# [250, 250, 250, 250]
# [250, 250, 250, 250]
# length: 1000

# %%
print("creating testing data")
testdata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/data8")
test_X = []
test_y = []

for X, y in testdata:
    test_X.append(X)
    test_y.append(y)

train_X = np.array(train_X).reshape(reshape)
test_X = np.array(test_X).reshape(reshape)


train_y = np.array(train_y)
test_y = np.array(test_y)
print(train_y.shape)
print(test_y.shape)
# Out:
# creating testing data
# [250, 250, 250, 250]
# [250, 250, 250, 250]
# length: 1000
# (1000, 4)
# (1000, 4)

# %%
import seaborn as sns
ye=pd.DataFrame(train_y)

ye.columns=["kiri", "maju","idle","kanan"]
categories = list(ye.columns.values)
sns.set(font_scale = 1)
plt.figure(figsize=(10,8))
ax= sns.barplot(categories, ye.iloc[:,0:].sum().values)
plt.title("Number of samples labeled as active (1) out of {0} length data".format((ye.shape[0])),fontsize=20)

plt.ylabel('Number of events', fontsize=18)
plt.xlabel('Event Type ', fontsize=12)
#adding the text labels
rects = ax.patches
labels = ye.iloc[:,0:].sum().values

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom', fontsize=10)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# With data augmentation to prevent overfitting
'''
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(train_X)
'''
# Out:
# '\ndatagen = ImageDataGenerator(\n        featurewise_center=False,  # set input mean to 0 over the dataset\n        samplewise_center=False,  # set each sample mean to 0\n        featurewise_std_normalization=False,  # divide inputs by std of the dataset\n        samplewise_std_normalization=False,  # divide each input by its std\n        zca_whitening=False,  # apply ZCA whitening\n        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)\n        zoom_range = 0.1, # Randomly zoom image \n        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)\n        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)\n        horizontal_flip=False,  # randomly flip images\n        vertical_flip=False)  # randomly flip images\n\n\ndatagen.fit(train_X)\n'

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1,factor=0.5, min_lr=0.0001)

# %%
#def cnn_model(size, num_cnn_layers):

def cnn_model():    

    model = Sequential()
    
    model.add(Conv2D(filters = 64, kernel_size = (8,8), padding = "same", activation = "relu", input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (4,4)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Conv2D(filters = 64, kernel_size = (4,4), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Conv2D(filters = 64, kernel_size = (2,2), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (1,1)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Flatten())
    
    model.add(Dense(32, activation = "relu"))
    model.add(BatchNormalization())
    
    model.add(Dense(4, activation = "sigmoid"))
   
    #adam = Adam(lr = 0.001)
    model.compile(optimizer ="adam", loss = "binary_crossentropy", metrics = ['accuracy'])
    #model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
 
    
    return model

# %%
#model = cnn_model(IMAGE_SIZE, 2)
model = cnn_model()
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 8, 60, 64)         4160
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 2, 15, 64)         0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 2, 15, 64)         0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 2, 15, 64)         256
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 2, 15, 64)         65600
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 1, 7, 64)          0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 1, 7, 64)          0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 1, 7, 64)          256
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 1, 7, 64)          16448
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 1, 7, 64)          0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1, 7, 64)          0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 1, 7, 64)          256
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 448)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                14368
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 32)                128
# _________________________________________________________________
# dense_13 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 101,604
# Trainable params: 101,156
# Non-trainable params: 448
# _________________________________________________________________

# %%
#set early stopping criteria
pat = 5
#this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='loss', patience=pat, verbose=1)

#define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('subjek1.h5', verbose=1, save_best_only=True)

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=100, BATCH_SIZE=32):
    model = None
    #model = cnn_model(IMAGE_SIZE, 2)
    model = cnn_model()
    #Model = model
   # results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[early_stopping, model_checkpoint], 
   #           verbose=1, validation_split=0.1) 
    results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[learning_rate_reduction,early_stopping, model_checkpoint], 
              verbose=1, validation_split=0.1)   
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs=100
batch_size=32

#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(train_X, train_y, test_size=0.2, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
   
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 23/23 [==============================] - 1s 16ms/step - loss: 0.7373 - accuracy: 0.4310 - val_loss: 0.6137 - val_accuracy: 0.4750
#
# Epoch 00001: val_loss improved from inf to 0.61372, saving model to subjek1.h5
# Epoch 2/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5535 - accuracy: 0.5700 - val_loss: 0.5769 - val_accuracy: 0.6000
#
# Epoch 00002: val_loss improved from 0.61372 to 0.57689, saving model to subjek1.h5
# Epoch 3/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4902 - accuracy: 0.6531 - val_loss: 0.5353 - val_accuracy: 0.6125
#
# Epoch 00003: val_loss improved from 0.57689 to 0.53533, saving model to subjek1.h5
# Epoch 4/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4641 - accuracy: 0.6496 - val_loss: 0.4846 - val_accuracy: 0.6250
#
# Epoch 00004: val_loss improved from 0.53533 to 0.48460, saving model to subjek1.h5
# Epoch 5/100
# 23/23 [==============================] - 0s 21ms/step - loss: 0.4003 - accuracy: 0.7235 - val_loss: 0.4473 - val_accuracy: 0.6500
#
# Epoch 00005: val_loss improved from 0.48460 to 0.44730, saving model to subjek1.h5
# Epoch 6/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.3946 - accuracy: 0.7155 - val_loss: 0.4034 - val_accuracy: 0.6500
#
# Epoch 00006: val_loss improved from 0.44730 to 0.40336, saving model to subjek1.h5
# Epoch 7/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3795 - accuracy: 0.7138 - val_loss: 0.3907 - val_accuracy: 0.6750
#
# Epoch 00007: val_loss improved from 0.40336 to 0.39074, saving model to subjek1.h5
# Epoch 8/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3483 - accuracy: 0.7226 - val_loss: 0.3568 - val_accuracy: 0.7000
#
# Epoch 00008: val_loss improved from 0.39074 to 0.35679, saving model to subjek1.h5
# Epoch 9/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3120 - accuracy: 0.7753 - val_loss: 0.3303 - val_accuracy: 0.7625
#
# Epoch 00009: val_loss improved from 0.35679 to 0.33029, saving model to subjek1.h5
# Epoch 10/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3106 - accuracy: 0.7368 - val_loss: 0.3051 - val_accuracy: 0.7875
#
# Epoch 00010: val_loss improved from 0.33029 to 0.30506, saving model to subjek1.h5
# Epoch 11/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2811 - accuracy: 0.7777 - val_loss: 0.3041 - val_accuracy: 0.7750
#
# Epoch 00011: val_loss improved from 0.30506 to 0.30415, saving model to subjek1.h5
# Epoch 12/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2695 - accuracy: 0.7742 - val_loss: 0.2745 - val_accuracy: 0.8125
#
# Epoch 00012: val_loss improved from 0.30415 to 0.27451, saving model to subjek1.h5
# Epoch 13/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2777 - accuracy: 0.7489 - val_loss: 0.2824 - val_accuracy: 0.8000
#
# Epoch 00013: val_loss did not improve from 0.27451
# Epoch 14/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2489 - accuracy: 0.7960 - val_loss: 0.2681 - val_accuracy: 0.8125
#
# Epoch 00014: val_loss improved from 0.27451 to 0.26806, saving model to subjek1.h5
# Epoch 15/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2365 - accuracy: 0.8278 - val_loss: 0.2414 - val_accuracy: 0.8250
#
# Epoch 00015: val_loss improved from 0.26806 to 0.24142, saving model to subjek1.h5
# Epoch 16/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2184 - accuracy: 0.8470 - val_loss: 0.2371 - val_accuracy: 0.8250
#
# Epoch 00016: val_loss improved from 0.24142 to 0.23710, saving model to subjek1.h5
# Epoch 17/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2254 - accuracy: 0.8177 - val_loss: 0.2235 - val_accuracy: 0.8375
#
# Epoch 00017: val_loss improved from 0.23710 to 0.22347, saving model to subjek1.h5
# Epoch 18/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2103 - accuracy: 0.8365 - val_loss: 0.2291 - val_accuracy: 0.8125
#
# Epoch 00018: val_loss did not improve from 0.22347
# Epoch 19/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2002 - accuracy: 0.8575 - val_loss: 0.2307 - val_accuracy: 0.8000
#
# Epoch 00019: val_loss did not improve from 0.22347
# Epoch 20/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2090 - accuracy: 0.8369 - val_loss: 0.2237 - val_accuracy: 0.7875
#
# Epoch 00020: val_loss did not improve from 0.22347
# Epoch 21/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1958 - accuracy: 0.8477 - val_loss: 0.2213 - val_accuracy: 0.7750
#
# Epoch 00021: val_loss improved from 0.22347 to 0.22129, saving model to subjek1.h5
# Epoch 22/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1730 - accuracy: 0.8819 - val_loss: 0.1953 - val_accuracy: 0.8250
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00022: val_loss improved from 0.22129 to 0.19534, saving model to subjek1.h5
# Epoch 23/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1717 - accuracy: 0.8643 - val_loss: 0.2031 - val_accuracy: 0.8125
#
# Epoch 00023: val_loss did not improve from 0.19534
# Epoch 24/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1809 - accuracy: 0.8690 - val_loss: 0.2095 - val_accuracy: 0.8000
#
# Epoch 00024: val_loss did not improve from 0.19534
# Epoch 25/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1415 - accuracy: 0.8977 - val_loss: 0.2038 - val_accuracy: 0.7750
#
# Epoch 00025: val_loss did not improve from 0.19534
# Epoch 26/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1604 - accuracy: 0.8741 - val_loss: 0.1870 - val_accuracy: 0.8125
#
# Epoch 00026: val_loss improved from 0.19534 to 0.18696, saving model to subjek1.h5
# Epoch 27/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1342 - accuracy: 0.9117 - val_loss: 0.1785 - val_accuracy: 0.8375
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00027: val_loss improved from 0.18696 to 0.17852, saving model to subjek1.h5
# Epoch 28/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1413 - accuracy: 0.8971 - val_loss: 0.1826 - val_accuracy: 0.8250
#
# Epoch 00028: val_loss did not improve from 0.17852
# Epoch 29/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1361 - accuracy: 0.9175 - val_loss: 0.1598 - val_accuracy: 0.8375
#
# Epoch 00029: val_loss improved from 0.17852 to 0.15981, saving model to subjek1.h5
# Epoch 30/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1326 - accuracy: 0.9044 - val_loss: 0.1547 - val_accuracy: 0.8500
#
# Epoch 00030: val_loss improved from 0.15981 to 0.15473, saving model to subjek1.h5
# Epoch 31/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1346 - accuracy: 0.9074 - val_loss: 0.1498 - val_accuracy: 0.8500
#
# Epoch 00031: val_loss improved from 0.15473 to 0.14982, saving model to subjek1.h5
# Epoch 32/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1400 - accuracy: 0.9013 - val_loss: 0.1399 - val_accuracy: 0.8500
#
# Epoch 00032: val_loss improved from 0.14982 to 0.13993, saving model to subjek1.h5
# Epoch 33/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1399 - accuracy: 0.8983 - val_loss: 0.1413 - val_accuracy: 0.8500
#
# Epoch 00033: val_loss did not improve from 0.13993
# Epoch 34/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1213 - accuracy: 0.9211 - val_loss: 0.1327 - val_accuracy: 0.8625
#
# Epoch 00034: val_loss improved from 0.13993 to 0.13271, saving model to subjek1.h5
# Epoch 35/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1146 - accuracy: 0.9342 - val_loss: 0.1296 - val_accuracy: 0.8625
#
# Epoch 00035: val_loss improved from 0.13271 to 0.12955, saving model to subjek1.h5
# Epoch 36/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1328 - accuracy: 0.9072 - val_loss: 0.1197 - val_accuracy: 0.8750
#
# Epoch 00036: val_loss improved from 0.12955 to 0.11972, saving model to subjek1.h5
# Epoch 37/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1141 - accuracy: 0.9368 - val_loss: 0.1161 - val_accuracy: 0.8875
#
# Epoch 00037: val_loss improved from 0.11972 to 0.11614, saving model to subjek1.h5
# Epoch 38/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1334 - accuracy: 0.9117 - val_loss: 0.1127 - val_accuracy: 0.8750
#
# Epoch 00038: val_loss improved from 0.11614 to 0.11269, saving model to subjek1.h5
# Epoch 39/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1236 - accuracy: 0.9194 - val_loss: 0.1068 - val_accuracy: 0.9000
#
# Epoch 00039: val_loss improved from 0.11269 to 0.10680, saving model to subjek1.h5
# Epoch 40/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1289 - accuracy: 0.9046 - val_loss: 0.1105 - val_accuracy: 0.9000
#
# Epoch 00040: val_loss did not improve from 0.10680
# Epoch 41/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1224 - accuracy: 0.9112 - val_loss: 0.1086 - val_accuracy: 0.9000
#
# Epoch 00041: val_loss did not improve from 0.10680
# Epoch 42/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1149 - accuracy: 0.9177 - val_loss: 0.1009 - val_accuracy: 0.9500
#
# Epoch 00042: val_loss improved from 0.10680 to 0.10091, saving model to subjek1.h5
# Epoch 43/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1242 - accuracy: 0.9095 - val_loss: 0.1018 - val_accuracy: 0.9625
#
# Epoch 00043: val_loss did not improve from 0.10091
# Epoch 44/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1148 - accuracy: 0.9393 - val_loss: 0.1071 - val_accuracy: 0.9250
#
# Epoch 00044: val_loss did not improve from 0.10091
# Epoch 45/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1207 - accuracy: 0.8991 - val_loss: 0.0919 - val_accuracy: 0.9750
#
# Epoch 00045: val_loss improved from 0.10091 to 0.09189, saving model to subjek1.h5
# Epoch 46/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1149 - accuracy: 0.9186 - val_loss: 0.0923 - val_accuracy: 0.9750
#
# Epoch 00046: val_loss did not improve from 0.09189
# Epoch 47/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1133 - accuracy: 0.9179 - val_loss: 0.0894 - val_accuracy: 0.9875
#
# Epoch 00047: val_loss improved from 0.09189 to 0.08937, saving model to subjek1.h5
# Epoch 48/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1092 - accuracy: 0.9155 - val_loss: 0.0914 - val_accuracy: 0.9750
#
# Epoch 00048: val_loss did not improve from 0.08937
# Epoch 49/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1206 - accuracy: 0.9130 - val_loss: 0.0888 - val_accuracy: 0.9375
#
# Epoch 00049: val_loss improved from 0.08937 to 0.08883, saving model to subjek1.h5
# Epoch 50/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1125 - accuracy: 0.9228 - val_loss: 0.0889 - val_accuracy: 0.9750
#
# Epoch 00050: val_loss did not improve from 0.08883
# Epoch 51/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1046 - accuracy: 0.9390 - val_loss: 0.0855 - val_accuracy: 0.9875
#
# Epoch 00051: val_loss improved from 0.08883 to 0.08555, saving model to subjek1.h5
# Epoch 52/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1025 - accuracy: 0.9382 - val_loss: 0.0840 - val_accuracy: 0.9875
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00052: val_loss improved from 0.08555 to 0.08399, saving model to subjek1.h5
# Epoch 53/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0978 - accuracy: 0.9429 - val_loss: 0.0832 - val_accuracy: 0.9875
#
# Epoch 00053: val_loss improved from 0.08399 to 0.08321, saving model to subjek1.h5
# Epoch 54/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1156 - accuracy: 0.9063 - val_loss: 0.0793 - val_accuracy: 0.9875
#
# Epoch 00054: val_loss improved from 0.08321 to 0.07933, saving model to subjek1.h5
# Epoch 55/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0977 - accuracy: 0.9272 - val_loss: 0.0819 - val_accuracy: 0.9875
#
# Epoch 00055: val_loss did not improve from 0.07933
# Epoch 56/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0908 - accuracy: 0.9430 - val_loss: 0.0845 - val_accuracy: 0.9875
#
# Epoch 00056: val_loss did not improve from 0.07933
# Epoch 57/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0940 - accuracy: 0.9340 - val_loss: 0.0851 - val_accuracy: 0.9875
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00057: val_loss did not improve from 0.07933
# Epoch 58/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0877 - accuracy: 0.9436 - val_loss: 0.0814 - val_accuracy: 0.9875
#
# Epoch 00058: val_loss did not improve from 0.07933
# Epoch 59/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1133 - accuracy: 0.9165 - val_loss: 0.0769 - val_accuracy: 0.9875
#
# Epoch 00059: val_loss improved from 0.07933 to 0.07691, saving model to subjek1.h5
# Epoch 60/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1068 - accuracy: 0.9211 - val_loss: 0.0764 - val_accuracy: 0.9875
#
# Epoch 00060: val_loss improved from 0.07691 to 0.07642, saving model to subjek1.h5
# Epoch 61/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0942 - accuracy: 0.9459 - val_loss: 0.0739 - val_accuracy: 0.9875
#
# Epoch 00061: val_loss improved from 0.07642 to 0.07391, saving model to subjek1.h5
# Epoch 00061: early stopping
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0841 - accuracy: 0.9600
# Val Score:  [0.08412055671215057, 0.9599999785423279]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
# 23/23 [==============================] - 1s 14ms/step - loss: 0.7695 - accuracy: 0.3510 - val_loss: 0.6502 - val_accuracy: 0.4750
#
# Epoch 00001: val_loss did not improve from 0.07391
# Epoch 2/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5605 - accuracy: 0.6225 - val_loss: 0.5860 - val_accuracy: 0.5250
#
# Epoch 00002: val_loss did not improve from 0.07391
# Epoch 3/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5145 - accuracy: 0.6292 - val_loss: 0.5346 - val_accuracy: 0.6875
#
# Epoch 00003: val_loss did not improve from 0.07391
# Epoch 4/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4454 - accuracy: 0.6906 - val_loss: 0.4828 - val_accuracy: 0.6625
#
# Epoch 00004: val_loss did not improve from 0.07391
# Epoch 5/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4255 - accuracy: 0.6713 - val_loss: 0.4290 - val_accuracy: 0.6875
#
# Epoch 00005: val_loss did not improve from 0.07391
# Epoch 6/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3989 - accuracy: 0.7067 - val_loss: 0.4073 - val_accuracy: 0.7000
#
# Epoch 00006: val_loss did not improve from 0.07391
# Epoch 7/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3677 - accuracy: 0.7175 - val_loss: 0.3997 - val_accuracy: 0.7000
#
# Epoch 00007: val_loss did not improve from 0.07391
# Epoch 8/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3600 - accuracy: 0.7048 - val_loss: 0.3607 - val_accuracy: 0.7125
#
# Epoch 00008: val_loss did not improve from 0.07391
# Epoch 9/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3109 - accuracy: 0.7656 - val_loss: 0.3257 - val_accuracy: 0.7125
#
# Epoch 00009: val_loss did not improve from 0.07391
# Epoch 10/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3039 - accuracy: 0.7432 - val_loss: 0.3227 - val_accuracy: 0.7375
#
# Epoch 00010: val_loss did not improve from 0.07391
# Epoch 11/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2991 - accuracy: 0.7691 - val_loss: 0.3256 - val_accuracy: 0.7750
#
# Epoch 00011: val_loss did not improve from 0.07391
# Epoch 12/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2804 - accuracy: 0.7762 - val_loss: 0.2891 - val_accuracy: 0.8000
#
# Epoch 00012: val_loss did not improve from 0.07391
# Epoch 13/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2670 - accuracy: 0.7807 - val_loss: 0.2701 - val_accuracy: 0.8125
#
# Epoch 00013: val_loss did not improve from 0.07391
# Epoch 14/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2412 - accuracy: 0.8110 - val_loss: 0.2561 - val_accuracy: 0.8125
#
# Epoch 00014: val_loss did not improve from 0.07391
# Epoch 15/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2360 - accuracy: 0.8078 - val_loss: 0.2437 - val_accuracy: 0.8250
#
# Epoch 00015: val_loss did not improve from 0.07391
# Epoch 16/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2186 - accuracy: 0.8160 - val_loss: 0.2231 - val_accuracy: 0.8375
#
# Epoch 00016: val_loss did not improve from 0.07391
# Epoch 17/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2413 - accuracy: 0.8008 - val_loss: 0.2079 - val_accuracy: 0.8375
#
# Epoch 00017: val_loss did not improve from 0.07391
# Epoch 18/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2103 - accuracy: 0.8560 - val_loss: 0.2047 - val_accuracy: 0.8375
#
# Epoch 00018: val_loss did not improve from 0.07391
# Epoch 19/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2029 - accuracy: 0.8311 - val_loss: 0.1920 - val_accuracy: 0.8875
#
# Epoch 00019: val_loss did not improve from 0.07391
# Epoch 20/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1819 - accuracy: 0.8595 - val_loss: 0.1761 - val_accuracy: 0.9500
#
# Epoch 00020: val_loss did not improve from 0.07391
# Epoch 21/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1696 - accuracy: 0.8902 - val_loss: 0.1833 - val_accuracy: 0.8875
#
# Epoch 00021: val_loss did not improve from 0.07391
# Epoch 22/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1688 - accuracy: 0.8755 - val_loss: 0.1670 - val_accuracy: 0.8750
#
# Epoch 00022: val_loss did not improve from 0.07391
# Epoch 23/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1630 - accuracy: 0.8867 - val_loss: 0.1479 - val_accuracy: 0.9375
#
# Epoch 00023: val_loss did not improve from 0.07391
# Epoch 24/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1705 - accuracy: 0.8771 - val_loss: 0.1472 - val_accuracy: 0.9250
#
# Epoch 00024: val_loss did not improve from 0.07391
# Epoch 25/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1467 - accuracy: 0.8903 - val_loss: 0.1339 - val_accuracy: 0.9125
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00025: val_loss did not improve from 0.07391
# Epoch 26/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1417 - accuracy: 0.9007 - val_loss: 0.1237 - val_accuracy: 0.9125
#
# Epoch 00026: val_loss did not improve from 0.07391
# Epoch 27/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1588 - accuracy: 0.8919 - val_loss: 0.1334 - val_accuracy: 0.9000
#
# Epoch 00027: val_loss did not improve from 0.07391
# Epoch 28/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1286 - accuracy: 0.9130 - val_loss: 0.1354 - val_accuracy: 0.8750
#
# Epoch 00028: val_loss did not improve from 0.07391
# Epoch 29/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1205 - accuracy: 0.9272 - val_loss: 0.1358 - val_accuracy: 0.8875
#
# Epoch 00029: val_loss did not improve from 0.07391
# Epoch 30/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1134 - accuracy: 0.9439 - val_loss: 0.1265 - val_accuracy: 0.9125
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00030: val_loss did not improve from 0.07391
# Epoch 31/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1450 - accuracy: 0.8890 - val_loss: 0.1075 - val_accuracy: 0.9250
#
# Epoch 00031: val_loss did not improve from 0.07391
# Epoch 32/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1266 - accuracy: 0.9139 - val_loss: 0.1164 - val_accuracy: 0.9375
#
# Epoch 00032: val_loss did not improve from 0.07391
# Epoch 33/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1251 - accuracy: 0.9218 - val_loss: 0.1031 - val_accuracy: 0.9625
#
# Epoch 00033: val_loss did not improve from 0.07391
# Epoch 34/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1128 - accuracy: 0.9202 - val_loss: 0.1010 - val_accuracy: 0.9625
#
# Epoch 00034: val_loss did not improve from 0.07391
# Epoch 35/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1088 - accuracy: 0.9294 - val_loss: 0.0935 - val_accuracy: 0.9625
#
# Epoch 00035: val_loss did not improve from 0.07391
# Epoch 36/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0983 - accuracy: 0.9475 - val_loss: 0.0921 - val_accuracy: 0.9500
#
# Epoch 00036: val_loss did not improve from 0.07391
# Epoch 37/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1178 - accuracy: 0.9069 - val_loss: 0.0904 - val_accuracy: 0.9625
#
# Epoch 00037: val_loss did not improve from 0.07391
# Epoch 38/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0944 - accuracy: 0.9589 - val_loss: 0.0913 - val_accuracy: 0.9625
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00038: val_loss did not improve from 0.07391
# Epoch 39/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1098 - accuracy: 0.9226 - val_loss: 0.0907 - val_accuracy: 0.9625
#
# Epoch 00039: val_loss did not improve from 0.07391
# Epoch 40/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1091 - accuracy: 0.9207 - val_loss: 0.0863 - val_accuracy: 0.9500
#
# Epoch 00040: val_loss did not improve from 0.07391
# Epoch 41/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0953 - accuracy: 0.9483 - val_loss: 0.0825 - val_accuracy: 0.9500
#
# Epoch 00041: val_loss did not improve from 0.07391
# Epoch 42/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1001 - accuracy: 0.9412 - val_loss: 0.0841 - val_accuracy: 0.9375
#
# Epoch 00042: val_loss did not improve from 0.07391
# Epoch 43/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1033 - accuracy: 0.9191 - val_loss: 0.0931 - val_accuracy: 0.9500
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00043: val_loss did not improve from 0.07391
# Epoch 00043: early stopping
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0770 - accuracy: 0.9800
# Val Score:  [0.07704808562994003, 0.9800000190734863]
# ====================================================================================
#
#
# Training on Fold:  3
# Epoch 1/100
# 23/23 [==============================] - 1s 15ms/step - loss: 0.7456 - accuracy: 0.3993 - val_loss: 0.6279 - val_accuracy: 0.4500
#
# Epoch 00001: val_loss did not improve from 0.07391
# Epoch 2/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5694 - accuracy: 0.5359 - val_loss: 0.5742 - val_accuracy: 0.4625
#
# Epoch 00002: val_loss did not improve from 0.07391
# Epoch 3/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4773 - accuracy: 0.6089 - val_loss: 0.5321 - val_accuracy: 0.4375
#
# Epoch 00003: val_loss did not improve from 0.07391
# Epoch 4/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4642 - accuracy: 0.6305 - val_loss: 0.5000 - val_accuracy: 0.5250
#
# Epoch 00004: val_loss did not improve from 0.07391
# Epoch 5/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4352 - accuracy: 0.6481 - val_loss: 0.4539 - val_accuracy: 0.6000
#
# Epoch 00005: val_loss did not improve from 0.07391
# Epoch 6/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3849 - accuracy: 0.6744 - val_loss: 0.4165 - val_accuracy: 0.6625
#
# Epoch 00006: val_loss did not improve from 0.07391
# Epoch 7/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3663 - accuracy: 0.7157 - val_loss: 0.4013 - val_accuracy: 0.6750
#
# Epoch 00007: val_loss did not improve from 0.07391
# Epoch 8/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3358 - accuracy: 0.7466 - val_loss: 0.3602 - val_accuracy: 0.7125
#
# Epoch 00008: val_loss did not improve from 0.07391
# Epoch 9/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3089 - accuracy: 0.7690 - val_loss: 0.3380 - val_accuracy: 0.7000
#
# Epoch 00009: val_loss did not improve from 0.07391
# Epoch 10/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3112 - accuracy: 0.7326 - val_loss: 0.3536 - val_accuracy: 0.6875
#
# Epoch 00010: val_loss did not improve from 0.07391
# Epoch 11/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2753 - accuracy: 0.8064 - val_loss: 0.3001 - val_accuracy: 0.7250
#
# Epoch 00011: val_loss did not improve from 0.07391
# Epoch 12/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2653 - accuracy: 0.7896 - val_loss: 0.3221 - val_accuracy: 0.7500
#
# Epoch 00012: val_loss did not improve from 0.07391
# Epoch 13/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2733 - accuracy: 0.7701 - val_loss: 0.2543 - val_accuracy: 0.7875
#
# Epoch 00013: val_loss did not improve from 0.07391
# Epoch 14/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2379 - accuracy: 0.8296 - val_loss: 0.2514 - val_accuracy: 0.7625
#
# Epoch 00014: val_loss did not improve from 0.07391
# Epoch 15/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2199 - accuracy: 0.8614 - val_loss: 0.2316 - val_accuracy: 0.8000
#
# Epoch 00015: val_loss did not improve from 0.07391
# Epoch 16/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2278 - accuracy: 0.8139 - val_loss: 0.2353 - val_accuracy: 0.7750
#
# Epoch 00016: val_loss did not improve from 0.07391
# Epoch 17/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2071 - accuracy: 0.8545 - val_loss: 0.2280 - val_accuracy: 0.7750
#
# Epoch 00017: val_loss did not improve from 0.07391
# Epoch 18/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2046 - accuracy: 0.8482 - val_loss: 0.2341 - val_accuracy: 0.7500
#
# Epoch 00018: val_loss did not improve from 0.07391
# Epoch 19/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2017 - accuracy: 0.8569 - val_loss: 0.2359 - val_accuracy: 0.7500
#
# Epoch 00019: val_loss did not improve from 0.07391
# Epoch 20/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2022 - accuracy: 0.8347 - val_loss: 0.2190 - val_accuracy: 0.7625
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00020: val_loss did not improve from 0.07391
# Epoch 21/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1713 - accuracy: 0.8749 - val_loss: 0.2175 - val_accuracy: 0.7500
#
# Epoch 00021: val_loss did not improve from 0.07391
# Epoch 22/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1679 - accuracy: 0.8845 - val_loss: 0.2211 - val_accuracy: 0.7750
#
# Epoch 00022: val_loss did not improve from 0.07391
# Epoch 23/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1520 - accuracy: 0.8956 - val_loss: 0.2159 - val_accuracy: 0.7875
#
# Epoch 00023: val_loss did not improve from 0.07391
# Epoch 24/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1693 - accuracy: 0.8576 - val_loss: 0.1862 - val_accuracy: 0.8000
#
# Epoch 00024: val_loss did not improve from 0.07391
# Epoch 25/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1496 - accuracy: 0.9112 - val_loss: 0.1834 - val_accuracy: 0.8000
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00025: val_loss did not improve from 0.07391
# Epoch 26/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1340 - accuracy: 0.9149 - val_loss: 0.1846 - val_accuracy: 0.8000
#
# Epoch 00026: val_loss did not improve from 0.07391
# Epoch 27/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1367 - accuracy: 0.9110 - val_loss: 0.1744 - val_accuracy: 0.8000
#
# Epoch 00027: val_loss did not improve from 0.07391
# Epoch 28/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1374 - accuracy: 0.9127 - val_loss: 0.1781 - val_accuracy: 0.8000
#
# Epoch 00028: val_loss did not improve from 0.07391
# Epoch 29/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1462 - accuracy: 0.8983 - val_loss: 0.1616 - val_accuracy: 0.8000
#
# Epoch 00029: val_loss did not improve from 0.07391
# Epoch 30/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1351 - accuracy: 0.8932 - val_loss: 0.1456 - val_accuracy: 0.8250
#
# Epoch 00030: val_loss did not improve from 0.07391
# Epoch 31/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1372 - accuracy: 0.8999 - val_loss: 0.1419 - val_accuracy: 0.8500
#
# Epoch 00031: val_loss did not improve from 0.07391
# Epoch 32/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1223 - accuracy: 0.9103 - val_loss: 0.1445 - val_accuracy: 0.8125
#
# Epoch 00032: val_loss did not improve from 0.07391
# Epoch 33/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1218 - accuracy: 0.9249 - val_loss: 0.1333 - val_accuracy: 0.8625
#
# Epoch 00033: val_loss did not improve from 0.07391
# Epoch 34/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1258 - accuracy: 0.9076 - val_loss: 0.1338 - val_accuracy: 0.8750
#
# Epoch 00034: val_loss did not improve from 0.07391
# Epoch 35/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1186 - accuracy: 0.9295 - val_loss: 0.1160 - val_accuracy: 0.9125
#
# Epoch 00035: val_loss did not improve from 0.07391
# Epoch 36/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1205 - accuracy: 0.9312 - val_loss: 0.1234 - val_accuracy: 0.8625
#
# Epoch 00036: val_loss did not improve from 0.07391
# Epoch 37/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1382 - accuracy: 0.9047 - val_loss: 0.1153 - val_accuracy: 0.9000
#
# Epoch 00037: val_loss did not improve from 0.07391
# Epoch 38/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1152 - accuracy: 0.9296 - val_loss: 0.1192 - val_accuracy: 0.8875
#
# Epoch 00038: val_loss did not improve from 0.07391
# Epoch 39/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1181 - accuracy: 0.9286 - val_loss: 0.1126 - val_accuracy: 0.9000
#
# Epoch 00039: val_loss did not improve from 0.07391
# Epoch 40/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1211 - accuracy: 0.9020 - val_loss: 0.1080 - val_accuracy: 0.9125
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00040: val_loss did not improve from 0.07391
# Epoch 41/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0989 - accuracy: 0.9564 - val_loss: 0.1027 - val_accuracy: 0.9375
#
# Epoch 00041: val_loss did not improve from 0.07391
# Epoch 42/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1032 - accuracy: 0.9367 - val_loss: 0.0969 - val_accuracy: 0.9500
#
# Epoch 00042: val_loss did not improve from 0.07391
# Epoch 43/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0918 - accuracy: 0.9545 - val_loss: 0.0925 - val_accuracy: 0.9500
#
# Epoch 00043: val_loss did not improve from 0.07391
# Epoch 44/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1206 - accuracy: 0.9180 - val_loss: 0.0977 - val_accuracy: 0.9500
#
# Epoch 00044: val_loss did not improve from 0.07391
# Epoch 45/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1023 - accuracy: 0.9344 - val_loss: 0.0929 - val_accuracy: 0.9500
#
# Epoch 00045: val_loss did not improve from 0.07391
# Epoch 46/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1099 - accuracy: 0.9347 - val_loss: 0.0915 - val_accuracy: 0.9500
#
# Epoch 00046: val_loss did not improve from 0.07391
# Epoch 47/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1099 - accuracy: 0.9360 - val_loss: 0.0906 - val_accuracy: 0.9500
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00047: val_loss did not improve from 0.07391
# Epoch 00047: early stopping
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0934 - accuracy: 0.9400
# Val Score:  [0.09340958297252655, 0.9399999976158142]
# ====================================================================================
#
#
# Training on Fold:  4
# Epoch 1/100
# 23/23 [==============================] - 1s 14ms/step - loss: 0.7624 - accuracy: 0.3785 - val_loss: 0.6397 - val_accuracy: 0.4875
#
# Epoch 00001: val_loss did not improve from 0.07391
# Epoch 2/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5697 - accuracy: 0.5365 - val_loss: 0.5975 - val_accuracy: 0.6750
#
# Epoch 00002: val_loss did not improve from 0.07391
# Epoch 3/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4959 - accuracy: 0.6209 - val_loss: 0.5255 - val_accuracy: 0.6750
#
# Epoch 00003: val_loss did not improve from 0.07391
# Epoch 4/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4493 - accuracy: 0.6667 - val_loss: 0.4775 - val_accuracy: 0.6375
#
# Epoch 00004: val_loss did not improve from 0.07391
# Epoch 5/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4181 - accuracy: 0.6680 - val_loss: 0.4397 - val_accuracy: 0.6750
#
# Epoch 00005: val_loss did not improve from 0.07391
# Epoch 6/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3873 - accuracy: 0.6883 - val_loss: 0.4219 - val_accuracy: 0.7500
#
# Epoch 00006: val_loss did not improve from 0.07391
# Epoch 7/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3562 - accuracy: 0.7120 - val_loss: 0.3679 - val_accuracy: 0.7625
#
# Epoch 00007: val_loss did not improve from 0.07391
# Epoch 8/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3213 - accuracy: 0.7724 - val_loss: 0.3427 - val_accuracy: 0.8375
#
# Epoch 00008: val_loss did not improve from 0.07391
# Epoch 9/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3229 - accuracy: 0.7286 - val_loss: 0.3241 - val_accuracy: 0.8125
#
# Epoch 00009: val_loss did not improve from 0.07391
# Epoch 10/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3012 - accuracy: 0.7501 - val_loss: 0.3101 - val_accuracy: 0.8250
#
# Epoch 00010: val_loss did not improve from 0.07391
# Epoch 11/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2960 - accuracy: 0.7573 - val_loss: 0.2825 - val_accuracy: 0.7875
#
# Epoch 00011: val_loss did not improve from 0.07391
# Epoch 12/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2812 - accuracy: 0.7676 - val_loss: 0.2868 - val_accuracy: 0.8125
#
# Epoch 00012: val_loss did not improve from 0.07391
# Epoch 13/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2509 - accuracy: 0.8079 - val_loss: 0.2706 - val_accuracy: 0.7875
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00013: val_loss did not improve from 0.07391
# Epoch 14/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2557 - accuracy: 0.7975 - val_loss: 0.2661 - val_accuracy: 0.7375
#
# Epoch 00014: val_loss did not improve from 0.07391
# Epoch 15/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2038 - accuracy: 0.8901 - val_loss: 0.2752 - val_accuracy: 0.7125
#
# Epoch 00015: val_loss did not improve from 0.07391
# Epoch 16/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2193 - accuracy: 0.8176 - val_loss: 0.2727 - val_accuracy: 0.7000
#
# Epoch 00016: val_loss did not improve from 0.07391
# Epoch 17/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2179 - accuracy: 0.8403 - val_loss: 0.2865 - val_accuracy: 0.6875
#
# Epoch 00017: val_loss did not improve from 0.07391
# Epoch 18/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2154 - accuracy: 0.8411 - val_loss: 0.2772 - val_accuracy: 0.6875
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00018: val_loss did not improve from 0.07391
# Epoch 19/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1959 - accuracy: 0.8709 - val_loss: 0.2671 - val_accuracy: 0.6875
#
# Epoch 00019: val_loss did not improve from 0.07391
# Epoch 20/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1890 - accuracy: 0.8838 - val_loss: 0.2581 - val_accuracy: 0.7000
#
# Epoch 00020: val_loss did not improve from 0.07391
# Epoch 21/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1826 - accuracy: 0.8801 - val_loss: 0.2554 - val_accuracy: 0.6875
#
# Epoch 00021: val_loss did not improve from 0.07391
# Epoch 22/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1862 - accuracy: 0.8830 - val_loss: 0.2319 - val_accuracy: 0.7625
#
# Epoch 00022: val_loss did not improve from 0.07391
# Epoch 23/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1862 - accuracy: 0.8794 - val_loss: 0.2438 - val_accuracy: 0.7375
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00023: val_loss did not improve from 0.07391
# Epoch 24/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1719 - accuracy: 0.8902 - val_loss: 0.2350 - val_accuracy: 0.7375
#
# Epoch 00024: val_loss did not improve from 0.07391
# Epoch 25/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1671 - accuracy: 0.8978 - val_loss: 0.2230 - val_accuracy: 0.7750
#
# Epoch 00025: val_loss did not improve from 0.07391
# Epoch 26/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1657 - accuracy: 0.9007 - val_loss: 0.2159 - val_accuracy: 0.8000
#
# Epoch 00026: val_loss did not improve from 0.07391
# Epoch 27/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1687 - accuracy: 0.8875 - val_loss: 0.1997 - val_accuracy: 0.8250
#
# Epoch 00027: val_loss did not improve from 0.07391
# Epoch 28/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1662 - accuracy: 0.8762 - val_loss: 0.1988 - val_accuracy: 0.8250
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00028: val_loss did not improve from 0.07391
# Epoch 29/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1712 - accuracy: 0.8885 - val_loss: 0.1900 - val_accuracy: 0.8375
#
# Epoch 00029: val_loss did not improve from 0.07391
# Epoch 30/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1633 - accuracy: 0.8909 - val_loss: 0.1819 - val_accuracy: 0.8625
#
# Epoch 00030: val_loss did not improve from 0.07391
# Epoch 31/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1633 - accuracy: 0.8835 - val_loss: 0.1737 - val_accuracy: 0.8750
#
# Epoch 00031: val_loss did not improve from 0.07391
# Epoch 32/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1743 - accuracy: 0.8849 - val_loss: 0.1727 - val_accuracy: 0.8625
#
# Epoch 00032: val_loss did not improve from 0.07391
# Epoch 33/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1565 - accuracy: 0.9114 - val_loss: 0.1732 - val_accuracy: 0.8625
#
# Epoch 00033: val_loss did not improve from 0.07391
# Epoch 34/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1532 - accuracy: 0.9146 - val_loss: 0.1620 - val_accuracy: 0.8625
#
# Epoch 00034: val_loss did not improve from 0.07391
# Epoch 35/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1654 - accuracy: 0.8853 - val_loss: 0.1596 - val_accuracy: 0.8625
#
# Epoch 00035: val_loss did not improve from 0.07391
# Epoch 36/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1623 - accuracy: 0.8966 - val_loss: 0.1594 - val_accuracy: 0.8875
#
# Epoch 00036: val_loss did not improve from 0.07391
# Epoch 37/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1661 - accuracy: 0.8905 - val_loss: 0.1615 - val_accuracy: 0.8625
#
# Epoch 00037: val_loss did not improve from 0.07391
# Epoch 38/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1506 - accuracy: 0.9213 - val_loss: 0.1653 - val_accuracy: 0.8625
#
# Epoch 00038: val_loss did not improve from 0.07391
# Epoch 39/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1425 - accuracy: 0.9156 - val_loss: 0.1588 - val_accuracy: 0.8625
#
# Epoch 00039: val_loss did not improve from 0.07391
# Epoch 40/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1493 - accuracy: 0.9047 - val_loss: 0.1414 - val_accuracy: 0.9000
#
# Epoch 00040: val_loss did not improve from 0.07391
# Epoch 41/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1403 - accuracy: 0.8983 - val_loss: 0.1410 - val_accuracy: 0.9000
#
# Epoch 00041: val_loss did not improve from 0.07391
# Epoch 42/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1552 - accuracy: 0.8856 - val_loss: 0.1471 - val_accuracy: 0.9000
#
# Epoch 00042: val_loss did not improve from 0.07391
# Epoch 43/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1443 - accuracy: 0.9200 - val_loss: 0.1505 - val_accuracy: 0.8750
#
# Epoch 00043: val_loss did not improve from 0.07391
# Epoch 44/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1507 - accuracy: 0.8943 - val_loss: 0.1427 - val_accuracy: 0.8750
#
# Epoch 00044: val_loss did not improve from 0.07391
# Epoch 45/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1366 - accuracy: 0.9292 - val_loss: 0.1480 - val_accuracy: 0.8875
#
# Epoch 00045: val_loss did not improve from 0.07391
# Epoch 46/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1531 - accuracy: 0.8943 - val_loss: 0.1365 - val_accuracy: 0.8875
#
# Epoch 00046: val_loss did not improve from 0.07391
# Epoch 47/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1224 - accuracy: 0.9448 - val_loss: 0.1361 - val_accuracy: 0.8875
#
# Epoch 00047: val_loss did not improve from 0.07391
# Epoch 48/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1379 - accuracy: 0.9191 - val_loss: 0.1212 - val_accuracy: 0.9000
#
# Epoch 00048: val_loss did not improve from 0.07391
# Epoch 49/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1314 - accuracy: 0.9382 - val_loss: 0.1249 - val_accuracy: 0.9250
#
# Epoch 00049: val_loss did not improve from 0.07391
# Epoch 50/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1309 - accuracy: 0.9313 - val_loss: 0.1339 - val_accuracy: 0.8875
#
# Epoch 00050: val_loss did not improve from 0.07391
# Epoch 51/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1313 - accuracy: 0.9213 - val_loss: 0.1377 - val_accuracy: 0.8875
#
# Epoch 00051: val_loss did not improve from 0.07391
# Epoch 52/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1399 - accuracy: 0.9088 - val_loss: 0.1334 - val_accuracy: 0.9000
#
# Epoch 00052: val_loss did not improve from 0.07391
# Epoch 53/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1278 - accuracy: 0.9388 - val_loss: 0.1259 - val_accuracy: 0.9125
#
# Epoch 00053: val_loss did not improve from 0.07391
# Epoch 54/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1321 - accuracy: 0.9198 - val_loss: 0.1329 - val_accuracy: 0.9000
#
# Epoch 00054: val_loss did not improve from 0.07391
# Epoch 55/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1306 - accuracy: 0.9289 - val_loss: 0.1386 - val_accuracy: 0.8875
#
# Epoch 00055: val_loss did not improve from 0.07391
# Epoch 56/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1411 - accuracy: 0.9152 - val_loss: 0.1328 - val_accuracy: 0.9000
#
# Epoch 00056: val_loss did not improve from 0.07391
# Epoch 57/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1368 - accuracy: 0.9178 - val_loss: 0.1218 - val_accuracy: 0.9125
#
# Epoch 00057: val_loss did not improve from 0.07391
# Epoch 58/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1395 - accuracy: 0.9034 - val_loss: 0.1200 - val_accuracy: 0.9125
#
# Epoch 00058: val_loss did not improve from 0.07391
# Epoch 59/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1237 - accuracy: 0.9231 - val_loss: 0.1275 - val_accuracy: 0.9000
#
# Epoch 00059: val_loss did not improve from 0.07391
# Epoch 60/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1252 - accuracy: 0.9361 - val_loss: 0.1396 - val_accuracy: 0.9000
#
# Epoch 00060: val_loss did not improve from 0.07391
# Epoch 61/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1388 - accuracy: 0.9193 - val_loss: 0.1239 - val_accuracy: 0.9000
#
# Epoch 00061: val_loss did not improve from 0.07391
# Epoch 62/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1323 - accuracy: 0.9213 - val_loss: 0.1199 - val_accuracy: 0.9250
#
# Epoch 00062: val_loss did not improve from 0.07391
# Epoch 63/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1271 - accuracy: 0.9194 - val_loss: 0.1119 - val_accuracy: 0.9125
#
# Epoch 00063: val_loss did not improve from 0.07391
# Epoch 64/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1172 - accuracy: 0.9325 - val_loss: 0.1070 - val_accuracy: 0.9375
#
# Epoch 00064: val_loss did not improve from 0.07391
# Epoch 00064: early stopping
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1141 - accuracy: 0.9150
# Val Score:  [0.11411722004413605, 0.9150000214576721]
# ====================================================================================
#
#
# Training on Fold:  5
# Epoch 1/100
# 23/23 [==============================] - 1s 15ms/step - loss: 0.7989 - accuracy: 0.3588 - val_loss: 0.6543 - val_accuracy: 0.4875
#
# Epoch 00001: val_loss did not improve from 0.07391
# Epoch 2/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5576 - accuracy: 0.5668 - val_loss: 0.6122 - val_accuracy: 0.6625
#
# Epoch 00002: val_loss did not improve from 0.07391
# Epoch 3/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4671 - accuracy: 0.6898 - val_loss: 0.5385 - val_accuracy: 0.7625
#
# Epoch 00003: val_loss did not improve from 0.07391
# Epoch 4/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4418 - accuracy: 0.6643 - val_loss: 0.4745 - val_accuracy: 0.7250
#
# Epoch 00004: val_loss did not improve from 0.07391
# Epoch 5/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4145 - accuracy: 0.6736 - val_loss: 0.4251 - val_accuracy: 0.7250
#
# Epoch 00005: val_loss did not improve from 0.07391
# Epoch 6/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3763 - accuracy: 0.7282 - val_loss: 0.3859 - val_accuracy: 0.7250
#
# Epoch 00006: val_loss did not improve from 0.07391
# Epoch 7/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3562 - accuracy: 0.7173 - val_loss: 0.3280 - val_accuracy: 0.7375
#
# Epoch 00007: val_loss did not improve from 0.07391
# Epoch 8/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3297 - accuracy: 0.7351 - val_loss: 0.3050 - val_accuracy: 0.7625
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00008: val_loss did not improve from 0.07391
# Epoch 9/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3134 - accuracy: 0.7535 - val_loss: 0.2936 - val_accuracy: 0.7875
#
# Epoch 00009: val_loss did not improve from 0.07391
# Epoch 10/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3005 - accuracy: 0.7441 - val_loss: 0.2880 - val_accuracy: 0.8000
#
# Epoch 00010: val_loss did not improve from 0.07391
# Epoch 11/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2998 - accuracy: 0.7704 - val_loss: 0.2772 - val_accuracy: 0.8125
#
# Epoch 00011: val_loss did not improve from 0.07391
# Epoch 12/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2781 - accuracy: 0.7950 - val_loss: 0.2782 - val_accuracy: 0.8125
#
# Epoch 00012: val_loss did not improve from 0.07391
# Epoch 13/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2595 - accuracy: 0.8142 - val_loss: 0.2623 - val_accuracy: 0.7750
#
# Epoch 00013: val_loss did not improve from 0.07391
# Epoch 14/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2734 - accuracy: 0.7576 - val_loss: 0.2560 - val_accuracy: 0.8000
#
# Epoch 00014: val_loss did not improve from 0.07391
# Epoch 15/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2629 - accuracy: 0.7842 - val_loss: 0.2538 - val_accuracy: 0.7875
#
# Epoch 00015: val_loss did not improve from 0.07391
# Epoch 16/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2512 - accuracy: 0.7976 - val_loss: 0.2536 - val_accuracy: 0.7875
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00016: val_loss did not improve from 0.07391
# Epoch 17/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2350 - accuracy: 0.8378 - val_loss: 0.2462 - val_accuracy: 0.7875
#
# Epoch 00017: val_loss did not improve from 0.07391
# Epoch 18/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2270 - accuracy: 0.8206 - val_loss: 0.2463 - val_accuracy: 0.8000
#
# Epoch 00018: val_loss did not improve from 0.07391
# Epoch 19/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2287 - accuracy: 0.8052 - val_loss: 0.2482 - val_accuracy: 0.7750
#
# Epoch 00019: val_loss did not improve from 0.07391
# Epoch 20/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2303 - accuracy: 0.8269 - val_loss: 0.2392 - val_accuracy: 0.7875
#
# Epoch 00020: val_loss did not improve from 0.07391
# Epoch 21/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2236 - accuracy: 0.8237 - val_loss: 0.2386 - val_accuracy: 0.7625
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00021: val_loss did not improve from 0.07391
# Epoch 22/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2216 - accuracy: 0.8362 - val_loss: 0.2327 - val_accuracy: 0.8000
#
# Epoch 00022: val_loss did not improve from 0.07391
# Epoch 23/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2070 - accuracy: 0.8410 - val_loss: 0.2336 - val_accuracy: 0.7875
#
# Epoch 00023: val_loss did not improve from 0.07391
# Epoch 24/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2256 - accuracy: 0.8332 - val_loss: 0.2344 - val_accuracy: 0.7625
#
# Epoch 00024: val_loss did not improve from 0.07391
# Epoch 25/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2039 - accuracy: 0.8573 - val_loss: 0.2349 - val_accuracy: 0.7625
#
# Epoch 00025: val_loss did not improve from 0.07391
# Epoch 26/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2224 - accuracy: 0.8537 - val_loss: 0.2287 - val_accuracy: 0.7875
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00026: val_loss did not improve from 0.07391
# Epoch 27/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2007 - accuracy: 0.8599 - val_loss: 0.2232 - val_accuracy: 0.8000
#
# Epoch 00027: val_loss did not improve from 0.07391
# Epoch 28/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2036 - accuracy: 0.8579 - val_loss: 0.2213 - val_accuracy: 0.8125
#
# Epoch 00028: val_loss did not improve from 0.07391
# Epoch 29/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2057 - accuracy: 0.8605 - val_loss: 0.2225 - val_accuracy: 0.8000
#
# Epoch 00029: val_loss did not improve from 0.07391
# Epoch 30/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2029 - accuracy: 0.8628 - val_loss: 0.2204 - val_accuracy: 0.8000
#
# Epoch 00030: val_loss did not improve from 0.07391
# Epoch 31/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1986 - accuracy: 0.8583 - val_loss: 0.2189 - val_accuracy: 0.8000
#
# Epoch 00031: val_loss did not improve from 0.07391
# Epoch 32/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2044 - accuracy: 0.8577 - val_loss: 0.2191 - val_accuracy: 0.7750
#
# Epoch 00032: val_loss did not improve from 0.07391
# Epoch 33/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1966 - accuracy: 0.8566 - val_loss: 0.2155 - val_accuracy: 0.8125
#
# Epoch 00033: val_loss did not improve from 0.07391
# Epoch 34/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1991 - accuracy: 0.8493 - val_loss: 0.2103 - val_accuracy: 0.8250
#
# Epoch 00034: val_loss did not improve from 0.07391
# Epoch 35/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1958 - accuracy: 0.8670 - val_loss: 0.2116 - val_accuracy: 0.8000
#
# Epoch 00035: val_loss did not improve from 0.07391
# Epoch 36/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2065 - accuracy: 0.8658 - val_loss: 0.2034 - val_accuracy: 0.8250
#
# Epoch 00036: val_loss did not improve from 0.07391
# Epoch 37/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2131 - accuracy: 0.8607 - val_loss: 0.2066 - val_accuracy: 0.8250
#
# Epoch 00037: val_loss did not improve from 0.07391
# Epoch 38/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1915 - accuracy: 0.8710 - val_loss: 0.2028 - val_accuracy: 0.8250
#
# Epoch 00038: val_loss did not improve from 0.07391
# Epoch 39/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1993 - accuracy: 0.8599 - val_loss: 0.2010 - val_accuracy: 0.8250
#
# Epoch 00039: val_loss did not improve from 0.07391
# Epoch 40/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1825 - accuracy: 0.8747 - val_loss: 0.1973 - val_accuracy: 0.8375
#
# Epoch 00040: val_loss did not improve from 0.07391
# Epoch 41/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1884 - accuracy: 0.8791 - val_loss: 0.2004 - val_accuracy: 0.8250
#
# Epoch 00041: val_loss did not improve from 0.07391
# Epoch 42/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1800 - accuracy: 0.8758 - val_loss: 0.1991 - val_accuracy: 0.8250
#
# Epoch 00042: val_loss did not improve from 0.07391
# Epoch 43/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1839 - accuracy: 0.8820 - val_loss: 0.1979 - val_accuracy: 0.8250
#
# Epoch 00043: val_loss did not improve from 0.07391
# Epoch 44/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1815 - accuracy: 0.8744 - val_loss: 0.1953 - val_accuracy: 0.8125
#
# Epoch 00044: val_loss did not improve from 0.07391
# Epoch 45/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1808 - accuracy: 0.8912 - val_loss: 0.1871 - val_accuracy: 0.8250
#
# Epoch 00045: val_loss did not improve from 0.07391
# Epoch 46/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1708 - accuracy: 0.9052 - val_loss: 0.1849 - val_accuracy: 0.8250
#
# Epoch 00046: val_loss did not improve from 0.07391
# Epoch 47/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1816 - accuracy: 0.8769 - val_loss: 0.1907 - val_accuracy: 0.8250
#
# Epoch 00047: val_loss did not improve from 0.07391
# Epoch 48/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1637 - accuracy: 0.9123 - val_loss: 0.1874 - val_accuracy: 0.8375
#
# Epoch 00048: val_loss did not improve from 0.07391
# Epoch 49/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1748 - accuracy: 0.8819 - val_loss: 0.1873 - val_accuracy: 0.8125
#
# Epoch 00049: val_loss did not improve from 0.07391
# Epoch 50/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1733 - accuracy: 0.8764 - val_loss: 0.1860 - val_accuracy: 0.8375
#
# Epoch 00050: val_loss did not improve from 0.07391
# Epoch 51/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1798 - accuracy: 0.8629 - val_loss: 0.2026 - val_accuracy: 0.8000
#
# Epoch 00051: val_loss did not improve from 0.07391
# Epoch 52/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1659 - accuracy: 0.8980 - val_loss: 0.1926 - val_accuracy: 0.8125
#
# Epoch 00052: val_loss did not improve from 0.07391
# Epoch 53/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1856 - accuracy: 0.8798 - val_loss: 0.1847 - val_accuracy: 0.8250
#
# Epoch 00053: val_loss did not improve from 0.07391
# Epoch 00053: early stopping
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1861 - accuracy: 0.8400
# Val Score:  [0.1860961765050888, 0.8399999737739563]
# ====================================================================================

# %%
#Load the model that was saved by ModelCheckpoint
model = load_model('subjek1.h5')

# %%
model.evaluate(test_X, test_y)
#print("Accuracy of the model is - " , model.evaluate(test_X,test_y)[1]*100 , "%")
#plt.bar( model.evaluate(test_X)[1].index,  model.evaluate(test_y)[1])
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0699 - accuracy: 0.9750
# [0.06987550854682922, 0.9750000238418579]

# %%
fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)

ax1.plot(model_history[0].history['accuracy'], label='Training Fold 1 accuration')
ax1.plot(model_history[1].history['accuracy'], label='Training Fold 2 accuration')
ax1.plot(model_history[2].history['accuracy'], label='Training Fold 3 accuration')
ax1.plot(model_history[3].history['accuracy'], label='Training Fold 4 accuration')
ax1.plot(model_history[4].history['accuracy'], label='Training Fold 5 accuration')
ax1.legend()
ax2.plot(model_history[1].history['loss'], label='Training Fold 1 loss')
ax2.plot(model_history[1].history['loss'], label='Training Fold 2 loss')
ax2.plot(model_history[2].history['loss'], label='Training Fold 3 loss')
ax2.plot(model_history[3].history['loss'], label='Training Fold 4 loss ')
ax2.plot(model_history[4].history['loss'], label='Training Fold 5 loss')
ax2.legend()
plt.show()

# %%
fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt1.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[0].history['loss'], label='Train Loss Fold 1', color='black')
plt2.plot(model_history[0].history['val_loss'], label='Val Loss Fold 1', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red')
plt1.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[1].history['loss'], label='Train Loss Fold 2', color='red')
plt2.plot(model_history[1].history['val_loss'], label='Val Loss Fold 2', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green')
plt1.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[2].history['loss'], label='Train Loss Fold 3', color='green')
plt2.plot(model_history[2].history['val_loss'], label='Val Loss Fold 3', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()


fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue')
plt1.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[3].history['loss'], label='Train Loss Fold 4', color='blue')
plt2.plot(model_history[3].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='purple')
plt1.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[4].history['loss'], label='Train Loss Fold 4', color='purple')
plt2.plot(model_history[4].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

# %%
MODEL_NAME ='/content/subjek1.h5' 

#CLIP = True # if your model was trained with np.clip to clip  values
CLIP = False
CLIP_VAL = 8  # if above, what was the value +/-

model = tf.keras.models.load_model(MODEL_NAME)

VALDIR = '/content/drive/MyDrive/Colab Notebooks/data8'
ACTIONS =  ["idle","maju","kiri", "kanan"]
PRED_BATCH = 32


def get_val_data(valdir, action, batch_size):

   # argmax_dict = {0: 0, 1: 0, 2: 0,3:0}
    argmax_dict = {2: 0, 0: 0, 1: 0,3:0}
    raw_pred_dict = {0: 0, 1: 0, 2: 0,3:0}

    action_dir = os.path.join(valdir, action)
    for session_file in os.listdir(action_dir):
        filepath = os.path.join(action_dir,session_file)
        if CLIP:
            data = np.clip(np.load(filepath), -CLIP_VAL, CLIP_VAL) / CLIP_VAL
            #print(data)
        else:
            data = np.load(filepath) 
        preds = model.predict([data.reshape(-1, 8, 60,1)], batch_size=batch_size)
        
        for pred in preds:
            argmax = np.argmax(pred)
            argmax_dict[argmax] += 1
            for idx,value in enumerate(pred):
                raw_pred_dict[idx] += value
    
    argmax_pct_dict = {}
    for i in argmax_dict:
        total = 0
        correct = argmax_dict[i]
        for ii in argmax_dict:
            total += argmax_dict[ii]
        argmax_pct_dict[i] = round(correct/total, 4)
    return argmax_dict, raw_pred_dict, argmax_pct_dict


def make_conf_mat(none,left,forward, right):
    action_dict = {"idle":none,"maju": forward, "kiri": left, "kanan": right}
    action_conf_mat = pd.DataFrame(action_dict)
    actions = [i for i in action_dict]

    fig = plt.figure(figsize=(15, 6))
    ax = fig.add_subplot(111)
    ax.matshow(action_conf_mat, cmap=plt.cm.RdYlGn)
    ax.set_xticklabels([""]+actions)
    ax.set_yticklabels([""]+actions)

    for idx, i in enumerate(action_dict):
        for idx2, ii in enumerate(action_dict[i]):
            ax.text(idx, idx2, f"{round(float(action_dict[i][ii]),2)}", va='center', ha='center')
    # Rotate the tick labels and set their alignment.
    
    plt.title("Matrik data")
    plt.ylabel("Predicted Action")
    fig.tight_layout()
    plt.show()



forward_argmax_dict, forward_raw_pred_dict, forward_argmax_pct_dict = get_val_data(VALDIR, "maju", PRED_BATCH)
none_argmax_dict, none_raw_pred_dict, none_argmax_pct_dict = get_val_data(VALDIR, "idle", PRED_BATCH)
left_argmax_dict, left_raw_pred_dict, left_argmax_pct_dict = get_val_data(VALDIR, "kiri", PRED_BATCH)
right_argmax_dict, right_raw_pred_dict, right_argmax_pct_dict = get_val_data(VALDIR, "kanan", PRED_BATCH)
make_conf_mat(none_argmax_pct_dict,forward_argmax_pct_dict,left_argmax_pct_dict,  right_argmax_pct_dict)

# %%
x_train,x_test,y_train,y_test=train_test_split(train_X,train_y,test_size=0.2)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (800, 8, 60, 1)
# (200, 8, 60, 1)
# (800, 4)
# (200, 4)

# %%
from sklearn.metrics import roc_curve, auc


#y_score = clf.decision_function(xval)
y_score = model.predict(x_test)

#Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()


# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
    
    
print("roc_auc:",sum(roc_auc.values())/4)
ACTIONS =  ["idle","maju","kiri", "kanan"]
for i in range(0,4):
    plt.figure()
    fig, ax = plt.subplots(figsize=(10,10))
    plt.plot(fpr[i], tpr[i],linewidth=3)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    #plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % ACTIONS[i])
    plt.title('%s -ROC curve (area = %0.2f)' % (ACTIONS[i],roc_auc[i]))
    
    plt.legend(loc="lower right")
    plt.show()
# Out:
# roc_auc: 0.998595718751337

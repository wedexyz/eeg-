# %%
import sys
import os
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense, Activation
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras import callbacks
import time

# %%
start = time.time()
DEV = False
argvs = sys.argv
argc = len(argvs)

if argc > 1 and (argvs[1] == "--development" or argvs[1] == "-d"):
  DEV = True

if DEV:
  epochs = 2
else:
  epochs = 100

train_data_path = 'data/train'
validation_data_path = 'data/test'

# %%
"""
Parameters
"""
img_width, img_height = 150, 150
batch_size = 32
samples_per_epoch = 1000
validation_steps = 300
nb_filters1 = 32
nb_filters2 = 64
conv1_size = 3
conv2_size = 2
pool_size = 2
classes_num = 4
lr = 0.0004

# %%
model = Sequential()
#model.add(Convolution2D(nb_filters1, conv1_size, conv1_size, border_mode ="same", input_shape=(img_width, img_height, 3)))
model.add(Convolution2D(nb_filters1, conv1_size, conv1_size, padding ="same", input_shape=(img_width, img_height, 3)))

model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(pool_size, pool_size)))

#model.add(Convolution2D(nb_filters2, conv2_size, conv2_size, border_mode ="same"))
model.add(Convolution2D(nb_filters1, conv1_size, conv1_size, padding ="same", input_shape=(img_width, img_height, 3)))
model.add(Activation("relu"))
#model.add(MaxPooling2D(pool_size=(pool_size, pool_size), dim_ordering='th'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid', data_format=None))

model.add(Flatten())
model.add(Dense(256))
model.add(Activation("relu"))
model.add(Dropout(0.5))
model.add(Dense(classes_num, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=lr),
              metrics=['accuracy'])

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    validation_data_path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical')

"""
Tensorboard log
"""
log_dir = './tf-log/'
tb_cb = callbacks.TensorBoard(log_dir=log_dir, histogram_freq=0)
cbks = [tb_cb]

model.fit_generator(
    train_generator,
    #samples_per_epoch=samples_per_epoch,
    #steps_per_epoch= 32,
    epochs=epochs,
    validation_data=validation_generator,
    callbacks=cbks,
    validation_steps=validation_steps)

target_dir = './models/'
if not os.path.exists(target_dir):
  os.mkdir(target_dir)
model.save('./models/model.h5')
model.save_weights('./models/weights.h5')

#Calculate execution time
end = time.time()
dur = end-start

if dur<60:
    print("Execution Time:",dur,"seconds")
elif dur>60 and dur<3600:
    dur=dur/60
    print("Execution Time:",dur,"minutes")
else:
    dur=dur/(60*60)
    print("Execution Time:",dur,"hours")
# Out:
# Found 240 images belonging to 4 classes.
# Found 0 images belonging to 0 classes.
# WARNING:tensorflow:From <ipython-input-4-0e050cb4ebe2>:58: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 1/8 [==>...........................] - ETA: 0s - loss: 1.3886 - accuracy: 0.2500WARNING:tensorflow:From D:\instalation\anaconda\envs\tf2gpu\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 2/8 [======>.......................] - ETA: 0s - loss: 1.3840 - accuracy: 0.2656WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0350s vs `on_train_batch_end` time: 0.2900s). Check your callbacks.
# 8/8 [==============================] - 2s 205ms/step - loss: 1.3923 - accuracy: 0.2458
# Epoch 2/100
# 8/8 [==============================] - 2s 195ms/step - loss: 1.3986 - accuracy: 0.2625
# Epoch 3/100
# 8/8 [==============================] - 2s 193ms/step - loss: 1.3996 - accuracy: 0.2250
# Epoch 4/100
# 8/8 [==============================] - 2s 191ms/step - loss: 1.3907 - accuracy: 0.2250
# Epoch 5/100
# 8/8 [==============================] - 2s 189ms/step - loss: 1.3918 - accuracy: 0.2667
# Epoch 6/100
# 8/8 [==============================] - 2s 195ms/step - loss: 1.3876 - accuracy: 0.2792
# Epoch 7/100
# 8/8 [==============================] - 2s 189ms/step - loss: 1.3749 - accuracy: 0.3125
# Epoch 8/100
# 8/8 [==============================] - 2s 188ms/step - loss: 1.3962 - accuracy: 0.2292
# Epoch 9/100
# 8/8 [==============================] - 2s 192ms/step - loss: 1.3861 - accuracy: 0.2542
# Epoch 10/100
# 8/8 [==============================] - 2s 190ms/step - loss: 1.3902 - accuracy: 0.2583
# Epoch 11/100
# 8/8 [==============================] - 2s 202ms/step - loss: 1.3794 - accuracy: 0.3125
# Epoch 12/100
# 8/8 [==============================] - 2s 192ms/step - loss: 1.3813 - accuracy: 0.2708
# Epoch 13/100
# 8/8 [==============================] - 2s 193ms/step - loss: 1.3885 - accuracy: 0.2458
# Epoch 14/100
# 8/8 [==============================] - 2s 190ms/step - loss: 1.3855 - accuracy: 0.2833
# Epoch 15/100
# 8/8 [==============================] - 2s 188ms/step - loss: 1.3795 - accuracy: 0.3000
# Epoch 16/100
# 8/8 [==============================] - 1s 186ms/step - loss: 1.3709 - accuracy: 0.3208
# Epoch 17/100
# 8/8 [==============================] - 2s 192ms/step - loss: 1.3662 - accuracy: 0.3417
# Epoch 18/100
# 8/8 [==============================] - 2s 211ms/step - loss: 1.3623 - accuracy: 0.3583
# Epoch 19/100
# 8/8 [==============================] - 2s 192ms/step - loss: 1.3567 - accuracy: 0.3417
# Epoch 20/100
# 8/8 [==============================] - 2s 193ms/step - loss: 1.3601 - accuracy: 0.3583
# Epoch 21/100
# 8/8 [==============================] - 2s 192ms/step - loss: 1.3438 - accuracy: 0.4167
# Epoch 22/100
# 8/8 [==============================] - 2s 188ms/step - loss: 1.3348 - accuracy: 0.4458
# Epoch 23/100
# 8/8 [==============================] - 2s 190ms/step - loss: 1.3248 - accuracy: 0.4583
# Epoch 24/100
# 8/8 [==============================] - 2s 190ms/step - loss: 1.3078 - accuracy: 0.5042
# Epoch 25/100
# 8/8 [==============================] - 2s 191ms/step - loss: 1.3013 - accuracy: 0.4875
# Epoch 26/100
# 8/8 [==============================] - 2s 189ms/step - loss: 1.2874 - accuracy: 0.5167
# Epoch 27/100
# 8/8 [==============================] - 2s 203ms/step - loss: 1.2710 - accuracy: 0.5625
# Epoch 28/100
# 8/8 [==============================] - 2s 191ms/step - loss: 1.2155 - accuracy: 0.6250
# Epoch 29/100
# 8/8 [==============================] - 2s 192ms/step - loss: 1.2178 - accuracy: 0.6125
# Epoch 30/100
# 8/8 [==============================] - 2s 188ms/step - loss: 1.1976 - accuracy: 0.6000
# Epoch 31/100
# 8/8 [==============================] - 2s 197ms/step - loss: 1.1475 - accuracy: 0.6125
# Epoch 32/100
# 8/8 [==============================] - 1s 187ms/step - loss: 1.1173 - accuracy: 0.6833
# Epoch 33/100
# 8/8 [==============================] - 2s 190ms/step - loss: 1.0947 - accuracy: 0.6667
# Epoch 34/100
# 8/8 [==============================] - 2s 191ms/step - loss: 1.0841 - accuracy: 0.6333
# Epoch 35/100
# 8/8 [==============================] - 2s 189ms/step - loss: 1.0435 - accuracy: 0.7083
# Epoch 36/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.9839 - accuracy: 0.7542
# Epoch 37/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.9440 - accuracy: 0.7958
# Epoch 38/100
# 8/8 [==============================] - 1s 187ms/step - loss: 0.9137 - accuracy: 0.7708
# Epoch 39/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.8893 - accuracy: 0.7167
# Epoch 40/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.8613 - accuracy: 0.7792
# Epoch 41/100
# 8/8 [==============================] - 2s 191ms/step - loss: 0.8252 - accuracy: 0.7417
# Epoch 42/100
# 8/8 [==============================] - 2s 191ms/step - loss: 0.7973 - accuracy: 0.7833
# Epoch 43/100
# 8/8 [==============================] - 2s 193ms/step - loss: 0.7661 - accuracy: 0.7917
# Epoch 44/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.7749 - accuracy: 0.8000
# Epoch 45/100
# 8/8 [==============================] - 2s 193ms/step - loss: 0.7011 - accuracy: 0.8583
# Epoch 46/100
# 8/8 [==============================] - 2s 192ms/step - loss: 0.6441 - accuracy: 0.8333
# Epoch 47/100
# 8/8 [==============================] - 2s 189ms/step - loss: 0.6384 - accuracy: 0.8708
# Epoch 48/100
# 8/8 [==============================] - 2s 192ms/step - loss: 0.5940 - accuracy: 0.8917
# Epoch 49/100
# 8/8 [==============================] - 2s 204ms/step - loss: 0.5841 - accuracy: 0.8833
# Epoch 50/100
# 8/8 [==============================] - 2s 189ms/step - loss: 0.5623 - accuracy: 0.8667
# Epoch 51/100
# 8/8 [==============================] - 2s 194ms/step - loss: 0.5247 - accuracy: 0.8875
# Epoch 52/100
# 8/8 [==============================] - 2s 193ms/step - loss: 0.5233 - accuracy: 0.8333
# Epoch 53/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.4137 - accuracy: 0.9500
# Epoch 54/100
# 8/8 [==============================] - 2s 197ms/step - loss: 0.4631 - accuracy: 0.9042
# Epoch 55/100
# 8/8 [==============================] - 2s 208ms/step - loss: 0.4569 - accuracy: 0.8833
# Epoch 56/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.3792 - accuracy: 0.9250
# Epoch 57/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.3853 - accuracy: 0.9417
# Epoch 58/100
# 8/8 [==============================] - 1s 187ms/step - loss: 0.3666 - accuracy: 0.9292
# Epoch 59/100
# 8/8 [==============================] - 2s 206ms/step - loss: 0.3509 - accuracy: 0.9167
# Epoch 60/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.3779 - accuracy: 0.9208
# Epoch 61/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.3158 - accuracy: 0.9375
# Epoch 62/100
# 8/8 [==============================] - 2s 206ms/step - loss: 0.2893 - accuracy: 0.9500
# Epoch 63/100
# 8/8 [==============================] - 2s 192ms/step - loss: 0.2902 - accuracy: 0.9292
# Epoch 64/100
# 8/8 [==============================] - 2s 192ms/step - loss: 0.2632 - accuracy: 0.9542
# Epoch 65/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.2774 - accuracy: 0.9458
# Epoch 66/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.2616 - accuracy: 0.9667
# Epoch 67/100
# 8/8 [==============================] - 2s 192ms/step - loss: 0.2700 - accuracy: 0.9667
# Epoch 68/100
# 8/8 [==============================] - 2s 191ms/step - loss: 0.1997 - accuracy: 0.9750
# Epoch 69/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.2121 - accuracy: 0.9708
# Epoch 70/100
# 8/8 [==============================] - 2s 193ms/step - loss: 0.1907 - accuracy: 0.9833
# Epoch 71/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.2269 - accuracy: 0.9417
# Epoch 72/100
# 8/8 [==============================] - 2s 206ms/step - loss: 0.1568 - accuracy: 0.9833
# Epoch 73/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.1980 - accuracy: 0.9625
# Epoch 74/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.1917 - accuracy: 0.9708
# Epoch 75/100
# 8/8 [==============================] - 2s 191ms/step - loss: 0.1812 - accuracy: 0.9708
# Epoch 76/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.1721 - accuracy: 0.9750
# Epoch 77/100
# 8/8 [==============================] - 2s 219ms/step - loss: 0.1747 - accuracy: 0.9750
# Epoch 78/100
# 8/8 [==============================] - 2s 208ms/step - loss: 0.1845 - accuracy: 0.9667
# Epoch 79/100
# 8/8 [==============================] - 2s 192ms/step - loss: 0.1417 - accuracy: 0.9792
# Epoch 80/100
# 8/8 [==============================] - 2s 195ms/step - loss: 0.1104 - accuracy: 0.9875
# Epoch 81/100
# 8/8 [==============================] - 2s 198ms/step - loss: 0.1562 - accuracy: 0.9708
# Epoch 82/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.1282 - accuracy: 0.9792
# Epoch 83/100
# 8/8 [==============================] - 2s 206ms/step - loss: 0.0934 - accuracy: 0.9875
# Epoch 84/100
# 8/8 [==============================] - 2s 205ms/step - loss: 0.1511 - accuracy: 0.9667
# Epoch 85/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.1304 - accuracy: 0.9750
# Epoch 86/100
# 8/8 [==============================] - 2s 192ms/step - loss: 0.1336 - accuracy: 0.9792
# Epoch 87/100
# 8/8 [==============================] - 2s 194ms/step - loss: 0.1322 - accuracy: 0.9875
# Epoch 88/100
# 8/8 [==============================] - 2s 192ms/step - loss: 0.1019 - accuracy: 0.9750
# Epoch 89/100
# 8/8 [==============================] - 2s 191ms/step - loss: 0.2165 - accuracy: 0.9375
# Epoch 90/100
# 8/8 [==============================] - 1s 186ms/step - loss: 0.1060 - accuracy: 0.9875
# Epoch 91/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.1171 - accuracy: 0.9708
# Epoch 92/100
# 8/8 [==============================] - 2s 192ms/step - loss: 0.0788 - accuracy: 0.9917
# Epoch 93/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.1134 - accuracy: 0.9875
# Epoch 94/100
# 8/8 [==============================] - 2s 194ms/step - loss: 0.1105 - accuracy: 0.9750
# Epoch 95/100
# 8/8 [==============================] - 2s 193ms/step - loss: 0.1329 - accuracy: 0.9750
# Epoch 96/100
# 8/8 [==============================] - 2s 201ms/step - loss: 0.1258 - accuracy: 0.9833
# Epoch 97/100
# 8/8 [==============================] - 2s 194ms/step - loss: 0.1074 - accuracy: 0.9833
# Epoch 98/100
# 8/8 [==============================] - 2s 194ms/step - loss: 0.0815 - accuracy: 0.9792
# Epoch 99/100
# 8/8 [==============================] - 2s 192ms/step - loss: 0.1042 - accuracy: 0.9875
# Epoch 100/100
# 8/8 [==============================] - 2s 191ms/step - loss: 0.0930 - accuracy: 0.9958
# Execution Time: 3.09608188867569 minutes

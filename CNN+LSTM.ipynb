# %% [markdown]
# <a href="https://colab.research.google.com/github/wedexyz/eeg-/blob/main/CNN%2BLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.18.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (0.17.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.4.1)

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM, BatchNormalization, Conv2D, Flatten, MaxPooling2D, Dropout
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.optimizers import Adam
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (20,7)
import pandas as pd
import os
import random
import time
import os
from keras.callbacks import ModelCheckpoint, EarlyStopping
#from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator

# %%
idle = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/idle/1604315006.npy")
kanan = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kanan/1604315180.npy")
kiri = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kiri/1604315126.npy")
maju = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/maju/1604315069.npy")

fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('idle')
ax1.plot(idle[0][16])
ax2.plot(idle[175])

fig, (ax3, ax4) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('kanan')
ax3.plot(kanan[0][16])
ax4.plot(kanan[175])

fig, (ax5, ax6) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('kiri')
ax5.plot(kiri[0][16])
ax6.plot(kiri[175])

fig, (ax7, ax8) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('maju')
ax7.plot(maju[0][16])
ax8.plot(maju[175])



plt.show()

# %%
ACTIONS = ["kiri", "maju","idle","kanan"]
reshape = (-1,16, 60,1)
#reshape(-1,28,28,1)

# %%
def create_data(starting_dir="=/content/drive/My Drive/Colab Notebooks/data_baru"):
    training_data = {}
    for action in ACTIONS:
        if action not in training_data:
            training_data[action] = []
        data_dir = os.path.join(starting_dir,action)
        for item in os.listdir(data_dir):
            data = np.load(os.path.join(data_dir, item))
            for item in data:
                training_data[action].append(item)

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)

    for action in ACTIONS:
        np.random.shuffle(training_data[action])  
        training_data[action] = training_data[action][:min(lengths)]

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)
    combined_data = []
    for action in ACTIONS:
        for data in training_data[action]:
            if action == "kiri":
                combined_data.append([data, [1, 0, 0,0]])
            elif action == "maju":
                combined_data.append([data, [0, 1, 0, 0]])
            elif action == "idle":
                combined_data.append([data, [0, 0, 1, 0]])
            elif action == "kanan":
                combined_data.append([data, [0, 0, 0, 1]])

    np.random.shuffle(combined_data)
    print("length:",len(combined_data))
    return combined_data

# %%
print("creating training data")
traindata = create_data(starting_dir="/content/drive/My Drive/Colab Notebooks/data_baru")
train_X = []
train_y = []
for X, y in traindata:
    train_X.append(X)
    train_y.append(y)
# Out:
# creating training data
# [1000, 1000, 1000, 1000]
# [1000, 1000, 1000, 1000]
# length: 4000

# %%
print("creating testing data")
testdata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/tes_data")
test_X = []
test_y = []

for X, y in testdata:
    test_X.append(X)
    test_y.append(y)
train_X = np.array(train_X).reshape(reshape)
test_X = np.array(test_X).reshape(reshape)

train_y = np.array(train_y)
test_y = np.array(test_y)
# Out:
# creating testing data
# [250, 250, 250, 250]
# [250, 250, 250, 250]
# length: 1000

# %%
f, ax = plt.subplots(2,4) 
f.set_size_inches(10, 10)
k = 0
for i in range(2):
    for j in range(4):
       # ax[i,j].imshow(train_X [k].reshape(28, 28) , cmap = "gray")
        ax[i,j].imshow(train_X [k].reshape(16,60)  ,cmap = "gray")
        k += 1
    plt.tight_layout()

# %%
IMAGE_SIZE = (16, 60, 1)

# %%
# With data augmentation to prevent overfitting

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(train_X)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1,factor=0.5, min_lr=0.0001)

# %%
time_steps = 1000
subsample = 10

def cnn_model(size, num_cnn_layers):
    

    model = Sequential()
    
    model.add(Conv2D(filters = 64, kernel_size = (7,7), padding = "same", activation = "relu", input_shape=train_X.shape[1:]))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Conv2D(filters = 64, kernel_size = (5,5), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (5,5)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Conv2D(filters = 64, kernel_size = (3,3), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (3,3)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Flatten())
    
    model.add(tf.keras.layers.Reshape((-1,256)))

    model.add(LSTM(64,input_shape = (time_steps//subsample, 32), return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(64,input_shape = (time_steps//subsample, 32), return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(64,input_shape = (time_steps//subsample, 32), return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(64))
    
    model.add(Dense(32, activation = "relu"))
    model.add(BatchNormalization())

    model.add(Dense(4, activation = "sigmoid"))
   
    #adam = Adam(lr = 0.001)
    model.compile(optimizer ="adam", loss = "binary_crossentropy", metrics = ['accuracy'])
    #model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
 
    
    return model

# %%
model = cnn_model(IMAGE_SIZE, 2)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 16, 60, 64)        3200
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 60, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 60, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 60, 64)        102464
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 3, 12, 64)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 12, 64)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 3, 12, 64)         256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 12, 64)         36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 4, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 4, 64)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 4, 64)          256
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# reshape (Reshape)            (None, 1, 256)            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 1, 64)             82176
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 64)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1, 64)             33024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 64)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 64)             33024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1, 64)             0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 326,948
# Trainable params: 326,500
# Non-trainable params: 448
# _________________________________________________________________

# %%
#set early stopping criteria
pat = 5
#this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='loss', patience=pat, verbose=1)

#define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('fas_mnist_1.h5', verbose=1, save_best_only=True)

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=100, BATCH_SIZE=32):
    model = None
    model = cnn_model(IMAGE_SIZE, 2)
    #Model = model
   # results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[early_stopping, model_checkpoint], 
   #           verbose=1, validation_split=0.1) 
    results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[ model_checkpoint], 
              verbose=1, validation_split=0.1)   
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs=100
batch_size=32

#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(train_X, train_y, test_size=0.1, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
   
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 102/102 [==============================] - ETA: 0s - loss: 0.6395 - accuracy: 0.2512
# Epoch 00001: val_loss improved from inf to 0.58389, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 2s 24ms/step - loss: 0.6395 - accuracy: 0.2512 - val_loss: 0.5839 - val_accuracy: 0.2333
# Epoch 2/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.5675 - accuracy: 0.2647
# Epoch 00002: val_loss improved from 0.58389 to 0.56285, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 13ms/step - loss: 0.5674 - accuracy: 0.2633 - val_loss: 0.5628 - val_accuracy: 0.2333
# Epoch 3/100
# 102/102 [==============================] - ETA: 0s - loss: 0.5616 - accuracy: 0.2676
# Epoch 00003: val_loss improved from 0.56285 to 0.56283, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 13ms/step - loss: 0.5616 - accuracy: 0.2676 - val_loss: 0.5628 - val_accuracy: 0.2500
# Epoch 4/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.5603 - accuracy: 0.2831
# Epoch 00004: val_loss improved from 0.56283 to 0.56227, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 12ms/step - loss: 0.5603 - accuracy: 0.2827 - val_loss: 0.5623 - val_accuracy: 0.2750
# Epoch 5/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.5560 - accuracy: 0.3015
# Epoch 00005: val_loss improved from 0.56227 to 0.56170, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 12ms/step - loss: 0.5559 - accuracy: 0.3031 - val_loss: 0.5617 - val_accuracy: 0.2444
# Epoch 6/100
# 102/102 [==============================] - ETA: 0s - loss: 0.5565 - accuracy: 0.2843
# Epoch 00006: val_loss did not improve from 0.56170
# 102/102 [==============================] - 1s 12ms/step - loss: 0.5565 - accuracy: 0.2843 - val_loss: 0.5694 - val_accuracy: 0.2472
# Epoch 7/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.5539 - accuracy: 0.2978
# Epoch 00007: val_loss improved from 0.56170 to 0.56143, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 13ms/step - loss: 0.5539 - accuracy: 0.2975 - val_loss: 0.5614 - val_accuracy: 0.2528
# Epoch 8/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.5495 - accuracy: 0.3119
# Epoch 00008: val_loss did not improve from 0.56143
# 102/102 [==============================] - 1s 12ms/step - loss: 0.5493 - accuracy: 0.3117 - val_loss: 0.5699 - val_accuracy: 0.2722
# Epoch 9/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.5458 - accuracy: 0.3230
# Epoch 00009: val_loss did not improve from 0.56143
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5458 - accuracy: 0.3231 - val_loss: 0.5719 - val_accuracy: 0.2972
# Epoch 10/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.5350 - accuracy: 0.3459
# Epoch 00010: val_loss improved from 0.56143 to 0.55377, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 12ms/step - loss: 0.5347 - accuracy: 0.3463 - val_loss: 0.5538 - val_accuracy: 0.3333
# Epoch 11/100
# 102/102 [==============================] - ETA: 0s - loss: 0.5281 - accuracy: 0.3534
# Epoch 00011: val_loss improved from 0.55377 to 0.52677, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 12ms/step - loss: 0.5281 - accuracy: 0.3534 - val_loss: 0.5268 - val_accuracy: 0.3944
# Epoch 12/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.5207 - accuracy: 0.3591
# Epoch 00012: val_loss improved from 0.52677 to 0.52261, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 13ms/step - loss: 0.5209 - accuracy: 0.3590 - val_loss: 0.5226 - val_accuracy: 0.3806
# Epoch 13/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.5145 - accuracy: 0.3756
# Epoch 00013: val_loss did not improve from 0.52261
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5141 - accuracy: 0.3753 - val_loss: 0.5317 - val_accuracy: 0.3528
# Epoch 14/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.5065 - accuracy: 0.3830
# Epoch 00014: val_loss did not improve from 0.52261
# 102/102 [==============================] - 1s 12ms/step - loss: 0.5066 - accuracy: 0.3830 - val_loss: 0.5274 - val_accuracy: 0.3556
# Epoch 15/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.5009 - accuracy: 0.4078
# Epoch 00015: val_loss improved from 0.52261 to 0.50023, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 12ms/step - loss: 0.5009 - accuracy: 0.4077 - val_loss: 0.5002 - val_accuracy: 0.4222
# Epoch 16/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4878 - accuracy: 0.4301
# Epoch 00016: val_loss improved from 0.50023 to 0.49122, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 12ms/step - loss: 0.4877 - accuracy: 0.4309 - val_loss: 0.4912 - val_accuracy: 0.4444
# Epoch 17/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.4939 - accuracy: 0.4109
# Epoch 00017: val_loss improved from 0.49122 to 0.47356, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 12ms/step - loss: 0.4935 - accuracy: 0.4111 - val_loss: 0.4736 - val_accuracy: 0.4417
# Epoch 18/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4672 - accuracy: 0.4647
# Epoch 00018: val_loss did not improve from 0.47356
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4678 - accuracy: 0.4645 - val_loss: 0.7559 - val_accuracy: 0.2639
# Epoch 19/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4709 - accuracy: 0.4657
# Epoch 00019: val_loss improved from 0.47356 to 0.45713, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 13ms/step - loss: 0.4714 - accuracy: 0.4645 - val_loss: 0.4571 - val_accuracy: 0.4611
# Epoch 20/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.4560 - accuracy: 0.4828
# Epoch 00020: val_loss did not improve from 0.45713
# 102/102 [==============================] - 1s 12ms/step - loss: 0.4550 - accuracy: 0.4830 - val_loss: 0.4689 - val_accuracy: 0.4444
# Epoch 21/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4505 - accuracy: 0.4799
# Epoch 00021: val_loss did not improve from 0.45713
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4508 - accuracy: 0.4799 - val_loss: 0.5218 - val_accuracy: 0.4056
# Epoch 22/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4480 - accuracy: 0.4985
# Epoch 00022: val_loss did not improve from 0.45713
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4482 - accuracy: 0.4985 - val_loss: 0.4571 - val_accuracy: 0.4639
# Epoch 23/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4304 - accuracy: 0.5161
# Epoch 00023: val_loss did not improve from 0.45713
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4306 - accuracy: 0.5160 - val_loss: 0.5910 - val_accuracy: 0.3722
# Epoch 24/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.4258 - accuracy: 0.5222
# Epoch 00024: val_loss improved from 0.45713 to 0.38576, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 12ms/step - loss: 0.4254 - accuracy: 0.5238 - val_loss: 0.3858 - val_accuracy: 0.5361
# Epoch 25/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.4030 - accuracy: 0.5564
# Epoch 00025: val_loss did not improve from 0.38576
# 102/102 [==============================] - 1s 12ms/step - loss: 0.4015 - accuracy: 0.5593 - val_loss: 0.5245 - val_accuracy: 0.4472
# Epoch 26/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.4072 - accuracy: 0.5450
# Epoch 00026: val_loss did not improve from 0.38576
# 102/102 [==============================] - 1s 12ms/step - loss: 0.4063 - accuracy: 0.5466 - val_loss: 0.4590 - val_accuracy: 0.4972
# Epoch 27/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.3993 - accuracy: 0.5531
# Epoch 00027: val_loss did not improve from 0.38576
# 102/102 [==============================] - 1s 12ms/step - loss: 0.3982 - accuracy: 0.5546 - val_loss: 0.5697 - val_accuracy: 0.3944
# Epoch 28/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.3957 - accuracy: 0.5575
# Epoch 00028: val_loss did not improve from 0.38576
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3954 - accuracy: 0.5583 - val_loss: 0.3974 - val_accuracy: 0.5417
# Epoch 29/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3821 - accuracy: 0.5783
# Epoch 00029: val_loss did not improve from 0.38576
# 102/102 [==============================] - 1s 13ms/step - loss: 0.3820 - accuracy: 0.5784 - val_loss: 0.4360 - val_accuracy: 0.5333
# Epoch 30/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.3813 - accuracy: 0.5891
# Epoch 00030: val_loss improved from 0.38576 to 0.33427, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 12ms/step - loss: 0.3822 - accuracy: 0.5877 - val_loss: 0.3343 - val_accuracy: 0.6306
# Epoch 31/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3830 - accuracy: 0.5798
# Epoch 00031: val_loss did not improve from 0.33427
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3838 - accuracy: 0.5790 - val_loss: 0.3635 - val_accuracy: 0.5750
# Epoch 32/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3727 - accuracy: 0.5860
# Epoch 00032: val_loss did not improve from 0.33427
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3744 - accuracy: 0.5846 - val_loss: 0.3585 - val_accuracy: 0.6167
# Epoch 33/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.3556 - accuracy: 0.6147
# Epoch 00033: val_loss did not improve from 0.33427
# 102/102 [==============================] - 1s 13ms/step - loss: 0.3554 - accuracy: 0.6148 - val_loss: 0.3432 - val_accuracy: 0.6167
# Epoch 34/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.3627 - accuracy: 0.5973
# Epoch 00034: val_loss improved from 0.33427 to 0.31804, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 12ms/step - loss: 0.3649 - accuracy: 0.5957 - val_loss: 0.3180 - val_accuracy: 0.6611
# Epoch 35/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3619 - accuracy: 0.6080
# Epoch 00035: val_loss did not improve from 0.31804
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3621 - accuracy: 0.6077 - val_loss: 0.3247 - val_accuracy: 0.6361
# Epoch 36/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.3462 - accuracy: 0.6172
# Epoch 00036: val_loss did not improve from 0.31804
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3476 - accuracy: 0.6160 - val_loss: 0.4329 - val_accuracy: 0.5250
# Epoch 37/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3495 - accuracy: 0.6244
# Epoch 00037: val_loss did not improve from 0.31804
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3498 - accuracy: 0.6241 - val_loss: 0.3277 - val_accuracy: 0.6278
# Epoch 38/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3526 - accuracy: 0.6105
# Epoch 00038: val_loss did not improve from 0.31804
# 102/102 [==============================] - 1s 12ms/step - loss: 0.3526 - accuracy: 0.6102 - val_loss: 0.4393 - val_accuracy: 0.5361
# Epoch 39/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.3515 - accuracy: 0.6266
# Epoch 00039: val_loss did not improve from 0.31804
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3519 - accuracy: 0.6262 - val_loss: 0.3662 - val_accuracy: 0.5917
# Epoch 40/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3351 - accuracy: 0.6519
# Epoch 00040: val_loss improved from 0.31804 to 0.29723, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 13ms/step - loss: 0.3353 - accuracy: 0.6515 - val_loss: 0.2972 - val_accuracy: 0.6611
# Epoch 41/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.3403 - accuracy: 0.6413
# Epoch 00041: val_loss improved from 0.29723 to 0.28813, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 2s 15ms/step - loss: 0.3405 - accuracy: 0.6401 - val_loss: 0.2881 - val_accuracy: 0.6861
# Epoch 42/100
# 102/102 [==============================] - ETA: 0s - loss: 0.3337 - accuracy: 0.6441
# Epoch 00042: val_loss did not improve from 0.28813
# 102/102 [==============================] - 1s 14ms/step - loss: 0.3337 - accuracy: 0.6441 - val_loss: 0.3495 - val_accuracy: 0.6167
# Epoch 43/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3222 - accuracy: 0.6535
# Epoch 00043: val_loss did not improve from 0.28813
# 102/102 [==============================] - 1s 13ms/step - loss: 0.3222 - accuracy: 0.6534 - val_loss: 0.3740 - val_accuracy: 0.6056
# Epoch 44/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.3115 - accuracy: 0.6758
# Epoch 00044: val_loss did not improve from 0.28813
# 102/102 [==============================] - 1s 12ms/step - loss: 0.3108 - accuracy: 0.6756 - val_loss: 0.4122 - val_accuracy: 0.5778
# Epoch 45/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3226 - accuracy: 0.6584
# Epoch 00045: val_loss did not improve from 0.28813
# 102/102 [==============================] - 1s 12ms/step - loss: 0.3228 - accuracy: 0.6580 - val_loss: 0.3846 - val_accuracy: 0.5889
# Epoch 46/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3061 - accuracy: 0.6723
# Epoch 00046: val_loss did not improve from 0.28813
# 102/102 [==============================] - 1s 12ms/step - loss: 0.3065 - accuracy: 0.6722 - val_loss: 0.2976 - val_accuracy: 0.6472
# Epoch 47/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3078 - accuracy: 0.6801
# Epoch 00047: val_loss improved from 0.28813 to 0.26302, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 14ms/step - loss: 0.3086 - accuracy: 0.6796 - val_loss: 0.2630 - val_accuracy: 0.7083
# Epoch 48/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3233 - accuracy: 0.6569
# Epoch 00048: val_loss did not improve from 0.26302
# 102/102 [==============================] - 1s 13ms/step - loss: 0.3237 - accuracy: 0.6568 - val_loss: 0.2640 - val_accuracy: 0.7000
# Epoch 49/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2980 - accuracy: 0.6860
# Epoch 00049: val_loss did not improve from 0.26302
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2994 - accuracy: 0.6852 - val_loss: 0.3119 - val_accuracy: 0.6583
# Epoch 50/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.3003 - accuracy: 0.6775
# Epoch 00050: val_loss did not improve from 0.26302
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3005 - accuracy: 0.6781 - val_loss: 0.4081 - val_accuracy: 0.5806
# Epoch 51/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2965 - accuracy: 0.6825
# Epoch 00051: val_loss did not improve from 0.26302
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2962 - accuracy: 0.6833 - val_loss: 0.3188 - val_accuracy: 0.6917
# Epoch 52/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2895 - accuracy: 0.6959
# Epoch 00052: val_loss did not improve from 0.26302
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2892 - accuracy: 0.6963 - val_loss: 0.2699 - val_accuracy: 0.7111
# Epoch 53/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2943 - accuracy: 0.6878
# Epoch 00053: val_loss did not improve from 0.26302
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2954 - accuracy: 0.6873 - val_loss: 0.3210 - val_accuracy: 0.6750
# Epoch 54/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.3011 - accuracy: 0.6850
# Epoch 00054: val_loss did not improve from 0.26302
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3017 - accuracy: 0.6849 - val_loss: 0.2772 - val_accuracy: 0.7028
# Epoch 55/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2848 - accuracy: 0.6946
# Epoch 00055: val_loss did not improve from 0.26302
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2845 - accuracy: 0.6951 - val_loss: 0.2938 - val_accuracy: 0.6833
# Epoch 56/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2841 - accuracy: 0.7011
# Epoch 00056: val_loss did not improve from 0.26302
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2842 - accuracy: 0.7009 - val_loss: 0.2991 - val_accuracy: 0.6917
# Epoch 57/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.2888 - accuracy: 0.6894
# Epoch 00057: val_loss did not improve from 0.26302
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2866 - accuracy: 0.6926 - val_loss: 0.2840 - val_accuracy: 0.6889
# Epoch 58/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.2785 - accuracy: 0.7047
# Epoch 00058: val_loss did not improve from 0.26302
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2792 - accuracy: 0.7052 - val_loss: 0.2927 - val_accuracy: 0.7056
# Epoch 59/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2734 - accuracy: 0.6989
# Epoch 00059: val_loss improved from 0.26302 to 0.23371, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2734 - accuracy: 0.6991 - val_loss: 0.2337 - val_accuracy: 0.7333
# Epoch 60/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2690 - accuracy: 0.7129
# Epoch 00060: val_loss did not improve from 0.23371
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2697 - accuracy: 0.7123 - val_loss: 0.2408 - val_accuracy: 0.7472
# Epoch 61/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.2700 - accuracy: 0.7105
# Epoch 00061: val_loss improved from 0.23371 to 0.22252, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2692 - accuracy: 0.7105 - val_loss: 0.2225 - val_accuracy: 0.7472
# Epoch 62/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2738 - accuracy: 0.7194
# Epoch 00062: val_loss did not improve from 0.22252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2731 - accuracy: 0.7204 - val_loss: 0.3001 - val_accuracy: 0.6806
# Epoch 63/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2811 - accuracy: 0.7036
# Epoch 00063: val_loss did not improve from 0.22252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2809 - accuracy: 0.7037 - val_loss: 0.2511 - val_accuracy: 0.7306
# Epoch 64/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.2700 - accuracy: 0.7136
# Epoch 00064: val_loss did not improve from 0.22252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2702 - accuracy: 0.7133 - val_loss: 0.2373 - val_accuracy: 0.7278
# Epoch 65/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.7154
# Epoch 00065: val_loss did not improve from 0.22252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2657 - accuracy: 0.7154 - val_loss: 0.2338 - val_accuracy: 0.7389
# Epoch 66/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2662 - accuracy: 0.7194
# Epoch 00066: val_loss did not improve from 0.22252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2655 - accuracy: 0.7204 - val_loss: 0.2626 - val_accuracy: 0.7250
# Epoch 67/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2658 - accuracy: 0.7234
# Epoch 00067: val_loss did not improve from 0.22252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2647 - accuracy: 0.7250 - val_loss: 0.2524 - val_accuracy: 0.7194
# Epoch 68/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2436 - accuracy: 0.7386
# Epoch 00068: val_loss did not improve from 0.22252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2436 - accuracy: 0.7386 - val_loss: 0.2467 - val_accuracy: 0.7194
# Epoch 69/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2607 - accuracy: 0.7178
# Epoch 00069: val_loss did not improve from 0.22252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2608 - accuracy: 0.7176 - val_loss: 0.2523 - val_accuracy: 0.7361
# Epoch 70/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2644 - accuracy: 0.7200
# Epoch 00070: val_loss did not improve from 0.22252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2647 - accuracy: 0.7204 - val_loss: 0.4445 - val_accuracy: 0.6222
# Epoch 71/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2686 - accuracy: 0.7148
# Epoch 00071: val_loss did not improve from 0.22252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2686 - accuracy: 0.7148 - val_loss: 0.2434 - val_accuracy: 0.7250
# Epoch 72/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2501 - accuracy: 0.7317
# Epoch 00072: val_loss did not improve from 0.22252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2499 - accuracy: 0.7321 - val_loss: 0.2292 - val_accuracy: 0.7333
# Epoch 73/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2458 - accuracy: 0.7377
# Epoch 00073: val_loss improved from 0.22252 to 0.21767, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2482 - accuracy: 0.7343 - val_loss: 0.2177 - val_accuracy: 0.7694
# Epoch 74/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2582 - accuracy: 0.7241
# Epoch 00074: val_loss did not improve from 0.21767
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2580 - accuracy: 0.7235 - val_loss: 0.2440 - val_accuracy: 0.7139
# Epoch 75/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2497 - accuracy: 0.7391
# Epoch 00075: val_loss did not improve from 0.21767
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2492 - accuracy: 0.7395 - val_loss: 0.2652 - val_accuracy: 0.7111
# Epoch 76/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2565 - accuracy: 0.7352
# Epoch 00076: val_loss did not improve from 0.21767
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2565 - accuracy: 0.7352 - val_loss: 0.2531 - val_accuracy: 0.7111
# Epoch 77/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2478 - accuracy: 0.7348
# Epoch 00077: val_loss did not improve from 0.21767
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2481 - accuracy: 0.7346 - val_loss: 0.2611 - val_accuracy: 0.7250
# Epoch 78/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2383 - accuracy: 0.7462
# Epoch 00078: val_loss did not improve from 0.21767
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2376 - accuracy: 0.7469 - val_loss: 0.2610 - val_accuracy: 0.7222
# Epoch 79/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2466 - accuracy: 0.7420
# Epoch 00079: val_loss did not improve from 0.21767
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2466 - accuracy: 0.7420 - val_loss: 0.2380 - val_accuracy: 0.7583
# Epoch 80/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2540 - accuracy: 0.7290
# Epoch 00080: val_loss did not improve from 0.21767
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2547 - accuracy: 0.7287 - val_loss: 0.2214 - val_accuracy: 0.7583
# Epoch 81/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2336 - accuracy: 0.7459
# Epoch 00081: val_loss improved from 0.21767 to 0.21697, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2329 - accuracy: 0.7460 - val_loss: 0.2170 - val_accuracy: 0.7556
# Epoch 82/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2409 - accuracy: 0.7438
# Epoch 00082: val_loss did not improve from 0.21697
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2416 - accuracy: 0.7435 - val_loss: 0.2182 - val_accuracy: 0.7500
# Epoch 83/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2347 - accuracy: 0.7401
# Epoch 00083: val_loss did not improve from 0.21697
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2349 - accuracy: 0.7398 - val_loss: 0.2556 - val_accuracy: 0.7361
# Epoch 84/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2491 - accuracy: 0.7376
# Epoch 00084: val_loss did not improve from 0.21697
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2494 - accuracy: 0.7370 - val_loss: 0.2587 - val_accuracy: 0.7333
# Epoch 85/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2392 - accuracy: 0.7416
# Epoch 00085: val_loss did not improve from 0.21697
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2389 - accuracy: 0.7423 - val_loss: 0.2575 - val_accuracy: 0.7306
# Epoch 86/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2407 - accuracy: 0.7422
# Epoch 00086: val_loss did not improve from 0.21697
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2404 - accuracy: 0.7423 - val_loss: 0.2266 - val_accuracy: 0.7417
# Epoch 87/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2316 - accuracy: 0.7546
# Epoch 00087: val_loss did not improve from 0.21697
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2318 - accuracy: 0.7543 - val_loss: 0.2213 - val_accuracy: 0.7722
# Epoch 88/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2286 - accuracy: 0.7603
# Epoch 00088: val_loss did not improve from 0.21697
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2284 - accuracy: 0.7602 - val_loss: 0.2349 - val_accuracy: 0.7444
# Epoch 89/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2317 - accuracy: 0.7503
# Epoch 00089: val_loss did not improve from 0.21697
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2318 - accuracy: 0.7503 - val_loss: 0.2172 - val_accuracy: 0.7583
# Epoch 90/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2332 - accuracy: 0.7575
# Epoch 00090: val_loss improved from 0.21697 to 0.20575, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2330 - accuracy: 0.7571 - val_loss: 0.2057 - val_accuracy: 0.7611
# Epoch 91/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2417 - accuracy: 0.7389
# Epoch 00091: val_loss did not improve from 0.20575
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2420 - accuracy: 0.7386 - val_loss: 0.2296 - val_accuracy: 0.7444
# Epoch 92/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2378 - accuracy: 0.7454
# Epoch 00092: val_loss did not improve from 0.20575
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2374 - accuracy: 0.7457 - val_loss: 0.2364 - val_accuracy: 0.7500
# Epoch 93/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2300 - accuracy: 0.7525
# Epoch 00093: val_loss did not improve from 0.20575
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2293 - accuracy: 0.7531 - val_loss: 0.2377 - val_accuracy: 0.7444
# Epoch 94/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2322 - accuracy: 0.7532
# Epoch 00094: val_loss improved from 0.20575 to 0.18252, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2328 - accuracy: 0.7519 - val_loss: 0.1825 - val_accuracy: 0.7778
# Epoch 95/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2354 - accuracy: 0.7488
# Epoch 00095: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2357 - accuracy: 0.7481 - val_loss: 0.2036 - val_accuracy: 0.7528
# Epoch 96/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2297 - accuracy: 0.7525
# Epoch 00096: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2302 - accuracy: 0.7525 - val_loss: 0.2275 - val_accuracy: 0.7500
# Epoch 97/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.2406 - accuracy: 0.7439
# Epoch 00097: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2386 - accuracy: 0.7469 - val_loss: 0.2469 - val_accuracy: 0.7333
# Epoch 98/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2240 - accuracy: 0.7541
# Epoch 00098: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2237 - accuracy: 0.7543 - val_loss: 0.2239 - val_accuracy: 0.7556
# Epoch 99/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2223 - accuracy: 0.7636
# Epoch 00099: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2223 - accuracy: 0.7636 - val_loss: 0.2444 - val_accuracy: 0.7194
# Epoch 100/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2267 - accuracy: 0.7519
# Epoch 00100: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2267 - accuracy: 0.7522 - val_loss: 0.2241 - val_accuracy: 0.7444
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2099 - accuracy: 0.7875
# Val Score:  [0.2098921835422516, 0.7875000238418579]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.6449 - accuracy: 0.2534
# Epoch 00001: val_loss did not improve from 0.18252
# 102/102 [==============================] - 2s 24ms/step - loss: 0.6448 - accuracy: 0.2531 - val_loss: 0.5906 - val_accuracy: 0.2778
# Epoch 2/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.5687 - accuracy: 0.2689
# Epoch 00002: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5686 - accuracy: 0.2688 - val_loss: 0.5623 - val_accuracy: 0.2778
# Epoch 3/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.5604 - accuracy: 0.2723
# Epoch 00003: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5604 - accuracy: 0.2725 - val_loss: 0.5622 - val_accuracy: 0.2528
# Epoch 4/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.5580 - accuracy: 0.2937
# Epoch 00004: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.5580 - accuracy: 0.2954 - val_loss: 0.5620 - val_accuracy: 0.2778
# Epoch 5/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.5529 - accuracy: 0.3030
# Epoch 00005: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5529 - accuracy: 0.3028 - val_loss: 0.5667 - val_accuracy: 0.2778
# Epoch 6/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.5487 - accuracy: 0.3125
# Epoch 00006: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5488 - accuracy: 0.3117 - val_loss: 0.5580 - val_accuracy: 0.2750
# Epoch 7/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.5439 - accuracy: 0.3286
# Epoch 00007: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5433 - accuracy: 0.3309 - val_loss: 0.5615 - val_accuracy: 0.3028
# Epoch 8/100
# 102/102 [==============================] - ETA: 0s - loss: 0.5354 - accuracy: 0.3426
# Epoch 00008: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.5354 - accuracy: 0.3426 - val_loss: 0.5470 - val_accuracy: 0.3278
# Epoch 9/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.5288 - accuracy: 0.3530
# Epoch 00009: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.5286 - accuracy: 0.3546 - val_loss: 0.5795 - val_accuracy: 0.3167
# Epoch 10/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.5247 - accuracy: 0.3722
# Epoch 00010: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5242 - accuracy: 0.3713 - val_loss: 0.5234 - val_accuracy: 0.3944
# Epoch 11/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.5184 - accuracy: 0.3651
# Epoch 00011: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5184 - accuracy: 0.3648 - val_loss: 0.5375 - val_accuracy: 0.3361
# Epoch 12/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.5066 - accuracy: 0.3982
# Epoch 00012: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5067 - accuracy: 0.3985 - val_loss: 0.5126 - val_accuracy: 0.4194
# Epoch 13/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4978 - accuracy: 0.3951
# Epoch 00013: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4979 - accuracy: 0.3948 - val_loss: 0.5906 - val_accuracy: 0.2667
# Epoch 14/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4935 - accuracy: 0.3945
# Epoch 00014: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4934 - accuracy: 0.3941 - val_loss: 0.5085 - val_accuracy: 0.3750
# Epoch 15/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.4831 - accuracy: 0.4256
# Epoch 00015: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4843 - accuracy: 0.4244 - val_loss: 0.4706 - val_accuracy: 0.4444
# Epoch 16/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4796 - accuracy: 0.4273
# Epoch 00016: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4796 - accuracy: 0.4272 - val_loss: 0.4892 - val_accuracy: 0.4333
# Epoch 17/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.4770 - accuracy: 0.4290
# Epoch 00017: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4765 - accuracy: 0.4309 - val_loss: 0.5001 - val_accuracy: 0.3556
# Epoch 18/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4688 - accuracy: 0.4338
# Epoch 00018: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.4687 - accuracy: 0.4336 - val_loss: 0.4910 - val_accuracy: 0.4278
# Epoch 19/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4688 - accuracy: 0.4381
# Epoch 00019: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.4686 - accuracy: 0.4380 - val_loss: 0.6737 - val_accuracy: 0.3222
# Epoch 20/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.4558 - accuracy: 0.4641
# Epoch 00020: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.4559 - accuracy: 0.4633 - val_loss: 0.4957 - val_accuracy: 0.4167
# Epoch 21/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.4526 - accuracy: 0.4584
# Epoch 00021: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4531 - accuracy: 0.4565 - val_loss: 0.4834 - val_accuracy: 0.4194
# Epoch 22/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.4406 - accuracy: 0.4822
# Epoch 00022: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.4411 - accuracy: 0.4812 - val_loss: 0.4177 - val_accuracy: 0.5028
# Epoch 23/100
# 102/102 [==============================] - ETA: 0s - loss: 0.4337 - accuracy: 0.4873
# Epoch 00023: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4337 - accuracy: 0.4873 - val_loss: 0.4504 - val_accuracy: 0.4639
# Epoch 24/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.4428 - accuracy: 0.4807
# Epoch 00024: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.4423 - accuracy: 0.4846 - val_loss: 0.4299 - val_accuracy: 0.4972
# Epoch 25/100
# 102/102 [==============================] - ETA: 0s - loss: 0.4293 - accuracy: 0.4941
# Epoch 00025: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.4293 - accuracy: 0.4941 - val_loss: 0.3998 - val_accuracy: 0.5222
# Epoch 26/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4228 - accuracy: 0.4994
# Epoch 00026: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4225 - accuracy: 0.4997 - val_loss: 0.4324 - val_accuracy: 0.5111
# Epoch 27/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4162 - accuracy: 0.5183
# Epoch 00027: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4159 - accuracy: 0.5182 - val_loss: 0.4212 - val_accuracy: 0.5083
# Epoch 28/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4145 - accuracy: 0.5195
# Epoch 00028: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4155 - accuracy: 0.5188 - val_loss: 0.5133 - val_accuracy: 0.4472
# Epoch 29/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4069 - accuracy: 0.5297
# Epoch 00029: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4072 - accuracy: 0.5290 - val_loss: 0.3794 - val_accuracy: 0.5667
# Epoch 30/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.3986 - accuracy: 0.5312
# Epoch 00030: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3989 - accuracy: 0.5299 - val_loss: 0.3861 - val_accuracy: 0.5417
# Epoch 31/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.4038 - accuracy: 0.5328
# Epoch 00031: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4033 - accuracy: 0.5352 - val_loss: 0.3936 - val_accuracy: 0.5306
# Epoch 32/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.4003 - accuracy: 0.5335
# Epoch 00032: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4006 - accuracy: 0.5315 - val_loss: 0.4090 - val_accuracy: 0.5083
# Epoch 33/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4011 - accuracy: 0.5402
# Epoch 00033: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.4011 - accuracy: 0.5401 - val_loss: 0.6046 - val_accuracy: 0.4306
# Epoch 34/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.3859 - accuracy: 0.5459
# Epoch 00034: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3849 - accuracy: 0.5463 - val_loss: 0.3968 - val_accuracy: 0.5278
# Epoch 35/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3864 - accuracy: 0.5541
# Epoch 00035: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3863 - accuracy: 0.5540 - val_loss: 0.4190 - val_accuracy: 0.5250
# Epoch 36/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3824 - accuracy: 0.5548
# Epoch 00036: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3826 - accuracy: 0.5546 - val_loss: 0.3555 - val_accuracy: 0.5611
# Epoch 37/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.3797 - accuracy: 0.5578
# Epoch 00037: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3795 - accuracy: 0.5583 - val_loss: 0.4086 - val_accuracy: 0.5611
# Epoch 38/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.3659 - accuracy: 0.5811
# Epoch 00038: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.3662 - accuracy: 0.5815 - val_loss: 0.3613 - val_accuracy: 0.5667
# Epoch 39/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3690 - accuracy: 0.5894
# Epoch 00039: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3689 - accuracy: 0.5895 - val_loss: 0.3757 - val_accuracy: 0.5806
# Epoch 40/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.3670 - accuracy: 0.5919
# Epoch 00040: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.3675 - accuracy: 0.5889 - val_loss: 0.3296 - val_accuracy: 0.6306
# Epoch 41/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.3584 - accuracy: 0.6059
# Epoch 00041: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3602 - accuracy: 0.6046 - val_loss: 0.3652 - val_accuracy: 0.6000
# Epoch 42/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.3400 - accuracy: 0.6322
# Epoch 00042: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.3394 - accuracy: 0.6333 - val_loss: 0.5635 - val_accuracy: 0.5056
# Epoch 43/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3456 - accuracy: 0.6200
# Epoch 00043: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.3453 - accuracy: 0.6207 - val_loss: 0.3302 - val_accuracy: 0.6528
# Epoch 44/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.3363 - accuracy: 0.6474
# Epoch 00044: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.3364 - accuracy: 0.6478 - val_loss: 0.3713 - val_accuracy: 0.6222
# Epoch 45/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3229 - accuracy: 0.6553
# Epoch 00045: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3238 - accuracy: 0.6549 - val_loss: 0.4038 - val_accuracy: 0.5917
# Epoch 46/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.3249 - accuracy: 0.6509
# Epoch 00046: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.3242 - accuracy: 0.6531 - val_loss: 0.3012 - val_accuracy: 0.6611
# Epoch 47/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3156 - accuracy: 0.6603
# Epoch 00047: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3156 - accuracy: 0.6602 - val_loss: 0.3086 - val_accuracy: 0.6611
# Epoch 48/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3104 - accuracy: 0.6751
# Epoch 00048: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.3103 - accuracy: 0.6756 - val_loss: 0.3262 - val_accuracy: 0.6444
# Epoch 49/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3097 - accuracy: 0.6730
# Epoch 00049: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.3098 - accuracy: 0.6725 - val_loss: 0.3058 - val_accuracy: 0.6778
# Epoch 50/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3009 - accuracy: 0.6909
# Epoch 00050: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.3006 - accuracy: 0.6910 - val_loss: 0.3153 - val_accuracy: 0.6472
# Epoch 51/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2952 - accuracy: 0.6894
# Epoch 00051: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2961 - accuracy: 0.6889 - val_loss: 0.3569 - val_accuracy: 0.6278
# Epoch 52/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2942 - accuracy: 0.6907
# Epoch 00052: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2938 - accuracy: 0.6907 - val_loss: 0.2795 - val_accuracy: 0.6833
# Epoch 53/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2873 - accuracy: 0.7039
# Epoch 00053: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2871 - accuracy: 0.7037 - val_loss: 0.3573 - val_accuracy: 0.6361
# Epoch 54/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2957 - accuracy: 0.6919
# Epoch 00054: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2948 - accuracy: 0.6941 - val_loss: 0.2753 - val_accuracy: 0.6944
# Epoch 55/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2883 - accuracy: 0.7022
# Epoch 00055: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2888 - accuracy: 0.7019 - val_loss: 0.3148 - val_accuracy: 0.6472
# Epoch 56/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2813 - accuracy: 0.7045
# Epoch 00056: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2815 - accuracy: 0.7043 - val_loss: 0.3160 - val_accuracy: 0.6444
# Epoch 57/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2855 - accuracy: 0.7044
# Epoch 00057: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2858 - accuracy: 0.7043 - val_loss: 0.2869 - val_accuracy: 0.6861
# Epoch 58/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2841 - accuracy: 0.6944
# Epoch 00058: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2842 - accuracy: 0.6944 - val_loss: 0.3279 - val_accuracy: 0.6639
# Epoch 59/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2931 - accuracy: 0.7017
# Epoch 00059: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2929 - accuracy: 0.7022 - val_loss: 0.2565 - val_accuracy: 0.7139
# Epoch 60/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2762 - accuracy: 0.7176
# Epoch 00060: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2762 - accuracy: 0.7176 - val_loss: 0.2666 - val_accuracy: 0.6917
# Epoch 61/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2650 - accuracy: 0.7262
# Epoch 00061: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 11ms/step - loss: 0.2650 - accuracy: 0.7262 - val_loss: 0.2835 - val_accuracy: 0.7000
# Epoch 62/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2634 - accuracy: 0.7194
# Epoch 00062: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2634 - accuracy: 0.7198 - val_loss: 0.3585 - val_accuracy: 0.6444
# Epoch 63/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2650 - accuracy: 0.7181
# Epoch 00063: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2658 - accuracy: 0.7182 - val_loss: 0.2726 - val_accuracy: 0.6972
# Epoch 64/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2665 - accuracy: 0.7237
# Epoch 00064: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2676 - accuracy: 0.7235 - val_loss: 0.2815 - val_accuracy: 0.6861
# Epoch 65/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2640 - accuracy: 0.7237
# Epoch 00065: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2647 - accuracy: 0.7228 - val_loss: 0.3351 - val_accuracy: 0.6250
# Epoch 66/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2679 - accuracy: 0.7179
# Epoch 00066: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2679 - accuracy: 0.7179 - val_loss: 0.2621 - val_accuracy: 0.6917
# Epoch 67/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2565 - accuracy: 0.7389
# Epoch 00067: val_loss did not improve from 0.18252
# ...
# Epoch 45/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2971 - accuracy: 0.6828
# Epoch 00045: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2981 - accuracy: 0.6815 - val_loss: 0.2477 - val_accuracy: 0.7194
# Epoch 46/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.3035 - accuracy: 0.6747
# Epoch 00046: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.3033 - accuracy: 0.6741 - val_loss: 0.2810 - val_accuracy: 0.7056
# Epoch 47/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2930 - accuracy: 0.6923
# Epoch 00047: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2930 - accuracy: 0.6923 - val_loss: 0.2831 - val_accuracy: 0.7250
# Epoch 48/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2897 - accuracy: 0.6962
# Epoch 00048: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2892 - accuracy: 0.6969 - val_loss: 0.2679 - val_accuracy: 0.7000
# Epoch 49/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2724 - accuracy: 0.7153
# Epoch 00049: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2721 - accuracy: 0.7157 - val_loss: 0.3261 - val_accuracy: 0.7028
# Epoch 50/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2780 - accuracy: 0.7019
# Epoch 00050: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2780 - accuracy: 0.7019 - val_loss: 0.2509 - val_accuracy: 0.7361
# Epoch 51/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2781 - accuracy: 0.7141
# Epoch 00051: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2775 - accuracy: 0.7145 - val_loss: 0.2998 - val_accuracy: 0.6917
# Epoch 52/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2753 - accuracy: 0.7127
# Epoch 00052: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2753 - accuracy: 0.7127 - val_loss: 0.3420 - val_accuracy: 0.6833
# Epoch 53/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2754 - accuracy: 0.7114
# Epoch 00053: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2754 - accuracy: 0.7114 - val_loss: 0.2986 - val_accuracy: 0.7167
# Epoch 54/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2700 - accuracy: 0.7178
# Epoch 00054: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 14ms/step - loss: 0.2700 - accuracy: 0.7179 - val_loss: 0.2555 - val_accuracy: 0.7111
# Epoch 55/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2703 - accuracy: 0.7069
# Epoch 00055: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2711 - accuracy: 0.7071 - val_loss: 0.2410 - val_accuracy: 0.7361
# Epoch 56/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.2703 - accuracy: 0.7108
# Epoch 00056: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2714 - accuracy: 0.7105 - val_loss: 0.2304 - val_accuracy: 0.7444
# Epoch 57/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2655 - accuracy: 0.7218
# Epoch 00057: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2657 - accuracy: 0.7219 - val_loss: 0.2093 - val_accuracy: 0.7639
# Epoch 58/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2642 - accuracy: 0.7194
# Epoch 00058: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2642 - accuracy: 0.7194 - val_loss: 0.1914 - val_accuracy: 0.7861
# Epoch 59/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2641 - accuracy: 0.7160
# Epoch 00059: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2650 - accuracy: 0.7154 - val_loss: 0.2579 - val_accuracy: 0.7278
# Epoch 60/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2490 - accuracy: 0.7375
# Epoch 00060: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 14ms/step - loss: 0.2488 - accuracy: 0.7383 - val_loss: 0.1963 - val_accuracy: 0.7694
# Epoch 61/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2577 - accuracy: 0.7262
# Epoch 00061: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2582 - accuracy: 0.7256 - val_loss: 0.2768 - val_accuracy: 0.7111
# Epoch 62/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2684 - accuracy: 0.7209
# Epoch 00062: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2682 - accuracy: 0.7204 - val_loss: 0.2521 - val_accuracy: 0.7306
# Epoch 63/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2554 - accuracy: 0.7318
# Epoch 00063: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2554 - accuracy: 0.7318 - val_loss: 0.3045 - val_accuracy: 0.6944
# Epoch 64/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2556 - accuracy: 0.7291
# Epoch 00064: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2561 - accuracy: 0.7281 - val_loss: 0.2098 - val_accuracy: 0.7639
# Epoch 65/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2529 - accuracy: 0.7347
# Epoch 00065: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2526 - accuracy: 0.7349 - val_loss: 0.2192 - val_accuracy: 0.7722
# Epoch 66/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2535 - accuracy: 0.7364
# Epoch 00066: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2544 - accuracy: 0.7355 - val_loss: 0.2214 - val_accuracy: 0.7528
# Epoch 67/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2440 - accuracy: 0.7444
# Epoch 00067: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2446 - accuracy: 0.7441 - val_loss: 0.2142 - val_accuracy: 0.7889
# Epoch 68/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2384 - accuracy: 0.7438
# Epoch 00068: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2386 - accuracy: 0.7435 - val_loss: 0.2298 - val_accuracy: 0.7444
# Epoch 69/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2399 - accuracy: 0.7438
# Epoch 00069: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2399 - accuracy: 0.7441 - val_loss: 0.2148 - val_accuracy: 0.7611
# Epoch 70/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2396 - accuracy: 0.7386
# Epoch 00070: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2396 - accuracy: 0.7389 - val_loss: 0.2312 - val_accuracy: 0.7528
# Epoch 71/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2407 - accuracy: 0.7522
# Epoch 00071: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2411 - accuracy: 0.7519 - val_loss: 0.2155 - val_accuracy: 0.7639
# Epoch 72/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2462 - accuracy: 0.7434
# Epoch 00072: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2461 - accuracy: 0.7444 - val_loss: 0.2079 - val_accuracy: 0.7722
# Epoch 73/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.2388 - accuracy: 0.7436
# Epoch 00073: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2372 - accuracy: 0.7463 - val_loss: 0.2254 - val_accuracy: 0.7556
# Epoch 74/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2397 - accuracy: 0.7422
# Epoch 00074: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2409 - accuracy: 0.7404 - val_loss: 0.2704 - val_accuracy: 0.7250
# Epoch 75/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2414 - accuracy: 0.7400
# Epoch 00075: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2407 - accuracy: 0.7407 - val_loss: 0.2015 - val_accuracy: 0.7889
# Epoch 76/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2403 - accuracy: 0.7491
# Epoch 00076: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2433 - accuracy: 0.7463 - val_loss: 0.2095 - val_accuracy: 0.7889
# Epoch 77/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2552 - accuracy: 0.7282
# Epoch 00077: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2561 - accuracy: 0.7269 - val_loss: 0.2189 - val_accuracy: 0.7611
# Epoch 78/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2362 - accuracy: 0.7416
# Epoch 00078: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2362 - accuracy: 0.7420 - val_loss: 0.2163 - val_accuracy: 0.7833
# Epoch 79/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2341 - accuracy: 0.7506
# Epoch 00079: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2344 - accuracy: 0.7512 - val_loss: 0.1957 - val_accuracy: 0.7944
# Epoch 80/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2314 - accuracy: 0.7500
# Epoch 00080: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2314 - accuracy: 0.7494 - val_loss: 0.2260 - val_accuracy: 0.7667
# Epoch 81/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2321 - accuracy: 0.7456
# Epoch 00081: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2340 - accuracy: 0.7448 - val_loss: 0.1874 - val_accuracy: 0.7917
# Epoch 82/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2406 - accuracy: 0.7358
# Epoch 00082: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2407 - accuracy: 0.7355 - val_loss: 0.2069 - val_accuracy: 0.7694
# Epoch 83/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2322 - accuracy: 0.7534
# Epoch 00083: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2322 - accuracy: 0.7534 - val_loss: 0.2069 - val_accuracy: 0.7833
# Epoch 84/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.2324 - accuracy: 0.7497
# Epoch 00084: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2332 - accuracy: 0.7500 - val_loss: 0.2051 - val_accuracy: 0.7722
# Epoch 85/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2263 - accuracy: 0.7522
# Epoch 00085: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2263 - accuracy: 0.7522 - val_loss: 0.2503 - val_accuracy: 0.7556
# Epoch 86/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2324 - accuracy: 0.7525
# Epoch 00086: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2323 - accuracy: 0.7528 - val_loss: 0.2883 - val_accuracy: 0.7361
# Epoch 87/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2260 - accuracy: 0.7525
# Epoch 00087: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2265 - accuracy: 0.7525 - val_loss: 0.2080 - val_accuracy: 0.7861
# Epoch 88/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.2310 - accuracy: 0.7459
# Epoch 00088: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2300 - accuracy: 0.7478 - val_loss: 0.2306 - val_accuracy: 0.7583
# Epoch 89/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2293 - accuracy: 0.7590
# Epoch 00089: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2301 - accuracy: 0.7583 - val_loss: 0.2031 - val_accuracy: 0.7667
# Epoch 90/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2390 - accuracy: 0.7429
# Epoch 00090: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2393 - accuracy: 0.7426 - val_loss: 0.2043 - val_accuracy: 0.7667
# Epoch 91/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2290 - accuracy: 0.7590
# Epoch 00091: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2290 - accuracy: 0.7593 - val_loss: 0.2112 - val_accuracy: 0.7833
# Epoch 92/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2360 - accuracy: 0.7487
# Epoch 00092: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2361 - accuracy: 0.7509 - val_loss: 0.1967 - val_accuracy: 0.7806
# Epoch 93/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2185 - accuracy: 0.7645
# Epoch 00093: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2201 - accuracy: 0.7627 - val_loss: 0.2102 - val_accuracy: 0.7778
# Epoch 94/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2420 - accuracy: 0.7506
# Epoch 00094: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2420 - accuracy: 0.7519 - val_loss: 0.1950 - val_accuracy: 0.8028
# Epoch 95/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2261 - accuracy: 0.7525
# Epoch 00095: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 13ms/step - loss: 0.2261 - accuracy: 0.7528 - val_loss: 0.1994 - val_accuracy: 0.7833
# Epoch 96/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2274 - accuracy: 0.7584
# Epoch 00096: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2273 - accuracy: 0.7586 - val_loss: 0.2015 - val_accuracy: 0.7889
# Epoch 97/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2198 - accuracy: 0.7548
# Epoch 00097: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 12ms/step - loss: 0.2200 - accuracy: 0.7537 - val_loss: 0.2238 - val_accuracy: 0.7694
# Epoch 98/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.2259 - accuracy: 0.7525
# Epoch 00098: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 14ms/step - loss: 0.2272 - accuracy: 0.7515 - val_loss: 0.1884 - val_accuracy: 0.7917
# Epoch 99/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2193 - accuracy: 0.7639
# Epoch 00099: val_loss did not improve from 0.18252
# 102/102 [==============================] - 1s 14ms/step - loss: 0.2193 - accuracy: 0.7639 - val_loss: 0.2007 - val_accuracy: 0.7917
# Epoch 100/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2268 - accuracy: 0.7503
# Epoch 00100: val_loss improved from 0.18252 to 0.16794, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 2s 15ms/step - loss: 0.2286 - accuracy: 0.7481 - val_loss: 0.1679 - val_accuracy: 0.8167
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2029 - accuracy: 0.7825
# Val Score:  [0.20289775729179382, 0.7825000286102295]
# ====================================================================================

# %%
#Load the model that was saved by ModelCheckpoint
model = load_model('fas_mnist_1.h5')

# %%
model.evaluate(test_X, test_y)
#print("Accuracy of the model is - " , model.evaluate(test_X,test_y)[1]*100 , "%")
#plt.bar( model.evaluate(test_X)[1].index,  model.evaluate(test_y)[1])
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1663 - accuracy: 0.7990
# [0.16630898416042328, 0.7990000247955322]

# %%
fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)

ax1.plot(model_history[0].history['accuracy'], label='Training Fold 1 accuration')
ax1.plot(model_history[1].history['accuracy'], label='Training Fold 2 accuration')
ax1.plot(model_history[2].history['accuracy'], label='Training Fold 3 accuration')
ax1.plot(model_history[3].history['accuracy'], label='Training Fold 4 accuration')
ax1.plot(model_history[4].history['accuracy'], label='Training Fold 5 accuration')
ax1.legend()
ax2.plot(model_history[1].history['loss'], label='Training Fold 1 loss')
ax2.plot(model_history[1].history['loss'], label='Training Fold 2 loss')
ax2.plot(model_history[2].history['loss'], label='Training Fold 3 loss')
ax2.plot(model_history[3].history['loss'], label='Training Fold 4 loss ')
ax2.plot(model_history[4].history['loss'], label='Training Fold 5 loss')
ax2.legend()
plt.show()

# %%
fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt1.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[0].history['loss'], label='Train Loss Fold 1', color='black')
plt2.plot(model_history[0].history['val_loss'], label='Val Loss Fold 1', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red')
plt1.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[1].history['loss'], label='Train Loss Fold 2', color='red')
plt2.plot(model_history[1].history['val_loss'], label='Val Loss Fold 2', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green')
plt1.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[2].history['loss'], label='Train Loss Fold 3', color='green')
plt2.plot(model_history[2].history['val_loss'], label='Val Loss Fold 3', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()


fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue')
plt1.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[3].history['loss'], label='Train Loss Fold 4', color='blue')
plt2.plot(model_history[3].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='purple')
plt1.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[4].history['loss'], label='Train Loss Fold 4', color='purple')
plt2.plot(model_history[4].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

# %%
MODEL_NAME ='fas_mnist_1.h5' 

#CLIP = True # if your model was trained with np.clip to clip  values
CLIP = False
CLIP_VAL = 8  # if above, what was the value +/-

model = tf.keras.models.load_model(MODEL_NAME)

VALDIR = '//content/drive/MyDrive/Colab Notebooks/tes_data'
ACTIONS =  ["idle","maju","kiri", "kanan"]
PRED_BATCH = 32


def get_val_data(valdir, action, batch_size):

   # argmax_dict = {0: 0, 1: 0, 2: 0,3:0}
    argmax_dict = {2: 0, 0: 0, 1: 0,3:0}
    raw_pred_dict = {0: 0, 1: 0, 2: 0,3:0}

    action_dir = os.path.join(valdir, action)
    for session_file in os.listdir(action_dir):
        filepath = os.path.join(action_dir,session_file)
        if CLIP:
            data = np.clip(np.load(filepath), -CLIP_VAL, CLIP_VAL) / CLIP_VAL
            #print(data)
        else:
            data = np.load(filepath) 
        preds = model.predict([data.reshape(-1, 16, 60,1)], batch_size=batch_size)
        
        for pred in preds:
            argmax = np.argmax(pred)
            argmax_dict[argmax] += 1
            for idx,value in enumerate(pred):
                raw_pred_dict[idx] += value
    
    argmax_pct_dict = {}
    for i in argmax_dict:
        total = 0
        correct = argmax_dict[i]
        for ii in argmax_dict:
            total += argmax_dict[ii]
        argmax_pct_dict[i] = round(correct/total, 4)
    return argmax_dict, raw_pred_dict, argmax_pct_dict


def make_conf_mat(none,left,forward, right):
    action_dict = {"idle":none,"maju": forward, "kiri": left, "kanan": right}
    action_conf_mat = pd.DataFrame(action_dict)
    actions = [i for i in action_dict]

    fig = plt.figure(figsize=(15, 6))
    ax = fig.add_subplot(111)
    ax.matshow(action_conf_mat, cmap=plt.cm.RdYlGn)
    ax.set_xticklabels([""]+actions)
    ax.set_yticklabels([""]+actions)

    for idx, i in enumerate(action_dict):
        for idx2, ii in enumerate(action_dict[i]):
            ax.text(idx, idx2, f"{round(float(action_dict[i][ii]),2)}", va='center', ha='center')
    # Rotate the tick labels and set their alignment.
    
    plt.title("Matrik data")
    plt.ylabel("Predicted Action")
    fig.tight_layout()
    plt.show()



forward_argmax_dict, forward_raw_pred_dict, forward_argmax_pct_dict = get_val_data(VALDIR, "maju", PRED_BATCH)
none_argmax_dict, none_raw_pred_dict, none_argmax_pct_dict = get_val_data(VALDIR, "idle", PRED_BATCH)
left_argmax_dict, left_raw_pred_dict, left_argmax_pct_dict = get_val_data(VALDIR, "kiri", PRED_BATCH)
right_argmax_dict, right_raw_pred_dict, right_argmax_pct_dict = get_val_data(VALDIR, "kanan", PRED_BATCH)

make_conf_mat(none_argmax_pct_dict,forward_argmax_pct_dict,left_argmax_pct_dict,  right_argmax_pct_dict)

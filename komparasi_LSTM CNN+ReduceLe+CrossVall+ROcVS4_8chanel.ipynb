# %% [markdown]
# <a href="https://colab.research.google.com/github/wedexyz/eeg-/blob/main/komparasi_LSTM%20CNN%2BReduceLe%2BCrossVall%2BROcVS4_8chanel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.models import Sequential,load_model
#from keras.layers import Dense, Dropout
#from keras.layers import Embedding
from keras.layers import LSTM
#from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Conv2D , MaxPooling2D , Flatten , Dropout , BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping


import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
import pandas as pd
import os
import random
import time
import os

#from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau


from scipy import signal
from scipy.fft import fftshift

# %% [markdown]
# # DATA

# %%
ACTIONS = ["kiri", "maju","idle","kanan"]
#reshape = (-1,16, 60,1)
reshape = (-1,8, 60,1)
reshape2 = (-1,8, 60)
#reshape(-1,28,28,1)

# %%
def create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/data8"):
    training_data = {}
    for action in ACTIONS:
        if action not in training_data:
            training_data[action] = []
        data_dir = os.path.join(starting_dir,action)
        for item in os.listdir(data_dir):
            data = np.load(os.path.join(data_dir, item))
            for item in data:
                training_data[action].append(item)

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)

    for action in ACTIONS:
        np.random.shuffle(training_data[action])  
        training_data[action] = training_data[action][:min(lengths)]

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)
    combined_data = []
    for action in ACTIONS:
        for data in training_data[action]:
            if action == "kiri":
                combined_data.append([data, [1, 0, 0,0]])
            elif action == "maju":
                combined_data.append([data, [0, 1, 0, 0]])
            elif action == "idle":
                combined_data.append([data, [0, 0, 1, 0]])
            elif action == "kanan":
                combined_data.append([data, [0, 0, 0, 1]])

    np.random.shuffle(combined_data)
    print("length:",len(combined_data))
    return combined_data

# %%
print("creating training data")
traindata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/data8")
train_X = []
train_y = []

for X, y in traindata:
    train_X.append(X)
    train_y.append(y)

train_X = np.array(train_X).reshape(reshape)
train2_X = np.array(train_X).reshape(reshape2)

train_y = np.array(train_y)
# Out:
# creating training data
# [250, 250, 250, 250]
# [250, 250, 250, 250]
# length: 1000

# %%
idle = np.load("/content/drive/MyDrive/Colab Notebooks/data8/idle/1608706768.npy")
kanan = np.load("/content/drive/MyDrive/Colab Notebooks/data8/kanan/1608707012.npy")
kiri = np.load("/content/drive/MyDrive/Colab Notebooks/data8/kiri/1608707050.npy")
maju = np.load("/content/drive/MyDrive/Colab Notebooks/data8/maju/1608706976.npy")

kelas1=idle[0][16]
kelas2=maju[0][16]
kelas3=kanan[0][16]
kelas4=kiri[0][16]

kelas1a=idle[175]
kelas2a=maju[175]
kelas3a=kanan[175]
kelas4a=kiri[175]



f1, t1,Sxx= signal.spectrogram(kelas1,fs=60, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd',
                            )
dbs1 = 10*np.log10(Sxx)
f2, t2,Sxx= signal.spectrogram(kelas2,fs=120, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd',
                            )
dbs2 = 10*np.log10(Sxx)
f3, t3,Sxx= signal.spectrogram(kelas3,fs=120, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )
dbs3 = 10*np.log10(Sxx)
f4, t4,Sxx= signal.spectrogram(kelas4,fs=120, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )  
dbs4 = 10*np.log10(Sxx)

# %%
fig, axs = plt.subplots(nrows=4, ncols=4,figsize=(20,10))
axs = axs.flatten()

axs[0].set_title("siggle")
axs[0].plot(kelas1)

axs[1].set_title("global")
axs[1].plot(kelas1a)

axs[2].set_title("Spectogram")
axs[2].pcolormesh(t1, f1,dbs1,  
                  shading='gouraud',
                  cmap='nipy_spectral')

cwt1 = signal.cwt(kelas1,signal.ricker,widths=np.arange(1,50))
cwt2 = signal.cwt(kelas2,signal.ricker,widths=np.arange(1,50))
cwt3 = signal.cwt(kelas3,signal.ricker,widths=np.arange(1,50))
cwt4 = signal.cwt(kelas4,signal.ricker,widths=np.arange(1,50))
axs[3].set_title("wavelet")
axs[3].imshow(cwt1,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt1).max(),vmin=-abs(cwt1).max())

axs[4].plot(kelas2)
axs[5].plot(kelas2a)
axs[6].pcolormesh(t2, f2,dbs2,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[7].imshow(cwt2,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt2).max(),vmin=-abs(cwt2).max())

axs[8].plot(kelas3)
axs[9].plot(kelas3a)
axs[10].pcolormesh(t3, f3,dbs3,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[11].imshow(cwt3,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt3).max(),vmin=-abs(cwt3).max())

axs[12].plot(kelas4)
axs[13].plot(kelas4a)
axs[14].pcolormesh(t4, f4,dbs4,  
                  shading='gouraud',
                  cmap='viridis')
axs[15].imshow(cwt4,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt4).max(),vmin=-abs(cwt4).max())
plt.show()

# %%
import seaborn as sns
ye=pd.DataFrame(train_y)

ye.columns=["kiri", "maju","idle","kanan"]
categories = list(ye.columns.values)
sns.set(font_scale = 1)
plt.figure(figsize=(10,8))
ax= sns.barplot(categories, ye.iloc[:,0:].sum().values)
plt.title("Number of samples labeled as active (1) out of {0} length data".format((ye.shape[0])),fontsize=20)

plt.ylabel('Number of events', fontsize=18)
plt.xlabel('Event Type ', fontsize=12)
#adding the text labels
rects = ax.patches
labels = ye.iloc[:,0:].sum().values

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom', fontsize=10)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # CNN

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1,factor=0.5, min_lr=0.0001)

# %%
#def cnn_model(size, num_cnn_layers):

def cnn_model():    

    model = Sequential()
    
    model.add(Conv2D(filters = 64, kernel_size = (8,8), padding = "same", activation = "relu", input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (4,4)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Conv2D(filters = 64, kernel_size = (4,4), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Conv2D(filters = 64, kernel_size = (2,2), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (1,1)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Flatten())
    
    model.add(Dense(32, activation = "relu"))
    model.add(BatchNormalization())
    
    model.add(Dense(4, activation = "sigmoid"))
   
    #adam = Adam(lr = 0.001)
    model.compile(optimizer ="adam", loss = "binary_crossentropy", metrics = ['accuracy'])
    #model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
 
    
    return model

# %%
#model = cnn_model(IMAGE_SIZE, 2)
model = cnn_model()
model.summary()
# Out:
# Model: "sequential_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_39 (Conv2D)           (None, 8, 60, 64)         4160
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 2, 15, 64)         0
# _________________________________________________________________
# dropout_90 (Dropout)         (None, 2, 15, 64)         0
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 2, 15, 64)         256
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 2, 15, 64)         65600
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 1, 7, 64)          0
# _________________________________________________________________
# dropout_91 (Dropout)         (None, 1, 7, 64)          0
# _________________________________________________________________
# batch_normalization_53 (Batc (None, 1, 7, 64)          256
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 1, 7, 64)          16448
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 1, 7, 64)          0
# _________________________________________________________________
# dropout_92 (Dropout)         (None, 1, 7, 64)          0
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 1, 7, 64)          256
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 448)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 32)                14368
# _________________________________________________________________
# batch_normalization_55 (Batc (None, 32)                128
# _________________________________________________________________
# dense_44 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 101,604
# Trainable params: 101,156
# Non-trainable params: 448
# _________________________________________________________________

# %%
#set early stopping criteria
pat = 5
#this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='loss', patience=pat, verbose=1)

#define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('subjek1CNN.h5', verbose=1, save_best_only=True)

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=100, BATCH_SIZE=32):
    model = None
    #model = cnn_model(IMAGE_SIZE, 2)
    model = cnn_model()
    #Model = model
   # results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[early_stopping, model_checkpoint], 
   #           verbose=1, validation_split=0.1) 
    results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[learning_rate_reduction,early_stopping, model_checkpoint], 
              verbose=1, validation_split=0.1)   
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs=100
batch_size=32

#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(train_X, train_y, test_size=0.2, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
   
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 23/23 [==============================] - 1s 14ms/step - loss: 0.7569 - accuracy: 0.3903 - val_loss: 0.6252 - val_accuracy: 0.6375
#
# Epoch 00001: val_loss improved from inf to 0.62521, saving model to subjek1CNN.h5
# Epoch 2/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5524 - accuracy: 0.6158 - val_loss: 0.5750 - val_accuracy: 0.6625
#
# Epoch 00002: val_loss improved from 0.62521 to 0.57498, saving model to subjek1CNN.h5
# Epoch 3/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4944 - accuracy: 0.6322 - val_loss: 0.4994 - val_accuracy: 0.6250
#
# Epoch 00003: val_loss improved from 0.57498 to 0.49938, saving model to subjek1CNN.h5
# Epoch 4/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4364 - accuracy: 0.6671 - val_loss: 0.4611 - val_accuracy: 0.6750
#
# Epoch 00004: val_loss improved from 0.49938 to 0.46110, saving model to subjek1CNN.h5
# Epoch 5/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4112 - accuracy: 0.6624 - val_loss: 0.4046 - val_accuracy: 0.7625
#
# Epoch 00005: val_loss improved from 0.46110 to 0.40458, saving model to subjek1CNN.h5
# Epoch 6/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3680 - accuracy: 0.7139 - val_loss: 0.3792 - val_accuracy: 0.7375
#
# Epoch 00006: val_loss improved from 0.40458 to 0.37922, saving model to subjek1CNN.h5
# Epoch 7/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3562 - accuracy: 0.7115 - val_loss: 0.3459 - val_accuracy: 0.7250
#
# Epoch 00007: val_loss improved from 0.37922 to 0.34591, saving model to subjek1CNN.h5
# Epoch 8/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3233 - accuracy: 0.7691 - val_loss: 0.3332 - val_accuracy: 0.7375
#
# Epoch 00008: val_loss improved from 0.34591 to 0.33320, saving model to subjek1CNN.h5
# Epoch 9/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3024 - accuracy: 0.7785 - val_loss: 0.3071 - val_accuracy: 0.7625
#
# Epoch 00009: val_loss improved from 0.33320 to 0.30710, saving model to subjek1CNN.h5
# Epoch 10/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2861 - accuracy: 0.7782 - val_loss: 0.2885 - val_accuracy: 0.7875
#
# Epoch 00010: val_loss improved from 0.30710 to 0.28848, saving model to subjek1CNN.h5
# Epoch 11/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2661 - accuracy: 0.8037 - val_loss: 0.2528 - val_accuracy: 0.8125
#
# Epoch 00011: val_loss improved from 0.28848 to 0.25276, saving model to subjek1CNN.h5
# Epoch 12/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2573 - accuracy: 0.8037 - val_loss: 0.2550 - val_accuracy: 0.8000
#
# Epoch 00012: val_loss did not improve from 0.25276
# Epoch 13/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2467 - accuracy: 0.8022 - val_loss: 0.2303 - val_accuracy: 0.8250
#
# Epoch 00013: val_loss improved from 0.25276 to 0.23029, saving model to subjek1CNN.h5
# Epoch 14/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2228 - accuracy: 0.8334 - val_loss: 0.2336 - val_accuracy: 0.8125
#
# Epoch 00014: val_loss did not improve from 0.23029
# Epoch 15/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2195 - accuracy: 0.8224 - val_loss: 0.2305 - val_accuracy: 0.8250
#
# Epoch 00015: val_loss did not improve from 0.23029
# Epoch 16/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2015 - accuracy: 0.8617 - val_loss: 0.2225 - val_accuracy: 0.7750
#
# Epoch 00016: val_loss improved from 0.23029 to 0.22252, saving model to subjek1CNN.h5
# Epoch 17/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1998 - accuracy: 0.8363 - val_loss: 0.2092 - val_accuracy: 0.8125
#
# Epoch 00017: val_loss improved from 0.22252 to 0.20924, saving model to subjek1CNN.h5
# Epoch 18/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1810 - accuracy: 0.8940 - val_loss: 0.2065 - val_accuracy: 0.8000
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00018: val_loss improved from 0.20924 to 0.20649, saving model to subjek1CNN.h5
# Epoch 19/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1876 - accuracy: 0.8507 - val_loss: 0.2059 - val_accuracy: 0.8125
#
# Epoch 00019: val_loss improved from 0.20649 to 0.20591, saving model to subjek1CNN.h5
# Epoch 20/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1677 - accuracy: 0.8914 - val_loss: 0.2057 - val_accuracy: 0.8000
#
# Epoch 00020: val_loss improved from 0.20591 to 0.20572, saving model to subjek1CNN.h5
# Epoch 21/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1543 - accuracy: 0.8967 - val_loss: 0.2091 - val_accuracy: 0.7875
#
# Epoch 00021: val_loss did not improve from 0.20572
# Epoch 22/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1586 - accuracy: 0.8877 - val_loss: 0.1912 - val_accuracy: 0.8125
#
# Epoch 00022: val_loss improved from 0.20572 to 0.19119, saving model to subjek1CNN.h5
# Epoch 23/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1592 - accuracy: 0.8777 - val_loss: 0.1861 - val_accuracy: 0.8000
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00023: val_loss improved from 0.19119 to 0.18607, saving model to subjek1CNN.h5
# Epoch 24/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1521 - accuracy: 0.8795 - val_loss: 0.1846 - val_accuracy: 0.8000
#
# Epoch 00024: val_loss improved from 0.18607 to 0.18461, saving model to subjek1CNN.h5
# Epoch 25/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1474 - accuracy: 0.9044 - val_loss: 0.1725 - val_accuracy: 0.8375
#
# Epoch 00025: val_loss improved from 0.18461 to 0.17246, saving model to subjek1CNN.h5
# Epoch 26/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1372 - accuracy: 0.9215 - val_loss: 0.1671 - val_accuracy: 0.8375
#
# Epoch 00026: val_loss improved from 0.17246 to 0.16708, saving model to subjek1CNN.h5
# Epoch 27/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1427 - accuracy: 0.9016 - val_loss: 0.1602 - val_accuracy: 0.8375
#
# Epoch 00027: val_loss improved from 0.16708 to 0.16024, saving model to subjek1CNN.h5
# Epoch 28/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1429 - accuracy: 0.9059 - val_loss: 0.1587 - val_accuracy: 0.8250
#
# Epoch 00028: val_loss improved from 0.16024 to 0.15868, saving model to subjek1CNN.h5
# Epoch 29/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1398 - accuracy: 0.8910 - val_loss: 0.1569 - val_accuracy: 0.8375
#
# Epoch 00029: val_loss improved from 0.15868 to 0.15691, saving model to subjek1CNN.h5
# Epoch 30/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1469 - accuracy: 0.8991 - val_loss: 0.1481 - val_accuracy: 0.8375
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: val_loss improved from 0.15691 to 0.14815, saving model to subjek1CNN.h5
# Epoch 31/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1411 - accuracy: 0.9135 - val_loss: 0.1525 - val_accuracy: 0.8250
#
# Epoch 00031: val_loss did not improve from 0.14815
# Epoch 32/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1432 - accuracy: 0.8997 - val_loss: 0.1404 - val_accuracy: 0.8625
#
# Epoch 00032: val_loss improved from 0.14815 to 0.14041, saving model to subjek1CNN.h5
# Epoch 33/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1300 - accuracy: 0.9224 - val_loss: 0.1344 - val_accuracy: 0.8625
#
# Epoch 00033: val_loss improved from 0.14041 to 0.13438, saving model to subjek1CNN.h5
# Epoch 34/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1237 - accuracy: 0.9085 - val_loss: 0.1349 - val_accuracy: 0.8625
#
# Epoch 00034: val_loss did not improve from 0.13438
# Epoch 35/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1214 - accuracy: 0.9153 - val_loss: 0.1298 - val_accuracy: 0.8750
#
# Epoch 00035: val_loss improved from 0.13438 to 0.12984, saving model to subjek1CNN.h5
# Epoch 36/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1289 - accuracy: 0.9350 - val_loss: 0.1233 - val_accuracy: 0.9000
#
# Epoch 00036: val_loss improved from 0.12984 to 0.12326, saving model to subjek1CNN.h5
# Epoch 37/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1395 - accuracy: 0.9105 - val_loss: 0.1172 - val_accuracy: 0.9000
#
# Epoch 00037: val_loss improved from 0.12326 to 0.11720, saving model to subjek1CNN.h5
# Epoch 38/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1120 - accuracy: 0.9465 - val_loss: 0.1127 - val_accuracy: 0.9250
#
# Epoch 00038: val_loss improved from 0.11720 to 0.11266, saving model to subjek1CNN.h5
# Epoch 39/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1365 - accuracy: 0.9206 - val_loss: 0.1171 - val_accuracy: 0.9250
#
# Epoch 00039: val_loss did not improve from 0.11266
# Epoch 40/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1238 - accuracy: 0.9166 - val_loss: 0.1205 - val_accuracy: 0.9125
#
# Epoch 00040: val_loss did not improve from 0.11266
# Epoch 41/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1168 - accuracy: 0.9313 - val_loss: 0.1198 - val_accuracy: 0.9000
#
# Epoch 00041: val_loss did not improve from 0.11266
# Epoch 42/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1199 - accuracy: 0.9257 - val_loss: 0.1145 - val_accuracy: 0.9000
#
# Epoch 00042: val_loss did not improve from 0.11266
# Epoch 43/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1357 - accuracy: 0.9079 - val_loss: 0.1145 - val_accuracy: 0.9125
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00043: val_loss did not improve from 0.11266
# Epoch 00043: early stopping
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1209 - accuracy: 0.9000
# Val Score:  [0.12089066207408905, 0.8999999761581421]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
# 23/23 [==============================] - 1s 14ms/step - loss: 0.7729 - accuracy: 0.3976 - val_loss: 0.6192 - val_accuracy: 0.5625
#
# Epoch 00001: val_loss did not improve from 0.11266
# Epoch 2/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5472 - accuracy: 0.6158 - val_loss: 0.5597 - val_accuracy: 0.6250
#
# Epoch 00002: val_loss did not improve from 0.11266
# Epoch 3/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4848 - accuracy: 0.6280 - val_loss: 0.5032 - val_accuracy: 0.6750
#
# Epoch 00003: val_loss did not improve from 0.11266
# Epoch 4/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4181 - accuracy: 0.7064 - val_loss: 0.4743 - val_accuracy: 0.6875
#
# Epoch 00004: val_loss did not improve from 0.11266
# Epoch 5/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4003 - accuracy: 0.6679 - val_loss: 0.4609 - val_accuracy: 0.6125
#
# Epoch 00005: val_loss did not improve from 0.11266
# Epoch 6/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3992 - accuracy: 0.6824 - val_loss: 0.4274 - val_accuracy: 0.7375
#
# Epoch 00006: val_loss did not improve from 0.11266
# Epoch 7/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3675 - accuracy: 0.7106 - val_loss: 0.4042 - val_accuracy: 0.7625
#
# Epoch 00007: val_loss did not improve from 0.11266
# Epoch 8/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3412 - accuracy: 0.7241 - val_loss: 0.3714 - val_accuracy: 0.7500
#
# Epoch 00008: val_loss did not improve from 0.11266
# Epoch 9/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2879 - accuracy: 0.7929 - val_loss: 0.3726 - val_accuracy: 0.7500
#
# Epoch 00009: val_loss did not improve from 0.11266
# Epoch 10/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2882 - accuracy: 0.7713 - val_loss: 0.4369 - val_accuracy: 0.5125
#
# Epoch 00010: val_loss did not improve from 0.11266
# Epoch 11/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2684 - accuracy: 0.8232 - val_loss: 0.3290 - val_accuracy: 0.8375
#
# Epoch 00011: val_loss did not improve from 0.11266
# Epoch 12/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2380 - accuracy: 0.8589 - val_loss: 0.2661 - val_accuracy: 0.8375
#
# Epoch 00012: val_loss did not improve from 0.11266
# Epoch 13/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2453 - accuracy: 0.8264 - val_loss: 0.2813 - val_accuracy: 0.8125
#
# Epoch 00013: val_loss did not improve from 0.11266
# Epoch 14/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2391 - accuracy: 0.8293 - val_loss: 0.2776 - val_accuracy: 0.8000
#
# Epoch 00014: val_loss did not improve from 0.11266
# Epoch 15/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2297 - accuracy: 0.8440 - val_loss: 0.2432 - val_accuracy: 0.8375
#
# Epoch 00015: val_loss did not improve from 0.11266
# Epoch 16/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1922 - accuracy: 0.8769 - val_loss: 0.2432 - val_accuracy: 0.8000
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00016: val_loss did not improve from 0.11266
# Epoch 17/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1769 - accuracy: 0.8913 - val_loss: 0.2356 - val_accuracy: 0.7875
#
# Epoch 00017: val_loss did not improve from 0.11266
# Epoch 18/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1760 - accuracy: 0.8873 - val_loss: 0.2298 - val_accuracy: 0.8125
#
# Epoch 00018: val_loss did not improve from 0.11266
# Epoch 19/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1695 - accuracy: 0.9079 - val_loss: 0.2384 - val_accuracy: 0.8125
#
# Epoch 00019: val_loss did not improve from 0.11266
# Epoch 20/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1813 - accuracy: 0.8799 - val_loss: 0.1944 - val_accuracy: 0.8625
#
# Epoch 00020: val_loss did not improve from 0.11266
# Epoch 21/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1651 - accuracy: 0.8817 - val_loss: 0.1888 - val_accuracy: 0.8375
#
# Epoch 00021: val_loss did not improve from 0.11266
# Epoch 22/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1643 - accuracy: 0.8804 - val_loss: 0.2077 - val_accuracy: 0.8375
#
# Epoch 00022: val_loss did not improve from 0.11266
# Epoch 23/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1539 - accuracy: 0.9182 - val_loss: 0.1884 - val_accuracy: 0.8500
#
# Epoch 00023: val_loss did not improve from 0.11266
# Epoch 24/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1471 - accuracy: 0.8982 - val_loss: 0.1946 - val_accuracy: 0.8500
#
# Epoch 00024: val_loss did not improve from 0.11266
# Epoch 25/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1531 - accuracy: 0.9139 - val_loss: 0.1842 - val_accuracy: 0.8750
#
# Epoch 00025: val_loss did not improve from 0.11266
# Epoch 26/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1471 - accuracy: 0.9017 - val_loss: 0.1811 - val_accuracy: 0.8500
#
# Epoch 00026: val_loss did not improve from 0.11266
# Epoch 27/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1502 - accuracy: 0.9067 - val_loss: 0.1549 - val_accuracy: 0.8875
#
# Epoch 00027: val_loss did not improve from 0.11266
# Epoch 28/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1278 - accuracy: 0.9109 - val_loss: 0.1598 - val_accuracy: 0.8500
#
# Epoch 00028: val_loss did not improve from 0.11266
# Epoch 29/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1461 - accuracy: 0.9048 - val_loss: 0.1595 - val_accuracy: 0.8375
#
# Epoch 00029: val_loss did not improve from 0.11266
# Epoch 30/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1312 - accuracy: 0.9189 - val_loss: 0.1669 - val_accuracy: 0.8500
#
# Epoch 00030: val_loss did not improve from 0.11266
# Epoch 31/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1158 - accuracy: 0.9390 - val_loss: 0.1359 - val_accuracy: 0.9125
#
# Epoch 00031: val_loss did not improve from 0.11266
# Epoch 32/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1426 - accuracy: 0.9147 - val_loss: 0.1390 - val_accuracy: 0.8750
#
# Epoch 00032: val_loss did not improve from 0.11266
# Epoch 33/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1067 - accuracy: 0.9564 - val_loss: 0.1286 - val_accuracy: 0.9125
#
# Epoch 00033: val_loss did not improve from 0.11266
# Epoch 34/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1094 - accuracy: 0.9366 - val_loss: 0.1308 - val_accuracy: 0.8875
#
# Epoch 00034: val_loss did not improve from 0.11266
# Epoch 35/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1124 - accuracy: 0.9346 - val_loss: 0.1191 - val_accuracy: 0.9000
#
# Epoch 00035: val_loss did not improve from 0.11266
# Epoch 36/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1092 - accuracy: 0.9139 - val_loss: 0.1155 - val_accuracy: 0.9000
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00036: val_loss did not improve from 0.11266
# Epoch 37/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1114 - accuracy: 0.9230 - val_loss: 0.1149 - val_accuracy: 0.9000
#
# Epoch 00037: val_loss did not improve from 0.11266
# Epoch 38/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0869 - accuracy: 0.9581 - val_loss: 0.1092 - val_accuracy: 0.9125
#
# Epoch 00038: val_loss improved from 0.11266 to 0.10917, saving model to subjek1CNN.h5
# Epoch 39/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0873 - accuracy: 0.9490 - val_loss: 0.1065 - val_accuracy: 0.9000
#
# Epoch 00039: val_loss improved from 0.10917 to 0.10652, saving model to subjek1CNN.h5
# Epoch 40/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1059 - accuracy: 0.9360 - val_loss: 0.1060 - val_accuracy: 0.9000
#
# Epoch 00040: val_loss improved from 0.10652 to 0.10602, saving model to subjek1CNN.h5
# Epoch 41/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1020 - accuracy: 0.9318 - val_loss: 0.1094 - val_accuracy: 0.9000
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00041: val_loss did not improve from 0.10602
# Epoch 42/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0989 - accuracy: 0.9394 - val_loss: 0.1042 - val_accuracy: 0.9000
#
# Epoch 00042: val_loss improved from 0.10602 to 0.10421, saving model to subjek1CNN.h5
# Epoch 43/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0842 - accuracy: 0.9570 - val_loss: 0.1084 - val_accuracy: 0.9125
#
# Epoch 00043: val_loss did not improve from 0.10421
# Epoch 44/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0891 - accuracy: 0.9456 - val_loss: 0.1033 - val_accuracy: 0.9125
#
# Epoch 00044: val_loss improved from 0.10421 to 0.10328, saving model to subjek1CNN.h5
# Epoch 45/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0827 - accuracy: 0.9468 - val_loss: 0.1014 - val_accuracy: 0.9125
#
# Epoch 00045: val_loss improved from 0.10328 to 0.10139, saving model to subjek1CNN.h5
# Epoch 46/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0746 - accuracy: 0.9685 - val_loss: 0.0972 - val_accuracy: 0.9250
#
# Epoch 00046: val_loss improved from 0.10139 to 0.09717, saving model to subjek1CNN.h5
# Epoch 47/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0852 - accuracy: 0.9464 - val_loss: 0.0964 - val_accuracy: 0.9250
#
# Epoch 00047: val_loss improved from 0.09717 to 0.09639, saving model to subjek1CNN.h5
# Epoch 48/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0902 - accuracy: 0.9442 - val_loss: 0.0981 - val_accuracy: 0.9125
#
# Epoch 00048: val_loss did not improve from 0.09639
# Epoch 49/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0793 - accuracy: 0.9584 - val_loss: 0.0932 - val_accuracy: 0.9125
#
# Epoch 00049: val_loss improved from 0.09639 to 0.09318, saving model to subjek1CNN.h5
# Epoch 50/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0713 - accuracy: 0.9711 - val_loss: 0.0914 - val_accuracy: 0.9125
#
# Epoch 00050: val_loss improved from 0.09318 to 0.09136, saving model to subjek1CNN.h5
# Epoch 51/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0822 - accuracy: 0.9492 - val_loss: 0.0914 - val_accuracy: 0.9125
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00051: val_loss improved from 0.09136 to 0.09136, saving model to subjek1CNN.h5
# Epoch 52/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0835 - accuracy: 0.9510 - val_loss: 0.0928 - val_accuracy: 0.9125
#
# Epoch 00052: val_loss did not improve from 0.09136
# Epoch 53/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0656 - accuracy: 0.9671 - val_loss: 0.0935 - val_accuracy: 0.9125
#
# Epoch 00053: val_loss did not improve from 0.09136
# Epoch 54/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0743 - accuracy: 0.9625 - val_loss: 0.0942 - val_accuracy: 0.9125
#
# Epoch 00054: val_loss did not improve from 0.09136
# Epoch 55/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0693 - accuracy: 0.9797 - val_loss: 0.0967 - val_accuracy: 0.9125
#
# Epoch 00055: val_loss did not improve from 0.09136
# Epoch 56/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0729 - accuracy: 0.9675 - val_loss: 0.0938 - val_accuracy: 0.9125
#
# Epoch 00056: val_loss did not improve from 0.09136
# Epoch 57/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0824 - accuracy: 0.9667 - val_loss: 0.0958 - val_accuracy: 0.9125
#
# Epoch 00057: val_loss did not improve from 0.09136
# Epoch 58/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0787 - accuracy: 0.9624 - val_loss: 0.0919 - val_accuracy: 0.9125
#
# Epoch 00058: val_loss did not improve from 0.09136
# Epoch 59/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0665 - accuracy: 0.9628 - val_loss: 0.0925 - val_accuracy: 0.9250
#
# Epoch 00059: val_loss did not improve from 0.09136
# Epoch 60/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0657 - accuracy: 0.9666 - val_loss: 0.0901 - val_accuracy: 0.9375
#
# Epoch 00060: val_loss improved from 0.09136 to 0.09011, saving model to subjek1CNN.h5
# Epoch 61/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0794 - accuracy: 0.9435 - val_loss: 0.0918 - val_accuracy: 0.9125
#
# Epoch 00061: val_loss did not improve from 0.09011
# Epoch 62/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0771 - accuracy: 0.9604 - val_loss: 0.0871 - val_accuracy: 0.9250
#
# Epoch 00062: val_loss improved from 0.09011 to 0.08707, saving model to subjek1CNN.h5
# Epoch 63/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0734 - accuracy: 0.9679 - val_loss: 0.0886 - val_accuracy: 0.9125
#
# Epoch 00063: val_loss did not improve from 0.08707
# Epoch 64/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0743 - accuracy: 0.9412 - val_loss: 0.0888 - val_accuracy: 0.9125
#
# Epoch 00064: val_loss did not improve from 0.08707
# Epoch 65/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0683 - accuracy: 0.9741 - val_loss: 0.0889 - val_accuracy: 0.9250
#
# Epoch 00065: val_loss did not improve from 0.08707
# Epoch 66/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0835 - accuracy: 0.9477 - val_loss: 0.0889 - val_accuracy: 0.9125
#
# Epoch 00066: val_loss did not improve from 0.08707
# Epoch 67/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0775 - accuracy: 0.9590 - val_loss: 0.0939 - val_accuracy: 0.9125
#
# Epoch 00067: val_loss did not improve from 0.08707
# Epoch 68/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0700 - accuracy: 0.9652 - val_loss: 0.0927 - val_accuracy: 0.9125
#
# Epoch 00068: val_loss did not improve from 0.08707
# Epoch 69/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0662 - accuracy: 0.9624 - val_loss: 0.0847 - val_accuracy: 0.9125
#
# Epoch 00069: val_loss improved from 0.08707 to 0.08473, saving model to subjek1CNN.h5
# Epoch 70/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0707 - accuracy: 0.9710 - val_loss: 0.0825 - val_accuracy: 0.9250
#
# Epoch 00070: val_loss improved from 0.08473 to 0.08252, saving model to subjek1CNN.h5
# Epoch 00070: early stopping
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0625 - accuracy: 0.9550
# Val Score:  [0.06252656131982803, 0.9549999833106995]
# ====================================================================================
#
#
# Training on Fold:  3
# Epoch 1/100
# 23/23 [==============================] - 1s 14ms/step - loss: 0.7952 - accuracy: 0.3543 - val_loss: 0.5973 - val_accuracy: 0.5250
#
# Epoch 00001: val_loss did not improve from 0.08252
# Epoch 2/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5951 - accuracy: 0.5403 - val_loss: 0.5574 - val_accuracy: 0.5250
#
# Epoch 00002: val_loss did not improve from 0.08252
# Epoch 3/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5027 - accuracy: 0.6382 - val_loss: 0.5103 - val_accuracy: 0.6125
#
# Epoch 00003: val_loss did not improve from 0.08252
# Epoch 4/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4423 - accuracy: 0.6538 - val_loss: 0.4614 - val_accuracy: 0.6375
#
# Epoch 00004: val_loss did not improve from 0.08252
# Epoch 5/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4156 - accuracy: 0.7102 - val_loss: 0.4177 - val_accuracy: 0.7125
#
# Epoch 00005: val_loss did not improve from 0.08252
# Epoch 6/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3743 - accuracy: 0.7549 - val_loss: 0.3913 - val_accuracy: 0.7250
#
# Epoch 00006: val_loss did not improve from 0.08252
# Epoch 7/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3586 - accuracy: 0.7098 - val_loss: 0.3621 - val_accuracy: 0.8000
#
# Epoch 00007: val_loss did not improve from 0.08252
# Epoch 8/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3295 - accuracy: 0.7506 - val_loss: 0.3345 - val_accuracy: 0.8250
#
# Epoch 00008: val_loss did not improve from 0.08252
# Epoch 9/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3099 - accuracy: 0.7493 - val_loss: 0.3096 - val_accuracy: 0.8375
#
# Epoch 00009: val_loss did not improve from 0.08252
# Epoch 10/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2872 - accuracy: 0.7865 - val_loss: 0.2766 - val_accuracy: 0.8625
#
# Epoch 00010: val_loss did not improve from 0.08252
# Epoch 11/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2863 - accuracy: 0.7604 - val_loss: 0.2830 - val_accuracy: 0.8625
#
# Epoch 00011: val_loss did not improve from 0.08252
# Epoch 12/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2657 - accuracy: 0.7831 - val_loss: 0.2464 - val_accuracy: 0.8625
#
# Epoch 00012: val_loss did not improve from 0.08252
# Epoch 13/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2422 - accuracy: 0.8091 - val_loss: 0.2428 - val_accuracy: 0.8500
#
# Epoch 00013: val_loss did not improve from 0.08252
# Epoch 14/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2563 - accuracy: 0.7850 - val_loss: 0.2293 - val_accuracy: 0.8625
#
# Epoch 00014: val_loss did not improve from 0.08252
# Epoch 15/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2296 - accuracy: 0.8061 - val_loss: 0.2191 - val_accuracy: 0.8500
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss did not improve from 0.08252
# Epoch 16/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2089 - accuracy: 0.8396 - val_loss: 0.2291 - val_accuracy: 0.8250
#
# Epoch 00016: val_loss did not improve from 0.08252
# Epoch 17/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2148 - accuracy: 0.8376 - val_loss: 0.2240 - val_accuracy: 0.8250
#
# Epoch 00017: val_loss did not improve from 0.08252
# Epoch 18/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1915 - accuracy: 0.8759 - val_loss: 0.2105 - val_accuracy: 0.8375
#
# Epoch 00018: val_loss did not improve from 0.08252
# Epoch 19/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1829 - accuracy: 0.8768 - val_loss: 0.2244 - val_accuracy: 0.7625
#
# Epoch 00019: val_loss did not improve from 0.08252
# Epoch 20/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1940 - accuracy: 0.8741 - val_loss: 0.2183 - val_accuracy: 0.7625
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00020: val_loss did not improve from 0.08252
# Epoch 21/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1936 - accuracy: 0.8772 - val_loss: 0.2000 - val_accuracy: 0.8250
#
# Epoch 00021: val_loss did not improve from 0.08252
# Epoch 22/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1806 - accuracy: 0.8948 - val_loss: 0.2066 - val_accuracy: 0.7750
#
# Epoch 00022: val_loss did not improve from 0.08252
# Epoch 23/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1950 - accuracy: 0.8617 - val_loss: 0.1894 - val_accuracy: 0.8500
#
# Epoch 00023: val_loss did not improve from 0.08252
# Epoch 24/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1789 - accuracy: 0.8638 - val_loss: 0.1811 - val_accuracy: 0.8375
#
# Epoch 00024: val_loss did not improve from 0.08252
# Epoch 25/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1723 - accuracy: 0.8836 - val_loss: 0.1767 - val_accuracy: 0.8375
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00025: val_loss did not improve from 0.08252
# Epoch 26/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1674 - accuracy: 0.8919 - val_loss: 0.1758 - val_accuracy: 0.8500
#
# Epoch 00026: val_loss did not improve from 0.08252
# Epoch 27/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1605 - accuracy: 0.8889 - val_loss: 0.1684 - val_accuracy: 0.8250
#
# Epoch 00027: val_loss did not improve from 0.08252
# Epoch 28/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1698 - accuracy: 0.8890 - val_loss: 0.1635 - val_accuracy: 0.8375
#
# Epoch 00028: val_loss did not improve from 0.08252
# Epoch 29/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1579 - accuracy: 0.8974 - val_loss: 0.1614 - val_accuracy: 0.8500
#
# Epoch 00029: val_loss did not improve from 0.08252
# Epoch 30/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1653 - accuracy: 0.8987 - val_loss: 0.1495 - val_accuracy: 0.8500
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00030: val_loss did not improve from 0.08252
# Epoch 31/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1534 - accuracy: 0.9009 - val_loss: 0.1477 - val_accuracy: 0.8625
#
# Epoch 00031: val_loss did not improve from 0.08252
# Epoch 32/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1803 - accuracy: 0.8665 - val_loss: 0.1397 - val_accuracy: 0.9125
#
# Epoch 00032: val_loss did not improve from 0.08252
# Epoch 33/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1567 - accuracy: 0.8958 - val_loss: 0.1412 - val_accuracy: 0.8875
#
# Epoch 00033: val_loss did not improve from 0.08252
# Epoch 34/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1731 - accuracy: 0.8825 - val_loss: 0.1321 - val_accuracy: 0.9000
#
# Epoch 00034: val_loss did not improve from 0.08252
# Epoch 35/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1601 - accuracy: 0.8950 - val_loss: 0.1327 - val_accuracy: 0.9000
#
# Epoch 00035: val_loss did not improve from 0.08252
# Epoch 36/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1494 - accuracy: 0.9198 - val_loss: 0.1331 - val_accuracy: 0.8875
#
# Epoch 00036: val_loss did not improve from 0.08252
# Epoch 37/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1485 - accuracy: 0.9043 - val_loss: 0.1326 - val_accuracy: 0.9000
#
# Epoch 00037: val_loss did not improve from 0.08252
# Epoch 38/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1624 - accuracy: 0.8728 - val_loss: 0.1310 - val_accuracy: 0.9375
#
# Epoch 00038: val_loss did not improve from 0.08252
# Epoch 39/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1573 - accuracy: 0.8858 - val_loss: 0.1203 - val_accuracy: 0.9500
#
# Epoch 00039: val_loss did not improve from 0.08252
# Epoch 40/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1574 - accuracy: 0.8923 - val_loss: 0.1221 - val_accuracy: 0.9250
#
# Epoch 00040: val_loss did not improve from 0.08252
# Epoch 41/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1493 - accuracy: 0.9082 - val_loss: 0.1221 - val_accuracy: 0.9500
#
# Epoch 00041: val_loss did not improve from 0.08252
# Epoch 42/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1536 - accuracy: 0.9072 - val_loss: 0.1213 - val_accuracy: 0.9625
#
# Epoch 00042: val_loss did not improve from 0.08252
# Epoch 43/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1518 - accuracy: 0.8886 - val_loss: 0.1196 - val_accuracy: 0.9500
#
# Epoch 00043: val_loss did not improve from 0.08252
# Epoch 44/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1412 - accuracy: 0.9164 - val_loss: 0.1193 - val_accuracy: 0.9375
#
# Epoch 00044: val_loss did not improve from 0.08252
# Epoch 45/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1498 - accuracy: 0.9023 - val_loss: 0.1238 - val_accuracy: 0.9250
#
# Epoch 00045: val_loss did not improve from 0.08252
# Epoch 46/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1486 - accuracy: 0.8942 - val_loss: 0.1186 - val_accuracy: 0.9375
#
# Epoch 00046: val_loss did not improve from 0.08252
# Epoch 47/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1470 - accuracy: 0.9029 - val_loss: 0.1249 - val_accuracy: 0.9250
#
# Epoch 00047: val_loss did not improve from 0.08252
# Epoch 48/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1423 - accuracy: 0.9153 - val_loss: 0.1217 - val_accuracy: 0.9250
#
# Epoch 00048: val_loss did not improve from 0.08252
# Epoch 49/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1461 - accuracy: 0.8923 - val_loss: 0.1150 - val_accuracy: 0.9250
#
# Epoch 00049: val_loss did not improve from 0.08252
# Epoch 50/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1355 - accuracy: 0.9113 - val_loss: 0.1158 - val_accuracy: 0.9250
#
# Epoch 00050: val_loss did not improve from 0.08252
# Epoch 51/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1406 - accuracy: 0.9128 - val_loss: 0.1116 - val_accuracy: 0.9500
#
# Epoch 00051: val_loss did not improve from 0.08252
# Epoch 52/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1317 - accuracy: 0.9196 - val_loss: 0.1184 - val_accuracy: 0.9125
#
# Epoch 00052: val_loss did not improve from 0.08252
# Epoch 53/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1439 - accuracy: 0.9050 - val_loss: 0.1111 - val_accuracy: 0.9125
#
# Epoch 00053: val_loss did not improve from 0.08252
# Epoch 54/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1418 - accuracy: 0.9075 - val_loss: 0.1142 - val_accuracy: 0.9125
#
# Epoch 00054: val_loss did not improve from 0.08252
# Epoch 55/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1339 - accuracy: 0.9119 - val_loss: 0.1161 - val_accuracy: 0.9000
#
# Epoch 00055: val_loss did not improve from 0.08252
# Epoch 56/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1516 - accuracy: 0.8609 - val_loss: 0.1197 - val_accuracy: 0.9000
#
# Epoch 00056: val_loss did not improve from 0.08252
# Epoch 57/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1315 - accuracy: 0.9266 - val_loss: 0.1134 - val_accuracy: 0.9125
#
# Epoch 00057: val_loss did not improve from 0.08252
# Epoch 58/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1325 - accuracy: 0.9214 - val_loss: 0.1090 - val_accuracy: 0.9250
#
# Epoch 00058: val_loss did not improve from 0.08252
# Epoch 59/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1336 - accuracy: 0.9169 - val_loss: 0.1173 - val_accuracy: 0.9250
#
# Epoch 00059: val_loss did not improve from 0.08252
# Epoch 60/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1210 - accuracy: 0.9330 - val_loss: 0.1078 - val_accuracy: 0.9625
#
# Epoch 00060: val_loss did not improve from 0.08252
# Epoch 61/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1318 - accuracy: 0.9237 - val_loss: 0.1087 - val_accuracy: 0.9250
#
# Epoch 00061: val_loss did not improve from 0.08252
# Epoch 62/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1319 - accuracy: 0.9161 - val_loss: 0.1039 - val_accuracy: 0.9625
#
# Epoch 00062: val_loss did not improve from 0.08252
# Epoch 63/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1179 - accuracy: 0.9262 - val_loss: 0.1007 - val_accuracy: 0.9625
#
# Epoch 00063: val_loss did not improve from 0.08252
# Epoch 64/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1478 - accuracy: 0.8954 - val_loss: 0.1065 - val_accuracy: 0.9250
#
# Epoch 00064: val_loss did not improve from 0.08252
# Epoch 65/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1233 - accuracy: 0.9227 - val_loss: 0.1093 - val_accuracy: 0.9250
#
# Epoch 00065: val_loss did not improve from 0.08252
# Epoch 66/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1357 - accuracy: 0.9069 - val_loss: 0.1024 - val_accuracy: 0.9625
#
# Epoch 00066: val_loss did not improve from 0.08252
# Epoch 67/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1285 - accuracy: 0.9181 - val_loss: 0.1045 - val_accuracy: 0.9625
#
# Epoch 00067: val_loss did not improve from 0.08252
# Epoch 68/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1241 - accuracy: 0.9156 - val_loss: 0.0983 - val_accuracy: 0.9625
#
# Epoch 00068: val_loss did not improve from 0.08252
# Epoch 69/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1226 - accuracy: 0.9193 - val_loss: 0.1004 - val_accuracy: 0.9375
#
# Epoch 00069: val_loss did not improve from 0.08252
# Epoch 70/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1264 - accuracy: 0.9185 - val_loss: 0.1064 - val_accuracy: 0.9000
#
# Epoch 00070: val_loss did not improve from 0.08252
# Epoch 00070: early stopping
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1123 - accuracy: 0.9150
# Val Score:  [0.11225864291191101, 0.9150000214576721]
# ====================================================================================
#
#
# Training on Fold:  4
# Epoch 1/100
# 23/23 [==============================] - 1s 14ms/step - loss: 0.7503 - accuracy: 0.4073 - val_loss: 0.6407 - val_accuracy: 0.5250
#
# Epoch 00001: val_loss did not improve from 0.08252
# Epoch 2/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5722 - accuracy: 0.6042 - val_loss: 0.5796 - val_accuracy: 0.6000
#
# Epoch 00002: val_loss did not improve from 0.08252
# Epoch 3/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5047 - accuracy: 0.6086 - val_loss: 0.5390 - val_accuracy: 0.6875
#
# Epoch 00003: val_loss did not improve from 0.08252
# Epoch 4/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4322 - accuracy: 0.7139 - val_loss: 0.5100 - val_accuracy: 0.7250
#
# Epoch 00004: val_loss did not improve from 0.08252
# Epoch 5/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4303 - accuracy: 0.6851 - val_loss: 0.4661 - val_accuracy: 0.7750
#
# Epoch 00005: val_loss did not improve from 0.08252
# Epoch 6/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3776 - accuracy: 0.7624 - val_loss: 0.4384 - val_accuracy: 0.8000
#
# Epoch 00006: val_loss did not improve from 0.08252
# Epoch 7/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3531 - accuracy: 0.7462 - val_loss: 0.3892 - val_accuracy: 0.7875
#
# Epoch 00007: val_loss did not improve from 0.08252
# Epoch 8/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3302 - accuracy: 0.7706 - val_loss: 0.3703 - val_accuracy: 0.8125
#
# Epoch 00008: val_loss did not improve from 0.08252
# Epoch 9/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3161 - accuracy: 0.7523 - val_loss: 0.3325 - val_accuracy: 0.7875
#
# Epoch 00009: val_loss did not improve from 0.08252
# Epoch 10/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2976 - accuracy: 0.7335 - val_loss: 0.3208 - val_accuracy: 0.8375
#
# Epoch 00010: val_loss did not improve from 0.08252
# Epoch 11/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2785 - accuracy: 0.7728 - val_loss: 0.3129 - val_accuracy: 0.7750
#
# Epoch 00011: val_loss did not improve from 0.08252
# Epoch 12/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2467 - accuracy: 0.8207 - val_loss: 0.2853 - val_accuracy: 0.7750
#
# Epoch 00012: val_loss did not improve from 0.08252
# Epoch 13/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2425 - accuracy: 0.8172 - val_loss: 0.2943 - val_accuracy: 0.7500
#
# Epoch 00013: val_loss did not improve from 0.08252
# Epoch 14/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2288 - accuracy: 0.8399 - val_loss: 0.2878 - val_accuracy: 0.8000
#
# Epoch 00014: val_loss did not improve from 0.08252
# Epoch 15/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2192 - accuracy: 0.8629 - val_loss: 0.2855 - val_accuracy: 0.7125
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss did not improve from 0.08252
# Epoch 16/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1849 - accuracy: 0.8796 - val_loss: 0.2775 - val_accuracy: 0.7500
#
# Epoch 00016: val_loss did not improve from 0.08252
# Epoch 17/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1857 - accuracy: 0.8753 - val_loss: 0.2767 - val_accuracy: 0.6625
#
# Epoch 00017: val_loss did not improve from 0.08252
# Epoch 18/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1847 - accuracy: 0.8806 - val_loss: 0.2641 - val_accuracy: 0.7125
#
# Epoch 00018: val_loss did not improve from 0.08252
# Epoch 19/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1965 - accuracy: 0.8505 - val_loss: 0.2749 - val_accuracy: 0.7000
#
# Epoch 00019: val_loss did not improve from 0.08252
# Epoch 20/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1611 - accuracy: 0.9091 - val_loss: 0.2649 - val_accuracy: 0.7500
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00020: val_loss did not improve from 0.08252
# Epoch 21/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2000 - accuracy: 0.8588 - val_loss: 0.2553 - val_accuracy: 0.7625
#
# Epoch 00021: val_loss did not improve from 0.08252
# Epoch 22/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1722 - accuracy: 0.8787 - val_loss: 0.2412 - val_accuracy: 0.7750
#
# Epoch 00022: val_loss did not improve from 0.08252
# Epoch 23/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1674 - accuracy: 0.8933 - val_loss: 0.2318 - val_accuracy: 0.8125
#
# Epoch 00023: val_loss did not improve from 0.08252
# Epoch 24/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1723 - accuracy: 0.8842 - val_loss: 0.2222 - val_accuracy: 0.8250
#
# Epoch 00024: val_loss did not improve from 0.08252
# Epoch 25/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1612 - accuracy: 0.9008 - val_loss: 0.2225 - val_accuracy: 0.8000
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00025: val_loss did not improve from 0.08252
# Epoch 26/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1578 - accuracy: 0.9071 - val_loss: 0.2109 - val_accuracy: 0.8250
#
# Epoch 00026: val_loss did not improve from 0.08252
# Epoch 27/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1646 - accuracy: 0.8874 - val_loss: 0.1948 - val_accuracy: 0.8625
#
# Epoch 00027: val_loss did not improve from 0.08252
# Epoch 28/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1672 - accuracy: 0.8796 - val_loss: 0.1929 - val_accuracy: 0.8375
#
# Epoch 00028: val_loss did not improve from 0.08252
# Epoch 29/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1445 - accuracy: 0.9026 - val_loss: 0.1890 - val_accuracy: 0.8625
#
# Epoch 00029: val_loss did not improve from 0.08252
# Epoch 30/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1457 - accuracy: 0.8980 - val_loss: 0.1762 - val_accuracy: 0.8625
#
# Epoch 00030: val_loss did not improve from 0.08252
# Epoch 31/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1426 - accuracy: 0.9094 - val_loss: 0.1694 - val_accuracy: 0.8750
#
# Epoch 00031: val_loss did not improve from 0.08252
# Epoch 32/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1514 - accuracy: 0.8984 - val_loss: 0.1682 - val_accuracy: 0.8750
#
# Epoch 00032: val_loss did not improve from 0.08252
# Epoch 33/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1489 - accuracy: 0.8897 - val_loss: 0.1652 - val_accuracy: 0.8625
#
# Epoch 00033: val_loss did not improve from 0.08252
# Epoch 34/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1548 - accuracy: 0.8725 - val_loss: 0.1632 - val_accuracy: 0.8625
#
# Epoch 00034: val_loss did not improve from 0.08252
# Epoch 00034: early stopping
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1728 - accuracy: 0.8350
# Val Score:  [0.1727808713912964, 0.8349999785423279]
# ====================================================================================
#
#
# Training on Fold:  5
# Epoch 1/100
# 23/23 [==============================] - 1s 15ms/step - loss: 0.7436 - accuracy: 0.4243 - val_loss: 0.6283 - val_accuracy: 0.5250
#
# Epoch 00001: val_loss did not improve from 0.08252
# Epoch 2/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5632 - accuracy: 0.5980 - val_loss: 0.5632 - val_accuracy: 0.6250
#
# Epoch 00002: val_loss did not improve from 0.08252
# Epoch 3/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4727 - accuracy: 0.6880 - val_loss: 0.4940 - val_accuracy: 0.7625
#
# Epoch 00003: val_loss did not improve from 0.08252
# Epoch 4/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4469 - accuracy: 0.6833 - val_loss: 0.4501 - val_accuracy: 0.8000
#
# Epoch 00004: val_loss did not improve from 0.08252
# Epoch 5/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4070 - accuracy: 0.7265 - val_loss: 0.4157 - val_accuracy: 0.7875
#
# Epoch 00005: val_loss did not improve from 0.08252
# Epoch 6/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3738 - accuracy: 0.7332 - val_loss: 0.4165 - val_accuracy: 0.6250
#
# Epoch 00006: val_loss did not improve from 0.08252
# Epoch 7/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3718 - accuracy: 0.7372 - val_loss: 0.3724 - val_accuracy: 0.7625
#
# Epoch 00007: val_loss did not improve from 0.08252
# Epoch 8/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3404 - accuracy: 0.7069 - val_loss: 0.3469 - val_accuracy: 0.8375
#
# Epoch 00008: val_loss did not improve from 0.08252
# Epoch 9/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3232 - accuracy: 0.7514 - val_loss: 0.3021 - val_accuracy: 0.8375
#
# Epoch 00009: val_loss did not improve from 0.08252
# Epoch 10/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3000 - accuracy: 0.7512 - val_loss: 0.2765 - val_accuracy: 0.8375
#
# Epoch 00010: val_loss did not improve from 0.08252
# Epoch 11/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2786 - accuracy: 0.7870 - val_loss: 0.2889 - val_accuracy: 0.8000
#
# Epoch 00011: val_loss did not improve from 0.08252
# Epoch 12/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2622 - accuracy: 0.8088 - val_loss: 0.2556 - val_accuracy: 0.8625
#
# Epoch 00012: val_loss did not improve from 0.08252
# Epoch 13/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2557 - accuracy: 0.7942 - val_loss: 0.2437 - val_accuracy: 0.8625
#
# Epoch 00013: val_loss did not improve from 0.08252
# Epoch 14/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2331 - accuracy: 0.8257 - val_loss: 0.2352 - val_accuracy: 0.8750
#
# Epoch 00014: val_loss did not improve from 0.08252
# Epoch 15/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2230 - accuracy: 0.8488 - val_loss: 0.2482 - val_accuracy: 0.8375
#
# Epoch 00015: val_loss did not improve from 0.08252
# Epoch 16/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2127 - accuracy: 0.8832 - val_loss: 0.2151 - val_accuracy: 0.8625
#
# Epoch 00016: val_loss did not improve from 0.08252
# Epoch 17/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2024 - accuracy: 0.8733 - val_loss: 0.2061 - val_accuracy: 0.8500
#
# Epoch 00017: val_loss did not improve from 0.08252
# Epoch 18/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2025 - accuracy: 0.8567 - val_loss: 0.1997 - val_accuracy: 0.8625
#
# Epoch 00018: val_loss did not improve from 0.08252
# Epoch 19/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1817 - accuracy: 0.8854 - val_loss: 0.1849 - val_accuracy: 0.8750
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_loss did not improve from 0.08252
# Epoch 20/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1668 - accuracy: 0.8967 - val_loss: 0.2198 - val_accuracy: 0.7750
#
# Epoch 00020: val_loss did not improve from 0.08252
# Epoch 21/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1702 - accuracy: 0.8737 - val_loss: 0.1881 - val_accuracy: 0.8625
#
# Epoch 00021: val_loss did not improve from 0.08252
# Epoch 22/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1649 - accuracy: 0.8984 - val_loss: 0.1846 - val_accuracy: 0.8375
#
# Epoch 00022: val_loss did not improve from 0.08252
# Epoch 23/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1537 - accuracy: 0.9114 - val_loss: 0.2207 - val_accuracy: 0.7500
#
# Epoch 00023: val_loss did not improve from 0.08252
# Epoch 24/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1406 - accuracy: 0.9119 - val_loss: 0.1786 - val_accuracy: 0.8500
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00024: val_loss did not improve from 0.08252
# Epoch 25/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1428 - accuracy: 0.9190 - val_loss: 0.1791 - val_accuracy: 0.8375
#
# Epoch 00025: val_loss did not improve from 0.08252
# Epoch 26/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1348 - accuracy: 0.9287 - val_loss: 0.1857 - val_accuracy: 0.8250
#
# Epoch 00026: val_loss did not improve from 0.08252
# Epoch 27/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1416 - accuracy: 0.9022 - val_loss: 0.1756 - val_accuracy: 0.8500
#
# Epoch 00027: val_loss did not improve from 0.08252
# Epoch 28/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1273 - accuracy: 0.9184 - val_loss: 0.1810 - val_accuracy: 0.8375
#
# Epoch 00028: val_loss did not improve from 0.08252
# Epoch 29/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1436 - accuracy: 0.9114 - val_loss: 0.1477 - val_accuracy: 0.8625
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00029: val_loss did not improve from 0.08252
# Epoch 30/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1272 - accuracy: 0.9337 - val_loss: 0.1330 - val_accuracy: 0.8875
#
# Epoch 00030: val_loss did not improve from 0.08252
# Epoch 31/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1405 - accuracy: 0.8967 - val_loss: 0.1310 - val_accuracy: 0.8875
#
# Epoch 00031: val_loss did not improve from 0.08252
# Epoch 32/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1317 - accuracy: 0.9104 - val_loss: 0.1264 - val_accuracy: 0.8875
#
# Epoch 00032: val_loss did not improve from 0.08252
# Epoch 33/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1313 - accuracy: 0.9218 - val_loss: 0.1230 - val_accuracy: 0.9000
#
# Epoch 00033: val_loss did not improve from 0.08252
# Epoch 34/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1314 - accuracy: 0.9130 - val_loss: 0.1132 - val_accuracy: 0.9000
#
# Epoch 00034: val_loss did not improve from 0.08252
# Epoch 35/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1103 - accuracy: 0.9441 - val_loss: 0.1195 - val_accuracy: 0.9125
#
# Epoch 00035: val_loss did not improve from 0.08252
# Epoch 36/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1324 - accuracy: 0.9201 - val_loss: 0.1201 - val_accuracy: 0.9000
#
# Epoch 00036: val_loss did not improve from 0.08252
# Epoch 37/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1183 - accuracy: 0.9338 - val_loss: 0.1174 - val_accuracy: 0.9000
#
# Epoch 00037: val_loss did not improve from 0.08252
# Epoch 38/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1134 - accuracy: 0.9265 - val_loss: 0.1089 - val_accuracy: 0.9000
#
# Epoch 00038: val_loss did not improve from 0.08252
# Epoch 39/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1213 - accuracy: 0.9086 - val_loss: 0.1069 - val_accuracy: 0.9250
#
# Epoch 00039: val_loss did not improve from 0.08252
# Epoch 40/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1086 - accuracy: 0.9448 - val_loss: 0.1081 - val_accuracy: 0.9250
#
# Epoch 00040: val_loss did not improve from 0.08252
# Epoch 41/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1121 - accuracy: 0.9369 - val_loss: 0.0941 - val_accuracy: 0.9625
#
# Epoch 00041: val_loss did not improve from 0.08252
# Epoch 42/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1069 - accuracy: 0.9444 - val_loss: 0.0920 - val_accuracy: 0.9625
#
# Epoch 00042: val_loss did not improve from 0.08252
# Epoch 43/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1073 - accuracy: 0.9362 - val_loss: 0.1020 - val_accuracy: 0.9125
#
# Epoch 00043: val_loss did not improve from 0.08252
# Epoch 44/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1001 - accuracy: 0.9492 - val_loss: 0.0982 - val_accuracy: 0.9500
#
# Epoch 00044: val_loss did not improve from 0.08252
# Epoch 45/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1097 - accuracy: 0.9308 - val_loss: 0.0992 - val_accuracy: 0.9250
#
# Epoch 00045: val_loss did not improve from 0.08252
# Epoch 46/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1280 - accuracy: 0.9130 - val_loss: 0.0938 - val_accuracy: 0.9375
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00046: val_loss did not improve from 0.08252
# Epoch 47/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1144 - accuracy: 0.9323 - val_loss: 0.0881 - val_accuracy: 0.9500
#
# Epoch 00047: val_loss did not improve from 0.08252
# Epoch 48/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1055 - accuracy: 0.9371 - val_loss: 0.0881 - val_accuracy: 0.9625
#
# Epoch 00048: val_loss did not improve from 0.08252
# Epoch 49/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0977 - accuracy: 0.9471 - val_loss: 0.0917 - val_accuracy: 0.9500
#
# Epoch 00049: val_loss did not improve from 0.08252
# Epoch 50/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1129 - accuracy: 0.9317 - val_loss: 0.0807 - val_accuracy: 0.9750
#
# Epoch 00050: val_loss improved from 0.08252 to 0.08070, saving model to subjek1CNN.h5
# Epoch 51/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0983 - accuracy: 0.9494 - val_loss: 0.0791 - val_accuracy: 0.9625
#
# Epoch 00051: val_loss improved from 0.08070 to 0.07909, saving model to subjek1CNN.h5
# Epoch 52/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1129 - accuracy: 0.9205 - val_loss: 0.0907 - val_accuracy: 0.9500
#
# Epoch 00052: val_loss did not improve from 0.07909
# Epoch 53/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1096 - accuracy: 0.9332 - val_loss: 0.0870 - val_accuracy: 0.9500
#
# Epoch 00053: val_loss did not improve from 0.07909
# Epoch 54/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1082 - accuracy: 0.9351 - val_loss: 0.0850 - val_accuracy: 0.9625
#
# Epoch 00054: val_loss did not improve from 0.07909
# Epoch 00054: early stopping
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1004 - accuracy: 0.9300
# Val Score:  [0.10043759644031525, 0.9300000071525574]
# ====================================================================================

# %%
print("data train x",t_x.shape)
print("data train y",t_y.shape)

print("data tes x",val_x.shape)
print("data tes y",val_y.shape)

model = load_model('subjek1CNN.h5')
model.evaluate(val_x, val_y)
# Out:
# data train x (800, 8, 60, 1)
# data train y (800, 4)
# data tes x (200, 8, 60, 1)
# data tes y (200, 4)
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0963 - accuracy: 0.9350
# [0.09625563770532608, 0.9350000023841858]

# %%
fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)
ax1.plot(model_history[0].history['accuracy'], label='Training Fold 1 accuration')
ax1.plot(model_history[1].history['accuracy'], label='Training Fold 2 accuration')
ax1.plot(model_history[2].history['accuracy'], label='Training Fold 3 accuration')
ax1.plot(model_history[3].history['accuracy'], label='Training Fold 4 accuration')
ax1.plot(model_history[4].history['accuracy'], label='Training Fold 5 accuration')
ax1.legend()
ax2.plot(model_history[1].history['loss'], label='Training Fold 1 loss')
ax2.plot(model_history[1].history['loss'], label='Training Fold 2 loss')
ax2.plot(model_history[2].history['loss'], label='Training Fold 3 loss')
ax2.plot(model_history[3].history['loss'], label='Training Fold 4 loss ')
ax2.plot(model_history[4].history['loss'], label='Training Fold 5 loss')
ax2.legend()
plt.show()

# %%
fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt1.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[0].history['loss'], label='Train Loss Fold 1', color='black')
plt2.plot(model_history[0].history['val_loss'], label='Val Loss Fold 1', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red')
plt1.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[1].history['loss'], label='Train Loss Fold 2', color='red')
plt2.plot(model_history[1].history['val_loss'], label='Val Loss Fold 2', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green')
plt1.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[2].history['loss'], label='Train Loss Fold 3', color='green')
plt2.plot(model_history[2].history['val_loss'], label='Val Loss Fold 3', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()


fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue')
plt1.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[3].history['loss'], label='Train Loss Fold 4', color='blue')
plt2.plot(model_history[3].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='purple')
plt1.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[4].history['loss'], label='Train Loss Fold 4', color='purple')
plt2.plot(model_history[4].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

# %%
MODEL_NAME ='/content/subjek1CNN.h5' 

#CLIP = True # if your model was trained with np.clip to clip  values
CLIP = False
CLIP_VAL = 8  # if above, what was the value +/-

model = tf.keras.models.load_model(MODEL_NAME)

VALDIR = '/content/drive/MyDrive/Colab Notebooks/data8'
ACTIONS =  ["idle","maju","kiri", "kanan"]
PRED_BATCH = 32


def get_val_data(valdir, action, batch_size):

   # argmax_dict = {0: 0, 1: 0, 2: 0,3:0}
    argmax_dict = {2: 0, 0: 0, 1: 0,3:0}
    raw_pred_dict = {0: 0, 1: 0, 2: 0,3:0}

    action_dir = os.path.join(valdir, action)
    for session_file in os.listdir(action_dir):
        filepath = os.path.join(action_dir,session_file)
        if CLIP:
            data = np.clip(np.load(filepath), -CLIP_VAL, CLIP_VAL) / CLIP_VAL
            #print(data)
        else:
            data = np.load(filepath) 
        preds = model.predict([data.reshape(-1, 8, 60,1)], batch_size=batch_size)
        
        for pred in preds:
            argmax = np.argmax(pred)
            argmax_dict[argmax] += 1
            for idx,value in enumerate(pred):
                raw_pred_dict[idx] += value
    
    argmax_pct_dict = {}
    for i in argmax_dict:
        total = 0
        correct = argmax_dict[i]
        for ii in argmax_dict:
            total += argmax_dict[ii]
        argmax_pct_dict[i] = round(correct/total, 4)
    return argmax_dict, raw_pred_dict, argmax_pct_dict


def make_conf_mat(none,left,forward, right):
    action_dict = {"idle":none,"maju": forward, "kiri": left, "kanan": right}
    action_conf_mat = pd.DataFrame(action_dict)
    actions = [i for i in action_dict]

    fig = plt.figure(figsize=(15, 6))
    ax = fig.add_subplot(111)
    ax.matshow(action_conf_mat, cmap=plt.cm.RdYlGn)
    ax.set_xticklabels([""]+actions)
    ax.set_yticklabels([""]+actions)

    for idx, i in enumerate(action_dict):
        for idx2, ii in enumerate(action_dict[i]):
            ax.text(idx, idx2, f"{round(float(action_dict[i][ii]),2)}", va='center', ha='center')
    # Rotate the tick labels and set their alignment.
    
    plt.title("Matrik data")
    plt.ylabel("Predicted Action")
    fig.tight_layout()
    plt.show()



forward_argmax_dict, forward_raw_pred_dict, forward_argmax_pct_dict = get_val_data(VALDIR, "maju", PRED_BATCH)
none_argmax_dict, none_raw_pred_dict, none_argmax_pct_dict = get_val_data(VALDIR, "idle", PRED_BATCH)
left_argmax_dict, left_raw_pred_dict, left_argmax_pct_dict = get_val_data(VALDIR, "kiri", PRED_BATCH)
right_argmax_dict, right_raw_pred_dict, right_argmax_pct_dict = get_val_data(VALDIR, "kanan", PRED_BATCH)
make_conf_mat(none_argmax_pct_dict,forward_argmax_pct_dict,left_argmax_pct_dict,  right_argmax_pct_dict)

# %%
x_train,x_test,y_train,y_test=train_test_split(train_X,train_y,test_size=0.2)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (800, 8, 60, 1)
# (200, 8, 60, 1)
# (800, 4)
# (200, 4)

# %%
from sklearn.metrics import roc_curve, auc

#y_score = clf.decision_function(xval)
y_score = model.predict(x_test)

#Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()


# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
    
    
print("roc_auc:",sum(roc_auc.values())/4)
ACTIONS =  ["idle","maju","kiri", "kanan"]
for i in range(0,4):
    plt.figure()
    fig, ax = plt.subplots(figsize=(10,10))
    plt.plot(fpr[i], tpr[i],linewidth=3)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    #plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % ACTIONS[i])
    plt.title('%s -ROC curve (area = %0.2f)' % (ACTIONS[i],roc_auc[i]))
    
    plt.legend(loc="lower right")
    plt.show()
# Out:
# roc_auc: 0.9993444055944056

# %% [markdown]
# # LSTM

# %%
def lstm_model():
  model2 = Sequential()
  model2.add(LSTM(64,input_shape = (train2_X.shape[1:]), return_sequences=True))
  model2.add(Dropout(0.5))
  model2.add(LSTM(64,input_shape = (train2_X.shape[1:]), return_sequences=True))
  model2.add(Dropout(0.5))
  model2.add(LSTM(64,input_shape = (train2_X.shape[1:]), return_sequences=True))
  model2.add(Dropout(0.5))
  model2.add(LSTM(64))
  model2.add(Dense(4, activation='sigmoid'))
  model2.compile(loss='binary_crossentropy', optimizer= Adam(lr = 0.0001), metrics=['accuracy'])
  return model2

# %%
model = lstm_model()
model.summary()
# Out:
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_70 (LSTM)               (None, 8, 64)             32000
# _________________________________________________________________
# dropout_108 (Dropout)        (None, 8, 64)             0
# _________________________________________________________________
# lstm_71 (LSTM)               (None, 8, 64)             33024
# _________________________________________________________________
# dropout_109 (Dropout)        (None, 8, 64)             0
# _________________________________________________________________
# lstm_72 (LSTM)               (None, 8, 64)             33024
# _________________________________________________________________
# dropout_110 (Dropout)        (None, 8, 64)             0
# _________________________________________________________________
# lstm_73 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dense_55 (Dense)             (None, 4)                 260
# =================================================================
# Total params: 131,332
# Trainable params: 131,332
# Non-trainable params: 0
# _________________________________________________________________

# %%
#set early stopping criteria
pat = 5
#this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='loss', patience=pat, verbose=1)

#define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('subjek1LSTM.h5', verbose=1, save_best_only=True)

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=100, BATCH_SIZE=32):
    model = None
    #model = cnn_model(IMAGE_SIZE, 2)
    model = lstm_model()
    #Model = model
   # results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[early_stopping, model_checkpoint], 
   #           verbose=1, validation_split=0.1) 
    results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[learning_rate_reduction,early_stopping, model_checkpoint], 
              verbose=1, validation_split=0.1)   
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs=100
batch_size=32

#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(train2_X, train_y, test_size=0.2, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
   
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 23/23 [==============================] - 6s 58ms/step - loss: 0.6902 - accuracy: 0.2562 - val_loss: 0.6820 - val_accuracy: 0.3000
#
# Epoch 00001: val_loss improved from inf to 0.68204, saving model to subjek1LSTM.h5
# Epoch 2/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6803 - accuracy: 0.2659 - val_loss: 0.6666 - val_accuracy: 0.3000
#
# Epoch 00002: val_loss improved from 0.68204 to 0.66658, saving model to subjek1LSTM.h5
# Epoch 3/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6632 - accuracy: 0.2487 - val_loss: 0.6356 - val_accuracy: 0.3000
#
# Epoch 00003: val_loss improved from 0.66658 to 0.63565, saving model to subjek1LSTM.h5
# Epoch 4/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6314 - accuracy: 0.2515 - val_loss: 0.5815 - val_accuracy: 0.3000
#
# Epoch 00004: val_loss improved from 0.63565 to 0.58150, saving model to subjek1LSTM.h5
# Epoch 5/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5865 - accuracy: 0.2536 - val_loss: 0.5552 - val_accuracy: 0.3000
#
# Epoch 00005: val_loss improved from 0.58150 to 0.55523, saving model to subjek1LSTM.h5
# Epoch 6/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5729 - accuracy: 0.2394 - val_loss: 0.5501 - val_accuracy: 0.3000
#
# Epoch 00006: val_loss improved from 0.55523 to 0.55009, saving model to subjek1LSTM.h5
# Epoch 7/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5654 - accuracy: 0.2771 - val_loss: 0.5451 - val_accuracy: 0.3625
#
# Epoch 00007: val_loss improved from 0.55009 to 0.54508, saving model to subjek1LSTM.h5
# Epoch 8/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5585 - accuracy: 0.3002 - val_loss: 0.5362 - val_accuracy: 0.4000
#
# Epoch 00008: val_loss improved from 0.54508 to 0.53622, saving model to subjek1LSTM.h5
# Epoch 9/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5503 - accuracy: 0.3439 - val_loss: 0.5222 - val_accuracy: 0.4375
#
# Epoch 00009: val_loss improved from 0.53622 to 0.52217, saving model to subjek1LSTM.h5
# Epoch 10/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5378 - accuracy: 0.3817 - val_loss: 0.5017 - val_accuracy: 0.4375
#
# Epoch 00010: val_loss improved from 0.52217 to 0.50166, saving model to subjek1LSTM.h5
# Epoch 11/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5229 - accuracy: 0.3574 - val_loss: 0.4788 - val_accuracy: 0.4750
#
# Epoch 00011: val_loss improved from 0.50166 to 0.47883, saving model to subjek1LSTM.h5
# Epoch 12/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5030 - accuracy: 0.3967 - val_loss: 0.4507 - val_accuracy: 0.5000
#
# Epoch 00012: val_loss improved from 0.47883 to 0.45071, saving model to subjek1LSTM.h5
# Epoch 13/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4837 - accuracy: 0.4450 - val_loss: 0.4322 - val_accuracy: 0.4875
#
# Epoch 00013: val_loss improved from 0.45071 to 0.43217, saving model to subjek1LSTM.h5
# Epoch 14/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4745 - accuracy: 0.4504 - val_loss: 0.4174 - val_accuracy: 0.5000
#
# Epoch 00014: val_loss improved from 0.43217 to 0.41739, saving model to subjek1LSTM.h5
# Epoch 15/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4589 - accuracy: 0.5165 - val_loss: 0.3998 - val_accuracy: 0.6000
#
# Epoch 00015: val_loss improved from 0.41739 to 0.39980, saving model to subjek1LSTM.h5
# Epoch 16/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4476 - accuracy: 0.5822 - val_loss: 0.3823 - val_accuracy: 0.6125
#
# Epoch 00016: val_loss improved from 0.39980 to 0.38231, saving model to subjek1LSTM.h5
# Epoch 17/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4285 - accuracy: 0.6382 - val_loss: 0.3769 - val_accuracy: 0.6375
#
# Epoch 00017: val_loss improved from 0.38231 to 0.37691, saving model to subjek1LSTM.h5
# Epoch 18/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4210 - accuracy: 0.6304 - val_loss: 0.3604 - val_accuracy: 0.6250
#
# Epoch 00018: val_loss improved from 0.37691 to 0.36035, saving model to subjek1LSTM.h5
# Epoch 19/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4207 - accuracy: 0.6000 - val_loss: 0.3465 - val_accuracy: 0.6375
#
# Epoch 00019: val_loss improved from 0.36035 to 0.34653, saving model to subjek1LSTM.h5
# Epoch 20/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.4003 - accuracy: 0.6174 - val_loss: 0.3354 - val_accuracy: 0.6750
#
# Epoch 00020: val_loss improved from 0.34653 to 0.33536, saving model to subjek1LSTM.h5
# Epoch 21/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3949 - accuracy: 0.6056 - val_loss: 0.3291 - val_accuracy: 0.6625
#
# Epoch 00021: val_loss improved from 0.33536 to 0.32910, saving model to subjek1LSTM.h5
# Epoch 22/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3675 - accuracy: 0.6483 - val_loss: 0.3192 - val_accuracy: 0.6875
#
# Epoch 00022: val_loss improved from 0.32910 to 0.31923, saving model to subjek1LSTM.h5
# Epoch 23/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3773 - accuracy: 0.6063 - val_loss: 0.3145 - val_accuracy: 0.7000
#
# Epoch 00023: val_loss improved from 0.31923 to 0.31450, saving model to subjek1LSTM.h5
# Epoch 24/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3599 - accuracy: 0.6384 - val_loss: 0.3085 - val_accuracy: 0.7000
#
# Epoch 00024: val_loss improved from 0.31450 to 0.30853, saving model to subjek1LSTM.h5
# Epoch 25/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3660 - accuracy: 0.6164 - val_loss: 0.3034 - val_accuracy: 0.6750
#
# Epoch 00025: val_loss improved from 0.30853 to 0.30340, saving model to subjek1LSTM.h5
# Epoch 26/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3565 - accuracy: 0.6129 - val_loss: 0.2989 - val_accuracy: 0.7125
#
# Epoch 00026: val_loss improved from 0.30340 to 0.29887, saving model to subjek1LSTM.h5
# Epoch 27/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3530 - accuracy: 0.6076 - val_loss: 0.2940 - val_accuracy: 0.6750
#
# Epoch 00027: val_loss improved from 0.29887 to 0.29398, saving model to subjek1LSTM.h5
# Epoch 28/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3438 - accuracy: 0.6386 - val_loss: 0.2893 - val_accuracy: 0.7125
#
# Epoch 00028: val_loss improved from 0.29398 to 0.28933, saving model to subjek1LSTM.h5
# Epoch 29/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3381 - accuracy: 0.6453 - val_loss: 0.2852 - val_accuracy: 0.7125
#
# Epoch 00029: val_loss improved from 0.28933 to 0.28522, saving model to subjek1LSTM.h5
# Epoch 30/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3381 - accuracy: 0.6293 - val_loss: 0.2819 - val_accuracy: 0.7000
#
# Epoch 00030: val_loss improved from 0.28522 to 0.28194, saving model to subjek1LSTM.h5
# Epoch 31/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3223 - accuracy: 0.6551 - val_loss: 0.2968 - val_accuracy: 0.6875
#
# Epoch 00031: val_loss did not improve from 0.28194
# Epoch 32/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3371 - accuracy: 0.6946 - val_loss: 0.2757 - val_accuracy: 0.7125
#
# Epoch 00032: val_loss improved from 0.28194 to 0.27570, saving model to subjek1LSTM.h5
# Epoch 33/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3196 - accuracy: 0.6625 - val_loss: 0.2717 - val_accuracy: 0.7375
#
# Epoch 00033: val_loss improved from 0.27570 to 0.27172, saving model to subjek1LSTM.h5
# Epoch 34/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3137 - accuracy: 0.6645 - val_loss: 0.2661 - val_accuracy: 0.7125
#
# Epoch 00034: val_loss improved from 0.27172 to 0.26608, saving model to subjek1LSTM.h5
# Epoch 35/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3113 - accuracy: 0.6671 - val_loss: 0.2629 - val_accuracy: 0.7250
#
# Epoch 00035: val_loss improved from 0.26608 to 0.26294, saving model to subjek1LSTM.h5
# Epoch 36/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3177 - accuracy: 0.6754 - val_loss: 0.2643 - val_accuracy: 0.7375
#
# Epoch 00036: val_loss did not improve from 0.26294
# Epoch 37/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3100 - accuracy: 0.6746 - val_loss: 0.2575 - val_accuracy: 0.7375
#
# Epoch 00037: val_loss improved from 0.26294 to 0.25751, saving model to subjek1LSTM.h5
# Epoch 38/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2887 - accuracy: 0.7026 - val_loss: 0.2509 - val_accuracy: 0.7625
#
# Epoch 00038: val_loss improved from 0.25751 to 0.25093, saving model to subjek1LSTM.h5
# Epoch 39/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2880 - accuracy: 0.7072 - val_loss: 0.2500 - val_accuracy: 0.7500
#
# Epoch 00039: val_loss improved from 0.25093 to 0.24999, saving model to subjek1LSTM.h5
# Epoch 40/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2694 - accuracy: 0.7410 - val_loss: 0.2467 - val_accuracy: 0.7375
#
# Epoch 00040: val_loss improved from 0.24999 to 0.24672, saving model to subjek1LSTM.h5
# Epoch 41/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2708 - accuracy: 0.7465 - val_loss: 0.2432 - val_accuracy: 0.7500
#
# Epoch 00041: val_loss improved from 0.24672 to 0.24319, saving model to subjek1LSTM.h5
# Epoch 42/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2773 - accuracy: 0.7164 - val_loss: 0.2413 - val_accuracy: 0.7500
#
# Epoch 00042: val_loss improved from 0.24319 to 0.24134, saving model to subjek1LSTM.h5
# Epoch 43/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2834 - accuracy: 0.6767 - val_loss: 0.2396 - val_accuracy: 0.7500
#
# Epoch 00043: val_loss improved from 0.24134 to 0.23959, saving model to subjek1LSTM.h5
# Epoch 44/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2689 - accuracy: 0.7277 - val_loss: 0.2348 - val_accuracy: 0.7500
#
# Epoch 00044: val_loss improved from 0.23959 to 0.23483, saving model to subjek1LSTM.h5
# Epoch 45/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2691 - accuracy: 0.7666 - val_loss: 0.2313 - val_accuracy: 0.7500
#
# Epoch 00045: val_loss improved from 0.23483 to 0.23126, saving model to subjek1LSTM.h5
# Epoch 46/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2698 - accuracy: 0.7331 - val_loss: 0.2315 - val_accuracy: 0.7500
#
# Epoch 00046: val_loss did not improve from 0.23126
# Epoch 47/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2729 - accuracy: 0.7151 - val_loss: 0.2275 - val_accuracy: 0.7500
#
# Epoch 00047: val_loss improved from 0.23126 to 0.22754, saving model to subjek1LSTM.h5
# Epoch 48/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2738 - accuracy: 0.7196 - val_loss: 0.2335 - val_accuracy: 0.7500
#
# Epoch 00048: val_loss did not improve from 0.22754
# Epoch 49/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2602 - accuracy: 0.7469 - val_loss: 0.2219 - val_accuracy: 0.7625
#
# Epoch 00049: val_loss improved from 0.22754 to 0.22187, saving model to subjek1LSTM.h5
# Epoch 50/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2643 - accuracy: 0.7214 - val_loss: 0.2212 - val_accuracy: 0.7625
#
# Epoch 00050: val_loss improved from 0.22187 to 0.22118, saving model to subjek1LSTM.h5
# Epoch 51/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2745 - accuracy: 0.7184 - val_loss: 0.2212 - val_accuracy: 0.7500
#
# Epoch 00051: val_loss did not improve from 0.22118
# Epoch 52/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2462 - accuracy: 0.7656 - val_loss: 0.2204 - val_accuracy: 0.7500
#
# Epoch 00052: val_loss improved from 0.22118 to 0.22040, saving model to subjek1LSTM.h5
# Epoch 53/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2494 - accuracy: 0.7529 - val_loss: 0.2194 - val_accuracy: 0.7625
#
# Epoch 00053: val_loss improved from 0.22040 to 0.21942, saving model to subjek1LSTM.h5
# Epoch 54/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2541 - accuracy: 0.7510 - val_loss: 0.2166 - val_accuracy: 0.7625
#
# Epoch 00054: val_loss improved from 0.21942 to 0.21661, saving model to subjek1LSTM.h5
# Epoch 55/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2348 - accuracy: 0.7900 - val_loss: 0.2193 - val_accuracy: 0.7375
#
# Epoch 00055: val_loss did not improve from 0.21661
# Epoch 56/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2453 - accuracy: 0.7798 - val_loss: 0.2122 - val_accuracy: 0.7750
#
# Epoch 00056: val_loss improved from 0.21661 to 0.21218, saving model to subjek1LSTM.h5
# Epoch 57/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2541 - accuracy: 0.7288 - val_loss: 0.2112 - val_accuracy: 0.7500
#
# Epoch 00057: val_loss improved from 0.21218 to 0.21121, saving model to subjek1LSTM.h5
# Epoch 58/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2416 - accuracy: 0.7722 - val_loss: 0.2071 - val_accuracy: 0.7625
#
# Epoch 00058: val_loss improved from 0.21121 to 0.20710, saving model to subjek1LSTM.h5
# Epoch 59/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2331 - accuracy: 0.7870 - val_loss: 0.2099 - val_accuracy: 0.7625
#
# Epoch 00059: val_loss did not improve from 0.20710
# Epoch 60/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2157 - accuracy: 0.7979 - val_loss: 0.2057 - val_accuracy: 0.7625
#
# Epoch 00060: val_loss improved from 0.20710 to 0.20572, saving model to subjek1LSTM.h5
# Epoch 61/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.2364 - accuracy: 0.7738 - val_loss: 0.2040 - val_accuracy: 0.7750
#
# Epoch 00061: val_loss improved from 0.20572 to 0.20401, saving model to subjek1LSTM.h5
# Epoch 62/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2369 - accuracy: 0.7604 - val_loss: 0.2010 - val_accuracy: 0.7750
#
# Epoch 00062: val_loss improved from 0.20401 to 0.20099, saving model to subjek1LSTM.h5
# Epoch 63/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2268 - accuracy: 0.7851 - val_loss: 0.2009 - val_accuracy: 0.7625
#
# Epoch 00063: val_loss improved from 0.20099 to 0.20087, saving model to subjek1LSTM.h5
# Epoch 64/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2214 - accuracy: 0.7714 - val_loss: 0.2000 - val_accuracy: 0.7750
#
# Epoch 00064: val_loss improved from 0.20087 to 0.20002, saving model to subjek1LSTM.h5
# Epoch 65/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2225 - accuracy: 0.7932 - val_loss: 0.1971 - val_accuracy: 0.7625
#
# Epoch 00065: val_loss improved from 0.20002 to 0.19715, saving model to subjek1LSTM.h5
# Epoch 66/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2240 - accuracy: 0.7662 - val_loss: 0.1956 - val_accuracy: 0.7625
#
# Epoch 00066: val_loss improved from 0.19715 to 0.19559, saving model to subjek1LSTM.h5
# Epoch 67/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2338 - accuracy: 0.7767 - val_loss: 0.1992 - val_accuracy: 0.7750
#
# Epoch 00067: val_loss did not improve from 0.19559
# Epoch 68/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2306 - accuracy: 0.7774 - val_loss: 0.1969 - val_accuracy: 0.7750
#
# Epoch 00068: val_loss did not improve from 0.19559
# Epoch 69/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2191 - accuracy: 0.7942 - val_loss: 0.1883 - val_accuracy: 0.8125
#
# Epoch 00069: val_loss improved from 0.19559 to 0.18827, saving model to subjek1LSTM.h5
# Epoch 70/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2138 - accuracy: 0.7950 - val_loss: 0.1900 - val_accuracy: 0.8000
#
# Epoch 00070: val_loss did not improve from 0.18827
# Epoch 71/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2232 - accuracy: 0.8147 - val_loss: 0.1870 - val_accuracy: 0.8250
#
# Epoch 00071: val_loss improved from 0.18827 to 0.18700, saving model to subjek1LSTM.h5
# Epoch 72/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2183 - accuracy: 0.7877 - val_loss: 0.1880 - val_accuracy: 0.7750
#
# Epoch 00072: val_loss did not improve from 0.18700
# Epoch 73/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2132 - accuracy: 0.7802 - val_loss: 0.1861 - val_accuracy: 0.7875
#
# Epoch 00073: val_loss improved from 0.18700 to 0.18607, saving model to subjek1LSTM.h5
# Epoch 74/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2085 - accuracy: 0.7915 - val_loss: 0.1820 - val_accuracy: 0.8125
#
# Epoch 00074: val_loss improved from 0.18607 to 0.18204, saving model to subjek1LSTM.h5
# Epoch 75/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2046 - accuracy: 0.8077 - val_loss: 0.1823 - val_accuracy: 0.7875
#
# Epoch 00075: val_loss did not improve from 0.18204
# Epoch 76/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2126 - accuracy: 0.8053 - val_loss: 0.1800 - val_accuracy: 0.7875
#
# Epoch 00076: val_loss improved from 0.18204 to 0.18001, saving model to subjek1LSTM.h5
# Epoch 77/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2134 - accuracy: 0.7980 - val_loss: 0.1767 - val_accuracy: 0.8250
#
# Epoch 00077: val_loss improved from 0.18001 to 0.17670, saving model to subjek1LSTM.h5
# Epoch 78/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1913 - accuracy: 0.8400 - val_loss: 0.1787 - val_accuracy: 0.7875
#
# Epoch 00078: val_loss did not improve from 0.17670
# Epoch 79/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1876 - accuracy: 0.8225 - val_loss: 0.1737 - val_accuracy: 0.8125
#
# Epoch 00079: val_loss improved from 0.17670 to 0.17370, saving model to subjek1LSTM.h5
# Epoch 80/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2013 - accuracy: 0.7928 - val_loss: 0.1728 - val_accuracy: 0.8125
#
# Epoch 00080: val_loss improved from 0.17370 to 0.17280, saving model to subjek1LSTM.h5
# Epoch 81/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1975 - accuracy: 0.8115 - val_loss: 0.1688 - val_accuracy: 0.8375
#
# Epoch 00081: val_loss improved from 0.17280 to 0.16881, saving model to subjek1LSTM.h5
# Epoch 82/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1987 - accuracy: 0.8269 - val_loss: 0.1635 - val_accuracy: 0.8375
#
# Epoch 00082: val_loss improved from 0.16881 to 0.16348, saving model to subjek1LSTM.h5
# Epoch 83/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1961 - accuracy: 0.8388 - val_loss: 0.1655 - val_accuracy: 0.8375
#
# Epoch 00083: val_loss did not improve from 0.16348
# Epoch 84/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2009 - accuracy: 0.8221 - val_loss: 0.1596 - val_accuracy: 0.8375
#
# Epoch 00084: val_loss improved from 0.16348 to 0.15959, saving model to subjek1LSTM.h5
# Epoch 85/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1829 - accuracy: 0.8323 - val_loss: 0.1705 - val_accuracy: 0.8125
#
# Epoch 00085: val_loss did not improve from 0.15959
# Epoch 86/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1993 - accuracy: 0.8081 - val_loss: 0.1572 - val_accuracy: 0.8500
#
# Epoch 00086: val_loss improved from 0.15959 to 0.15719, saving model to subjek1LSTM.h5
# Epoch 87/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1892 - accuracy: 0.8255 - val_loss: 0.1605 - val_accuracy: 0.8250
#
# Epoch 00087: val_loss did not improve from 0.15719
# Epoch 88/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1813 - accuracy: 0.8351 - val_loss: 0.1580 - val_accuracy: 0.8375
#
# Epoch 00088: val_loss did not improve from 0.15719
# Epoch 89/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1903 - accuracy: 0.8286 - val_loss: 0.1520 - val_accuracy: 0.8500
#
# Epoch 00089: val_loss improved from 0.15719 to 0.15197, saving model to subjek1LSTM.h5
# Epoch 90/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1733 - accuracy: 0.8269 - val_loss: 0.1467 - val_accuracy: 0.8375
#
# Epoch 00090: val_loss improved from 0.15197 to 0.14668, saving model to subjek1LSTM.h5
# Epoch 91/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1814 - accuracy: 0.8392 - val_loss: 0.1501 - val_accuracy: 0.8625
#
# Epoch 00091: val_loss did not improve from 0.14668
# Epoch 92/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1729 - accuracy: 0.8565 - val_loss: 0.1433 - val_accuracy: 0.8625
#
# Epoch 00092: val_loss improved from 0.14668 to 0.14326, saving model to subjek1LSTM.h5
# Epoch 93/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1769 - accuracy: 0.8466 - val_loss: 0.1418 - val_accuracy: 0.8750
#
# Epoch 00093: val_loss improved from 0.14326 to 0.14181, saving model to subjek1LSTM.h5
# Epoch 94/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1642 - accuracy: 0.8490 - val_loss: 0.1414 - val_accuracy: 0.8750
#
# Epoch 00094: val_loss improved from 0.14181 to 0.14138, saving model to subjek1LSTM.h5
# Epoch 95/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1799 - accuracy: 0.8555 - val_loss: 0.1412 - val_accuracy: 0.8875
#
# Epoch 00095: val_loss improved from 0.14138 to 0.14117, saving model to subjek1LSTM.h5
# Epoch 96/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1784 - accuracy: 0.8441 - val_loss: 0.1481 - val_accuracy: 0.8125
#
# Epoch 00096: val_loss did not improve from 0.14117
# Epoch 97/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1732 - accuracy: 0.8639 - val_loss: 0.1380 - val_accuracy: 0.8750
#
# Epoch 00097: val_loss improved from 0.14117 to 0.13795, saving model to subjek1LSTM.h5
# Epoch 98/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1586 - accuracy: 0.8647 - val_loss: 0.1383 - val_accuracy: 0.8625
#
# Epoch 00098: val_loss did not improve from 0.13795
# Epoch 99/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1778 - accuracy: 0.8450 - val_loss: 0.1350 - val_accuracy: 0.8750
#
# Epoch 00099: val_loss improved from 0.13795 to 0.13501, saving model to subjek1LSTM.h5
# Epoch 100/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1649 - accuracy: 0.8618 - val_loss: 0.1315 - val_accuracy: 0.8875
#
# Epoch 00100: val_loss improved from 0.13501 to 0.13150, saving model to subjek1LSTM.h5
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1691 - accuracy: 0.8800
# Val Score:  [0.16912242770195007, 0.8799999952316284]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
# 23/23 [==============================] - 6s 68ms/step - loss: 0.6900 - accuracy: 0.2891 - val_loss: 0.6841 - val_accuracy: 0.2250
#
# Epoch 00001: val_loss did not improve from 0.13150
# Epoch 2/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6803 - accuracy: 0.3216 - val_loss: 0.6714 - val_accuracy: 0.1875
#
# Epoch 00002: val_loss did not improve from 0.13150
# Epoch 3/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6650 - accuracy: 0.2667 - val_loss: 0.6455 - val_accuracy: 0.1875
#
# Epoch 00003: val_loss did not improve from 0.13150
# Epoch 4/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.6339 - accuracy: 0.2525 - val_loss: 0.6007 - val_accuracy: 0.1875
#
# Epoch 00004: val_loss did not improve from 0.13150
# Epoch 5/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5863 - accuracy: 0.2654 - val_loss: 0.5775 - val_accuracy: 0.1875
#
# Epoch 00005: val_loss did not improve from 0.13150
# Epoch 6/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5690 - accuracy: 0.2594 - val_loss: 0.5659 - val_accuracy: 0.1875
#
# Epoch 00006: val_loss did not improve from 0.13150
# Epoch 7/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5576 - accuracy: 0.2578 - val_loss: 0.5592 - val_accuracy: 0.1875
#
# Epoch 00007: val_loss did not improve from 0.13150
# Epoch 8/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5513 - accuracy: 0.2773 - val_loss: 0.5528 - val_accuracy: 0.1875
#
# Epoch 00008: val_loss did not improve from 0.13150
# Epoch 9/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5486 - accuracy: 0.2643 - val_loss: 0.5432 - val_accuracy: 0.2375
#
# Epoch 00009: val_loss did not improve from 0.13150
# Epoch 10/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5309 - accuracy: 0.3458 - val_loss: 0.5319 - val_accuracy: 0.2750
#
# Epoch 00010: val_loss did not improve from 0.13150
# Epoch 11/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5201 - accuracy: 0.4050 - val_loss: 0.5135 - val_accuracy: 0.4875
#
# Epoch 00011: val_loss did not improve from 0.13150
# Epoch 12/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5046 - accuracy: 0.5130 - val_loss: 0.4916 - val_accuracy: 0.5375
#
# Epoch 00012: val_loss did not improve from 0.13150
# Epoch 13/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4824 - accuracy: 0.5893 - val_loss: 0.4654 - val_accuracy: 0.5500
#
# Epoch 00013: val_loss did not improve from 0.13150
# Epoch 14/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4583 - accuracy: 0.5703 - val_loss: 0.4451 - val_accuracy: 0.5625
#
# Epoch 00014: val_loss did not improve from 0.13150
# Epoch 15/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4376 - accuracy: 0.6002 - val_loss: 0.4375 - val_accuracy: 0.5625
#
# Epoch 00015: val_loss did not improve from 0.13150
# Epoch 16/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4266 - accuracy: 0.5781 - val_loss: 0.4118 - val_accuracy: 0.5375
#
# Epoch 00016: val_loss did not improve from 0.13150
# Epoch 17/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4113 - accuracy: 0.5873 - val_loss: 0.4076 - val_accuracy: 0.5500
#
# Epoch 00017: val_loss did not improve from 0.13150
# Epoch 18/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4105 - accuracy: 0.5544 - val_loss: 0.3919 - val_accuracy: 0.5250
#
# Epoch 00018: val_loss did not improve from 0.13150
# Epoch 19/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4055 - accuracy: 0.5823 - val_loss: 0.3844 - val_accuracy: 0.5375
#
# Epoch 00019: val_loss did not improve from 0.13150
# Epoch 20/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3868 - accuracy: 0.6370 - val_loss: 0.3758 - val_accuracy: 0.5500
#
# Epoch 00020: val_loss did not improve from 0.13150
# Epoch 21/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3770 - accuracy: 0.6269 - val_loss: 0.3664 - val_accuracy: 0.5375
#
# Epoch 00021: val_loss did not improve from 0.13150
# Epoch 22/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3617 - accuracy: 0.6199 - val_loss: 0.3633 - val_accuracy: 0.5625
#
# Epoch 00022: val_loss did not improve from 0.13150
# Epoch 23/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3578 - accuracy: 0.6510 - val_loss: 0.3533 - val_accuracy: 0.6000
#
# Epoch 00023: val_loss did not improve from 0.13150
# Epoch 24/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3646 - accuracy: 0.6469 - val_loss: 0.3587 - val_accuracy: 0.5625
#
# Epoch 00024: val_loss did not improve from 0.13150
# Epoch 25/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3695 - accuracy: 0.6198 - val_loss: 0.3446 - val_accuracy: 0.5625
#
# Epoch 00025: val_loss did not improve from 0.13150
# Epoch 26/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3441 - accuracy: 0.6594 - val_loss: 0.3359 - val_accuracy: 0.5875
#
# Epoch 00026: val_loss did not improve from 0.13150
# Epoch 27/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3455 - accuracy: 0.6564 - val_loss: 0.3459 - val_accuracy: 0.5750
#
# Epoch 00027: val_loss did not improve from 0.13150
# Epoch 28/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3408 - accuracy: 0.6323 - val_loss: 0.3207 - val_accuracy: 0.6250
#
# Epoch 00028: val_loss did not improve from 0.13150
# Epoch 29/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3254 - accuracy: 0.6664 - val_loss: 0.3155 - val_accuracy: 0.6125
#
# Epoch 00029: val_loss did not improve from 0.13150
# Epoch 30/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3338 - accuracy: 0.6565 - val_loss: 0.3106 - val_accuracy: 0.6125
#
# Epoch 00030: val_loss did not improve from 0.13150
# Epoch 31/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3181 - accuracy: 0.6485 - val_loss: 0.3120 - val_accuracy: 0.5875
#
# Epoch 00031: val_loss did not improve from 0.13150
# Epoch 32/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3195 - accuracy: 0.6709 - val_loss: 0.3036 - val_accuracy: 0.6000
#
# Epoch 00032: val_loss did not improve from 0.13150
# Epoch 33/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3160 - accuracy: 0.6587 - val_loss: 0.3020 - val_accuracy: 0.6250
#
# Epoch 00033: val_loss did not improve from 0.13150
# Epoch 34/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3167 - accuracy: 0.6897 - val_loss: 0.2954 - val_accuracy: 0.6125
#
# Epoch 00034: val_loss did not improve from 0.13150
# Epoch 35/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3002 - accuracy: 0.6704 - val_loss: 0.2937 - val_accuracy: 0.6375
#
# Epoch 00035: val_loss did not improve from 0.13150
# Epoch 36/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3106 - accuracy: 0.6931 - val_loss: 0.2865 - val_accuracy: 0.7000
#
# Epoch 00036: val_loss did not improve from 0.13150
# Epoch 37/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2953 - accuracy: 0.7060 - val_loss: 0.2843 - val_accuracy: 0.6750
#
# Epoch 00037: val_loss did not improve from 0.13150
# Epoch 38/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2951 - accuracy: 0.6825 - val_loss: 0.2850 - val_accuracy: 0.6625
#
# Epoch 00038: val_loss did not improve from 0.13150
# Epoch 39/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2705 - accuracy: 0.7166 - val_loss: 0.2790 - val_accuracy: 0.6625
#
# Epoch 00039: val_loss did not improve from 0.13150
# Epoch 40/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.2826 - accuracy: 0.7345 - val_loss: 0.2752 - val_accuracy: 0.6875
#
# Epoch 00040: val_loss did not improve from 0.13150
# Epoch 41/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2790 - accuracy: 0.7272 - val_loss: 0.2775 - val_accuracy: 0.6625
#
# Epoch 00041: val_loss did not improve from 0.13150
# Epoch 42/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2828 - accuracy: 0.7137 - val_loss: 0.2755 - val_accuracy: 0.6500
#
# Epoch 00042: val_loss did not improve from 0.13150
# Epoch 43/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2590 - accuracy: 0.7667 - val_loss: 0.2699 - val_accuracy: 0.6875
#
# Epoch 00043: val_loss did not improve from 0.13150
# Epoch 44/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2735 - accuracy: 0.7007 - val_loss: 0.2649 - val_accuracy: 0.7000
#
# Epoch 00044: val_loss did not improve from 0.13150
# Epoch 45/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2525 - accuracy: 0.7562 - val_loss: 0.2661 - val_accuracy: 0.6500
#
# Epoch 00045: val_loss did not improve from 0.13150
# Epoch 46/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2545 - accuracy: 0.7352 - val_loss: 0.2607 - val_accuracy: 0.6875
#
# Epoch 00046: val_loss did not improve from 0.13150
# Epoch 47/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2432 - accuracy: 0.7671 - val_loss: 0.2590 - val_accuracy: 0.6750
#
# Epoch 00047: val_loss did not improve from 0.13150
# Epoch 48/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2439 - accuracy: 0.7201 - val_loss: 0.2506 - val_accuracy: 0.7375
#
# Epoch 00048: val_loss did not improve from 0.13150
# Epoch 49/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2555 - accuracy: 0.7466 - val_loss: 0.2564 - val_accuracy: 0.6875
#
# Epoch 00049: val_loss did not improve from 0.13150
# Epoch 50/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2460 - accuracy: 0.7352 - val_loss: 0.2518 - val_accuracy: 0.7000
#
# Epoch 00050: val_loss did not improve from 0.13150
# Epoch 51/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2494 - accuracy: 0.7676 - val_loss: 0.2477 - val_accuracy: 0.7000
#
# Epoch 00051: val_loss did not improve from 0.13150
# Epoch 52/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2546 - accuracy: 0.7429 - val_loss: 0.2529 - val_accuracy: 0.7125
#
# Epoch 00052: val_loss did not improve from 0.13150
# Epoch 53/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2366 - accuracy: 0.7646 - val_loss: 0.2524 - val_accuracy: 0.6750
#
# Epoch 00053: val_loss did not improve from 0.13150
# Epoch 54/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2480 - accuracy: 0.7691 - val_loss: 0.2413 - val_accuracy: 0.7000
#
# Epoch 00054: val_loss did not improve from 0.13150
# Epoch 55/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2480 - accuracy: 0.7367 - val_loss: 0.2454 - val_accuracy: 0.7000
#
# Epoch 00055: val_loss did not improve from 0.13150
# Epoch 56/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2330 - accuracy: 0.7498 - val_loss: 0.2354 - val_accuracy: 0.7125
#
# Epoch 00056: val_loss did not improve from 0.13150
# Epoch 57/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2332 - accuracy: 0.7616 - val_loss: 0.2434 - val_accuracy: 0.7000
#
# Epoch 00057: val_loss did not improve from 0.13150
# Epoch 58/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2441 - accuracy: 0.7666 - val_loss: 0.2316 - val_accuracy: 0.7125
#
# Epoch 00058: val_loss did not improve from 0.13150
# Epoch 59/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2216 - accuracy: 0.7632 - val_loss: 0.2312 - val_accuracy: 0.7250
#
# Epoch 00059: val_loss did not improve from 0.13150
# Epoch 60/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2278 - accuracy: 0.7768 - val_loss: 0.2355 - val_accuracy: 0.7250
#
# Epoch 00060: val_loss did not improve from 0.13150
# Epoch 61/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2212 - accuracy: 0.7760 - val_loss: 0.2283 - val_accuracy: 0.7250
#
# Epoch 00061: val_loss did not improve from 0.13150
# Epoch 62/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2198 - accuracy: 0.7764 - val_loss: 0.2302 - val_accuracy: 0.7000
#
# Epoch 00062: val_loss did not improve from 0.13150
# Epoch 63/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2119 - accuracy: 0.8037 - val_loss: 0.2267 - val_accuracy: 0.7375
#
# Epoch 00063: val_loss did not improve from 0.13150
# Epoch 64/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2149 - accuracy: 0.7948 - val_loss: 0.2206 - val_accuracy: 0.7125
#
# Epoch 00064: val_loss did not improve from 0.13150
# Epoch 65/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2096 - accuracy: 0.8038 - val_loss: 0.2202 - val_accuracy: 0.7375
#
# Epoch 00065: val_loss did not improve from 0.13150
# Epoch 66/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2118 - accuracy: 0.7821 - val_loss: 0.2203 - val_accuracy: 0.7625
#
# Epoch 00066: val_loss did not improve from 0.13150
# Epoch 67/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2140 - accuracy: 0.8081 - val_loss: 0.2143 - val_accuracy: 0.7500
#
# Epoch 00067: val_loss did not improve from 0.13150
# Epoch 68/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2163 - accuracy: 0.7905 - val_loss: 0.2134 - val_accuracy: 0.7625
#
# Epoch 00068: val_loss did not improve from 0.13150
# Epoch 69/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2051 - accuracy: 0.8111 - val_loss: 0.2185 - val_accuracy: 0.7625
#
# Epoch 00069: val_loss did not improve from 0.13150
# Epoch 70/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2129 - accuracy: 0.7740 - val_loss: 0.2091 - val_accuracy: 0.7750
#
# Epoch 00070: val_loss did not improve from 0.13150
# Epoch 71/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2039 - accuracy: 0.8003 - val_loss: 0.2110 - val_accuracy: 0.7750
#
# Epoch 00071: val_loss did not improve from 0.13150
# Epoch 72/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2009 - accuracy: 0.7961 - val_loss: 0.2132 - val_accuracy: 0.7750
#
# Epoch 00072: val_loss did not improve from 0.13150
# Epoch 73/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2141 - accuracy: 0.8008 - val_loss: 0.2040 - val_accuracy: 0.8000
#
# Epoch 00073: val_loss did not improve from 0.13150
# Epoch 74/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2088 - accuracy: 0.7919 - val_loss: 0.2100 - val_accuracy: 0.7875
#
# Epoch 00074: val_loss did not improve from 0.13150
# Epoch 75/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2008 - accuracy: 0.8216 - val_loss: 0.2055 - val_accuracy: 0.8000
#
# Epoch 00075: val_loss did not improve from 0.13150
# Epoch 76/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2064 - accuracy: 0.7930 - val_loss: 0.2060 - val_accuracy: 0.8000
#
# Epoch 00076: val_loss did not improve from 0.13150
# Epoch 77/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1760 - accuracy: 0.8480 - val_loss: 0.2084 - val_accuracy: 0.7500
#
# Epoch 00077: val_loss did not improve from 0.13150
# Epoch 78/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1955 - accuracy: 0.8120 - val_loss: 0.1960 - val_accuracy: 0.8000
#
# Epoch 00078: val_loss did not improve from 0.13150
# Epoch 79/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2020 - accuracy: 0.7913 - val_loss: 0.1971 - val_accuracy: 0.8125
#
# Epoch 00079: val_loss did not improve from 0.13150
# Epoch 80/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.1865 - accuracy: 0.8177 - val_loss: 0.1970 - val_accuracy: 0.7875
#
# Epoch 00080: val_loss did not improve from 0.13150
# Epoch 81/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1926 - accuracy: 0.8133 - val_loss: 0.1906 - val_accuracy: 0.8375
#
# Epoch 00081: val_loss did not improve from 0.13150
# Epoch 82/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1925 - accuracy: 0.8015 - val_loss: 0.1927 - val_accuracy: 0.8125
#
# Epoch 00082: val_loss did not improve from 0.13150
# Epoch 83/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1765 - accuracy: 0.8324 - val_loss: 0.1905 - val_accuracy: 0.8250
#
# Epoch 00083: val_loss did not improve from 0.13150
# Epoch 84/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1753 - accuracy: 0.8467 - val_loss: 0.1853 - val_accuracy: 0.8375
#
# Epoch 00084: val_loss did not improve from 0.13150
# Epoch 85/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1911 - accuracy: 0.8265 - val_loss: 0.1848 - val_accuracy: 0.8375
#
# Epoch 00085: val_loss did not improve from 0.13150
# Epoch 86/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1772 - accuracy: 0.8340 - val_loss: 0.1854 - val_accuracy: 0.8375
#
# Epoch 00086: val_loss did not improve from 0.13150
# Epoch 87/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1875 - accuracy: 0.8174 - val_loss: 0.1815 - val_accuracy: 0.8625
#
# Epoch 00087: val_loss did not improve from 0.13150
# Epoch 88/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1752 - accuracy: 0.8481 - val_loss: 0.1817 - val_accuracy: 0.8500
#
# Epoch 00088: val_loss did not improve from 0.13150
# Epoch 89/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1779 - accuracy: 0.8479 - val_loss: 0.1789 - val_accuracy: 0.8500
#
# Epoch 00089: val_loss did not improve from 0.13150
# Epoch 90/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1711 - accuracy: 0.8603 - val_loss: 0.1770 - val_accuracy: 0.8625
#
# Epoch 00090: val_loss did not improve from 0.13150
# Epoch 91/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1891 - accuracy: 0.8270 - val_loss: 0.1686 - val_accuracy: 0.8625
#
# Epoch 00091: val_loss did not improve from 0.13150
# Epoch 92/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1774 - accuracy: 0.8431 - val_loss: 0.1753 - val_accuracy: 0.8375
#
# Epoch 00092: val_loss did not improve from 0.13150
# Epoch 93/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1734 - accuracy: 0.8524 - val_loss: 0.1686 - val_accuracy: 0.8750
#
# Epoch 00093: val_loss did not improve from 0.13150
# Epoch 94/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1891 - accuracy: 0.8138 - val_loss: 0.1640 - val_accuracy: 0.8625
#
# Epoch 00094: val_loss did not improve from 0.13150
# Epoch 95/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1609 - accuracy: 0.8607 - val_loss: 0.1642 - val_accuracy: 0.8750
#
# Epoch 00095: val_loss did not improve from 0.13150
# Epoch 96/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1579 - accuracy: 0.8800 - val_loss: 0.1586 - val_accuracy: 0.8750
#
# Epoch 00096: val_loss did not improve from 0.13150
# Epoch 97/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1769 - accuracy: 0.8314 - val_loss: 0.1564 - val_accuracy: 0.8875
#
# Epoch 00097: val_loss did not improve from 0.13150
# Epoch 98/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1663 - accuracy: 0.8566 - val_loss: 0.1572 - val_accuracy: 0.8750
#
# Epoch 00098: val_loss did not improve from 0.13150
# Epoch 99/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1562 - accuracy: 0.8933 - val_loss: 0.1520 - val_accuracy: 0.8750
#
# Epoch 00099: val_loss did not improve from 0.13150
# Epoch 100/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1708 - accuracy: 0.8534 - val_loss: 0.1586 - val_accuracy: 0.8875
#
# Epoch 00100: val_loss did not improve from 0.13150
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1774 - accuracy: 0.8950
# Val Score:  [0.17743530869483948, 0.8949999809265137]
# ====================================================================================
#
#
# Training on Fold:  3
# Epoch 1/100
# 23/23 [==============================] - 6s 60ms/step - loss: 0.6906 - accuracy: 0.2645 - val_loss: 0.6825 - val_accuracy: 0.2750
#
# Epoch 00001: val_loss did not improve from 0.13150
# Epoch 2/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.6802 - accuracy: 0.3028 - val_loss: 0.6676 - val_accuracy: 0.3125
#
# Epoch 00002: val_loss did not improve from 0.13150
# Epoch 3/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.6629 - accuracy: 0.2626 - val_loss: 0.6363 - val_accuracy: 0.3375
#
# Epoch 00003: val_loss did not improve from 0.13150
# Epoch 4/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.6278 - accuracy: 0.2653 - val_loss: 0.5818 - val_accuracy: 0.3125
#
# Epoch 00004: val_loss did not improve from 0.13150
# Epoch 5/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5831 - accuracy: 0.2374 - val_loss: 0.5622 - val_accuracy: 0.3750
#
# Epoch 00005: val_loss did not improve from 0.13150
# Epoch 6/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5659 - accuracy: 0.2928 - val_loss: 0.5552 - val_accuracy: 0.2375
#
# Epoch 00006: val_loss did not improve from 0.13150
# Epoch 7/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5624 - accuracy: 0.2769 - val_loss: 0.5507 - val_accuracy: 0.2375
#
# Epoch 00007: val_loss did not improve from 0.13150
# Epoch 8/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5541 - accuracy: 0.3027 - val_loss: 0.5462 - val_accuracy: 0.2375
#
# Epoch 00008: val_loss did not improve from 0.13150
# Epoch 9/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5553 - accuracy: 0.2726 - val_loss: 0.5398 - val_accuracy: 0.2500
#
# Epoch 00009: val_loss did not improve from 0.13150
# Epoch 10/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5437 - accuracy: 0.2956 - val_loss: 0.5322 - val_accuracy: 0.2750
#
# Epoch 00010: val_loss did not improve from 0.13150
# Epoch 11/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5358 - accuracy: 0.3463 - val_loss: 0.5212 - val_accuracy: 0.3750
#
# Epoch 00011: val_loss did not improve from 0.13150
# Epoch 12/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5252 - accuracy: 0.3659 - val_loss: 0.5088 - val_accuracy: 0.4875
#
# Epoch 00012: val_loss did not improve from 0.13150
# Epoch 13/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5130 - accuracy: 0.4977 - val_loss: 0.4926 - val_accuracy: 0.5125
#
# Epoch 00013: val_loss did not improve from 0.13150
# Epoch 14/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4986 - accuracy: 0.5516 - val_loss: 0.4740 - val_accuracy: 0.5250
#
# Epoch 00014: val_loss did not improve from 0.13150
# Epoch 15/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4837 - accuracy: 0.5357 - val_loss: 0.4548 - val_accuracy: 0.5750
#
# Epoch 00015: val_loss did not improve from 0.13150
# Epoch 16/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4547 - accuracy: 0.5727 - val_loss: 0.4391 - val_accuracy: 0.5625
#
# Epoch 00016: val_loss did not improve from 0.13150
# Epoch 17/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4309 - accuracy: 0.6101 - val_loss: 0.4322 - val_accuracy: 0.5750
#
# Epoch 00017: val_loss did not improve from 0.13150
# Epoch 18/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4359 - accuracy: 0.5890 - val_loss: 0.4181 - val_accuracy: 0.6000
#
# Epoch 00018: val_loss did not improve from 0.13150
# Epoch 19/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4195 - accuracy: 0.5790 - val_loss: 0.4108 - val_accuracy: 0.5875
#
# Epoch 00019: val_loss did not improve from 0.13150
# Epoch 20/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3924 - accuracy: 0.6469 - val_loss: 0.4024 - val_accuracy: 0.5875
#
# Epoch 00020: val_loss did not improve from 0.13150
# Epoch 21/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3856 - accuracy: 0.6273 - val_loss: 0.3943 - val_accuracy: 0.5750
#
# Epoch 00021: val_loss did not improve from 0.13150
# Epoch 22/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3754 - accuracy: 0.6390 - val_loss: 0.3831 - val_accuracy: 0.5750
#
# Epoch 00022: val_loss did not improve from 0.13150
# Epoch 23/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3646 - accuracy: 0.6483 - val_loss: 0.3741 - val_accuracy: 0.5750
#
# Epoch 00023: val_loss did not improve from 0.13150
# Epoch 24/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3655 - accuracy: 0.6417 - val_loss: 0.3768 - val_accuracy: 0.6250
#
# Epoch 00024: val_loss did not improve from 0.13150
# Epoch 25/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3570 - accuracy: 0.6568 - val_loss: 0.3612 - val_accuracy: 0.5750
#
# Epoch 00025: val_loss did not improve from 0.13150
# Epoch 26/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3463 - accuracy: 0.6546 - val_loss: 0.3534 - val_accuracy: 0.6000
#
# Epoch 00026: val_loss did not improve from 0.13150
# Epoch 27/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3284 - accuracy: 0.7037 - val_loss: 0.3530 - val_accuracy: 0.6125
#
# Epoch 00027: val_loss did not improve from 0.13150
# Epoch 28/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3305 - accuracy: 0.6985 - val_loss: 0.3444 - val_accuracy: 0.6250
#
# Epoch 00028: val_loss did not improve from 0.13150
# Epoch 29/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3306 - accuracy: 0.6806 - val_loss: 0.3332 - val_accuracy: 0.6750
#
# ...
#
# Epoch 00020: val_loss did not improve from 0.09381
# Epoch 21/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3995 - accuracy: 0.6204 - val_loss: 0.3280 - val_accuracy: 0.6750
#
# Epoch 00021: val_loss did not improve from 0.09381
# Epoch 22/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3904 - accuracy: 0.6159 - val_loss: 0.3189 - val_accuracy: 0.6875
#
# Epoch 00022: val_loss did not improve from 0.09381
# Epoch 23/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3827 - accuracy: 0.6282 - val_loss: 0.3077 - val_accuracy: 0.6875
#
# Epoch 00023: val_loss did not improve from 0.09381
# Epoch 24/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3743 - accuracy: 0.6340 - val_loss: 0.3029 - val_accuracy: 0.7125
#
# Epoch 00024: val_loss did not improve from 0.09381
# Epoch 25/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3597 - accuracy: 0.6477 - val_loss: 0.2944 - val_accuracy: 0.7000
#
# Epoch 00025: val_loss did not improve from 0.09381
# Epoch 26/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3765 - accuracy: 0.6169 - val_loss: 0.2884 - val_accuracy: 0.6875
#
# Epoch 00026: val_loss did not improve from 0.09381
# Epoch 27/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3535 - accuracy: 0.6519 - val_loss: 0.2815 - val_accuracy: 0.7125
#
# Epoch 00027: val_loss did not improve from 0.09381
# Epoch 28/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3353 - accuracy: 0.6675 - val_loss: 0.2732 - val_accuracy: 0.7125
#
# Epoch 00028: val_loss did not improve from 0.09381
# Epoch 29/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3360 - accuracy: 0.6623 - val_loss: 0.2699 - val_accuracy: 0.7125
#
# Epoch 00029: val_loss did not improve from 0.09381
# Epoch 30/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3256 - accuracy: 0.6713 - val_loss: 0.2630 - val_accuracy: 0.7375
#
# Epoch 00030: val_loss did not improve from 0.09381
# Epoch 31/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3125 - accuracy: 0.6949 - val_loss: 0.2604 - val_accuracy: 0.7375
#
# Epoch 00031: val_loss did not improve from 0.09381
# Epoch 32/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3087 - accuracy: 0.7205 - val_loss: 0.2595 - val_accuracy: 0.7250
#
# Epoch 00032: val_loss did not improve from 0.09381
# Epoch 33/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3235 - accuracy: 0.6661 - val_loss: 0.2561 - val_accuracy: 0.7500
#
# Epoch 00033: val_loss did not improve from 0.09381
# Epoch 34/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2972 - accuracy: 0.7075 - val_loss: 0.2516 - val_accuracy: 0.7375
#
# Epoch 00034: val_loss did not improve from 0.09381
# Epoch 35/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3035 - accuracy: 0.7238 - val_loss: 0.2448 - val_accuracy: 0.7625
#
# Epoch 00035: val_loss did not improve from 0.09381
# Epoch 36/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2993 - accuracy: 0.6925 - val_loss: 0.2454 - val_accuracy: 0.7625
#
# Epoch 00036: val_loss did not improve from 0.09381
# Epoch 37/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2918 - accuracy: 0.7289 - val_loss: 0.2385 - val_accuracy: 0.7500
#
# Epoch 00037: val_loss did not improve from 0.09381
# Epoch 38/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2946 - accuracy: 0.7357 - val_loss: 0.2355 - val_accuracy: 0.7500
#
# Epoch 00038: val_loss did not improve from 0.09381
# Epoch 39/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2748 - accuracy: 0.7481 - val_loss: 0.2264 - val_accuracy: 0.7625
#
# Epoch 00039: val_loss did not improve from 0.09381
# Epoch 40/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2619 - accuracy: 0.7764 - val_loss: 0.2272 - val_accuracy: 0.7625
#
# Epoch 00040: val_loss did not improve from 0.09381
# Epoch 41/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2744 - accuracy: 0.7237 - val_loss: 0.2229 - val_accuracy: 0.7750
#
# Epoch 00041: val_loss did not improve from 0.09381
# Epoch 42/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2618 - accuracy: 0.7565 - val_loss: 0.2256 - val_accuracy: 0.7750
#
# Epoch 00042: val_loss did not improve from 0.09381
# Epoch 43/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2689 - accuracy: 0.7412 - val_loss: 0.2166 - val_accuracy: 0.7875
#
# Epoch 00043: val_loss did not improve from 0.09381
# Epoch 44/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2643 - accuracy: 0.7600 - val_loss: 0.2130 - val_accuracy: 0.7875
#
# Epoch 00044: val_loss did not improve from 0.09381
# Epoch 45/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2679 - accuracy: 0.7496 - val_loss: 0.2119 - val_accuracy: 0.7875
#
# Epoch 00045: val_loss did not improve from 0.09381
# Epoch 46/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2569 - accuracy: 0.7768 - val_loss: 0.2113 - val_accuracy: 0.7875
#
# Epoch 00046: val_loss did not improve from 0.09381
# Epoch 47/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2605 - accuracy: 0.7446 - val_loss: 0.2205 - val_accuracy: 0.7750
#
# Epoch 00047: val_loss did not improve from 0.09381
# Epoch 48/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2406 - accuracy: 0.7843 - val_loss: 0.2091 - val_accuracy: 0.7750
#
# Epoch 00048: val_loss did not improve from 0.09381
# Epoch 49/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2372 - accuracy: 0.7989 - val_loss: 0.2046 - val_accuracy: 0.8000
#
# Epoch 00049: val_loss did not improve from 0.09381
# Epoch 50/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2399 - accuracy: 0.7947 - val_loss: 0.1965 - val_accuracy: 0.8250
#
# Epoch 00050: val_loss did not improve from 0.09381
# Epoch 51/100
# 23/23 [==============================] - 1s 25ms/step - loss: 0.2478 - accuracy: 0.7539 - val_loss: 0.2019 - val_accuracy: 0.7875
#
# Epoch 00051: val_loss did not improve from 0.09381
# Epoch 52/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2522 - accuracy: 0.7776 - val_loss: 0.1975 - val_accuracy: 0.8250
#
# Epoch 00052: val_loss did not improve from 0.09381
# Epoch 53/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2535 - accuracy: 0.7605 - val_loss: 0.1953 - val_accuracy: 0.8250
#
# Epoch 00053: val_loss did not improve from 0.09381
# Epoch 54/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2223 - accuracy: 0.8059 - val_loss: 0.1980 - val_accuracy: 0.8000
#
# Epoch 00054: val_loss did not improve from 0.09381
# Epoch 55/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2199 - accuracy: 0.8015 - val_loss: 0.1979 - val_accuracy: 0.8000
#
# Epoch 00055: val_loss did not improve from 0.09381
# Epoch 56/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2283 - accuracy: 0.7970 - val_loss: 0.1910 - val_accuracy: 0.8250
#
# Epoch 00056: val_loss did not improve from 0.09381
# Epoch 57/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2263 - accuracy: 0.8127 - val_loss: 0.1828 - val_accuracy: 0.8125
#
# Epoch 00057: val_loss did not improve from 0.09381
# Epoch 58/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2232 - accuracy: 0.8113 - val_loss: 0.1926 - val_accuracy: 0.8125
#
# Epoch 00058: val_loss did not improve from 0.09381
# Epoch 59/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2199 - accuracy: 0.7908 - val_loss: 0.1806 - val_accuracy: 0.8250
#
# Epoch 00059: val_loss did not improve from 0.09381
# Epoch 60/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2249 - accuracy: 0.7976 - val_loss: 0.1713 - val_accuracy: 0.8250
#
# Epoch 00060: val_loss did not improve from 0.09381
# Epoch 61/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2128 - accuracy: 0.8255 - val_loss: 0.1758 - val_accuracy: 0.8500
#
# Epoch 00061: val_loss did not improve from 0.09381
# Epoch 62/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2017 - accuracy: 0.8253 - val_loss: 0.1752 - val_accuracy: 0.8500
#
# Epoch 00062: val_loss did not improve from 0.09381
# Epoch 63/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2143 - accuracy: 0.8116 - val_loss: 0.1712 - val_accuracy: 0.8375
#
# Epoch 00063: val_loss did not improve from 0.09381
# Epoch 64/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2050 - accuracy: 0.8115 - val_loss: 0.1727 - val_accuracy: 0.8500
#
# Epoch 00064: val_loss did not improve from 0.09381
# Epoch 65/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1931 - accuracy: 0.8491 - val_loss: 0.1676 - val_accuracy: 0.8500
#
# Epoch 00065: val_loss did not improve from 0.09381
# Epoch 66/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2041 - accuracy: 0.8372 - val_loss: 0.1666 - val_accuracy: 0.8500
#
# Epoch 00066: val_loss did not improve from 0.09381
# Epoch 67/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2071 - accuracy: 0.8365 - val_loss: 0.1515 - val_accuracy: 0.8500
#
# Epoch 00067: val_loss did not improve from 0.09381
# Epoch 68/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1783 - accuracy: 0.8493 - val_loss: 0.1513 - val_accuracy: 0.8500
#
# Epoch 00068: val_loss did not improve from 0.09381
# Epoch 69/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1957 - accuracy: 0.8226 - val_loss: 0.1600 - val_accuracy: 0.8625
#
# Epoch 00069: val_loss did not improve from 0.09381
# Epoch 70/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1891 - accuracy: 0.8400 - val_loss: 0.1480 - val_accuracy: 0.8625
#
# Epoch 00070: val_loss did not improve from 0.09381
# Epoch 71/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1866 - accuracy: 0.8518 - val_loss: 0.1417 - val_accuracy: 0.8625
#
# Epoch 00071: val_loss did not improve from 0.09381
# Epoch 72/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1912 - accuracy: 0.8430 - val_loss: 0.1391 - val_accuracy: 0.8625
#
# Epoch 00072: val_loss did not improve from 0.09381
# Epoch 73/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1819 - accuracy: 0.8385 - val_loss: 0.1415 - val_accuracy: 0.8500
#
# Epoch 00073: val_loss did not improve from 0.09381
# Epoch 74/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1797 - accuracy: 0.8478 - val_loss: 0.1557 - val_accuracy: 0.8625
#
# Epoch 00074: val_loss did not improve from 0.09381
# Epoch 75/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1796 - accuracy: 0.8616 - val_loss: 0.1379 - val_accuracy: 0.8750
#
# Epoch 00075: val_loss did not improve from 0.09381
# Epoch 76/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1970 - accuracy: 0.8413 - val_loss: 0.1468 - val_accuracy: 0.8750
#
# Epoch 00076: val_loss did not improve from 0.09381
# Epoch 77/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1962 - accuracy: 0.8120 - val_loss: 0.1488 - val_accuracy: 0.8750
#
# Epoch 00077: val_loss did not improve from 0.09381
# Epoch 78/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1732 - accuracy: 0.8536 - val_loss: 0.1317 - val_accuracy: 0.8750
#
# Epoch 00078: val_loss did not improve from 0.09381
# Epoch 79/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1758 - accuracy: 0.8482 - val_loss: 0.1371 - val_accuracy: 0.8750
#
# Epoch 00079: val_loss did not improve from 0.09381
# Epoch 80/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1776 - accuracy: 0.8608 - val_loss: 0.1240 - val_accuracy: 0.9000
#
# Epoch 00080: val_loss did not improve from 0.09381
# Epoch 81/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1663 - accuracy: 0.8652 - val_loss: 0.1272 - val_accuracy: 0.8875
#
# Epoch 00081: val_loss did not improve from 0.09381
# Epoch 82/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1763 - accuracy: 0.8555 - val_loss: 0.1305 - val_accuracy: 0.8875
#
# Epoch 00082: val_loss did not improve from 0.09381
# Epoch 83/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1532 - accuracy: 0.8841 - val_loss: 0.1274 - val_accuracy: 0.8875
#
# Epoch 00083: val_loss did not improve from 0.09381
# Epoch 84/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1720 - accuracy: 0.8512 - val_loss: 0.1341 - val_accuracy: 0.8625
#
# Epoch 00084: val_loss did not improve from 0.09381
# Epoch 85/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1687 - accuracy: 0.8578 - val_loss: 0.1299 - val_accuracy: 0.8750
#
# Epoch 00085: val_loss did not improve from 0.09381
# Epoch 86/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1676 - accuracy: 0.8551 - val_loss: 0.1296 - val_accuracy: 0.8750
#
# Epoch 00086: val_loss did not improve from 0.09381
# Epoch 87/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1566 - accuracy: 0.8676 - val_loss: 0.1236 - val_accuracy: 0.8750
#
# Epoch 00087: val_loss did not improve from 0.09381
# Epoch 88/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1606 - accuracy: 0.8701 - val_loss: 0.1239 - val_accuracy: 0.8875
#
# Epoch 00088: val_loss did not improve from 0.09381
# Epoch 89/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1569 - accuracy: 0.8845 - val_loss: 0.1221 - val_accuracy: 0.8875
#
# Epoch 00089: val_loss did not improve from 0.09381
# Epoch 90/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1670 - accuracy: 0.8568 - val_loss: 0.1216 - val_accuracy: 0.8875
#
# Epoch 00090: val_loss did not improve from 0.09381
# Epoch 91/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1567 - accuracy: 0.8660 - val_loss: 0.1104 - val_accuracy: 0.9000
#
# Epoch 00091: val_loss did not improve from 0.09381
# Epoch 92/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1464 - accuracy: 0.8833 - val_loss: 0.1091 - val_accuracy: 0.9125
#
# Epoch 00092: val_loss did not improve from 0.09381
# Epoch 93/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1357 - accuracy: 0.8937 - val_loss: 0.1154 - val_accuracy: 0.9125
#
# Epoch 00093: val_loss did not improve from 0.09381
# Epoch 94/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1518 - accuracy: 0.8703 - val_loss: 0.1189 - val_accuracy: 0.9125
#
# Epoch 00094: val_loss did not improve from 0.09381
# Epoch 95/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1429 - accuracy: 0.8999 - val_loss: 0.1131 - val_accuracy: 0.9000
#
# Epoch 00095: val_loss did not improve from 0.09381
# Epoch 96/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1394 - accuracy: 0.8841 - val_loss: 0.1147 - val_accuracy: 0.9125
#
# Epoch 00096: val_loss did not improve from 0.09381
# Epoch 97/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1251 - accuracy: 0.9154 - val_loss: 0.1065 - val_accuracy: 0.9000
#
# Epoch 00097: val_loss did not improve from 0.09381
# Epoch 98/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1496 - accuracy: 0.8679 - val_loss: 0.1000 - val_accuracy: 0.8875
#
# Epoch 00098: val_loss did not improve from 0.09381
# Epoch 99/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1344 - accuracy: 0.8979 - val_loss: 0.1129 - val_accuracy: 0.9000
#
# Epoch 00099: val_loss did not improve from 0.09381
# Epoch 100/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1334 - accuracy: 0.8923 - val_loss: 0.1110 - val_accuracy: 0.9125
#
# Epoch 00100: val_loss did not improve from 0.09381
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1717 - accuracy: 0.8600
# Val Score:  [0.17174750566482544, 0.8600000143051147]
# ====================================================================================

# %%
print("data train x",t_x.shape)
print("data train y",t_y.shape)

print("data tes x",val_x.shape)
print("data tes y",val_y.shape)

model = load_model('subjek1LSTM.h5')
model.evaluate(val_x, val_y)
# Out:
# data train x (800, 8, 60)
# data train y (800, 4)
# data tes x (200, 8, 60)
# data tes y (200, 4)
# 7/7 [==============================] - 1s 5ms/step - loss: 0.1356 - accuracy: 0.9100
# [0.13564050197601318, 0.9100000262260437]

# %%
fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)
ax1.plot(model_history[0].history['accuracy'], label='Training Fold 1 accuration')
ax1.plot(model_history[1].history['accuracy'], label='Training Fold 2 accuration')
ax1.plot(model_history[2].history['accuracy'], label='Training Fold 3 accuration')
ax1.plot(model_history[3].history['accuracy'], label='Training Fold 4 accuration')
ax1.plot(model_history[4].history['accuracy'], label='Training Fold 5 accuration')
ax1.legend()
ax2.plot(model_history[1].history['loss'], label='Training Fold 1 loss')
ax2.plot(model_history[1].history['loss'], label='Training Fold 2 loss')
ax2.plot(model_history[2].history['loss'], label='Training Fold 3 loss')
ax2.plot(model_history[3].history['loss'], label='Training Fold 4 loss ')
ax2.plot(model_history[4].history['loss'], label='Training Fold 5 loss')
ax2.legend()
plt.show()

# %%
fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt1.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[0].history['loss'], label='Train Loss Fold 1', color='black')
plt2.plot(model_history[0].history['val_loss'], label='Val Loss Fold 1', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red')
plt1.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[1].history['loss'], label='Train Loss Fold 2', color='red')
plt2.plot(model_history[1].history['val_loss'], label='Val Loss Fold 2', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green')
plt1.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[2].history['loss'], label='Train Loss Fold 3', color='green')
plt2.plot(model_history[2].history['val_loss'], label='Val Loss Fold 3', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()


fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue')
plt1.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[3].history['loss'], label='Train Loss Fold 4', color='blue')
plt2.plot(model_history[3].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='purple')
plt1.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[4].history['loss'], label='Train Loss Fold 4', color='purple')
plt2.plot(model_history[4].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

# %%
MODEL_NAME ='/content/subjek1LSTM.h5' 

#CLIP = True # if your model was trained with np.clip to clip  values
CLIP = False
CLIP_VAL = 8  # if above, what was the value +/-

model = tf.keras.models.load_model(MODEL_NAME)

VALDIR = '/content/drive/MyDrive/Colab Notebooks/data8'
ACTIONS =  ["idle","maju","kiri", "kanan"]
PRED_BATCH = 32


def get_val_data(valdir, action, batch_size):

   # argmax_dict = {0: 0, 1: 0, 2: 0,3:0}
    argmax_dict = {2: 0, 0: 0, 1: 0,3:0}
    raw_pred_dict = {0: 0, 1: 0, 2: 0,3:0}

    action_dir = os.path.join(valdir, action)
    for session_file in os.listdir(action_dir):
        filepath = os.path.join(action_dir,session_file)
        if CLIP:
            data = np.clip(np.load(filepath), -CLIP_VAL, CLIP_VAL) / CLIP_VAL
            #print(data)
        else:
            data = np.load(filepath) 
        preds = model.predict([data.reshape(-1, 8, 60)], batch_size=batch_size)
        
        for pred in preds:
            argmax = np.argmax(pred)
            argmax_dict[argmax] += 1
            for idx,value in enumerate(pred):
                raw_pred_dict[idx] += value
    
    argmax_pct_dict = {}
    for i in argmax_dict:
        total = 0
        correct = argmax_dict[i]
        for ii in argmax_dict:
            total += argmax_dict[ii]
        argmax_pct_dict[i] = round(correct/total, 4)
    return argmax_dict, raw_pred_dict, argmax_pct_dict


def make_conf_mat(none,left,forward, right):
    action_dict = {"idle":none,"maju": forward, "kiri": left, "kanan": right}
    action_conf_mat = pd.DataFrame(action_dict)
    actions = [i for i in action_dict]

    fig = plt.figure(figsize=(15, 6))
    ax = fig.add_subplot(111)
    ax.matshow(action_conf_mat, cmap=plt.cm.RdYlGn)
    ax.set_xticklabels([""]+actions)
    ax.set_yticklabels([""]+actions)

    for idx, i in enumerate(action_dict):
        for idx2, ii in enumerate(action_dict[i]):
            ax.text(idx, idx2, f"{round(float(action_dict[i][ii]),2)}", va='center', ha='center')
    # Rotate the tick labels and set their alignment.
    
    plt.title("Matrik data")
    plt.ylabel("Predicted Action")
    fig.tight_layout()
    plt.show()



forward_argmax_dict, forward_raw_pred_dict, forward_argmax_pct_dict = get_val_data(VALDIR, "maju", PRED_BATCH)
none_argmax_dict, none_raw_pred_dict, none_argmax_pct_dict = get_val_data(VALDIR, "idle", PRED_BATCH)
left_argmax_dict, left_raw_pred_dict, left_argmax_pct_dict = get_val_data(VALDIR, "kiri", PRED_BATCH)
right_argmax_dict, right_raw_pred_dict, right_argmax_pct_dict = get_val_data(VALDIR, "kanan", PRED_BATCH)
make_conf_mat(none_argmax_pct_dict,forward_argmax_pct_dict,left_argmax_pct_dict,  right_argmax_pct_dict)

# %%
x_train,x_test,y_train,y_test=train_test_split(train2_X,train_y,test_size=0.2)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (800, 8, 60)
# (200, 8, 60)
# (800, 4)
# (200, 4)

# %%
from sklearn.metrics import roc_curve, auc

#y_score = clf.decision_function(xval)
y_score = model.predict(x_test)

#Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()


# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
    
    
print("roc_auc:",sum(roc_auc.values())/4)
ACTIONS =  ["idle","maju","kiri", "kanan"]
for i in range(0,4):
    plt.figure()
    fig, ax = plt.subplots(figsize=(10,10))
    plt.plot(fpr[i], tpr[i],linewidth=3)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    #plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % ACTIONS[i])
    plt.title('%s -ROC curve (area = %0.2f)' % (ACTIONS[i],roc_auc[i]))
    
    plt.legend(loc="lower right")
    plt.show()
# Out:
# roc_auc: 0.9912181521222269

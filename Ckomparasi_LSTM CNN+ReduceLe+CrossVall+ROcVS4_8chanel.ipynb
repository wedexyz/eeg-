# %% [markdown]
# <a href="https://colab.research.google.com/github/wedexyz/eeg-/blob/main/Ckomparasi_LSTM%20CNN%2BReduceLe%2BCrossVall%2BROcVS4_8chanel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.models import Sequential,load_model
from keras.layers import LSTM
from keras.layers import Dense, Conv2D , MaxPooling2D , Flatten , Dropout , BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping


import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
import pandas as pd
import os
import random
import time
import os


from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau


from scipy import signal
from scipy.fft import fftshift

# %% [markdown]
# # DATA

# %%
ACTIONS = ["kiri", "maju","idle","kanan"]
#reshape = (-1,16, 60,1)
reshape = (-1,8, 60,1)
reshape2 = (-1,8, 60)
reshape3 = (-1,8, 60)
#reshape(-1,28,28,1)

# %%
def create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/data8"):
    training_data = {}
    for action in ACTIONS:
        if action not in training_data:
            training_data[action] = []
        data_dir = os.path.join(starting_dir,action)
        for item in os.listdir(data_dir):
            data = np.load(os.path.join(data_dir, item))
            for item in data:
                training_data[action].append(item)

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)

    for action in ACTIONS:
        np.random.shuffle(training_data[action])  
        training_data[action] = training_data[action][:min(lengths)]

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)
    combined_data = []
    for action in ACTIONS:
        for data in training_data[action]:
            if action == "kiri":
                combined_data.append([data, [1, 0, 0,0]])
            elif action == "maju":
                combined_data.append([data, [0, 1, 0, 0]])
            elif action == "idle":
                combined_data.append([data, [0, 0, 1, 0]])
            elif action == "kanan":
                combined_data.append([data, [0, 0, 0, 1]])

    np.random.shuffle(combined_data)
    print("length:",len(combined_data))
    return combined_data

# %%
print("creating training data")
traindata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/data8")
train_X = []
train_y = []

for X, y in traindata:
    train_X.append(X)
    train_y.append(y)

train_X = np.array(train_X).reshape(reshape)
train2_X = np.array(train_X).reshape(reshape2)

train_y = np.array(train_y)
# Out:
# creating training data
# [250, 250, 250, 250]
# [250, 250, 250, 250]
# length: 1000

# %%
idle = np.load("/content/drive/MyDrive/Colab Notebooks/data8/idle/1608706768.npy")
kanan = np.load("/content/drive/MyDrive/Colab Notebooks/data8/kanan/1608707012.npy")
kiri = np.load("/content/drive/MyDrive/Colab Notebooks/data8/kiri/1608707050.npy")
maju = np.load("/content/drive/MyDrive/Colab Notebooks/data8/maju/1608706976.npy")

kelas1=idle[0][16]
kelas2=maju[0][16]
kelas3=kanan[0][16]
kelas4=kiri[0][16]

kelas1a=idle[175]
kelas2a=maju[175]
kelas3a=kanan[175]
kelas4a=kiri[175]



f1, t1,Sxx= signal.spectrogram(kelas1,fs=60, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd',
                            )
dbs1 = 10*np.log10(Sxx)
f2, t2,Sxx= signal.spectrogram(kelas2,fs=120, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd',
                            )
dbs2 = 10*np.log10(Sxx)
f3, t3,Sxx= signal.spectrogram(kelas3,fs=120, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )
dbs3 = 10*np.log10(Sxx)
f4, t4,Sxx= signal.spectrogram(kelas4,fs=120, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )  
dbs4 = 10*np.log10(Sxx)

# %%
fig, axs = plt.subplots(nrows=4, ncols=4,figsize=(20,10))
axs = axs.flatten()

axs[0].set_title("siggle")
axs[0].plot(kelas1)

axs[1].set_title("global")
axs[1].plot(kelas1a)

axs[2].set_title("Spectogram")
axs[2].pcolormesh(t1, f1,dbs1,  
                  shading='gouraud',
                  cmap='nipy_spectral')

cwt1 = signal.cwt(kelas1,signal.ricker,widths=np.arange(1,50))
cwt2 = signal.cwt(kelas2,signal.ricker,widths=np.arange(1,50))
cwt3 = signal.cwt(kelas3,signal.ricker,widths=np.arange(1,50))
cwt4 = signal.cwt(kelas4,signal.ricker,widths=np.arange(1,50))
axs[3].set_title("wavelet")
axs[3].imshow(cwt1,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt1).max(),vmin=-abs(cwt1).max())

axs[4].plot(kelas2)
axs[5].plot(kelas2a)
axs[6].pcolormesh(t2, f2,dbs2,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[7].imshow(cwt2,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt2).max(),vmin=-abs(cwt2).max())

axs[8].plot(kelas3)
axs[9].plot(kelas3a)
axs[10].pcolormesh(t3, f3,dbs3,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[11].imshow(cwt3,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt3).max(),vmin=-abs(cwt3).max())

axs[12].plot(kelas4)
axs[13].plot(kelas4a)
axs[14].pcolormesh(t4, f4,dbs4,  
                  shading='gouraud',
                  cmap='viridis')
axs[15].imshow(cwt4,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt4).max(),vmin=-abs(cwt4).max())
plt.show()

# %%
import seaborn as sns
ye=pd.DataFrame(train_y)

ye.columns=["kiri", "maju","idle","kanan"]
categories = list(ye.columns.values)
sns.set(font_scale = 1)
plt.figure(figsize=(10,8))
ax= sns.barplot(categories, ye.iloc[:,0:].sum().values)
plt.title("Number of samples labeled as active (1) out of {0} length data".format((ye.shape[0])),fontsize=20)

plt.ylabel('Number of events', fontsize=18)
plt.xlabel('Event Type ', fontsize=12)
#adding the text labels
rects = ax.patches
labels = ye.iloc[:,0:].sum().values

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom', fontsize=10)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # CNN

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1,factor=0.5, min_lr=0.0001)

# %%
#def cnn_model(size, num_cnn_layers):

def cnn_model():    

    model = Sequential()
    
    model.add(Conv2D(filters = 64, kernel_size = (8,8), padding = "same", activation = "relu", input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (4,4)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Conv2D(filters = 64, kernel_size = (4,4), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Conv2D(filters = 64, kernel_size = (2,2), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (1,1)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Flatten())
    
    model.add(Dense(32, activation = "relu"))
    model.add(BatchNormalization())
    
    model.add(Dense(4, activation = "sigmoid"))
   
    #adam = Adam(lr = 0.001)
    model.compile(optimizer ="adam", loss = "binary_crossentropy", 
                  metrics = ['accuracy',tf.keras.metrics.AUC(),
                             tf.keras.metrics.Precision(),
                             tf.keras.metrics.PrecisionAtRecall(0.5),
                             tf.keras.metrics.SpecificityAtSensitivity(0.5),
                             tf.keras.metrics.SensitivityAtSpecificity(0.5)

                             ])
    #model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
 
    
    return model

# %%
model = cnn_model()
model.summary()
# Out:
# Model: "sequential_54"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_126 (Conv2D)          (None, 8, 60, 64)         4160
# _________________________________________________________________
# max_pooling2d_126 (MaxPoolin (None, 2, 15, 64)         0
# _________________________________________________________________
# dropout_162 (Dropout)        (None, 2, 15, 64)         0
# _________________________________________________________________
# batch_normalization_216 (Bat (None, 2, 15, 64)         256
# _________________________________________________________________
# conv2d_127 (Conv2D)          (None, 2, 15, 64)         65600
# _________________________________________________________________
# max_pooling2d_127 (MaxPoolin (None, 1, 7, 64)          0
# _________________________________________________________________
# dropout_163 (Dropout)        (None, 1, 7, 64)          0
# _________________________________________________________________
# batch_normalization_217 (Bat (None, 1, 7, 64)          256
# _________________________________________________________________
# conv2d_128 (Conv2D)          (None, 1, 7, 64)          16448
# _________________________________________________________________
# max_pooling2d_128 (MaxPoolin (None, 1, 7, 64)          0
# _________________________________________________________________
# dropout_164 (Dropout)        (None, 1, 7, 64)          0
# _________________________________________________________________
# batch_normalization_218 (Bat (None, 1, 7, 64)          256
# _________________________________________________________________
# flatten_54 (Flatten)         (None, 448)               0
# _________________________________________________________________
# dense_108 (Dense)            (None, 32)                14368
# _________________________________________________________________
# batch_normalization_219 (Bat (None, 32)                128
# _________________________________________________________________
# dense_109 (Dense)            (None, 4)                 132
# =================================================================
# Total params: 101,604
# Trainable params: 101,156
# Non-trainable params: 448
# _________________________________________________________________

# %%
#set early stopping criteria
pat = 5
#this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='loss', patience=pat, verbose=1)

#define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('subjek1CNN.h5', verbose=1, save_best_only=True)

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=100, BATCH_SIZE=32):
    model = None
    model = cnn_model() 
    results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[learning_rate_reduction,early_stopping, model_checkpoint], 
              verbose=1, validation_split=0.1)   
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %%
n_folds=5
epochs=100
batch_size=32

#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(train_X, train_y, test_size=0.2, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
   
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 23/23 [==============================] - 2s 40ms/step - loss: 0.7798 - accuracy: 0.3729 - auc_43: 0.6083 - precision_43: 0.3111 - precision_at_recall_34: 0.3340 - specificity_at_sensitivity_31: 0.6554 - sensitivity_at_specificity_25: 0.6485 - val_loss: 0.6069 - val_accuracy: 0.5750 - val_auc_43: 0.7798 - val_precision_43: 0.4815 - val_precision_at_recall_34: 0.5481 - val_specificity_at_sensitivity_31: 0.8375 - val_sensitivity_at_specificity_25: 0.8500
#
# Epoch 00001: val_loss improved from inf to 0.60694, saving model to subjek1CNN.h5
# Epoch 2/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5677 - accuracy: 0.6006 - auc_43: 0.8214 - precision_43: 0.4441 - precision_at_recall_34: 0.6437 - specificity_at_sensitivity_31: 0.9056 - sensitivity_at_specificity_25: 0.8951 - val_loss: 0.5721 - val_accuracy: 0.6250 - val_auc_43: 0.8198 - val_precision_43: 0.5079 - val_precision_at_recall_34: 0.5810 - val_specificity_at_sensitivity_31: 0.8542 - val_sensitivity_at_specificity_25: 0.9250
#
# Epoch 00002: val_loss improved from 0.60694 to 0.57213, saving model to subjek1CNN.h5
# Epoch 3/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4768 - accuracy: 0.6882 - auc_43: 0.8825 - precision_43: 0.5349 - precision_at_recall_34: 0.8223 - specificity_at_sensitivity_31: 0.9634 - sensitivity_at_specificity_25: 0.9543 - val_loss: 0.5082 - val_accuracy: 0.7500 - val_auc_43: 0.9016 - val_precision_43: 0.6632 - val_precision_at_recall_34: 0.8113 - val_specificity_at_sensitivity_31: 0.9583 - val_sensitivity_at_specificity_25: 0.9500
#
# Epoch 00003: val_loss improved from 0.57213 to 0.50824, saving model to subjek1CNN.h5
# Epoch 4/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4466 - accuracy: 0.6760 - auc_43: 0.8952 - precision_43: 0.5893 - precision_at_recall_34: 0.8003 - specificity_at_sensitivity_31: 0.9578 - sensitivity_at_specificity_25: 0.9629 - val_loss: 0.4712 - val_accuracy: 0.7000 - val_auc_43: 0.9190 - val_precision_43: 0.6897 - val_precision_at_recall_34: 0.9565 - val_specificity_at_sensitivity_31: 0.9917 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00004: val_loss improved from 0.50824 to 0.47118, saving model to subjek1CNN.h5
# Epoch 5/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4012 - accuracy: 0.7271 - auc_43: 0.9188 - precision_43: 0.6170 - precision_at_recall_34: 0.8664 - specificity_at_sensitivity_31: 0.9736 - sensitivity_at_specificity_25: 0.9809 - val_loss: 0.4224 - val_accuracy: 0.7000 - val_auc_43: 0.9364 - val_precision_43: 0.7229 - val_precision_at_recall_34: 1.0000 - val_specificity_at_sensitivity_31: 1.0000 - val_sensitivity_at_specificity_25: 0.9875
#
# Epoch 00005: val_loss improved from 0.47118 to 0.42235, saving model to subjek1CNN.h5
# Epoch 6/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3669 - accuracy: 0.7542 - auc_43: 0.9355 - precision_43: 0.6822 - precision_at_recall_34: 0.8672 - specificity_at_sensitivity_31: 0.9737 - sensitivity_at_specificity_25: 0.9924 - val_loss: 0.3911 - val_accuracy: 0.7375 - val_auc_43: 0.9380 - val_precision_43: 0.7654 - val_precision_at_recall_34: 0.9756 - val_specificity_at_sensitivity_31: 0.9958 - val_sensitivity_at_specificity_25: 0.9875
#
# Epoch 00006: val_loss improved from 0.42235 to 0.39110, saving model to subjek1CNN.h5
# Epoch 7/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3573 - accuracy: 0.7407 - auc_43: 0.9282 - precision_43: 0.6780 - precision_at_recall_34: 0.8803 - specificity_at_sensitivity_31: 0.9770 - sensitivity_at_specificity_25: 0.9808 - val_loss: 0.3647 - val_accuracy: 0.7625 - val_auc_43: 0.9422 - val_precision_43: 0.7326 - val_precision_at_recall_34: 0.8913 - val_specificity_at_sensitivity_31: 0.9792 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00007: val_loss improved from 0.39110 to 0.36472, saving model to subjek1CNN.h5
# Epoch 8/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3334 - accuracy: 0.7378 - auc_43: 0.9376 - precision_43: 0.6901 - precision_at_recall_34: 0.8936 - specificity_at_sensitivity_31: 0.9798 - sensitivity_at_specificity_25: 0.9947 - val_loss: 0.3458 - val_accuracy: 0.7875 - val_auc_43: 0.9435 - val_precision_43: 0.7500 - val_precision_at_recall_34: 0.8936 - val_specificity_at_sensitivity_31: 0.9792 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00008: val_loss improved from 0.36472 to 0.34582, saving model to subjek1CNN.h5
# Epoch 9/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3380 - accuracy: 0.7154 - auc_43: 0.9294 - precision_43: 0.6761 - precision_at_recall_34: 0.8768 - specificity_at_sensitivity_31: 0.9763 - sensitivity_at_specificity_25: 0.9857 - val_loss: 0.3271 - val_accuracy: 0.8000 - val_auc_43: 0.9385 - val_precision_43: 0.7561 - val_precision_at_recall_34: 0.8776 - val_specificity_at_sensitivity_31: 0.9750 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00009: val_loss improved from 0.34582 to 0.32706, saving model to subjek1CNN.h5
# Epoch 10/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2994 - accuracy: 0.7712 - auc_43: 0.9467 - precision_43: 0.7277 - precision_at_recall_34: 0.9388 - specificity_at_sensitivity_31: 0.9889 - sensitivity_at_specificity_25: 0.9929 - val_loss: 0.3178 - val_accuracy: 0.7500 - val_auc_43: 0.9404 - val_precision_43: 0.7317 - val_precision_at_recall_34: 0.8627 - val_specificity_at_sensitivity_31: 0.9708 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00010: val_loss improved from 0.32706 to 0.31779, saving model to subjek1CNN.h5
# Epoch 11/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2748 - accuracy: 0.7458 - auc_43: 0.9569 - precision_43: 0.7364 - precision_at_recall_34: 0.9551 - specificity_at_sensitivity_31: 0.9920 - sensitivity_at_specificity_25: 0.9980 - val_loss: 0.3042 - val_accuracy: 0.7750 - val_auc_43: 0.9427 - val_precision_43: 0.7349 - val_precision_at_recall_34: 0.8627 - val_specificity_at_sensitivity_31: 0.9708 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00011: val_loss improved from 0.31779 to 0.30416, saving model to subjek1CNN.h5
# Epoch 12/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2887 - accuracy: 0.7815 - auc_43: 0.9432 - precision_43: 0.7521 - precision_at_recall_34: 0.9282 - specificity_at_sensitivity_31: 0.9868 - sensitivity_at_specificity_25: 0.9927 - val_loss: 0.2925 - val_accuracy: 0.7750 - val_auc_43: 0.9468 - val_precision_43: 0.7778 - val_precision_at_recall_34: 0.8889 - val_specificity_at_sensitivity_31: 0.9792 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00012: val_loss improved from 0.30416 to 0.29249, saving model to subjek1CNN.h5
# Epoch 13/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2643 - accuracy: 0.7842 - auc_43: 0.9542 - precision_43: 0.7563 - precision_at_recall_34: 0.9615 - specificity_at_sensitivity_31: 0.9932 - sensitivity_at_specificity_25: 0.9990 - val_loss: 0.2830 - val_accuracy: 0.7875 - val_auc_43: 0.9471 - val_precision_43: 0.7778 - val_precision_at_recall_34: 0.8913 - val_specificity_at_sensitivity_31: 0.9792 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00013: val_loss improved from 0.29249 to 0.28300, saving model to subjek1CNN.h5
# Epoch 14/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2518 - accuracy: 0.8078 - auc_43: 0.9556 - precision_43: 0.7883 - precision_at_recall_34: 0.9609 - specificity_at_sensitivity_31: 0.9929 - sensitivity_at_specificity_25: 0.9945 - val_loss: 0.2946 - val_accuracy: 0.7375 - val_auc_43: 0.9404 - val_precision_43: 0.7045 - val_precision_at_recall_34: 0.8696 - val_specificity_at_sensitivity_31: 0.9750 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00014: val_loss did not improve from 0.28300
# Epoch 15/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2433 - accuracy: 0.7778 - auc_43: 0.9578 - precision_43: 0.7781 - precision_at_recall_34: 0.9802 - specificity_at_sensitivity_31: 0.9965 - sensitivity_at_specificity_25: 0.9996 - val_loss: 0.2750 - val_accuracy: 0.7500 - val_auc_43: 0.9465 - val_precision_43: 0.7229 - val_precision_at_recall_34: 0.8542 - val_specificity_at_sensitivity_31: 0.9708 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00015: val_loss improved from 0.28300 to 0.27498, saving model to subjek1CNN.h5
# Epoch 16/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2267 - accuracy: 0.8219 - auc_43: 0.9660 - precision_43: 0.8281 - precision_at_recall_34: 0.9796 - specificity_at_sensitivity_31: 0.9964 - sensitivity_at_specificity_25: 0.9964 - val_loss: 0.2858 - val_accuracy: 0.7250 - val_auc_43: 0.9410 - val_precision_43: 0.7294 - val_precision_at_recall_34: 0.8182 - val_specificity_at_sensitivity_31: 0.9625 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00016: val_loss did not improve from 0.27498
# Epoch 17/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2385 - accuracy: 0.8064 - auc_43: 0.9576 - precision_43: 0.8119 - precision_at_recall_34: 0.9675 - specificity_at_sensitivity_31: 0.9936 - sensitivity_at_specificity_25: 0.9987 - val_loss: 0.2889 - val_accuracy: 0.7125 - val_auc_43: 0.9381 - val_precision_43: 0.6854 - val_precision_at_recall_34: 0.8163 - val_specificity_at_sensitivity_31: 0.9625 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00017: val_loss did not improve from 0.27498
# Epoch 18/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2048 - accuracy: 0.8762 - auc_43: 0.9752 - precision_43: 0.8507 - precision_at_recall_34: 0.9908 - specificity_at_sensitivity_31: 0.9983 - sensitivity_at_specificity_25: 1.0000 - val_loss: 0.2897 - val_accuracy: 0.7375 - val_auc_43: 0.9408 - val_precision_43: 0.7108 - val_precision_at_recall_34: 0.8511 - val_specificity_at_sensitivity_31: 0.9708 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00018: val_loss did not improve from 0.27498
# Epoch 19/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2065 - accuracy: 0.8474 - auc_43: 0.9731 - precision_43: 0.8313 - precision_at_recall_34: 0.9916 - specificity_at_sensitivity_31: 0.9985 - sensitivity_at_specificity_25: 1.0000 - val_loss: 0.2799 - val_accuracy: 0.7000 - val_auc_43: 0.9432 - val_precision_43: 0.6932 - val_precision_at_recall_34: 0.9091 - val_specificity_at_sensitivity_31: 0.9833 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00019: val_loss did not improve from 0.27498
# Epoch 20/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2004 - accuracy: 0.8696 - auc_43: 0.9762 - precision_43: 0.8405 - precision_at_recall_34: 0.9911 - specificity_at_sensitivity_31: 0.9984 - sensitivity_at_specificity_25: 1.0000 - val_loss: 0.2722 - val_accuracy: 0.7250 - val_auc_43: 0.9459 - val_precision_43: 0.7093 - val_precision_at_recall_34: 0.8889 - val_specificity_at_sensitivity_31: 0.9792 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00020: val_loss improved from 0.27498 to 0.27219, saving model to subjek1CNN.h5
# Epoch 21/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1995 - accuracy: 0.8496 - auc_43: 0.9752 - precision_43: 0.8524 - precision_at_recall_34: 0.9892 - specificity_at_sensitivity_31: 0.9980 - sensitivity_at_specificity_25: 0.9997 - val_loss: 0.2694 - val_accuracy: 0.7375 - val_auc_43: 0.9483 - val_precision_43: 0.7176 - val_precision_at_recall_34: 0.9302 - val_specificity_at_sensitivity_31: 0.9875 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00021: val_loss improved from 0.27219 to 0.26939, saving model to subjek1CNN.h5
# Epoch 22/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1854 - accuracy: 0.8757 - auc_43: 0.9805 - precision_43: 0.8778 - precision_at_recall_34: 0.9966 - specificity_at_sensitivity_31: 0.9994 - sensitivity_at_specificity_25: 0.9999 - val_loss: 0.2691 - val_accuracy: 0.7250 - val_auc_43: 0.9481 - val_precision_43: 0.7059 - val_precision_at_recall_34: 0.9556 - val_specificity_at_sensitivity_31: 0.9917 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00022: val_loss improved from 0.26939 to 0.26912, saving model to subjek1CNN.h5
# Epoch 23/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1981 - accuracy: 0.8894 - auc_43: 0.9762 - precision_43: 0.8856 - precision_at_recall_34: 0.9978 - specificity_at_sensitivity_31: 0.9996 - sensitivity_at_specificity_25: 0.9981 - val_loss: 0.2657 - val_accuracy: 0.7250 - val_auc_43: 0.9490 - val_precision_43: 0.7059 - val_precision_at_recall_34: 0.9524 - val_specificity_at_sensitivity_31: 0.9917 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00023: val_loss improved from 0.26912 to 0.26572, saving model to subjek1CNN.h5
# Epoch 24/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.1847 - accuracy: 0.8597 - auc_43: 0.9788 - precision_43: 0.8616 - precision_at_recall_34: 0.9981 - specificity_at_sensitivity_31: 0.9997 - sensitivity_at_specificity_25: 0.9996 - val_loss: 0.2625 - val_accuracy: 0.7375 - val_auc_43: 0.9511 - val_precision_43: 0.6988 - val_precision_at_recall_34: 0.9556 - val_specificity_at_sensitivity_31: 0.9917 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00024: val_loss improved from 0.26572 to 0.26248, saving model to subjek1CNN.h5
# Epoch 25/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1800 - accuracy: 0.8654 - auc_43: 0.9811 - precision_43: 0.8649 - precision_at_recall_34: 0.9976 - specificity_at_sensitivity_31: 0.9995 - sensitivity_at_specificity_25: 0.9986 - val_loss: 0.2526 - val_accuracy: 0.7375 - val_auc_43: 0.9538 - val_precision_43: 0.7176 - val_precision_at_recall_34: 0.9756 - val_specificity_at_sensitivity_31: 0.9958 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00025: val_loss improved from 0.26248 to 0.25262, saving model to subjek1CNN.h5
# Epoch 26/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1718 - accuracy: 0.8875 - auc_43: 0.9843 - precision_43: 0.9014 - precision_at_recall_34: 0.9998 - specificity_at_sensitivity_31: 1.0000 - sensitivity_at_specificity_25: 1.0000 - val_loss: 0.2469 - val_accuracy: 0.7375 - val_auc_43: 0.9548 - val_precision_43: 0.7093 - val_precision_at_recall_34: 1.0000 - val_specificity_at_sensitivity_31: 1.0000 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00026: val_loss improved from 0.25262 to 0.24692, saving model to subjek1CNN.h5
# Epoch 27/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1722 - accuracy: 0.8800 - auc_43: 0.9834 - precision_43: 0.8687 - precision_at_recall_34: 0.9990 - specificity_at_sensitivity_31: 0.9998 - sensitivity_at_specificity_25: 1.0000 - val_loss: 0.2459 - val_accuracy: 0.7375 - val_auc_43: 0.9564 - val_precision_43: 0.7059 - val_precision_at_recall_34: 1.0000 - val_specificity_at_sensitivity_31: 1.0000 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00027: val_loss improved from 0.24692 to 0.24593, saving model to subjek1CNN.h5
# Epoch 28/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1768 - accuracy: 0.8780 - auc_43: 0.9810 - precision_43: 0.8833 - precision_at_recall_34: 0.9984 - specificity_at_sensitivity_31: 0.9997 - sensitivity_at_specificity_25: 0.9996 - val_loss: 0.2404 - val_accuracy: 0.7375 - val_auc_43: 0.9573 - val_precision_43: 0.7284 - val_precision_at_recall_34: 0.9773 - val_specificity_at_sensitivity_31: 0.9958 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00028: val_loss improved from 0.24593 to 0.24040, saving model to subjek1CNN.h5
# Epoch 29/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1826 - accuracy: 0.8922 - auc_43: 0.9799 - precision_43: 0.8688 - precision_at_recall_34: 0.9835 - specificity_at_sensitivity_31: 0.9965 - sensitivity_at_specificity_25: 1.0000 - val_loss: 0.2362 - val_accuracy: 0.7375 - val_auc_43: 0.9587 - val_precision_43: 0.7349 - val_precision_at_recall_34: 1.0000 - val_specificity_at_sensitivity_31: 1.0000 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00029: val_loss improved from 0.24040 to 0.23622, saving model to subjek1CNN.h5
# Epoch 30/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1641 - accuracy: 0.8983 - auc_43: 0.9845 - precision_43: 0.8813 - precision_at_recall_34: 1.0000 - specificity_at_sensitivity_31: 1.0000 - sensitivity_at_specificity_25: 1.0000 - val_loss: 0.2298 - val_accuracy: 0.7500 - val_auc_43: 0.9607 - val_precision_43: 0.7349 - val_precision_at_recall_34: 1.0000 - val_specificity_at_sensitivity_31: 1.0000 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00030: val_loss improved from 0.23622 to 0.22980, saving model to subjek1CNN.h5
# Epoch 31/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1615 - accuracy: 0.9019 - auc_43: 0.9859 - precision_43: 0.9054 - precision_at_recall_34: 1.0000 - specificity_at_sensitivity_31: 1.0000 - sensitivity_at_specificity_25: 0.9998 - val_loss: 0.2239 - val_accuracy: 0.7500 - val_auc_43: 0.9630 - val_precision_43: 0.7381 - val_precision_at_recall_34: 1.0000 - val_specificity_at_sensitivity_31: 1.0000 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00031: val_loss improved from 0.22980 to 0.22386, saving model to subjek1CNN.h5
# Epoch 32/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1790 - accuracy: 0.8731 - auc_43: 0.9786 - precision_43: 0.8631 - precision_at_recall_34: 1.0000 - specificity_at_sensitivity_31: 1.0000 - sensitivity_at_specificity_25: 1.0000 - val_loss: 0.2175 - val_accuracy: 0.7750 - val_auc_43: 0.9651 - val_precision_43: 0.7561 - val_precision_at_recall_34: 1.0000 - val_specificity_at_sensitivity_31: 1.0000 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00032: val_loss improved from 0.22386 to 0.21749, saving model to subjek1CNN.h5
# Epoch 33/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1631 - accuracy: 0.8987 - auc_43: 0.9861 - precision_43: 0.9049 - precision_at_recall_34: 0.9978 - specificity_at_sensitivity_31: 0.9996 - sensitivity_at_specificity_25: 1.0000 - val_loss: 0.2158 - val_accuracy: 0.7750 - val_auc_43: 0.9654 - val_precision_43: 0.7500 - val_precision_at_recall_34: 1.0000 - val_specificity_at_sensitivity_31: 1.0000 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00033: val_loss improved from 0.21749 to 0.21578, saving model to subjek1CNN.h5
# Epoch 34/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1887 - accuracy: 0.8660 - auc_43: 0.9761 - precision_43: 0.8689 - precision_at_recall_34: 0.9984 - specificity_at_sensitivity_31: 0.9997 - sensitivity_at_specificity_25: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.7625 - val_auc_43: 0.9681 - val_precision_43: 0.7927 - val_precision_at_recall_34: 1.0000 - val_specificity_at_sensitivity_31: 1.0000 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00034: val_loss improved from 0.21578 to 0.20907, saving model to subjek1CNN.h5
# Epoch 35/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1702 - accuracy: 0.8781 - auc_43: 0.9823 - precision_43: 0.8790 - precision_at_recall_34: 0.9996 - specificity_at_sensitivity_31: 0.9999 - sensitivity_at_specificity_25: 0.9999 - val_loss: 0.2032 - val_accuracy: 0.7875 - val_auc_43: 0.9699 - val_precision_43: 0.8025 - val_precision_at_recall_34: 1.0000 - val_specificity_at_sensitivity_31: 1.0000 - val_sensitivity_at_specificity_25: 1.0000
#
# Epoch 00035: val_loss improved from 0.20907 to 0.20320, saving model to subjek1CNN.h5
# Epoch 00035: early stopping
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1902 - accuracy: 0.8050 - auc_43: 0.9762 - precision_43: 0.7816 - precision_at_recall_34: 1.0000 - specificity_at_sensitivity_31: 1.0000 - sensitivity_at_specificity_25: 1.0000
# Val Score:  [0.19020003080368042, 0.8050000071525574, 0.976154088973999, 0.7815533876419067, 1.0, 1.0, 1.0]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
# 23/23 [==============================] - 3s 41ms/step - loss: 0.7856 - accuracy: 0.3529 - auc_44: 0.6095 - precision_44: 0.3088 - precision_at_recall_35: 0.3308 - specificity_at_sensitivity_32: 0.6417 - sensitivity_at_specificity_26: 0.6679 - val_loss: 0.6300 - val_accuracy: 0.6250 - val_auc_44: 0.7504 - val_precision_44: 0.4622 - val_precision_at_recall_35: 0.5479 - val_specificity_at_sensitivity_32: 0.8625 - val_sensitivity_at_specificity_26: 0.8000
#
# Epoch 00001: val_loss did not improve from 0.20320
# Epoch 2/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5742 - accuracy: 0.5823 - auc_44: 0.7958 - precision_44: 0.4316 - precision_at_recall_35: 0.6051 - specificity_at_sensitivity_32: 0.8899 - sensitivity_at_specificity_26: 0.8678 - val_loss: 0.5458 - val_accuracy: 0.6250 - val_auc_44: 0.8741 - val_precision_44: 0.6885 - val_precision_at_recall_35: 0.6970 - val_specificity_at_sensitivity_32: 0.9208 - val_sensitivity_at_specificity_26: 0.9500
#
# Epoch 00002: val_loss did not improve from 0.20320
# Epoch 3/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4865 - accuracy: 0.6397 - auc_44: 0.8502 - precision_44: 0.5216 - precision_at_recall_35: 0.7465 - specificity_at_sensitivity_32: 0.9411 - sensitivity_at_specificity_26: 0.9278 - val_loss: 0.5050 - val_accuracy: 0.6875 - val_auc_44: 0.9009 - val_precision_44: 0.6857 - val_precision_at_recall_35: 0.8163 - val_specificity_at_sensitivity_32: 0.9625 - val_sensitivity_at_specificity_26: 0.9750
#
# Epoch 00003: val_loss did not improve from 0.20320
# Epoch 4/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4515 - accuracy: 0.6500 - auc_44: 0.8706 - precision_44: 0.5623 - precision_at_recall_35: 0.7192 - specificity_at_sensitivity_32: 0.9323 - sensitivity_at_specificity_26: 0.9579 - val_loss: 0.4663 - val_accuracy: 0.7250 - val_auc_44: 0.9200 - val_precision_44: 0.7215 - val_precision_at_recall_35: 0.7843 - val_specificity_at_sensitivity_32: 0.9542 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00004: val_loss did not improve from 0.20320
# Epoch 5/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4088 - accuracy: 0.6978 - auc_44: 0.9027 - precision_44: 0.6165 - precision_at_recall_35: 0.8284 - specificity_at_sensitivity_32: 0.9647 - sensitivity_at_specificity_26: 0.9764 - val_loss: 0.4124 - val_accuracy: 0.7000 - val_auc_44: 0.9435 - val_precision_44: 0.7222 - val_precision_at_recall_35: 0.9111 - val_specificity_at_sensitivity_32: 0.9833 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00005: val_loss did not improve from 0.20320
# Epoch 6/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3846 - accuracy: 0.6861 - auc_44: 0.9110 - precision_44: 0.6657 - precision_at_recall_35: 0.8100 - specificity_at_sensitivity_32: 0.9593 - sensitivity_at_specificity_26: 0.9757 - val_loss: 0.3745 - val_accuracy: 0.7625 - val_auc_44: 0.9541 - val_precision_44: 0.7532 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00006: val_loss did not improve from 0.20320
# Epoch 7/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.3510 - accuracy: 0.6964 - auc_44: 0.9243 - precision_44: 0.7008 - precision_at_recall_35: 0.8552 - specificity_at_sensitivity_32: 0.9712 - sensitivity_at_specificity_26: 0.9847 - val_loss: 0.3393 - val_accuracy: 0.7125 - val_auc_44: 0.9482 - val_precision_44: 0.7333 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00007: val_loss did not improve from 0.20320
# Epoch 8/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3392 - accuracy: 0.6998 - auc_44: 0.9241 - precision_44: 0.6922 - precision_at_recall_35: 0.8537 - specificity_at_sensitivity_32: 0.9698 - sensitivity_at_specificity_26: 0.9886 - val_loss: 0.3245 - val_accuracy: 0.7375 - val_auc_44: 0.9516 - val_precision_44: 0.7564 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00008: val_loss did not improve from 0.20320
# Epoch 9/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3060 - accuracy: 0.7574 - auc_44: 0.9420 - precision_44: 0.7268 - precision_at_recall_35: 0.9067 - specificity_at_sensitivity_32: 0.9822 - sensitivity_at_specificity_26: 0.9997 - val_loss: 0.3041 - val_accuracy: 0.7375 - val_auc_44: 0.9517 - val_precision_44: 0.7500 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00009: val_loss did not improve from 0.20320
# Epoch 10/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2868 - accuracy: 0.7604 - auc_44: 0.9470 - precision_44: 0.7172 - precision_at_recall_35: 0.9390 - specificity_at_sensitivity_32: 0.9889 - sensitivity_at_specificity_26: 0.9950 - val_loss: 0.2878 - val_accuracy: 0.7250 - val_auc_44: 0.9484 - val_precision_44: 0.7326 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00010: val_loss did not improve from 0.20320
# Epoch 11/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2861 - accuracy: 0.7652 - auc_44: 0.9443 - precision_44: 0.7628 - precision_at_recall_35: 0.9222 - specificity_at_sensitivity_32: 0.9855 - sensitivity_at_specificity_26: 0.9956 - val_loss: 0.2691 - val_accuracy: 0.7500 - val_auc_44: 0.9577 - val_precision_44: 0.7619 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00011: val_loss did not improve from 0.20320
# Epoch 12/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2608 - accuracy: 0.7827 - auc_44: 0.9550 - precision_44: 0.7785 - precision_at_recall_35: 0.9601 - specificity_at_sensitivity_32: 0.9928 - sensitivity_at_specificity_26: 0.9984 - val_loss: 0.2599 - val_accuracy: 0.7500 - val_auc_44: 0.9596 - val_precision_44: 0.7590 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00012: val_loss did not improve from 0.20320
# Epoch 13/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2688 - accuracy: 0.7687 - auc_44: 0.9485 - precision_44: 0.7651 - precision_at_recall_35: 0.9542 - specificity_at_sensitivity_32: 0.9918 - sensitivity_at_specificity_26: 0.9965 - val_loss: 0.2493 - val_accuracy: 0.7875 - val_auc_44: 0.9624 - val_precision_44: 0.7586 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00013: val_loss did not improve from 0.20320
# Epoch 14/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2496 - accuracy: 0.7997 - auc_44: 0.9572 - precision_44: 0.7753 - precision_at_recall_35: 0.9500 - specificity_at_sensitivity_32: 0.9906 - sensitivity_at_specificity_26: 0.9992 - val_loss: 0.2483 - val_accuracy: 0.7875 - val_auc_44: 0.9624 - val_precision_44: 0.7529 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00014: val_loss did not improve from 0.20320
# Epoch 15/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2529 - accuracy: 0.7673 - auc_44: 0.9549 - precision_44: 0.7775 - precision_at_recall_35: 0.9533 - specificity_at_sensitivity_32: 0.9910 - sensitivity_at_specificity_26: 0.9975 - val_loss: 0.2374 - val_accuracy: 0.7875 - val_auc_44: 0.9653 - val_precision_44: 0.7711 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00015: val_loss did not improve from 0.20320
# Epoch 16/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2324 - accuracy: 0.8159 - auc_44: 0.9654 - precision_44: 0.8185 - precision_at_recall_35: 0.9789 - specificity_at_sensitivity_32: 0.9963 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.2371 - val_accuracy: 0.8000 - val_auc_44: 0.9638 - val_precision_44: 0.7831 - val_precision_at_recall_35: 0.9778 - val_specificity_at_sensitivity_32: 0.9958 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00016: val_loss did not improve from 0.20320
# Epoch 17/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2237 - accuracy: 0.8141 - auc_44: 0.9674 - precision_44: 0.8049 - precision_at_recall_35: 0.9848 - specificity_at_sensitivity_32: 0.9973 - sensitivity_at_specificity_26: 0.9998 - val_loss: 0.2295 - val_accuracy: 0.8375 - val_auc_44: 0.9660 - val_precision_44: 0.8462 - val_precision_at_recall_35: 0.9767 - val_specificity_at_sensitivity_32: 0.9958 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00017: val_loss did not improve from 0.20320
# Epoch 18/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2135 - accuracy: 0.8532 - auc_44: 0.9714 - precision_44: 0.8222 - precision_at_recall_35: 0.9874 - specificity_at_sensitivity_32: 0.9978 - sensitivity_at_specificity_26: 0.9961 - val_loss: 0.2214 - val_accuracy: 0.8250 - val_auc_44: 0.9678 - val_precision_44: 0.8193 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00018: val_loss did not improve from 0.20320
# Epoch 19/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2257 - accuracy: 0.8139 - auc_44: 0.9641 - precision_44: 0.8280 - precision_at_recall_35: 0.9811 - specificity_at_sensitivity_32: 0.9967 - sensitivity_at_specificity_26: 0.9973 - val_loss: 0.2252 - val_accuracy: 0.8125 - val_auc_44: 0.9651 - val_precision_44: 0.8095 - val_precision_at_recall_35: 0.9767 - val_specificity_at_sensitivity_32: 0.9958 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00019: val_loss did not improve from 0.20320
# Epoch 20/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2203 - accuracy: 0.8158 - auc_44: 0.9659 - precision_44: 0.8319 - precision_at_recall_35: 0.9839 - specificity_at_sensitivity_32: 0.9972 - sensitivity_at_specificity_26: 0.9951 - val_loss: 0.2120 - val_accuracy: 0.8375 - val_auc_44: 0.9697 - val_precision_44: 0.8095 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00020: val_loss did not improve from 0.20320
# Epoch 21/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2070 - accuracy: 0.8540 - auc_44: 0.9713 - precision_44: 0.8562 - precision_at_recall_35: 0.9976 - specificity_at_sensitivity_32: 0.9996 - sensitivity_at_specificity_26: 0.9924 - val_loss: 0.2051 - val_accuracy: 0.8125 - val_auc_44: 0.9735 - val_precision_44: 0.8025 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00021: val_loss did not improve from 0.20320
# Epoch 22/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1974 - accuracy: 0.8545 - auc_44: 0.9756 - precision_44: 0.8558 - precision_at_recall_35: 0.9919 - specificity_at_sensitivity_32: 0.9985 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.8125 - val_auc_44: 0.9727 - val_precision_44: 0.8025 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00022: val_loss did not improve from 0.20320
# Epoch 23/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1922 - accuracy: 0.8725 - auc_44: 0.9786 - precision_44: 0.8722 - precision_at_recall_35: 0.9954 - specificity_at_sensitivity_32: 0.9992 - sensitivity_at_specificity_26: 0.9989 - val_loss: 0.2009 - val_accuracy: 0.8000 - val_auc_44: 0.9753 - val_precision_44: 0.8025 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00023: val_loss improved from 0.20320 to 0.20087, saving model to subjek1CNN.h5
# Epoch 24/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1898 - accuracy: 0.8672 - auc_44: 0.9774 - precision_44: 0.8626 - precision_at_recall_35: 0.9937 - specificity_at_sensitivity_32: 0.9989 - sensitivity_at_specificity_26: 0.9977 - val_loss: 0.1973 - val_accuracy: 0.8125 - val_auc_44: 0.9745 - val_precision_44: 0.8025 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00024: val_loss improved from 0.20087 to 0.19733, saving model to subjek1CNN.h5
# Epoch 25/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1844 - accuracy: 0.8663 - auc_44: 0.9795 - precision_44: 0.8691 - precision_at_recall_35: 0.9956 - specificity_at_sensitivity_32: 0.9992 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.2024 - val_accuracy: 0.8125 - val_auc_44: 0.9740 - val_precision_44: 0.7975 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00025: val_loss did not improve from 0.19733
# Epoch 26/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1768 - accuracy: 0.9082 - auc_44: 0.9824 - precision_44: 0.9089 - precision_at_recall_35: 0.9988 - specificity_at_sensitivity_32: 0.9998 - sensitivity_at_specificity_26: 0.9981 - val_loss: 0.1947 - val_accuracy: 0.8125 - val_auc_44: 0.9747 - val_precision_44: 0.8095 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00026: val_loss improved from 0.19733 to 0.19468, saving model to subjek1CNN.h5
# Epoch 27/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1787 - accuracy: 0.8659 - auc_44: 0.9798 - precision_44: 0.8576 - precision_at_recall_35: 1.0000 - specificity_at_sensitivity_32: 1.0000 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1957 - val_accuracy: 0.8125 - val_auc_44: 0.9748 - val_precision_44: 0.8000 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00027: val_loss did not improve from 0.19468
# Epoch 28/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1802 - accuracy: 0.8716 - auc_44: 0.9791 - precision_44: 0.8710 - precision_at_recall_35: 0.9974 - specificity_at_sensitivity_32: 0.9995 - sensitivity_at_specificity_26: 0.9995 - val_loss: 0.1888 - val_accuracy: 0.8125 - val_auc_44: 0.9761 - val_precision_44: 0.8072 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00028: val_loss improved from 0.19468 to 0.18875, saving model to subjek1CNN.h5
# Epoch 29/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1730 - accuracy: 0.8884 - auc_44: 0.9820 - precision_44: 0.8758 - precision_at_recall_35: 1.0000 - specificity_at_sensitivity_32: 1.0000 - sensitivity_at_specificity_26: 0.9996 - val_loss: 0.1858 - val_accuracy: 0.8375 - val_auc_44: 0.9768 - val_precision_44: 0.8095 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00029: val_loss improved from 0.18875 to 0.18578, saving model to subjek1CNN.h5
# Epoch 30/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1785 - accuracy: 0.8463 - auc_44: 0.9791 - precision_44: 0.8521 - precision_at_recall_35: 1.0000 - specificity_at_sensitivity_32: 1.0000 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1811 - val_accuracy: 0.8125 - val_auc_44: 0.9787 - val_precision_44: 0.8072 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00030: val_loss improved from 0.18578 to 0.18106, saving model to subjek1CNN.h5
# Epoch 31/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1640 - accuracy: 0.8811 - auc_44: 0.9850 - precision_44: 0.8971 - precision_at_recall_35: 1.0000 - specificity_at_sensitivity_32: 1.0000 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1809 - val_accuracy: 0.8250 - val_auc_44: 0.9785 - val_precision_44: 0.8095 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00031: val_loss improved from 0.18106 to 0.18087, saving model to subjek1CNN.h5
# Epoch 32/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1719 - accuracy: 0.8676 - auc_44: 0.9819 - precision_44: 0.8875 - precision_at_recall_35: 0.9930 - specificity_at_sensitivity_32: 0.9986 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1776 - val_accuracy: 0.8250 - val_auc_44: 0.9787 - val_precision_44: 0.8118 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00032: val_loss improved from 0.18087 to 0.17761, saving model to subjek1CNN.h5
# Epoch 33/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1667 - accuracy: 0.8907 - auc_44: 0.9836 - precision_44: 0.8889 - precision_at_recall_35: 1.0000 - specificity_at_sensitivity_32: 1.0000 - sensitivity_at_specificity_26: 0.9990 - val_loss: 0.1688 - val_accuracy: 0.8500 - val_auc_44: 0.9811 - val_precision_44: 0.8118 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00033: val_loss improved from 0.17761 to 0.16876, saving model to subjek1CNN.h5
# Epoch 34/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1691 - accuracy: 0.8879 - auc_44: 0.9827 - precision_44: 0.8834 - precision_at_recall_35: 0.9985 - specificity_at_sensitivity_32: 0.9997 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.8375 - val_auc_44: 0.9809 - val_precision_44: 0.8140 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00034: val_loss improved from 0.16876 to 0.16749, saving model to subjek1CNN.h5
# Epoch 35/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1902 - accuracy: 0.8789 - auc_44: 0.9763 - precision_44: 0.8840 - precision_at_recall_35: 0.9873 - specificity_at_sensitivity_32: 0.9977 - sensitivity_at_specificity_26: 0.9973 - val_loss: 0.1677 - val_accuracy: 0.8500 - val_auc_44: 0.9807 - val_precision_44: 0.8118 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00035: val_loss did not improve from 0.16749
# Epoch 36/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1569 - accuracy: 0.9036 - auc_44: 0.9871 - precision_44: 0.8966 - precision_at_recall_35: 1.0000 - specificity_at_sensitivity_32: 1.0000 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1618 - val_accuracy: 0.8500 - val_auc_44: 0.9829 - val_precision_44: 0.8333 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00036: val_loss improved from 0.16749 to 0.16179, saving model to subjek1CNN.h5
# Epoch 37/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1621 - accuracy: 0.9076 - auc_44: 0.9848 - precision_44: 0.9003 - precision_at_recall_35: 1.0000 - specificity_at_sensitivity_32: 1.0000 - sensitivity_at_specificity_26: 0.9994 - val_loss: 0.1614 - val_accuracy: 0.8500 - val_auc_44: 0.9829 - val_precision_44: 0.8235 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00037: val_loss improved from 0.16179 to 0.16142, saving model to subjek1CNN.h5
# Epoch 38/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1617 - accuracy: 0.8884 - auc_44: 0.9847 - precision_44: 0.8950 - precision_at_recall_35: 0.9973 - specificity_at_sensitivity_32: 0.9995 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.8500 - val_auc_44: 0.9836 - val_precision_44: 0.8353 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00038: val_loss improved from 0.16142 to 0.15870, saving model to subjek1CNN.h5
# Epoch 39/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1540 - accuracy: 0.8790 - auc_44: 0.9863 - precision_44: 0.8876 - precision_at_recall_35: 1.0000 - specificity_at_sensitivity_32: 1.0000 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1554 - val_accuracy: 0.8625 - val_auc_44: 0.9850 - val_precision_44: 0.8554 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00039: val_loss improved from 0.15870 to 0.15535, saving model to subjek1CNN.h5
# Epoch 40/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1595 - accuracy: 0.8889 - auc_44: 0.9843 - precision_44: 0.8853 - precision_at_recall_35: 0.9964 - specificity_at_sensitivity_32: 0.9993 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1541 - val_accuracy: 0.8625 - val_auc_44: 0.9848 - val_precision_44: 0.8554 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00040: val_loss improved from 0.15535 to 0.15407, saving model to subjek1CNN.h5
# Epoch 41/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.1563 - accuracy: 0.8999 - auc_44: 0.9854 - precision_44: 0.8915 - precision_at_recall_35: 1.0000 - specificity_at_sensitivity_32: 1.0000 - sensitivity_at_specificity_26: 0.9991 - val_loss: 0.1535 - val_accuracy: 0.8750 - val_auc_44: 0.9852 - val_precision_44: 0.8537 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00041: val_loss improved from 0.15407 to 0.15345, saving model to subjek1CNN.h5
# Epoch 42/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1608 - accuracy: 0.8997 - auc_44: 0.9853 - precision_44: 0.8917 - precision_at_recall_35: 0.9991 - specificity_at_sensitivity_32: 0.9998 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.8750 - val_auc_44: 0.9876 - val_precision_44: 0.8795 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00042: val_loss improved from 0.15345 to 0.14619, saving model to subjek1CNN.h5
# Epoch 43/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1574 - accuracy: 0.8839 - auc_44: 0.9854 - precision_44: 0.8977 - precision_at_recall_35: 1.0000 - specificity_at_sensitivity_32: 1.0000 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.8750 - val_auc_44: 0.9886 - val_precision_44: 0.8780 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00043: val_loss improved from 0.14619 to 0.14295, saving model to subjek1CNN.h5
# Epoch 44/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1592 - accuracy: 0.8839 - auc_44: 0.9847 - precision_44: 0.8922 - precision_at_recall_35: 1.0000 - specificity_at_sensitivity_32: 1.0000 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.8750 - val_auc_44: 0.9878 - val_precision_44: 0.8780 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00044: val_loss did not improve from 0.14295
# Epoch 45/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1445 - accuracy: 0.8959 - auc_44: 0.9888 - precision_44: 0.9077 - precision_at_recall_35: 1.0000 - specificity_at_sensitivity_32: 1.0000 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.8625 - val_auc_44: 0.9867 - val_precision_44: 0.8659 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00045: val_loss did not improve from 0.14295
# Epoch 46/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1583 - accuracy: 0.8803 - auc_44: 0.9842 - precision_44: 0.8712 - precision_at_recall_35: 0.9993 - specificity_at_sensitivity_32: 0.9999 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.8625 - val_auc_44: 0.9875 - val_precision_44: 0.8675 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00046: val_loss did not improve from 0.14295
# Epoch 47/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1528 - accuracy: 0.8910 - auc_44: 0.9848 - precision_44: 0.8962 - precision_at_recall_35: 1.0000 - specificity_at_sensitivity_32: 1.0000 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1446 - val_accuracy: 0.8625 - val_auc_44: 0.9873 - val_precision_44: 0.8642 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00047: val_loss did not improve from 0.14295
# Epoch 48/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1453 - accuracy: 0.9178 - auc_44: 0.9888 - precision_44: 0.9105 - precision_at_recall_35: 1.0000 - specificity_at_sensitivity_32: 1.0000 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.8625 - val_auc_44: 0.9889 - val_precision_44: 0.8675 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00048: val_loss improved from 0.14295 to 0.14097, saving model to subjek1CNN.h5
# Epoch 49/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1531 - accuracy: 0.8884 - auc_44: 0.9863 - precision_44: 0.8812 - precision_at_recall_35: 1.0000 - specificity_at_sensitivity_32: 1.0000 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.8750 - val_auc_44: 0.9891 - val_precision_44: 0.8659 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00049: val_loss improved from 0.14097 to 0.13722, saving model to subjek1CNN.h5
# Epoch 50/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1541 - accuracy: 0.8975 - auc_44: 0.9861 - precision_44: 0.9110 - precision_at_recall_35: 0.9996 - specificity_at_sensitivity_32: 0.9999 - sensitivity_at_specificity_26: 0.9999 - val_loss: 0.1445 - val_accuracy: 0.8625 - val_auc_44: 0.9867 - val_precision_44: 0.8642 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00050: val_loss did not improve from 0.13722
# Epoch 51/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1550 - accuracy: 0.8821 - auc_44: 0.9851 - precision_44: 0.8825 - precision_at_recall_35: 0.9942 - specificity_at_sensitivity_32: 0.9989 - sensitivity_at_specificity_26: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.8750 - val_auc_44: 0.9852 - val_precision_44: 0.8353 - val_precision_at_recall_35: 1.0000 - val_specificity_at_sensitivity_32: 1.0000 - val_sensitivity_at_specificity_26: 1.0000
#
# Epoch 00051: val_loss did not improve from 0.13722
# Epoch 52/100
# ...
#
# Epoch 00057: val_loss did not improve from 0.10736
# Epoch 58/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1160 - accuracy: 0.9268 - auc_47: 0.9926 - precision_47: 0.9159 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1206 - val_accuracy: 0.9250 - val_auc_47: 0.9916 - val_precision_47: 0.8795 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00058: val_loss did not improve from 0.10736
# Epoch 59/100
# 23/23 [==============================] - 0s 22ms/step - loss: 0.1261 - accuracy: 0.9082 - auc_47: 0.9890 - precision_47: 0.9102 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1217 - val_accuracy: 0.9250 - val_auc_47: 0.9915 - val_precision_47: 0.8902 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00059: val_loss did not improve from 0.10736
# Epoch 60/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1281 - accuracy: 0.9143 - auc_47: 0.9890 - precision_47: 0.9071 - precision_at_recall_38: 0.9920 - specificity_at_sensitivity_35: 0.9984 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1285 - val_accuracy: 0.9000 - val_auc_47: 0.9904 - val_precision_47: 0.8588 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00060: val_loss did not improve from 0.10736
# Epoch 61/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1323 - accuracy: 0.9107 - auc_47: 0.9876 - precision_47: 0.9166 - precision_at_recall_38: 0.9919 - specificity_at_sensitivity_35: 0.9986 - sensitivity_at_specificity_29: 0.9970 - val_loss: 0.1242 - val_accuracy: 0.9125 - val_auc_47: 0.9913 - val_precision_47: 0.8795 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00061: val_loss did not improve from 0.10736
# Epoch 62/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1132 - accuracy: 0.9327 - auc_47: 0.9930 - precision_47: 0.9307 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9000 - val_auc_47: 0.9905 - val_precision_47: 0.8690 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00062: val_loss did not improve from 0.10736
# Epoch 63/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1223 - accuracy: 0.9006 - auc_47: 0.9909 - precision_47: 0.8988 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1192 - val_accuracy: 0.9125 - val_auc_47: 0.9920 - val_precision_47: 0.8902 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00063: val_loss did not improve from 0.10736
# Epoch 64/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1196 - accuracy: 0.9193 - auc_47: 0.9907 - precision_47: 0.9246 - precision_at_recall_38: 0.9999 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9125 - val_auc_47: 0.9908 - val_precision_47: 0.8795 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00064: val_loss did not improve from 0.10736
# Epoch 65/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1097 - accuracy: 0.9267 - auc_47: 0.9939 - precision_47: 0.9213 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1195 - val_accuracy: 0.9125 - val_auc_47: 0.9917 - val_precision_47: 0.8690 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00065: val_loss did not improve from 0.10736
# Epoch 66/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1157 - accuracy: 0.9150 - auc_47: 0.9921 - precision_47: 0.9263 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9125 - val_auc_47: 0.9924 - val_precision_47: 0.8916 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00066: val_loss did not improve from 0.10736
# Epoch 67/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1074 - accuracy: 0.9301 - auc_47: 0.9938 - precision_47: 0.9311 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1105 - val_accuracy: 0.9375 - val_auc_47: 0.9937 - val_precision_47: 0.8916 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00067: val_loss did not improve from 0.10736
# Epoch 68/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1059 - accuracy: 0.9300 - auc_47: 0.9941 - precision_47: 0.9216 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1111 - val_accuracy: 0.9375 - val_auc_47: 0.9932 - val_precision_47: 0.8916 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00068: val_loss did not improve from 0.10736
# Epoch 69/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1311 - accuracy: 0.9095 - auc_47: 0.9888 - precision_47: 0.9091 - precision_at_recall_38: 0.9932 - specificity_at_sensitivity_35: 0.9986 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1048 - val_accuracy: 0.9250 - val_auc_47: 0.9949 - val_precision_47: 0.9024 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00069: val_loss improved from 0.10736 to 0.10484, saving model to subjek1CNN.h5
# Epoch 70/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1081 - accuracy: 0.9237 - auc_47: 0.9937 - precision_47: 0.9262 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1057 - val_accuracy: 0.9250 - val_auc_47: 0.9943 - val_precision_47: 0.9024 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00070: val_loss did not improve from 0.10484
# Epoch 71/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1217 - accuracy: 0.9157 - auc_47: 0.9911 - precision_47: 0.9060 - precision_at_recall_38: 0.9972 - specificity_at_sensitivity_35: 0.9993 - sensitivity_at_specificity_29: 0.9995 - val_loss: 0.1095 - val_accuracy: 0.9250 - val_auc_47: 0.9939 - val_precision_47: 0.9024 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00071: val_loss did not improve from 0.10484
# Epoch 72/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1078 - accuracy: 0.9291 - auc_47: 0.9932 - precision_47: 0.9276 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9125 - val_auc_47: 0.9936 - val_precision_47: 0.9012 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00072: val_loss did not improve from 0.10484
# Epoch 73/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1355 - accuracy: 0.8908 - auc_47: 0.9868 - precision_47: 0.8919 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 0.9996 - val_loss: 0.1046 - val_accuracy: 0.9125 - val_auc_47: 0.9947 - val_precision_47: 0.9125 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00073: val_loss improved from 0.10484 to 0.10462, saving model to subjek1CNN.h5
# Epoch 74/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1076 - accuracy: 0.9138 - auc_47: 0.9932 - precision_47: 0.9280 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1028 - val_accuracy: 0.9125 - val_auc_47: 0.9949 - val_precision_47: 0.9012 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00074: val_loss improved from 0.10462 to 0.10284, saving model to subjek1CNN.h5
# Epoch 75/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0969 - accuracy: 0.9382 - auc_47: 0.9949 - precision_47: 0.9418 - precision_at_recall_38: 0.9971 - specificity_at_sensitivity_35: 0.9994 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1053 - val_accuracy: 0.9250 - val_auc_47: 0.9935 - val_precision_47: 0.9036 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00075: val_loss did not improve from 0.10284
# Epoch 76/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0999 - accuracy: 0.9368 - auc_47: 0.9950 - precision_47: 0.9394 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.0976 - val_accuracy: 0.9125 - val_auc_47: 0.9957 - val_precision_47: 0.9024 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00076: val_loss improved from 0.10284 to 0.09761, saving model to subjek1CNN.h5
# Epoch 77/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0921 - accuracy: 0.9423 - auc_47: 0.9962 - precision_47: 0.9563 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1010 - val_accuracy: 0.9125 - val_auc_47: 0.9953 - val_precision_47: 0.9146 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00077: val_loss did not improve from 0.09761
# Epoch 78/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1054 - accuracy: 0.9306 - auc_47: 0.9931 - precision_47: 0.9308 - precision_at_recall_38: 0.9957 - specificity_at_sensitivity_35: 0.9991 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9125 - val_auc_47: 0.9952 - val_precision_47: 0.9036 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00078: val_loss did not improve from 0.09761
# Epoch 79/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0957 - accuracy: 0.9478 - auc_47: 0.9951 - precision_47: 0.9403 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1057 - val_accuracy: 0.9125 - val_auc_47: 0.9941 - val_precision_47: 0.9024 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00079: val_loss did not improve from 0.09761
# Epoch 80/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0926 - accuracy: 0.9390 - auc_47: 0.9955 - precision_47: 0.9462 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1083 - val_accuracy: 0.9125 - val_auc_47: 0.9929 - val_precision_47: 0.8810 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00080: val_loss did not improve from 0.09761
# Epoch 81/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0965 - accuracy: 0.9349 - auc_47: 0.9953 - precision_47: 0.9283 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1015 - val_accuracy: 0.9125 - val_auc_47: 0.9943 - val_precision_47: 0.9036 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00081: val_loss did not improve from 0.09761
# Epoch 82/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1038 - accuracy: 0.9476 - auc_47: 0.9944 - precision_47: 0.9369 - precision_at_recall_38: 0.9985 - specificity_at_sensitivity_35: 0.9997 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1020 - val_accuracy: 0.9250 - val_auc_47: 0.9944 - val_precision_47: 0.9024 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00082: val_loss did not improve from 0.09761
# Epoch 83/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1005 - accuracy: 0.9267 - auc_47: 0.9938 - precision_47: 0.9355 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.0985 - val_accuracy: 0.9125 - val_auc_47: 0.9948 - val_precision_47: 0.9024 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00083: val_loss did not improve from 0.09761
# Epoch 84/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0986 - accuracy: 0.9420 - auc_47: 0.9945 - precision_47: 0.9492 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.1029 - val_accuracy: 0.9375 - val_auc_47: 0.9938 - val_precision_47: 0.9024 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00084: val_loss did not improve from 0.09761
# Epoch 85/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0937 - accuracy: 0.9484 - auc_47: 0.9952 - precision_47: 0.9358 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9125 - val_auc_47: 0.9955 - val_precision_47: 0.9136 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00085: val_loss improved from 0.09761 to 0.09636, saving model to subjek1CNN.h5
# Epoch 86/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0903 - accuracy: 0.9596 - auc_47: 0.9959 - precision_47: 0.9585 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000 - val_loss: 0.0944 - val_accuracy: 0.9250 - val_auc_47: 0.9955 - val_precision_47: 0.9024 - val_precision_at_recall_38: 1.0000 - val_specificity_at_sensitivity_35: 1.0000 - val_sensitivity_at_specificity_29: 1.0000
#
# Epoch 00086: val_loss improved from 0.09636 to 0.09440, saving model to subjek1CNN.h5
# Epoch 00086: early stopping
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0736 - accuracy: 0.9650 - auc_47: 0.9974 - precision_47: 0.9646 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000
# Val Score:  [0.07363865524530411, 0.9649999737739563, 0.9974417090415955, 0.9646464586257935, 1.0, 1.0, 1.0]
# ====================================================================================

# %%
print("data train x",t_x.shape)
print("data train y",t_y.shape)

print("data tes x",val_x.shape)
print("data tes y",val_y.shape)

model = load_model('subjek1CNN.h5')
#model.evaluate(val_x, val_y)
a = model.evaluate(val_x, val_y)
print('loss',a[0])
print('Accuracy',a[1])
print('AUC',a[2])
print('precision',a[3])
print('recall',a[4])
print('specificity_at_sensitivity',a[5])
print('sensitivity_at_specificity',a[6])
# Out:
# data train x (800, 8, 60, 1)
# data train y (800, 4)
# data tes x (200, 8, 60, 1)
# data tes y (200, 4)
# 7/7 [==============================] - 1s 6ms/step - loss: 0.0736 - accuracy: 0.9650 - auc_47: 0.9974 - precision_47: 0.9646 - precision_at_recall_38: 1.0000 - specificity_at_sensitivity_35: 1.0000 - sensitivity_at_specificity_29: 1.0000
# loss 0.07363865524530411
# Accuracy 0.9649999737739563
# AUC 0.9974417090415955
# precision 0.9646464586257935
# recall 1.0
# specificity_at_sensitivity 1.0
# sensitivity_at_specificity 1.0

# %%
fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)
ax1.plot(model_history[0].history['accuracy'], label='Training Fold 1 accuration')
ax1.plot(model_history[1].history['accuracy'], label='Training Fold 2 accuration')
ax1.plot(model_history[2].history['accuracy'], label='Training Fold 3 accuration')
ax1.plot(model_history[3].history['accuracy'], label='Training Fold 4 accuration')
ax1.plot(model_history[4].history['accuracy'], label='Training Fold 5 accuration')
ax1.legend()
ax2.plot(model_history[1].history['loss'], label='Training Fold 1 loss')
ax2.plot(model_history[1].history['loss'], label='Training Fold 2 loss')
ax2.plot(model_history[2].history['loss'], label='Training Fold 3 loss')
ax2.plot(model_history[3].history['loss'], label='Training Fold 4 loss ')
ax2.plot(model_history[4].history['loss'], label='Training Fold 5 loss')
ax2.legend()
plt.show()

# %%
fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt1.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[0].history['loss'], label='Train Loss Fold 1', color='black')
plt2.plot(model_history[0].history['val_loss'], label='Val Loss Fold 1', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red')
plt1.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[1].history['loss'], label='Train Loss Fold 2', color='red')
plt2.plot(model_history[1].history['val_loss'], label='Val Loss Fold 2', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green')
plt1.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[2].history['loss'], label='Train Loss Fold 3', color='green')
plt2.plot(model_history[2].history['val_loss'], label='Val Loss Fold 3', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()


fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue')
plt1.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[3].history['loss'], label='Train Loss Fold 4', color='blue')
plt2.plot(model_history[3].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='purple')
plt1.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[4].history['loss'], label='Train Loss Fold 4', color='purple')
plt2.plot(model_history[4].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

# %%
MODEL_NAME ='/content/subjek1CNN.h5' 

#CLIP = True # if your model was trained with np.clip to clip  values
CLIP = False
CLIP_VAL = 8  # if above, what was the value +/-

model = tf.keras.models.load_model(MODEL_NAME)

VALDIR = '/content/drive/MyDrive/Colab Notebooks/data8'
ACTIONS =  ["idle","maju","kiri", "kanan"]
PRED_BATCH = 32


def get_val_data(valdir, action, batch_size):

   # argmax_dict = {0: 0, 1: 0, 2: 0,3:0}
    argmax_dict = {2: 0, 0: 0, 1: 0,3:0}
    raw_pred_dict = {0: 0, 1: 0, 2: 0,3:0}

    action_dir = os.path.join(valdir, action)
    for session_file in os.listdir(action_dir):
        filepath = os.path.join(action_dir,session_file)
        if CLIP:
            data = np.clip(np.load(filepath), -CLIP_VAL, CLIP_VAL) / CLIP_VAL
            #print(data)
        else:
            data = np.load(filepath) 
        preds = model.predict([data.reshape(-1, 8, 60,1)], batch_size=batch_size)
        
        for pred in preds:
            argmax = np.argmax(pred)
            argmax_dict[argmax] += 1
            for idx,value in enumerate(pred):
                raw_pred_dict[idx] += value
    
    argmax_pct_dict = {}
    for i in argmax_dict:
        total = 0
        correct = argmax_dict[i]
        for ii in argmax_dict:
            total += argmax_dict[ii]
        argmax_pct_dict[i] = round(correct/total, 4)
    return argmax_dict, raw_pred_dict, argmax_pct_dict


def make_conf_mat(none,left,forward, right):
    action_dict = {"idle":none,"maju": forward, "kiri": left, "kanan": right}
    action_conf_mat = pd.DataFrame(action_dict)
    actions = [i for i in action_dict]

    fig = plt.figure(figsize=(15, 6))
    ax = fig.add_subplot(111)
    ax.matshow(action_conf_mat, cmap=plt.cm.RdYlGn)
    ax.set_xticklabels([""]+actions)
    ax.set_yticklabels([""]+actions)

    for idx, i in enumerate(action_dict):
        for idx2, ii in enumerate(action_dict[i]):
            ax.text(idx, idx2, f"{round(float(action_dict[i][ii]),2)}", va='center', ha='center')
    # Rotate the tick labels and set their alignment.
    
    plt.title("Matrik data")
    plt.ylabel("Predicted Action")
    fig.tight_layout()
    plt.show()



forward_argmax_dict, forward_raw_pred_dict, forward_argmax_pct_dict = get_val_data(VALDIR, "maju", PRED_BATCH)
none_argmax_dict, none_raw_pred_dict, none_argmax_pct_dict = get_val_data(VALDIR, "idle", PRED_BATCH)
left_argmax_dict, left_raw_pred_dict, left_argmax_pct_dict = get_val_data(VALDIR, "kiri", PRED_BATCH)
right_argmax_dict, right_raw_pred_dict, right_argmax_pct_dict = get_val_data(VALDIR, "kanan", PRED_BATCH)
make_conf_mat(none_argmax_pct_dict,forward_argmax_pct_dict,left_argmax_pct_dict,  right_argmax_pct_dict)

# %%
x_train,x_test,y_train,y_test=train_test_split(train_X,train_y,test_size=0.2)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (800, 8, 60, 1)
# (200, 8, 60, 1)
# (800, 4)
# (200, 4)

# %%
from sklearn.metrics import roc_curve, auc

#y_score = clf.decision_function(xval)
y_score = model.predict(x_test)

#Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()


# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
    
    
print("roc_auc:",sum(roc_auc.values())/4)
ACTIONS =  ["idle","maju","kiri", "kanan"]
for i in range(0,4):
    plt.figure()
    fig, ax = plt.subplots(figsize=(10,10))
    plt.plot(fpr[i], tpr[i],linewidth=3)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    #plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % ACTIONS[i])
    plt.title('%s -ROC curve (area = %0.2f)' % (ACTIONS[i],roc_auc[i]))
    
    plt.legend(loc="lower right")
    plt.show()
# Out:
# roc_auc: 0.9998999388929616

# %% [markdown]
# # LSTM

# %%
def lstm_model():
  model2 = Sequential()

  model2.add(LSTM(64,input_shape = (train2_X.shape[1:]), return_sequences=True))
  #model2.add(Dropout(0.5))
  #model2.add(MaxPooling2D(pool_size = (4,4)))
  model2.add(Dropout(0.2))
  model2.add(BatchNormalization())

  model2.add(LSTM(64,input_shape = (train2_X.shape[1:]), return_sequences=True))
  #model2.add(Dropout(0.5))
  #model2.add(MaxPooling2D(pool_size = (2,2)))
  model2.add(Dropout(0.2))
  model2.add(BatchNormalization())

  model2.add(LSTM(64,input_shape = (train2_X.shape[1:]), return_sequences=True))
  #model2.add(Dropout(0.5))
  #model2.add(MaxPooling2D(pool_size = (1,1)))
  model2.add(Dropout(0.2))
  model2.add(BatchNormalization())
 
  model2.add(LSTM(64))

  model.add(Flatten())
    
  model2.add(Dense(32, activation = "relu"))
  model2.add(BatchNormalization())

  model2.add(Dense(4, activation='sigmoid'))

   
    #adam = Adam(lr = 0.001)
  model2.compile(optimizer ="adam", loss = "binary_crossentropy", 
                  metrics = ['accuracy',tf.keras.metrics.AUC(),
                             tf.keras.metrics.Precision(),
                             tf.keras.metrics.PrecisionAtRecall(0.5),
                             tf.keras.metrics.SpecificityAtSensitivity(0.5),
                             tf.keras.metrics.SensitivityAtSpecificity(0.5)

                             ])

  return model2

# %%
model = lstm_model()
model.summary()
# Out:
# Model: "sequential_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_24 (LSTM)               (None, 8, 64)             32000
# _________________________________________________________________
# dropout_126 (Dropout)        (None, 8, 64)             0
# _________________________________________________________________
# batch_normalization_168 (Bat (None, 8, 64)             256
# _________________________________________________________________
# lstm_25 (LSTM)               (None, 8, 64)             33024
# _________________________________________________________________
# dropout_127 (Dropout)        (None, 8, 64)             0
# _________________________________________________________________
# batch_normalization_169 (Bat (None, 8, 64)             256
# _________________________________________________________________
# lstm_26 (LSTM)               (None, 8, 64)             33024
# _________________________________________________________________
# dropout_128 (Dropout)        (None, 8, 64)             0
# _________________________________________________________________
# batch_normalization_170 (Bat (None, 8, 64)             256
# _________________________________________________________________
# lstm_27 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dense_84 (Dense)             (None, 32)                2080
# _________________________________________________________________
# batch_normalization_171 (Bat (None, 32)                128
# _________________________________________________________________
# dense_85 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 134,180
# Trainable params: 133,732
# Non-trainable params: 448
# _________________________________________________________________

# %%
#set early stopping criteria
pat = 5
#this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='loss', patience=pat, verbose=1)

#define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('subjek1LSTM.h5', verbose=1, save_best_only=True)

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=100, BATCH_SIZE=32):
    model = None
    model = lstm_model() 
    results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[learning_rate_reduction,early_stopping, model_checkpoint], 
              verbose=1, validation_split=0.1)   
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs=100
batch_size=32

#save the model history in a list after fitting so that we can plot later
model_history = [] 
for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(train2_X, train_y, test_size=0.2, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
   
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 23/23 [==============================] - 9s 157ms/step - loss: 0.7463 - accuracy: 0.4227 - auc_31: 0.6345 - precision_31: 0.3208 - precision_at_recall_22: 0.3770 - specificity_at_sensitivity_19: 0.6934 - sensitivity_at_specificity_13: 0.6572 - val_loss: 0.6729 - val_accuracy: 0.1875 - val_auc_31: 0.6133 - val_precision_31: 0.0000e+00 - val_precision_at_recall_22: 0.3200 - val_specificity_at_sensitivity_19: 0.6458 - val_sensitivity_at_specificity_13: 0.5000
#
# Epoch 00001: val_loss improved from inf to 0.67290, saving model to subjek1LSTM.h5
# Epoch 2/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.5243 - accuracy: 0.6496 - auc_31: 0.8659 - precision_31: 0.5058 - precision_at_recall_22: 0.6853 - specificity_at_sensitivity_19: 0.9211 - sensitivity_at_specificity_13: 0.9544 - val_loss: 0.6552 - val_accuracy: 0.2500 - val_auc_31: 0.6136 - val_precision_31: 0.0000e+00 - val_precision_at_recall_22: 0.3163 - val_specificity_at_sensitivity_19: 0.5375 - val_sensitivity_at_specificity_13: 0.5875
#
# Epoch 00002: val_loss improved from 0.67290 to 0.65516, saving model to subjek1LSTM.h5
# Epoch 3/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.4742 - accuracy: 0.6723 - auc_31: 0.8886 - precision_31: 0.5555 - precision_at_recall_22: 0.7828 - specificity_at_sensitivity_19: 0.9515 - sensitivity_at_specificity_13: 0.9686 - val_loss: 0.6363 - val_accuracy: 0.2750 - val_auc_31: 0.6588 - val_precision_31: 1.0000 - val_precision_at_recall_22: 0.3284 - val_specificity_at_sensitivity_19: 0.6250 - val_sensitivity_at_specificity_13: 0.6125
#
# Epoch 00003: val_loss improved from 0.65516 to 0.63629, saving model to subjek1LSTM.h5
# Epoch 4/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.4011 - accuracy: 0.7415 - auc_31: 0.9317 - precision_31: 0.6324 - precision_at_recall_22: 0.8584 - specificity_at_sensitivity_19: 0.9718 - sensitivity_at_specificity_13: 0.9905 - val_loss: 0.6130 - val_accuracy: 0.3375 - val_auc_31: 0.7089 - val_precision_31: 1.0000 - val_precision_at_recall_22: 0.3644 - val_specificity_at_sensitivity_19: 0.6875 - val_sensitivity_at_specificity_13: 0.6750
#
# Epoch 00004: val_loss improved from 0.63629 to 0.61296, saving model to subjek1LSTM.h5
# Epoch 5/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.3561 - accuracy: 0.7901 - auc_31: 0.9489 - precision_31: 0.6504 - precision_at_recall_22: 0.9411 - specificity_at_sensitivity_19: 0.9894 - sensitivity_at_specificity_13: 0.9885 - val_loss: 0.5892 - val_accuracy: 0.4125 - val_auc_31: 0.7420 - val_precision_31: 1.0000 - val_precision_at_recall_22: 0.4356 - val_specificity_at_sensitivity_19: 0.7625 - val_sensitivity_at_specificity_13: 0.8250
#
# Epoch 00005: val_loss improved from 0.61296 to 0.58916, saving model to subjek1LSTM.h5
# Epoch 6/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.3152 - accuracy: 0.8035 - auc_31: 0.9586 - precision_31: 0.6883 - precision_at_recall_22: 0.9734 - specificity_at_sensitivity_19: 0.9953 - sensitivity_at_specificity_13: 0.9917 - val_loss: 0.5601 - val_accuracy: 0.5500 - val_auc_31: 0.8184 - val_precision_31: 0.8667 - val_precision_at_recall_22: 0.6027 - val_specificity_at_sensitivity_19: 0.8792 - val_sensitivity_at_specificity_13: 0.9125
#
# Epoch 00006: val_loss improved from 0.58916 to 0.56006, saving model to subjek1LSTM.h5
# Epoch 7/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.2977 - accuracy: 0.8032 - auc_31: 0.9621 - precision_31: 0.7309 - precision_at_recall_22: 0.9447 - specificity_at_sensitivity_19: 0.9898 - sensitivity_at_specificity_13: 0.9967 - val_loss: 0.5258 - val_accuracy: 0.6375 - val_auc_31: 0.8628 - val_precision_31: 0.8947 - val_precision_at_recall_22: 0.6721 - val_specificity_at_sensitivity_19: 0.9167 - val_sensitivity_at_specificity_13: 0.9500
#
# Epoch 00007: val_loss improved from 0.56006 to 0.52577, saving model to subjek1LSTM.h5
# Epoch 8/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.2477 - accuracy: 0.8779 - auc_31: 0.9759 - precision_31: 0.8109 - precision_at_recall_22: 0.9927 - specificity_at_sensitivity_19: 0.9987 - sensitivity_at_specificity_13: 0.9949 - val_loss: 0.4908 - val_accuracy: 0.6625 - val_auc_31: 0.8647 - val_precision_31: 0.8000 - val_precision_at_recall_22: 0.7547 - val_specificity_at_sensitivity_19: 0.9458 - val_sensitivity_at_specificity_13: 0.9500
#
# Epoch 00008: val_loss improved from 0.52577 to 0.49081, saving model to subjek1LSTM.h5
# Epoch 9/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.2296 - accuracy: 0.8765 - auc_31: 0.9802 - precision_31: 0.7972 - precision_at_recall_22: 0.9921 - specificity_at_sensitivity_19: 0.9986 - sensitivity_at_specificity_13: 0.9987 - val_loss: 0.4091 - val_accuracy: 0.7875 - val_auc_31: 0.9515 - val_precision_31: 0.8448 - val_precision_at_recall_22: 0.9767 - val_specificity_at_sensitivity_19: 0.9958 - val_sensitivity_at_specificity_13: 0.9875
#
# Epoch 00009: val_loss improved from 0.49081 to 0.40912, saving model to subjek1LSTM.h5
# Epoch 10/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.2072 - accuracy: 0.8763 - auc_31: 0.9832 - precision_31: 0.8231 - precision_at_recall_22: 0.9902 - specificity_at_sensitivity_19: 0.9982 - sensitivity_at_specificity_13: 0.9997 - val_loss: 0.3658 - val_accuracy: 0.8375 - val_auc_31: 0.9464 - val_precision_31: 0.8462 - val_precision_at_recall_22: 0.8868 - val_specificity_at_sensitivity_19: 0.9750 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00010: val_loss improved from 0.40912 to 0.36581, saving model to subjek1LSTM.h5
# Epoch 11/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.1910 - accuracy: 0.8856 - auc_31: 0.9848 - precision_31: 0.8336 - precision_at_recall_22: 0.9956 - specificity_at_sensitivity_19: 0.9992 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.3085 - val_accuracy: 0.8500 - val_auc_31: 0.9661 - val_precision_31: 0.8732 - val_precision_at_recall_22: 0.9545 - val_specificity_at_sensitivity_19: 0.9917 - val_sensitivity_at_specificity_13: 0.9875
#
# Epoch 00011: val_loss improved from 0.36581 to 0.30847, saving model to subjek1LSTM.h5
# Epoch 12/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.1679 - accuracy: 0.8905 - auc_31: 0.9893 - precision_31: 0.8598 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.2601 - val_accuracy: 0.8250 - val_auc_31: 0.9720 - val_precision_31: 0.8684 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 0.9875
#
# Epoch 00012: val_loss improved from 0.30847 to 0.26012, saving model to subjek1LSTM.h5
# Epoch 13/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.1361 - accuracy: 0.9284 - auc_31: 0.9932 - precision_31: 0.9179 - precision_at_recall_22: 0.9996 - specificity_at_sensitivity_19: 0.9999 - sensitivity_at_specificity_13: 0.9976 - val_loss: 0.2266 - val_accuracy: 0.8250 - val_auc_31: 0.9724 - val_precision_31: 0.8312 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00013: val_loss improved from 0.26012 to 0.22659, saving model to subjek1LSTM.h5
# Epoch 14/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.1345 - accuracy: 0.9279 - auc_31: 0.9900 - precision_31: 0.9045 - precision_at_recall_22: 0.9975 - specificity_at_sensitivity_19: 0.9995 - sensitivity_at_specificity_13: 0.9981 - val_loss: 0.1916 - val_accuracy: 0.8750 - val_auc_31: 0.9776 - val_precision_31: 0.8947 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00014: val_loss improved from 0.22659 to 0.19163, saving model to subjek1LSTM.h5
# Epoch 15/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.1322 - accuracy: 0.9338 - auc_31: 0.9884 - precision_31: 0.9175 - precision_at_recall_22: 0.9961 - specificity_at_sensitivity_19: 0.9993 - sensitivity_at_specificity_13: 0.9955 - val_loss: 0.1808 - val_accuracy: 0.8375 - val_auc_31: 0.9799 - val_precision_31: 0.8276 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00015: val_loss improved from 0.19163 to 0.18078, saving model to subjek1LSTM.h5
# Epoch 16/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.1153 - accuracy: 0.9442 - auc_31: 0.9936 - precision_31: 0.9352 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.1187 - val_accuracy: 0.9500 - val_auc_31: 0.9955 - val_precision_31: 0.8966 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00016: val_loss improved from 0.18078 to 0.11870, saving model to subjek1LSTM.h5
# Epoch 17/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.1180 - accuracy: 0.9330 - auc_31: 0.9920 - precision_31: 0.9179 - precision_at_recall_22: 0.9967 - specificity_at_sensitivity_19: 0.9994 - sensitivity_at_specificity_13: 0.9991 - val_loss: 0.1045 - val_accuracy: 0.9500 - val_auc_31: 0.9951 - val_precision_31: 0.9615 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00017: val_loss improved from 0.11870 to 0.10450, saving model to subjek1LSTM.h5
# Epoch 18/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0874 - accuracy: 0.9608 - auc_31: 0.9971 - precision_31: 0.9510 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9500 - val_auc_31: 0.9926 - val_precision_31: 0.9383 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00018: val_loss improved from 0.10450 to 0.09271, saving model to subjek1LSTM.h5
# Epoch 19/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0994 - accuracy: 0.9415 - auc_31: 0.9941 - precision_31: 0.9336 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 0.9986 - val_loss: 0.0839 - val_accuracy: 0.9750 - val_auc_31: 0.9956 - val_precision_31: 0.9506 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00019: val_loss improved from 0.09271 to 0.08394, saving model to subjek1LSTM.h5
# Epoch 20/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0864 - accuracy: 0.9380 - auc_31: 0.9946 - precision_31: 0.9326 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 0.9975 - val_loss: 0.0873 - val_accuracy: 0.9375 - val_auc_31: 0.9960 - val_precision_31: 0.9375 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00020: val_loss did not improve from 0.08394
# Epoch 21/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0726 - accuracy: 0.9673 - auc_31: 0.9974 - precision_31: 0.9659 - precision_at_recall_22: 0.9996 - specificity_at_sensitivity_19: 0.9999 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0504 - val_accuracy: 0.9750 - val_auc_31: 0.9995 - val_precision_31: 0.9753 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00021: val_loss improved from 0.08394 to 0.05044, saving model to subjek1LSTM.h5
# Epoch 22/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0865 - accuracy: 0.9691 - auc_31: 0.9914 - precision_31: 0.9598 - precision_at_recall_22: 0.9919 - specificity_at_sensitivity_19: 0.9978 - sensitivity_at_specificity_13: 0.9951 - val_loss: 0.0577 - val_accuracy: 0.9750 - val_auc_31: 0.9988 - val_precision_31: 0.9506 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00022: val_loss did not improve from 0.05044
# Epoch 23/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0567 - accuracy: 0.9768 - auc_31: 0.9975 - precision_31: 0.9711 - precision_at_recall_22: 0.9981 - specificity_at_sensitivity_19: 0.9997 - sensitivity_at_specificity_13: 0.9995 - val_loss: 0.0301 - val_accuracy: 1.0000 - val_auc_31: 0.9999 - val_precision_31: 0.9875 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00023: val_loss improved from 0.05044 to 0.03009, saving model to subjek1LSTM.h5
# Epoch 24/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0536 - accuracy: 0.9771 - auc_31: 0.9989 - precision_31: 0.9748 - precision_at_recall_22: 0.9994 - specificity_at_sensitivity_19: 0.9999 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9750 - val_auc_31: 0.9992 - val_precision_31: 0.9750 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00024: val_loss did not improve from 0.03009
# Epoch 25/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0588 - accuracy: 0.9702 - auc_31: 0.9967 - precision_31: 0.9675 - precision_at_recall_22: 0.9969 - specificity_at_sensitivity_19: 0.9992 - sensitivity_at_specificity_13: 0.9975 - val_loss: 0.0431 - val_accuracy: 0.9625 - val_auc_31: 0.9991 - val_precision_31: 0.9506 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00025: val_loss did not improve from 0.03009
# Epoch 26/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0462 - accuracy: 0.9762 - auc_31: 0.9991 - precision_31: 0.9736 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0836 - val_accuracy: 0.9125 - val_auc_31: 0.9959 - val_precision_31: 0.9241 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00026: val_loss did not improve from 0.03009
# Epoch 27/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0702 - accuracy: 0.9564 - auc_31: 0.9955 - precision_31: 0.9588 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 0.9979 - val_loss: 0.0420 - val_accuracy: 0.9750 - val_auc_31: 0.9993 - val_precision_31: 0.9512 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00027: val_loss did not improve from 0.03009
# Epoch 28/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0390 - accuracy: 0.9835 - auc_31: 0.9988 - precision_31: 0.9819 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9500 - val_auc_31: 0.9977 - val_precision_31: 0.9390 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00028: val_loss did not improve from 0.03009
# Epoch 29/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0386 - accuracy: 0.9850 - auc_31: 0.9994 - precision_31: 0.9818 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9625 - val_auc_31: 0.9992 - val_precision_31: 0.9512 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00029: val_loss did not improve from 0.03009
# Epoch 30/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0258 - accuracy: 0.9966 - auc_31: 0.9994 - precision_31: 0.9970 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 0.9991 - val_loss: 0.0356 - val_accuracy: 0.9625 - val_auc_31: 0.9994 - val_precision_31: 0.9630 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00030: val_loss did not improve from 0.03009
# Epoch 31/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0254 - accuracy: 0.9956 - auc_31: 0.9996 - precision_31: 0.9950 - precision_at_recall_22: 0.9992 - specificity_at_sensitivity_19: 0.9998 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9875 - val_auc_31: 0.9998 - val_precision_31: 0.9634 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00031: val_loss improved from 0.03009 to 0.02388, saving model to subjek1LSTM.h5
# Epoch 32/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0368 - accuracy: 0.9866 - auc_31: 0.9992 - precision_31: 0.9847 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9750 - val_auc_31: 0.9993 - val_precision_31: 0.9630 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00032: val_loss did not improve from 0.02388
# Epoch 33/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0244 - accuracy: 0.9905 - auc_31: 0.9998 - precision_31: 0.9893 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 0.9999 - val_loss: 0.0439 - val_accuracy: 0.9750 - val_auc_31: 0.9991 - val_precision_31: 0.9750 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00033: val_loss did not improve from 0.02388
# Epoch 34/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0351 - accuracy: 0.9804 - auc_31: 0.9992 - precision_31: 0.9737 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 0.9996 - val_loss: 0.0270 - val_accuracy: 0.9875 - val_auc_31: 0.9997 - val_precision_31: 0.9753 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00034: val_loss did not improve from 0.02388
# Epoch 35/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0259 - accuracy: 0.9891 - auc_31: 0.9998 - precision_31: 0.9895 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9750 - val_auc_31: 0.9992 - val_precision_31: 0.9512 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00035: val_loss did not improve from 0.02388
# Epoch 36/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0280 - accuracy: 0.9916 - auc_31: 0.9991 - precision_31: 0.9880 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9875 - val_auc_31: 0.9996 - val_precision_31: 0.9875 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00036: val_loss did not improve from 0.02388
# Epoch 37/100
# 23/23 [==============================] - 1s 25ms/step - loss: 0.0244 - accuracy: 0.9906 - auc_31: 0.9999 - precision_31: 0.9909 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9875 - val_auc_31: 0.9997 - val_precision_31: 0.9875 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00037: val_loss did not improve from 0.02388
# Epoch 38/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0299 - accuracy: 0.9873 - auc_31: 0.9992 - precision_31: 0.9826 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0181 - val_accuracy: 0.9875 - val_auc_31: 0.9998 - val_precision_31: 0.9875 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00038: val_loss improved from 0.02388 to 0.01809, saving model to subjek1LSTM.h5
# Epoch 39/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0263 - accuracy: 0.9900 - auc_31: 0.9998 - precision_31: 0.9900 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9875 - val_auc_31: 0.9999 - val_precision_31: 0.9753 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00039: val_loss did not improve from 0.01809
# Epoch 40/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0207 - accuracy: 0.9954 - auc_31: 0.9999 - precision_31: 0.9954 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9875 - val_auc_31: 0.9999 - val_precision_31: 0.9753 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00040: val_loss improved from 0.01809 to 0.01804, saving model to subjek1LSTM.h5
# Epoch 41/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0200 - accuracy: 0.9949 - auc_31: 0.9999 - precision_31: 0.9947 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0184 - val_accuracy: 0.9875 - val_auc_31: 0.9999 - val_precision_31: 0.9875 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00041: val_loss did not improve from 0.01804
# Epoch 42/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0226 - accuracy: 0.9940 - auc_31: 0.9995 - precision_31: 0.9956 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9875 - val_auc_31: 0.9999 - val_precision_31: 0.9875 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00042: val_loss did not improve from 0.01804
# Epoch 43/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0266 - accuracy: 0.9875 - auc_31: 0.9997 - precision_31: 0.9895 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9875 - val_auc_31: 0.9998 - val_precision_31: 0.9753 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00043: val_loss did not improve from 0.01804
# Epoch 44/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0289 - accuracy: 0.9880 - auc_31: 0.9993 - precision_31: 0.9881 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9875 - val_auc_31: 0.9998 - val_precision_31: 0.9753 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00044: val_loss did not improve from 0.01804
# Epoch 45/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0228 - accuracy: 0.9901 - auc_31: 0.9998 - precision_31: 0.9964 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9875 - val_auc_31: 0.9998 - val_precision_31: 0.9753 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00045: val_loss did not improve from 0.01804
# Epoch 46/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0176 - accuracy: 0.9948 - auc_31: 0.9999 - precision_31: 0.9943 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9875 - val_auc_31: 0.9998 - val_precision_31: 0.9875 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00046: val_loss did not improve from 0.01804
# Epoch 47/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0204 - accuracy: 0.9895 - auc_31: 0.9999 - precision_31: 0.9882 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9875 - val_auc_31: 0.9998 - val_precision_31: 0.9753 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00047: val_loss did not improve from 0.01804
# Epoch 48/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0275 - accuracy: 0.9828 - auc_31: 0.9997 - precision_31: 0.9818 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0150 - val_accuracy: 1.0000 - val_auc_31: 0.9999 - val_precision_31: 0.9875 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00048: val_loss improved from 0.01804 to 0.01496, saving model to subjek1LSTM.h5
# Epoch 49/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0202 - accuracy: 0.9929 - auc_31: 0.9997 - precision_31: 0.9929 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0161 - val_accuracy: 0.9875 - val_auc_31: 0.9999 - val_precision_31: 0.9875 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00049: val_loss did not improve from 0.01496
# Epoch 50/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0212 - accuracy: 0.9934 - auc_31: 0.9999 - precision_31: 0.9918 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0156 - val_accuracy: 0.9875 - val_auc_31: 0.9999 - val_precision_31: 0.9875 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00050: val_loss did not improve from 0.01496
# Epoch 51/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0292 - accuracy: 0.9803 - auc_31: 0.9997 - precision_31: 0.9837 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0142 - val_accuracy: 1.0000 - val_auc_31: 1.0000 - val_precision_31: 1.0000 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00051: val_loss improved from 0.01496 to 0.01420, saving model to subjek1LSTM.h5
# Epoch 52/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0222 - accuracy: 0.9881 - auc_31: 0.9999 - precision_31: 0.9882 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000 - val_loss: 0.0267 - val_accuracy: 0.9875 - val_auc_31: 0.9996 - val_precision_31: 0.9753 - val_precision_at_recall_22: 1.0000 - val_specificity_at_sensitivity_19: 1.0000 - val_sensitivity_at_specificity_13: 1.0000
#
# Epoch 00052: val_loss did not improve from 0.01420
# Epoch 00052: early stopping
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0447 - accuracy: 0.9800 - auc_31: 0.9988 - precision_31: 0.9800 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000
# Val Score:  [0.04468861222267151, 0.9800000190734863, 0.9987708926200867, 0.9800000190734863, 1.0, 1.0, 1.0]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
# 23/23 [==============================] - 8s 91ms/step - loss: 0.7300 - accuracy: 0.4121 - auc_32: 0.6450 - precision_32: 0.3357 - precision_at_recall_23: 0.3826 - specificity_at_sensitivity_20: 0.7119 - sensitivity_at_specificity_14: 0.6900 - val_loss: 0.6677 - val_accuracy: 0.2625 - val_auc_32: 0.6168 - val_precision_32: 1.0000 - val_precision_at_recall_23: 0.3505 - val_specificity_at_sensitivity_20: 0.5542 - val_sensitivity_at_specificity_14: 0.5375
#
# Epoch 00001: val_loss did not improve from 0.01420
# Epoch 2/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.5276 - accuracy: 0.6441 - auc_32: 0.8531 - precision_32: 0.4994 - precision_at_recall_23: 0.7329 - specificity_at_sensitivity_20: 0.9379 - sensitivity_at_specificity_14: 0.9172 - val_loss: 0.6446 - val_accuracy: 0.3125 - val_auc_32: 0.6020 - val_precision_32: 0.0000e+00 - val_precision_at_recall_23: 0.3121 - val_specificity_at_sensitivity_20: 0.5500 - val_sensitivity_at_specificity_14: 0.6125
#
# Epoch 00002: val_loss did not improve from 0.01420
# Epoch 3/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.4464 - accuracy: 0.7145 - auc_32: 0.9061 - precision_32: 0.5878 - precision_at_recall_23: 0.8625 - specificity_at_sensitivity_20: 0.9726 - sensitivity_at_specificity_14: 0.9662 - val_loss: 0.6232 - val_accuracy: 0.3875 - val_auc_32: 0.6511 - val_precision_32: 1.0000 - val_precision_at_recall_23: 0.4000 - val_specificity_at_sensitivity_20: 0.7500 - val_sensitivity_at_specificity_14: 0.7000
#
# Epoch 00003: val_loss did not improve from 0.01420
# Epoch 4/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.3774 - accuracy: 0.7948 - auc_32: 0.9435 - precision_32: 0.6497 - precision_at_recall_23: 0.9133 - specificity_at_sensitivity_20: 0.9829 - sensitivity_at_specificity_14: 0.9857 - val_loss: 0.5998 - val_accuracy: 0.3625 - val_auc_32: 0.6714 - val_precision_32: 0.8333 - val_precision_at_recall_23: 0.3913 - val_specificity_at_sensitivity_20: 0.7000 - val_sensitivity_at_specificity_14: 0.7375
#
# Epoch 00004: val_loss did not improve from 0.01420
# Epoch 5/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.3296 - accuracy: 0.7880 - auc_32: 0.9526 - precision_32: 0.6996 - precision_at_recall_23: 0.9712 - specificity_at_sensitivity_20: 0.9949 - sensitivity_at_specificity_14: 0.9867 - val_loss: 0.5715 - val_accuracy: 0.3750 - val_auc_32: 0.7037 - val_precision_32: 1.0000 - val_precision_at_recall_23: 0.4167 - val_specificity_at_sensitivity_20: 0.7333 - val_sensitivity_at_specificity_14: 0.7625
#
# Epoch 00005: val_loss did not improve from 0.01420
# Epoch 6/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.3120 - accuracy: 0.7982 - auc_32: 0.9555 - precision_32: 0.7232 - precision_at_recall_23: 0.9646 - specificity_at_sensitivity_20: 0.9937 - sensitivity_at_specificity_14: 0.9920 - val_loss: 0.5426 - val_accuracy: 0.4875 - val_auc_32: 0.7328 - val_precision_32: 1.0000 - val_precision_at_recall_23: 0.4624 - val_specificity_at_sensitivity_20: 0.7917 - val_sensitivity_at_specificity_14: 0.7625
#
# Epoch 00006: val_loss did not improve from 0.01420
# Epoch 7/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.2502 - accuracy: 0.8572 - auc_32: 0.9769 - precision_32: 0.7883 - precision_at_recall_23: 0.9942 - specificity_at_sensitivity_20: 0.9989 - sensitivity_at_specificity_14: 0.9973 - val_loss: 0.5092 - val_accuracy: 0.5250 - val_auc_32: 0.7752 - val_precision_32: 1.0000 - val_precision_at_recall_23: 0.6119 - val_specificity_at_sensitivity_20: 0.8917 - val_sensitivity_at_specificity_14: 0.7750
#
# Epoch 00007: val_loss did not improve from 0.01420
# Epoch 8/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.2235 - accuracy: 0.8703 - auc_32: 0.9798 - precision_32: 0.8181 - precision_at_recall_23: 0.9927 - specificity_at_sensitivity_20: 0.9987 - sensitivity_at_specificity_14: 0.9998 - val_loss: 0.4610 - val_accuracy: 0.6500 - val_auc_32: 0.8726 - val_precision_32: 0.9091 - val_precision_at_recall_23: 0.6557 - val_specificity_at_sensitivity_20: 0.9125 - val_sensitivity_at_specificity_14: 0.9625
#
# Epoch 00008: val_loss did not improve from 0.01420
# Epoch 9/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.2080 - accuracy: 0.8792 - auc_32: 0.9810 - precision_32: 0.8360 - precision_at_recall_23: 0.9917 - specificity_at_sensitivity_20: 0.9985 - sensitivity_at_specificity_14: 1.0000 - val_loss: 0.4138 - val_accuracy: 0.7125 - val_auc_32: 0.9149 - val_precision_32: 0.9310 - val_precision_at_recall_23: 0.7593 - val_specificity_at_sensitivity_20: 0.9458 - val_sensitivity_at_specificity_14: 1.0000
#
# Epoch 00009: val_loss did not improve from 0.01420
# Epoch 10/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.1890 - accuracy: 0.8652 - auc_32: 0.9820 - precision_32: 0.8443 - precision_at_recall_23: 0.9991 - specificity_at_sensitivity_20: 0.9998 - sensitivity_at_specificity_14: 0.9951 - val_loss: 0.3570 - val_accuracy: 0.7875 - val_auc_32: 0.9339 - val_precision_32: 0.8060 - val_precision_at_recall_23: 0.9038 - val_specificity_at_sensitivity_20: 0.9792 - val_sensitivity_at_specificity_14: 1.0000
#
# Epoch 00010: val_loss did not improve from 0.01420
# Epoch 11/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.1621 - accuracy: 0.9230 - auc_32: 0.9879 - precision_32: 0.8887 - precision_at_recall_23: 0.9930 - specificity_at_sensitivity_20: 0.9987 - sensitivity_at_specificity_14: 0.9998 - val_loss: 0.2809 - val_accuracy: 0.8625 - val_auc_32: 0.9739 - val_precision_32: 0.9206 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 1.0000
#
# Epoch 00011: val_loss did not improve from 0.01420
# Epoch 12/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.1533 - accuracy: 0.9311 - auc_32: 0.9843 - precision_32: 0.9043 - precision_at_recall_23: 0.9832 - specificity_at_sensitivity_20: 0.9963 - sensitivity_at_specificity_14: 0.9886 - val_loss: 0.2698 - val_accuracy: 0.7875 - val_auc_32: 0.9533 - val_precision_32: 0.8356 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 1.0000
#
# Epoch 00012: val_loss did not improve from 0.01420
# Epoch 13/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.1336 - accuracy: 0.9261 - auc_32: 0.9905 - precision_32: 0.9049 - precision_at_recall_23: 0.9957 - specificity_at_sensitivity_20: 0.9991 - sensitivity_at_specificity_14: 0.9985 - val_loss: 0.2112 - val_accuracy: 0.8500 - val_auc_32: 0.9696 - val_precision_32: 0.8553 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 0.9875
#
# Epoch 00013: val_loss did not improve from 0.01420
# Epoch 14/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.1063 - accuracy: 0.9437 - auc_32: 0.9940 - precision_32: 0.9319 - precision_at_recall_23: 0.9996 - specificity_at_sensitivity_20: 0.9999 - sensitivity_at_specificity_14: 0.9966 - val_loss: 0.1656 - val_accuracy: 0.9250 - val_auc_32: 0.9857 - val_precision_32: 0.9333 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 1.0000
#
# Epoch 00014: val_loss did not improve from 0.01420
# Epoch 15/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0966 - accuracy: 0.9387 - auc_32: 0.9967 - precision_32: 0.9280 - precision_at_recall_23: 0.9993 - specificity_at_sensitivity_20: 0.9999 - sensitivity_at_specificity_14: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9500 - val_auc_32: 0.9923 - val_precision_32: 0.9375 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 1.0000
#
# Epoch 00015: val_loss did not improve from 0.01420
# Epoch 16/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.1088 - accuracy: 0.9321 - auc_32: 0.9915 - precision_32: 0.9242 - precision_at_recall_23: 1.0000 - specificity_at_sensitivity_20: 1.0000 - sensitivity_at_specificity_14: 0.9958 - val_loss: 0.1082 - val_accuracy: 0.9125 - val_auc_32: 0.9948 - val_precision_32: 0.9367 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 1.0000
#
# Epoch 00016: val_loss did not improve from 0.01420
# Epoch 17/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0970 - accuracy: 0.9516 - auc_32: 0.9941 - precision_32: 0.9357 - precision_at_recall_23: 0.9981 - specificity_at_sensitivity_20: 0.9995 - sensitivity_at_specificity_14: 0.9986 - val_loss: 0.0808 - val_accuracy: 0.9625 - val_auc_32: 0.9963 - val_precision_32: 0.9625 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 1.0000
#
# Epoch 00017: val_loss did not improve from 0.01420
# Epoch 18/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.1046 - accuracy: 0.9357 - auc_32: 0.9927 - precision_32: 0.9297 - precision_at_recall_23: 0.9962 - specificity_at_sensitivity_20: 0.9992 - sensitivity_at_specificity_14: 0.9989 - val_loss: 0.0895 - val_accuracy: 0.9250 - val_auc_32: 0.9959 - val_precision_32: 0.9259 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 1.0000
#
# Epoch 00018: val_loss did not improve from 0.01420
# Epoch 19/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0978 - accuracy: 0.9334 - auc_32: 0.9949 - precision_32: 0.9273 - precision_at_recall_23: 0.9996 - specificity_at_sensitivity_20: 0.9999 - sensitivity_at_specificity_14: 0.9998 - val_loss: 0.0923 - val_accuracy: 0.9250 - val_auc_32: 0.9955 - val_precision_32: 0.9250 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 1.0000
#
# Epoch 00019: val_loss did not improve from 0.01420
# Epoch 20/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0800 - accuracy: 0.9483 - auc_32: 0.9968 - precision_32: 0.9470 - precision_at_recall_23: 1.0000 - specificity_at_sensitivity_20: 1.0000 - sensitivity_at_specificity_14: 1.0000 - val_loss: 0.0679 - val_accuracy: 0.9625 - val_auc_32: 0.9972 - val_precision_32: 0.9744 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 1.0000
#
# Epoch 00020: val_loss did not improve from 0.01420
# Epoch 21/100
# 23/23 [==============================] - 1s 29ms/step - loss: 0.0813 - accuracy: 0.9514 - auc_32: 0.9959 - precision_32: 0.9603 - precision_at_recall_23: 0.9948 - specificity_at_sensitivity_20: 0.9990 - sensitivity_at_specificity_14: 0.9999 - val_loss: 0.0600 - val_accuracy: 0.9625 - val_auc_32: 0.9983 - val_precision_32: 0.9506 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 1.0000
#
# Epoch 00021: val_loss did not improve from 0.01420
# Epoch 22/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0709 - accuracy: 0.9524 - auc_32: 0.9966 - precision_32: 0.9495 - precision_at_recall_23: 0.9981 - specificity_at_sensitivity_20: 0.9996 - sensitivity_at_specificity_14: 0.9988 - val_loss: 0.0925 - val_accuracy: 0.9250 - val_auc_32: 0.9921 - val_precision_32: 0.9136 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 1.0000
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00022: val_loss did not improve from 0.01420
# Epoch 23/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0535 - accuracy: 0.9857 - auc_32: 0.9986 - precision_32: 0.9791 - precision_at_recall_23: 1.0000 - specificity_at_sensitivity_20: 1.0000 - sensitivity_at_specificity_14: 1.0000 - val_loss: 0.0560 - val_accuracy: 0.9750 - val_auc_32: 0.9986 - val_precision_32: 0.9750 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 1.0000
#
# Epoch 00023: val_loss did not improve from 0.01420
# Epoch 24/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0455 - accuracy: 0.9776 - auc_32: 0.9991 - precision_32: 0.9790 - precision_at_recall_23: 1.0000 - specificity_at_sensitivity_20: 1.0000 - sensitivity_at_specificity_14: 0.9996 - val_loss: 0.0689 - val_accuracy: 0.9750 - val_auc_32: 0.9917 - val_precision_32: 0.9750 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 0.9875
#
# Epoch 00024: val_loss did not improve from 0.01420
# Epoch 25/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0507 - accuracy: 0.9763 - auc_32: 0.9984 - precision_32: 0.9788 - precision_at_recall_23: 0.9994 - specificity_at_sensitivity_20: 0.9999 - sensitivity_at_specificity_14: 0.9993 - val_loss: 0.0563 - val_accuracy: 0.9875 - val_auc_32: 0.9894 - val_precision_32: 0.9875 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 0.9875
#
# Epoch 00025: val_loss did not improve from 0.01420
# Epoch 26/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0429 - accuracy: 0.9815 - auc_32: 0.9994 - precision_32: 0.9775 - precision_at_recall_23: 1.0000 - specificity_at_sensitivity_20: 1.0000 - sensitivity_at_specificity_14: 1.0000 - val_loss: 0.0527 - val_accuracy: 0.9750 - val_auc_32: 0.9941 - val_precision_32: 0.9750 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 0.9875
#
# Epoch 00026: val_loss did not improve from 0.01420
# Epoch 27/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0400 - accuracy: 0.9744 - auc_32: 0.9995 - precision_32: 0.9759 - precision_at_recall_23: 1.0000 - specificity_at_sensitivity_20: 1.0000 - sensitivity_at_specificity_14: 1.0000 - val_loss: 0.0557 - val_accuracy: 0.9750 - val_auc_32: 0.9903 - val_precision_32: 0.9750 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 0.9875
#
# Epoch 00027: val_loss did not improve from 0.01420
# Epoch 28/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0478 - accuracy: 0.9742 - auc_32: 0.9989 - precision_32: 0.9777 - precision_at_recall_23: 1.0000 - specificity_at_sensitivity_20: 1.0000 - sensitivity_at_specificity_14: 1.0000 - val_loss: 0.0589 - val_accuracy: 0.9750 - val_auc_32: 0.9973 - val_precision_32: 0.9750 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 1.0000
#
# Epoch 00028: val_loss did not improve from 0.01420
# Epoch 29/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0328 - accuracy: 0.9906 - auc_32: 0.9998 - precision_32: 0.9925 - precision_at_recall_23: 1.0000 - specificity_at_sensitivity_20: 1.0000 - sensitivity_at_specificity_14: 1.0000 - val_loss: 0.0601 - val_accuracy: 0.9750 - val_auc_32: 0.9906 - val_precision_32: 0.9750 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 0.9875
#
# Epoch 00029: val_loss did not improve from 0.01420
# Epoch 30/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0489 - accuracy: 0.9723 - auc_32: 0.9977 - precision_32: 0.9718 - precision_at_recall_23: 1.0000 - specificity_at_sensitivity_20: 1.0000 - sensitivity_at_specificity_14: 0.9978 - val_loss: 0.0564 - val_accuracy: 0.9750 - val_auc_32: 0.9915 - val_precision_32: 0.9750 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 0.9875
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00030: val_loss did not improve from 0.01420
# Epoch 31/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0387 - accuracy: 0.9822 - auc_32: 0.9977 - precision_32: 0.9821 - precision_at_recall_23: 1.0000 - specificity_at_sensitivity_20: 1.0000 - sensitivity_at_specificity_14: 0.9987 - val_loss: 0.0652 - val_accuracy: 0.9750 - val_auc_32: 0.9910 - val_precision_32: 0.9750 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 0.9875
#
# Epoch 00031: val_loss did not improve from 0.01420
# Epoch 32/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0317 - accuracy: 0.9828 - auc_32: 0.9997 - precision_32: 0.9849 - precision_at_recall_23: 1.0000 - specificity_at_sensitivity_20: 1.0000 - sensitivity_at_specificity_14: 1.0000 - val_loss: 0.0577 - val_accuracy: 0.9750 - val_auc_32: 0.9918 - val_precision_32: 0.9750 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 0.9875
#
# Epoch 00032: val_loss did not improve from 0.01420
# Epoch 33/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0367 - accuracy: 0.9774 - auc_32: 0.9994 - precision_32: 0.9770 - precision_at_recall_23: 1.0000 - specificity_at_sensitivity_20: 1.0000 - sensitivity_at_specificity_14: 1.0000 - val_loss: 0.0634 - val_accuracy: 0.9750 - val_auc_32: 0.9914 - val_precision_32: 0.9750 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 0.9875
#
# Epoch 00033: val_loss did not improve from 0.01420
# Epoch 34/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0255 - accuracy: 0.9866 - auc_32: 0.9999 - precision_32: 0.9898 - precision_at_recall_23: 1.0000 - specificity_at_sensitivity_20: 1.0000 - sensitivity_at_specificity_14: 1.0000 - val_loss: 0.0588 - val_accuracy: 0.9750 - val_auc_32: 0.9918 - val_precision_32: 0.9750 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 0.9875
#
# Epoch 00034: val_loss did not improve from 0.01420
# Epoch 35/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0309 - accuracy: 0.9881 - auc_32: 0.9996 - precision_32: 0.9887 - precision_at_recall_23: 1.0000 - specificity_at_sensitivity_20: 1.0000 - sensitivity_at_specificity_14: 1.0000 - val_loss: 0.0605 - val_accuracy: 0.9750 - val_auc_32: 0.9876 - val_precision_32: 0.9750 - val_precision_at_recall_23: 1.0000 - val_specificity_at_sensitivity_20: 1.0000 - val_sensitivity_at_specificity_14: 0.9875
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00035: val_loss did not improve from 0.01420
# Epoch 36/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0251 - accuracy: 0.9833 - auc_32: 0.9999 - precision_32: 0.9865 - precision_at_recall_23: 1.0000 - specificity_at_sensitivity_20: 1.0000 - sensitivity_at_specificity_14: 1.0000 - val_loss: 0.0584 - val_accuracy: 0.9750 - val_auc_32: 0.9859 - val_precision_32: 0.9750 - val_precision_at_recall_23: 0.9870 - val_specificity_at_sensitivity_20: 0.9958 - val_sensitivity_at_specificity_14: 0.9875
#
# Epoch 00036: val_loss did not improve from 0.01420
# Epoch 37/100
# ...
#
# Epoch 00016: val_loss did not improve from 0.01420
# Epoch 17/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0854 - accuracy: 0.9487 - auc_35: 0.9973 - precision_35: 0.9414 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9000 - val_auc_35: 0.9844 - val_precision_35: 0.9012 - val_precision_at_recall_26: 0.9828 - val_specificity_at_sensitivity_23: 0.9958 - val_sensitivity_at_specificity_17: 0.9875
#
# Epoch 00017: val_loss did not improve from 0.01420
# Epoch 18/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0941 - accuracy: 0.9519 - auc_35: 0.9946 - precision_35: 0.9357 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.1400 - val_accuracy: 0.9125 - val_auc_35: 0.9864 - val_precision_35: 0.9125 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00018: val_loss did not improve from 0.01420
# Epoch 19/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0746 - accuracy: 0.9627 - auc_35: 0.9961 - precision_35: 0.9544 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 0.9981 - val_loss: 0.1198 - val_accuracy: 0.9000 - val_auc_35: 0.9884 - val_precision_35: 0.9136 - val_precision_at_recall_26: 0.9857 - val_specificity_at_sensitivity_23: 0.9958 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00019: val_loss did not improve from 0.01420
# Epoch 20/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0876 - accuracy: 0.9510 - auc_35: 0.9951 - precision_35: 0.9408 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.1320 - val_accuracy: 0.9125 - val_auc_35: 0.9853 - val_precision_35: 0.9012 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00020: val_loss did not improve from 0.01420
# Epoch 21/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0659 - accuracy: 0.9681 - auc_35: 0.9977 - precision_35: 0.9652 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9250 - val_auc_35: 0.9900 - val_precision_35: 0.9487 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00021: val_loss did not improve from 0.01420
# Epoch 22/100
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0739 - accuracy: 0.9629 - auc_35: 0.9967 - precision_35: 0.9574 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9375 - val_auc_35: 0.9934 - val_precision_35: 0.9146 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00022: val_loss did not improve from 0.01420
# Epoch 23/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0484 - accuracy: 0.9772 - auc_35: 0.9995 - precision_35: 0.9665 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0889 - val_accuracy: 0.9500 - val_auc_35: 0.9930 - val_precision_35: 0.9620 - val_precision_at_recall_26: 0.9846 - val_specificity_at_sensitivity_23: 0.9958 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00023: val_loss did not improve from 0.01420
# Epoch 24/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0481 - accuracy: 0.9813 - auc_35: 0.9992 - precision_35: 0.9754 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0863 - val_accuracy: 0.9500 - val_auc_35: 0.9939 - val_precision_35: 0.9620 - val_precision_at_recall_26: 0.9859 - val_specificity_at_sensitivity_23: 0.9958 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00024: val_loss did not improve from 0.01420
# Epoch 25/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0396 - accuracy: 0.9804 - auc_35: 0.9993 - precision_35: 0.9772 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 0.9995 - val_loss: 0.0923 - val_accuracy: 0.9500 - val_auc_35: 0.9932 - val_precision_35: 0.9500 - val_precision_at_recall_26: 0.9859 - val_specificity_at_sensitivity_23: 0.9958 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00025: val_loss did not improve from 0.01420
# Epoch 26/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0564 - accuracy: 0.9643 - auc_35: 0.9984 - precision_35: 0.9547 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0809 - val_accuracy: 0.9500 - val_auc_35: 0.9958 - val_precision_35: 0.9048 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00026: val_loss did not improve from 0.01420
# Epoch 27/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0533 - accuracy: 0.9731 - auc_35: 0.9982 - precision_35: 0.9599 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9500 - val_auc_35: 0.9963 - val_precision_35: 0.9398 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00027: val_loss did not improve from 0.01420
# Epoch 28/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0436 - accuracy: 0.9794 - auc_35: 0.9989 - precision_35: 0.9795 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 0.9995 - val_loss: 0.0816 - val_accuracy: 0.9375 - val_auc_35: 0.9957 - val_precision_35: 0.9383 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00028: val_loss did not improve from 0.01420
# Epoch 29/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0390 - accuracy: 0.9829 - auc_35: 0.9995 - precision_35: 0.9842 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0677 - val_accuracy: 0.9625 - val_auc_35: 0.9971 - val_precision_35: 0.9286 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00029: val_loss did not improve from 0.01420
# Epoch 30/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0403 - accuracy: 0.9798 - auc_35: 0.9992 - precision_35: 0.9832 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0670 - val_accuracy: 0.9750 - val_auc_35: 0.9957 - val_precision_35: 0.9750 - val_precision_at_recall_26: 0.9873 - val_specificity_at_sensitivity_23: 0.9958 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00030: val_loss did not improve from 0.01420
# Epoch 31/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0435 - accuracy: 0.9736 - auc_35: 0.9992 - precision_35: 0.9725 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9625 - val_auc_35: 0.9959 - val_precision_35: 0.9512 - val_precision_at_recall_26: 0.9872 - val_specificity_at_sensitivity_23: 0.9958 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00031: val_loss did not improve from 0.01420
# Epoch 32/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0306 - accuracy: 0.9909 - auc_35: 0.9997 - precision_35: 0.9815 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9750 - val_auc_35: 0.9970 - val_precision_35: 0.9630 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00032: val_loss did not improve from 0.01420
# Epoch 33/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0353 - accuracy: 0.9851 - auc_35: 0.9991 - precision_35: 0.9836 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0551 - val_accuracy: 0.9750 - val_auc_35: 0.9980 - val_precision_35: 0.9630 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00033: val_loss did not improve from 0.01420
# Epoch 34/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0366 - accuracy: 0.9833 - auc_35: 0.9993 - precision_35: 0.9855 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9750 - val_auc_35: 0.9976 - val_precision_35: 0.9630 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00034: val_loss did not improve from 0.01420
# Epoch 35/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0325 - accuracy: 0.9866 - auc_35: 0.9997 - precision_35: 0.9808 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0621 - val_accuracy: 0.9750 - val_auc_35: 0.9975 - val_precision_35: 0.9750 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00035: val_loss did not improve from 0.01420
# Epoch 36/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0391 - accuracy: 0.9821 - auc_35: 0.9995 - precision_35: 0.9819 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0582 - val_accuracy: 0.9750 - val_auc_35: 0.9973 - val_precision_35: 0.9873 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00036: val_loss did not improve from 0.01420
# Epoch 37/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0275 - accuracy: 0.9859 - auc_35: 0.9998 - precision_35: 0.9847 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0557 - val_accuracy: 0.9750 - val_auc_35: 0.9976 - val_precision_35: 0.9873 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00037: val_loss did not improve from 0.01420
# Epoch 38/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0414 - accuracy: 0.9832 - auc_35: 0.9959 - precision_35: 0.9817 - precision_at_recall_26: 0.9987 - specificity_at_sensitivity_23: 0.9996 - sensitivity_at_specificity_17: 0.9951 - val_loss: 0.0546 - val_accuracy: 0.9750 - val_auc_35: 0.9981 - val_precision_35: 0.9873 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00038: val_loss did not improve from 0.01420
# Epoch 39/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0272 - accuracy: 0.9906 - auc_35: 0.9998 - precision_35: 0.9870 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0572 - val_accuracy: 0.9750 - val_auc_35: 0.9960 - val_precision_35: 0.9873 - val_precision_at_recall_26: 0.9873 - val_specificity_at_sensitivity_23: 0.9958 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00039: val_loss did not improve from 0.01420
# Epoch 40/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0227 - accuracy: 0.9983 - auc_35: 1.0000 - precision_35: 0.9966 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0567 - val_accuracy: 0.9750 - val_auc_35: 0.9961 - val_precision_35: 0.9873 - val_precision_at_recall_26: 0.9873 - val_specificity_at_sensitivity_23: 0.9958 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00040: val_loss did not improve from 0.01420
# Epoch 41/100
# 23/23 [==============================] - 1s 37ms/step - loss: 0.0355 - accuracy: 0.9852 - auc_35: 0.9996 - precision_35: 0.9709 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0544 - val_accuracy: 0.9750 - val_auc_35: 0.9977 - val_precision_35: 0.9873 - val_precision_at_recall_26: 1.0000 - val_specificity_at_sensitivity_23: 1.0000 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00041: val_loss did not improve from 0.01420
# Epoch 42/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0350 - accuracy: 0.9819 - auc_35: 0.9996 - precision_35: 0.9864 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0552 - val_accuracy: 0.9750 - val_auc_35: 0.9960 - val_precision_35: 0.9873 - val_precision_at_recall_26: 0.9873 - val_specificity_at_sensitivity_23: 0.9958 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00042: val_loss did not improve from 0.01420
# Epoch 43/100
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0284 - accuracy: 0.9899 - auc_35: 0.9996 - precision_35: 0.9902 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0563 - val_accuracy: 0.9750 - val_auc_35: 0.9961 - val_precision_35: 0.9873 - val_precision_at_recall_26: 0.9873 - val_specificity_at_sensitivity_23: 0.9958 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00043: val_loss did not improve from 0.01420
# Epoch 44/100
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0278 - accuracy: 0.9934 - auc_35: 0.9998 - precision_35: 0.9873 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000 - val_loss: 0.0571 - val_accuracy: 0.9750 - val_auc_35: 0.9962 - val_precision_35: 0.9750 - val_precision_at_recall_26: 0.9873 - val_specificity_at_sensitivity_23: 0.9958 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00044: val_loss did not improve from 0.01420
# Epoch 45/100
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0264 - accuracy: 0.9920 - auc_35: 0.9997 - precision_35: 0.9870 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 0.9996 - val_loss: 0.0556 - val_accuracy: 0.9750 - val_auc_35: 0.9963 - val_precision_35: 0.9750 - val_precision_at_recall_26: 0.9873 - val_specificity_at_sensitivity_23: 0.9958 - val_sensitivity_at_specificity_17: 1.0000
#
# Epoch 00045: val_loss did not improve from 0.01420
# Epoch 00045: early stopping
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0262 - accuracy: 0.9800 - auc_35: 0.9997 - precision_35: 0.9755 - precision_at_recall_26: 1.0000 - specificity_at_sensitivity_23: 1.0000 - sensitivity_at_specificity_17: 1.0000
# Val Score:  [0.026226820424199104, 0.9800000190734863, 0.999695897102356, 0.9754902124404907, 1.0, 1.0, 1.0]
# ====================================================================================

# %%
print("data train x",t_x.shape)
print("data train y",t_y.shape)

print("data tes x",val_x.shape)
print("data tes y",val_y.shape)

model2 = load_model('subjek1LSTM.h5')
#model2.evaluate(val_x, val_y)
b = model2.evaluate(val_x, val_y)
print('loss',b[0])
print('Accuracy',b[1])
print('AUC',b[2])
print('precision',b[3])
print('recall',b[4])
print('specificity_at_sensitivity',b[5])
print('sensitivity_at_specificity',b[6])
# Out:
# data train x (800, 8, 60)
# data train y (800, 4)
# data tes x (200, 8, 60)
# data tes y (200, 4)
# 7/7 [==============================] - 2s 8ms/step - loss: 0.0099 - accuracy: 1.0000 - auc_31: 1.0000 - precision_31: 1.0000 - precision_at_recall_22: 1.0000 - specificity_at_sensitivity_19: 1.0000 - sensitivity_at_specificity_13: 1.0000
# loss 0.009874125942587852
# Accuracy 1.0
# AUC 1.0
# precision 1.0
# recall 1.0
# specificity_at_sensitivity 1.0
# sensitivity_at_specificity 1.0

# %%
fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)
ax1.plot(model_history[0].history['accuracy'], label='Training Fold 1 accuration')
ax1.plot(model_history[1].history['accuracy'], label='Training Fold 2 accuration')
ax1.plot(model_history[2].history['accuracy'], label='Training Fold 3 accuration')
ax1.plot(model_history[3].history['accuracy'], label='Training Fold 4 accuration')
ax1.plot(model_history[4].history['accuracy'], label='Training Fold 5 accuration')
ax1.legend()
ax2.plot(model_history[1].history['loss'], label='Training Fold 1 loss')
ax2.plot(model_history[1].history['loss'], label='Training Fold 2 loss')
ax2.plot(model_history[2].history['loss'], label='Training Fold 3 loss')
ax2.plot(model_history[3].history['loss'], label='Training Fold 4 loss ')
ax2.plot(model_history[4].history['loss'], label='Training Fold 5 loss')
ax2.legend()
plt.show()

# %%
fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt1.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[0].history['loss'], label='Train Loss Fold 1', color='black')
plt2.plot(model_history[0].history['val_loss'], label='Val Loss Fold 1', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red')
plt1.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[1].history['loss'], label='Train Loss Fold 2', color='red')
plt2.plot(model_history[1].history['val_loss'], label='Val Loss Fold 2', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green')
plt1.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[2].history['loss'], label='Train Loss Fold 3', color='green')
plt2.plot(model_history[2].history['val_loss'], label='Val Loss Fold 3', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()


fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue')
plt1.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[3].history['loss'], label='Train Loss Fold 4', color='blue')
plt2.plot(model_history[3].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='purple')
plt1.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[4].history['loss'], label='Train Loss Fold 4', color='purple')
plt2.plot(model_history[4].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

# %%
MODEL_NAME ='/content/subjek1LSTM.h5' 

#CLIP = True # if your model was trained with np.clip to clip  values
CLIP = False
CLIP_VAL = 8  # if above, what was the value +/-

model = tf.keras.models.load_model(MODEL_NAME)

VALDIR = '/content/drive/MyDrive/Colab Notebooks/data8'
ACTIONS =  ["idle","maju","kiri", "kanan"]
PRED_BATCH = 32


def get_val_data(valdir, action, batch_size):

   # argmax_dict = {0: 0, 1: 0, 2: 0,3:0}
    argmax_dict = {2: 0, 0: 0, 1: 0,3:0}
    raw_pred_dict = {0: 0, 1: 0, 2: 0,3:0}

    action_dir = os.path.join(valdir, action)
    for session_file in os.listdir(action_dir):
        filepath = os.path.join(action_dir,session_file)
        if CLIP:
            data = np.clip(np.load(filepath), -CLIP_VAL, CLIP_VAL) / CLIP_VAL
            #print(data)
        else:
            data = np.load(filepath) 
        preds = model.predict([data.reshape(-1, 8, 60)], batch_size=batch_size)
        
        for pred in preds:
            argmax = np.argmax(pred)
            argmax_dict[argmax] += 1
            for idx,value in enumerate(pred):
                raw_pred_dict[idx] += value
    
    argmax_pct_dict = {}
    for i in argmax_dict:
        total = 0
        correct = argmax_dict[i]
        for ii in argmax_dict:
            total += argmax_dict[ii]
        argmax_pct_dict[i] = round(correct/total, 4)
    return argmax_dict, raw_pred_dict, argmax_pct_dict


def make_conf_mat(none,left,forward, right):
    action_dict = {"idle":none,"maju": forward, "kiri": left, "kanan": right}
    action_conf_mat = pd.DataFrame(action_dict)
    actions = [i for i in action_dict]

    fig = plt.figure(figsize=(15, 6))
    ax = fig.add_subplot(111)
    ax.matshow(action_conf_mat, cmap=plt.cm.RdYlGn)
    ax.set_xticklabels([""]+actions)
    ax.set_yticklabels([""]+actions)

    for idx, i in enumerate(action_dict):
        for idx2, ii in enumerate(action_dict[i]):
            ax.text(idx, idx2, f"{round(float(action_dict[i][ii]),2)}", va='center', ha='center')
    # Rotate the tick labels and set their alignment.
    
    plt.title("Matrik data")
    plt.ylabel("Predicted Action")
    fig.tight_layout()
    plt.show()



forward_argmax_dict, forward_raw_pred_dict, forward_argmax_pct_dict = get_val_data(VALDIR, "maju", PRED_BATCH)
none_argmax_dict, none_raw_pred_dict, none_argmax_pct_dict = get_val_data(VALDIR, "idle", PRED_BATCH)
left_argmax_dict, left_raw_pred_dict, left_argmax_pct_dict = get_val_data(VALDIR, "kiri", PRED_BATCH)
right_argmax_dict, right_raw_pred_dict, right_argmax_pct_dict = get_val_data(VALDIR, "kanan", PRED_BATCH)
make_conf_mat(none_argmax_pct_dict,forward_argmax_pct_dict,left_argmax_pct_dict,  right_argmax_pct_dict)

# %%
x_train,x_test,y_train,y_test=train_test_split(train2_X,train_y,test_size=0.2)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (800, 8, 60)
# (200, 8, 60)
# (800, 4)
# (200, 4)

# %%
from sklearn.metrics import roc_curve, auc

#y_score = clf.decision_function(xval)
y_score = model.predict(x_test)

#Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()


# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
    
    
print("roc_auc:",sum(roc_auc.values())/4)
ACTIONS =  ["idle","maju","kiri", "kanan"]
for i in range(0,4):
    plt.figure()
    fig, ax = plt.subplots(figsize=(10,10))
    plt.plot(fpr[i], tpr[i],linewidth=3)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    #plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % ACTIONS[i])
    plt.title('%s -ROC curve (area = %0.2f)' % (ACTIONS[i],roc_auc[i]))
    
    plt.legend(loc="lower right")
    plt.show()
# Out:
# roc_auc: 1.0

# %% [markdown]
# #ML

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau
import matplotlib.pyplot as plt

from scipy import signal
from scipy.fft import fftshift
import numpy as np

import os
import random
import time
import os
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import accuracy_score
from sklearn.pipeline import make_pipeline
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import accuracy_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import label_ranking_average_precision_score
from sklearn.metrics import multilabel_confusion_matrix
import time

# Binary Relevance
from sklearn.multiclass import OneVsRestClassifier

# Performance metric
from sklearn.metrics import f1_score

# %%
train_X = np.array(train_X).reshape(reshape3)
train_y = np.array(train_y)

x_train,x_test,y_train,y_test=train_test_split(train_X,train_y,test_size=0.2,random_state = np.random.randint(1,1000, 1)[0] )
x_train = np.asarray(x_train)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

x_train = [np.concatenate(i) for i in x_train]
x_test = [np.concatenate(i) for i in x_test]
x_train,x_test,y_train,y_test=train_test_split(train_X,train_y,test_size=0.2,random_state = np.random.randint(1,1000, 1)[0] )
x_train = np.asarray(x_train)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

x_train = [np.concatenate(i) for i in x_train]
x_test = [np.concatenate(i) for i in x_test]
# Out:
# (800, 8, 60)
# (200, 8, 60)
# (800, 4)
# (200, 4)
# (800, 8, 60)
# (200, 8, 60)
# (800, 4)
# (200, 4)

# %%
sgd = SGDClassifier()
lr = LogisticRegression()
rf = RandomForestClassifier()
ld = LinearDiscriminantAnalysis()
sv = SVC()
ada= AdaBoostClassifier()
kn = KNeighborsClassifier()
GU = GaussianNB()


clf1 =OneVsRestClassifier(sgd)
clf2 =OneVsRestClassifier(lr)
clf3 =OneVsRestClassifier(rf)
clf4 =OneVsRestClassifier(ld)
clf5 =OneVsRestClassifier(sv)  
clf6 =OneVsRestClassifier(ada) 
clf7 =OneVsRestClassifier(kn) 
clf8 =OneVsRestClassifier(GU) 

start=time.time()

clf1.fit(x_train,y_train)
clf2.fit(x_train,y_train)
clf3.fit(x_train,y_train)
clf4.fit(x_train,y_train)
clf5.fit(x_train,y_train)
clf6.fit(x_train,y_train)
clf7.fit(x_train,y_train)
clf8.fit(x_train,y_train)



predictions1 = clf1.predict(x_test)
predictions2 = clf2.predict(x_test)
predictions3 = clf3.predict(x_test)
predictions4 = clf4.predict(x_test)
predictions5 = clf5.predict(x_test)
predictions6 = clf6.predict(x_test)
predictions7 = clf7.predict(x_test)
predictions8 = clf8.predict(x_test)

# accuracy
print("-------------------------")
print( "SGD")
print("Accuracy = ",accuracy_score(y_test,predictions1))
print("Hamming Loss = ",hamming_loss(y_test,predictions1))
print("label_ranking_average_precision_score",label_ranking_average_precision_score(y_test,predictions1))

# accuracy
print("-------------------------")
print( "LR")
print("Accuracy = ",accuracy_score(y_test,predictions2))
print("Hamming Loss = ",hamming_loss(y_test,predictions2))
print("label_ranking_average_precision_score",label_ranking_average_precision_score(y_test,predictions2))

# accuracy
print("-------------------------")
print( "RF")
print("Accuracy = ",accuracy_score(y_test,predictions3))
print("Hamming Loss = ",hamming_loss(y_test,predictions3))
print("label_ranking_average_precision_score",label_ranking_average_precision_score(y_test,predictions3))

# accuracy
print("-------------------------")
print( "LD")
print("Accuracy = ",accuracy_score(y_test,predictions4))
print("Hamming Loss = ",hamming_loss(y_test,predictions4))
print("label_ranking_average_precision_score",label_ranking_average_precision_score(y_test,predictions4))

# accuracy
print("-------------------------")
print( "SV")
print("Accuracy = ",accuracy_score(y_test,predictions5))
print("Hamming Loss = ",hamming_loss(y_test,predictions5))
print("label_ranking_average_precision_score",label_ranking_average_precision_score(y_test,predictions5))

# accuracy
print("-------------------------")
print( "AD")
print("Accuracy = ",accuracy_score(y_test,predictions6))
print("Hamming Loss = ",hamming_loss(y_test,predictions6))
print("label_ranking_average_precision_score",label_ranking_average_precision_score(y_test,predictions6))
# accuracy
print("-------------------------")
print( "KN")
print("Accuracy = ",accuracy_score(y_test,predictions7))
print("Hamming Loss = ",hamming_loss(y_test,predictions7))
print("label_ranking_average_precision_score",label_ranking_average_precision_score(y_test,predictions7))
# accuracy
print("-------------------------")
print( "GU")
print("Accuracy = ",accuracy_score(y_test,predictions8))
print("Hamming Loss = ",hamming_loss(y_test,predictions8))
print("label_ranking_average_precision_score",label_ranking_average_precision_score(y_test,predictions8))

print('training time taken: ',round(time.time()-start,0),'seconds')
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# -------------------------
# SGD
# Accuracy =  0.665
# Hamming Loss =  0.09625
# label_ranking_average_precision_score 0.765
# -------------------------
# LR
# Accuracy =  0.785
# Hamming Loss =  0.05875
# label_ranking_average_precision_score 0.8566666666666667
# -------------------------
# RF
# Accuracy =  0.875
# Hamming Loss =  0.03125
# label_ranking_average_precision_score 0.91125
# -------------------------
# LD
# Accuracy =  0.48
# Hamming Loss =  0.215
# label_ranking_average_precision_score 0.6529166666666666
# -------------------------
# SV
# Accuracy =  0.48
# Hamming Loss =  0.13375
# label_ranking_average_precision_score 0.61
# -------------------------
# AD
# Accuracy =  0.72
# Hamming Loss =  0.07875
# label_ranking_average_precision_score 0.8029166666666667
# -------------------------
# KN
# Accuracy =  0.9
# Hamming Loss =  0.0425
# label_ranking_average_precision_score 0.925
# -------------------------
# GU
# Accuracy =  0.24
# Hamming Loss =  0.26875
# label_ranking_average_precision_score 0.5654166666666665
# training time taken:  10.0 seconds

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

data = {'SGD': accuracy_score(y_test,predictions1), 'LR': accuracy_score(y_test,predictions2), 
        'RF': accuracy_score(y_test,predictions3), 'LDA': accuracy_score(y_test,predictions4),
        'SVM': accuracy_score(y_test,predictions5),'AD': accuracy_score(y_test,predictions6),
        'KNN': accuracy_score(y_test,predictions7),'GU': accuracy_score(y_test,predictions8),}
names = list(data.keys())
values = list(data.values())
print(names)
print(values)
plt.figure(figsize=(15, 6))
plt.bar(names,values)
# Out:
# ['SGD', 'LR', 'RF', 'LDA', 'SVM', 'AD', 'KNN', 'GU']
# [0.665, 0.785, 0.875, 0.48, 0.48, 0.72, 0.9, 0.24]
# <BarContainer object of 8 artists>

# %% [markdown]
# #RF

# %%
from sklearn.metrics import roc_curve, auc
y_score = clf3.predict(x_test)
#y_score = clf.predict(xval)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
ACTIONS =  ["idle","maju","kiri", "kanan"]
# Plot of a ROC curve for a specific class
for i in range(4):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    #plt.title('Receiver operating characteristic example')
    plt.title('%s RF (area = %0.2f)' % (ACTIONS[i],roc_auc[i]))
    plt.legend(loc="lower right")
    plt.show()

# %%
from sklearn.metrics import multilabel_confusion_matrix
cm=multilabel_confusion_matrix(y_test, predictions3)

import matplotlib.pyplot as plt
from mlxtend.plotting import plot_confusion_matrix

fig, ax = plot_confusion_matrix(conf_mat=cm[0])
plt.title('RF ' )
plt.show()

# %% [markdown]
# #KNN

# %%
from sklearn.metrics import roc_curve, auc
y_score = clf7.predict(x_test)
#y_score = clf.predict(xval)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
ACTIONS =  ["idle","maju","kiri", "kanan"]
# Plot of a ROC curve for a specific class
for i in range(4):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    #plt.title('Receiver operating characteristic example')
    plt.title('%s KNN (area = %0.2f)' % (ACTIONS[i],roc_auc[i]))
    plt.legend(loc="lower right")
    plt.show()

# %%
from sklearn.metrics import multilabel_confusion_matrix
cm=multilabel_confusion_matrix(y_test, predictions7)

import matplotlib.pyplot as plt
from mlxtend.plotting import plot_confusion_matrix

fig, ax = plot_confusion_matrix(conf_mat=cm[0])
plt.title('KNN' )
plt.show()

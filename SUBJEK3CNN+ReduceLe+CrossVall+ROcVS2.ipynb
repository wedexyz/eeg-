# %% [markdown]
# <a href="https://colab.research.google.com/github/wedexyz/eeg-/blob/main/SUBJEK3CNN%2BReduceLe%2BCrossVall%2BROcVS2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.0.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.19.4)

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM, BatchNormalization, Conv2D, Flatten, MaxPooling2D, Dropout
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.optimizers import Adam
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
import pandas as pd
import os
import random
import time
import os
from keras.callbacks import ModelCheckpoint, EarlyStopping
#from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator

from scipy import signal
from scipy.fft import fftshift

# %%
'''
idle = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/idle/1604315006.npy")
kanan = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kanan/1604315180.npy")
kiri = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kiri/1604315126.npy")
maju = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/maju/1604315069.npy")

kelas1=idle[0][16]
kelas2=maju[0][16]
kelas3=kanan[0][16]
kelas4=kiri[0][16]

kelas1a=idle[175]
kelas2a=maju[175]
kelas3a=kanan[175]
kelas4a=kiri[175]

#print(idlea.shape)


f1, t1,Sxx= signal.spectrogram(kelas1,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )
dbs1 = 10*np.log10(Sxx)
f2, t2,Sxx= signal.spectrogram(kelas2,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd',
                            )
dbs2 = 10*np.log10(Sxx)
f3, t3,Sxx= signal.spectrogram(kelas3,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )
dbs3 = 10*np.log10(Sxx)
f4, t4,Sxx= signal.spectrogram(kelas4,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )  
dbs4 = 10*np.log10(Sxx)



fig, axs = plt.subplots(nrows=4, ncols=4)
axs = axs.flatten()

axs[0].set_title("siggle")
axs[0].plot(kelas1)

axs[1].set_title("global")
axs[1].plot(kelas1a)

axs[2].set_title("Spectogram")
axs[2].pcolormesh(t1, f1,dbs1,  
                  shading='gouraud',
                  cmap='nipy_spectral')

cwt1 = signal.cwt(kelas1,signal.ricker,widths=np.arange(1,50))
cwt2 = signal.cwt(kelas2,signal.ricker,widths=np.arange(1,50))
cwt3 = signal.cwt(kelas3,signal.ricker,widths=np.arange(1,50))
cwt4 = signal.cwt(kelas4,signal.ricker,widths=np.arange(1,50))
axs[3].set_title("wavelet")
axs[3].imshow(cwt1,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt1).max(),vmin=-abs(cwt1).max())

axs[4].plot(kelas2)
axs[5].plot(kelas2a)
axs[6].pcolormesh(t2, f2,dbs2,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[7].imshow(cwt2,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt2).max(),vmin=-abs(cwt2).max())

axs[8].plot(kelas3)
axs[9].plot(kelas3a)
axs[10].pcolormesh(t3, f3,dbs3,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[11].imshow(cwt3,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt3).max(),vmin=-abs(cwt3).max())

axs[12].plot(kelas4)
axs[13].plot(kelas4a)
axs[14].pcolormesh(t4, f4,dbs4,  
                  shading='gouraud',
                  cmap='viridis')
axs[15].imshow(cwt4,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt4).max(),vmin=-abs(cwt4).max())
plt.show()
'''
# Out:
# '\nidle = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/idle/1604315006.npy")\nkanan = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kanan/1604315180.npy")\nkiri = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kiri/1604315126.npy")\nmaju = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/maju/1604315069.npy")\n\nkelas1=idle[0][16]\nkelas2=maju[0][16]\nkelas3=kanan[0][16]\nkelas4=kiri[0][16]\n\nkelas1a=idle[175]\nkelas2a=maju[175]\nkelas3a=kanan[175]\nkelas4a=kiri[175]\n\n#print(idlea.shape)\n\n\nf1, t1,Sxx= signal.spectrogram(kelas1,fs=120, window=(\'tukey\', 0.25),\n                             nperseg=11,\n                             noverlap=10,\n                             nfft=None, \n                             detrend=\'constant\',\n                             return_onesided=True, \n                             scaling=\'density\', \n                             axis=-1,\n                             mode=\'psd\'\n                            )\ndbs1 = 10*np.log10(Sxx)\nf2, t2,Sxx= signal.spectrogram(kelas2,fs=120, window=(\'tukey\', 0.25),\n                             nperseg=11,\n                             noverlap=10,\n                             nfft=None, \n                             detrend=\'constant\',\n                             return_onesided=True, \n                             scaling=\'density\', \n                             axis=-1,\n                             mode=\'psd\',\n                            )\ndbs2 = 10*np.log10(Sxx)\nf3, t3,Sxx= signal.spectrogram(kelas3,fs=120, window=(\'tukey\', 0.25),\n                             nperseg=11,\n                             noverlap=10,\n                             nfft=None, \n                             detrend=\'constant\',\n                             return_onesided=True, \n                             scaling=\'density\', \n                             axis=-1,\n                             mode=\'psd\'\n                            )\ndbs3 = 10*np.log10(Sxx)\nf4, t4,Sxx= signal.spectrogram(kelas4,fs=120, window=(\'tukey\', 0.25),\n                             nperseg=11,\n                             noverlap=10,\n                             nfft=None, \n                             detrend=\'constant\',\n                             return_onesided=True, \n                             scaling=\'density\', \n                             axis=-1,\n                             mode=\'psd\'\n                            )  \ndbs4 = 10*np.log10(Sxx)\n\n\n\nfig, axs = plt.subplots(nrows=4, ncols=4)\naxs = axs.flatten()\n\naxs[0].set_title("siggle")\naxs[0].plot(kelas1)\n\naxs[1].set_title("global")\naxs[1].plot(kelas1a)\n\naxs[2].set_title("Spectogram")\naxs[2].pcolormesh(t1, f1,dbs1,  \n                  shading=\'gouraud\',\n                  cmap=\'nipy_spectral\')\n\ncwt1 = signal.cwt(kelas1,signal.ricker,widths=np.arange(1,50))\ncwt2 = signal.cwt(kelas2,signal.ricker,widths=np.arange(1,50))\ncwt3 = signal.cwt(kelas3,signal.ricker,widths=np.arange(1,50))\ncwt4 = signal.cwt(kelas4,signal.ricker,widths=np.arange(1,50))\naxs[3].set_title("wavelet")\naxs[3].imshow(cwt1,extent=[0,16,0,60],cmap=\'jet\',aspect=\'auto\',vmax=abs(cwt1).max(),vmin=-abs(cwt1).max())\n\naxs[4].plot(kelas2)\naxs[5].plot(kelas2a)\naxs[6].pcolormesh(t2, f2,dbs2,  \n                  shading=\'gouraud\',\n                  cmap=\'nipy_spectral\')\naxs[7].imshow(cwt2,extent=[0,16,0,60],cmap=\'jet\',aspect=\'auto\',vmax=abs(cwt2).max(),vmin=-abs(cwt2).max())\n\naxs[8].plot(kelas3)\naxs[9].plot(kelas3a)\naxs[10].pcolormesh(t3, f3,dbs3,  \n                  shading=\'gouraud\',\n                  cmap=\'nipy_spectral\')\naxs[11].imshow(cwt3,extent=[0,16,0,60],cmap=\'jet\',aspect=\'auto\',vmax=abs(cwt3).max(),vmin=-abs(cwt3).max())\n\naxs[12].plot(kelas4)\naxs[13].plot(kelas4a)\naxs[14].pcolormesh(t4, f4,dbs4,  \n                  shading=\'gouraud\',\n                  cmap=\'viridis\')\naxs[15].imshow(cwt4,extent=[0,16,0, ...

# %%
ACTIONS = ["kiri", "maju","idle","kanan"]
reshape = (-1,16, 60,1)
#reshape(-1,28,28,1)

# %%
def create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/AFIF/afif_subjek3"):
    training_data = {}
    for action in ACTIONS:
        if action not in training_data:
            training_data[action] = []
        data_dir = os.path.join(starting_dir,action)
        for item in os.listdir(data_dir):
            data = np.load(os.path.join(data_dir, item))
            for item in data:
                training_data[action].append(item)

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)

    for action in ACTIONS:
        np.random.shuffle(training_data[action])  
        training_data[action] = training_data[action][:min(lengths)]

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)
    combined_data = []
    for action in ACTIONS:
        for data in training_data[action]:
            if action == "kiri":
                combined_data.append([data, [1, 0, 0,0]])
            elif action == "maju":
                combined_data.append([data, [0, 1, 0, 0]])
            elif action == "idle":
                combined_data.append([data, [0, 0, 1, 0]])
            elif action == "kanan":
                combined_data.append([data, [0, 0, 0, 1]])

    np.random.shuffle(combined_data)
    print("length:",len(combined_data))
    return combined_data

# %%
print("creating training data")
traindata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/AFIF/afif_subjek3")
train_X = []
train_y = []
for X, y in traindata:
    train_X.append(X)
    train_y.append(y)
# Out:
# creating training data
# [1000, 1000, 1000, 1000]
# [1000, 1000, 1000, 1000]
# length: 4000

# %%
print("creating testing data")
testdata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/AFIF/subjek3tes")
test_X = []
test_y = []

for X, y in testdata:
    test_X.append(X)
    test_y.append(y)
train_X = np.array(train_X).reshape(reshape)
test_X = np.array(test_X).reshape(reshape)

train_y = np.array(train_y)
test_y = np.array(test_y)
# Out:
# creating testing data
# [250, 250, 250, 250]
# [250, 250, 250, 250]
# length: 1000

# %%
import seaborn as sns
ye=pd.DataFrame(train_y)

ye.columns=["kiri", "maju","idle","kanan"]
categories = list(ye.columns.values)
sns.set(font_scale = 1)
plt.figure(figsize=(10,8))
ax= sns.barplot(categories, ye.iloc[:,0:].sum().values)
plt.title("Number of samples labeled as active (1) out of {0} length data".format((ye.shape[0])),fontsize=20)

plt.ylabel('Number of events', fontsize=18)
plt.xlabel('Event Type ', fontsize=12)
#adding the text labels
rects = ax.patches
labels = ye.iloc[:,0:].sum().values

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom', fontsize=10)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# With data augmentation to prevent overfitting
'''
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(train_X)
'''
# Out:
# '\ndatagen = ImageDataGenerator(\n        featurewise_center=False,  # set input mean to 0 over the dataset\n        samplewise_center=False,  # set each sample mean to 0\n        featurewise_std_normalization=False,  # divide inputs by std of the dataset\n        samplewise_std_normalization=False,  # divide each input by its std\n        zca_whitening=False,  # apply ZCA whitening\n        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)\n        zoom_range = 0.1, # Randomly zoom image \n        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)\n        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)\n        horizontal_flip=False,  # randomly flip images\n        vertical_flip=False)  # randomly flip images\n\n\ndatagen.fit(train_X)\n'

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1,factor=0.5, min_lr=0.0001)

# %%
#def cnn_model(size, num_cnn_layers):
def cnn_model():    

    model = Sequential()
    
    model.add(Conv2D(filters = 64, kernel_size = (7,7), padding = "same", activation = "relu", input_shape=train_X.shape[1:]))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Conv2D(filters = 64, kernel_size = (5,5), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (5,5)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Conv2D(filters = 64, kernel_size = (3,3), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (3,3)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Flatten())
    
    model.add(Dense(32, activation = "relu"))
    model.add(BatchNormalization())

    model.add(Dense(4, activation = "sigmoid"))
   
    #adam = Adam(lr = 0.001)
    model.compile(optimizer ="adam", loss = "binary_crossentropy", metrics = ['accuracy'])
    #model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
 
    
    return model

# %%
#model = cnn_model(IMAGE_SIZE, 2)
model = cnn_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 16, 60, 64)        3200
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 60, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 60, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 60, 64)        102464
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 3, 12, 64)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 12, 64)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 3, 12, 64)         256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 12, 64)         36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 4, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 4, 64)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 4, 64)          256
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                8224
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 151,844
# Trainable params: 151,396
# Non-trainable params: 448
# _________________________________________________________________

# %%
#set early stopping criteria
pat = 5
#this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='loss', patience=pat, verbose=1)

#define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('subjek3.h5', verbose=1, save_best_only=True)

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=100, BATCH_SIZE=32):
    model = None
    #model = cnn_model(IMAGE_SIZE, 2)
    model = cnn_model()
    #Model = model
   # results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[early_stopping, model_checkpoint], 
   #           verbose=1, validation_split=0.1) 
    results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[learning_rate_reduction,early_stopping, model_checkpoint], 
              verbose=1, validation_split=0.1)   
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs=100
batch_size=32

#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(train_X, train_y, test_size=0.1, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
   
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 102/102 [==============================] - 9s 13ms/step - loss: 0.7569 - accuracy: 0.2538 - val_loss: 0.6192 - val_accuracy: 0.2472
#
# Epoch 00001: val_loss improved from inf to 0.61918, saving model to subjek3.h5
# Epoch 2/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.6328 - accuracy: 0.2456 - val_loss: 0.5856 - val_accuracy: 0.2472
#
# Epoch 00002: val_loss improved from 0.61918 to 0.58556, saving model to subjek3.h5
# Epoch 3/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5873 - accuracy: 0.2560 - val_loss: 0.5670 - val_accuracy: 0.2472
#
# Epoch 00003: val_loss improved from 0.58556 to 0.56701, saving model to subjek3.h5
# Epoch 4/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5746 - accuracy: 0.2401 - val_loss: 0.5664 - val_accuracy: 0.2444
#
# Epoch 00004: val_loss improved from 0.56701 to 0.56640, saving model to subjek3.h5
# Epoch 5/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5693 - accuracy: 0.2650 - val_loss: 0.5711 - val_accuracy: 0.2028
#
# Epoch 00005: val_loss did not improve from 0.56640
# Epoch 6/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5676 - accuracy: 0.2730 - val_loss: 0.5663 - val_accuracy: 0.2083
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss improved from 0.56640 to 0.56630, saving model to subjek3.h5
# Epoch 7/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5641 - accuracy: 0.2562 - val_loss: 0.5666 - val_accuracy: 0.2139
#
# Epoch 00007: val_loss did not improve from 0.56630
# Epoch 8/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5646 - accuracy: 0.2729 - val_loss: 0.5691 - val_accuracy: 0.1944
#
# Epoch 00008: val_loss did not improve from 0.56630
# Epoch 9/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5677 - accuracy: 0.2527 - val_loss: 0.5675 - val_accuracy: 0.1944
#
# Epoch 00009: val_loss did not improve from 0.56630
# Epoch 10/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5667 - accuracy: 0.2489 - val_loss: 0.5671 - val_accuracy: 0.2056
#
# Epoch 00010: val_loss did not improve from 0.56630
# Epoch 11/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5622 - accuracy: 0.2827 - val_loss: 0.5686 - val_accuracy: 0.2056
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00011: val_loss did not improve from 0.56630
# Epoch 12/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5610 - accuracy: 0.2840 - val_loss: 0.5658 - val_accuracy: 0.2139
#
# Epoch 00012: val_loss improved from 0.56630 to 0.56575, saving model to subjek3.h5
# Epoch 13/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5597 - accuracy: 0.2839 - val_loss: 0.5644 - val_accuracy: 0.2278
#
# Epoch 00013: val_loss improved from 0.56575 to 0.56441, saving model to subjek3.h5
# Epoch 14/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5591 - accuracy: 0.2853 - val_loss: 0.5656 - val_accuracy: 0.2250
#
# Epoch 00014: val_loss did not improve from 0.56441
# Epoch 15/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5559 - accuracy: 0.3023 - val_loss: 0.5679 - val_accuracy: 0.2222
#
# Epoch 00015: val_loss did not improve from 0.56441
# Epoch 16/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5540 - accuracy: 0.3014 - val_loss: 0.5558 - val_accuracy: 0.2444
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00016: val_loss improved from 0.56441 to 0.55579, saving model to subjek3.h5
# Epoch 17/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5462 - accuracy: 0.3241 - val_loss: 0.5686 - val_accuracy: 0.2194
#
# Epoch 00017: val_loss did not improve from 0.55579
# Epoch 18/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5421 - accuracy: 0.3373 - val_loss: 0.5581 - val_accuracy: 0.2278
#
# Epoch 00018: val_loss did not improve from 0.55579
# Epoch 19/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5428 - accuracy: 0.3335 - val_loss: 0.5502 - val_accuracy: 0.2556
#
# Epoch 00019: val_loss improved from 0.55579 to 0.55016, saving model to subjek3.h5
# Epoch 20/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5384 - accuracy: 0.3287 - val_loss: 0.5436 - val_accuracy: 0.3056
#
# Epoch 00020: val_loss improved from 0.55016 to 0.54363, saving model to subjek3.h5
# Epoch 21/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5383 - accuracy: 0.3263 - val_loss: 0.5472 - val_accuracy: 0.2722
#
# Epoch 00021: val_loss did not improve from 0.54363
# Epoch 22/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5329 - accuracy: 0.3610 - val_loss: 0.5366 - val_accuracy: 0.3000
#
# Epoch 00022: val_loss improved from 0.54363 to 0.53658, saving model to subjek3.h5
# Epoch 23/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5261 - accuracy: 0.3483 - val_loss: 0.5397 - val_accuracy: 0.2833
#
# Epoch 00023: val_loss did not improve from 0.53658
# Epoch 24/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5323 - accuracy: 0.3347 - val_loss: 0.5348 - val_accuracy: 0.2944
#
# Epoch 00024: val_loss improved from 0.53658 to 0.53485, saving model to subjek3.h5
# Epoch 25/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5266 - accuracy: 0.3554 - val_loss: 0.5493 - val_accuracy: 0.2889
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00025: val_loss did not improve from 0.53485
# Epoch 26/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5244 - accuracy: 0.3562 - val_loss: 0.5323 - val_accuracy: 0.3306
#
# Epoch 00026: val_loss improved from 0.53485 to 0.53228, saving model to subjek3.h5
# Epoch 27/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5155 - accuracy: 0.3697 - val_loss: 0.5228 - val_accuracy: 0.3444
#
# Epoch 00027: val_loss improved from 0.53228 to 0.52276, saving model to subjek3.h5
# Epoch 28/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5174 - accuracy: 0.3709 - val_loss: 0.5244 - val_accuracy: 0.3389
#
# Epoch 00028: val_loss did not improve from 0.52276
# Epoch 29/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5129 - accuracy: 0.3842 - val_loss: 0.5324 - val_accuracy: 0.3222
#
# Epoch 00029: val_loss did not improve from 0.52276
# Epoch 30/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5140 - accuracy: 0.3838 - val_loss: 0.5246 - val_accuracy: 0.3278
#
# Epoch 00030: val_loss did not improve from 0.52276
# Epoch 31/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5107 - accuracy: 0.3822 - val_loss: 0.5099 - val_accuracy: 0.3806
#
# Epoch 00031: val_loss improved from 0.52276 to 0.50986, saving model to subjek3.h5
# Epoch 32/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5110 - accuracy: 0.3781 - val_loss: 0.5499 - val_accuracy: 0.3111
#
# Epoch 00032: val_loss did not improve from 0.50986
# Epoch 33/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5047 - accuracy: 0.4083 - val_loss: 0.5436 - val_accuracy: 0.3167
#
# Epoch 00033: val_loss did not improve from 0.50986
# Epoch 34/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5040 - accuracy: 0.4044 - val_loss: 0.5298 - val_accuracy: 0.3389
#
# Epoch 00034: val_loss did not improve from 0.50986
# Epoch 35/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5069 - accuracy: 0.3900 - val_loss: 0.5358 - val_accuracy: 0.3278
#
# Epoch 00035: val_loss did not improve from 0.50986
# Epoch 36/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5044 - accuracy: 0.3977 - val_loss: 0.5129 - val_accuracy: 0.3694
#
# Epoch 00036: val_loss did not improve from 0.50986
# Epoch 37/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4975 - accuracy: 0.4279 - val_loss: 0.5016 - val_accuracy: 0.4056
#
# Epoch 00037: val_loss improved from 0.50986 to 0.50156, saving model to subjek3.h5
# Epoch 38/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4966 - accuracy: 0.4122 - val_loss: 0.5083 - val_accuracy: 0.3750
#
# Epoch 00038: val_loss did not improve from 0.50156
# Epoch 39/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4980 - accuracy: 0.4184 - val_loss: 0.5003 - val_accuracy: 0.3889
#
# Epoch 00039: val_loss improved from 0.50156 to 0.50029, saving model to subjek3.h5
# Epoch 40/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4935 - accuracy: 0.4354 - val_loss: 0.5011 - val_accuracy: 0.4056
#
# Epoch 00040: val_loss did not improve from 0.50029
# Epoch 41/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4924 - accuracy: 0.4222 - val_loss: 0.5014 - val_accuracy: 0.3833
#
# Epoch 00041: val_loss did not improve from 0.50029
# Epoch 42/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4938 - accuracy: 0.4146 - val_loss: 0.4963 - val_accuracy: 0.4278
#
# Epoch 00042: val_loss improved from 0.50029 to 0.49625, saving model to subjek3.h5
# Epoch 43/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4969 - accuracy: 0.4085 - val_loss: 0.5187 - val_accuracy: 0.3500
#
# Epoch 00043: val_loss did not improve from 0.49625
# Epoch 44/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4868 - accuracy: 0.4552 - val_loss: 0.4852 - val_accuracy: 0.4500
#
# Epoch 00044: val_loss improved from 0.49625 to 0.48522, saving model to subjek3.h5
# Epoch 45/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4889 - accuracy: 0.4415 - val_loss: 0.5292 - val_accuracy: 0.3556
#
# Epoch 00045: val_loss did not improve from 0.48522
# Epoch 46/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4821 - accuracy: 0.4650 - val_loss: 0.4844 - val_accuracy: 0.4361
#
# Epoch 00046: val_loss improved from 0.48522 to 0.48440, saving model to subjek3.h5
# Epoch 47/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4781 - accuracy: 0.4537 - val_loss: 0.4819 - val_accuracy: 0.4417
#
# Epoch 00047: val_loss improved from 0.48440 to 0.48194, saving model to subjek3.h5
# Epoch 48/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4717 - accuracy: 0.4699 - val_loss: 0.4889 - val_accuracy: 0.4250
#
# Epoch 00048: val_loss did not improve from 0.48194
# Epoch 49/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4714 - accuracy: 0.4577 - val_loss: 0.5257 - val_accuracy: 0.3389
#
# Epoch 00049: val_loss did not improve from 0.48194
# Epoch 50/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4709 - accuracy: 0.4593 - val_loss: 0.4786 - val_accuracy: 0.4389
#
# Epoch 00050: val_loss improved from 0.48194 to 0.47863, saving model to subjek3.h5
# Epoch 51/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4646 - accuracy: 0.4807 - val_loss: 0.4732 - val_accuracy: 0.4694
#
# Epoch 00051: val_loss improved from 0.47863 to 0.47324, saving model to subjek3.h5
# Epoch 52/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4712 - accuracy: 0.4671 - val_loss: 0.4662 - val_accuracy: 0.4806
#
# Epoch 00052: val_loss improved from 0.47324 to 0.46621, saving model to subjek3.h5
# Epoch 53/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4649 - accuracy: 0.4908 - val_loss: 0.5364 - val_accuracy: 0.3583
#
# Epoch 00053: val_loss did not improve from 0.46621
# Epoch 54/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4678 - accuracy: 0.4834 - val_loss: 0.4594 - val_accuracy: 0.4833
#
# Epoch 00054: val_loss improved from 0.46621 to 0.45940, saving model to subjek3.h5
# Epoch 55/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4650 - accuracy: 0.4720 - val_loss: 0.4810 - val_accuracy: 0.4139
#
# Epoch 00055: val_loss did not improve from 0.45940
# Epoch 56/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4627 - accuracy: 0.4732 - val_loss: 0.4653 - val_accuracy: 0.4444
#
# Epoch 00056: val_loss did not improve from 0.45940
# Epoch 57/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4508 - accuracy: 0.4996 - val_loss: 0.4913 - val_accuracy: 0.3944
#
# Epoch 00057: val_loss did not improve from 0.45940
# Epoch 58/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4529 - accuracy: 0.4843 - val_loss: 0.4707 - val_accuracy: 0.4556
#
# Epoch 00058: val_loss did not improve from 0.45940
# Epoch 59/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4431 - accuracy: 0.5129 - val_loss: 0.4410 - val_accuracy: 0.5194
#
# Epoch 00059: val_loss improved from 0.45940 to 0.44100, saving model to subjek3.h5
# Epoch 60/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4445 - accuracy: 0.5109 - val_loss: 0.4571 - val_accuracy: 0.4944
#
# Epoch 00060: val_loss did not improve from 0.44100
# Epoch 61/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4412 - accuracy: 0.5149 - val_loss: 0.4719 - val_accuracy: 0.4778
#
# Epoch 00061: val_loss did not improve from 0.44100
# Epoch 62/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4371 - accuracy: 0.5090 - val_loss: 0.4293 - val_accuracy: 0.5444
#
# Epoch 00062: val_loss improved from 0.44100 to 0.42930, saving model to subjek3.h5
# Epoch 63/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4478 - accuracy: 0.5048 - val_loss: 0.4495 - val_accuracy: 0.4778
#
# Epoch 00063: val_loss did not improve from 0.42930
# Epoch 64/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4324 - accuracy: 0.5250 - val_loss: 0.4593 - val_accuracy: 0.4833
#
# Epoch 00064: val_loss did not improve from 0.42930
# Epoch 65/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4320 - accuracy: 0.5234 - val_loss: 0.4532 - val_accuracy: 0.4722
#
# Epoch 00065: val_loss did not improve from 0.42930
# Epoch 66/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4231 - accuracy: 0.5407 - val_loss: 0.4286 - val_accuracy: 0.5333
#
# Epoch 00066: val_loss improved from 0.42930 to 0.42861, saving model to subjek3.h5
# Epoch 67/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4211 - accuracy: 0.5465 - val_loss: 0.4502 - val_accuracy: 0.5194
#
# Epoch 00067: val_loss did not improve from 0.42861
# Epoch 68/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4307 - accuracy: 0.5271 - val_loss: 0.4463 - val_accuracy: 0.5111
#
# Epoch 00068: val_loss did not improve from 0.42861
# Epoch 69/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4223 - accuracy: 0.5477 - val_loss: 0.4134 - val_accuracy: 0.5639
#
# Epoch 00069: val_loss improved from 0.42861 to 0.41342, saving model to subjek3.h5
# Epoch 70/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4274 - accuracy: 0.5312 - val_loss: 0.4285 - val_accuracy: 0.5194
#
# Epoch 00070: val_loss did not improve from 0.41342
# Epoch 71/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4126 - accuracy: 0.5478 - val_loss: 0.4162 - val_accuracy: 0.5250
#
# Epoch 00071: val_loss did not improve from 0.41342
# Epoch 72/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4227 - accuracy: 0.5320 - val_loss: 0.4163 - val_accuracy: 0.5389
#
# Epoch 00072: val_loss did not improve from 0.41342
# Epoch 73/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4133 - accuracy: 0.5536 - val_loss: 0.4209 - val_accuracy: 0.5389
#
# Epoch 00073: val_loss did not improve from 0.41342
# Epoch 74/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4145 - accuracy: 0.5512 - val_loss: 0.4556 - val_accuracy: 0.4667
#
# Epoch 00074: val_loss did not improve from 0.41342
# Epoch 75/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4144 - accuracy: 0.5611 - val_loss: 0.4152 - val_accuracy: 0.5639
#
# Epoch 00075: val_loss did not improve from 0.41342
# Epoch 76/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4083 - accuracy: 0.5641 - val_loss: 0.4003 - val_accuracy: 0.5806
#
# Epoch 00076: val_loss improved from 0.41342 to 0.40033, saving model to subjek3.h5
# Epoch 77/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4012 - accuracy: 0.5705 - val_loss: 0.4012 - val_accuracy: 0.5667
#
# Epoch 00077: val_loss did not improve from 0.40033
# Epoch 78/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3996 - accuracy: 0.5591 - val_loss: 0.3878 - val_accuracy: 0.5806
#
# Epoch 00078: val_loss improved from 0.40033 to 0.38781, saving model to subjek3.h5
# Epoch 79/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4008 - accuracy: 0.5548 - val_loss: 0.3970 - val_accuracy: 0.5833
#
# Epoch 00079: val_loss did not improve from 0.38781
# Epoch 80/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3977 - accuracy: 0.5713 - val_loss: 0.3928 - val_accuracy: 0.5639
#
# Epoch 00080: val_loss did not improve from 0.38781
# Epoch 81/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3928 - accuracy: 0.5781 - val_loss: 0.4023 - val_accuracy: 0.5583
#
# Epoch 00081: val_loss did not improve from 0.38781
# Epoch 82/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3913 - accuracy: 0.5847 - val_loss: 0.4044 - val_accuracy: 0.5444
#
# Epoch 00082: val_loss did not improve from 0.38781
# Epoch 83/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3886 - accuracy: 0.5789 - val_loss: 0.3900 - val_accuracy: 0.5778
#
# Epoch 00083: val_loss did not improve from 0.38781
# Epoch 84/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3895 - accuracy: 0.5719 - val_loss: 0.3779 - val_accuracy: 0.5833
#
# Epoch 00084: val_loss improved from 0.38781 to 0.37791, saving model to subjek3.h5
# Epoch 85/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3860 - accuracy: 0.5787 - val_loss: 0.3904 - val_accuracy: 0.5833
#
# Epoch 00085: val_loss did not improve from 0.37791
# Epoch 86/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3780 - accuracy: 0.5949 - val_loss: 0.3897 - val_accuracy: 0.5639
#
# Epoch 00086: val_loss did not improve from 0.37791
# Epoch 87/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3830 - accuracy: 0.5764 - val_loss: 0.3898 - val_accuracy: 0.5389
#
# Epoch 00087: val_loss did not improve from 0.37791
# Epoch 88/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3791 - accuracy: 0.5801 - val_loss: 0.3701 - val_accuracy: 0.5806
#
# Epoch 00088: val_loss improved from 0.37791 to 0.37010, saving model to subjek3.h5
# Epoch 89/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3833 - accuracy: 0.5862 - val_loss: 0.3655 - val_accuracy: 0.5944
#
# Epoch 00089: val_loss improved from 0.37010 to 0.36552, saving model to subjek3.h5
# Epoch 90/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3763 - accuracy: 0.5880 - val_loss: 0.3799 - val_accuracy: 0.5611
#
# Epoch 00090: val_loss did not improve from 0.36552
# Epoch 91/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3742 - accuracy: 0.5804 - val_loss: 0.3720 - val_accuracy: 0.5806
#
# Epoch 00091: val_loss did not improve from 0.36552
# Epoch 92/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3777 - accuracy: 0.5801 - val_loss: 0.3587 - val_accuracy: 0.6111
#
# Epoch 00092: val_loss improved from 0.36552 to 0.35871, saving model to subjek3.h5
# Epoch 93/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3757 - accuracy: 0.5763 - val_loss: 0.3596 - val_accuracy: 0.6111
#
# Epoch 00093: val_loss did not improve from 0.35871
# Epoch 94/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3686 - accuracy: 0.6120 - val_loss: 0.3724 - val_accuracy: 0.5889
#
# Epoch 00094: val_loss did not improve from 0.35871
# Epoch 95/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3720 - accuracy: 0.5926 - val_loss: 0.3658 - val_accuracy: 0.5833
#
# Epoch 00095: val_loss did not improve from 0.35871
# Epoch 96/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3602 - accuracy: 0.6070 - val_loss: 0.3593 - val_accuracy: 0.6028
#
# Epoch 00096: val_loss did not improve from 0.35871
# Epoch 97/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3575 - accuracy: 0.6203 - val_loss: 0.3800 - val_accuracy: 0.5861
#
# Epoch 00097: val_loss did not improve from 0.35871
# Epoch 98/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3669 - accuracy: 0.5883 - val_loss: 0.3563 - val_accuracy: 0.6222
#
# Epoch 00098: val_loss improved from 0.35871 to 0.35632, saving model to subjek3.h5
# Epoch 99/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3638 - accuracy: 0.6051 - val_loss: 0.3481 - val_accuracy: 0.6306
#
# Epoch 00099: val_loss improved from 0.35632 to 0.34814, saving model to subjek3.h5
# Epoch 100/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3512 - accuracy: 0.6295 - val_loss: 0.3433 - val_accuracy: 0.6333
#
# Epoch 00100: val_loss improved from 0.34814 to 0.34329, saving model to subjek3.h5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3439 - accuracy: 0.6425
# Val Score:  [0.34387850761413574, 0.6424999833106995]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
# 102/102 [==============================] - 2s 9ms/step - loss: 0.7688 - accuracy: 0.2268 - val_loss: 0.6304 - val_accuracy: 0.2444
#
# Epoch 00001: val_loss did not improve from 0.34329
# Epoch 2/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.6264 - accuracy: 0.2407 - val_loss: 0.5780 - val_accuracy: 0.2194
#
# Epoch 00002: val_loss did not improve from 0.34329
# Epoch 3/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5856 - accuracy: 0.2363 - val_loss: 0.5657 - val_accuracy: 0.2778
#
# Epoch 00003: val_loss did not improve from 0.34329
# Epoch 4/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5733 - accuracy: 0.2428 - val_loss: 0.5645 - val_accuracy: 0.2472
#
# Epoch 00004: val_loss did not improve from 0.34329
# Epoch 5/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5670 - accuracy: 0.2470 - val_loss: 0.5655 - val_accuracy: 0.2389
#
# Epoch 00005: val_loss did not improve from 0.34329
# Epoch 6/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5680 - accuracy: 0.2533 - val_loss: 0.5639 - val_accuracy: 0.2722
#
# Epoch 00006: val_loss did not improve from 0.34329
# Epoch 7/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5679 - accuracy: 0.2444 - val_loss: 0.5687 - val_accuracy: 0.2111
#
# Epoch 00007: val_loss did not improve from 0.34329
# Epoch 8/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5661 - accuracy: 0.2424 - val_loss: 0.5675 - val_accuracy: 0.2139
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00008: val_loss did not improve from 0.34329
# Epoch 9/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5655 - accuracy: 0.2515 - val_loss: 0.5656 - val_accuracy: 0.2083
#
# Epoch 00009: val_loss did not improve from 0.34329
# Epoch 10/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5640 - accuracy: 0.2512 - val_loss: 0.5656 - val_accuracy: 0.2167
#
# Epoch 00010: val_loss did not improve from 0.34329
# Epoch 11/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5647 - accuracy: 0.2533 - val_loss: 0.5661 - val_accuracy: 0.1917
#
# Epoch 00011: val_loss did not improve from 0.34329
# Epoch 12/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5641 - accuracy: 0.2505 - val_loss: 0.5655 - val_accuracy: 0.2028
#
# Epoch 00012: val_loss did not improve from 0.34329
# Epoch 13/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5639 - accuracy: 0.2647 - val_loss: 0.5655 - val_accuracy: 0.1861
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00013: val_loss did not improve from 0.34329
# Epoch 14/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5647 - accuracy: 0.2555 - val_loss: 0.5652 - val_accuracy: 0.2139
#
# Epoch 00014: val_loss did not improve from 0.34329
# Epoch 15/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5639 - accuracy: 0.2565 - val_loss: 0.5656 - val_accuracy: 0.2194
#
# Epoch 00015: val_loss did not improve from 0.34329
# Epoch 16/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5638 - accuracy: 0.2540 - val_loss: 0.5653 - val_accuracy: 0.2111
#
# Epoch 00016: val_loss did not improve from 0.34329
# Epoch 17/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5630 - accuracy: 0.2568 - val_loss: 0.5650 - val_accuracy: 0.2083
#
# Epoch 00017: val_loss did not improve from 0.34329
# Epoch 18/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5629 - accuracy: 0.2599 - val_loss: 0.5659 - val_accuracy: 0.2000
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00018: val_loss did not improve from 0.34329
# Epoch 19/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5625 - accuracy: 0.2771 - val_loss: 0.5654 - val_accuracy: 0.2056
#
# Epoch 00019: val_loss did not improve from 0.34329
# Epoch 20/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5618 - accuracy: 0.2729 - val_loss: 0.5651 - val_accuracy: 0.1972
#
# Epoch 00020: val_loss did not improve from 0.34329
# Epoch 21/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5626 - accuracy: 0.2601 - val_loss: 0.5656 - val_accuracy: 0.1944
#
# Epoch 00021: val_loss did not improve from 0.34329
# Epoch 22/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5628 - accuracy: 0.2550 - val_loss: 0.5649 - val_accuracy: 0.2083
#
# Epoch 00022: val_loss did not improve from 0.34329
# Epoch 23/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5632 - accuracy: 0.2535 - val_loss: 0.5650 - val_accuracy: 0.2139
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00023: val_loss did not improve from 0.34329
# Epoch 24/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5621 - accuracy: 0.2688 - val_loss: 0.5648 - val_accuracy: 0.2167
#
# Epoch 00024: val_loss did not improve from 0.34329
# Epoch 25/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5629 - accuracy: 0.2631 - val_loss: 0.5652 - val_accuracy: 0.2139
#
# Epoch 00025: val_loss did not improve from 0.34329
# Epoch 26/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5625 - accuracy: 0.2648 - val_loss: 0.5646 - val_accuracy: 0.2222
#
# Epoch 00026: val_loss did not improve from 0.34329
# Epoch 00026: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5647 - accuracy: 0.2175
# Val Score:  [0.5647397041320801, 0.2175000011920929]
# ====================================================================================
#
#
# Training on Fold:  3
# Epoch 1/100
# 102/102 [==============================] - 2s 9ms/step - loss: 0.7618 - accuracy: 0.2587 - val_loss: 0.6090 - val_accuracy: 0.2389
#
# Epoch 00001: val_loss did not improve from 0.34329
# Epoch 2/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.6274 - accuracy: 0.2566 - val_loss: 0.5821 - val_accuracy: 0.2861
#
# Epoch 00002: val_loss did not improve from 0.34329
# Epoch 3/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5863 - accuracy: 0.2310 - val_loss: 0.5627 - val_accuracy: 0.2889
#
# Epoch 00003: val_loss did not improve from 0.34329
# Epoch 4/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5716 - accuracy: 0.2513 - val_loss: 0.5652 - val_accuracy: 0.2500
#
# Epoch 00004: val_loss did not improve from 0.34329
# Epoch 5/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5686 - accuracy: 0.2358 - val_loss: 0.5687 - val_accuracy: 0.2139
#
# Epoch 00005: val_loss did not improve from 0.34329
# Epoch 6/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5666 - accuracy: 0.2673 - val_loss: 0.5694 - val_accuracy: 0.1972
#
# Epoch 00006: val_loss did not improve from 0.34329
# Epoch 7/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5675 - accuracy: 0.2472 - val_loss: 0.5669 - val_accuracy: 0.2139
#
# Epoch 00007: val_loss did not improve from 0.34329
# Epoch 8/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5660 - accuracy: 0.2732 - val_loss: 0.5662 - val_accuracy: 0.2139
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00008: val_loss did not improve from 0.34329
# Epoch 9/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5644 - accuracy: 0.2726 - val_loss: 0.5658 - val_accuracy: 0.1972
#
# Epoch 00009: val_loss did not improve from 0.34329
# Epoch 10/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5642 - accuracy: 0.2546 - val_loss: 0.5656 - val_accuracy: 0.2250
#
# Epoch 00010: val_loss did not improve from 0.34329
# Epoch 11/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5628 - accuracy: 0.2727 - val_loss: 0.5659 - val_accuracy: 0.2056
#
# Epoch 00011: val_loss did not improve from 0.34329
# Epoch 12/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5635 - accuracy: 0.2789 - val_loss: 0.5669 - val_accuracy: 0.2167
#
# Epoch 00012: val_loss did not improve from 0.34329
# Epoch 13/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5637 - accuracy: 0.2689 - val_loss: 0.5666 - val_accuracy: 0.2083
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00013: val_loss did not improve from 0.34329
# Epoch 14/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5624 - accuracy: 0.2782 - val_loss: 0.5665 - val_accuracy: 0.1972
#
# Epoch 00014: val_loss did not improve from 0.34329
# Epoch 15/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5624 - accuracy: 0.2694 - val_loss: 0.5662 - val_accuracy: 0.1917
#
# Epoch 00015: val_loss did not improve from 0.34329
# Epoch 16/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5614 - accuracy: 0.2692 - val_loss: 0.5663 - val_accuracy: 0.2139
#
# Epoch 00016: val_loss did not improve from 0.34329
# Epoch 17/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5609 - accuracy: 0.2857 - val_loss: 0.5657 - val_accuracy: 0.2194
#
# Epoch 00017: val_loss did not improve from 0.34329
# Epoch 18/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5621 - accuracy: 0.2737 - val_loss: 0.5661 - val_accuracy: 0.2000
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00018: val_loss did not improve from 0.34329
# Epoch 19/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5630 - accuracy: 0.2696 - val_loss: 0.5651 - val_accuracy: 0.2000
#
# Epoch 00019: val_loss did not improve from 0.34329
# Epoch 20/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5593 - accuracy: 0.2904 - val_loss: 0.5642 - val_accuracy: 0.2333
#
# Epoch 00020: val_loss did not improve from 0.34329
# Epoch 21/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5593 - accuracy: 0.2900 - val_loss: 0.5651 - val_accuracy: 0.2000
#
# Epoch 00021: val_loss did not improve from 0.34329
# Epoch 22/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5583 - accuracy: 0.3090 - val_loss: 0.5657 - val_accuracy: 0.1917
#
# Epoch 00022: val_loss did not improve from 0.34329
# Epoch 23/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5593 - accuracy: 0.2842 - val_loss: 0.5620 - val_accuracy: 0.2222
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00023: val_loss did not improve from 0.34329
# Epoch 24/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5612 - accuracy: 0.2839 - val_loss: 0.5616 - val_accuracy: 0.2056
#
# Epoch 00024: val_loss did not improve from 0.34329
# Epoch 25/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5568 - accuracy: 0.2945 - val_loss: 0.5633 - val_accuracy: 0.2139
#
# Epoch 00025: val_loss did not improve from 0.34329
# Epoch 26/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5537 - accuracy: 0.3298 - val_loss: 0.5631 - val_accuracy: 0.2389
#
# Epoch 00026: val_loss did not improve from 0.34329
# Epoch 27/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5549 - accuracy: 0.3079 - val_loss: 0.5576 - val_accuracy: 0.2361
#
# Epoch 00027: val_loss did not improve from 0.34329
# Epoch 28/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5529 - accuracy: 0.3139 - val_loss: 0.5574 - val_accuracy: 0.2389
#
# Epoch 00028: val_loss did not improve from 0.34329
# Epoch 29/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5522 - accuracy: 0.3089 - val_loss: 0.5522 - val_accuracy: 0.2861
#
# Epoch 00029: val_loss did not improve from 0.34329
# Epoch 30/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5511 - accuracy: 0.3246 - val_loss: 0.5598 - val_accuracy: 0.2417
#
# Epoch 00030: val_loss did not improve from 0.34329
# Epoch 31/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5500 - accuracy: 0.3276 - val_loss: 0.5621 - val_accuracy: 0.2556
#
# Epoch 00031: val_loss did not improve from 0.34329
# Epoch 32/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5457 - accuracy: 0.3333 - val_loss: 0.5445 - val_accuracy: 0.3167
#
# Epoch 00032: val_loss did not improve from 0.34329
# Epoch 33/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5468 - accuracy: 0.3263 - val_loss: 0.5632 - val_accuracy: 0.2500
#
# Epoch 00033: val_loss did not improve from 0.34329
# Epoch 34/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5445 - accuracy: 0.3183 - val_loss: 0.5500 - val_accuracy: 0.2806
#
# Epoch 00034: val_loss did not improve from 0.34329
# Epoch 35/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5392 - accuracy: 0.3609 - val_loss: 0.5589 - val_accuracy: 0.2583
#
# Epoch 00035: val_loss did not improve from 0.34329
# Epoch 36/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5425 - accuracy: 0.3376 - val_loss: 0.5582 - val_accuracy: 0.2639
#
# Epoch 00036: val_loss did not improve from 0.34329
# Epoch 37/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5379 - accuracy: 0.3557 - val_loss: 0.5501 - val_accuracy: 0.2694
#
# Epoch 00037: val_loss did not improve from 0.34329
# Epoch 38/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5406 - accuracy: 0.3435 - val_loss: 0.5317 - val_accuracy: 0.3500
#
# Epoch 00038: val_loss did not improve from 0.34329
# Epoch 39/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5334 - accuracy: 0.3569 - val_loss: 0.5686 - val_accuracy: 0.2556
#
# Epoch 00039: val_loss did not improve from 0.34329
# Epoch 40/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5312 - accuracy: 0.3605 - val_loss: 0.5667 - val_accuracy: 0.2583
#
# Epoch 00040: val_loss did not improve from 0.34329
# Epoch 41/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5306 - accuracy: 0.3548 - val_loss: 0.5369 - val_accuracy: 0.3111
#
# Epoch 00041: val_loss did not improve from 0.34329
# Epoch 42/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5287 - accuracy: 0.3618 - val_loss: 0.5364 - val_accuracy: 0.3056
#
# Epoch 00042: val_loss did not improve from 0.34329
# Epoch 43/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5242 - accuracy: 0.3817 - val_loss: 0.5236 - val_accuracy: 0.3583
#
# Epoch 00043: val_loss did not improve from 0.34329
# Epoch 44/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5237 - accuracy: 0.3860 - val_loss: 0.5403 - val_accuracy: 0.2806
#
# Epoch 00044: val_loss did not improve from 0.34329
# Epoch 45/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5153 - accuracy: 0.4052 - val_loss: 0.5255 - val_accuracy: 0.3417
#
# Epoch 00045: val_loss did not improve from 0.34329
# Epoch 46/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5156 - accuracy: 0.4095 - val_loss: 0.5412 - val_accuracy: 0.2778
#
# Epoch 00046: val_loss did not improve from 0.34329
# Epoch 47/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5131 - accuracy: 0.3947 - val_loss: 0.5298 - val_accuracy: 0.3250
#
# Epoch 00047: val_loss did not improve from 0.34329
# Epoch 48/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5094 - accuracy: 0.4113 - val_loss: 0.5215 - val_accuracy: 0.3611
#
# Epoch 00048: val_loss did not improve from 0.34329
# Epoch 49/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5079 - accuracy: 0.3915 - val_loss: 0.5338 - val_accuracy: 0.3361
#
# Epoch 00049: val_loss did not improve from 0.34329
# Epoch 50/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5090 - accuracy: 0.3931 - val_loss: 0.5056 - val_accuracy: 0.3972
#
# Epoch 00050: val_loss did not improve from 0.34329
# Epoch 51/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5092 - accuracy: 0.3890 - val_loss: 0.5314 - val_accuracy: 0.3333
#
# Epoch 00051: val_loss did not improve from 0.34329
# Epoch 52/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4994 - accuracy: 0.4084 - val_loss: 0.5060 - val_accuracy: 0.4000
#
# Epoch 00052: val_loss did not improve from 0.34329
# Epoch 53/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4977 - accuracy: 0.4223 - val_loss: 0.5217 - val_accuracy: 0.3583
#
# Epoch 00053: val_loss did not improve from 0.34329
# Epoch 54/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5009 - accuracy: 0.4213 - val_loss: 0.5014 - val_accuracy: 0.4333
#
# Epoch 00054: val_loss did not improve from 0.34329
# Epoch 55/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4932 - accuracy: 0.4309 - val_loss: 0.4964 - val_accuracy: 0.4333
#
# Epoch 00055: val_loss did not improve from 0.34329
# Epoch 56/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4939 - accuracy: 0.4376 - val_loss: 0.5060 - val_accuracy: 0.4056
#
# Epoch 00056: val_loss did not improve from 0.34329
# Epoch 57/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4864 - accuracy: 0.4267 - val_loss: 0.5040 - val_accuracy: 0.4111
#
# Epoch 00057: val_loss did not improve from 0.34329
# Epoch 58/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4833 - accuracy: 0.4455 - val_loss: 0.4861 - val_accuracy: 0.4250
#
# Epoch 00058: val_loss did not improve from 0.34329
# Epoch 59/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4778 - accuracy: 0.4488 - val_loss: 0.4846 - val_accuracy: 0.4528
#
# Epoch 00059: val_loss did not improve from 0.34329
# Epoch 60/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4806 - accuracy: 0.4466 - val_loss: 0.4843 - val_accuracy: 0.4417
#
# Epoch 00060: val_loss did not improve from 0.34329
# Epoch 61/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4746 - accuracy: 0.4677 - val_loss: 0.4947 - val_accuracy: 0.4194
#
# Epoch 00061: val_loss did not improve from 0.34329
# Epoch 62/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4735 - accuracy: 0.4672 - val_loss: 0.4683 - val_accuracy: 0.4667
#
# Epoch 00062: val_loss did not improve from 0.34329
# Epoch 63/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4717 - accuracy: 0.4733 - val_loss: 0.4969 - val_accuracy: 0.4000
#
# Epoch 00063: val_loss did not improve from 0.34329
# Epoch 64/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4696 - accuracy: 0.4728 - val_loss: 0.4762 - val_accuracy: 0.4389
#
# Epoch 00064: val_loss did not improve from 0.34329
# Epoch 65/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4739 - accuracy: 0.4720 - val_loss: 0.4797 - val_accuracy: 0.4361
#
# Epoch 00065: val_loss did not improve from 0.34329
# Epoch 66/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4537 - accuracy: 0.4978 - val_loss: 0.4654 - val_accuracy: 0.4500
#
# Epoch 00066: val_loss did not improve from 0.34329
# Epoch 67/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4554 - accuracy: 0.4912 - val_loss: 0.4673 - val_accuracy: 0.4556
#
# Epoch 00067: val_loss did not improve from 0.34329
# Epoch 68/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4574 - accuracy: 0.4836 - val_loss: 0.4533 - val_accuracy: 0.4694
#
# Epoch 00068: val_loss did not improve from 0.34329
# Epoch 69/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4541 - accuracy: 0.4963 - val_loss: 0.4495 - val_accuracy: 0.4917
#
# Epoch 00069: val_loss did not improve from 0.34329
# Epoch 70/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4530 - accuracy: 0.4937 - val_loss: 0.4558 - val_accuracy: 0.4861
#
# Epoch 00070: val_loss did not improve from 0.34329
# Epoch 71/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4465 - accuracy: 0.4985 - val_loss: 0.4531 - val_accuracy: 0.5000
#
# Epoch 00071: val_loss did not improve from 0.34329
# Epoch 72/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4477 - accuracy: 0.4960 - val_loss: 0.4454 - val_accuracy: 0.5083
#
# Epoch 00072: val_loss did not improve from 0.34329
# Epoch 73/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4382 - accuracy: 0.5027 - val_loss: 0.4435 - val_accuracy: 0.5111
#
# Epoch 00073: val_loss did not improve from 0.34329
# Epoch 74/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4384 - accuracy: 0.5172 - val_loss: 0.4620 - val_accuracy: 0.4417
#
# Epoch 00074: val_loss did not improve from 0.34329
# Epoch 75/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4340 - accuracy: 0.5212 - val_loss: 0.4452 - val_accuracy: 0.5000
#
# Epoch 00075: val_loss did not improve from 0.34329
# Epoch 76/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4371 - accuracy: 0.5240 - val_loss: 0.4285 - val_accuracy: 0.5250
#
# Epoch 00076: val_loss did not improve from 0.34329
# Epoch 77/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4309 - accuracy: 0.5352 - val_loss: 0.4281 - val_accuracy: 0.5306
#
# Epoch 00077: val_loss did not improve from 0.34329
# Epoch 78/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4252 - accuracy: 0.5395 - val_loss: 0.4318 - val_accuracy: 0.5167
#
# Epoch 00078: val_loss did not improve from 0.34329
# Epoch 79/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4281 - accuracy: 0.5389 - val_loss: 0.4326 - val_accuracy: 0.5028
#
# Epoch 00079: val_loss did not improve from 0.34329
# Epoch 80/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4169 - accuracy: 0.5493 - val_loss: 0.4293 - val_accuracy: 0.5139
#
# Epoch 00080: val_loss did not improve from 0.34329
# Epoch 81/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4181 - accuracy: 0.5550 - val_loss: 0.4287 - val_accuracy: 0.5361
#
# Epoch 00081: val_loss did not improve from 0.34329
# Epoch 82/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4200 - accuracy: 0.5312 - val_loss: 0.4138 - val_accuracy: 0.5611
#
# Epoch 00082: val_loss did not improve from 0.34329
# Epoch 83/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4197 - accuracy: 0.5450 - val_loss: 0.4374 - val_accuracy: 0.5000
#
# Epoch 00083: val_loss did not improve from 0.34329
# Epoch 84/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4095 - accuracy: 0.5392 - val_loss: 0.4114 - val_accuracy: 0.5278
#
# Epoch 00084: val_loss did not improve from 0.34329
# Epoch 85/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4028 - accuracy: 0.5705 - val_loss: 0.4111 - val_accuracy: 0.5444
#
# Epoch 00085: val_loss did not improve from 0.34329
# Epoch 86/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4058 - accuracy: 0.5572 - val_loss: 0.4177 - val_accuracy: 0.5333
#
# Epoch 00086: val_loss did not improve from 0.34329
# Epoch 87/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3983 - accuracy: 0.5708 - val_loss: 0.4143 - val_accuracy: 0.5250
#
# Epoch 00087: val_loss did not improve from 0.34329
# Epoch 88/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4002 - accuracy: 0.5587 - val_loss: 0.4032 - val_accuracy: 0.5806
#
# Epoch 00088: val_loss did not improve from 0.34329
# Epoch 89/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3975 - accuracy: 0.5660 - val_loss: 0.4030 - val_accuracy: 0.5611
#
# Epoch 00089: val_loss did not improve from 0.34329
# Epoch 90/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3945 - accuracy: 0.5604 - val_loss: 0.3998 - val_accuracy: 0.5583
#
# Epoch 00090: val_loss did not improve from 0.34329
# Epoch 91/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3898 - accuracy: 0.5916 - val_loss: 0.3960 - val_accuracy: 0.5444
#
# Epoch 00091: val_loss did not improve from 0.34329
# Epoch 92/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3886 - accuracy: 0.5915 - val_loss: 0.3944 - val_accuracy: 0.5389
#
# Epoch 00092: val_loss did not improve from 0.34329
# Epoch 93/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3767 - accuracy: 0.6062 - val_loss: 0.4027 - val_accuracy: 0.5306
#
# Epoch 00093: val_loss did not improve from 0.34329
# Epoch 94/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3897 - accuracy: 0.5808 - val_loss: 0.4033 - val_accuracy: 0.5250
#
# Epoch 00094: val_loss did not improve from 0.34329
# Epoch 95/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3810 - accuracy: 0.5906 - val_loss: 0.3920 - val_accuracy: 0.5806
#
# Epoch 00095: val_loss did not improve from 0.34329
# Epoch 96/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3911 - accuracy: 0.5712 - val_loss: 0.3809 - val_accuracy: 0.5778
#
# Epoch 00096: val_loss did not improve from 0.34329
# Epoch 97/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3776 - accuracy: 0.5980 - val_loss: 0.3882 - val_accuracy: 0.5583
#
# Epoch 00097: val_loss did not improve from 0.34329
# Epoch 98/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3783 - accuracy: 0.5945 - val_loss: 0.3860 - val_accuracy: 0.5639
#
# Epoch 00098: val_loss did not improve from 0.34329
# Epoch 99/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3639 - accuracy: 0.6119 - val_loss: 0.3864 - val_accuracy: 0.5639
#
# Epoch 00099: val_loss did not improve from 0.34329
# Epoch 100/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3676 - accuracy: 0.6129 - val_loss: 0.3750 - val_accuracy: 0.6056
#
# Epoch 00100: val_loss did not improve from 0.34329
# 13/13 [==============================] - 0s 3ms/step - loss: 0.3780 - accuracy: 0.5600
# Val Score:  [0.37795302271842957, 0.5600000023841858]
# ====================================================================================
#
#
# Training on Fold:  4
# Epoch 1/100
# 102/102 [==============================] - 2s 9ms/step - loss: 0.7592 - accuracy: 0.2764 - val_loss: 0.6252 - val_accuracy: 0.2389
#
# Epoch 00001: val_loss did not improve from 0.34329
# Epoch 2/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.6234 - accuracy: 0.2476 - val_loss: 0.5844 - val_accuracy: 0.2361
#
# Epoch 00002: val_loss did not improve from 0.34329
# Epoch 3/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5809 - accuracy: 0.2530 - val_loss: 0.5662 - val_accuracy: 0.2556
#
# Epoch 00003: val_loss did not improve from 0.34329
# Epoch 4/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5702 - accuracy: 0.2583 - val_loss: 0.5675 - val_accuracy: 0.2083
#
# Epoch 00004: val_loss did not improve from 0.34329
# Epoch 5/100
# ...
# Epoch 21/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5597 - accuracy: 0.2873 - val_loss: 0.5629 - val_accuracy: 0.2278
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00021: val_loss did not improve from 0.28788
# Epoch 22/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5612 - accuracy: 0.2848 - val_loss: 0.5626 - val_accuracy: 0.2306
#
# Epoch 00022: val_loss did not improve from 0.28788
# Epoch 23/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5605 - accuracy: 0.2799 - val_loss: 0.5618 - val_accuracy: 0.2333
#
# Epoch 00023: val_loss did not improve from 0.28788
# Epoch 24/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5603 - accuracy: 0.2874 - val_loss: 0.5615 - val_accuracy: 0.2361
#
# Epoch 00024: val_loss did not improve from 0.28788
# Epoch 25/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5587 - accuracy: 0.2827 - val_loss: 0.5605 - val_accuracy: 0.2528
#
# Epoch 00025: val_loss did not improve from 0.28788
# Epoch 26/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5578 - accuracy: 0.3096 - val_loss: 0.5604 - val_accuracy: 0.2472
#
# Epoch 00026: val_loss did not improve from 0.28788
# Epoch 27/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5590 - accuracy: 0.2974 - val_loss: 0.5595 - val_accuracy: 0.2528
#
# Epoch 00027: val_loss did not improve from 0.28788
# Epoch 28/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5547 - accuracy: 0.3017 - val_loss: 0.5576 - val_accuracy: 0.2722
#
# Epoch 00028: val_loss did not improve from 0.28788
# Epoch 29/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5529 - accuracy: 0.3149 - val_loss: 0.5613 - val_accuracy: 0.2333
#
# Epoch 00029: val_loss did not improve from 0.28788
# Epoch 30/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5524 - accuracy: 0.3112 - val_loss: 0.5636 - val_accuracy: 0.2444
#
# Epoch 00030: val_loss did not improve from 0.28788
# Epoch 31/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5507 - accuracy: 0.3181 - val_loss: 0.5490 - val_accuracy: 0.3028
#
# Epoch 00031: val_loss did not improve from 0.28788
# Epoch 32/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5456 - accuracy: 0.3284 - val_loss: 0.5452 - val_accuracy: 0.3306
#
# Epoch 00032: val_loss did not improve from 0.28788
# Epoch 33/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5473 - accuracy: 0.3276 - val_loss: 0.5456 - val_accuracy: 0.3389
#
# Epoch 00033: val_loss did not improve from 0.28788
# Epoch 34/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5450 - accuracy: 0.3415 - val_loss: 0.5368 - val_accuracy: 0.3639
#
# Epoch 00034: val_loss did not improve from 0.28788
# Epoch 35/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5388 - accuracy: 0.3462 - val_loss: 0.5418 - val_accuracy: 0.3167
#
# Epoch 00035: val_loss did not improve from 0.28788
# Epoch 36/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5392 - accuracy: 0.3456 - val_loss: 0.5334 - val_accuracy: 0.3500
#
# Epoch 00036: val_loss did not improve from 0.28788
# Epoch 37/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5331 - accuracy: 0.3594 - val_loss: 0.5355 - val_accuracy: 0.3306
#
# Epoch 00037: val_loss did not improve from 0.28788
# Epoch 38/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.5289 - accuracy: 0.3952 - val_loss: 0.5346 - val_accuracy: 0.3528
#
# Epoch 00038: val_loss did not improve from 0.28788
# Epoch 39/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5272 - accuracy: 0.3747 - val_loss: 0.5342 - val_accuracy: 0.3361
#
# Epoch 00039: val_loss did not improve from 0.28788
# Epoch 40/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5239 - accuracy: 0.3715 - val_loss: 0.5286 - val_accuracy: 0.3417
#
# Epoch 00040: val_loss did not improve from 0.28788
# Epoch 41/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5192 - accuracy: 0.3847 - val_loss: 0.5271 - val_accuracy: 0.3694
#
# Epoch 00041: val_loss did not improve from 0.28788
# Epoch 42/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5251 - accuracy: 0.3859 - val_loss: 0.5182 - val_accuracy: 0.3667
#
# Epoch 00042: val_loss did not improve from 0.28788
# Epoch 43/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5105 - accuracy: 0.4057 - val_loss: 0.5181 - val_accuracy: 0.3556
#
# Epoch 00043: val_loss did not improve from 0.28788
# Epoch 44/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5050 - accuracy: 0.4095 - val_loss: 0.5156 - val_accuracy: 0.3583
#
# Epoch 00044: val_loss did not improve from 0.28788
# Epoch 45/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5077 - accuracy: 0.3989 - val_loss: 0.5260 - val_accuracy: 0.3361
#
# Epoch 00045: val_loss did not improve from 0.28788
# Epoch 46/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5015 - accuracy: 0.4209 - val_loss: 0.5488 - val_accuracy: 0.3111
#
# Epoch 00046: val_loss did not improve from 0.28788
# Epoch 47/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4985 - accuracy: 0.4318 - val_loss: 0.5412 - val_accuracy: 0.3056
#
# Epoch 00047: val_loss did not improve from 0.28788
# Epoch 48/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4987 - accuracy: 0.4286 - val_loss: 0.5472 - val_accuracy: 0.3111
#
# Epoch 00048: val_loss did not improve from 0.28788
# Epoch 49/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4985 - accuracy: 0.4036 - val_loss: 0.5138 - val_accuracy: 0.4083
#
# Epoch 00049: val_loss did not improve from 0.28788
# Epoch 50/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4921 - accuracy: 0.4391 - val_loss: 0.5007 - val_accuracy: 0.4250
#
# Epoch 00050: val_loss did not improve from 0.28788
# Epoch 51/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4910 - accuracy: 0.4291 - val_loss: 0.5199 - val_accuracy: 0.3361
#
# Epoch 00051: val_loss did not improve from 0.28788
# Epoch 52/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4861 - accuracy: 0.4501 - val_loss: 0.5105 - val_accuracy: 0.3778
#
# Epoch 00052: val_loss did not improve from 0.28788
# Epoch 53/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4832 - accuracy: 0.4590 - val_loss: 0.4844 - val_accuracy: 0.4333
#
# Epoch 00053: val_loss did not improve from 0.28788
# Epoch 54/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4773 - accuracy: 0.4408 - val_loss: 0.4828 - val_accuracy: 0.4333
#
# Epoch 00054: val_loss did not improve from 0.28788
# Epoch 55/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4736 - accuracy: 0.4785 - val_loss: 0.4980 - val_accuracy: 0.4361
#
# Epoch 00055: val_loss did not improve from 0.28788
# Epoch 56/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4713 - accuracy: 0.4600 - val_loss: 0.4805 - val_accuracy: 0.4556
#
# Epoch 00056: val_loss did not improve from 0.28788
# Epoch 57/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4738 - accuracy: 0.4730 - val_loss: 0.4827 - val_accuracy: 0.4417
#
# Epoch 00057: val_loss did not improve from 0.28788
# Epoch 58/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4717 - accuracy: 0.4660 - val_loss: 0.4693 - val_accuracy: 0.4500
#
# Epoch 00058: val_loss did not improve from 0.28788
# Epoch 59/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4678 - accuracy: 0.4726 - val_loss: 0.4737 - val_accuracy: 0.4583
#
# Epoch 00059: val_loss did not improve from 0.28788
# Epoch 60/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4633 - accuracy: 0.4829 - val_loss: 0.4621 - val_accuracy: 0.4750
#
# Epoch 00060: val_loss did not improve from 0.28788
# Epoch 61/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4522 - accuracy: 0.4979 - val_loss: 0.4742 - val_accuracy: 0.4639
#
# Epoch 00061: val_loss did not improve from 0.28788
# Epoch 62/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4557 - accuracy: 0.4922 - val_loss: 0.4686 - val_accuracy: 0.4750
#
# Epoch 00062: val_loss did not improve from 0.28788
# Epoch 63/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4481 - accuracy: 0.5046 - val_loss: 0.4730 - val_accuracy: 0.4722
#
# Epoch 00063: val_loss did not improve from 0.28788
# Epoch 64/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4563 - accuracy: 0.5050 - val_loss: 0.4578 - val_accuracy: 0.4750
#
# Epoch 00064: val_loss did not improve from 0.28788
# Epoch 65/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4526 - accuracy: 0.4919 - val_loss: 0.4569 - val_accuracy: 0.4806
#
# Epoch 00065: val_loss did not improve from 0.28788
# Epoch 66/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4555 - accuracy: 0.4830 - val_loss: 0.4790 - val_accuracy: 0.4889
#
# Epoch 00066: val_loss did not improve from 0.28788
# Epoch 67/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4544 - accuracy: 0.4941 - val_loss: 0.4723 - val_accuracy: 0.4917
#
# Epoch 00067: val_loss did not improve from 0.28788
# Epoch 68/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4501 - accuracy: 0.4917 - val_loss: 0.4610 - val_accuracy: 0.4722
#
# Epoch 00068: val_loss did not improve from 0.28788
# Epoch 69/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4418 - accuracy: 0.5126 - val_loss: 0.4475 - val_accuracy: 0.4972
#
# Epoch 00069: val_loss did not improve from 0.28788
# Epoch 70/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.4375 - accuracy: 0.5224 - val_loss: 0.4603 - val_accuracy: 0.4861
#
# Epoch 00070: val_loss did not improve from 0.28788
# Epoch 71/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4393 - accuracy: 0.5167 - val_loss: 0.4455 - val_accuracy: 0.5222
#
# Epoch 00071: val_loss did not improve from 0.28788
# Epoch 72/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4408 - accuracy: 0.5134 - val_loss: 0.4531 - val_accuracy: 0.4639
#
# Epoch 00072: val_loss did not improve from 0.28788
# Epoch 73/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4366 - accuracy: 0.5082 - val_loss: 0.4757 - val_accuracy: 0.4556
#
# Epoch 00073: val_loss did not improve from 0.28788
# Epoch 74/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4352 - accuracy: 0.5331 - val_loss: 0.4245 - val_accuracy: 0.5389
#
# Epoch 00074: val_loss did not improve from 0.28788
# Epoch 75/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4281 - accuracy: 0.5305 - val_loss: 0.4244 - val_accuracy: 0.5250
#
# Epoch 00075: val_loss did not improve from 0.28788
# Epoch 76/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4289 - accuracy: 0.5386 - val_loss: 0.4490 - val_accuracy: 0.5278
#
# Epoch 00076: val_loss did not improve from 0.28788
# Epoch 77/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4212 - accuracy: 0.5478 - val_loss: 0.4384 - val_accuracy: 0.5139
#
# Epoch 00077: val_loss did not improve from 0.28788
# Epoch 78/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4222 - accuracy: 0.5294 - val_loss: 0.4337 - val_accuracy: 0.5361
#
# Epoch 00078: val_loss did not improve from 0.28788
# Epoch 79/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4165 - accuracy: 0.5500 - val_loss: 0.4180 - val_accuracy: 0.5611
#
# Epoch 00079: val_loss did not improve from 0.28788
# Epoch 80/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4167 - accuracy: 0.5444 - val_loss: 0.4348 - val_accuracy: 0.5167
#
# Epoch 00080: val_loss did not improve from 0.28788
# Epoch 81/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4078 - accuracy: 0.5479 - val_loss: 0.4327 - val_accuracy: 0.5056
#
# Epoch 00081: val_loss did not improve from 0.28788
# Epoch 82/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4092 - accuracy: 0.5568 - val_loss: 0.4173 - val_accuracy: 0.5556
#
# Epoch 00082: val_loss did not improve from 0.28788
# Epoch 83/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4070 - accuracy: 0.5568 - val_loss: 0.4057 - val_accuracy: 0.5750
#
# Epoch 00083: val_loss did not improve from 0.28788
# Epoch 84/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4051 - accuracy: 0.5561 - val_loss: 0.4024 - val_accuracy: 0.5528
#
# Epoch 00084: val_loss did not improve from 0.28788
# Epoch 85/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4095 - accuracy: 0.5501 - val_loss: 0.3974 - val_accuracy: 0.5861
#
# Epoch 00085: val_loss did not improve from 0.28788
# Epoch 86/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4054 - accuracy: 0.5540 - val_loss: 0.4022 - val_accuracy: 0.5694
#
# Epoch 00086: val_loss did not improve from 0.28788
# Epoch 87/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4045 - accuracy: 0.5459 - val_loss: 0.4028 - val_accuracy: 0.5722
#
# Epoch 00087: val_loss did not improve from 0.28788
# Epoch 88/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3920 - accuracy: 0.5753 - val_loss: 0.4011 - val_accuracy: 0.5583
#
# Epoch 00088: val_loss did not improve from 0.28788
# Epoch 89/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3922 - accuracy: 0.5877 - val_loss: 0.3901 - val_accuracy: 0.5833
#
# Epoch 00089: val_loss did not improve from 0.28788
# Epoch 90/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3930 - accuracy: 0.5776 - val_loss: 0.3998 - val_accuracy: 0.5583
#
# Epoch 00090: val_loss did not improve from 0.28788
# Epoch 91/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3880 - accuracy: 0.5747 - val_loss: 0.3848 - val_accuracy: 0.5611
#
# Epoch 00091: val_loss did not improve from 0.28788
# Epoch 92/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3910 - accuracy: 0.5845 - val_loss: 0.3833 - val_accuracy: 0.5833
#
# Epoch 00092: val_loss did not improve from 0.28788
# Epoch 93/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3897 - accuracy: 0.5868 - val_loss: 0.3912 - val_accuracy: 0.5722
#
# Epoch 00093: val_loss did not improve from 0.28788
# Epoch 94/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3885 - accuracy: 0.5847 - val_loss: 0.3927 - val_accuracy: 0.5500
#
# Epoch 00094: val_loss did not improve from 0.28788
# Epoch 95/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3821 - accuracy: 0.5960 - val_loss: 0.3835 - val_accuracy: 0.5750
#
# Epoch 00095: val_loss did not improve from 0.28788
# Epoch 96/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3845 - accuracy: 0.5752 - val_loss: 0.3654 - val_accuracy: 0.5944
#
# Epoch 00096: val_loss did not improve from 0.28788
# Epoch 97/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3736 - accuracy: 0.6077 - val_loss: 0.3699 - val_accuracy: 0.5972
#
# Epoch 00097: val_loss did not improve from 0.28788
# Epoch 98/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.3773 - accuracy: 0.6002 - val_loss: 0.3640 - val_accuracy: 0.5944
#
# Epoch 00098: val_loss did not improve from 0.28788
# Epoch 99/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3721 - accuracy: 0.5918 - val_loss: 0.3763 - val_accuracy: 0.5861
#
# Epoch 00099: val_loss did not improve from 0.28788
# Epoch 100/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3721 - accuracy: 0.5946 - val_loss: 0.3800 - val_accuracy: 0.5750
#
# Epoch 00100: val_loss did not improve from 0.28788
# 13/13 [==============================] - 0s 3ms/step - loss: 0.3794 - accuracy: 0.5750
# Val Score:  [0.37936124205589294, 0.574999988079071]
# ====================================================================================

# %%
#Load the model that was saved by ModelCheckpoint
model = load_model('subjek3.h5')

# %%
model.evaluate(test_X, test_y)
#print("Accuracy of the model is - " , model.evaluate(test_X,test_y)[1]*100 , "%")
#plt.bar( model.evaluate(test_X)[1].index,  model.evaluate(test_y)[1])
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2829 - accuracy: 0.7010
# [0.28291845321655273, 0.7009999752044678]

# %%
fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)

ax1.plot(model_history[0].history['accuracy'], label='Training Fold 1 accuration')
ax1.plot(model_history[1].history['accuracy'], label='Training Fold 2 accuration')
ax1.plot(model_history[2].history['accuracy'], label='Training Fold 3 accuration')
ax1.plot(model_history[3].history['accuracy'], label='Training Fold 4 accuration')
ax1.plot(model_history[4].history['accuracy'], label='Training Fold 5 accuration')
ax1.legend()
ax2.plot(model_history[1].history['loss'], label='Training Fold 1 loss')
ax2.plot(model_history[1].history['loss'], label='Training Fold 2 loss')
ax2.plot(model_history[2].history['loss'], label='Training Fold 3 loss')
ax2.plot(model_history[3].history['loss'], label='Training Fold 4 loss ')
ax2.plot(model_history[4].history['loss'], label='Training Fold 5 loss')
ax2.legend()
plt.show()

# %%
fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt1.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[0].history['loss'], label='Train Loss Fold 1', color='black')
plt2.plot(model_history[0].history['val_loss'], label='Val Loss Fold 1', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red')
plt1.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[1].history['loss'], label='Train Loss Fold 2', color='red')
plt2.plot(model_history[1].history['val_loss'], label='Val Loss Fold 2', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green')
plt1.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[2].history['loss'], label='Train Loss Fold 3', color='green')
plt2.plot(model_history[2].history['val_loss'], label='Val Loss Fold 3', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()


fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue')
plt1.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[3].history['loss'], label='Train Loss Fold 4', color='blue')
plt2.plot(model_history[3].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='purple')
plt1.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[4].history['loss'], label='Train Loss Fold 4', color='purple')
plt2.plot(model_history[4].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

# %%
MODEL_NAME ='/content/subjek3.h5' 

#CLIP = True # if your model was trained with np.clip to clip  values
CLIP = False
CLIP_VAL = 8  # if above, what was the value +/-

model = tf.keras.models.load_model(MODEL_NAME)

VALDIR = '/content/drive/MyDrive/Colab Notebooks/AFIF/subjek3tes'
ACTIONS =  ["idle","maju","kiri", "kanan"]
PRED_BATCH = 32


def get_val_data(valdir, action, batch_size):

   # argmax_dict = {0: 0, 1: 0, 2: 0,3:0}
    argmax_dict = {2: 0, 0: 0, 1: 0,3:0}
    raw_pred_dict = {0: 0, 1: 0, 2: 0,3:0}

    action_dir = os.path.join(valdir, action)
    for session_file in os.listdir(action_dir):
        filepath = os.path.join(action_dir,session_file)
        if CLIP:
            data = np.clip(np.load(filepath), -CLIP_VAL, CLIP_VAL) / CLIP_VAL
            #print(data)
        else:
            data = np.load(filepath) 
        preds = model.predict([data.reshape(-1, 16, 60,1)], batch_size=batch_size)
        
        for pred in preds:
            argmax = np.argmax(pred)
            argmax_dict[argmax] += 1
            for idx,value in enumerate(pred):
                raw_pred_dict[idx] += value
    
    argmax_pct_dict = {}
    for i in argmax_dict:
        total = 0
        correct = argmax_dict[i]
        for ii in argmax_dict:
            total += argmax_dict[ii]
        argmax_pct_dict[i] = round(correct/total, 4)
    return argmax_dict, raw_pred_dict, argmax_pct_dict


def make_conf_mat(none,left,forward, right):
    action_dict = {"idle":none,"maju": forward, "kiri": left, "kanan": right}
    action_conf_mat = pd.DataFrame(action_dict)
    actions = [i for i in action_dict]

    fig = plt.figure(figsize=(15, 6))
    ax = fig.add_subplot(111)
    ax.matshow(action_conf_mat, cmap=plt.cm.RdYlGn)
    ax.set_xticklabels([""]+actions)
    ax.set_yticklabels([""]+actions)

    for idx, i in enumerate(action_dict):
        for idx2, ii in enumerate(action_dict[i]):
            ax.text(idx, idx2, f"{round(float(action_dict[i][ii]),2)}", va='center', ha='center')
    # Rotate the tick labels and set their alignment.
    
    plt.title("Matrik data")
    plt.ylabel("Predicted Action")
    fig.tight_layout()
    plt.show()



forward_argmax_dict, forward_raw_pred_dict, forward_argmax_pct_dict = get_val_data(VALDIR, "maju", PRED_BATCH)
none_argmax_dict, none_raw_pred_dict, none_argmax_pct_dict = get_val_data(VALDIR, "idle", PRED_BATCH)
left_argmax_dict, left_raw_pred_dict, left_argmax_pct_dict = get_val_data(VALDIR, "kiri", PRED_BATCH)
right_argmax_dict, right_raw_pred_dict, right_argmax_pct_dict = get_val_data(VALDIR, "kanan", PRED_BATCH)
make_conf_mat(none_argmax_pct_dict,forward_argmax_pct_dict,left_argmax_pct_dict,  right_argmax_pct_dict)

# %%
from sklearn.metrics import roc_curve, auc
#y_score = clf.decision_function(xval)
y_score = model.predict(test_X)

#Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()


# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(test_y[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
    
    
print("roc_auc:",sum(roc_auc.values())/4)
ACTIONS =  ["idle","maju","kiri", "kanan"]
for i in range(0,4):
    plt.figure()
    fig, ax = plt.subplots(figsize=(5,5))
    plt.plot(fpr[i], tpr[i],linewidth=3)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    #plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % ACTIONS[i])
    plt.title('%s -ROC curve (area = %0.2f)' % (ACTIONS[i],roc_auc[i]))
    
    plt.legend(loc="lower right")
    plt.show()
# Out:
# roc_auc: 0.9149813333333333

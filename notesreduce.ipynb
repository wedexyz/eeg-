# %% [markdown]
# <a href="https://colab.research.google.com/github/wedexyz/eeg-/blob/main/notesreduce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.18.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (0.17.0)

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM, BatchNormalization, Conv2D, Flatten, MaxPooling2D, Dropout
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.optimizers import Adam
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (20,7)
import pandas as pd
import os
import random
import time
import os
from keras.callbacks import ModelCheckpoint, EarlyStopping
#from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator

# %%
idle = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/idle/1604315006.npy")
kanan = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kanan/1604315180.npy")
kiri = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kiri/1604315126.npy")
maju = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/maju/1604315069.npy")

fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('idle')
ax1.plot(idle[0][16])
ax2.plot(idle[175])

fig, (ax3, ax4) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('kanan')
ax3.plot(kanan[0][16])
ax4.plot(kanan[175])

fig, (ax5, ax6) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('kiri')
ax5.plot(kiri[0][16])
ax6.plot(kiri[175])

fig, (ax7, ax8) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('maju')
ax7.plot(maju[0][16])
ax8.plot(maju[175])



plt.show()

# %%
ACTIONS = ["kiri", "maju","idle","kanan"]
reshape = (-1,16, 60,1)
#reshape(-1,28,28,1)

# %%
def create_data(starting_dir="=/content/drive/My Drive/Colab Notebooks/data_baru"):
    training_data = {}
    for action in ACTIONS:
        if action not in training_data:
            training_data[action] = []
        data_dir = os.path.join(starting_dir,action)
        for item in os.listdir(data_dir):
            data = np.load(os.path.join(data_dir, item))
            for item in data:
                training_data[action].append(item)

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)

    for action in ACTIONS:
        np.random.shuffle(training_data[action])  
        training_data[action] = training_data[action][:min(lengths)]

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)
    combined_data = []
    for action in ACTIONS:
        for data in training_data[action]:
            if action == "kiri":
                combined_data.append([data, [1, 0, 0,0]])
            elif action == "maju":
                combined_data.append([data, [0, 1, 0, 0]])
            elif action == "idle":
                combined_data.append([data, [0, 0, 1, 0]])
            elif action == "kanan":
                combined_data.append([data, [0, 0, 0, 1]])

    np.random.shuffle(combined_data)
    print("length:",len(combined_data))
    return combined_data

# %%
print("creating training data")
traindata = create_data(starting_dir="/content/drive/My Drive/Colab Notebooks/data_baru")
train_X = []
train_y = []
for X, y in traindata:
    train_X.append(X)
    train_y.append(y)
# Out:
# creating training data
# [1000, 1000, 1000, 1000]
# [1000, 1000, 1000, 1000]
# length: 4000

# %%
print("creating testing data")
testdata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/tes_data")
test_X = []
test_y = []

for X, y in testdata:
    test_X.append(X)
    test_y.append(y)
train_X = np.array(train_X).reshape(reshape)
test_X = np.array(test_X).reshape(reshape)

train_y = np.array(train_y)
test_y = np.array(test_y)
# Out:
# creating testing data
# [250, 250, 250, 250]
# [250, 250, 250, 250]
# length: 1000

# %%
f, ax = plt.subplots(2,4) 
f.set_size_inches(10, 10)
k = 0
for i in range(2):
    for j in range(4):
       # ax[i,j].imshow(train_X [k].reshape(28, 28) , cmap = "gray")
        ax[i,j].imshow(train_X [k].reshape(16,60)  ,cmap = "gray")
        k += 1
    plt.tight_layout()

# %%
IMAGE_SIZE = (16, 60, 1)

# %%
# With data augmentation to prevent overfitting

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(train_X)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1,factor=0.5, min_lr=0.0001)

# %%
def cnn_model(size, num_cnn_layers):
    

    model = Sequential()
    
    model.add(Conv2D(filters = 64, kernel_size = (7,7), padding = "same", activation = "relu", input_shape=train_X.shape[1:]))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Conv2D(filters = 64, kernel_size = (5,5), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (5,5)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Conv2D(filters = 64, kernel_size = (3,3), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (3,3)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Flatten())
    
    model.add(Dense(32, activation = "relu"))
    model.add(BatchNormalization())

    model.add(Dense(4, activation = "sigmoid"))
   
    #adam = Adam(lr = 0.001)
    model.compile(optimizer ="adam", loss = "binary_crossentropy", metrics = ['accuracy'])
    #model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
 
    
    return model

# %%
model = cnn_model(IMAGE_SIZE, 2)
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_42 (Conv2D)           (None, 16, 60, 64)        3200
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 16, 60, 64)        256
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 16, 60, 64)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 16, 60, 64)        102464
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 3, 12, 64)         0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 3, 12, 64)         0
# _________________________________________________________________
# batch_normalization_57 (Batc (None, 3, 12, 64)         256
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 3, 12, 64)         36928
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 1, 4, 64)          0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 1, 4, 64)          0
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 1, 4, 64)          256
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 32)                8224
# _________________________________________________________________
# batch_normalization_59 (Batc (None, 32)                128
# _________________________________________________________________
# dense_29 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 151,844
# Trainable params: 151,396
# Non-trainable params: 448
# _________________________________________________________________

# %%
#set early stopping criteria
pat = 5
#this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='loss', patience=pat, verbose=1)

#define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('fas_mnist_1.h5', verbose=1, save_best_only=True)

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=100, BATCH_SIZE=64):
    model = None
    model = cnn_model(IMAGE_SIZE, 2)
    #Model = model
   # results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[early_stopping, model_checkpoint], 
   #           verbose=1, validation_split=0.1) 
    results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[learning_rate_reduction,early_stopping, model_checkpoint], 
              verbose=1, validation_split=0.1)   
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs=100
batch_size=64

#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(train_X, train_y, test_size=0.1, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
   
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 48/51 [===========================>..] - ETA: 0s - loss: 0.7458 - accuracy: 0.2594
# Epoch 00001: val_loss improved from inf to 0.63341, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 16ms/step - loss: 0.7425 - accuracy: 0.2577 - val_loss: 0.6334 - val_accuracy: 0.2444
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.6614 - accuracy: 0.2670
# Epoch 00002: val_loss improved from 0.63341 to 0.59602, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.6614 - accuracy: 0.2670 - val_loss: 0.5960 - val_accuracy: 0.3083
# Epoch 3/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.6194 - accuracy: 0.2704
# Epoch 00003: val_loss improved from 0.59602 to 0.58020, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.6183 - accuracy: 0.2722 - val_loss: 0.5802 - val_accuracy: 0.3083
# Epoch 4/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.5912 - accuracy: 0.2993
# Epoch 00004: val_loss improved from 0.58020 to 0.56704, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.5908 - accuracy: 0.2966 - val_loss: 0.5670 - val_accuracy: 0.3111
# Epoch 5/100
# 47/51 [==========================>...] - ETA: 0s - loss: 0.5694 - accuracy: 0.3188
# Epoch 00005: val_loss improved from 0.56704 to 0.56397, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.5690 - accuracy: 0.3182 - val_loss: 0.5640 - val_accuracy: 0.2944
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5565 - accuracy: 0.3275
# Epoch 00006: val_loss improved from 0.56397 to 0.56252, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.5565 - accuracy: 0.3275 - val_loss: 0.5625 - val_accuracy: 0.2306
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5443 - accuracy: 0.3481
# Epoch 00007: val_loss did not improve from 0.56252
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5443 - accuracy: 0.3481 - val_loss: 0.5773 - val_accuracy: 0.2306
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5331 - accuracy: 0.3722
# Epoch 00008: val_loss did not improve from 0.56252
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5331 - accuracy: 0.3722 - val_loss: 0.5867 - val_accuracy: 0.2306
# Epoch 9/100
# 48/51 [===========================>..] - ETA: 0s - loss: 0.5162 - accuracy: 0.4157
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00009: val_loss did not improve from 0.56252
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5155 - accuracy: 0.4151 - val_loss: 0.6200 - val_accuracy: 0.2306
# Epoch 10/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.4887 - accuracy: 0.4596
# Epoch 00010: val_loss did not improve from 0.56252
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4879 - accuracy: 0.4605 - val_loss: 0.6220 - val_accuracy: 0.2306
# Epoch 11/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.4750 - accuracy: 0.4718
# Epoch 00011: val_loss did not improve from 0.56252
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4734 - accuracy: 0.4738 - val_loss: 0.5922 - val_accuracy: 0.2472
# Epoch 12/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.4524 - accuracy: 0.5153
# Epoch 00012: val_loss improved from 0.56252 to 0.55912, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4516 - accuracy: 0.5170 - val_loss: 0.5591 - val_accuracy: 0.2639
# Epoch 13/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.4389 - accuracy: 0.5170
# Epoch 00013: val_loss improved from 0.55912 to 0.55286, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4383 - accuracy: 0.5173 - val_loss: 0.5529 - val_accuracy: 0.2889
# Epoch 14/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.4156 - accuracy: 0.5591
# Epoch 00014: val_loss improved from 0.55286 to 0.52739, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4171 - accuracy: 0.5568 - val_loss: 0.5274 - val_accuracy: 0.3389
# Epoch 15/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.4014 - accuracy: 0.5808
# Epoch 00015: val_loss improved from 0.52739 to 0.46678, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4021 - accuracy: 0.5809 - val_loss: 0.4668 - val_accuracy: 0.5250
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3873 - accuracy: 0.5920
# Epoch 00016: val_loss improved from 0.46678 to 0.45028, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3873 - accuracy: 0.5920 - val_loss: 0.4503 - val_accuracy: 0.5194
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3721 - accuracy: 0.6157
# Epoch 00017: val_loss improved from 0.45028 to 0.40288, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3721 - accuracy: 0.6157 - val_loss: 0.4029 - val_accuracy: 0.5750
# Epoch 18/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.3521 - accuracy: 0.6498
# Epoch 00018: val_loss improved from 0.40288 to 0.39198, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3528 - accuracy: 0.6491 - val_loss: 0.3920 - val_accuracy: 0.5833
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3421 - accuracy: 0.6546
# Epoch 00019: val_loss improved from 0.39198 to 0.38458, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3421 - accuracy: 0.6546 - val_loss: 0.3846 - val_accuracy: 0.5944
# Epoch 20/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.3240 - accuracy: 0.6780
# Epoch 00020: val_loss improved from 0.38458 to 0.34730, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3243 - accuracy: 0.6744 - val_loss: 0.3473 - val_accuracy: 0.6333
# Epoch 21/100
# 47/51 [==========================>...] - ETA: 0s - loss: 0.3146 - accuracy: 0.6852
# Epoch 00021: val_loss did not improve from 0.34730
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3132 - accuracy: 0.6877 - val_loss: 0.3481 - val_accuracy: 0.6194
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2983 - accuracy: 0.7034
# Epoch 00022: val_loss improved from 0.34730 to 0.29558, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2983 - accuracy: 0.7034 - val_loss: 0.2956 - val_accuracy: 0.6722
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2893 - accuracy: 0.7025
# Epoch 00023: val_loss did not improve from 0.29558
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2893 - accuracy: 0.7025 - val_loss: 0.3158 - val_accuracy: 0.6417
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2810 - accuracy: 0.7090
# Epoch 00024: val_loss improved from 0.29558 to 0.28839, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2810 - accuracy: 0.7090 - val_loss: 0.2884 - val_accuracy: 0.6917
# Epoch 25/100
# 47/51 [==========================>...] - ETA: 0s - loss: 0.2710 - accuracy: 0.7188
# Epoch 00025: val_loss improved from 0.28839 to 0.28542, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2728 - accuracy: 0.7160 - val_loss: 0.2854 - val_accuracy: 0.7083
# Epoch 26/100
# 47/51 [==========================>...] - ETA: 0s - loss: 0.2625 - accuracy: 0.7241
# Epoch 00026: val_loss improved from 0.28542 to 0.25191, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2625 - accuracy: 0.7241 - val_loss: 0.2519 - val_accuracy: 0.7139
# Epoch 27/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.2555 - accuracy: 0.7334
# Epoch 00027: val_loss did not improve from 0.25191
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2562 - accuracy: 0.7306 - val_loss: 0.2549 - val_accuracy: 0.7333
# Epoch 28/100
# 48/51 [===========================>..] - ETA: 0s - loss: 0.2573 - accuracy: 0.7282
# Epoch 00028: val_loss improved from 0.25191 to 0.24713, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2562 - accuracy: 0.7296 - val_loss: 0.2471 - val_accuracy: 0.7278
# Epoch 29/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.2468 - accuracy: 0.7412
# Epoch 00029: val_loss improved from 0.24713 to 0.23004, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2469 - accuracy: 0.7392 - val_loss: 0.2300 - val_accuracy: 0.7861
# Epoch 30/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.2408 - accuracy: 0.7418
# Epoch 00030: val_loss did not improve from 0.23004
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2387 - accuracy: 0.7454 - val_loss: 0.2394 - val_accuracy: 0.7389
# Epoch 31/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.2300 - accuracy: 0.7517
# Epoch 00031: val_loss improved from 0.23004 to 0.22922, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2336 - accuracy: 0.7485 - val_loss: 0.2292 - val_accuracy: 0.7667
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2326 - accuracy: 0.7509
# Epoch 00032: val_loss improved from 0.22922 to 0.21484, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2326 - accuracy: 0.7509 - val_loss: 0.2148 - val_accuracy: 0.7722
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2288 - accuracy: 0.7460
# Epoch 00033: val_loss did not improve from 0.21484
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2288 - accuracy: 0.7460 - val_loss: 0.2202 - val_accuracy: 0.7833
# Epoch 34/100
# 47/51 [==========================>...] - ETA: 0s - loss: 0.2224 - accuracy: 0.7566
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00034: val_loss did not improve from 0.21484
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2212 - accuracy: 0.7596 - val_loss: 0.2205 - val_accuracy: 0.7722
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2115 - accuracy: 0.7676
# Epoch 00035: val_loss improved from 0.21484 to 0.21103, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2115 - accuracy: 0.7676 - val_loss: 0.2110 - val_accuracy: 0.7500
# Epoch 36/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.2044 - accuracy: 0.7714
# Epoch 00036: val_loss improved from 0.21103 to 0.20609, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2045 - accuracy: 0.7719 - val_loss: 0.2061 - val_accuracy: 0.7889
# Epoch 37/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.2050 - accuracy: 0.7707
# Epoch 00037: val_loss did not improve from 0.20609
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2062 - accuracy: 0.7685 - val_loss: 0.2079 - val_accuracy: 0.8028
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2081 - accuracy: 0.7673
# Epoch 00038: val_loss improved from 0.20609 to 0.19908, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2081 - accuracy: 0.7673 - val_loss: 0.1991 - val_accuracy: 0.7722
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1959 - accuracy: 0.7926
# Epoch 00039: val_loss improved from 0.19908 to 0.19145, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1959 - accuracy: 0.7926 - val_loss: 0.1914 - val_accuracy: 0.8028
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1956 - accuracy: 0.7806
# Epoch 00040: val_loss did not improve from 0.19145
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1956 - accuracy: 0.7806 - val_loss: 0.1967 - val_accuracy: 0.7806
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.7833
# Epoch 00041: val_loss improved from 0.19145 to 0.18921, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1952 - accuracy: 0.7833 - val_loss: 0.1892 - val_accuracy: 0.7889
# Epoch 42/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1948 - accuracy: 0.7823
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00042: val_loss improved from 0.18921 to 0.18665, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1961 - accuracy: 0.7812 - val_loss: 0.1866 - val_accuracy: 0.7861
# Epoch 43/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1924 - accuracy: 0.7799
# Epoch 00043: val_loss improved from 0.18665 to 0.18502, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1895 - accuracy: 0.7833 - val_loss: 0.1850 - val_accuracy: 0.8111
# Epoch 44/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1880 - accuracy: 0.7853
# Epoch 00044: val_loss improved from 0.18502 to 0.18247, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1879 - accuracy: 0.7852 - val_loss: 0.1825 - val_accuracy: 0.8250
# Epoch 45/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1825 - accuracy: 0.8010
# Epoch 00045: val_loss did not improve from 0.18247
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1863 - accuracy: 0.7972 - val_loss: 0.1840 - val_accuracy: 0.8194
# Epoch 46/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1843 - accuracy: 0.7887
# Epoch 00046: val_loss improved from 0.18247 to 0.18156, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1840 - accuracy: 0.7895 - val_loss: 0.1816 - val_accuracy: 0.7861
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1827 - accuracy: 0.7991
# Epoch 00047: val_loss did not improve from 0.18156
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1827 - accuracy: 0.7991 - val_loss: 0.1848 - val_accuracy: 0.8250
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.7988
# Epoch 00048: val_loss did not improve from 0.18156
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1845 - accuracy: 0.7988 - val_loss: 0.1841 - val_accuracy: 0.8222
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1795 - accuracy: 0.8040
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00049: val_loss improved from 0.18156 to 0.17884, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1795 - accuracy: 0.8040 - val_loss: 0.1788 - val_accuracy: 0.8222
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1780 - accuracy: 0.8031
# Epoch 00050: val_loss did not improve from 0.17884
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1780 - accuracy: 0.8031 - val_loss: 0.1798 - val_accuracy: 0.8306
# Epoch 51/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1807 - accuracy: 0.7935
# Epoch 00051: val_loss improved from 0.17884 to 0.17693, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1813 - accuracy: 0.7935 - val_loss: 0.1769 - val_accuracy: 0.8250
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.7988
# Epoch 00052: val_loss did not improve from 0.17693
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1802 - accuracy: 0.7988 - val_loss: 0.1818 - val_accuracy: 0.8139
# Epoch 53/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1772 - accuracy: 0.7979
# Epoch 00053: val_loss did not improve from 0.17693
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1763 - accuracy: 0.7985 - val_loss: 0.1777 - val_accuracy: 0.8222
# Epoch 54/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1822 - accuracy: 0.7891
# Epoch 00054: val_loss did not improve from 0.17693
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1813 - accuracy: 0.7917 - val_loss: 0.1807 - val_accuracy: 0.7861
# Epoch 55/100
# 48/51 [===========================>..] - ETA: 0s - loss: 0.1824 - accuracy: 0.7923
# Epoch 00055: val_loss improved from 0.17693 to 0.17605, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1818 - accuracy: 0.7948 - val_loss: 0.1761 - val_accuracy: 0.8250
# Epoch 56/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1781 - accuracy: 0.7962
# Epoch 00056: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1806 - accuracy: 0.7932 - val_loss: 0.1785 - val_accuracy: 0.7917
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1786 - accuracy: 0.8000
# Epoch 00057: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1786 - accuracy: 0.8000 - val_loss: 0.1814 - val_accuracy: 0.8000
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1780 - accuracy: 0.8006
# Epoch 00058: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1780 - accuracy: 0.8006 - val_loss: 0.1799 - val_accuracy: 0.7833
# Epoch 00058: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1906 - accuracy: 0.7825
# Val Score:  [0.19063200056552887, 0.7825000286102295]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.7399 - accuracy: 0.2590
# Epoch 00001: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 14ms/step - loss: 0.7399 - accuracy: 0.2590 - val_loss: 0.6542 - val_accuracy: 0.2306
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.6484 - accuracy: 0.2753
# Epoch 00002: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.6484 - accuracy: 0.2753 - val_loss: 0.6318 - val_accuracy: 0.2361
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.6068 - accuracy: 0.2840
# Epoch 00003: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.6068 - accuracy: 0.2840 - val_loss: 0.5994 - val_accuracy: 0.2361
# Epoch 4/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.5814 - accuracy: 0.3033
# Epoch 00004: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5803 - accuracy: 0.3049 - val_loss: 0.5783 - val_accuracy: 0.2361
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5675 - accuracy: 0.3062
# Epoch 00005: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5675 - accuracy: 0.3062 - val_loss: 0.5708 - val_accuracy: 0.2361
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5555 - accuracy: 0.3330
# Epoch 00006: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5555 - accuracy: 0.3330 - val_loss: 0.5673 - val_accuracy: 0.2361
# Epoch 7/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.5490 - accuracy: 0.3404
# Epoch 00007: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5481 - accuracy: 0.3423 - val_loss: 0.5645 - val_accuracy: 0.2806
# Epoch 8/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.5401 - accuracy: 0.3651
# Epoch 00008: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5388 - accuracy: 0.3670 - val_loss: 0.5643 - val_accuracy: 0.2833
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5271 - accuracy: 0.3799
# Epoch 00009: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5271 - accuracy: 0.3799 - val_loss: 0.5737 - val_accuracy: 0.2750
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5139 - accuracy: 0.4201
# Epoch 00010: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5139 - accuracy: 0.4201 - val_loss: 0.5870 - val_accuracy: 0.2750
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4938 - accuracy: 0.4466
# Epoch 00011: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4938 - accuracy: 0.4466 - val_loss: 0.5846 - val_accuracy: 0.2750
# Epoch 12/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.4703 - accuracy: 0.4825
# Epoch 00012: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4704 - accuracy: 0.4818 - val_loss: 0.5744 - val_accuracy: 0.2889
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4492 - accuracy: 0.5102
# Epoch 00013: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4492 - accuracy: 0.5102 - val_loss: 0.5619 - val_accuracy: 0.3500
# Epoch 14/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.4316 - accuracy: 0.5431
# Epoch 00014: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4285 - accuracy: 0.5454 - val_loss: 0.4884 - val_accuracy: 0.5222
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3963 - accuracy: 0.5796
# Epoch 00015: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3963 - accuracy: 0.5796 - val_loss: 0.4981 - val_accuracy: 0.4028
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3721 - accuracy: 0.6167
# Epoch 00016: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3721 - accuracy: 0.6167 - val_loss: 0.4506 - val_accuracy: 0.4944
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3448 - accuracy: 0.6503
# Epoch 00017: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3448 - accuracy: 0.6503 - val_loss: 0.6106 - val_accuracy: 0.3806
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3191 - accuracy: 0.6735
# Epoch 00018: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3191 - accuracy: 0.6735 - val_loss: 0.4245 - val_accuracy: 0.5083
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3117 - accuracy: 0.6716
# Epoch 00019: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3117 - accuracy: 0.6716 - val_loss: 0.3995 - val_accuracy: 0.5472
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2963 - accuracy: 0.6904
# Epoch 00020: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2963 - accuracy: 0.6904 - val_loss: 0.2956 - val_accuracy: 0.7000
# Epoch 21/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.2725 - accuracy: 0.7191
# Epoch 00021: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2736 - accuracy: 0.7179 - val_loss: 0.3672 - val_accuracy: 0.5750
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2638 - accuracy: 0.7241
# Epoch 00022: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2638 - accuracy: 0.7241 - val_loss: 0.2599 - val_accuracy: 0.7444
# Epoch 23/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.2596 - accuracy: 0.7276
# Epoch 00023: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2599 - accuracy: 0.7247 - val_loss: 0.2461 - val_accuracy: 0.7389
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2456 - accuracy: 0.7349
# Epoch 00024: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2456 - accuracy: 0.7349 - val_loss: 0.2927 - val_accuracy: 0.6667
# Epoch 25/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.2464 - accuracy: 0.7388
# Epoch 00025: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2478 - accuracy: 0.7364 - val_loss: 0.2925 - val_accuracy: 0.6667
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2363 - accuracy: 0.7466
# Epoch 00026: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2363 - accuracy: 0.7466 - val_loss: 0.2979 - val_accuracy: 0.6944
# Epoch 27/100
# 47/51 [==========================>...] - ETA: 0s - loss: 0.2336 - accuracy: 0.7517
# Epoch 00027: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2350 - accuracy: 0.7481 - val_loss: 0.2319 - val_accuracy: 0.7500
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2278 - accuracy: 0.7552
# Epoch 00028: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2278 - accuracy: 0.7552 - val_loss: 0.2296 - val_accuracy: 0.7556
# Epoch 29/100
# 47/51 [==========================>...] - ETA: 0s - loss: 0.2224 - accuracy: 0.7523
# Epoch 00029: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2218 - accuracy: 0.7534 - val_loss: 0.2156 - val_accuracy: 0.7750
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2135 - accuracy: 0.7611
# Epoch 00030: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2135 - accuracy: 0.7611 - val_loss: 0.2339 - val_accuracy: 0.7222
# Epoch 31/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.2103 - accuracy: 0.7643
# Epoch 00031: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2119 - accuracy: 0.7636 - val_loss: 0.2367 - val_accuracy: 0.7472
# Epoch 32/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2118 - accuracy: 0.7625
# Epoch 00032: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2120 - accuracy: 0.7617 - val_loss: 0.2118 - val_accuracy: 0.7778
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.7660
# Epoch 00033: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2117 - accuracy: 0.7660 - val_loss: 0.3068 - val_accuracy: 0.6722
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2130 - accuracy: 0.7698
# Epoch 00034: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2130 - accuracy: 0.7698 - val_loss: 0.2090 - val_accuracy: 0.7750
# Epoch 35/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1980 - accuracy: 0.7782
# Epoch 00035: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1955 - accuracy: 0.7827 - val_loss: 0.2098 - val_accuracy: 0.7694
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1975 - accuracy: 0.7772
# Epoch 00036: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1975 - accuracy: 0.7772 - val_loss: 0.1965 - val_accuracy: 0.7833
# Epoch 37/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1962 - accuracy: 0.7796
# Epoch 00037: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1941 - accuracy: 0.7827 - val_loss: 0.2215 - val_accuracy: 0.7389
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1894 - accuracy: 0.7904
# Epoch 00038: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1894 - accuracy: 0.7904 - val_loss: 0.1968 - val_accuracy: 0.7778
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1894 - accuracy: 0.7926
# Epoch 00039: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1894 - accuracy: 0.7926 - val_loss: 0.1951 - val_accuracy: 0.7722
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1873 - accuracy: 0.7904
# Epoch 00040: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1873 - accuracy: 0.7904 - val_loss: 0.2060 - val_accuracy: 0.7694
# Epoch 41/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1855 - accuracy: 0.7904
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00041: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1860 - accuracy: 0.7892 - val_loss: 0.2243 - val_accuracy: 0.7444
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1791 - accuracy: 0.7997
# Epoch 00042: val_loss did not improve from 0.17605
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1791 - accuracy: 0.7997 - val_loss: 0.1833 - val_accuracy: 0.7944
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1743 - accuracy: 0.7991
# Epoch 00043: val_loss improved from 0.17605 to 0.17363, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1743 - accuracy: 0.7991 - val_loss: 0.1736 - val_accuracy: 0.8083
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1704 - accuracy: 0.8043
# Epoch 00044: val_loss did not improve from 0.17363
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1704 - accuracy: 0.8043 - val_loss: 0.1785 - val_accuracy: 0.8000
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1732 - accuracy: 0.7948
# Epoch 00045: val_loss did not improve from 0.17363
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1732 - accuracy: 0.7948 - val_loss: 0.1786 - val_accuracy: 0.7917
# Epoch 46/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1676 - accuracy: 0.7993
# Epoch 00046: val_loss did not improve from 0.17363
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1672 - accuracy: 0.8000 - val_loss: 0.1795 - val_accuracy: 0.7778
# Epoch 47/100
# 47/51 [==========================>...] - ETA: 0s - loss: 0.1645 - accuracy: 0.8082
# Epoch 00047: val_loss improved from 0.17363 to 0.17129, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1655 - accuracy: 0.8071 - val_loss: 0.1713 - val_accuracy: 0.8139
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1661 - accuracy: 0.8080
# Epoch 00048: val_loss did not improve from 0.17129
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1661 - accuracy: 0.8080 - val_loss: 0.1795 - val_accuracy: 0.8000
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1626 - accuracy: 0.8083
# Epoch 00049: val_loss did not improve from 0.17129
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1626 - accuracy: 0.8083 - val_loss: 0.1718 - val_accuracy: 0.8056
# Epoch 50/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1623 - accuracy: 0.8023
# Epoch 00050: val_loss did not improve from 0.17129
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1616 - accuracy: 0.8028 - val_loss: 0.1719 - val_accuracy: 0.8083
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1627 - accuracy: 0.8068
# Epoch 00051: val_loss did not improve from 0.17129
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1627 - accuracy: 0.8068 - val_loss: 0.1765 - val_accuracy: 0.8028
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1645 - accuracy: 0.8071
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00052: val_loss did not improve from 0.17129
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1645 - accuracy: 0.8071 - val_loss: 0.1836 - val_accuracy: 0.7944
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1601 - accuracy: 0.8090
# Epoch 00053: val_loss did not improve from 0.17129
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1601 - accuracy: 0.8090 - val_loss: 0.1716 - val_accuracy: 0.8139
# Epoch 54/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1600 - accuracy: 0.8037
# Epoch 00054: val_loss improved from 0.17129 to 0.16832, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1578 - accuracy: 0.8059 - val_loss: 0.1683 - val_accuracy: 0.8167
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1552 - accuracy: 0.8188
# Epoch 00055: val_loss improved from 0.16832 to 0.16752, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1552 - accuracy: 0.8188 - val_loss: 0.1675 - val_accuracy: 0.8111
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1553 - accuracy: 0.8136
# Epoch 00056: val_loss improved from 0.16752 to 0.16557, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1553 - accuracy: 0.8136 - val_loss: 0.1656 - val_accuracy: 0.8167
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1529 - accuracy: 0.8219
# Epoch 00057: val_loss did not improve from 0.16557
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1529 - accuracy: 0.8219 - val_loss: 0.1675 - val_accuracy: 0.8139
# Epoch 58/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1549 - accuracy: 0.8156
# Epoch 00058: val_loss improved from 0.16557 to 0.16543, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1567 - accuracy: 0.8133 - val_loss: 0.1654 - val_accuracy: 0.8139
# Epoch 59/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1554 - accuracy: 0.8176
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00059: val_loss did not improve from 0.16543
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1557 - accuracy: 0.8157 - val_loss: 0.1659 - val_accuracy: 0.8167
# Epoch 60/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1546 - accuracy: 0.8122
# Epoch 00060: val_loss improved from 0.16543 to 0.16172, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1558 - accuracy: 0.8127 - val_loss: 0.1617 - val_accuracy: 0.8167
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1535 - accuracy: 0.8188
# Epoch 00061: val_loss improved from 0.16172 to 0.15966, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1535 - accuracy: 0.8188 - val_loss: 0.1597 - val_accuracy: 0.8167
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1510 - accuracy: 0.8201
# Epoch 00062: val_loss did not improve from 0.15966
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1510 - accuracy: 0.8201 - val_loss: 0.1604 - val_accuracy: 0.8111
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1526 - accuracy: 0.8117
# Epoch 00063: val_loss improved from 0.15966 to 0.15929, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1526 - accuracy: 0.8117 - val_loss: 0.1593 - val_accuracy: 0.8167
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 0.8120
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00064: val_loss improved from 0.15929 to 0.15874, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 13ms/step - loss: 0.1545 - accuracy: 0.8120 - val_loss: 0.1587 - val_accuracy: 0.8139
# Epoch 65/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.1530 - accuracy: 0.8179
# Epoch 00065: val_loss improved from 0.15874 to 0.15807, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1518 - accuracy: 0.8201 - val_loss: 0.1581 - val_accuracy: 0.8139
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1519 - accuracy: 0.8145
# Epoch 00066: val_loss improved from 0.15807 to 0.15757, saving model to fas_mnist_1.h5
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1519 - accuracy: 0.8145 - val_loss: 0.1576 - val_accuracy: 0.8167
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1527 - accuracy: 0.8194
# Epoch 00067: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1527 - accuracy: 0.8194 - val_loss: 0.1583 - val_accuracy: 0.8194
# Epoch 00067: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1506 - accuracy: 0.8275
# Val Score:  [0.15061137080192566, 0.8274999856948853]
# ====================================================================================
#
#
# Training on Fold:  3
# Epoch 1/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.7607 - accuracy: 0.2562
# Epoch 00001: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 14ms/step - loss: 0.7596 - accuracy: 0.2568 - val_loss: 0.6405 - val_accuracy: 0.2694
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.6575 - accuracy: 0.2627
# Epoch 00002: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.6575 - accuracy: 0.2627 - val_loss: 0.6004 - val_accuracy: 0.2361
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.6174 - accuracy: 0.2664
# Epoch 00003: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.6174 - accuracy: 0.2664 - val_loss: 0.5838 - val_accuracy: 0.2444
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5874 - accuracy: 0.2815
# Epoch 00004: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5874 - accuracy: 0.2815 - val_loss: 0.5767 - val_accuracy: 0.2222
# Epoch 5/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.5725 - accuracy: 0.2989
# Epoch 00005: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5722 - accuracy: 0.2963 - val_loss: 0.5676 - val_accuracy: 0.2028
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5562 - accuracy: 0.3111
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5562 - accuracy: 0.3111 - val_loss: 0.5652 - val_accuracy: 0.2417
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5479 - accuracy: 0.3299
# Epoch 00007: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5479 - accuracy: 0.3299 - val_loss: 0.5647 - val_accuracy: 0.2889
# Epoch 8/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.5393 - accuracy: 0.3597
# Epoch 00008: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5388 - accuracy: 0.3593 - val_loss: 0.5644 - val_accuracy: 0.2750
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5277 - accuracy: 0.3833
# Epoch 00009: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.5277 - accuracy: 0.3833 - val_loss: 0.5661 - val_accuracy: 0.2750
# Epoch 10/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.5148 - accuracy: 0.4181
# Epoch 00010: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.5152 - accuracy: 0.4170 - val_loss: 0.5672 - val_accuracy: 0.2750
# Epoch 11/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.4997 - accuracy: 0.4545
# Epoch 00011: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4976 - accuracy: 0.4574 - val_loss: 0.5805 - val_accuracy: 0.2750
# Epoch 12/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.4734 - accuracy: 0.4976
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00012: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4745 - accuracy: 0.4948 - val_loss: 0.5651 - val_accuracy: 0.2806
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4517 - accuracy: 0.5247
# Epoch 00013: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4517 - accuracy: 0.5247 - val_loss: 0.5515 - val_accuracy: 0.2889
# Epoch 14/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.4356 - accuracy: 0.5453
# Epoch 00014: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4356 - accuracy: 0.5451 - val_loss: 0.5299 - val_accuracy: 0.3472
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4204 - accuracy: 0.5630
# Epoch 00015: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4204 - accuracy: 0.5630 - val_loss: 0.4986 - val_accuracy: 0.4722
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3984 - accuracy: 0.5901
# Epoch 00016: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3984 - accuracy: 0.5901 - val_loss: 0.4886 - val_accuracy: 0.4778
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3841 - accuracy: 0.6133
# Epoch 00017: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3841 - accuracy: 0.6133 - val_loss: 0.4734 - val_accuracy: 0.4528
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3698 - accuracy: 0.6222
# Epoch 00018: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3698 - accuracy: 0.6222 - val_loss: 0.4519 - val_accuracy: 0.4972
# Epoch 19/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.3574 - accuracy: 0.6549
# Epoch 00019: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3552 - accuracy: 0.6568 - val_loss: 0.4426 - val_accuracy: 0.4778
# Epoch 20/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.3426 - accuracy: 0.6583
# Epoch 00020: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3434 - accuracy: 0.6571 - val_loss: 0.3893 - val_accuracy: 0.5806
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3267 - accuracy: 0.6806
# Epoch 00021: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3267 - accuracy: 0.6806 - val_loss: 0.4199 - val_accuracy: 0.5389
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3234 - accuracy: 0.6796
# Epoch 00022: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3234 - accuracy: 0.6796 - val_loss: 0.3460 - val_accuracy: 0.6472
# Epoch 23/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.3079 - accuracy: 0.6941
# Epoch 00023: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3079 - accuracy: 0.6935 - val_loss: 0.3504 - val_accuracy: 0.6139
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3012 - accuracy: 0.6988
# Epoch 00024: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3012 - accuracy: 0.6988 - val_loss: 0.3321 - val_accuracy: 0.6389
# Epoch 25/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.2892 - accuracy: 0.7099
# Epoch 00025: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2875 - accuracy: 0.7133 - val_loss: 0.3231 - val_accuracy: 0.6778
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2810 - accuracy: 0.7157
# Epoch 00026: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2810 - accuracy: 0.7157 - val_loss: 0.3182 - val_accuracy: 0.6417
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2746 - accuracy: 0.7127
# Epoch 00027: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2746 - accuracy: 0.7127 - val_loss: 0.3054 - val_accuracy: 0.6667
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2665 - accuracy: 0.7330
# Epoch 00028: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2665 - accuracy: 0.7330 - val_loss: 0.3053 - val_accuracy: 0.6694
# Epoch 29/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2660 - accuracy: 0.7319
# Epoch 00029: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2653 - accuracy: 0.7333 - val_loss: 0.2968 - val_accuracy: 0.6500
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2574 - accuracy: 0.7327
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2574 - accuracy: 0.7327 - val_loss: 0.3010 - val_accuracy: 0.6694
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2473 - accuracy: 0.7414
# Epoch 00031: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2473 - accuracy: 0.7414 - val_loss: 0.2922 - val_accuracy: 0.6722
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2448 - accuracy: 0.7528
# Epoch 00032: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2448 - accuracy: 0.7528 - val_loss: 0.2927 - val_accuracy: 0.6833
# Epoch 33/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2415 - accuracy: 0.7519
# Epoch 00033: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2416 - accuracy: 0.7512 - val_loss: 0.2770 - val_accuracy: 0.6944
# Epoch 34/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2371 - accuracy: 0.7525
# Epoch 00034: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2367 - accuracy: 0.7528 - val_loss: 0.2830 - val_accuracy: 0.6889
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2355 - accuracy: 0.7534
# Epoch 00035: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2355 - accuracy: 0.7534 - val_loss: 0.2793 - val_accuracy: 0.7000
# Epoch 36/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.2349 - accuracy: 0.7554
# Epoch 00036: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2364 - accuracy: 0.7525 - val_loss: 0.2729 - val_accuracy: 0.6944
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2281 - accuracy: 0.7614
# Epoch 00037: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2281 - accuracy: 0.7614 - val_loss: 0.2700 - val_accuracy: 0.7028
# Epoch 38/100
# ...
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.5498 - accuracy: 0.3448 - val_loss: 0.5669 - val_accuracy: 0.2667
# Epoch 7/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.5416 - accuracy: 0.3497
# Epoch 00007: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.5411 - accuracy: 0.3512 - val_loss: 0.5645 - val_accuracy: 0.2722
# Epoch 8/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.5291 - accuracy: 0.3928
# Epoch 00008: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.5292 - accuracy: 0.3923 - val_loss: 0.5641 - val_accuracy: 0.2583
# Epoch 9/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.5180 - accuracy: 0.4084
# Epoch 00009: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.5179 - accuracy: 0.4077 - val_loss: 0.5684 - val_accuracy: 0.2583
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5090 - accuracy: 0.4198
# Epoch 00010: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.5090 - accuracy: 0.4198 - val_loss: 0.5729 - val_accuracy: 0.2583
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4935 - accuracy: 0.4586
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00011: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4935 - accuracy: 0.4586 - val_loss: 0.5686 - val_accuracy: 0.2583
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4688 - accuracy: 0.5062
# Epoch 00012: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4688 - accuracy: 0.5062 - val_loss: 0.5614 - val_accuracy: 0.2639
# Epoch 13/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.4545 - accuracy: 0.5150
# Epoch 00013: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4541 - accuracy: 0.5154 - val_loss: 0.5497 - val_accuracy: 0.2750
# Epoch 14/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.4437 - accuracy: 0.5500
# Epoch 00014: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4436 - accuracy: 0.5500 - val_loss: 0.5431 - val_accuracy: 0.2972
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4272 - accuracy: 0.5546
# Epoch 00015: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4272 - accuracy: 0.5546 - val_loss: 0.5130 - val_accuracy: 0.4139
# Epoch 16/100
# 49/51 [===========================>..] - ETA: 0s - loss: 0.4118 - accuracy: 0.5851
# Epoch 00016: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4123 - accuracy: 0.5840 - val_loss: 0.5087 - val_accuracy: 0.4694
# Epoch 17/100
# 49/51 [===========================>..] - ETA: 0s - loss: 0.4029 - accuracy: 0.5963
# Epoch 00017: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4023 - accuracy: 0.5963 - val_loss: 0.5391 - val_accuracy: 0.4028
# Epoch 18/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.3837 - accuracy: 0.6259
# Epoch 00018: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3835 - accuracy: 0.6259 - val_loss: 0.4920 - val_accuracy: 0.5250
# Epoch 19/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.3640 - accuracy: 0.6359
# Epoch 00019: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3644 - accuracy: 0.6364 - val_loss: 0.4325 - val_accuracy: 0.5722
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3547 - accuracy: 0.6568
# Epoch 00020: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3547 - accuracy: 0.6568 - val_loss: 0.4128 - val_accuracy: 0.5944
# Epoch 21/100
# 49/51 [===========================>..] - ETA: 0s - loss: 0.3417 - accuracy: 0.6601
# Epoch 00021: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3401 - accuracy: 0.6630 - val_loss: 0.4111 - val_accuracy: 0.5889
# Epoch 22/100
# 49/51 [===========================>..] - ETA: 0s - loss: 0.3262 - accuracy: 0.6862
# Epoch 00022: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3271 - accuracy: 0.6846 - val_loss: 0.3737 - val_accuracy: 0.6250
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3204 - accuracy: 0.6880
# Epoch 00023: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3204 - accuracy: 0.6880 - val_loss: 0.3491 - val_accuracy: 0.6694
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3122 - accuracy: 0.6886
# Epoch 00024: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3122 - accuracy: 0.6886 - val_loss: 0.3431 - val_accuracy: 0.6417
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2970 - accuracy: 0.7052
# Epoch 00025: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2970 - accuracy: 0.7052 - val_loss: 0.3571 - val_accuracy: 0.6306
# Epoch 26/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2917 - accuracy: 0.7141
# Epoch 00026: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2919 - accuracy: 0.7130 - val_loss: 0.3405 - val_accuracy: 0.6306
# Epoch 27/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2855 - accuracy: 0.7138
# Epoch 00027: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2857 - accuracy: 0.7139 - val_loss: 0.2966 - val_accuracy: 0.7306
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2757 - accuracy: 0.7191
# Epoch 00028: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2757 - accuracy: 0.7191 - val_loss: 0.3388 - val_accuracy: 0.6417
# Epoch 29/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2705 - accuracy: 0.7294
# Epoch 00029: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2711 - accuracy: 0.7287 - val_loss: 0.3247 - val_accuracy: 0.6750
# Epoch 30/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2694 - accuracy: 0.7253
# Epoch 00030: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2686 - accuracy: 0.7272 - val_loss: 0.3156 - val_accuracy: 0.6778
# Epoch 31/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2611 - accuracy: 0.7378
# Epoch 00031: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2608 - accuracy: 0.7383 - val_loss: 0.3420 - val_accuracy: 0.6500
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2553 - accuracy: 0.7352
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2553 - accuracy: 0.7352 - val_loss: 0.2588 - val_accuracy: 0.7278
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2464 - accuracy: 0.7404
# Epoch 00033: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2464 - accuracy: 0.7404 - val_loss: 0.2740 - val_accuracy: 0.7139
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2414 - accuracy: 0.7481
# Epoch 00034: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2414 - accuracy: 0.7481 - val_loss: 0.2590 - val_accuracy: 0.7306
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2371 - accuracy: 0.7642
# Epoch 00035: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2371 - accuracy: 0.7642 - val_loss: 0.2742 - val_accuracy: 0.7139
# Epoch 36/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2342 - accuracy: 0.7581
# Epoch 00036: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2335 - accuracy: 0.7596 - val_loss: 0.2679 - val_accuracy: 0.7333
# Epoch 37/100
# 48/51 [===========================>..] - ETA: 0s - loss: 0.2367 - accuracy: 0.7500
# Epoch 00037: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2365 - accuracy: 0.7497 - val_loss: 0.2629 - val_accuracy: 0.7444
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2280 - accuracy: 0.7673
# Epoch 00038: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2280 - accuracy: 0.7673 - val_loss: 0.2583 - val_accuracy: 0.7361
# Epoch 39/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2298 - accuracy: 0.7588
# Epoch 00039: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2296 - accuracy: 0.7583 - val_loss: 0.2535 - val_accuracy: 0.7528
# Epoch 40/100
# 49/51 [===========================>..] - ETA: 0s - loss: 0.2289 - accuracy: 0.7659
# Epoch 00040: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2297 - accuracy: 0.7639 - val_loss: 0.2560 - val_accuracy: 0.7389
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2229 - accuracy: 0.7728
# Epoch 00041: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2229 - accuracy: 0.7728 - val_loss: 0.2503 - val_accuracy: 0.7333
# Epoch 42/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2253 - accuracy: 0.7656
# Epoch 00042: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2250 - accuracy: 0.7657 - val_loss: 0.2485 - val_accuracy: 0.7500
# Epoch 43/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2258 - accuracy: 0.7613
# Epoch 00043: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2251 - accuracy: 0.7630 - val_loss: 0.2454 - val_accuracy: 0.7528
# Epoch 44/100
# 48/51 [===========================>..] - ETA: 0s - loss: 0.2224 - accuracy: 0.7718
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00044: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2209 - accuracy: 0.7744 - val_loss: 0.2380 - val_accuracy: 0.7472
# Epoch 45/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2155 - accuracy: 0.7734
# Epoch 00045: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2154 - accuracy: 0.7728 - val_loss: 0.2352 - val_accuracy: 0.7611
# Epoch 46/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2142 - accuracy: 0.7728
# Epoch 00046: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2141 - accuracy: 0.7731 - val_loss: 0.2438 - val_accuracy: 0.7500
# Epoch 47/100
# 49/51 [===========================>..] - ETA: 0s - loss: 0.2123 - accuracy: 0.7768
# Epoch 00047: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2109 - accuracy: 0.7793 - val_loss: 0.2352 - val_accuracy: 0.7694
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2108 - accuracy: 0.7799
# Epoch 00048: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2108 - accuracy: 0.7799 - val_loss: 0.2414 - val_accuracy: 0.7611
# Epoch 49/100
# 46/51 [==========================>...] - ETA: 0s - loss: 0.2077 - accuracy: 0.7816
# Epoch 00049: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2081 - accuracy: 0.7843 - val_loss: 0.2342 - val_accuracy: 0.7639
# Epoch 50/100
# 49/51 [===========================>..] - ETA: 0s - loss: 0.2116 - accuracy: 0.7752
# Epoch 00050: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2109 - accuracy: 0.7756 - val_loss: 0.2366 - val_accuracy: 0.7639
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2098 - accuracy: 0.7738
# Epoch 00051: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2098 - accuracy: 0.7738 - val_loss: 0.2340 - val_accuracy: 0.7611
# Epoch 52/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2101 - accuracy: 0.7803
# Epoch 00052: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2094 - accuracy: 0.7815 - val_loss: 0.2324 - val_accuracy: 0.7639
# Epoch 53/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2044 - accuracy: 0.7781
# Epoch 00053: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2043 - accuracy: 0.7781 - val_loss: 0.2326 - val_accuracy: 0.7639
# Epoch 54/100
# 48/51 [===========================>..] - ETA: 0s - loss: 0.2040 - accuracy: 0.7816
# Epoch 00054: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2056 - accuracy: 0.7809 - val_loss: 0.2289 - val_accuracy: 0.7806
# Epoch 55/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2046 - accuracy: 0.7847
# Epoch 00055: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2045 - accuracy: 0.7852 - val_loss: 0.2326 - val_accuracy: 0.7694
# Epoch 56/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.1984 - accuracy: 0.7922
# Epoch 00056: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1977 - accuracy: 0.7932 - val_loss: 0.2261 - val_accuracy: 0.7750
# Epoch 57/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.2032 - accuracy: 0.7825
# Epoch 00057: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2037 - accuracy: 0.7818 - val_loss: 0.2310 - val_accuracy: 0.7722
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2001 - accuracy: 0.7904
# Epoch 00058: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2001 - accuracy: 0.7904 - val_loss: 0.2323 - val_accuracy: 0.7583
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2017 - accuracy: 0.7883
# Epoch 00059: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.2017 - accuracy: 0.7883 - val_loss: 0.2311 - val_accuracy: 0.7806
# Epoch 60/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.1985 - accuracy: 0.7841
# Epoch 00060: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1985 - accuracy: 0.7843 - val_loss: 0.2253 - val_accuracy: 0.7750
# Epoch 61/100
# 50/51 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.7875
# Epoch 00061: val_loss did not improve from 0.15757
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1983 - accuracy: 0.7880 - val_loss: 0.2230 - val_accuracy: 0.7694
# Epoch 00061: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.2263 - accuracy: 0.7650
# Val Score:  [0.22627133131027222, 0.7649999856948853]
# ====================================================================================

# %%
#Load the model that was saved by ModelCheckpoint
model = load_model('fas_mnist_1.h5')

# %%
#model.evaluate(test_X, test_y)
print("Accuracy of the model is - " , model.evaluate(test_X,test_y)[1]*100 , "%")
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1407 - accuracy: 0.8270
# Accuracy of the model is -  82.70000219345093 %

# %%
fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)
#ax1.title('Accuracies vs Epochs')
ax1.plot(model_history[0].history['accuracy'], label='Training Fold 1')
ax1.plot(model_history[1].history['accuracy'], label='Training Fold 2')
ax1.plot(model_history[2].history['accuracy'], label='Training Fold 3')
ax1.plot(model_history[3].history['accuracy'], label='Training Fold 4')
ax1.plot(model_history[4].history['accuracy'], label='Training Fold 5')
ax1.legend()
ax2.plot(model_history[1].history['loss'], label='Training Fold 1')
ax2.plot(model_history[1].history['loss'], label='Training Fold 2')
ax2.plot(model_history[2].history['loss'], label='Training Fold 3')
ax2.plot(model_history[3].history['loss'], label='Training Fold 4')
ax2.plot(model_history[4].history['loss'], label='Training Fold 5')
ax2.legend()
plt.show()

# %%
plt.title('Train Accuracy vs Val Accuracy')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='orange', linestyle = "dashdot")
plt.legend()
plt.show()
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='orange', linestyle = "dashdot")
plt.legend()
plt.show()
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='orange', linestyle = "dashdot")
plt.legend()
plt.show()
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='orange', linestyle = "dashdot")
plt.legend()
plt.show()
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='brown', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='orange', linestyle = "dashdot")

plt.legend()
plt.show()

# %%
MODEL_NAME ='/content/fas_mnist_1.h5' 
CLIP = True  # if your model was trained with np.clip to clip  values
CLIP_VAL = 10  # if above, what was the value +/-

model = tf.keras.models.load_model(MODEL_NAME)

VALDIR = "/content/drive/MyDrive/Colab Notebooks/tes_data"
ACTIONS =  ["idle","maju","kiri", "kanan"]
PRED_BATCH = 64


def get_val_data(valdir, action, batch_size):

    argmax_dict = {0: 0, 1: 0, 2: 0,3:0}
    raw_pred_dict = {0: 0, 1: 0, 2: 0,3:0}

    action_dir = os.path.join(valdir, action)
    for session_file in os.listdir(action_dir):
        filepath = os.path.join(action_dir,session_file)
        if CLIP:
            data = np.clip(np.load(filepath), -CLIP_VAL, CLIP_VAL) / CLIP_VAL
        else:
            data = np.load(filepath) 
        preds = model.predict([data.reshape(-1, 16, 60,1)], batch_size=batch_size)

        for pred in preds:
            argmax = np.argmax(pred)
            argmax_dict[argmax] += 1
            for idx,value in enumerate(pred):
                raw_pred_dict[idx] += value

    argmax_pct_dict = {}
    for i in argmax_dict:
        total = 0
        correct = argmax_dict[i]
        for ii in argmax_dict:
            total += argmax_dict[ii]
        argmax_pct_dict[i] = round(correct/total, 4)
    return argmax_dict, raw_pred_dict, argmax_pct_dict


def make_conf_mat(none,left,forward,  right):
    action_dict = {"idle":none,"maju": forward, "kiri": left, "kanan": right}
    action_conf_mat = pd.DataFrame(action_dict)
    actions = [i for i in action_dict]

    fig = plt.figure(figsize=(15, 6))
   
    ax = fig.add_subplot(111)
    
    ax.matshow(action_conf_mat, cmap=plt.cm.RdYlGn)
    ax.set_xticklabels([""]+actions)
    ax.set_yticklabels([""]+actions)

    #print("__________")
    #print(action_dict)
    for idx, i in enumerate(action_dict):
        #print('tf',i)
        for idx2, ii in enumerate(action_dict[i]):
            #print(i, ii)
            #print(action_dict[i][ii])
            ax.text(idx, idx2, f"{round(float(action_dict[i][ii]),2)}", va='center', ha='center')
    # Rotate the tick labels and set their alignment.
    
    plt.title("Matrik data")
    plt.ylabel("Predicted Action")
    fig.tight_layout()
    plt.show()


left_argmax_dict, left_raw_pred_dict, left_argmax_pct_dict = get_val_data(VALDIR, "kiri", PRED_BATCH)
forward_argmax_dict, forward_raw_pred_dict, forward_argmax_pct_dict = get_val_data(VALDIR, "maju", PRED_BATCH)
none_argmax_dict, none_raw_pred_dict, none_argmax_pct_dict = get_val_data(VALDIR, "idle", PRED_BATCH)
right_argmax_dict, right_raw_pred_dict, right_argmax_pct_dict = get_val_data(VALDIR, "kanan", PRED_BATCH)
make_conf_mat(none_argmax_pct_dict,forward_argmax_pct_dict, left_argmax_pct_dict, right_argmax_pct_dict)

# %% [markdown]
# <a href="https://colab.research.google.com/github/wedexyz/eeg-/blob/main/Akomparasi_LSTM%20CNN%2BReduceLe%2BCrossVall%2BROcVS4_8chanel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.models import Sequential,load_model
from keras.layers import LSTM
from keras.layers import Dense, Conv2D , MaxPooling2D , Flatten , Dropout , BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping


import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
import pandas as pd
import os
import random
import time
import os


from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau


from scipy import signal
from scipy.fft import fftshift

# %% [markdown]
# # DATA

# %%
ACTIONS = ["kiri", "maju","idle","kanan"]
#reshape = (-1,16, 60,1)
reshape = (-1,8, 60,1)
reshape2 = (-1,8, 60)
#reshape(-1,28,28,1)

# %%
def create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/data8"):
    training_data = {}
    for action in ACTIONS:
        if action not in training_data:
            training_data[action] = []
        data_dir = os.path.join(starting_dir,action)
        for item in os.listdir(data_dir):
            data = np.load(os.path.join(data_dir, item))
            for item in data:
                training_data[action].append(item)

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)

    for action in ACTIONS:
        np.random.shuffle(training_data[action])  
        training_data[action] = training_data[action][:min(lengths)]

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)
    combined_data = []
    for action in ACTIONS:
        for data in training_data[action]:
            if action == "kiri":
                combined_data.append([data, [1, 0, 0,0]])
            elif action == "maju":
                combined_data.append([data, [0, 1, 0, 0]])
            elif action == "idle":
                combined_data.append([data, [0, 0, 1, 0]])
            elif action == "kanan":
                combined_data.append([data, [0, 0, 0, 1]])

    np.random.shuffle(combined_data)
    print("length:",len(combined_data))
    return combined_data

# %%
print("creating training data")
traindata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/data8")
train_X = []
train_y = []

for X, y in traindata:
    train_X.append(X)
    train_y.append(y)

train_X = np.array(train_X).reshape(reshape)
train2_X = np.array(train_X).reshape(reshape2)

train_y = np.array(train_y)
# Out:
# creating training data
# [250, 250, 250, 250]
# [250, 250, 250, 250]
# length: 1000

# %%
idle = np.load("/content/drive/MyDrive/Colab Notebooks/data8/idle/1608706768.npy")
kanan = np.load("/content/drive/MyDrive/Colab Notebooks/data8/kanan/1608707012.npy")
kiri = np.load("/content/drive/MyDrive/Colab Notebooks/data8/kiri/1608707050.npy")
maju = np.load("/content/drive/MyDrive/Colab Notebooks/data8/maju/1608706976.npy")

kelas1=idle[0][16]
kelas2=maju[0][16]
kelas3=kanan[0][16]
kelas4=kiri[0][16]

kelas1a=idle[175]
kelas2a=maju[175]
kelas3a=kanan[175]
kelas4a=kiri[175]



f1, t1,Sxx= signal.spectrogram(kelas1,fs=60, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd',
                            )
dbs1 = 10*np.log10(Sxx)
f2, t2,Sxx= signal.spectrogram(kelas2,fs=120, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd',
                            )
dbs2 = 10*np.log10(Sxx)
f3, t3,Sxx= signal.spectrogram(kelas3,fs=120, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )
dbs3 = 10*np.log10(Sxx)
f4, t4,Sxx= signal.spectrogram(kelas4,fs=120, window=('tukey', 0.25),
                             nperseg=2,
                             noverlap=1,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )  
dbs4 = 10*np.log10(Sxx)

# %%
fig, axs = plt.subplots(nrows=4, ncols=4,figsize=(20,10))
axs = axs.flatten()

axs[0].set_title("siggle")
axs[0].plot(kelas1)

axs[1].set_title("global")
axs[1].plot(kelas1a)

axs[2].set_title("Spectogram")
axs[2].pcolormesh(t1, f1,dbs1,  
                  shading='gouraud',
                  cmap='nipy_spectral')

cwt1 = signal.cwt(kelas1,signal.ricker,widths=np.arange(1,50))
cwt2 = signal.cwt(kelas2,signal.ricker,widths=np.arange(1,50))
cwt3 = signal.cwt(kelas3,signal.ricker,widths=np.arange(1,50))
cwt4 = signal.cwt(kelas4,signal.ricker,widths=np.arange(1,50))
axs[3].set_title("wavelet")
axs[3].imshow(cwt1,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt1).max(),vmin=-abs(cwt1).max())

axs[4].plot(kelas2)
axs[5].plot(kelas2a)
axs[6].pcolormesh(t2, f2,dbs2,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[7].imshow(cwt2,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt2).max(),vmin=-abs(cwt2).max())

axs[8].plot(kelas3)
axs[9].plot(kelas3a)
axs[10].pcolormesh(t3, f3,dbs3,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[11].imshow(cwt3,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt3).max(),vmin=-abs(cwt3).max())

axs[12].plot(kelas4)
axs[13].plot(kelas4a)
axs[14].pcolormesh(t4, f4,dbs4,  
                  shading='gouraud',
                  cmap='viridis')
axs[15].imshow(cwt4,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt4).max(),vmin=-abs(cwt4).max())
plt.show()

# %%
import seaborn as sns
ye=pd.DataFrame(train_y)

ye.columns=["kiri", "maju","idle","kanan"]
categories = list(ye.columns.values)
sns.set(font_scale = 1)
plt.figure(figsize=(10,8))
ax= sns.barplot(categories, ye.iloc[:,0:].sum().values)
plt.title("Number of samples labeled as active (1) out of {0} length data".format((ye.shape[0])),fontsize=20)

plt.ylabel('Number of events', fontsize=18)
plt.xlabel('Event Type ', fontsize=12)
#adding the text labels
rects = ax.patches
labels = ye.iloc[:,0:].sum().values

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom', fontsize=10)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # CNN

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1,factor=0.5, min_lr=0.0001)

# %%
#def cnn_model(size, num_cnn_layers):

def cnn_model():    

    model = Sequential()
    
    model.add(Conv2D(filters = 64, kernel_size = (8,8), padding = "same", activation = "relu", input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (4,4)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Conv2D(filters = 64, kernel_size = (4,4), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (2,2)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Conv2D(filters = 64, kernel_size = (2,2), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (1,1)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Flatten())
    
    model.add(Dense(32, activation = "relu"))
    model.add(BatchNormalization())
    
    model.add(Dense(4, activation = "sigmoid"))
   
    #adam = Adam(lr = 0.001)
    model.compile(optimizer ="adam", loss = "binary_crossentropy", metrics = ['accuracy'])
    #model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
 
    
    return model

# %%
#model = cnn_model(IMAGE_SIZE, 2)
model = cnn_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 8, 60, 64)         4160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 2, 15, 64)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 2, 15, 64)         0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2, 15, 64)         256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 2, 15, 64)         65600
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 7, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 7, 64)          0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1, 7, 64)          256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 7, 64)          16448
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 7, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 7, 64)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 7, 64)          256
# _________________________________________________________________
# flatten (Flatten)            (None, 448)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                14368
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 101,604
# Trainable params: 101,156
# Non-trainable params: 448
# _________________________________________________________________

# %%
#set early stopping criteria
pat = 5
#this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='loss', patience=pat, verbose=1)

#define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('subjek1CNN.h5', verbose=1, save_best_only=True)

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=100, BATCH_SIZE=32):
    model = None
    model = cnn_model() 
    results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[learning_rate_reduction,early_stopping, model_checkpoint], 
              verbose=1, validation_split=0.1)   
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs=100
batch_size=32

#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(train_X, train_y, test_size=0.2, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
   
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 23/23 [==============================] - 8s 29ms/step - loss: 0.7559 - accuracy: 0.3654 - val_loss: 0.6346 - val_accuracy: 0.3250
#
# Epoch 00001: val_loss improved from inf to 0.63457, saving model to subjek1CNN.h5
# Epoch 2/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5437 - accuracy: 0.5959 - val_loss: 0.5849 - val_accuracy: 0.4125
#
# Epoch 00002: val_loss improved from 0.63457 to 0.58492, saving model to subjek1CNN.h5
# Epoch 3/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4835 - accuracy: 0.6528 - val_loss: 0.5392 - val_accuracy: 0.5000
#
# Epoch 00003: val_loss improved from 0.58492 to 0.53923, saving model to subjek1CNN.h5
# Epoch 4/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4304 - accuracy: 0.7350 - val_loss: 0.5089 - val_accuracy: 0.5375
#
# Epoch 00004: val_loss improved from 0.53923 to 0.50887, saving model to subjek1CNN.h5
# Epoch 5/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3947 - accuracy: 0.6919 - val_loss: 0.4684 - val_accuracy: 0.6125
#
# Epoch 00005: val_loss improved from 0.50887 to 0.46841, saving model to subjek1CNN.h5
# Epoch 6/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3781 - accuracy: 0.7101 - val_loss: 0.4573 - val_accuracy: 0.6625
#
# Epoch 00006: val_loss improved from 0.46841 to 0.45735, saving model to subjek1CNN.h5
# Epoch 7/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3346 - accuracy: 0.7434 - val_loss: 0.4570 - val_accuracy: 0.5000
#
# Epoch 00007: val_loss improved from 0.45735 to 0.45698, saving model to subjek1CNN.h5
# Epoch 8/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3118 - accuracy: 0.7788 - val_loss: 0.3889 - val_accuracy: 0.6375
#
# Epoch 00008: val_loss improved from 0.45698 to 0.38892, saving model to subjek1CNN.h5
# Epoch 9/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2854 - accuracy: 0.7842 - val_loss: 0.4264 - val_accuracy: 0.5250
#
# Epoch 00009: val_loss did not improve from 0.38892
# Epoch 10/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2815 - accuracy: 0.7940 - val_loss: 0.3730 - val_accuracy: 0.7250
#
# Epoch 00010: val_loss improved from 0.38892 to 0.37301, saving model to subjek1CNN.h5
# Epoch 11/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2659 - accuracy: 0.7940 - val_loss: 0.3576 - val_accuracy: 0.7375
#
# Epoch 00011: val_loss improved from 0.37301 to 0.35761, saving model to subjek1CNN.h5
# Epoch 12/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2489 - accuracy: 0.8050 - val_loss: 0.3167 - val_accuracy: 0.7500
#
# Epoch 00012: val_loss improved from 0.35761 to 0.31669, saving model to subjek1CNN.h5
# Epoch 13/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2436 - accuracy: 0.7980 - val_loss: 0.3300 - val_accuracy: 0.7375
#
# Epoch 00013: val_loss did not improve from 0.31669
# Epoch 14/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2335 - accuracy: 0.8399 - val_loss: 0.2635 - val_accuracy: 0.7875
#
# Epoch 00014: val_loss improved from 0.31669 to 0.26346, saving model to subjek1CNN.h5
# Epoch 15/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2094 - accuracy: 0.8378 - val_loss: 0.2811 - val_accuracy: 0.7875
#
# Epoch 00015: val_loss did not improve from 0.26346
# Epoch 16/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2099 - accuracy: 0.8513 - val_loss: 0.2492 - val_accuracy: 0.8125
#
# Epoch 00016: val_loss improved from 0.26346 to 0.24924, saving model to subjek1CNN.h5
# Epoch 17/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1964 - accuracy: 0.8516 - val_loss: 0.2482 - val_accuracy: 0.8125
#
# Epoch 00017: val_loss improved from 0.24924 to 0.24818, saving model to subjek1CNN.h5
# Epoch 18/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1903 - accuracy: 0.8583 - val_loss: 0.2371 - val_accuracy: 0.8250
#
# Epoch 00018: val_loss improved from 0.24818 to 0.23713, saving model to subjek1CNN.h5
# Epoch 19/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1827 - accuracy: 0.8698 - val_loss: 0.2456 - val_accuracy: 0.8125
#
# Epoch 00019: val_loss did not improve from 0.23713
# Epoch 20/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1701 - accuracy: 0.8645 - val_loss: 0.2120 - val_accuracy: 0.8250
#
# Epoch 00020: val_loss improved from 0.23713 to 0.21203, saving model to subjek1CNN.h5
# Epoch 21/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1517 - accuracy: 0.9064 - val_loss: 0.2180 - val_accuracy: 0.7875
#
# Epoch 00021: val_loss did not improve from 0.21203
# Epoch 22/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1588 - accuracy: 0.8817 - val_loss: 0.2240 - val_accuracy: 0.7875
#
# Epoch 00022: val_loss did not improve from 0.21203
# Epoch 23/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1622 - accuracy: 0.8896 - val_loss: 0.1882 - val_accuracy: 0.8250
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00023: val_loss improved from 0.21203 to 0.18820, saving model to subjek1CNN.h5
# Epoch 24/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1542 - accuracy: 0.9082 - val_loss: 0.1853 - val_accuracy: 0.8125
#
# Epoch 00024: val_loss improved from 0.18820 to 0.18532, saving model to subjek1CNN.h5
# Epoch 25/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1445 - accuracy: 0.8909 - val_loss: 0.1861 - val_accuracy: 0.8250
#
# Epoch 00025: val_loss did not improve from 0.18532
# Epoch 26/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1346 - accuracy: 0.9045 - val_loss: 0.1749 - val_accuracy: 0.8250
#
# Epoch 00026: val_loss improved from 0.18532 to 0.17492, saving model to subjek1CNN.h5
# Epoch 27/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1377 - accuracy: 0.8928 - val_loss: 0.1866 - val_accuracy: 0.8250
#
# Epoch 00027: val_loss did not improve from 0.17492
# Epoch 28/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1208 - accuracy: 0.9265 - val_loss: 0.1748 - val_accuracy: 0.8250
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00028: val_loss improved from 0.17492 to 0.17481, saving model to subjek1CNN.h5
# Epoch 29/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1188 - accuracy: 0.9265 - val_loss: 0.1631 - val_accuracy: 0.8375
#
# Epoch 00029: val_loss improved from 0.17481 to 0.16308, saving model to subjek1CNN.h5
# Epoch 30/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1173 - accuracy: 0.9200 - val_loss: 0.1550 - val_accuracy: 0.8500
#
# Epoch 00030: val_loss improved from 0.16308 to 0.15499, saving model to subjek1CNN.h5
# Epoch 31/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1265 - accuracy: 0.9124 - val_loss: 0.1524 - val_accuracy: 0.8625
#
# Epoch 00031: val_loss improved from 0.15499 to 0.15238, saving model to subjek1CNN.h5
# Epoch 32/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1174 - accuracy: 0.9256 - val_loss: 0.1484 - val_accuracy: 0.8750
#
# Epoch 00032: val_loss improved from 0.15238 to 0.14839, saving model to subjek1CNN.h5
# Epoch 33/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1066 - accuracy: 0.9237 - val_loss: 0.1413 - val_accuracy: 0.8625
#
# Epoch 00033: val_loss improved from 0.14839 to 0.14129, saving model to subjek1CNN.h5
# Epoch 34/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1178 - accuracy: 0.9212 - val_loss: 0.1336 - val_accuracy: 0.8750
#
# Epoch 00034: val_loss improved from 0.14129 to 0.13356, saving model to subjek1CNN.h5
# Epoch 35/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1087 - accuracy: 0.9469 - val_loss: 0.1308 - val_accuracy: 0.9000
#
# Epoch 00035: val_loss improved from 0.13356 to 0.13084, saving model to subjek1CNN.h5
# Epoch 00035: early stopping
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1320 - accuracy: 0.9000
# Val Score:  [0.13198891282081604, 0.8999999761581421]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
# 23/23 [==============================] - 1s 14ms/step - loss: 0.7077 - accuracy: 0.4585 - val_loss: 0.5787 - val_accuracy: 0.4250
#
# Epoch 00001: val_loss did not improve from 0.13084
# Epoch 2/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5298 - accuracy: 0.6407 - val_loss: 0.5203 - val_accuracy: 0.7250
#
# Epoch 00002: val_loss did not improve from 0.13084
# Epoch 3/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4551 - accuracy: 0.6775 - val_loss: 0.4807 - val_accuracy: 0.7125
#
# Epoch 00003: val_loss did not improve from 0.13084
# Epoch 4/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4369 - accuracy: 0.6820 - val_loss: 0.4461 - val_accuracy: 0.7125
#
# Epoch 00004: val_loss did not improve from 0.13084
# Epoch 5/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3961 - accuracy: 0.7034 - val_loss: 0.3981 - val_accuracy: 0.7625
#
# Epoch 00005: val_loss did not improve from 0.13084
# Epoch 6/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3664 - accuracy: 0.7495 - val_loss: 0.3853 - val_accuracy: 0.7375
#
# Epoch 00006: val_loss did not improve from 0.13084
# Epoch 7/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3359 - accuracy: 0.7531 - val_loss: 0.3200 - val_accuracy: 0.8250
#
# Epoch 00007: val_loss did not improve from 0.13084
# Epoch 8/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3190 - accuracy: 0.7673 - val_loss: 0.3101 - val_accuracy: 0.8125
#
# Epoch 00008: val_loss did not improve from 0.13084
# Epoch 9/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2974 - accuracy: 0.7960 - val_loss: 0.3037 - val_accuracy: 0.8250
#
# Epoch 00009: val_loss did not improve from 0.13084
# Epoch 10/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2943 - accuracy: 0.7877 - val_loss: 0.2872 - val_accuracy: 0.8500
#
# Epoch 00010: val_loss did not improve from 0.13084
# Epoch 11/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2657 - accuracy: 0.8040 - val_loss: 0.2376 - val_accuracy: 0.8250
#
# Epoch 00011: val_loss did not improve from 0.13084
# Epoch 12/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2562 - accuracy: 0.7966 - val_loss: 0.2527 - val_accuracy: 0.8500
#
# Epoch 00012: val_loss did not improve from 0.13084
# Epoch 13/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2676 - accuracy: 0.7954 - val_loss: 0.2337 - val_accuracy: 0.8375
#
# Epoch 00013: val_loss did not improve from 0.13084
# Epoch 14/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2406 - accuracy: 0.7954 - val_loss: 0.2240 - val_accuracy: 0.8375
#
# Epoch 00014: val_loss did not improve from 0.13084
# Epoch 15/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2119 - accuracy: 0.8629 - val_loss: 0.2122 - val_accuracy: 0.8625
#
# Epoch 00015: val_loss did not improve from 0.13084
# Epoch 16/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2171 - accuracy: 0.8505 - val_loss: 0.2039 - val_accuracy: 0.8625
#
# Epoch 00016: val_loss did not improve from 0.13084
# Epoch 17/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1879 - accuracy: 0.8785 - val_loss: 0.2108 - val_accuracy: 0.8125
#
# Epoch 00017: val_loss did not improve from 0.13084
# Epoch 18/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1841 - accuracy: 0.8695 - val_loss: 0.1983 - val_accuracy: 0.8625
#
# Epoch 00018: val_loss did not improve from 0.13084
# Epoch 19/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1881 - accuracy: 0.8539 - val_loss: 0.1997 - val_accuracy: 0.8375
#
# Epoch 00019: val_loss did not improve from 0.13084
# Epoch 20/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1898 - accuracy: 0.8509 - val_loss: 0.1751 - val_accuracy: 0.8625
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00020: val_loss did not improve from 0.13084
# Epoch 21/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1766 - accuracy: 0.8740 - val_loss: 0.1808 - val_accuracy: 0.8500
#
# Epoch 00021: val_loss did not improve from 0.13084
# Epoch 22/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1407 - accuracy: 0.9156 - val_loss: 0.1821 - val_accuracy: 0.8500
#
# Epoch 00022: val_loss did not improve from 0.13084
# Epoch 23/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1343 - accuracy: 0.9196 - val_loss: 0.1884 - val_accuracy: 0.8375
#
# Epoch 00023: val_loss did not improve from 0.13084
# Epoch 24/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1395 - accuracy: 0.9196 - val_loss: 0.2020 - val_accuracy: 0.8250
#
# Epoch 00024: val_loss did not improve from 0.13084
# Epoch 25/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1405 - accuracy: 0.9124 - val_loss: 0.1834 - val_accuracy: 0.8375
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00025: val_loss did not improve from 0.13084
# Epoch 26/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1251 - accuracy: 0.9244 - val_loss: 0.1909 - val_accuracy: 0.8375
#
# Epoch 00026: val_loss did not improve from 0.13084
# Epoch 27/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1227 - accuracy: 0.9250 - val_loss: 0.1932 - val_accuracy: 0.8375
#
# Epoch 00027: val_loss did not improve from 0.13084
# Epoch 28/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1289 - accuracy: 0.9116 - val_loss: 0.1782 - val_accuracy: 0.8500
#
# Epoch 00028: val_loss did not improve from 0.13084
# Epoch 29/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1226 - accuracy: 0.9260 - val_loss: 0.1541 - val_accuracy: 0.8375
#
# Epoch 00029: val_loss did not improve from 0.13084
# Epoch 30/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1294 - accuracy: 0.9210 - val_loss: 0.1470 - val_accuracy: 0.8625
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: val_loss did not improve from 0.13084
# Epoch 31/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1082 - accuracy: 0.9472 - val_loss: 0.1402 - val_accuracy: 0.8625
#
# Epoch 00031: val_loss did not improve from 0.13084
# Epoch 32/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1473 - accuracy: 0.8996 - val_loss: 0.1333 - val_accuracy: 0.8625
#
# Epoch 00032: val_loss did not improve from 0.13084
# Epoch 33/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1131 - accuracy: 0.9322 - val_loss: 0.1273 - val_accuracy: 0.8750
#
# Epoch 00033: val_loss improved from 0.13084 to 0.12730, saving model to subjek1CNN.h5
# Epoch 34/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1177 - accuracy: 0.9210 - val_loss: 0.1216 - val_accuracy: 0.8750
#
# Epoch 00034: val_loss improved from 0.12730 to 0.12162, saving model to subjek1CNN.h5
# Epoch 35/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1265 - accuracy: 0.9190 - val_loss: 0.1084 - val_accuracy: 0.9000
#
# Epoch 00035: val_loss improved from 0.12162 to 0.10845, saving model to subjek1CNN.h5
# Epoch 36/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1075 - accuracy: 0.9301 - val_loss: 0.1110 - val_accuracy: 0.9000
#
# Epoch 00036: val_loss did not improve from 0.10845
# Epoch 00036: early stopping
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1388 - accuracy: 0.8350
# Val Score:  [0.13882267475128174, 0.8349999785423279]
# ====================================================================================
#
#
# Training on Fold:  3
# Epoch 1/100
# 23/23 [==============================] - 1s 14ms/step - loss: 0.7582 - accuracy: 0.4117 - val_loss: 0.6200 - val_accuracy: 0.5000
#
# Epoch 00001: val_loss did not improve from 0.10845
# Epoch 2/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5733 - accuracy: 0.5575 - val_loss: 0.5620 - val_accuracy: 0.5750
#
# Epoch 00002: val_loss did not improve from 0.10845
# Epoch 3/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5167 - accuracy: 0.6043 - val_loss: 0.5192 - val_accuracy: 0.5875
#
# Epoch 00003: val_loss did not improve from 0.10845
# Epoch 4/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4476 - accuracy: 0.6873 - val_loss: 0.4884 - val_accuracy: 0.5750
#
# Epoch 00004: val_loss did not improve from 0.10845
# Epoch 5/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4155 - accuracy: 0.7038 - val_loss: 0.4456 - val_accuracy: 0.6125
#
# Epoch 00005: val_loss did not improve from 0.10845
# Epoch 6/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3777 - accuracy: 0.7190 - val_loss: 0.4088 - val_accuracy: 0.7250
#
# Epoch 00006: val_loss did not improve from 0.10845
# Epoch 7/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3518 - accuracy: 0.7614 - val_loss: 0.3794 - val_accuracy: 0.7250
#
# Epoch 00007: val_loss did not improve from 0.10845
# Epoch 8/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3442 - accuracy: 0.7316 - val_loss: 0.3602 - val_accuracy: 0.7375
#
# Epoch 00008: val_loss did not improve from 0.10845
# Epoch 9/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3119 - accuracy: 0.7610 - val_loss: 0.3322 - val_accuracy: 0.7625
#
# Epoch 00009: val_loss did not improve from 0.10845
# Epoch 10/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2949 - accuracy: 0.7951 - val_loss: 0.3164 - val_accuracy: 0.7750
#
# Epoch 00010: val_loss did not improve from 0.10845
# Epoch 11/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2929 - accuracy: 0.7874 - val_loss: 0.3042 - val_accuracy: 0.7625
#
# Epoch 00011: val_loss did not improve from 0.10845
# Epoch 12/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2770 - accuracy: 0.7589 - val_loss: 0.2872 - val_accuracy: 0.7750
#
# Epoch 00012: val_loss did not improve from 0.10845
# Epoch 13/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2492 - accuracy: 0.7948 - val_loss: 0.2855 - val_accuracy: 0.7375
#
# Epoch 00013: val_loss did not improve from 0.10845
# Epoch 14/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2459 - accuracy: 0.8046 - val_loss: 0.2768 - val_accuracy: 0.7500
#
# Epoch 00014: val_loss did not improve from 0.10845
# Epoch 15/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2385 - accuracy: 0.8004 - val_loss: 0.2721 - val_accuracy: 0.7625
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_loss did not improve from 0.10845
# Epoch 16/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2340 - accuracy: 0.7956 - val_loss: 0.2527 - val_accuracy: 0.8000
#
# Epoch 00016: val_loss did not improve from 0.10845
# Epoch 17/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2167 - accuracy: 0.8281 - val_loss: 0.2528 - val_accuracy: 0.7750
#
# Epoch 00017: val_loss did not improve from 0.10845
# Epoch 18/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2062 - accuracy: 0.8354 - val_loss: 0.2482 - val_accuracy: 0.7500
#
# Epoch 00018: val_loss did not improve from 0.10845
# Epoch 19/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2107 - accuracy: 0.8406 - val_loss: 0.2453 - val_accuracy: 0.7625
#
# Epoch 00019: val_loss did not improve from 0.10845
# Epoch 20/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1969 - accuracy: 0.8685 - val_loss: 0.2376 - val_accuracy: 0.7750
#
# Epoch 00020: val_loss did not improve from 0.10845
# Epoch 21/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1875 - accuracy: 0.8612 - val_loss: 0.2363 - val_accuracy: 0.7500
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00021: val_loss did not improve from 0.10845
# Epoch 22/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1849 - accuracy: 0.8567 - val_loss: 0.2270 - val_accuracy: 0.7750
#
# Epoch 00022: val_loss did not improve from 0.10845
# Epoch 23/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1828 - accuracy: 0.8608 - val_loss: 0.2292 - val_accuracy: 0.7500
#
# Epoch 00023: val_loss did not improve from 0.10845
# Epoch 24/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1756 - accuracy: 0.8807 - val_loss: 0.2325 - val_accuracy: 0.7875
#
# Epoch 00024: val_loss did not improve from 0.10845
# Epoch 25/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1691 - accuracy: 0.8870 - val_loss: 0.2297 - val_accuracy: 0.7750
#
# Epoch 00025: val_loss did not improve from 0.10845
# Epoch 26/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1642 - accuracy: 0.9135 - val_loss: 0.2226 - val_accuracy: 0.7625
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00026: val_loss did not improve from 0.10845
# Epoch 27/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1698 - accuracy: 0.8876 - val_loss: 0.2217 - val_accuracy: 0.7875
#
# Epoch 00027: val_loss did not improve from 0.10845
# Epoch 28/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1519 - accuracy: 0.9237 - val_loss: 0.2056 - val_accuracy: 0.8250
#
# Epoch 00028: val_loss did not improve from 0.10845
# Epoch 29/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1660 - accuracy: 0.8864 - val_loss: 0.2008 - val_accuracy: 0.8250
#
# Epoch 00029: val_loss did not improve from 0.10845
# Epoch 30/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1558 - accuracy: 0.9062 - val_loss: 0.1973 - val_accuracy: 0.8250
#
# Epoch 00030: val_loss did not improve from 0.10845
# Epoch 31/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1664 - accuracy: 0.8932 - val_loss: 0.1990 - val_accuracy: 0.8125
#
# Epoch 00031: val_loss did not improve from 0.10845
# Epoch 32/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1609 - accuracy: 0.8783 - val_loss: 0.1923 - val_accuracy: 0.8500
#
# Epoch 00032: val_loss did not improve from 0.10845
# Epoch 33/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1499 - accuracy: 0.9120 - val_loss: 0.1908 - val_accuracy: 0.8500
#
# Epoch 00033: val_loss did not improve from 0.10845
# Epoch 34/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1544 - accuracy: 0.8984 - val_loss: 0.1831 - val_accuracy: 0.8500
#
# Epoch 00034: val_loss did not improve from 0.10845
# Epoch 35/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1489 - accuracy: 0.9190 - val_loss: 0.1772 - val_accuracy: 0.8500
#
# Epoch 00035: val_loss did not improve from 0.10845
# Epoch 36/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1431 - accuracy: 0.9154 - val_loss: 0.1720 - val_accuracy: 0.8500
#
# Epoch 00036: val_loss did not improve from 0.10845
# Epoch 37/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1505 - accuracy: 0.9066 - val_loss: 0.1650 - val_accuracy: 0.8625
#
# Epoch 00037: val_loss did not improve from 0.10845
# Epoch 38/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1537 - accuracy: 0.8921 - val_loss: 0.1639 - val_accuracy: 0.8625
#
# Epoch 00038: val_loss did not improve from 0.10845
# Epoch 39/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1525 - accuracy: 0.8930 - val_loss: 0.1709 - val_accuracy: 0.8500
#
# Epoch 00039: val_loss did not improve from 0.10845
# Epoch 40/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1441 - accuracy: 0.9124 - val_loss: 0.1666 - val_accuracy: 0.8625
#
# Epoch 00040: val_loss did not improve from 0.10845
# Epoch 41/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1440 - accuracy: 0.8992 - val_loss: 0.1598 - val_accuracy: 0.8750
#
# Epoch 00041: val_loss did not improve from 0.10845
# Epoch 42/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1450 - accuracy: 0.8953 - val_loss: 0.1593 - val_accuracy: 0.8625
#
# Epoch 00042: val_loss did not improve from 0.10845
# Epoch 43/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1469 - accuracy: 0.9012 - val_loss: 0.1584 - val_accuracy: 0.8625
#
# Epoch 00043: val_loss did not improve from 0.10845
# Epoch 44/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1500 - accuracy: 0.8973 - val_loss: 0.1575 - val_accuracy: 0.8625
#
# Epoch 00044: val_loss did not improve from 0.10845
# Epoch 45/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1569 - accuracy: 0.8723 - val_loss: 0.1583 - val_accuracy: 0.8500
#
# Epoch 00045: val_loss did not improve from 0.10845
# Epoch 46/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1352 - accuracy: 0.9198 - val_loss: 0.1532 - val_accuracy: 0.8625
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00046: val_loss did not improve from 0.10845
# Epoch 47/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1484 - accuracy: 0.9025 - val_loss: 0.1497 - val_accuracy: 0.8875
#
# Epoch 00047: val_loss did not improve from 0.10845
# Epoch 48/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1312 - accuracy: 0.9172 - val_loss: 0.1490 - val_accuracy: 0.8875
#
# Epoch 00048: val_loss did not improve from 0.10845
# Epoch 49/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1376 - accuracy: 0.9074 - val_loss: 0.1451 - val_accuracy: 0.8875
#
# Epoch 00049: val_loss did not improve from 0.10845
# Epoch 50/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1328 - accuracy: 0.9195 - val_loss: 0.1459 - val_accuracy: 0.8875
#
# Epoch 00050: val_loss did not improve from 0.10845
# Epoch 51/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1207 - accuracy: 0.9283 - val_loss: 0.1476 - val_accuracy: 0.8625
#
# Epoch 00051: val_loss did not improve from 0.10845
# Epoch 52/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1149 - accuracy: 0.9517 - val_loss: 0.1405 - val_accuracy: 0.8875
#
# Epoch 00052: val_loss did not improve from 0.10845
# Epoch 53/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1375 - accuracy: 0.8979 - val_loss: 0.1400 - val_accuracy: 0.8875
#
# Epoch 00053: val_loss did not improve from 0.10845
# Epoch 54/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1301 - accuracy: 0.9168 - val_loss: 0.1369 - val_accuracy: 0.8875
#
# Epoch 00054: val_loss did not improve from 0.10845
# Epoch 55/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1393 - accuracy: 0.9095 - val_loss: 0.1367 - val_accuracy: 0.8875
#
# Epoch 00055: val_loss did not improve from 0.10845
# Epoch 56/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1467 - accuracy: 0.9028 - val_loss: 0.1345 - val_accuracy: 0.8875
#
# Epoch 00056: val_loss did not improve from 0.10845
# Epoch 57/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1405 - accuracy: 0.8919 - val_loss: 0.1344 - val_accuracy: 0.8875
#
# Epoch 00057: val_loss did not improve from 0.10845
# Epoch 00057: early stopping
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1222 - accuracy: 0.9200
# Val Score:  [0.12221704423427582, 0.9200000166893005]
# ====================================================================================
#
#
# Training on Fold:  4
# Epoch 1/100
# 23/23 [==============================] - 1s 14ms/step - loss: 0.7641 - accuracy: 0.3574 - val_loss: 0.6108 - val_accuracy: 0.5125
#
# Epoch 00001: val_loss did not improve from 0.10845
# Epoch 2/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5812 - accuracy: 0.5649 - val_loss: 0.5601 - val_accuracy: 0.5500
#
# Epoch 00002: val_loss did not improve from 0.10845
# Epoch 3/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5109 - accuracy: 0.6056 - val_loss: 0.5067 - val_accuracy: 0.6000
#
# Epoch 00003: val_loss did not improve from 0.10845
# Epoch 4/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4482 - accuracy: 0.6732 - val_loss: 0.4682 - val_accuracy: 0.6875
#
# Epoch 00004: val_loss did not improve from 0.10845
# Epoch 5/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4191 - accuracy: 0.6852 - val_loss: 0.4364 - val_accuracy: 0.6500
#
# Epoch 00005: val_loss did not improve from 0.10845
# Epoch 6/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3882 - accuracy: 0.7044 - val_loss: 0.4122 - val_accuracy: 0.7125
#
# Epoch 00006: val_loss did not improve from 0.10845
# Epoch 7/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3686 - accuracy: 0.7349 - val_loss: 0.3900 - val_accuracy: 0.7250
#
# Epoch 00007: val_loss did not improve from 0.10845
# Epoch 8/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3602 - accuracy: 0.6724 - val_loss: 0.3595 - val_accuracy: 0.7375
#
# Epoch 00008: val_loss did not improve from 0.10845
# Epoch 9/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3164 - accuracy: 0.7601 - val_loss: 0.3718 - val_accuracy: 0.7000
#
# Epoch 00009: val_loss did not improve from 0.10845
# Epoch 10/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3078 - accuracy: 0.7636 - val_loss: 0.3264 - val_accuracy: 0.7625
#
# Epoch 00010: val_loss did not improve from 0.10845
# Epoch 11/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2880 - accuracy: 0.7739 - val_loss: 0.3340 - val_accuracy: 0.6875
#
# Epoch 00011: val_loss did not improve from 0.10845
# Epoch 12/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2657 - accuracy: 0.8025 - val_loss: 0.2851 - val_accuracy: 0.7875
#
# Epoch 00012: val_loss did not improve from 0.10845
# Epoch 13/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2735 - accuracy: 0.7748 - val_loss: 0.2757 - val_accuracy: 0.8250
#
# Epoch 00013: val_loss did not improve from 0.10845
# Epoch 14/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2504 - accuracy: 0.8048 - val_loss: 0.2393 - val_accuracy: 0.8125
#
# Epoch 00014: val_loss did not improve from 0.10845
# Epoch 15/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2406 - accuracy: 0.8109 - val_loss: 0.2476 - val_accuracy: 0.8125
#
# Epoch 00015: val_loss did not improve from 0.10845
# Epoch 16/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2427 - accuracy: 0.8127 - val_loss: 0.2331 - val_accuracy: 0.8375
#
# Epoch 00016: val_loss did not improve from 0.10845
# Epoch 17/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2137 - accuracy: 0.8475 - val_loss: 0.2132 - val_accuracy: 0.8375
#
# Epoch 00017: val_loss did not improve from 0.10845
# Epoch 18/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2060 - accuracy: 0.8429 - val_loss: 0.1946 - val_accuracy: 0.8750
#
# Epoch 00018: val_loss did not improve from 0.10845
# Epoch 19/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2007 - accuracy: 0.8708 - val_loss: 0.2008 - val_accuracy: 0.8375
#
# Epoch 00019: val_loss did not improve from 0.10845
# Epoch 20/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1909 - accuracy: 0.8679 - val_loss: 0.1882 - val_accuracy: 0.8625
#
# Epoch 00020: val_loss did not improve from 0.10845
# Epoch 21/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1870 - accuracy: 0.8414 - val_loss: 0.1964 - val_accuracy: 0.8375
#
# Epoch 00021: val_loss did not improve from 0.10845
# Epoch 22/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1611 - accuracy: 0.8917 - val_loss: 0.1660 - val_accuracy: 0.8750
#
# Epoch 00022: val_loss did not improve from 0.10845
# Epoch 23/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1578 - accuracy: 0.8840 - val_loss: 0.1624 - val_accuracy: 0.8500
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00023: val_loss did not improve from 0.10845
# Epoch 24/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1665 - accuracy: 0.8757 - val_loss: 0.1551 - val_accuracy: 0.8750
#
# Epoch 00024: val_loss did not improve from 0.10845
# Epoch 25/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1411 - accuracy: 0.9076 - val_loss: 0.1613 - val_accuracy: 0.8500
#
# Epoch 00025: val_loss did not improve from 0.10845
# Epoch 26/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1395 - accuracy: 0.9095 - val_loss: 0.1524 - val_accuracy: 0.8625
#
# Epoch 00026: val_loss did not improve from 0.10845
# Epoch 27/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1325 - accuracy: 0.9136 - val_loss: 0.1454 - val_accuracy: 0.8875
#
# Epoch 00027: val_loss did not improve from 0.10845
# Epoch 28/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1332 - accuracy: 0.9218 - val_loss: 0.1506 - val_accuracy: 0.8500
#
# Epoch 00028: val_loss did not improve from 0.10845
# Epoch 29/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1213 - accuracy: 0.9353 - val_loss: 0.1263 - val_accuracy: 0.8875
#
# Epoch 00029: val_loss did not improve from 0.10845
# Epoch 30/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1371 - accuracy: 0.9070 - val_loss: 0.1417 - val_accuracy: 0.8750
#
# Epoch 00030: val_loss did not improve from 0.10845
# Epoch 31/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1170 - accuracy: 0.9191 - val_loss: 0.1265 - val_accuracy: 0.8875
#
# Epoch 00031: val_loss did not improve from 0.10845
# Epoch 32/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1283 - accuracy: 0.9087 - val_loss: 0.1297 - val_accuracy: 0.9000
#
# Epoch 00032: val_loss did not improve from 0.10845
# Epoch 33/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1242 - accuracy: 0.9206 - val_loss: 0.1347 - val_accuracy: 0.8875
#
# Epoch 00033: val_loss did not improve from 0.10845
# Epoch 34/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1095 - accuracy: 0.9280 - val_loss: 0.1178 - val_accuracy: 0.9250
#
# Epoch 00034: val_loss did not improve from 0.10845
# Epoch 35/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1217 - accuracy: 0.9350 - val_loss: 0.1156 - val_accuracy: 0.9250
#
# Epoch 00035: val_loss did not improve from 0.10845
# Epoch 36/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1108 - accuracy: 0.9295 - val_loss: 0.1121 - val_accuracy: 0.8875
#
# Epoch 00036: val_loss did not improve from 0.10845
# Epoch 37/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0980 - accuracy: 0.9455 - val_loss: 0.1027 - val_accuracy: 0.9250
#
# Epoch 00037: val_loss improved from 0.10845 to 0.10271, saving model to subjek1CNN.h5
# Epoch 38/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1228 - accuracy: 0.9114 - val_loss: 0.0889 - val_accuracy: 0.9500
#
# Epoch 00038: val_loss improved from 0.10271 to 0.08893, saving model to subjek1CNN.h5
# Epoch 39/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1059 - accuracy: 0.9286 - val_loss: 0.0947 - val_accuracy: 0.9500
#
# Epoch 00039: val_loss did not improve from 0.08893
# Epoch 40/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0987 - accuracy: 0.9329 - val_loss: 0.0920 - val_accuracy: 0.9375
#
# Epoch 00040: val_loss did not improve from 0.08893
# Epoch 41/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1005 - accuracy: 0.9336 - val_loss: 0.0948 - val_accuracy: 0.9500
#
# Epoch 00041: val_loss did not improve from 0.08893
# Epoch 42/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0884 - accuracy: 0.9435 - val_loss: 0.0736 - val_accuracy: 0.9625
#
# Epoch 00042: val_loss improved from 0.08893 to 0.07357, saving model to subjek1CNN.h5
# Epoch 43/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0995 - accuracy: 0.9421 - val_loss: 0.0762 - val_accuracy: 0.9625
#
# Epoch 00043: val_loss did not improve from 0.07357
# Epoch 44/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0915 - accuracy: 0.9482 - val_loss: 0.0761 - val_accuracy: 0.9625
#
# Epoch 00044: val_loss did not improve from 0.07357
# Epoch 45/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0753 - accuracy: 0.9580 - val_loss: 0.0787 - val_accuracy: 0.9500
#
# Epoch 00045: val_loss did not improve from 0.07357
# Epoch 46/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0872 - accuracy: 0.9504 - val_loss: 0.0684 - val_accuracy: 0.9500
#
# Epoch 00046: val_loss improved from 0.07357 to 0.06840, saving model to subjek1CNN.h5
# Epoch 47/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0869 - accuracy: 0.9470 - val_loss: 0.0851 - val_accuracy: 0.9375
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00047: val_loss did not improve from 0.06840
# Epoch 48/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0829 - accuracy: 0.9333 - val_loss: 0.0695 - val_accuracy: 0.9500
#
# Epoch 00048: val_loss did not improve from 0.06840
# Epoch 49/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0781 - accuracy: 0.9501 - val_loss: 0.0609 - val_accuracy: 0.9625
#
# Epoch 00049: val_loss improved from 0.06840 to 0.06091, saving model to subjek1CNN.h5
# Epoch 50/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0862 - accuracy: 0.9488 - val_loss: 0.0639 - val_accuracy: 0.9500
#
# Epoch 00050: val_loss did not improve from 0.06091
# Epoch 51/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0691 - accuracy: 0.9586 - val_loss: 0.0619 - val_accuracy: 0.9500
#
# Epoch 00051: val_loss did not improve from 0.06091
# Epoch 52/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0819 - accuracy: 0.9562 - val_loss: 0.0607 - val_accuracy: 0.9625
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00052: val_loss improved from 0.06091 to 0.06067, saving model to subjek1CNN.h5
# Epoch 53/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0737 - accuracy: 0.9480 - val_loss: 0.0623 - val_accuracy: 0.9500
#
# Epoch 00053: val_loss did not improve from 0.06067
# Epoch 54/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0624 - accuracy: 0.9739 - val_loss: 0.0583 - val_accuracy: 0.9625
#
# Epoch 00054: val_loss improved from 0.06067 to 0.05833, saving model to subjek1CNN.h5
# Epoch 55/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0663 - accuracy: 0.9628 - val_loss: 0.0556 - val_accuracy: 0.9625
#
# Epoch 00055: val_loss improved from 0.05833 to 0.05560, saving model to subjek1CNN.h5
# Epoch 56/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0734 - accuracy: 0.9639 - val_loss: 0.0498 - val_accuracy: 0.9625
#
# Epoch 00056: val_loss improved from 0.05560 to 0.04984, saving model to subjek1CNN.h5
# Epoch 57/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0761 - accuracy: 0.9562 - val_loss: 0.0546 - val_accuracy: 0.9625
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00057: val_loss did not improve from 0.04984
# Epoch 58/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0542 - accuracy: 0.9793 - val_loss: 0.0553 - val_accuracy: 0.9625
#
# Epoch 00058: val_loss did not improve from 0.04984
# Epoch 59/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0712 - accuracy: 0.9512 - val_loss: 0.0560 - val_accuracy: 0.9500
#
# Epoch 00059: val_loss did not improve from 0.04984
# Epoch 60/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0672 - accuracy: 0.9582 - val_loss: 0.0532 - val_accuracy: 0.9625
#
# Epoch 00060: val_loss did not improve from 0.04984
# Epoch 61/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0645 - accuracy: 0.9599 - val_loss: 0.0502 - val_accuracy: 0.9625
#
# Epoch 00061: val_loss did not improve from 0.04984
# Epoch 62/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0616 - accuracy: 0.9745 - val_loss: 0.0528 - val_accuracy: 0.9625
#
# Epoch 00062: val_loss did not improve from 0.04984
# Epoch 63/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0627 - accuracy: 0.9632 - val_loss: 0.0529 - val_accuracy: 0.9625
#
# Epoch 00063: val_loss did not improve from 0.04984
# Epoch 00063: early stopping
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0449 - accuracy: 0.9700
# Val Score:  [0.04490414634346962, 0.9700000286102295]
# ====================================================================================
#
#
# Training on Fold:  5
# Epoch 1/100
# 23/23 [==============================] - 1s 14ms/step - loss: 0.8022 - accuracy: 0.3385 - val_loss: 0.6023 - val_accuracy: 0.6250
#
# Epoch 00001: val_loss did not improve from 0.04984
# Epoch 2/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5660 - accuracy: 0.5969 - val_loss: 0.5463 - val_accuracy: 0.6500
#
# Epoch 00002: val_loss did not improve from 0.04984
# Epoch 3/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4840 - accuracy: 0.6300 - val_loss: 0.4999 - val_accuracy: 0.7125
#
# Epoch 00003: val_loss did not improve from 0.04984
# Epoch 4/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4425 - accuracy: 0.6394 - val_loss: 0.4793 - val_accuracy: 0.6750
#
# Epoch 00004: val_loss did not improve from 0.04984
# Epoch 5/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4094 - accuracy: 0.6735 - val_loss: 0.4458 - val_accuracy: 0.7250
#
# Epoch 00005: val_loss did not improve from 0.04984
# Epoch 6/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3997 - accuracy: 0.6907 - val_loss: 0.4269 - val_accuracy: 0.7250
#
# Epoch 00006: val_loss did not improve from 0.04984
# Epoch 7/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3524 - accuracy: 0.7370 - val_loss: 0.4156 - val_accuracy: 0.7375
#
# Epoch 00007: val_loss did not improve from 0.04984
# Epoch 8/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3213 - accuracy: 0.7486 - val_loss: 0.3933 - val_accuracy: 0.7375
#
# Epoch 00008: val_loss did not improve from 0.04984
# Epoch 9/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3190 - accuracy: 0.7501 - val_loss: 0.3341 - val_accuracy: 0.7750
#
# Epoch 00009: val_loss did not improve from 0.04984
# Epoch 10/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3008 - accuracy: 0.7288 - val_loss: 0.3094 - val_accuracy: 0.7625
#
# Epoch 00010: val_loss did not improve from 0.04984
# Epoch 11/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2781 - accuracy: 0.7705 - val_loss: 0.3136 - val_accuracy: 0.8125
#
# Epoch 00011: val_loss did not improve from 0.04984
# Epoch 12/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2636 - accuracy: 0.7946 - val_loss: 0.3454 - val_accuracy: 0.7500
#
# Epoch 00012: val_loss did not improve from 0.04984
# Epoch 13/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2604 - accuracy: 0.7669 - val_loss: 0.2839 - val_accuracy: 0.8125
#
# Epoch 00013: val_loss did not improve from 0.04984
# Epoch 14/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2380 - accuracy: 0.7889 - val_loss: 0.2743 - val_accuracy: 0.8125
#
# Epoch 00014: val_loss did not improve from 0.04984
# Epoch 15/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2275 - accuracy: 0.8123 - val_loss: 0.2347 - val_accuracy: 0.8375
#
# Epoch 00015: val_loss did not improve from 0.04984
# Epoch 16/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2416 - accuracy: 0.8188 - val_loss: 0.2301 - val_accuracy: 0.8375
#
# Epoch 00016: val_loss did not improve from 0.04984
# Epoch 17/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2123 - accuracy: 0.8423 - val_loss: 0.2158 - val_accuracy: 0.8250
#
# Epoch 00017: val_loss did not improve from 0.04984
# Epoch 18/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1899 - accuracy: 0.8663 - val_loss: 0.2136 - val_accuracy: 0.8250
#
# Epoch 00018: val_loss did not improve from 0.04984
# Epoch 19/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2001 - accuracy: 0.8340 - val_loss: 0.2137 - val_accuracy: 0.8250
#
# Epoch 00019: val_loss did not improve from 0.04984
# Epoch 20/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1874 - accuracy: 0.8700 - val_loss: 0.2003 - val_accuracy: 0.8375
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00020: val_loss did not improve from 0.04984
# Epoch 21/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1854 - accuracy: 0.8545 - val_loss: 0.2047 - val_accuracy: 0.8250
#
# Epoch 00021: val_loss did not improve from 0.04984
# Epoch 22/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1658 - accuracy: 0.8692 - val_loss: 0.1968 - val_accuracy: 0.8250
#
# Epoch 00022: val_loss did not improve from 0.04984
# Epoch 23/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1667 - accuracy: 0.8859 - val_loss: 0.1773 - val_accuracy: 0.8500
#
# Epoch 00023: val_loss did not improve from 0.04984
# Epoch 24/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1612 - accuracy: 0.8747 - val_loss: 0.1766 - val_accuracy: 0.8250
#
# Epoch 00024: val_loss did not improve from 0.04984
# Epoch 25/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1358 - accuracy: 0.9173 - val_loss: 0.1802 - val_accuracy: 0.8250
#
# Epoch 00025: val_loss did not improve from 0.04984
# Epoch 26/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1512 - accuracy: 0.8978 - val_loss: 0.1729 - val_accuracy: 0.8375
#
# Epoch 00026: val_loss did not improve from 0.04984
# Epoch 27/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1420 - accuracy: 0.9113 - val_loss: 0.1654 - val_accuracy: 0.8375
#
# Epoch 00027: val_loss did not improve from 0.04984
# Epoch 28/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1485 - accuracy: 0.8896 - val_loss: 0.1533 - val_accuracy: 0.8500
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00028: val_loss did not improve from 0.04984
# Epoch 29/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1375 - accuracy: 0.8979 - val_loss: 0.1409 - val_accuracy: 0.8625
#
# Epoch 00029: val_loss did not improve from 0.04984
# Epoch 30/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1406 - accuracy: 0.9133 - val_loss: 0.1451 - val_accuracy: 0.8375
#
# Epoch 00030: val_loss did not improve from 0.04984
# Epoch 31/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1188 - accuracy: 0.9227 - val_loss: 0.1397 - val_accuracy: 0.8875
#
# Epoch 00031: val_loss did not improve from 0.04984
# Epoch 32/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1236 - accuracy: 0.9301 - val_loss: 0.1390 - val_accuracy: 0.8750
#
# Epoch 00032: val_loss did not improve from 0.04984
# Epoch 33/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1427 - accuracy: 0.9020 - val_loss: 0.1419 - val_accuracy: 0.8500
#
# Epoch 00033: val_loss did not improve from 0.04984
# Epoch 34/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1461 - accuracy: 0.8930 - val_loss: 0.1422 - val_accuracy: 0.8500
#
# Epoch 00034: val_loss did not improve from 0.04984
# Epoch 35/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1141 - accuracy: 0.9402 - val_loss: 0.1441 - val_accuracy: 0.8625
#
# Epoch 00035: val_loss did not improve from 0.04984
# Epoch 36/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1516 - accuracy: 0.8932 - val_loss: 0.1204 - val_accuracy: 0.8750
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00036: val_loss did not improve from 0.04984
# Epoch 37/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1090 - accuracy: 0.9409 - val_loss: 0.1167 - val_accuracy: 0.8875
#
# Epoch 00037: val_loss did not improve from 0.04984
# Epoch 38/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1171 - accuracy: 0.9209 - val_loss: 0.1164 - val_accuracy: 0.8875
#
# Epoch 00038: val_loss did not improve from 0.04984
# Epoch 39/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1258 - accuracy: 0.9093 - val_loss: 0.1150 - val_accuracy: 0.8875
#
# Epoch 00039: val_loss did not improve from 0.04984
# Epoch 40/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1233 - accuracy: 0.9063 - val_loss: 0.1143 - val_accuracy: 0.8750
#
# Epoch 00040: val_loss did not improve from 0.04984
# Epoch 41/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1106 - accuracy: 0.9390 - val_loss: 0.1119 - val_accuracy: 0.8750
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00041: val_loss did not improve from 0.04984
# Epoch 42/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1042 - accuracy: 0.9322 - val_loss: 0.1117 - val_accuracy: 0.8875
#
# Epoch 00042: val_loss did not improve from 0.04984
# Epoch 43/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1383 - accuracy: 0.9094 - val_loss: 0.1077 - val_accuracy: 0.9125
#
# Epoch 00043: val_loss did not improve from 0.04984
# Epoch 44/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0958 - accuracy: 0.9415 - val_loss: 0.1039 - val_accuracy: 0.9125
#
# Epoch 00044: val_loss did not improve from 0.04984
# Epoch 45/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1130 - accuracy: 0.9262 - val_loss: 0.1013 - val_accuracy: 0.9250
#
# Epoch 00045: val_loss did not improve from 0.04984
# Epoch 46/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1157 - accuracy: 0.9246 - val_loss: 0.1034 - val_accuracy: 0.9000
#
# Epoch 00046: val_loss did not improve from 0.04984
# Epoch 47/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0973 - accuracy: 0.9480 - val_loss: 0.1042 - val_accuracy: 0.9125
#
# Epoch 00047: val_loss did not improve from 0.04984
# Epoch 48/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1153 - accuracy: 0.9144 - val_loss: 0.1031 - val_accuracy: 0.9250
#
# Epoch 00048: val_loss did not improve from 0.04984
# Epoch 49/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1108 - accuracy: 0.9363 - val_loss: 0.0995 - val_accuracy: 0.9375
#
# Epoch 00049: val_loss did not improve from 0.04984
# Epoch 00049: early stopping
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0798 - accuracy: 0.9250
# Val Score:  [0.07975541055202484, 0.925000011920929]
# ====================================================================================

# %%
print("data train x",t_x.shape)
print("data train y",t_y.shape)

print("data tes x",val_x.shape)
print("data tes y",val_y.shape)

model = load_model('subjek1CNN.h5')
model.evaluate(val_x, val_y)
# Out:
# data train x (800, 8, 60, 1)
# data train y (800, 4)
# data tes x (200, 8, 60, 1)
# data tes y (200, 4)
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0276 - accuracy: 1.0000
# [0.027589749544858932, 1.0]

# %%
fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)
ax1.plot(model_history[0].history['accuracy'], label='Training Fold 1 accuration')
ax1.plot(model_history[1].history['accuracy'], label='Training Fold 2 accuration')
ax1.plot(model_history[2].history['accuracy'], label='Training Fold 3 accuration')
ax1.plot(model_history[3].history['accuracy'], label='Training Fold 4 accuration')
ax1.plot(model_history[4].history['accuracy'], label='Training Fold 5 accuration')
ax1.legend()
ax2.plot(model_history[1].history['loss'], label='Training Fold 1 loss')
ax2.plot(model_history[1].history['loss'], label='Training Fold 2 loss')
ax2.plot(model_history[2].history['loss'], label='Training Fold 3 loss')
ax2.plot(model_history[3].history['loss'], label='Training Fold 4 loss ')
ax2.plot(model_history[4].history['loss'], label='Training Fold 5 loss')
ax2.legend()
plt.show()

# %%
fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt1.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[0].history['loss'], label='Train Loss Fold 1', color='black')
plt2.plot(model_history[0].history['val_loss'], label='Val Loss Fold 1', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red')
plt1.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[1].history['loss'], label='Train Loss Fold 2', color='red')
plt2.plot(model_history[1].history['val_loss'], label='Val Loss Fold 2', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green')
plt1.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[2].history['loss'], label='Train Loss Fold 3', color='green')
plt2.plot(model_history[2].history['val_loss'], label='Val Loss Fold 3', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()


fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue')
plt1.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[3].history['loss'], label='Train Loss Fold 4', color='blue')
plt2.plot(model_history[3].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='purple')
plt1.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[4].history['loss'], label='Train Loss Fold 4', color='purple')
plt2.plot(model_history[4].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

# %%
MODEL_NAME ='/content/subjek1CNN.h5' 

#CLIP = True # if your model was trained with np.clip to clip  values
CLIP = False
CLIP_VAL = 8  # if above, what was the value +/-

model = tf.keras.models.load_model(MODEL_NAME)

VALDIR = '/content/drive/MyDrive/Colab Notebooks/data8'
ACTIONS =  ["idle","maju","kiri", "kanan"]
PRED_BATCH = 32


def get_val_data(valdir, action, batch_size):

   # argmax_dict = {0: 0, 1: 0, 2: 0,3:0}
    argmax_dict = {2: 0, 0: 0, 1: 0,3:0}
    raw_pred_dict = {0: 0, 1: 0, 2: 0,3:0}

    action_dir = os.path.join(valdir, action)
    for session_file in os.listdir(action_dir):
        filepath = os.path.join(action_dir,session_file)
        if CLIP:
            data = np.clip(np.load(filepath), -CLIP_VAL, CLIP_VAL) / CLIP_VAL
            #print(data)
        else:
            data = np.load(filepath) 
        preds = model.predict([data.reshape(-1, 8, 60,1)], batch_size=batch_size)
        
        for pred in preds:
            argmax = np.argmax(pred)
            argmax_dict[argmax] += 1
            for idx,value in enumerate(pred):
                raw_pred_dict[idx] += value
    
    argmax_pct_dict = {}
    for i in argmax_dict:
        total = 0
        correct = argmax_dict[i]
        for ii in argmax_dict:
            total += argmax_dict[ii]
        argmax_pct_dict[i] = round(correct/total, 4)
    return argmax_dict, raw_pred_dict, argmax_pct_dict


def make_conf_mat(none,left,forward, right):
    action_dict = {"idle":none,"maju": forward, "kiri": left, "kanan": right}
    action_conf_mat = pd.DataFrame(action_dict)
    actions = [i for i in action_dict]

    fig = plt.figure(figsize=(15, 6))
    ax = fig.add_subplot(111)
    ax.matshow(action_conf_mat, cmap=plt.cm.RdYlGn)
    ax.set_xticklabels([""]+actions)
    ax.set_yticklabels([""]+actions)

    for idx, i in enumerate(action_dict):
        for idx2, ii in enumerate(action_dict[i]):
            ax.text(idx, idx2, f"{round(float(action_dict[i][ii]),2)}", va='center', ha='center')
    # Rotate the tick labels and set their alignment.
    
    plt.title("Matrik data")
    plt.ylabel("Predicted Action")
    fig.tight_layout()
    plt.show()



forward_argmax_dict, forward_raw_pred_dict, forward_argmax_pct_dict = get_val_data(VALDIR, "maju", PRED_BATCH)
none_argmax_dict, none_raw_pred_dict, none_argmax_pct_dict = get_val_data(VALDIR, "idle", PRED_BATCH)
left_argmax_dict, left_raw_pred_dict, left_argmax_pct_dict = get_val_data(VALDIR, "kiri", PRED_BATCH)
right_argmax_dict, right_raw_pred_dict, right_argmax_pct_dict = get_val_data(VALDIR, "kanan", PRED_BATCH)
make_conf_mat(none_argmax_pct_dict,forward_argmax_pct_dict,left_argmax_pct_dict,  right_argmax_pct_dict)

# %%
x_train,x_test,y_train,y_test=train_test_split(train_X,train_y,test_size=0.2)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (800, 8, 60, 1)
# (200, 8, 60, 1)
# (800, 4)
# (200, 4)

# %%
from sklearn.metrics import roc_curve, auc

#y_score = clf.decision_function(xval)
y_score = model.predict(x_test)

#Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()


# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
    
    
print("roc_auc:",sum(roc_auc.values())/4)
ACTIONS =  ["idle","maju","kiri", "kanan"]
for i in range(0,4):
    plt.figure()
    fig, ax = plt.subplots(figsize=(10,10))
    plt.plot(fpr[i], tpr[i],linewidth=3)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    #plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % ACTIONS[i])
    plt.title('%s -ROC curve (area = %0.2f)' % (ACTIONS[i],roc_auc[i]))
    
    plt.legend(loc="lower right")
    plt.show()
# Out:
# roc_auc: 0.9997287391995836

# %% [markdown]
# # LSTM

# %%
def lstm_model():
  model2 = Sequential()

  model2.add(LSTM(64,input_shape = (train2_X.shape[1:]), return_sequences=True))
  #model2.add(Dropout(0.5))
  #model2.add(MaxPooling2D(pool_size = (4,4)))
  model2.add(Dropout(0.2))
  model2.add(BatchNormalization())

  model2.add(LSTM(64,input_shape = (train2_X.shape[1:]), return_sequences=True))
  #model2.add(Dropout(0.5))
  #model2.add(MaxPooling2D(pool_size = (2,2)))
  model2.add(Dropout(0.2))
  model2.add(BatchNormalization())

  model2.add(LSTM(64,input_shape = (train2_X.shape[1:]), return_sequences=True))
  #model2.add(Dropout(0.5))
  #model2.add(MaxPooling2D(pool_size = (1,1)))
  model2.add(Dropout(0.2))
  model2.add(BatchNormalization())
 
  model2.add(LSTM(64))

  model.add(Flatten())
    
  model2.add(Dense(32, activation = "relu"))
  model2.add(BatchNormalization())

  model2.add(Dense(4, activation='sigmoid'))

  model2.compile(loss='binary_crossentropy', optimizer= Adam(lr = 0.0001), metrics=['accuracy'])
  return model2

# %%
model = lstm_model()
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_34 (LSTM)               (None, 8, 64)             32000
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 8, 64)             0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 8, 64)             256
# _________________________________________________________________
# lstm_35 (LSTM)               (None, 8, 64)             33024
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 8, 64)             0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 8, 64)             256
# _________________________________________________________________
# lstm_36 (LSTM)               (None, 8, 64)             33024
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 8, 64)             0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 8, 64)             256
# _________________________________________________________________
# lstm_37 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dense_21 (Dense)             (None, 32)                2080
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 32)                128
# _________________________________________________________________
# dense_22 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 134,180
# Trainable params: 133,732
# Non-trainable params: 448
# _________________________________________________________________

# %%
#set early stopping criteria
pat = 5
#this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='loss', patience=pat, verbose=1)

#define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('subjek1LSTM.h5', verbose=1, save_best_only=True)

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=100, BATCH_SIZE=32):
    model = None
    model = lstm_model() 
    results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[learning_rate_reduction,early_stopping, model_checkpoint], 
              verbose=1, validation_split=0.1)   
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs=100
batch_size=32

#save the model history in a list after fitting so that we can plot later
model_history = [] 
for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(train2_X, train_y, test_size=0.2, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
   
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 23/23 [==============================] - 6s 66ms/step - loss: 0.8286 - accuracy: 0.2848 - val_loss: 0.6920 - val_accuracy: 0.3625
#
# Epoch 00001: val_loss improved from inf to 0.69199, saving model to subjek1LSTM.h5
# Epoch 2/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.7337 - accuracy: 0.4047 - val_loss: 0.6920 - val_accuracy: 0.3750
#
# Epoch 00002: val_loss improved from 0.69199 to 0.69198, saving model to subjek1LSTM.h5
# Epoch 3/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.6923 - accuracy: 0.4453 - val_loss: 0.6914 - val_accuracy: 0.3750
#
# Epoch 00003: val_loss improved from 0.69198 to 0.69144, saving model to subjek1LSTM.h5
# Epoch 4/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.6869 - accuracy: 0.4599 - val_loss: 0.6904 - val_accuracy: 0.4250
#
# Epoch 00004: val_loss improved from 0.69144 to 0.69036, saving model to subjek1LSTM.h5
# Epoch 5/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.6320 - accuracy: 0.5422 - val_loss: 0.6881 - val_accuracy: 0.4875
#
# Epoch 00005: val_loss improved from 0.69036 to 0.68807, saving model to subjek1LSTM.h5
# Epoch 6/100
# 23/23 [==============================] - 2s 78ms/step - loss: 0.6256 - accuracy: 0.5400 - val_loss: 0.6850 - val_accuracy: 0.5000
#
# Epoch 00006: val_loss improved from 0.68807 to 0.68499, saving model to subjek1LSTM.h5
# Epoch 7/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.6034 - accuracy: 0.5624 - val_loss: 0.6806 - val_accuracy: 0.5500
#
# Epoch 00007: val_loss improved from 0.68499 to 0.68056, saving model to subjek1LSTM.h5
# Epoch 8/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.5944 - accuracy: 0.5762 - val_loss: 0.6736 - val_accuracy: 0.5500
#
# Epoch 00008: val_loss improved from 0.68056 to 0.67360, saving model to subjek1LSTM.h5
# Epoch 9/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5572 - accuracy: 0.6289 - val_loss: 0.6647 - val_accuracy: 0.5250
#
# Epoch 00009: val_loss improved from 0.67360 to 0.66466, saving model to subjek1LSTM.h5
# Epoch 10/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.5636 - accuracy: 0.6000 - val_loss: 0.6503 - val_accuracy: 0.5500
#
# Epoch 00010: val_loss improved from 0.66466 to 0.65028, saving model to subjek1LSTM.h5
# Epoch 11/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.5322 - accuracy: 0.6428 - val_loss: 0.6315 - val_accuracy: 0.5750
#
# Epoch 00011: val_loss improved from 0.65028 to 0.63147, saving model to subjek1LSTM.h5
# Epoch 12/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.5130 - accuracy: 0.6904 - val_loss: 0.6076 - val_accuracy: 0.6125
#
# Epoch 00012: val_loss improved from 0.63147 to 0.60762, saving model to subjek1LSTM.h5
# Epoch 13/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.5196 - accuracy: 0.6584 - val_loss: 0.5816 - val_accuracy: 0.6500
#
# Epoch 00013: val_loss improved from 0.60762 to 0.58161, saving model to subjek1LSTM.h5
# Epoch 14/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.5179 - accuracy: 0.6730 - val_loss: 0.5508 - val_accuracy: 0.6625
#
# Epoch 00014: val_loss improved from 0.58161 to 0.55084, saving model to subjek1LSTM.h5
# Epoch 15/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.4920 - accuracy: 0.6843 - val_loss: 0.5198 - val_accuracy: 0.7250
#
# Epoch 00015: val_loss improved from 0.55084 to 0.51975, saving model to subjek1LSTM.h5
# Epoch 16/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4897 - accuracy: 0.7101 - val_loss: 0.4860 - val_accuracy: 0.7500
#
# Epoch 00016: val_loss improved from 0.51975 to 0.48602, saving model to subjek1LSTM.h5
# Epoch 17/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4653 - accuracy: 0.7094 - val_loss: 0.4576 - val_accuracy: 0.7500
#
# Epoch 00017: val_loss improved from 0.48602 to 0.45756, saving model to subjek1LSTM.h5
# Epoch 18/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4471 - accuracy: 0.7568 - val_loss: 0.4379 - val_accuracy: 0.7500
#
# Epoch 00018: val_loss improved from 0.45756 to 0.43788, saving model to subjek1LSTM.h5
# Epoch 19/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4448 - accuracy: 0.7432 - val_loss: 0.4122 - val_accuracy: 0.7500
#
# Epoch 00019: val_loss improved from 0.43788 to 0.41224, saving model to subjek1LSTM.h5
# Epoch 20/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.4456 - accuracy: 0.7202 - val_loss: 0.3941 - val_accuracy: 0.7125
#
# Epoch 00020: val_loss improved from 0.41224 to 0.39409, saving model to subjek1LSTM.h5
# Epoch 21/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4401 - accuracy: 0.7265 - val_loss: 0.3797 - val_accuracy: 0.7375
#
# Epoch 00021: val_loss improved from 0.39409 to 0.37965, saving model to subjek1LSTM.h5
# Epoch 22/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4244 - accuracy: 0.7479 - val_loss: 0.3635 - val_accuracy: 0.7625
#
# Epoch 00022: val_loss improved from 0.37965 to 0.36346, saving model to subjek1LSTM.h5
# Epoch 23/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.4204 - accuracy: 0.7505 - val_loss: 0.3439 - val_accuracy: 0.8250
#
# Epoch 00023: val_loss improved from 0.36346 to 0.34392, saving model to subjek1LSTM.h5
# Epoch 24/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4106 - accuracy: 0.7613 - val_loss: 0.3307 - val_accuracy: 0.8500
#
# Epoch 00024: val_loss improved from 0.34392 to 0.33075, saving model to subjek1LSTM.h5
# Epoch 25/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.4067 - accuracy: 0.7876 - val_loss: 0.3232 - val_accuracy: 0.8125
#
# Epoch 00025: val_loss improved from 0.33075 to 0.32320, saving model to subjek1LSTM.h5
# Epoch 26/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3907 - accuracy: 0.7779 - val_loss: 0.3127 - val_accuracy: 0.8000
#
# Epoch 00026: val_loss improved from 0.32320 to 0.31267, saving model to subjek1LSTM.h5
# Epoch 27/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3956 - accuracy: 0.7801 - val_loss: 0.3049 - val_accuracy: 0.8375
#
# Epoch 00027: val_loss improved from 0.31267 to 0.30495, saving model to subjek1LSTM.h5
# Epoch 28/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4007 - accuracy: 0.7713 - val_loss: 0.2974 - val_accuracy: 0.8500
#
# Epoch 00028: val_loss improved from 0.30495 to 0.29742, saving model to subjek1LSTM.h5
# Epoch 29/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3861 - accuracy: 0.8021 - val_loss: 0.2852 - val_accuracy: 0.8625
#
# Epoch 00029: val_loss improved from 0.29742 to 0.28521, saving model to subjek1LSTM.h5
# Epoch 30/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3791 - accuracy: 0.8007 - val_loss: 0.2762 - val_accuracy: 0.8625
#
# Epoch 00030: val_loss improved from 0.28521 to 0.27617, saving model to subjek1LSTM.h5
# Epoch 31/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3650 - accuracy: 0.8230 - val_loss: 0.2746 - val_accuracy: 0.8375
#
# Epoch 00031: val_loss improved from 0.27617 to 0.27463, saving model to subjek1LSTM.h5
# Epoch 32/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3556 - accuracy: 0.8169 - val_loss: 0.2813 - val_accuracy: 0.8125
#
# Epoch 00032: val_loss did not improve from 0.27463
# Epoch 33/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3588 - accuracy: 0.8057 - val_loss: 0.2702 - val_accuracy: 0.8500
#
# Epoch 00033: val_loss improved from 0.27463 to 0.27017, saving model to subjek1LSTM.h5
# Epoch 34/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3532 - accuracy: 0.8006 - val_loss: 0.2645 - val_accuracy: 0.8375
#
# Epoch 00034: val_loss improved from 0.27017 to 0.26448, saving model to subjek1LSTM.h5
# Epoch 35/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3493 - accuracy: 0.8052 - val_loss: 0.2579 - val_accuracy: 0.8500
#
# Epoch 00035: val_loss improved from 0.26448 to 0.25787, saving model to subjek1LSTM.h5
# Epoch 36/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3401 - accuracy: 0.8386 - val_loss: 0.2537 - val_accuracy: 0.8625
#
# Epoch 00036: val_loss improved from 0.25787 to 0.25372, saving model to subjek1LSTM.h5
# Epoch 37/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3401 - accuracy: 0.8102 - val_loss: 0.2463 - val_accuracy: 0.8500
#
# Epoch 00037: val_loss improved from 0.25372 to 0.24630, saving model to subjek1LSTM.h5
# Epoch 38/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3110 - accuracy: 0.8613 - val_loss: 0.2438 - val_accuracy: 0.8500
#
# Epoch 00038: val_loss improved from 0.24630 to 0.24379, saving model to subjek1LSTM.h5
# Epoch 39/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.3245 - accuracy: 0.8501 - val_loss: 0.2412 - val_accuracy: 0.8375
#
# Epoch 00039: val_loss improved from 0.24379 to 0.24119, saving model to subjek1LSTM.h5
# Epoch 40/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3141 - accuracy: 0.8701 - val_loss: 0.2373 - val_accuracy: 0.8375
#
# Epoch 00040: val_loss improved from 0.24119 to 0.23733, saving model to subjek1LSTM.h5
# Epoch 41/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3153 - accuracy: 0.8479 - val_loss: 0.2310 - val_accuracy: 0.8500
#
# Epoch 00041: val_loss improved from 0.23733 to 0.23103, saving model to subjek1LSTM.h5
# Epoch 42/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3127 - accuracy: 0.8472 - val_loss: 0.2255 - val_accuracy: 0.8750
#
# Epoch 00042: val_loss improved from 0.23103 to 0.22548, saving model to subjek1LSTM.h5
# Epoch 43/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3078 - accuracy: 0.8284 - val_loss: 0.2213 - val_accuracy: 0.8625
#
# Epoch 00043: val_loss improved from 0.22548 to 0.22133, saving model to subjek1LSTM.h5
# Epoch 44/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.3047 - accuracy: 0.8589 - val_loss: 0.2241 - val_accuracy: 0.8875
#
# Epoch 00044: val_loss did not improve from 0.22133
# Epoch 45/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2949 - accuracy: 0.8323 - val_loss: 0.2201 - val_accuracy: 0.8875
#
# Epoch 00045: val_loss improved from 0.22133 to 0.22007, saving model to subjek1LSTM.h5
# Epoch 46/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2797 - accuracy: 0.8720 - val_loss: 0.2107 - val_accuracy: 0.8625
#
# Epoch 00046: val_loss improved from 0.22007 to 0.21067, saving model to subjek1LSTM.h5
# Epoch 47/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2761 - accuracy: 0.8711 - val_loss: 0.2053 - val_accuracy: 0.8875
#
# Epoch 00047: val_loss improved from 0.21067 to 0.20526, saving model to subjek1LSTM.h5
# Epoch 48/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3017 - accuracy: 0.8565 - val_loss: 0.2006 - val_accuracy: 0.8750
#
# Epoch 00048: val_loss improved from 0.20526 to 0.20057, saving model to subjek1LSTM.h5
# Epoch 49/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2693 - accuracy: 0.8769 - val_loss: 0.1974 - val_accuracy: 0.8750
#
# Epoch 00049: val_loss improved from 0.20057 to 0.19741, saving model to subjek1LSTM.h5
# Epoch 50/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2843 - accuracy: 0.8378 - val_loss: 0.1953 - val_accuracy: 0.8750
#
# Epoch 00050: val_loss improved from 0.19741 to 0.19531, saving model to subjek1LSTM.h5
# Epoch 51/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2790 - accuracy: 0.8521 - val_loss: 0.1881 - val_accuracy: 0.9125
#
# Epoch 00051: val_loss improved from 0.19531 to 0.18809, saving model to subjek1LSTM.h5
# Epoch 52/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2624 - accuracy: 0.8770 - val_loss: 0.1873 - val_accuracy: 0.9000
#
# Epoch 00052: val_loss improved from 0.18809 to 0.18728, saving model to subjek1LSTM.h5
# Epoch 53/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2785 - accuracy: 0.8673 - val_loss: 0.1790 - val_accuracy: 0.8875
#
# Epoch 00053: val_loss improved from 0.18728 to 0.17897, saving model to subjek1LSTM.h5
# Epoch 54/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2397 - accuracy: 0.8885 - val_loss: 0.1779 - val_accuracy: 0.9000
#
# Epoch 00054: val_loss improved from 0.17897 to 0.17787, saving model to subjek1LSTM.h5
# Epoch 55/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2387 - accuracy: 0.8890 - val_loss: 0.1775 - val_accuracy: 0.9000
#
# Epoch 00055: val_loss improved from 0.17787 to 0.17749, saving model to subjek1LSTM.h5
# Epoch 56/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2447 - accuracy: 0.8818 - val_loss: 0.1780 - val_accuracy: 0.9000
#
# Epoch 00056: val_loss did not improve from 0.17749
# Epoch 57/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2475 - accuracy: 0.8810 - val_loss: 0.1743 - val_accuracy: 0.8875
#
# Epoch 00057: val_loss improved from 0.17749 to 0.17430, saving model to subjek1LSTM.h5
# Epoch 58/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2500 - accuracy: 0.8689 - val_loss: 0.1714 - val_accuracy: 0.9125
#
# Epoch 00058: val_loss improved from 0.17430 to 0.17135, saving model to subjek1LSTM.h5
# Epoch 59/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2366 - accuracy: 0.8756 - val_loss: 0.1704 - val_accuracy: 0.9000
#
# Epoch 00059: val_loss improved from 0.17135 to 0.17043, saving model to subjek1LSTM.h5
# Epoch 60/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2342 - accuracy: 0.8888 - val_loss: 0.1646 - val_accuracy: 0.9125
#
# Epoch 00060: val_loss improved from 0.17043 to 0.16456, saving model to subjek1LSTM.h5
# Epoch 61/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2215 - accuracy: 0.9001 - val_loss: 0.1625 - val_accuracy: 0.9000
#
# Epoch 00061: val_loss improved from 0.16456 to 0.16248, saving model to subjek1LSTM.h5
# Epoch 62/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2411 - accuracy: 0.8796 - val_loss: 0.1594 - val_accuracy: 0.9250
#
# Epoch 00062: val_loss improved from 0.16248 to 0.15942, saving model to subjek1LSTM.h5
# Epoch 63/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2154 - accuracy: 0.8905 - val_loss: 0.1555 - val_accuracy: 0.9125
#
# Epoch 00063: val_loss improved from 0.15942 to 0.15551, saving model to subjek1LSTM.h5
# Epoch 64/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2252 - accuracy: 0.8929 - val_loss: 0.1567 - val_accuracy: 0.9125
#
# Epoch 00064: val_loss did not improve from 0.15551
# Epoch 65/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2071 - accuracy: 0.9141 - val_loss: 0.1487 - val_accuracy: 0.9250
#
# Epoch 00065: val_loss improved from 0.15551 to 0.14874, saving model to subjek1LSTM.h5
# Epoch 66/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2006 - accuracy: 0.9114 - val_loss: 0.1494 - val_accuracy: 0.9375
#
# Epoch 00066: val_loss did not improve from 0.14874
# Epoch 67/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1954 - accuracy: 0.9169 - val_loss: 0.1504 - val_accuracy: 0.9375
#
# Epoch 00067: val_loss did not improve from 0.14874
# Epoch 68/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2001 - accuracy: 0.8982 - val_loss: 0.1509 - val_accuracy: 0.9375
#
# Epoch 00068: val_loss did not improve from 0.14874
# Epoch 69/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1960 - accuracy: 0.9115 - val_loss: 0.1439 - val_accuracy: 0.9375
#
# Epoch 00069: val_loss improved from 0.14874 to 0.14388, saving model to subjek1LSTM.h5
# Epoch 70/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1911 - accuracy: 0.9155 - val_loss: 0.1420 - val_accuracy: 0.9375
#
# Epoch 00070: val_loss improved from 0.14388 to 0.14204, saving model to subjek1LSTM.h5
# Epoch 71/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1994 - accuracy: 0.9133 - val_loss: 0.1397 - val_accuracy: 0.9375
#
# Epoch 00071: val_loss improved from 0.14204 to 0.13966, saving model to subjek1LSTM.h5
# Epoch 72/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1883 - accuracy: 0.9175 - val_loss: 0.1335 - val_accuracy: 0.9500
#
# Epoch 00072: val_loss improved from 0.13966 to 0.13347, saving model to subjek1LSTM.h5
# Epoch 73/100
# 23/23 [==============================] - 0s 21ms/step - loss: 0.1795 - accuracy: 0.9240 - val_loss: 0.1224 - val_accuracy: 0.9500
#
# Epoch 00073: val_loss improved from 0.13347 to 0.12242, saving model to subjek1LSTM.h5
# Epoch 74/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2017 - accuracy: 0.8958 - val_loss: 0.1226 - val_accuracy: 0.9500
#
# Epoch 00074: val_loss did not improve from 0.12242
# Epoch 75/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1756 - accuracy: 0.9268 - val_loss: 0.1210 - val_accuracy: 0.9500
#
# Epoch 00075: val_loss improved from 0.12242 to 0.12099, saving model to subjek1LSTM.h5
# Epoch 76/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1844 - accuracy: 0.9149 - val_loss: 0.1144 - val_accuracy: 0.9625
#
# Epoch 00076: val_loss improved from 0.12099 to 0.11438, saving model to subjek1LSTM.h5
# Epoch 77/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1547 - accuracy: 0.9370 - val_loss: 0.1188 - val_accuracy: 0.9625
#
# Epoch 00077: val_loss did not improve from 0.11438
# Epoch 78/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1882 - accuracy: 0.9030 - val_loss: 0.1175 - val_accuracy: 0.9500
#
# Epoch 00078: val_loss did not improve from 0.11438
# Epoch 79/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1681 - accuracy: 0.9185 - val_loss: 0.1161 - val_accuracy: 0.9625
#
# Epoch 00079: val_loss did not improve from 0.11438
# Epoch 80/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1750 - accuracy: 0.9204 - val_loss: 0.1194 - val_accuracy: 0.9625
#
# Epoch 00080: val_loss did not improve from 0.11438
# Epoch 81/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1742 - accuracy: 0.9134 - val_loss: 0.1123 - val_accuracy: 0.9625
#
# Epoch 00081: val_loss improved from 0.11438 to 0.11231, saving model to subjek1LSTM.h5
# Epoch 82/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1746 - accuracy: 0.9314 - val_loss: 0.1115 - val_accuracy: 0.9500
#
# Epoch 00082: val_loss improved from 0.11231 to 0.11151, saving model to subjek1LSTM.h5
# Epoch 00082: early stopping
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1052 - accuracy: 0.9650
# Val Score:  [0.10523758828639984, 0.9649999737739563]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
# 23/23 [==============================] - 6s 65ms/step - loss: 0.9128 - accuracy: 0.2528 - val_loss: 0.7021 - val_accuracy: 0.2500
#
# Epoch 00001: val_loss did not improve from 0.11151
# Epoch 2/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.7538 - accuracy: 0.4231 - val_loss: 0.7106 - val_accuracy: 0.2625
#
# Epoch 00002: val_loss did not improve from 0.11151
# Epoch 3/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.6781 - accuracy: 0.4852 - val_loss: 0.7192 - val_accuracy: 0.2625
#
# Epoch 00003: val_loss did not improve from 0.11151
# Epoch 4/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.6508 - accuracy: 0.5367 - val_loss: 0.7271 - val_accuracy: 0.2875
#
# Epoch 00004: val_loss did not improve from 0.11151
# Epoch 5/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5937 - accuracy: 0.6102 - val_loss: 0.7353 - val_accuracy: 0.2875
#
# Epoch 00005: val_loss did not improve from 0.11151
# Epoch 6/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.5978 - accuracy: 0.5839 - val_loss: 0.7422 - val_accuracy: 0.3125
#
# Epoch 00006: val_loss did not improve from 0.11151
# Epoch 7/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5857 - accuracy: 0.5829 - val_loss: 0.7464 - val_accuracy: 0.3125
#
# Epoch 00007: val_loss did not improve from 0.11151
# Epoch 8/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5639 - accuracy: 0.5940 - val_loss: 0.7464 - val_accuracy: 0.3125
#
# Epoch 00008: val_loss did not improve from 0.11151
# Epoch 9/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5468 - accuracy: 0.6297 - val_loss: 0.7409 - val_accuracy: 0.3375
#
# Epoch 00009: val_loss did not improve from 0.11151
# Epoch 10/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.5237 - accuracy: 0.6732 - val_loss: 0.7263 - val_accuracy: 0.3500
#
# Epoch 00010: val_loss did not improve from 0.11151
# Epoch 11/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.5271 - accuracy: 0.6468 - val_loss: 0.7040 - val_accuracy: 0.3875
#
# Epoch 00011: val_loss did not improve from 0.11151
# Epoch 12/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.5123 - accuracy: 0.6874 - val_loss: 0.6766 - val_accuracy: 0.4750
#
# Epoch 00012: val_loss did not improve from 0.11151
# Epoch 13/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.4762 - accuracy: 0.7264 - val_loss: 0.6408 - val_accuracy: 0.6875
#
# Epoch 00013: val_loss did not improve from 0.11151
# Epoch 14/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4793 - accuracy: 0.6920 - val_loss: 0.6043 - val_accuracy: 0.6875
#
# Epoch 00014: val_loss did not improve from 0.11151
# Epoch 15/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4907 - accuracy: 0.6778 - val_loss: 0.5722 - val_accuracy: 0.7250
#
# Epoch 00015: val_loss did not improve from 0.11151
# Epoch 16/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.4528 - accuracy: 0.7616 - val_loss: 0.5389 - val_accuracy: 0.7125
#
# Epoch 00016: val_loss did not improve from 0.11151
# Epoch 17/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4540 - accuracy: 0.7396 - val_loss: 0.5109 - val_accuracy: 0.7250
#
# Epoch 00017: val_loss did not improve from 0.11151
# Epoch 18/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.4471 - accuracy: 0.7367 - val_loss: 0.4849 - val_accuracy: 0.7000
#
# Epoch 00018: val_loss did not improve from 0.11151
# Epoch 19/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.4330 - accuracy: 0.7485 - val_loss: 0.4628 - val_accuracy: 0.7125
#
# Epoch 00019: val_loss did not improve from 0.11151
# Epoch 20/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.4275 - accuracy: 0.7667 - val_loss: 0.4422 - val_accuracy: 0.7250
#
# Epoch 00020: val_loss did not improve from 0.11151
# Epoch 21/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.4088 - accuracy: 0.7862 - val_loss: 0.4233 - val_accuracy: 0.7625
#
# Epoch 00021: val_loss did not improve from 0.11151
# Epoch 22/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.4096 - accuracy: 0.7772 - val_loss: 0.4205 - val_accuracy: 0.7500
#
# Epoch 00022: val_loss did not improve from 0.11151
# Epoch 23/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3948 - accuracy: 0.7867 - val_loss: 0.4038 - val_accuracy: 0.7875
#
# Epoch 00023: val_loss did not improve from 0.11151
# Epoch 24/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4072 - accuracy: 0.7470 - val_loss: 0.3831 - val_accuracy: 0.7875
#
# Epoch 00024: val_loss did not improve from 0.11151
# Epoch 25/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3978 - accuracy: 0.7741 - val_loss: 0.3696 - val_accuracy: 0.8125
#
# Epoch 00025: val_loss did not improve from 0.11151
# Epoch 26/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3729 - accuracy: 0.8121 - val_loss: 0.3654 - val_accuracy: 0.8000
#
# Epoch 00026: val_loss did not improve from 0.11151
# Epoch 27/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3660 - accuracy: 0.8128 - val_loss: 0.3526 - val_accuracy: 0.8125
#
# Epoch 00027: val_loss did not improve from 0.11151
# Epoch 28/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3625 - accuracy: 0.8199 - val_loss: 0.3425 - val_accuracy: 0.8125
#
# Epoch 00028: val_loss did not improve from 0.11151
# Epoch 29/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3619 - accuracy: 0.8127 - val_loss: 0.3324 - val_accuracy: 0.8250
#
# Epoch 00029: val_loss did not improve from 0.11151
# Epoch 30/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.3523 - accuracy: 0.8266 - val_loss: 0.3238 - val_accuracy: 0.8375
#
# Epoch 00030: val_loss did not improve from 0.11151
# Epoch 31/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3710 - accuracy: 0.7889 - val_loss: 0.3096 - val_accuracy: 0.8000
#
# Epoch 00031: val_loss did not improve from 0.11151
# Epoch 32/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3499 - accuracy: 0.8115 - val_loss: 0.3122 - val_accuracy: 0.8625
#
# Epoch 00032: val_loss did not improve from 0.11151
# Epoch 33/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3368 - accuracy: 0.8375 - val_loss: 0.3113 - val_accuracy: 0.8625
#
# Epoch 00033: val_loss did not improve from 0.11151
# Epoch 34/100
# 23/23 [==============================] - 0s 22ms/step - loss: 0.3506 - accuracy: 0.8253 - val_loss: 0.2978 - val_accuracy: 0.8375
#
# Epoch 00034: val_loss did not improve from 0.11151
# Epoch 35/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3349 - accuracy: 0.8109 - val_loss: 0.2801 - val_accuracy: 0.8625
#
# Epoch 00035: val_loss did not improve from 0.11151
# Epoch 36/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3299 - accuracy: 0.8287 - val_loss: 0.2823 - val_accuracy: 0.8625
#
# Epoch 00036: val_loss did not improve from 0.11151
# Epoch 37/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3060 - accuracy: 0.8536 - val_loss: 0.2661 - val_accuracy: 0.8750
#
# Epoch 00037: val_loss did not improve from 0.11151
# Epoch 38/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3093 - accuracy: 0.8434 - val_loss: 0.2644 - val_accuracy: 0.8625
#
# Epoch 00038: val_loss did not improve from 0.11151
# Epoch 39/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3119 - accuracy: 0.8583 - val_loss: 0.2635 - val_accuracy: 0.8625
#
# Epoch 00039: val_loss did not improve from 0.11151
# Epoch 40/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2888 - accuracy: 0.8653 - val_loss: 0.2596 - val_accuracy: 0.8750
#
# Epoch 00040: val_loss did not improve from 0.11151
# Epoch 41/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2897 - accuracy: 0.8831 - val_loss: 0.2465 - val_accuracy: 0.9000
#
# Epoch 00041: val_loss did not improve from 0.11151
# Epoch 42/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2875 - accuracy: 0.8629 - val_loss: 0.2331 - val_accuracy: 0.8875
#
# Epoch 00042: val_loss did not improve from 0.11151
# Epoch 43/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2838 - accuracy: 0.8523 - val_loss: 0.2360 - val_accuracy: 0.9000
#
# Epoch 00043: val_loss did not improve from 0.11151
# Epoch 44/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2958 - accuracy: 0.8420 - val_loss: 0.2242 - val_accuracy: 0.9000
#
# Epoch 00044: val_loss did not improve from 0.11151
# Epoch 45/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2912 - accuracy: 0.8460 - val_loss: 0.2212 - val_accuracy: 0.8750
#
# Epoch 00045: val_loss did not improve from 0.11151
# Epoch 46/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2788 - accuracy: 0.8612 - val_loss: 0.2185 - val_accuracy: 0.9000
#
# Epoch 00046: val_loss did not improve from 0.11151
# Epoch 47/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2541 - accuracy: 0.8823 - val_loss: 0.2114 - val_accuracy: 0.8875
#
# Epoch 00047: val_loss did not improve from 0.11151
# Epoch 48/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2635 - accuracy: 0.8837 - val_loss: 0.2049 - val_accuracy: 0.9000
#
# Epoch 00048: val_loss did not improve from 0.11151
# Epoch 49/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2753 - accuracy: 0.8416 - val_loss: 0.1997 - val_accuracy: 0.9000
#
# Epoch 00049: val_loss did not improve from 0.11151
# Epoch 50/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2467 - accuracy: 0.9032 - val_loss: 0.1943 - val_accuracy: 0.9125
#
# Epoch 00050: val_loss did not improve from 0.11151
# Epoch 51/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2503 - accuracy: 0.8905 - val_loss: 0.1932 - val_accuracy: 0.9250
#
# Epoch 00051: val_loss did not improve from 0.11151
# Epoch 52/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2729 - accuracy: 0.8568 - val_loss: 0.1876 - val_accuracy: 0.8875
#
# Epoch 00052: val_loss did not improve from 0.11151
# Epoch 53/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2399 - accuracy: 0.8804 - val_loss: 0.1843 - val_accuracy: 0.9000
#
# Epoch 00053: val_loss did not improve from 0.11151
# Epoch 54/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2418 - accuracy: 0.8757 - val_loss: 0.1832 - val_accuracy: 0.8875
#
# Epoch 00054: val_loss did not improve from 0.11151
# Epoch 55/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2289 - accuracy: 0.8872 - val_loss: 0.1828 - val_accuracy: 0.9125
#
# Epoch 00055: val_loss did not improve from 0.11151
# Epoch 56/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2283 - accuracy: 0.8907 - val_loss: 0.1784 - val_accuracy: 0.8875
#
# Epoch 00056: val_loss did not improve from 0.11151
# Epoch 57/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2239 - accuracy: 0.9063 - val_loss: 0.1796 - val_accuracy: 0.8750
#
# Epoch 00057: val_loss did not improve from 0.11151
# Epoch 58/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2120 - accuracy: 0.9087 - val_loss: 0.1750 - val_accuracy: 0.9000
#
# Epoch 00058: val_loss did not improve from 0.11151
# Epoch 59/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2182 - accuracy: 0.9085 - val_loss: 0.1800 - val_accuracy: 0.9000
#
# Epoch 00059: val_loss did not improve from 0.11151
# Epoch 60/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2199 - accuracy: 0.8933 - val_loss: 0.1670 - val_accuracy: 0.9000
#
# Epoch 00060: val_loss did not improve from 0.11151
# Epoch 61/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2169 - accuracy: 0.9019 - val_loss: 0.1623 - val_accuracy: 0.8875
#
# Epoch 00061: val_loss did not improve from 0.11151
# Epoch 62/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2110 - accuracy: 0.8924 - val_loss: 0.1653 - val_accuracy: 0.9250
#
# Epoch 00062: val_loss did not improve from 0.11151
# Epoch 63/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2090 - accuracy: 0.9181 - val_loss: 0.1571 - val_accuracy: 0.9125
#
# Epoch 00063: val_loss did not improve from 0.11151
# Epoch 64/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1934 - accuracy: 0.9198 - val_loss: 0.1574 - val_accuracy: 0.9000
#
# Epoch 00064: val_loss did not improve from 0.11151
# Epoch 65/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1948 - accuracy: 0.9170 - val_loss: 0.1539 - val_accuracy: 0.9125
#
# Epoch 00065: val_loss did not improve from 0.11151
# Epoch 66/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1967 - accuracy: 0.9029 - val_loss: 0.1525 - val_accuracy: 0.9250
#
# Epoch 00066: val_loss did not improve from 0.11151
# Epoch 67/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1883 - accuracy: 0.9207 - val_loss: 0.1457 - val_accuracy: 0.9250
#
# Epoch 00067: val_loss did not improve from 0.11151
# Epoch 68/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1756 - accuracy: 0.9369 - val_loss: 0.1431 - val_accuracy: 0.9250
#
# Epoch 00068: val_loss did not improve from 0.11151
# Epoch 69/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1849 - accuracy: 0.9179 - val_loss: 0.1408 - val_accuracy: 0.9000
#
# Epoch 00069: val_loss did not improve from 0.11151
# Epoch 70/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2020 - accuracy: 0.8943 - val_loss: 0.1429 - val_accuracy: 0.9000
#
# Epoch 00070: val_loss did not improve from 0.11151
# Epoch 71/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1857 - accuracy: 0.9104 - val_loss: 0.1437 - val_accuracy: 0.9000
#
# Epoch 00071: val_loss did not improve from 0.11151
# Epoch 72/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1750 - accuracy: 0.9179 - val_loss: 0.1367 - val_accuracy: 0.9125
#
# Epoch 00072: val_loss did not improve from 0.11151
# Epoch 00072: early stopping
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1494 - accuracy: 0.9150
# Val Score:  [0.14937198162078857, 0.9150000214576721]
# ====================================================================================
#
#
# Training on Fold:  3
# Epoch 1/100
# 23/23 [==============================] - 6s 62ms/step - loss: 0.8810 - accuracy: 0.2933 - val_loss: 0.6949 - val_accuracy: 0.2125
#
# Epoch 00001: val_loss did not improve from 0.11151
# Epoch 2/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7563 - accuracy: 0.3939 - val_loss: 0.6985 - val_accuracy: 0.2250
#
# Epoch 00002: val_loss did not improve from 0.11151
# Epoch 3/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.6847 - accuracy: 0.4815 - val_loss: 0.7020 - val_accuracy: 0.2250
#
# Epoch 00003: val_loss did not improve from 0.11151
# Epoch 4/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.6445 - accuracy: 0.5462 - val_loss: 0.7041 - val_accuracy: 0.2250
#
# Epoch 00004: val_loss did not improve from 0.11151
# Epoch 5/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.6095 - accuracy: 0.5541 - val_loss: 0.7041 - val_accuracy: 0.2250
#
# Epoch 00005: val_loss did not improve from 0.11151
# Epoch 6/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.6025 - accuracy: 0.5633 - val_loss: 0.7016 - val_accuracy: 0.2375
#
# Epoch 00006: val_loss did not improve from 0.11151
# Epoch 7/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.5803 - accuracy: 0.5892 - val_loss: 0.6957 - val_accuracy: 0.2875
#
# Epoch 00007: val_loss did not improve from 0.11151
# Epoch 8/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.5680 - accuracy: 0.5939 - val_loss: 0.6855 - val_accuracy: 0.3375
#
# Epoch 00008: val_loss did not improve from 0.11151
# Epoch 9/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5448 - accuracy: 0.6402 - val_loss: 0.6692 - val_accuracy: 0.3500
#
# Epoch 00009: val_loss did not improve from 0.11151
# Epoch 10/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5361 - accuracy: 0.6429 - val_loss: 0.6491 - val_accuracy: 0.4125
#
# Epoch 00010: val_loss did not improve from 0.11151
# Epoch 11/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.5189 - accuracy: 0.6853 - val_loss: 0.6249 - val_accuracy: 0.5125
#
# Epoch 00011: val_loss did not improve from 0.11151
# Epoch 12/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.5271 - accuracy: 0.6541 - val_loss: 0.5948 - val_accuracy: 0.6750
#
# Epoch 00012: val_loss did not improve from 0.11151
# Epoch 13/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5193 - accuracy: 0.6677 - val_loss: 0.5607 - val_accuracy: 0.7500
#
# Epoch 00013: val_loss did not improve from 0.11151
# Epoch 14/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5065 - accuracy: 0.6698 - val_loss: 0.5222 - val_accuracy: 0.7750
#
# Epoch 00014: val_loss did not improve from 0.11151
# Epoch 15/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.4909 - accuracy: 0.6847 - val_loss: 0.4847 - val_accuracy: 0.7875
#
# Epoch 00015: val_loss did not improve from 0.11151
# Epoch 16/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.4780 - accuracy: 0.7226 - val_loss: 0.4559 - val_accuracy: 0.7750
#
# Epoch 00016: val_loss did not improve from 0.11151
# Epoch 17/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4811 - accuracy: 0.6890 - val_loss: 0.4315 - val_accuracy: 0.7625
#
# Epoch 00017: val_loss did not improve from 0.11151
# Epoch 18/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4563 - accuracy: 0.7275 - val_loss: 0.4083 - val_accuracy: 0.7750
#
# Epoch 00018: val_loss did not improve from 0.11151
# Epoch 19/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.4601 - accuracy: 0.7152 - val_loss: 0.3883 - val_accuracy: 0.7875
#
# Epoch 00019: val_loss did not improve from 0.11151
# Epoch 20/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4531 - accuracy: 0.7376 - val_loss: 0.3754 - val_accuracy: 0.7875
#
# Epoch 00020: val_loss did not improve from 0.11151
# Epoch 21/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.4311 - accuracy: 0.7396 - val_loss: 0.3662 - val_accuracy: 0.7750
#
# Epoch 00021: val_loss did not improve from 0.11151
# Epoch 22/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.4251 - accuracy: 0.7602 - val_loss: 0.3588 - val_accuracy: 0.7875
#
# Epoch 00022: val_loss did not improve from 0.11151
# Epoch 23/100
# 23/23 [==============================] - 1s 24ms/step - loss: 0.4240 - accuracy: 0.7450 - val_loss: 0.3497 - val_accuracy: 0.7750
#
# Epoch 00023: val_loss did not improve from 0.11151
# Epoch 24/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.4204 - accuracy: 0.7572 - val_loss: 0.3422 - val_accuracy: 0.7750
#
# Epoch 00024: val_loss did not improve from 0.11151
# Epoch 25/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.4082 - accuracy: 0.7762 - val_loss: 0.3290 - val_accuracy: 0.8000
#
# Epoch 00025: val_loss did not improve from 0.11151
# Epoch 26/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.4094 - accuracy: 0.7726 - val_loss: 0.3186 - val_accuracy: 0.8250
#
# Epoch 00026: val_loss did not improve from 0.11151
# Epoch 27/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.3908 - accuracy: 0.7729 - val_loss: 0.3107 - val_accuracy: 0.8375
#
# Epoch 00027: val_loss did not improve from 0.11151
# Epoch 28/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.3855 - accuracy: 0.7907 - val_loss: 0.3051 - val_accuracy: 0.8500
#
# Epoch 00028: val_loss did not improve from 0.11151
# Epoch 29/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.3692 - accuracy: 0.8123 - val_loss: 0.2975 - val_accuracy: 0.8500
#
# Epoch 00029: val_loss did not improve from 0.11151
# Epoch 30/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.3595 - accuracy: 0.8303 - val_loss: 0.2890 - val_accuracy: 0.8250
#
# Epoch 00030: val_loss did not improve from 0.11151
# Epoch 31/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3629 - accuracy: 0.8044 - val_loss: 0.2865 - val_accuracy: 0.8375
#
# Epoch 00031: val_loss did not improve from 0.11151
# Epoch 32/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3647 - accuracy: 0.8132 - val_loss: 0.2831 - val_accuracy: 0.8500
#
# Epoch 00032: val_loss did not improve from 0.11151
# Epoch 33/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3628 - accuracy: 0.7990 - val_loss: 0.2746 - val_accuracy: 0.8500
#
# Epoch 00033: val_loss did not improve from 0.11151
# Epoch 34/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3487 - accuracy: 0.8001 - val_loss: 0.2712 - val_accuracy: 0.8500
#
# Epoch 00034: val_loss did not improve from 0.11151
# Epoch 35/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3410 - accuracy: 0.8148 - val_loss: 0.2743 - val_accuracy: 0.8500
#
# Epoch 00035: val_loss did not improve from 0.11151
# Epoch 36/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3360 - accuracy: 0.8137 - val_loss: 0.2622 - val_accuracy: 0.8375
#
# Epoch 00036: val_loss did not improve from 0.11151
# Epoch 37/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3429 - accuracy: 0.8251 - val_loss: 0.2560 - val_accuracy: 0.8625
#
# Epoch 00037: val_loss did not improve from 0.11151
# Epoch 38/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3194 - accuracy: 0.8402 - val_loss: 0.2562 - val_accuracy: 0.8500
#
# Epoch 00038: val_loss did not improve from 0.11151
# Epoch 39/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3139 - accuracy: 0.8528 - val_loss: 0.2471 - val_accuracy: 0.8625
#
# Epoch 00039: val_loss did not improve from 0.11151
# Epoch 40/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3015 - accuracy: 0.8525 - val_loss: 0.2410 - val_accuracy: 0.8500
#
# Epoch 00040: val_loss did not improve from 0.11151
# Epoch 41/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2962 - accuracy: 0.8714 - val_loss: 0.2308 - val_accuracy: 0.8750
#
# Epoch 00041: val_loss did not improve from 0.11151
# Epoch 42/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2913 - accuracy: 0.8670 - val_loss: 0.2291 - val_accuracy: 0.8875
#
# Epoch 00042: val_loss did not improve from 0.11151
# Epoch 43/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2829 - accuracy: 0.8625 - val_loss: 0.2232 - val_accuracy: 0.8875
#
# Epoch 00043: val_loss did not improve from 0.11151
# Epoch 44/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2956 - accuracy: 0.8356 - val_loss: 0.2194 - val_accuracy: 0.8750
#
# Epoch 00044: val_loss did not improve from 0.11151
# Epoch 45/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3009 - accuracy: 0.8338 - val_loss: 0.2275 - val_accuracy: 0.8625
#
# Epoch 00045: val_loss did not improve from 0.11151
# Epoch 46/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2831 - accuracy: 0.8609 - val_loss: 0.2177 - val_accuracy: 0.8750
#
# Epoch 00046: val_loss did not improve from 0.11151
# Epoch 47/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2866 - accuracy: 0.8436 - val_loss: 0.2120 - val_accuracy: 0.8750
#
# Epoch 00047: val_loss did not improve from 0.11151
# Epoch 48/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2848 - accuracy: 0.8627 - val_loss: 0.2017 - val_accuracy: 0.8875
#
# Epoch 00048: val_loss did not improve from 0.11151
# Epoch 49/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2651 - accuracy: 0.8744 - val_loss: 0.2044 - val_accuracy: 0.8875
#
# Epoch 00049: val_loss did not improve from 0.11151
# Epoch 50/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2551 - accuracy: 0.8929 - val_loss: 0.2003 - val_accuracy: 0.8875
#
# Epoch 00050: val_loss did not improve from 0.11151
# Epoch 51/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2610 - accuracy: 0.8730 - val_loss: 0.1943 - val_accuracy: 0.8875
#
# Epoch 00051: val_loss did not improve from 0.11151
# Epoch 52/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2422 - accuracy: 0.8914 - val_loss: 0.1973 - val_accuracy: 0.8875
#
# Epoch 00052: val_loss did not improve from 0.11151
# Epoch 53/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2444 - accuracy: 0.8903 - val_loss: 0.1853 - val_accuracy: 0.8875
#
# Epoch 00053: val_loss did not improve from 0.11151
# Epoch 54/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2448 - accuracy: 0.8733 - val_loss: 0.1868 - val_accuracy: 0.8875
#
# Epoch 00054: val_loss did not improve from 0.11151
# Epoch 55/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2343 - accuracy: 0.8869 - val_loss: 0.1847 - val_accuracy: 0.8875
#
# Epoch 00055: val_loss did not improve from 0.11151
# Epoch 56/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2281 - accuracy: 0.8956 - val_loss: 0.1862 - val_accuracy: 0.8750
#
# Epoch 00056: val_loss did not improve from 0.11151
# Epoch 57/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2234 - accuracy: 0.9034 - val_loss: 0.1849 - val_accuracy: 0.8750
#
# Epoch 00057: val_loss did not improve from 0.11151
# Epoch 58/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2587 - accuracy: 0.8584 - val_loss: 0.1727 - val_accuracy: 0.9000
#
# Epoch 00058: val_loss did not improve from 0.11151
# Epoch 59/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2210 - accuracy: 0.9035 - val_loss: 0.1732 - val_accuracy: 0.9000
#
# Epoch 00059: val_loss did not improve from 0.11151
# Epoch 60/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2224 - accuracy: 0.8789 - val_loss: 0.1717 - val_accuracy: 0.9125
#
# Epoch 00060: val_loss did not improve from 0.11151
# Epoch 61/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1998 - accuracy: 0.9220 - val_loss: 0.1639 - val_accuracy: 0.9375
#
# Epoch 00061: val_loss did not improve from 0.11151
# Epoch 62/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1990 - accuracy: 0.9029 - val_loss: 0.1609 - val_accuracy: 0.9000
#
# Epoch 00062: val_loss did not improve from 0.11151
# Epoch 63/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2150 - accuracy: 0.8913 - val_loss: 0.1518 - val_accuracy: 0.9375
#
# Epoch 00063: val_loss did not improve from 0.11151
# Epoch 64/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2044 - accuracy: 0.8999 - val_loss: 0.1561 - val_accuracy: 0.9000
#
# Epoch 00064: val_loss did not improve from 0.11151
# Epoch 65/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1909 - accuracy: 0.9318 - val_loss: 0.1581 - val_accuracy: 0.9000
#
# Epoch 00065: val_loss did not improve from 0.11151
# Epoch 66/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1841 - accuracy: 0.9243 - val_loss: 0.1489 - val_accuracy: 0.9125
#
# Epoch 00066: val_loss did not improve from 0.11151
# Epoch 67/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1899 - accuracy: 0.9000 - val_loss: 0.1498 - val_accuracy: 0.9125
#
# Epoch 00067: val_loss did not improve from 0.11151
# Epoch 68/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1883 - accuracy: 0.9226 - val_loss: 0.1519 - val_accuracy: 0.9000
#
# Epoch 00068: val_loss did not improve from 0.11151
# Epoch 69/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1641 - accuracy: 0.9492 - val_loss: 0.1421 - val_accuracy: 0.9125
#
# Epoch 00069: val_loss did not improve from 0.11151
# Epoch 70/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1847 - accuracy: 0.9265 - val_loss: 0.1453 - val_accuracy: 0.9250
#
# Epoch 00070: val_loss did not improve from 0.11151
# Epoch 71/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2107 - accuracy: 0.8745 - val_loss: 0.1387 - val_accuracy: 0.9000
#
# Epoch 00071: val_loss did not improve from 0.11151
# Epoch 72/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1735 - accuracy: 0.9324 - val_loss: 0.1337 - val_accuracy: 0.9125
#
# Epoch 00072: val_loss did not improve from 0.11151
# Epoch 73/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1719 - accuracy: 0.9424 - val_loss: 0.1335 - val_accuracy: 0.9375
#
# Epoch 00073: val_loss did not improve from 0.11151
# Epoch 74/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1733 - accuracy: 0.9129 - val_loss: 0.1338 - val_accuracy: 0.9125
#
# Epoch 00074: val_loss did not improve from 0.11151
# Epoch 00074: early stopping
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1287 - accuracy: 0.9400
# Val Score:  [0.12869560718536377, 0.9399999976158142]
# ====================================================================================
#
#
# Training on Fold:  4
# Epoch 1/100
# 23/23 [==============================] - 6s 62ms/step - loss: 0.9023 - accuracy: 0.2276 - val_loss: 0.6871 - val_accuracy: 0.2875
#
# Epoch 00001: val_loss did not improve from 0.11151
# ...
#
# Epoch 00020: val_loss did not improve from 0.09896
# Epoch 21/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.4406 - accuracy: 0.7615 - val_loss: 0.4326 - val_accuracy: 0.7125
#
# Epoch 00021: val_loss did not improve from 0.09896
# Epoch 22/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.4179 - accuracy: 0.7467 - val_loss: 0.4145 - val_accuracy: 0.7625
#
# Epoch 00022: val_loss did not improve from 0.09896
# Epoch 23/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.4110 - accuracy: 0.7634 - val_loss: 0.4006 - val_accuracy: 0.7750
#
# Epoch 00023: val_loss did not improve from 0.09896
# Epoch 24/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.3972 - accuracy: 0.7783 - val_loss: 0.3923 - val_accuracy: 0.7875
#
# Epoch 00024: val_loss did not improve from 0.09896
# Epoch 25/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.3916 - accuracy: 0.8181 - val_loss: 0.3857 - val_accuracy: 0.7750
#
# Epoch 00025: val_loss did not improve from 0.09896
# Epoch 26/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.4027 - accuracy: 0.7621 - val_loss: 0.3794 - val_accuracy: 0.7875
#
# Epoch 00026: val_loss did not improve from 0.09896
# Epoch 27/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3727 - accuracy: 0.8041 - val_loss: 0.3719 - val_accuracy: 0.7875
#
# Epoch 00027: val_loss did not improve from 0.09896
# Epoch 28/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3663 - accuracy: 0.8175 - val_loss: 0.3602 - val_accuracy: 0.7750
#
# Epoch 00028: val_loss did not improve from 0.09896
# Epoch 29/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.3743 - accuracy: 0.7772 - val_loss: 0.3473 - val_accuracy: 0.7875
#
# Epoch 00029: val_loss did not improve from 0.09896
# Epoch 30/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3611 - accuracy: 0.7940 - val_loss: 0.3431 - val_accuracy: 0.8000
#
# Epoch 00030: val_loss did not improve from 0.09896
# Epoch 31/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.3693 - accuracy: 0.7875 - val_loss: 0.3320 - val_accuracy: 0.8125
#
# Epoch 00031: val_loss did not improve from 0.09896
# Epoch 32/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3488 - accuracy: 0.8066 - val_loss: 0.3291 - val_accuracy: 0.8000
#
# Epoch 00032: val_loss did not improve from 0.09896
# Epoch 33/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3436 - accuracy: 0.8244 - val_loss: 0.3258 - val_accuracy: 0.7875
#
# Epoch 00033: val_loss did not improve from 0.09896
# Epoch 34/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3451 - accuracy: 0.8141 - val_loss: 0.3212 - val_accuracy: 0.8125
#
# Epoch 00034: val_loss did not improve from 0.09896
# Epoch 35/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3269 - accuracy: 0.8436 - val_loss: 0.3129 - val_accuracy: 0.8125
#
# Epoch 00035: val_loss did not improve from 0.09896
# Epoch 36/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.3396 - accuracy: 0.8220 - val_loss: 0.3016 - val_accuracy: 0.8000
#
# Epoch 00036: val_loss did not improve from 0.09896
# Epoch 37/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3353 - accuracy: 0.8180 - val_loss: 0.2939 - val_accuracy: 0.8250
#
# Epoch 00037: val_loss did not improve from 0.09896
# Epoch 38/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.3103 - accuracy: 0.8453 - val_loss: 0.2865 - val_accuracy: 0.8625
#
# Epoch 00038: val_loss did not improve from 0.09896
# Epoch 39/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3167 - accuracy: 0.8239 - val_loss: 0.2837 - val_accuracy: 0.8250
#
# Epoch 00039: val_loss did not improve from 0.09896
# Epoch 40/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3062 - accuracy: 0.8583 - val_loss: 0.2825 - val_accuracy: 0.8500
#
# Epoch 00040: val_loss did not improve from 0.09896
# Epoch 41/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3100 - accuracy: 0.8229 - val_loss: 0.2818 - val_accuracy: 0.8250
#
# Epoch 00041: val_loss did not improve from 0.09896
# Epoch 42/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.3003 - accuracy: 0.8444 - val_loss: 0.2760 - val_accuracy: 0.8250
#
# Epoch 00042: val_loss did not improve from 0.09896
# Epoch 43/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2904 - accuracy: 0.8363 - val_loss: 0.2678 - val_accuracy: 0.8375
#
# Epoch 00043: val_loss did not improve from 0.09896
# Epoch 44/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.2860 - accuracy: 0.8721 - val_loss: 0.2577 - val_accuracy: 0.8500
#
# Epoch 00044: val_loss did not improve from 0.09896
# Epoch 45/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2899 - accuracy: 0.8580 - val_loss: 0.2578 - val_accuracy: 0.8500
#
# Epoch 00045: val_loss did not improve from 0.09896
# Epoch 46/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2739 - accuracy: 0.8807 - val_loss: 0.2511 - val_accuracy: 0.8375
#
# Epoch 00046: val_loss did not improve from 0.09896
# Epoch 47/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2758 - accuracy: 0.8551 - val_loss: 0.2472 - val_accuracy: 0.8625
#
# Epoch 00047: val_loss did not improve from 0.09896
# Epoch 48/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2756 - accuracy: 0.8601 - val_loss: 0.2403 - val_accuracy: 0.8625
#
# Epoch 00048: val_loss did not improve from 0.09896
# Epoch 49/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2630 - accuracy: 0.8806 - val_loss: 0.2350 - val_accuracy: 0.8625
#
# Epoch 00049: val_loss did not improve from 0.09896
# Epoch 50/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2780 - accuracy: 0.8326 - val_loss: 0.2279 - val_accuracy: 0.8750
#
# Epoch 00050: val_loss did not improve from 0.09896
# Epoch 51/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2516 - accuracy: 0.8834 - val_loss: 0.2263 - val_accuracy: 0.8625
#
# Epoch 00051: val_loss did not improve from 0.09896
# Epoch 52/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2495 - accuracy: 0.8892 - val_loss: 0.2164 - val_accuracy: 0.8875
#
# Epoch 00052: val_loss did not improve from 0.09896
# Epoch 53/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2627 - accuracy: 0.8657 - val_loss: 0.2151 - val_accuracy: 0.8875
#
# Epoch 00053: val_loss did not improve from 0.09896
# Epoch 54/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2556 - accuracy: 0.8780 - val_loss: 0.2092 - val_accuracy: 0.8875
#
# Epoch 00054: val_loss did not improve from 0.09896
# Epoch 55/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2528 - accuracy: 0.8715 - val_loss: 0.2089 - val_accuracy: 0.8875
#
# Epoch 00055: val_loss did not improve from 0.09896
# Epoch 56/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2407 - accuracy: 0.8756 - val_loss: 0.2032 - val_accuracy: 0.9000
#
# Epoch 00056: val_loss did not improve from 0.09896
# Epoch 57/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2313 - accuracy: 0.8943 - val_loss: 0.2035 - val_accuracy: 0.8625
#
# Epoch 00057: val_loss did not improve from 0.09896
# Epoch 58/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2418 - accuracy: 0.8715 - val_loss: 0.1935 - val_accuracy: 0.9000
#
# Epoch 00058: val_loss did not improve from 0.09896
# Epoch 59/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2297 - accuracy: 0.8863 - val_loss: 0.1875 - val_accuracy: 0.9000
#
# Epoch 00059: val_loss did not improve from 0.09896
# Epoch 60/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2257 - accuracy: 0.9058 - val_loss: 0.1888 - val_accuracy: 0.9000
#
# Epoch 00060: val_loss did not improve from 0.09896
# Epoch 61/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2310 - accuracy: 0.8716 - val_loss: 0.1886 - val_accuracy: 0.9125
#
# Epoch 00061: val_loss did not improve from 0.09896
# Epoch 62/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2114 - accuracy: 0.8969 - val_loss: 0.1890 - val_accuracy: 0.8875
#
# Epoch 00062: val_loss did not improve from 0.09896
# Epoch 63/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2255 - accuracy: 0.8933 - val_loss: 0.1881 - val_accuracy: 0.8875
#
# Epoch 00063: val_loss did not improve from 0.09896
# Epoch 64/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2150 - accuracy: 0.8876 - val_loss: 0.1793 - val_accuracy: 0.9000
#
# Epoch 00064: val_loss did not improve from 0.09896
# Epoch 65/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2163 - accuracy: 0.9197 - val_loss: 0.1745 - val_accuracy: 0.9000
#
# Epoch 00065: val_loss did not improve from 0.09896
# Epoch 66/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.2012 - accuracy: 0.8988 - val_loss: 0.1786 - val_accuracy: 0.9000
#
# Epoch 00066: val_loss did not improve from 0.09896
# Epoch 67/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2064 - accuracy: 0.9034 - val_loss: 0.1709 - val_accuracy: 0.9000
#
# Epoch 00067: val_loss did not improve from 0.09896
# Epoch 68/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2195 - accuracy: 0.8915 - val_loss: 0.1692 - val_accuracy: 0.9000
#
# Epoch 00068: val_loss did not improve from 0.09896
# Epoch 69/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1953 - accuracy: 0.9214 - val_loss: 0.1635 - val_accuracy: 0.9250
#
# Epoch 00069: val_loss did not improve from 0.09896
# Epoch 70/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1926 - accuracy: 0.8952 - val_loss: 0.1566 - val_accuracy: 0.9250
#
# Epoch 00070: val_loss did not improve from 0.09896
# Epoch 71/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1924 - accuracy: 0.9117 - val_loss: 0.1571 - val_accuracy: 0.9250
#
# Epoch 00071: val_loss did not improve from 0.09896
# Epoch 72/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1900 - accuracy: 0.9104 - val_loss: 0.1576 - val_accuracy: 0.9125
#
# Epoch 00072: val_loss did not improve from 0.09896
# Epoch 73/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1924 - accuracy: 0.9057 - val_loss: 0.1488 - val_accuracy: 0.9250
#
# Epoch 00073: val_loss did not improve from 0.09896
# Epoch 74/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1852 - accuracy: 0.9070 - val_loss: 0.1497 - val_accuracy: 0.9375
#
# Epoch 00074: val_loss did not improve from 0.09896
# Epoch 75/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1765 - accuracy: 0.9203 - val_loss: 0.1495 - val_accuracy: 0.9125
#
# Epoch 00075: val_loss did not improve from 0.09896
# Epoch 76/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1665 - accuracy: 0.9325 - val_loss: 0.1461 - val_accuracy: 0.9250
#
# Epoch 00076: val_loss did not improve from 0.09896
# Epoch 77/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1610 - accuracy: 0.9374 - val_loss: 0.1391 - val_accuracy: 0.9250
#
# Epoch 00077: val_loss did not improve from 0.09896
# Epoch 78/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1783 - accuracy: 0.9296 - val_loss: 0.1391 - val_accuracy: 0.9250
#
# Epoch 00078: val_loss did not improve from 0.09896
# Epoch 79/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1519 - accuracy: 0.9453 - val_loss: 0.1342 - val_accuracy: 0.9250
#
# Epoch 00079: val_loss did not improve from 0.09896
# Epoch 80/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1713 - accuracy: 0.9282 - val_loss: 0.1319 - val_accuracy: 0.9250
#
# Epoch 00080: val_loss did not improve from 0.09896
# Epoch 81/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1677 - accuracy: 0.9070 - val_loss: 0.1331 - val_accuracy: 0.9375
#
# Epoch 00081: val_loss did not improve from 0.09896
# Epoch 82/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1636 - accuracy: 0.9430 - val_loss: 0.1305 - val_accuracy: 0.9250
#
# Epoch 00082: val_loss did not improve from 0.09896
# Epoch 83/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1448 - accuracy: 0.9443 - val_loss: 0.1302 - val_accuracy: 0.9375
#
# Epoch 00083: val_loss did not improve from 0.09896
# Epoch 84/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.1549 - accuracy: 0.9302 - val_loss: 0.1315 - val_accuracy: 0.9250
#
# Epoch 00084: val_loss did not improve from 0.09896
# Epoch 85/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.1436 - accuracy: 0.9369 - val_loss: 0.1280 - val_accuracy: 0.9375
#
# Epoch 00085: val_loss did not improve from 0.09896
# Epoch 86/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1538 - accuracy: 0.9222 - val_loss: 0.1265 - val_accuracy: 0.9375
#
# Epoch 00086: val_loss did not improve from 0.09896
# Epoch 87/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1380 - accuracy: 0.9498 - val_loss: 0.1182 - val_accuracy: 0.9375
#
# Epoch 00087: val_loss did not improve from 0.09896
# Epoch 88/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1342 - accuracy: 0.9409 - val_loss: 0.1164 - val_accuracy: 0.9375
#
# Epoch 00088: val_loss did not improve from 0.09896
# Epoch 89/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1467 - accuracy: 0.9252 - val_loss: 0.1111 - val_accuracy: 0.9250
#
# Epoch 00089: val_loss did not improve from 0.09896
# Epoch 90/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1426 - accuracy: 0.9385 - val_loss: 0.1146 - val_accuracy: 0.9250
#
# Epoch 00090: val_loss did not improve from 0.09896
# Epoch 91/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1287 - accuracy: 0.9562 - val_loss: 0.1140 - val_accuracy: 0.9625
#
# Epoch 00091: val_loss did not improve from 0.09896
# Epoch 92/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1326 - accuracy: 0.9456 - val_loss: 0.1149 - val_accuracy: 0.9500
#
# Epoch 00092: val_loss did not improve from 0.09896
# Epoch 93/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1272 - accuracy: 0.9561 - val_loss: 0.1109 - val_accuracy: 0.9500
#
# Epoch 00093: val_loss did not improve from 0.09896
# Epoch 94/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1273 - accuracy: 0.9491 - val_loss: 0.1090 - val_accuracy: 0.9500
#
# Epoch 00094: val_loss did not improve from 0.09896
# Epoch 95/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1214 - accuracy: 0.9575 - val_loss: 0.1074 - val_accuracy: 0.9500
#
# Epoch 00095: val_loss did not improve from 0.09896
# Epoch 96/100
# 23/23 [==============================] - 1s 29ms/step - loss: 0.1370 - accuracy: 0.9371 - val_loss: 0.1090 - val_accuracy: 0.9500
#
# Epoch 00096: val_loss did not improve from 0.09896
# Epoch 97/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1215 - accuracy: 0.9499 - val_loss: 0.1051 - val_accuracy: 0.9375
#
# Epoch 00097: val_loss did not improve from 0.09896
# Epoch 98/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1262 - accuracy: 0.9527 - val_loss: 0.1024 - val_accuracy: 0.9500
#
# Epoch 00098: val_loss did not improve from 0.09896
# Epoch 99/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1245 - accuracy: 0.9458 - val_loss: 0.1030 - val_accuracy: 0.9500
#
# Epoch 00099: val_loss did not improve from 0.09896
# Epoch 100/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1142 - accuracy: 0.9479 - val_loss: 0.1013 - val_accuracy: 0.9500
#
# Epoch 00100: val_loss did not improve from 0.09896
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0890 - accuracy: 0.9600
# Val Score:  [0.08898235112428665, 0.9599999785423279]
# ====================================================================================

# %%
print("data train x",t_x.shape)
print("data train y",t_y.shape)

print("data tes x",val_x.shape)
print("data tes y",val_y.shape)

model = load_model('subjek1LSTM.h5')
model.evaluate(val_x, val_y)
# Out:
# data train x (800, 8, 60)
# data train y (800, 4)
# data tes x (200, 8, 60)
# data tes y (200, 4)
# 7/7 [==============================] - 1s 5ms/step - loss: 0.0788 - accuracy: 0.9800
# [0.07877449691295624, 0.9800000190734863]

# %%
fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)
ax1.plot(model_history[0].history['accuracy'], label='Training Fold 1 accuration')
ax1.plot(model_history[1].history['accuracy'], label='Training Fold 2 accuration')
ax1.plot(model_history[2].history['accuracy'], label='Training Fold 3 accuration')
ax1.plot(model_history[3].history['accuracy'], label='Training Fold 4 accuration')
ax1.plot(model_history[4].history['accuracy'], label='Training Fold 5 accuration')
ax1.legend()
ax2.plot(model_history[1].history['loss'], label='Training Fold 1 loss')
ax2.plot(model_history[1].history['loss'], label='Training Fold 2 loss')
ax2.plot(model_history[2].history['loss'], label='Training Fold 3 loss')
ax2.plot(model_history[3].history['loss'], label='Training Fold 4 loss ')
ax2.plot(model_history[4].history['loss'], label='Training Fold 5 loss')
ax2.legend()
plt.show()

# %%
fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt1.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[0].history['loss'], label='Train Loss Fold 1', color='black')
plt2.plot(model_history[0].history['val_loss'], label='Val Loss Fold 1', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red')
plt1.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[1].history['loss'], label='Train Loss Fold 2', color='red')
plt2.plot(model_history[1].history['val_loss'], label='Val Loss Fold 2', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green')
plt1.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[2].history['loss'], label='Train Loss Fold 3', color='green')
plt2.plot(model_history[2].history['val_loss'], label='Val Loss Fold 3', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()


fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue')
plt1.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[3].history['loss'], label='Train Loss Fold 4', color='blue')
plt2.plot(model_history[3].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='purple')
plt1.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[4].history['loss'], label='Train Loss Fold 4', color='purple')
plt2.plot(model_history[4].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

# %%
MODEL_NAME ='/content/subjek1LSTM.h5' 

#CLIP = True # if your model was trained with np.clip to clip  values
CLIP = False
CLIP_VAL = 8  # if above, what was the value +/-

model = tf.keras.models.load_model(MODEL_NAME)

VALDIR = '/content/drive/MyDrive/Colab Notebooks/data8'
ACTIONS =  ["idle","maju","kiri", "kanan"]
PRED_BATCH = 32


def get_val_data(valdir, action, batch_size):

   # argmax_dict = {0: 0, 1: 0, 2: 0,3:0}
    argmax_dict = {2: 0, 0: 0, 1: 0,3:0}
    raw_pred_dict = {0: 0, 1: 0, 2: 0,3:0}

    action_dir = os.path.join(valdir, action)
    for session_file in os.listdir(action_dir):
        filepath = os.path.join(action_dir,session_file)
        if CLIP:
            data = np.clip(np.load(filepath), -CLIP_VAL, CLIP_VAL) / CLIP_VAL
            #print(data)
        else:
            data = np.load(filepath) 
        preds = model.predict([data.reshape(-1, 8, 60)], batch_size=batch_size)
        
        for pred in preds:
            argmax = np.argmax(pred)
            argmax_dict[argmax] += 1
            for idx,value in enumerate(pred):
                raw_pred_dict[idx] += value
    
    argmax_pct_dict = {}
    for i in argmax_dict:
        total = 0
        correct = argmax_dict[i]
        for ii in argmax_dict:
            total += argmax_dict[ii]
        argmax_pct_dict[i] = round(correct/total, 4)
    return argmax_dict, raw_pred_dict, argmax_pct_dict


def make_conf_mat(none,left,forward, right):
    action_dict = {"idle":none,"maju": forward, "kiri": left, "kanan": right}
    action_conf_mat = pd.DataFrame(action_dict)
    actions = [i for i in action_dict]

    fig = plt.figure(figsize=(15, 6))
    ax = fig.add_subplot(111)
    ax.matshow(action_conf_mat, cmap=plt.cm.RdYlGn)
    ax.set_xticklabels([""]+actions)
    ax.set_yticklabels([""]+actions)

    for idx, i in enumerate(action_dict):
        for idx2, ii in enumerate(action_dict[i]):
            ax.text(idx, idx2, f"{round(float(action_dict[i][ii]),2)}", va='center', ha='center')
    # Rotate the tick labels and set their alignment.
    
    plt.title("Matrik data")
    plt.ylabel("Predicted Action")
    fig.tight_layout()
    plt.show()



forward_argmax_dict, forward_raw_pred_dict, forward_argmax_pct_dict = get_val_data(VALDIR, "maju", PRED_BATCH)
none_argmax_dict, none_raw_pred_dict, none_argmax_pct_dict = get_val_data(VALDIR, "idle", PRED_BATCH)
left_argmax_dict, left_raw_pred_dict, left_argmax_pct_dict = get_val_data(VALDIR, "kiri", PRED_BATCH)
right_argmax_dict, right_raw_pred_dict, right_argmax_pct_dict = get_val_data(VALDIR, "kanan", PRED_BATCH)
make_conf_mat(none_argmax_pct_dict,forward_argmax_pct_dict,left_argmax_pct_dict,  right_argmax_pct_dict)

# %%
x_train,x_test,y_train,y_test=train_test_split(train2_X,train_y,test_size=0.2)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (800, 8, 60)
# (200, 8, 60)
# (800, 4)
# (200, 4)

# %%
from sklearn.metrics import roc_curve, auc

#y_score = clf.decision_function(xval)
y_score = model.predict(x_test)

#Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()


# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
    
    
print("roc_auc:",sum(roc_auc.values())/4)
ACTIONS =  ["idle","maju","kiri", "kanan"]
for i in range(0,4):
    plt.figure()
    fig, ax = plt.subplots(figsize=(10,10))
    plt.plot(fpr[i], tpr[i],linewidth=3)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    #plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % ACTIONS[i])
    plt.title('%s -ROC curve (area = %0.2f)' % (ACTIONS[i],roc_auc[i]))
    
    plt.legend(loc="lower right")
    plt.show()
# Out:
# roc_auc: 0.9956457060953888

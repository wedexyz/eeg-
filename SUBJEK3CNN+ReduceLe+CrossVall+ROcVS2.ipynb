# %% [markdown]
# <a href="https://colab.research.google.com/github/wedexyz/eeg-/blob/main/SUBJEK3CNN%2BReduceLe%2BCrossVall%2BROcVS2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.0.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.19.4)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.4.1)

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM, BatchNormalization, Conv2D, Flatten, MaxPooling2D, Dropout
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.optimizers import Adam
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
import pandas as pd
import os
import random
import time
import os
from keras.callbacks import ModelCheckpoint, EarlyStopping
#from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator

from scipy import signal
from scipy.fft import fftshift

# %%
'''
idle = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/idle/1604315006.npy")
kanan = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kanan/1604315180.npy")
kiri = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kiri/1604315126.npy")
maju = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/maju/1604315069.npy")

kelas1=idle[0][16]
kelas2=maju[0][16]
kelas3=kanan[0][16]
kelas4=kiri[0][16]

kelas1a=idle[175]
kelas2a=maju[175]
kelas3a=kanan[175]
kelas4a=kiri[175]

#print(idlea.shape)


f1, t1,Sxx= signal.spectrogram(kelas1,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )
dbs1 = 10*np.log10(Sxx)
f2, t2,Sxx= signal.spectrogram(kelas2,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd',
                            )
dbs2 = 10*np.log10(Sxx)
f3, t3,Sxx= signal.spectrogram(kelas3,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )
dbs3 = 10*np.log10(Sxx)
f4, t4,Sxx= signal.spectrogram(kelas4,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )  
dbs4 = 10*np.log10(Sxx)



fig, axs = plt.subplots(nrows=4, ncols=4)
axs = axs.flatten()

axs[0].set_title("siggle")
axs[0].plot(kelas1)

axs[1].set_title("global")
axs[1].plot(kelas1a)

axs[2].set_title("Spectogram")
axs[2].pcolormesh(t1, f1,dbs1,  
                  shading='gouraud',
                  cmap='nipy_spectral')

cwt1 = signal.cwt(kelas1,signal.ricker,widths=np.arange(1,50))
cwt2 = signal.cwt(kelas2,signal.ricker,widths=np.arange(1,50))
cwt3 = signal.cwt(kelas3,signal.ricker,widths=np.arange(1,50))
cwt4 = signal.cwt(kelas4,signal.ricker,widths=np.arange(1,50))
axs[3].set_title("wavelet")
axs[3].imshow(cwt1,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt1).max(),vmin=-abs(cwt1).max())

axs[4].plot(kelas2)
axs[5].plot(kelas2a)
axs[6].pcolormesh(t2, f2,dbs2,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[7].imshow(cwt2,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt2).max(),vmin=-abs(cwt2).max())

axs[8].plot(kelas3)
axs[9].plot(kelas3a)
axs[10].pcolormesh(t3, f3,dbs3,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[11].imshow(cwt3,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt3).max(),vmin=-abs(cwt3).max())

axs[12].plot(kelas4)
axs[13].plot(kelas4a)
axs[14].pcolormesh(t4, f4,dbs4,  
                  shading='gouraud',
                  cmap='viridis')
axs[15].imshow(cwt4,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt4).max(),vmin=-abs(cwt4).max())
plt.show()
'''
# Out:
# '\nidle = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/idle/1604315006.npy")\nkanan = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kanan/1604315180.npy")\nkiri = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kiri/1604315126.npy")\nmaju = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/maju/1604315069.npy")\n\nkelas1=idle[0][16]\nkelas2=maju[0][16]\nkelas3=kanan[0][16]\nkelas4=kiri[0][16]\n\nkelas1a=idle[175]\nkelas2a=maju[175]\nkelas3a=kanan[175]\nkelas4a=kiri[175]\n\n#print(idlea.shape)\n\n\nf1, t1,Sxx= signal.spectrogram(kelas1,fs=120, window=(\'tukey\', 0.25),\n                             nperseg=11,\n                             noverlap=10,\n                             nfft=None, \n                             detrend=\'constant\',\n                             return_onesided=True, \n                             scaling=\'density\', \n                             axis=-1,\n                             mode=\'psd\'\n                            )\ndbs1 = 10*np.log10(Sxx)\nf2, t2,Sxx= signal.spectrogram(kelas2,fs=120, window=(\'tukey\', 0.25),\n                             nperseg=11,\n                             noverlap=10,\n                             nfft=None, \n                             detrend=\'constant\',\n                             return_onesided=True, \n                             scaling=\'density\', \n                             axis=-1,\n                             mode=\'psd\',\n                            )\ndbs2 = 10*np.log10(Sxx)\nf3, t3,Sxx= signal.spectrogram(kelas3,fs=120, window=(\'tukey\', 0.25),\n                             nperseg=11,\n                             noverlap=10,\n                             nfft=None, \n                             detrend=\'constant\',\n                             return_onesided=True, \n                             scaling=\'density\', \n                             axis=-1,\n                             mode=\'psd\'\n                            )\ndbs3 = 10*np.log10(Sxx)\nf4, t4,Sxx= signal.spectrogram(kelas4,fs=120, window=(\'tukey\', 0.25),\n                             nperseg=11,\n                             noverlap=10,\n                             nfft=None, \n                             detrend=\'constant\',\n                             return_onesided=True, \n                             scaling=\'density\', \n                             axis=-1,\n                             mode=\'psd\'\n                            )  \ndbs4 = 10*np.log10(Sxx)\n\n\n\nfig, axs = plt.subplots(nrows=4, ncols=4)\naxs = axs.flatten()\n\naxs[0].set_title("siggle")\naxs[0].plot(kelas1)\n\naxs[1].set_title("global")\naxs[1].plot(kelas1a)\n\naxs[2].set_title("Spectogram")\naxs[2].pcolormesh(t1, f1,dbs1,  \n                  shading=\'gouraud\',\n                  cmap=\'nipy_spectral\')\n\ncwt1 = signal.cwt(kelas1,signal.ricker,widths=np.arange(1,50))\ncwt2 = signal.cwt(kelas2,signal.ricker,widths=np.arange(1,50))\ncwt3 = signal.cwt(kelas3,signal.ricker,widths=np.arange(1,50))\ncwt4 = signal.cwt(kelas4,signal.ricker,widths=np.arange(1,50))\naxs[3].set_title("wavelet")\naxs[3].imshow(cwt1,extent=[0,16,0,60],cmap=\'jet\',aspect=\'auto\',vmax=abs(cwt1).max(),vmin=-abs(cwt1).max())\n\naxs[4].plot(kelas2)\naxs[5].plot(kelas2a)\naxs[6].pcolormesh(t2, f2,dbs2,  \n                  shading=\'gouraud\',\n                  cmap=\'nipy_spectral\')\naxs[7].imshow(cwt2,extent=[0,16,0,60],cmap=\'jet\',aspect=\'auto\',vmax=abs(cwt2).max(),vmin=-abs(cwt2).max())\n\naxs[8].plot(kelas3)\naxs[9].plot(kelas3a)\naxs[10].pcolormesh(t3, f3,dbs3,  \n                  shading=\'gouraud\',\n                  cmap=\'nipy_spectral\')\naxs[11].imshow(cwt3,extent=[0,16,0,60],cmap=\'jet\',aspect=\'auto\',vmax=abs(cwt3).max(),vmin=-abs(cwt3).max())\n\naxs[12].plot(kelas4)\naxs[13].plot(kelas4a)\naxs[14].pcolormesh(t4, f4,dbs4,  \n                  shading=\'gouraud\',\n                  cmap=\'viridis\')\naxs[15].imshow(cwt4,extent=[0,16,0, ...

# %%
ACTIONS = ["kiri", "maju","idle","kanan"]
reshape = (-1,16, 60,1)
#reshape(-1,28,28,1)

# %%
def create_data(starting_dir="=/content/drive/MyDrive/Colab Notebooks/afif_subjek3"):
    training_data = {}
    for action in ACTIONS:
        if action not in training_data:
            training_data[action] = []
        data_dir = os.path.join(starting_dir,action)
        for item in os.listdir(data_dir):
            data = np.load(os.path.join(data_dir, item))
            for item in data:
                training_data[action].append(item)

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)

    for action in ACTIONS:
        np.random.shuffle(training_data[action])  
        training_data[action] = training_data[action][:min(lengths)]

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)
    combined_data = []
    for action in ACTIONS:
        for data in training_data[action]:
            if action == "kiri":
                combined_data.append([data, [1, 0, 0,0]])
            elif action == "maju":
                combined_data.append([data, [0, 1, 0, 0]])
            elif action == "idle":
                combined_data.append([data, [0, 0, 1, 0]])
            elif action == "kanan":
                combined_data.append([data, [0, 0, 0, 1]])

    np.random.shuffle(combined_data)
    print("length:",len(combined_data))
    return combined_data

# %%
print("creating training data")
traindata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/afif_subjek3")
train_X = []
train_y = []
for X, y in traindata:
    train_X.append(X)
    train_y.append(y)
# Out:
# creating training data
# [1000, 1000, 1000, 1000]
# [1000, 1000, 1000, 1000]
# length: 4000

# %%
print("creating testing data")
testdata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/subjek3tes")
test_X = []
test_y = []

for X, y in testdata:
    test_X.append(X)
    test_y.append(y)
train_X = np.array(train_X).reshape(reshape)
test_X = np.array(test_X).reshape(reshape)

train_y = np.array(train_y)
test_y = np.array(test_y)
# Out:
# creating testing data
# [250, 250, 250, 250]
# [250, 250, 250, 250]
# length: 1000

# %%
import seaborn as sns
ye=pd.DataFrame(train_y)

ye.columns=["kiri", "maju","idle","kanan"]
categories = list(ye.columns.values)
sns.set(font_scale = 1)
plt.figure(figsize=(10,8))
ax= sns.barplot(categories, ye.iloc[:,0:].sum().values)
plt.title("Number of samples labeled as active (1) out of {0} length data".format((ye.shape[0])),fontsize=20)

plt.ylabel('Number of events', fontsize=18)
plt.xlabel('Event Type ', fontsize=12)
#adding the text labels
rects = ax.patches
labels = ye.iloc[:,0:].sum().values

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom', fontsize=10)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# With data augmentation to prevent overfitting
'''
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(train_X)
'''
# Out:
# '\ndatagen = ImageDataGenerator(\n        featurewise_center=False,  # set input mean to 0 over the dataset\n        samplewise_center=False,  # set each sample mean to 0\n        featurewise_std_normalization=False,  # divide inputs by std of the dataset\n        samplewise_std_normalization=False,  # divide each input by its std\n        zca_whitening=False,  # apply ZCA whitening\n        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)\n        zoom_range = 0.1, # Randomly zoom image \n        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)\n        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)\n        horizontal_flip=False,  # randomly flip images\n        vertical_flip=False)  # randomly flip images\n\n\ndatagen.fit(train_X)\n'

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1,factor=0.5, min_lr=0.0001)

# %%
#def cnn_model(size, num_cnn_layers):
def cnn_model():    

    model = Sequential()
    
    model.add(Conv2D(filters = 64, kernel_size = (7,7), padding = "same", activation = "relu", input_shape=train_X.shape[1:]))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Conv2D(filters = 64, kernel_size = (5,5), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (5,5)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Conv2D(filters = 64, kernel_size = (3,3), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (3,3)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Flatten())
    
    model.add(Dense(32, activation = "relu"))
    model.add(BatchNormalization())

    model.add(Dense(4, activation = "sigmoid"))
   
    #adam = Adam(lr = 0.001)
    model.compile(optimizer ="adam", loss = "binary_crossentropy", metrics = ['accuracy'])
    #model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
 
    
    return model

# %%
#model = cnn_model(IMAGE_SIZE, 2)
model = cnn_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 16, 60, 64)        3200
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 60, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 60, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 60, 64)        102464
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 3, 12, 64)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 12, 64)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 3, 12, 64)         256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 12, 64)         36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 4, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 4, 64)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 4, 64)          256
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                8224
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 151,844
# Trainable params: 151,396
# Non-trainable params: 448
# _________________________________________________________________

# %%
#set early stopping criteria
pat = 5
#this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='loss', patience=pat, verbose=1)

#define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('subjek3.h5', verbose=1, save_best_only=True)

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=100, BATCH_SIZE=32):
    model = None
    #model = cnn_model(IMAGE_SIZE, 2)
    model = cnn_model()
    #Model = model
   # results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[early_stopping, model_checkpoint], 
   #           verbose=1, validation_split=0.1) 
    results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[learning_rate_reduction,early_stopping, model_checkpoint], 
              verbose=1, validation_split=0.1)   
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs=100
batch_size=32

#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(train_X, train_y, test_size=0.1, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
   
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 102/102 [==============================] - 9s 13ms/step - loss: 0.7498 - accuracy: 0.2526 - val_loss: 0.6241 - val_accuracy: 0.2361
#
# Epoch 00001: val_loss improved from inf to 0.62415, saving model to subjek3.h5
# Epoch 2/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.6252 - accuracy: 0.2584 - val_loss: 0.5852 - val_accuracy: 0.2250
#
# Epoch 00002: val_loss improved from 0.62415 to 0.58524, saving model to subjek3.h5
# Epoch 3/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5838 - accuracy: 0.2575 - val_loss: 0.5680 - val_accuracy: 0.2306
#
# Epoch 00003: val_loss improved from 0.58524 to 0.56801, saving model to subjek3.h5
# Epoch 4/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5696 - accuracy: 0.2560 - val_loss: 0.5669 - val_accuracy: 0.2639
#
# Epoch 00004: val_loss improved from 0.56801 to 0.56685, saving model to subjek3.h5
# Epoch 5/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5653 - accuracy: 0.2625 - val_loss: 0.5677 - val_accuracy: 0.2500
#
# Epoch 00005: val_loss did not improve from 0.56685
# Epoch 6/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5648 - accuracy: 0.2595 - val_loss: 0.5669 - val_accuracy: 0.2194
#
# Epoch 00006: val_loss did not improve from 0.56685
# Epoch 7/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5648 - accuracy: 0.2508 - val_loss: 0.5674 - val_accuracy: 0.2194
#
# Epoch 00007: val_loss did not improve from 0.56685
# Epoch 8/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5663 - accuracy: 0.2519 - val_loss: 0.5671 - val_accuracy: 0.1889
#
# Epoch 00008: val_loss did not improve from 0.56685
# Epoch 9/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5635 - accuracy: 0.2753 - val_loss: 0.5642 - val_accuracy: 0.2222
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00009: val_loss improved from 0.56685 to 0.56423, saving model to subjek3.h5
# Epoch 10/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5622 - accuracy: 0.2806 - val_loss: 0.5635 - val_accuracy: 0.2139
#
# Epoch 00010: val_loss improved from 0.56423 to 0.56348, saving model to subjek3.h5
# Epoch 11/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5623 - accuracy: 0.2559 - val_loss: 0.5654 - val_accuracy: 0.2306
#
# Epoch 00011: val_loss did not improve from 0.56348
# Epoch 12/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5625 - accuracy: 0.2665 - val_loss: 0.5630 - val_accuracy: 0.2417
#
# Epoch 00012: val_loss improved from 0.56348 to 0.56304, saving model to subjek3.h5
# Epoch 13/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5591 - accuracy: 0.2933 - val_loss: 0.5589 - val_accuracy: 0.2750
#
# Epoch 00013: val_loss improved from 0.56304 to 0.55894, saving model to subjek3.h5
# Epoch 14/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5602 - accuracy: 0.2670 - val_loss: 0.5582 - val_accuracy: 0.2750
#
# Epoch 00014: val_loss improved from 0.55894 to 0.55816, saving model to subjek3.h5
# Epoch 15/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5557 - accuracy: 0.3095 - val_loss: 0.5580 - val_accuracy: 0.2694
#
# Epoch 00015: val_loss improved from 0.55816 to 0.55799, saving model to subjek3.h5
# Epoch 16/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5541 - accuracy: 0.3147 - val_loss: 0.5524 - val_accuracy: 0.2917
#
# Epoch 00016: val_loss improved from 0.55799 to 0.55242, saving model to subjek3.h5
# Epoch 17/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5477 - accuracy: 0.3224 - val_loss: 0.5756 - val_accuracy: 0.2472
#
# Epoch 00017: val_loss did not improve from 0.55242
# Epoch 18/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5436 - accuracy: 0.3352 - val_loss: 0.5520 - val_accuracy: 0.2833
#
# Epoch 00018: val_loss improved from 0.55242 to 0.55202, saving model to subjek3.h5
# Epoch 19/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5342 - accuracy: 0.3612 - val_loss: 0.5635 - val_accuracy: 0.2500
#
# Epoch 00019: val_loss did not improve from 0.55202
# Epoch 20/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5340 - accuracy: 0.3525 - val_loss: 0.5476 - val_accuracy: 0.2806
#
# Epoch 00020: val_loss improved from 0.55202 to 0.54763, saving model to subjek3.h5
# Epoch 21/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5255 - accuracy: 0.3670 - val_loss: 0.6051 - val_accuracy: 0.2444
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00021: val_loss did not improve from 0.54763
# Epoch 22/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5225 - accuracy: 0.3687 - val_loss: 0.5478 - val_accuracy: 0.3028
#
# Epoch 00022: val_loss did not improve from 0.54763
# Epoch 23/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5060 - accuracy: 0.4106 - val_loss: 0.5461 - val_accuracy: 0.3111
#
# Epoch 00023: val_loss improved from 0.54763 to 0.54615, saving model to subjek3.h5
# Epoch 24/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5107 - accuracy: 0.3906 - val_loss: 0.5103 - val_accuracy: 0.3750
#
# Epoch 00024: val_loss improved from 0.54615 to 0.51027, saving model to subjek3.h5
# Epoch 25/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5029 - accuracy: 0.4027 - val_loss: 0.5104 - val_accuracy: 0.3528
#
# Epoch 00025: val_loss did not improve from 0.51027
# Epoch 26/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5062 - accuracy: 0.3927 - val_loss: 0.5024 - val_accuracy: 0.3833
#
# Epoch 00026: val_loss improved from 0.51027 to 0.50242, saving model to subjek3.h5
# Epoch 27/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4936 - accuracy: 0.4256 - val_loss: 0.5217 - val_accuracy: 0.3694
#
# Epoch 00027: val_loss did not improve from 0.50242
# Epoch 28/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4887 - accuracy: 0.4238 - val_loss: 0.5047 - val_accuracy: 0.3806
#
# Epoch 00028: val_loss did not improve from 0.50242
# Epoch 29/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4864 - accuracy: 0.4279 - val_loss: 0.4887 - val_accuracy: 0.3889
#
# Epoch 00029: val_loss improved from 0.50242 to 0.48873, saving model to subjek3.h5
# Epoch 30/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4834 - accuracy: 0.4272 - val_loss: 0.5243 - val_accuracy: 0.3333
#
# Epoch 00030: val_loss did not improve from 0.48873
# Epoch 31/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4764 - accuracy: 0.4597 - val_loss: 0.5361 - val_accuracy: 0.3278
#
# Epoch 00031: val_loss did not improve from 0.48873
# Epoch 32/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4838 - accuracy: 0.4250 - val_loss: 0.4865 - val_accuracy: 0.4500
#
# Epoch 00032: val_loss improved from 0.48873 to 0.48645, saving model to subjek3.h5
# Epoch 33/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4745 - accuracy: 0.4443 - val_loss: 0.4873 - val_accuracy: 0.4028
#
# Epoch 00033: val_loss did not improve from 0.48645
# Epoch 34/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4707 - accuracy: 0.4598 - val_loss: 0.4798 - val_accuracy: 0.4250
#
# Epoch 00034: val_loss improved from 0.48645 to 0.47984, saving model to subjek3.h5
# Epoch 35/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4690 - accuracy: 0.4658 - val_loss: 0.4678 - val_accuracy: 0.4667
#
# Epoch 00035: val_loss improved from 0.47984 to 0.46778, saving model to subjek3.h5
# Epoch 36/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4653 - accuracy: 0.4690 - val_loss: 0.4606 - val_accuracy: 0.4667
#
# Epoch 00036: val_loss improved from 0.46778 to 0.46057, saving model to subjek3.h5
# Epoch 37/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4638 - accuracy: 0.4736 - val_loss: 0.4855 - val_accuracy: 0.4167
#
# Epoch 00037: val_loss did not improve from 0.46057
# Epoch 38/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4586 - accuracy: 0.4964 - val_loss: 0.5148 - val_accuracy: 0.3778
#
# Epoch 00038: val_loss did not improve from 0.46057
# Epoch 39/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4593 - accuracy: 0.4787 - val_loss: 0.4545 - val_accuracy: 0.4694
#
# Epoch 00039: val_loss improved from 0.46057 to 0.45451, saving model to subjek3.h5
# Epoch 40/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4463 - accuracy: 0.5058 - val_loss: 0.4574 - val_accuracy: 0.4556
#
# Epoch 00040: val_loss did not improve from 0.45451
# Epoch 41/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4333 - accuracy: 0.5193 - val_loss: 0.4394 - val_accuracy: 0.5000
#
# Epoch 00041: val_loss improved from 0.45451 to 0.43938, saving model to subjek3.h5
# Epoch 42/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4342 - accuracy: 0.5304 - val_loss: 0.4338 - val_accuracy: 0.4861
#
# Epoch 00042: val_loss improved from 0.43938 to 0.43379, saving model to subjek3.h5
# Epoch 43/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4314 - accuracy: 0.5154 - val_loss: 0.4399 - val_accuracy: 0.4722
#
# Epoch 00043: val_loss did not improve from 0.43379
# Epoch 44/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4245 - accuracy: 0.5319 - val_loss: 0.4219 - val_accuracy: 0.5250
#
# Epoch 00044: val_loss improved from 0.43379 to 0.42193, saving model to subjek3.h5
# Epoch 45/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4151 - accuracy: 0.5430 - val_loss: 0.4217 - val_accuracy: 0.5194
#
# Epoch 00045: val_loss improved from 0.42193 to 0.42166, saving model to subjek3.h5
# Epoch 46/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4043 - accuracy: 0.5694 - val_loss: 0.4138 - val_accuracy: 0.5111
#
# Epoch 00046: val_loss improved from 0.42166 to 0.41378, saving model to subjek3.h5
# Epoch 47/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4125 - accuracy: 0.5415 - val_loss: 0.4115 - val_accuracy: 0.5250
#
# Epoch 00047: val_loss improved from 0.41378 to 0.41148, saving model to subjek3.h5
# Epoch 48/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4067 - accuracy: 0.5591 - val_loss: 0.4129 - val_accuracy: 0.5222
#
# Epoch 00048: val_loss did not improve from 0.41148
# Epoch 49/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4098 - accuracy: 0.5498 - val_loss: 0.4223 - val_accuracy: 0.5083
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00049: val_loss did not improve from 0.41148
# Epoch 50/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3973 - accuracy: 0.5539 - val_loss: 0.4067 - val_accuracy: 0.5222
#
# Epoch 00050: val_loss improved from 0.41148 to 0.40675, saving model to subjek3.h5
# Epoch 51/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3808 - accuracy: 0.5814 - val_loss: 0.3883 - val_accuracy: 0.5556
#
# Epoch 00051: val_loss improved from 0.40675 to 0.38832, saving model to subjek3.h5
# Epoch 52/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3874 - accuracy: 0.5756 - val_loss: 0.3816 - val_accuracy: 0.5611
#
# Epoch 00052: val_loss improved from 0.38832 to 0.38158, saving model to subjek3.h5
# Epoch 53/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3808 - accuracy: 0.5855 - val_loss: 0.3774 - val_accuracy: 0.5806
#
# Epoch 00053: val_loss improved from 0.38158 to 0.37735, saving model to subjek3.h5
# Epoch 54/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3787 - accuracy: 0.5911 - val_loss: 0.3749 - val_accuracy: 0.5722
#
# Epoch 00054: val_loss improved from 0.37735 to 0.37492, saving model to subjek3.h5
# Epoch 55/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3792 - accuracy: 0.5922 - val_loss: 0.3695 - val_accuracy: 0.5722
#
# Epoch 00055: val_loss improved from 0.37492 to 0.36946, saving model to subjek3.h5
# Epoch 56/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3849 - accuracy: 0.5885 - val_loss: 0.3726 - val_accuracy: 0.5833
#
# Epoch 00056: val_loss did not improve from 0.36946
# Epoch 57/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3670 - accuracy: 0.6110 - val_loss: 0.3852 - val_accuracy: 0.5528
#
# Epoch 00057: val_loss did not improve from 0.36946
# Epoch 58/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3669 - accuracy: 0.6039 - val_loss: 0.3602 - val_accuracy: 0.5917
#
# Epoch 00058: val_loss improved from 0.36946 to 0.36018, saving model to subjek3.h5
# Epoch 59/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3642 - accuracy: 0.5922 - val_loss: 0.3652 - val_accuracy: 0.5889
#
# Epoch 00059: val_loss did not improve from 0.36018
# Epoch 60/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3735 - accuracy: 0.6027 - val_loss: 0.3646 - val_accuracy: 0.5611
#
# Epoch 00060: val_loss did not improve from 0.36018
# Epoch 61/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3702 - accuracy: 0.6006 - val_loss: 0.3792 - val_accuracy: 0.5861
#
# Epoch 00061: val_loss did not improve from 0.36018
# Epoch 62/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3645 - accuracy: 0.6006 - val_loss: 0.3629 - val_accuracy: 0.5889
#
# Epoch 00062: val_loss did not improve from 0.36018
# Epoch 63/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3591 - accuracy: 0.6107 - val_loss: 0.3651 - val_accuracy: 0.5611
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00063: val_loss did not improve from 0.36018
# Epoch 64/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3536 - accuracy: 0.6134 - val_loss: 0.3533 - val_accuracy: 0.6056
#
# Epoch 00064: val_loss improved from 0.36018 to 0.35326, saving model to subjek3.h5
# Epoch 65/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3509 - accuracy: 0.6224 - val_loss: 0.3478 - val_accuracy: 0.5944
#
# Epoch 00065: val_loss improved from 0.35326 to 0.34775, saving model to subjek3.h5
# Epoch 66/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3438 - accuracy: 0.6263 - val_loss: 0.3481 - val_accuracy: 0.6278
#
# Epoch 00066: val_loss did not improve from 0.34775
# Epoch 67/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3503 - accuracy: 0.6188 - val_loss: 0.3423 - val_accuracy: 0.6083
#
# Epoch 00067: val_loss improved from 0.34775 to 0.34231, saving model to subjek3.h5
# Epoch 68/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3538 - accuracy: 0.6130 - val_loss: 0.3429 - val_accuracy: 0.6083
#
# Epoch 00068: val_loss did not improve from 0.34231
# Epoch 69/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3483 - accuracy: 0.6216 - val_loss: 0.3408 - val_accuracy: 0.6139
#
# Epoch 00069: val_loss improved from 0.34231 to 0.34080, saving model to subjek3.h5
# Epoch 70/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3546 - accuracy: 0.6016 - val_loss: 0.3441 - val_accuracy: 0.6028
#
# Epoch 00070: val_loss did not improve from 0.34080
# Epoch 71/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3466 - accuracy: 0.6275 - val_loss: 0.3492 - val_accuracy: 0.5972
#
# Epoch 00071: val_loss did not improve from 0.34080
# Epoch 72/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3385 - accuracy: 0.6318 - val_loss: 0.3461 - val_accuracy: 0.5972
#
# Epoch 00072: val_loss did not improve from 0.34080
# Epoch 73/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3469 - accuracy: 0.6176 - val_loss: 0.3425 - val_accuracy: 0.6000
#
# Epoch 00073: val_loss did not improve from 0.34080
# Epoch 74/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3332 - accuracy: 0.6377 - val_loss: 0.3371 - val_accuracy: 0.6167
#
# Epoch 00074: val_loss improved from 0.34080 to 0.33709, saving model to subjek3.h5
# Epoch 75/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3368 - accuracy: 0.6296 - val_loss: 0.3290 - val_accuracy: 0.6000
#
# Epoch 00075: val_loss improved from 0.33709 to 0.32895, saving model to subjek3.h5
# Epoch 76/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3311 - accuracy: 0.6432 - val_loss: 0.3365 - val_accuracy: 0.5972
#
# Epoch 00076: val_loss did not improve from 0.32895
# Epoch 77/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3431 - accuracy: 0.6292 - val_loss: 0.3326 - val_accuracy: 0.6028
#
# Epoch 00077: val_loss did not improve from 0.32895
# Epoch 78/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3281 - accuracy: 0.6510 - val_loss: 0.3342 - val_accuracy: 0.6111
#
# Epoch 00078: val_loss did not improve from 0.32895
# Epoch 79/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3413 - accuracy: 0.6310 - val_loss: 0.3287 - val_accuracy: 0.6250
#
# Epoch 00079: val_loss improved from 0.32895 to 0.32872, saving model to subjek3.h5
# Epoch 80/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3306 - accuracy: 0.6414 - val_loss: 0.3317 - val_accuracy: 0.6167
#
# Epoch 00080: val_loss did not improve from 0.32872
# Epoch 81/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3407 - accuracy: 0.6300 - val_loss: 0.3225 - val_accuracy: 0.6250
#
# Epoch 00081: val_loss improved from 0.32872 to 0.32254, saving model to subjek3.h5
# Epoch 82/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3271 - accuracy: 0.6449 - val_loss: 0.3294 - val_accuracy: 0.6167
#
# Epoch 00082: val_loss did not improve from 0.32254
# Epoch 83/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3286 - accuracy: 0.6367 - val_loss: 0.3324 - val_accuracy: 0.6222
#
# Epoch 00083: val_loss did not improve from 0.32254
# Epoch 84/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3246 - accuracy: 0.6538 - val_loss: 0.3230 - val_accuracy: 0.6278
#
# Epoch 00084: val_loss did not improve from 0.32254
# Epoch 85/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3246 - accuracy: 0.6506 - val_loss: 0.3225 - val_accuracy: 0.6194
#
# Epoch 00085: val_loss improved from 0.32254 to 0.32253, saving model to subjek3.h5
# Epoch 86/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3189 - accuracy: 0.6632 - val_loss: 0.3211 - val_accuracy: 0.6167
#
# Epoch 00086: val_loss improved from 0.32253 to 0.32108, saving model to subjek3.h5
# Epoch 87/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3275 - accuracy: 0.6496 - val_loss: 0.3192 - val_accuracy: 0.6306
#
# Epoch 00087: val_loss improved from 0.32108 to 0.31917, saving model to subjek3.h5
# Epoch 88/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3219 - accuracy: 0.6538 - val_loss: 0.3225 - val_accuracy: 0.6222
#
# Epoch 00088: val_loss did not improve from 0.31917
# Epoch 89/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3366 - accuracy: 0.6423 - val_loss: 0.3237 - val_accuracy: 0.6389
#
# Epoch 00089: val_loss did not improve from 0.31917
# Epoch 90/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3193 - accuracy: 0.6598 - val_loss: 0.3219 - val_accuracy: 0.6250
#
# Epoch 00090: val_loss did not improve from 0.31917
# Epoch 91/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3167 - accuracy: 0.6656 - val_loss: 0.3245 - val_accuracy: 0.6250
#
# Epoch 00091: val_loss did not improve from 0.31917
# Epoch 92/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3273 - accuracy: 0.6433 - val_loss: 0.3197 - val_accuracy: 0.6250
#
# Epoch 00092: val_loss did not improve from 0.31917
# Epoch 93/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3193 - accuracy: 0.6516 - val_loss: 0.3167 - val_accuracy: 0.6306
#
# Epoch 00093: val_loss improved from 0.31917 to 0.31669, saving model to subjek3.h5
# Epoch 94/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3118 - accuracy: 0.6630 - val_loss: 0.3210 - val_accuracy: 0.6361
#
# Epoch 00094: val_loss did not improve from 0.31669
# Epoch 95/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3113 - accuracy: 0.6691 - val_loss: 0.3202 - val_accuracy: 0.6111
#
# Epoch 00095: val_loss did not improve from 0.31669
# Epoch 96/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3120 - accuracy: 0.6506 - val_loss: 0.3250 - val_accuracy: 0.6306
#
# Epoch 00096: val_loss did not improve from 0.31669
# Epoch 97/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3092 - accuracy: 0.6543 - val_loss: 0.3170 - val_accuracy: 0.6306
#
# Epoch 00097: val_loss did not improve from 0.31669
# Epoch 98/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3174 - accuracy: 0.6630 - val_loss: 0.3124 - val_accuracy: 0.6333
#
# Epoch 00098: val_loss improved from 0.31669 to 0.31245, saving model to subjek3.h5
# Epoch 99/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3139 - accuracy: 0.6444 - val_loss: 0.3130 - val_accuracy: 0.6417
#
# Epoch 00099: val_loss did not improve from 0.31245
# Epoch 100/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3211 - accuracy: 0.6626 - val_loss: 0.3122 - val_accuracy: 0.6444
#
# Epoch 00100: val_loss improved from 0.31245 to 0.31223, saving model to subjek3.h5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3005 - accuracy: 0.6700
# Val Score:  [0.3004893362522125, 0.6700000166893005]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
# 102/102 [==============================] - 2s 9ms/step - loss: 0.7671 - accuracy: 0.2460 - val_loss: 0.6782 - val_accuracy: 0.2750
#
# Epoch 00001: val_loss did not improve from 0.31223
# Epoch 2/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.6332 - accuracy: 0.2687 - val_loss: 0.6053 - val_accuracy: 0.2750
#
# Epoch 00002: val_loss did not improve from 0.31223
# Epoch 3/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5904 - accuracy: 0.2343 - val_loss: 0.5695 - val_accuracy: 0.2611
#
# Epoch 00003: val_loss did not improve from 0.31223
# Epoch 4/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5720 - accuracy: 0.2391 - val_loss: 0.5678 - val_accuracy: 0.2333
#
# Epoch 00004: val_loss did not improve from 0.31223
# Epoch 5/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5723 - accuracy: 0.2331 - val_loss: 0.5691 - val_accuracy: 0.2194
#
# Epoch 00005: val_loss did not improve from 0.31223
# Epoch 6/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5670 - accuracy: 0.2481 - val_loss: 0.5682 - val_accuracy: 0.2167
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.31223
# Epoch 7/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5663 - accuracy: 0.2448 - val_loss: 0.5677 - val_accuracy: 0.2000
#
# Epoch 00007: val_loss did not improve from 0.31223
# Epoch 8/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5664 - accuracy: 0.2585 - val_loss: 0.5669 - val_accuracy: 0.1778
#
# Epoch 00008: val_loss did not improve from 0.31223
# Epoch 9/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5640 - accuracy: 0.2559 - val_loss: 0.5664 - val_accuracy: 0.2167
#
# Epoch 00009: val_loss did not improve from 0.31223
# Epoch 10/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5633 - accuracy: 0.2680 - val_loss: 0.5668 - val_accuracy: 0.1750
#
# Epoch 00010: val_loss did not improve from 0.31223
# Epoch 11/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5630 - accuracy: 0.2764 - val_loss: 0.5674 - val_accuracy: 0.2306
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00011: val_loss did not improve from 0.31223
# Epoch 12/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5617 - accuracy: 0.2672 - val_loss: 0.5668 - val_accuracy: 0.2167
#
# Epoch 00012: val_loss did not improve from 0.31223
# Epoch 13/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5625 - accuracy: 0.2806 - val_loss: 0.5670 - val_accuracy: 0.1889
#
# Epoch 00013: val_loss did not improve from 0.31223
# Epoch 14/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5633 - accuracy: 0.2590 - val_loss: 0.5673 - val_accuracy: 0.2111
#
# Epoch 00014: val_loss did not improve from 0.31223
# Epoch 15/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5629 - accuracy: 0.2686 - val_loss: 0.5664 - val_accuracy: 0.1944
#
# Epoch 00015: val_loss did not improve from 0.31223
# Epoch 16/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5640 - accuracy: 0.2599 - val_loss: 0.5662 - val_accuracy: 0.2111
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00016: val_loss did not improve from 0.31223
# Epoch 17/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5623 - accuracy: 0.2616 - val_loss: 0.5664 - val_accuracy: 0.2250
#
# Epoch 00017: val_loss did not improve from 0.31223
# Epoch 18/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5630 - accuracy: 0.2709 - val_loss: 0.5663 - val_accuracy: 0.2056
#
# Epoch 00018: val_loss did not improve from 0.31223
# Epoch 19/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5622 - accuracy: 0.2697 - val_loss: 0.5657 - val_accuracy: 0.2056
#
# Epoch 00019: val_loss did not improve from 0.31223
# Epoch 20/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5614 - accuracy: 0.2723 - val_loss: 0.5655 - val_accuracy: 0.2083
#
# Epoch 00020: val_loss did not improve from 0.31223
# Epoch 21/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5626 - accuracy: 0.2552 - val_loss: 0.5656 - val_accuracy: 0.2250
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00021: val_loss did not improve from 0.31223
# Epoch 22/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5613 - accuracy: 0.2843 - val_loss: 0.5652 - val_accuracy: 0.2194
#
# Epoch 00022: val_loss did not improve from 0.31223
# Epoch 23/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5624 - accuracy: 0.2660 - val_loss: 0.5653 - val_accuracy: 0.2111
#
# Epoch 00023: val_loss did not improve from 0.31223
# Epoch 24/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5609 - accuracy: 0.2778 - val_loss: 0.5655 - val_accuracy: 0.2278
#
# Epoch 00024: val_loss did not improve from 0.31223
# Epoch 25/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5605 - accuracy: 0.2927 - val_loss: 0.5654 - val_accuracy: 0.2333
#
# Epoch 00025: val_loss did not improve from 0.31223
# Epoch 26/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5623 - accuracy: 0.2730 - val_loss: 0.5653 - val_accuracy: 0.2167
#
# Epoch 00026: val_loss did not improve from 0.31223
# Epoch 27/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5600 - accuracy: 0.2734 - val_loss: 0.5640 - val_accuracy: 0.2528
#
# Epoch 00027: val_loss did not improve from 0.31223
# Epoch 28/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5600 - accuracy: 0.2894 - val_loss: 0.5644 - val_accuracy: 0.2361
#
# Epoch 00028: val_loss did not improve from 0.31223
# Epoch 29/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5585 - accuracy: 0.3018 - val_loss: 0.5637 - val_accuracy: 0.2389
#
# Epoch 00029: val_loss did not improve from 0.31223
# Epoch 30/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5595 - accuracy: 0.2803 - val_loss: 0.5645 - val_accuracy: 0.2361
#
# Epoch 00030: val_loss did not improve from 0.31223
# Epoch 31/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5585 - accuracy: 0.2812 - val_loss: 0.5653 - val_accuracy: 0.2306
#
# Epoch 00031: val_loss did not improve from 0.31223
# Epoch 32/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5551 - accuracy: 0.2992 - val_loss: 0.5561 - val_accuracy: 0.2806
#
# Epoch 00032: val_loss did not improve from 0.31223
# Epoch 33/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5519 - accuracy: 0.3257 - val_loss: 0.5526 - val_accuracy: 0.3000
#
# Epoch 00033: val_loss did not improve from 0.31223
# Epoch 34/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5463 - accuracy: 0.3113 - val_loss: 0.5538 - val_accuracy: 0.2833
#
# Epoch 00034: val_loss did not improve from 0.31223
# Epoch 35/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5454 - accuracy: 0.3185 - val_loss: 0.5528 - val_accuracy: 0.2750
#
# Epoch 00035: val_loss did not improve from 0.31223
# Epoch 36/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5444 - accuracy: 0.3307 - val_loss: 0.5644 - val_accuracy: 0.2583
#
# Epoch 00036: val_loss did not improve from 0.31223
# Epoch 37/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5374 - accuracy: 0.3437 - val_loss: 0.5423 - val_accuracy: 0.3194
#
# Epoch 00037: val_loss did not improve from 0.31223
# Epoch 38/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5319 - accuracy: 0.3479 - val_loss: 0.5574 - val_accuracy: 0.2750
#
# Epoch 00038: val_loss did not improve from 0.31223
# Epoch 39/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5291 - accuracy: 0.3494 - val_loss: 0.5681 - val_accuracy: 0.2583
#
# Epoch 00039: val_loss did not improve from 0.31223
# Epoch 40/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5277 - accuracy: 0.3680 - val_loss: 0.6003 - val_accuracy: 0.2444
#
# Epoch 00040: val_loss did not improve from 0.31223
# Epoch 41/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5181 - accuracy: 0.3637 - val_loss: 0.5378 - val_accuracy: 0.3278
#
# Epoch 00041: val_loss did not improve from 0.31223
# Epoch 42/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5196 - accuracy: 0.3747 - val_loss: 0.6012 - val_accuracy: 0.2528
#
# Epoch 00042: val_loss did not improve from 0.31223
# Epoch 43/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5180 - accuracy: 0.3533 - val_loss: 0.5234 - val_accuracy: 0.3472
#
# Epoch 00043: val_loss did not improve from 0.31223
# Epoch 44/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5158 - accuracy: 0.3689 - val_loss: 0.5713 - val_accuracy: 0.2806
#
# Epoch 00044: val_loss did not improve from 0.31223
# Epoch 45/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5132 - accuracy: 0.3714 - val_loss: 0.5441 - val_accuracy: 0.2917
#
# Epoch 00045: val_loss did not improve from 0.31223
# Epoch 46/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5055 - accuracy: 0.4152 - val_loss: 0.5328 - val_accuracy: 0.3333
#
# Epoch 00046: val_loss did not improve from 0.31223
# Epoch 47/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5067 - accuracy: 0.3959 - val_loss: 0.5651 - val_accuracy: 0.2833
#
# Epoch 00047: val_loss did not improve from 0.31223
# Epoch 48/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5047 - accuracy: 0.3830 - val_loss: 0.5283 - val_accuracy: 0.3250
#
# Epoch 00048: val_loss did not improve from 0.31223
# Epoch 49/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5014 - accuracy: 0.4221 - val_loss: 0.5053 - val_accuracy: 0.4000
#
# Epoch 00049: val_loss did not improve from 0.31223
# Epoch 50/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5027 - accuracy: 0.4013 - val_loss: 0.5121 - val_accuracy: 0.3611
#
# Epoch 00050: val_loss did not improve from 0.31223
# Epoch 51/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4907 - accuracy: 0.4158 - val_loss: 0.5391 - val_accuracy: 0.3111
#
# Epoch 00051: val_loss did not improve from 0.31223
# Epoch 52/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4879 - accuracy: 0.4496 - val_loss: 0.5339 - val_accuracy: 0.3111
#
# Epoch 00052: val_loss did not improve from 0.31223
# Epoch 53/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4873 - accuracy: 0.4442 - val_loss: 0.5432 - val_accuracy: 0.3111
#
# Epoch 00053: val_loss did not improve from 0.31223
# Epoch 54/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4863 - accuracy: 0.4350 - val_loss: 0.5115 - val_accuracy: 0.3639
#
# Epoch 00054: val_loss did not improve from 0.31223
# Epoch 55/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4836 - accuracy: 0.4502 - val_loss: 0.5537 - val_accuracy: 0.3167
#
# Epoch 00055: val_loss did not improve from 0.31223
# Epoch 56/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4852 - accuracy: 0.4314 - val_loss: 0.4943 - val_accuracy: 0.3889
#
# Epoch 00056: val_loss did not improve from 0.31223
# Epoch 57/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4807 - accuracy: 0.4456 - val_loss: 0.4965 - val_accuracy: 0.3917
#
# Epoch 00057: val_loss did not improve from 0.31223
# Epoch 58/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4770 - accuracy: 0.4641 - val_loss: 0.4776 - val_accuracy: 0.4667
#
# Epoch 00058: val_loss did not improve from 0.31223
# Epoch 59/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4691 - accuracy: 0.4830 - val_loss: 0.4924 - val_accuracy: 0.4083
#
# Epoch 00059: val_loss did not improve from 0.31223
# Epoch 60/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4655 - accuracy: 0.4825 - val_loss: 0.5091 - val_accuracy: 0.3917
#
# Epoch 00060: val_loss did not improve from 0.31223
# Epoch 61/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4641 - accuracy: 0.4544 - val_loss: 0.5257 - val_accuracy: 0.3722
#
# Epoch 00061: val_loss did not improve from 0.31223
# Epoch 62/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4653 - accuracy: 0.4846 - val_loss: 0.5149 - val_accuracy: 0.3611
#
# Epoch 00062: val_loss did not improve from 0.31223
# Epoch 63/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4566 - accuracy: 0.4963 - val_loss: 0.4925 - val_accuracy: 0.4278
#
# Epoch 00063: val_loss did not improve from 0.31223
# Epoch 64/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4506 - accuracy: 0.5063 - val_loss: 0.4684 - val_accuracy: 0.4556
#
# Epoch 00064: val_loss did not improve from 0.31223
# Epoch 65/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4603 - accuracy: 0.4804 - val_loss: 0.4640 - val_accuracy: 0.4611
#
# Epoch 00065: val_loss did not improve from 0.31223
# Epoch 66/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4501 - accuracy: 0.4928 - val_loss: 0.4488 - val_accuracy: 0.4833
#
# Epoch 00066: val_loss did not improve from 0.31223
# Epoch 67/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4432 - accuracy: 0.5101 - val_loss: 0.4720 - val_accuracy: 0.4444
#
# Epoch 00067: val_loss did not improve from 0.31223
# Epoch 68/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4470 - accuracy: 0.4930 - val_loss: 0.4503 - val_accuracy: 0.4694
#
# Epoch 00068: val_loss did not improve from 0.31223
# Epoch 69/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4447 - accuracy: 0.5046 - val_loss: 0.4588 - val_accuracy: 0.4694
#
# Epoch 00069: val_loss did not improve from 0.31223
# Epoch 70/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4395 - accuracy: 0.5056 - val_loss: 0.5131 - val_accuracy: 0.3528
#
# Epoch 00070: val_loss did not improve from 0.31223
# Epoch 71/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4336 - accuracy: 0.5265 - val_loss: 0.4476 - val_accuracy: 0.4889
#
# Epoch 00071: val_loss did not improve from 0.31223
# Epoch 72/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4275 - accuracy: 0.5215 - val_loss: 0.4437 - val_accuracy: 0.4667
#
# Epoch 00072: val_loss did not improve from 0.31223
# Epoch 73/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4363 - accuracy: 0.5134 - val_loss: 0.4359 - val_accuracy: 0.5139
#
# Epoch 00073: val_loss did not improve from 0.31223
# Epoch 74/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4315 - accuracy: 0.5164 - val_loss: 0.4169 - val_accuracy: 0.5389
#
# Epoch 00074: val_loss did not improve from 0.31223
# Epoch 75/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4280 - accuracy: 0.5329 - val_loss: 0.4207 - val_accuracy: 0.5250
#
# Epoch 00075: val_loss did not improve from 0.31223
# Epoch 76/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4224 - accuracy: 0.5277 - val_loss: 0.4146 - val_accuracy: 0.5389
#
# Epoch 00076: val_loss did not improve from 0.31223
# Epoch 77/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4148 - accuracy: 0.5410 - val_loss: 0.4368 - val_accuracy: 0.4861
#
# Epoch 00077: val_loss did not improve from 0.31223
# Epoch 78/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4159 - accuracy: 0.5381 - val_loss: 0.4251 - val_accuracy: 0.5222
#
# Epoch 00078: val_loss did not improve from 0.31223
# Epoch 79/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4207 - accuracy: 0.5319 - val_loss: 0.4098 - val_accuracy: 0.5528
#
# Epoch 00079: val_loss did not improve from 0.31223
# Epoch 80/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4208 - accuracy: 0.5444 - val_loss: 0.4070 - val_accuracy: 0.5472
#
# Epoch 00080: val_loss did not improve from 0.31223
# Epoch 81/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4112 - accuracy: 0.5491 - val_loss: 0.4265 - val_accuracy: 0.5250
#
# Epoch 00081: val_loss did not improve from 0.31223
# Epoch 82/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4118 - accuracy: 0.5535 - val_loss: 0.4193 - val_accuracy: 0.5417
#
# Epoch 00082: val_loss did not improve from 0.31223
# Epoch 83/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4057 - accuracy: 0.5455 - val_loss: 0.4381 - val_accuracy: 0.4833
#
# Epoch 00083: val_loss did not improve from 0.31223
# Epoch 84/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4091 - accuracy: 0.5536 - val_loss: 0.4020 - val_accuracy: 0.5639
#
# Epoch 00084: val_loss did not improve from 0.31223
# Epoch 85/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4056 - accuracy: 0.5681 - val_loss: 0.4280 - val_accuracy: 0.5194
#
# Epoch 00085: val_loss did not improve from 0.31223
# Epoch 86/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3977 - accuracy: 0.5680 - val_loss: 0.3949 - val_accuracy: 0.5778
#
# Epoch 00086: val_loss did not improve from 0.31223
# Epoch 87/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4010 - accuracy: 0.5517 - val_loss: 0.3980 - val_accuracy: 0.5833
#
# Epoch 00087: val_loss did not improve from 0.31223
# Epoch 88/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.3964 - accuracy: 0.5585 - val_loss: 0.3935 - val_accuracy: 0.5611
#
# Epoch 00088: val_loss did not improve from 0.31223
# Epoch 89/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3881 - accuracy: 0.5819 - val_loss: 0.3904 - val_accuracy: 0.5778
#
# Epoch 00089: val_loss did not improve from 0.31223
# Epoch 90/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3953 - accuracy: 0.5828 - val_loss: 0.3855 - val_accuracy: 0.5722
#
# Epoch 00090: val_loss did not improve from 0.31223
# Epoch 91/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3822 - accuracy: 0.5768 - val_loss: 0.3799 - val_accuracy: 0.6000
#
# Epoch 00091: val_loss did not improve from 0.31223
# Epoch 92/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3924 - accuracy: 0.5790 - val_loss: 0.3887 - val_accuracy: 0.5861
#
# Epoch 00092: val_loss did not improve from 0.31223
# Epoch 93/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3869 - accuracy: 0.5687 - val_loss: 0.3879 - val_accuracy: 0.5722
#
# Epoch 00093: val_loss did not improve from 0.31223
# Epoch 94/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3832 - accuracy: 0.5601 - val_loss: 0.3830 - val_accuracy: 0.5722
#
# Epoch 00094: val_loss did not improve from 0.31223
# Epoch 95/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3696 - accuracy: 0.6014 - val_loss: 0.3948 - val_accuracy: 0.5528
#
# Epoch 00095: val_loss did not improve from 0.31223
# Epoch 96/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3799 - accuracy: 0.5879 - val_loss: 0.3851 - val_accuracy: 0.5750
#
# Epoch 00096: val_loss did not improve from 0.31223
# Epoch 97/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3812 - accuracy: 0.5840 - val_loss: 0.3743 - val_accuracy: 0.6000
#
# Epoch 00097: val_loss did not improve from 0.31223
# Epoch 98/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3826 - accuracy: 0.5787 - val_loss: 0.3926 - val_accuracy: 0.5556
#
# Epoch 00098: val_loss did not improve from 0.31223
# Epoch 99/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3785 - accuracy: 0.5967 - val_loss: 0.3660 - val_accuracy: 0.6000
#
# Epoch 00099: val_loss did not improve from 0.31223
# Epoch 100/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3742 - accuracy: 0.5937 - val_loss: 0.3719 - val_accuracy: 0.6000
#
# Epoch 00100: val_loss did not improve from 0.31223
# 13/13 [==============================] - 0s 3ms/step - loss: 0.3735 - accuracy: 0.5625
# Val Score:  [0.3735183775424957, 0.5625]
# ====================================================================================
#
#
# Training on Fold:  3
# Epoch 1/100
# 102/102 [==============================] - 2s 9ms/step - loss: 0.7510 - accuracy: 0.2648 - val_loss: 0.6126 - val_accuracy: 0.2389
#
# Epoch 00001: val_loss did not improve from 0.31223
# Epoch 2/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.6252 - accuracy: 0.2334 - val_loss: 0.5766 - val_accuracy: 0.2139
#
# Epoch 00002: val_loss did not improve from 0.31223
# Epoch 3/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5840 - accuracy: 0.2639 - val_loss: 0.5650 - val_accuracy: 0.2583
#
# Epoch 00003: val_loss did not improve from 0.31223
# Epoch 4/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5716 - accuracy: 0.2575 - val_loss: 0.5622 - val_accuracy: 0.2667
#
# Epoch 00004: val_loss did not improve from 0.31223
# Epoch 5/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5697 - accuracy: 0.2298 - val_loss: 0.5622 - val_accuracy: 0.2639
#
# Epoch 00005: val_loss did not improve from 0.31223
# Epoch 6/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5667 - accuracy: 0.2535 - val_loss: 0.5626 - val_accuracy: 0.2528
#
# Epoch 00006: val_loss did not improve from 0.31223
# Epoch 7/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5668 - accuracy: 0.2610 - val_loss: 0.5628 - val_accuracy: 0.2472
#
# Epoch 00007: val_loss did not improve from 0.31223
# Epoch 8/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5644 - accuracy: 0.2721 - val_loss: 0.5636 - val_accuracy: 0.2500
#
# Epoch 00008: val_loss did not improve from 0.31223
# Epoch 9/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5643 - accuracy: 0.2750 - val_loss: 0.5656 - val_accuracy: 0.2417
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00009: val_loss did not improve from 0.31223
# Epoch 10/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5636 - accuracy: 0.2637 - val_loss: 0.5630 - val_accuracy: 0.2556
#
# Epoch 00010: val_loss did not improve from 0.31223
# Epoch 11/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5635 - accuracy: 0.2690 - val_loss: 0.5609 - val_accuracy: 0.2861
#
# Epoch 00011: val_loss did not improve from 0.31223
# Epoch 12/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5604 - accuracy: 0.2835 - val_loss: 0.5593 - val_accuracy: 0.2917
#
# Epoch 00012: val_loss did not improve from 0.31223
# Epoch 13/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5629 - accuracy: 0.2797 - val_loss: 0.5654 - val_accuracy: 0.2389
#
# Epoch 00013: val_loss did not improve from 0.31223
# Epoch 14/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5589 - accuracy: 0.2922 - val_loss: 0.5578 - val_accuracy: 0.2917
#
# Epoch 00014: val_loss did not improve from 0.31223
# Epoch 15/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5598 - accuracy: 0.2842 - val_loss: 0.5566 - val_accuracy: 0.2694
#
# Epoch 00015: val_loss did not improve from 0.31223
# Epoch 16/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5546 - accuracy: 0.3015 - val_loss: 0.5573 - val_accuracy: 0.2861
#
# Epoch 00016: val_loss did not improve from 0.31223
# Epoch 17/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5564 - accuracy: 0.2958 - val_loss: 0.5531 - val_accuracy: 0.2972
#
# Epoch 00017: val_loss did not improve from 0.31223
# Epoch 18/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5486 - accuracy: 0.3316 - val_loss: 0.5602 - val_accuracy: 0.2667
#
# Epoch 00018: val_loss did not improve from 0.31223
# Epoch 19/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5418 - accuracy: 0.3392 - val_loss: 0.5723 - val_accuracy: 0.2667
#
# Epoch 00019: val_loss did not improve from 0.31223
# Epoch 20/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5375 - accuracy: 0.3593 - val_loss: 0.5284 - val_accuracy: 0.3250
#
# Epoch 00020: val_loss did not improve from 0.31223
# Epoch 21/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5318 - accuracy: 0.3424 - val_loss: 0.6401 - val_accuracy: 0.2667
#
# Epoch 00021: val_loss did not improve from 0.31223
# Epoch 22/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5316 - accuracy: 0.3469 - val_loss: 0.6484 - val_accuracy: 0.2639
#
# Epoch 00022: val_loss did not improve from 0.31223
# Epoch 23/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5230 - accuracy: 0.3683 - val_loss: 0.5888 - val_accuracy: 0.2833
#
# Epoch 00023: val_loss did not improve from 0.31223
# Epoch 24/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5121 - accuracy: 0.3798 - val_loss: 0.5287 - val_accuracy: 0.3167
#
# Epoch 00024: val_loss did not improve from 0.31223
# Epoch 25/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5161 - accuracy: 0.3647 - val_loss: 0.5921 - val_accuracy: 0.2778
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00025: val_loss did not improve from 0.31223
# Epoch 26/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5044 - accuracy: 0.3842 - val_loss: 0.4845 - val_accuracy: 0.4194
#
# Epoch 00026: val_loss did not improve from 0.31223
# Epoch 27/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5057 - accuracy: 0.3902 - val_loss: 0.4827 - val_accuracy: 0.4028
#
# Epoch 00027: val_loss did not improve from 0.31223
# Epoch 28/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4935 - accuracy: 0.4128 - val_loss: 0.4749 - val_accuracy: 0.4417
#
# Epoch 00028: val_loss did not improve from 0.31223
# Epoch 29/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4908 - accuracy: 0.4185 - val_loss: 0.4758 - val_accuracy: 0.4333
#
# Epoch 00029: val_loss did not improve from 0.31223
# Epoch 30/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4917 - accuracy: 0.4220 - val_loss: 0.4783 - val_accuracy: 0.4056
#
# Epoch 00030: val_loss did not improve from 0.31223
# Epoch 31/100
# ...
# Epoch 21/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5618 - accuracy: 0.2608 - val_loss: 0.5625 - val_accuracy: 0.2333
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00021: val_loss did not improve from 0.31223
# Epoch 22/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5599 - accuracy: 0.2870 - val_loss: 0.5626 - val_accuracy: 0.2278
#
# Epoch 00022: val_loss did not improve from 0.31223
# Epoch 23/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5616 - accuracy: 0.2792 - val_loss: 0.5624 - val_accuracy: 0.2250
#
# Epoch 00023: val_loss did not improve from 0.31223
# Epoch 24/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5604 - accuracy: 0.2937 - val_loss: 0.5621 - val_accuracy: 0.2278
#
# Epoch 00024: val_loss did not improve from 0.31223
# Epoch 25/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5613 - accuracy: 0.2907 - val_loss: 0.5621 - val_accuracy: 0.2111
#
# Epoch 00025: val_loss did not improve from 0.31223
# Epoch 26/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5595 - accuracy: 0.2911 - val_loss: 0.5604 - val_accuracy: 0.2306
#
# Epoch 00026: val_loss did not improve from 0.31223
# Epoch 27/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5599 - accuracy: 0.2804 - val_loss: 0.5605 - val_accuracy: 0.2611
#
# Epoch 00027: val_loss did not improve from 0.31223
# Epoch 28/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5585 - accuracy: 0.2884 - val_loss: 0.5603 - val_accuracy: 0.2333
#
# Epoch 00028: val_loss did not improve from 0.31223
# Epoch 29/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5546 - accuracy: 0.3165 - val_loss: 0.5591 - val_accuracy: 0.2389
#
# Epoch 00029: val_loss did not improve from 0.31223
# Epoch 30/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.5554 - accuracy: 0.3020 - val_loss: 0.5598 - val_accuracy: 0.2306
#
# Epoch 00030: val_loss did not improve from 0.31223
# Epoch 31/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5531 - accuracy: 0.3014 - val_loss: 0.5549 - val_accuracy: 0.2611
#
# Epoch 00031: val_loss did not improve from 0.31223
# Epoch 32/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5499 - accuracy: 0.3245 - val_loss: 0.5636 - val_accuracy: 0.2333
#
# Epoch 00032: val_loss did not improve from 0.31223
# Epoch 33/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5471 - accuracy: 0.3285 - val_loss: 0.5505 - val_accuracy: 0.2889
#
# Epoch 00033: val_loss did not improve from 0.31223
# Epoch 34/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5424 - accuracy: 0.3386 - val_loss: 0.5620 - val_accuracy: 0.2833
#
# Epoch 00034: val_loss did not improve from 0.31223
# Epoch 35/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5390 - accuracy: 0.3364 - val_loss: 0.5375 - val_accuracy: 0.3444
#
# Epoch 00035: val_loss did not improve from 0.31223
# Epoch 36/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5363 - accuracy: 0.3277 - val_loss: 0.5375 - val_accuracy: 0.3083
#
# Epoch 00036: val_loss did not improve from 0.31223
# Epoch 37/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5326 - accuracy: 0.3531 - val_loss: 0.5274 - val_accuracy: 0.3500
#
# Epoch 00037: val_loss did not improve from 0.31223
# Epoch 38/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5356 - accuracy: 0.3400 - val_loss: 0.5443 - val_accuracy: 0.3222
#
# Epoch 00038: val_loss did not improve from 0.31223
# Epoch 39/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5299 - accuracy: 0.3624 - val_loss: 0.5458 - val_accuracy: 0.2917
#
# Epoch 00039: val_loss did not improve from 0.31223
# Epoch 40/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5260 - accuracy: 0.3751 - val_loss: 0.5265 - val_accuracy: 0.3611
#
# Epoch 00040: val_loss did not improve from 0.31223
# Epoch 41/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5247 - accuracy: 0.3634 - val_loss: 0.5461 - val_accuracy: 0.3083
#
# Epoch 00041: val_loss did not improve from 0.31223
# Epoch 42/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5175 - accuracy: 0.3749 - val_loss: 0.5444 - val_accuracy: 0.3306
#
# Epoch 00042: val_loss did not improve from 0.31223
# Epoch 43/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5170 - accuracy: 0.3778 - val_loss: 0.5313 - val_accuracy: 0.3611
#
# Epoch 00043: val_loss did not improve from 0.31223
# Epoch 44/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5156 - accuracy: 0.3831 - val_loss: 0.5271 - val_accuracy: 0.3833
#
# Epoch 00044: val_loss did not improve from 0.31223
# Epoch 45/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.5173 - accuracy: 0.3783 - val_loss: 0.5416 - val_accuracy: 0.3139
#
# Epoch 00045: val_loss did not improve from 0.31223
# Epoch 46/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5066 - accuracy: 0.3872 - val_loss: 0.5141 - val_accuracy: 0.3694
#
# Epoch 00046: val_loss did not improve from 0.31223
# Epoch 47/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.5154 - accuracy: 0.3813 - val_loss: 0.5205 - val_accuracy: 0.3583
#
# Epoch 00047: val_loss did not improve from 0.31223
# Epoch 48/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5088 - accuracy: 0.3925 - val_loss: 0.5076 - val_accuracy: 0.3750
#
# Epoch 00048: val_loss did not improve from 0.31223
# Epoch 49/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5052 - accuracy: 0.3863 - val_loss: 0.5225 - val_accuracy: 0.3528
#
# Epoch 00049: val_loss did not improve from 0.31223
# Epoch 50/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4997 - accuracy: 0.4001 - val_loss: 0.5050 - val_accuracy: 0.4139
#
# Epoch 00050: val_loss did not improve from 0.31223
# Epoch 51/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5042 - accuracy: 0.4019 - val_loss: 0.5251 - val_accuracy: 0.3639
#
# Epoch 00051: val_loss did not improve from 0.31223
# Epoch 52/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5112 - accuracy: 0.3861 - val_loss: 0.5114 - val_accuracy: 0.3667
#
# Epoch 00052: val_loss did not improve from 0.31223
# Epoch 53/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4999 - accuracy: 0.4069 - val_loss: 0.5042 - val_accuracy: 0.3667
#
# Epoch 00053: val_loss did not improve from 0.31223
# Epoch 54/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4982 - accuracy: 0.3903 - val_loss: 0.5007 - val_accuracy: 0.3583
#
# Epoch 00054: val_loss did not improve from 0.31223
# Epoch 55/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4952 - accuracy: 0.4018 - val_loss: 0.4955 - val_accuracy: 0.3833
#
# Epoch 00055: val_loss did not improve from 0.31223
# Epoch 56/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4912 - accuracy: 0.4260 - val_loss: 0.5169 - val_accuracy: 0.3389
#
# Epoch 00056: val_loss did not improve from 0.31223
# Epoch 57/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4982 - accuracy: 0.4130 - val_loss: 0.5057 - val_accuracy: 0.3667
#
# Epoch 00057: val_loss did not improve from 0.31223
# Epoch 58/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4867 - accuracy: 0.4130 - val_loss: 0.4850 - val_accuracy: 0.4111
#
# Epoch 00058: val_loss did not improve from 0.31223
# Epoch 59/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4882 - accuracy: 0.4098 - val_loss: 0.5182 - val_accuracy: 0.3472
#
# Epoch 00059: val_loss did not improve from 0.31223
# Epoch 60/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4893 - accuracy: 0.4214 - val_loss: 0.5043 - val_accuracy: 0.3639
#
# Epoch 00060: val_loss did not improve from 0.31223
# Epoch 61/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4852 - accuracy: 0.4168 - val_loss: 0.5117 - val_accuracy: 0.3528
#
# Epoch 00061: val_loss did not improve from 0.31223
# Epoch 62/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4850 - accuracy: 0.4308 - val_loss: 0.4930 - val_accuracy: 0.3778
#
# Epoch 00062: val_loss did not improve from 0.31223
# Epoch 63/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4799 - accuracy: 0.4496 - val_loss: 0.4929 - val_accuracy: 0.3889
#
# Epoch 00063: val_loss did not improve from 0.31223
# Epoch 64/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4809 - accuracy: 0.4324 - val_loss: 0.4779 - val_accuracy: 0.4306
#
# Epoch 00064: val_loss did not improve from 0.31223
# Epoch 65/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4804 - accuracy: 0.4499 - val_loss: 0.4805 - val_accuracy: 0.4194
#
# Epoch 00065: val_loss did not improve from 0.31223
# Epoch 66/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4784 - accuracy: 0.4563 - val_loss: 0.4736 - val_accuracy: 0.4472
#
# Epoch 00066: val_loss did not improve from 0.31223
# Epoch 67/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4718 - accuracy: 0.4642 - val_loss: 0.4900 - val_accuracy: 0.3889
#
# Epoch 00067: val_loss did not improve from 0.31223
# Epoch 68/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4748 - accuracy: 0.4483 - val_loss: 0.4690 - val_accuracy: 0.4444
#
# Epoch 00068: val_loss did not improve from 0.31223
# Epoch 69/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4712 - accuracy: 0.4606 - val_loss: 0.4727 - val_accuracy: 0.4250
#
# Epoch 00069: val_loss did not improve from 0.31223
# Epoch 70/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4709 - accuracy: 0.4603 - val_loss: 0.4688 - val_accuracy: 0.4444
#
# Epoch 00070: val_loss did not improve from 0.31223
# Epoch 71/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4627 - accuracy: 0.4663 - val_loss: 0.4688 - val_accuracy: 0.4444
#
# Epoch 00071: val_loss did not improve from 0.31223
# Epoch 72/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4611 - accuracy: 0.4754 - val_loss: 0.4581 - val_accuracy: 0.4444
#
# Epoch 00072: val_loss did not improve from 0.31223
# Epoch 73/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4680 - accuracy: 0.4605 - val_loss: 0.4725 - val_accuracy: 0.4361
#
# Epoch 00073: val_loss did not improve from 0.31223
# Epoch 74/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4553 - accuracy: 0.4944 - val_loss: 0.4766 - val_accuracy: 0.4139
#
# Epoch 00074: val_loss did not improve from 0.31223
# Epoch 75/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4505 - accuracy: 0.4801 - val_loss: 0.4497 - val_accuracy: 0.4583
#
# Epoch 00075: val_loss did not improve from 0.31223
# Epoch 76/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4548 - accuracy: 0.4850 - val_loss: 0.4747 - val_accuracy: 0.4167
#
# Epoch 00076: val_loss did not improve from 0.31223
# Epoch 77/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4523 - accuracy: 0.4929 - val_loss: 0.4572 - val_accuracy: 0.4444
#
# Epoch 00077: val_loss did not improve from 0.31223
# Epoch 78/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4570 - accuracy: 0.4739 - val_loss: 0.4693 - val_accuracy: 0.4250
#
# Epoch 00078: val_loss did not improve from 0.31223
# Epoch 79/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.4443 - accuracy: 0.5004 - val_loss: 0.4577 - val_accuracy: 0.4306
#
# Epoch 00079: val_loss did not improve from 0.31223
# Epoch 80/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4440 - accuracy: 0.5031 - val_loss: 0.4656 - val_accuracy: 0.4194
#
# Epoch 00080: val_loss did not improve from 0.31223
# Epoch 81/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4474 - accuracy: 0.5057 - val_loss: 0.4444 - val_accuracy: 0.4472
#
# Epoch 00081: val_loss did not improve from 0.31223
# Epoch 82/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4343 - accuracy: 0.5185 - val_loss: 0.4613 - val_accuracy: 0.4278
#
# Epoch 00082: val_loss did not improve from 0.31223
# Epoch 83/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4393 - accuracy: 0.5037 - val_loss: 0.4582 - val_accuracy: 0.4444
#
# Epoch 00083: val_loss did not improve from 0.31223
# Epoch 84/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4363 - accuracy: 0.5150 - val_loss: 0.4343 - val_accuracy: 0.4833
#
# Epoch 00084: val_loss did not improve from 0.31223
# Epoch 85/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4293 - accuracy: 0.5292 - val_loss: 0.4373 - val_accuracy: 0.4944
#
# Epoch 00085: val_loss did not improve from 0.31223
# Epoch 86/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4296 - accuracy: 0.5298 - val_loss: 0.4433 - val_accuracy: 0.4444
#
# Epoch 00086: val_loss did not improve from 0.31223
# Epoch 87/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4235 - accuracy: 0.5261 - val_loss: 0.4321 - val_accuracy: 0.4889
#
# Epoch 00087: val_loss did not improve from 0.31223
# Epoch 88/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4226 - accuracy: 0.5309 - val_loss: 0.4258 - val_accuracy: 0.5000
#
# Epoch 00088: val_loss did not improve from 0.31223
# Epoch 89/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4213 - accuracy: 0.5355 - val_loss: 0.4412 - val_accuracy: 0.4694
#
# Epoch 00089: val_loss did not improve from 0.31223
# Epoch 90/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4153 - accuracy: 0.5439 - val_loss: 0.4360 - val_accuracy: 0.4861
#
# Epoch 00090: val_loss did not improve from 0.31223
# Epoch 91/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4090 - accuracy: 0.5505 - val_loss: 0.4420 - val_accuracy: 0.4583
#
# Epoch 00091: val_loss did not improve from 0.31223
# Epoch 92/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4121 - accuracy: 0.5558 - val_loss: 0.4252 - val_accuracy: 0.4944
#
# Epoch 00092: val_loss did not improve from 0.31223
# Epoch 93/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4074 - accuracy: 0.5490 - val_loss: 0.4318 - val_accuracy: 0.4694
#
# Epoch 00093: val_loss did not improve from 0.31223
# Epoch 94/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4005 - accuracy: 0.5708 - val_loss: 0.4530 - val_accuracy: 0.4750
#
# Epoch 00094: val_loss did not improve from 0.31223
# Epoch 95/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4029 - accuracy: 0.5635 - val_loss: 0.4163 - val_accuracy: 0.5000
#
# Epoch 00095: val_loss did not improve from 0.31223
# Epoch 96/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3978 - accuracy: 0.5618 - val_loss: 0.4591 - val_accuracy: 0.4556
#
# Epoch 00096: val_loss did not improve from 0.31223
# Epoch 97/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4103 - accuracy: 0.5472 - val_loss: 0.4185 - val_accuracy: 0.4889
#
# Epoch 00097: val_loss did not improve from 0.31223
# Epoch 98/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3957 - accuracy: 0.5672 - val_loss: 0.4305 - val_accuracy: 0.5083
#
# Epoch 00098: val_loss did not improve from 0.31223
# Epoch 99/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3790 - accuracy: 0.5977 - val_loss: 0.4127 - val_accuracy: 0.5389
#
# Epoch 00099: val_loss did not improve from 0.31223
# Epoch 100/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3963 - accuracy: 0.5629 - val_loss: 0.4433 - val_accuracy: 0.4889
#
# Epoch 00100: val_loss did not improve from 0.31223
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4526 - accuracy: 0.4650
# Val Score:  [0.45256248116493225, 0.4650000035762787]
# ====================================================================================

# %%
#Load the model that was saved by ModelCheckpoint
model = load_model('subjek3.h5')

# %%
model.evaluate(test_X, test_y)
#print("Accuracy of the model is - " , model.evaluate(test_X,test_y)[1]*100 , "%")
#plt.bar( model.evaluate(test_X)[1].index,  model.evaluate(test_y)[1])
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2698 - accuracy: 0.7050
# [0.26983410120010376, 0.7049999833106995]

# %%
fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)

ax1.plot(model_history[0].history['accuracy'], label='Training Fold 1 accuration')
ax1.plot(model_history[1].history['accuracy'], label='Training Fold 2 accuration')
ax1.plot(model_history[2].history['accuracy'], label='Training Fold 3 accuration')
ax1.plot(model_history[3].history['accuracy'], label='Training Fold 4 accuration')
ax1.plot(model_history[4].history['accuracy'], label='Training Fold 5 accuration')
ax1.legend()
ax2.plot(model_history[1].history['loss'], label='Training Fold 1 loss')
ax2.plot(model_history[1].history['loss'], label='Training Fold 2 loss')
ax2.plot(model_history[2].history['loss'], label='Training Fold 3 loss')
ax2.plot(model_history[3].history['loss'], label='Training Fold 4 loss ')
ax2.plot(model_history[4].history['loss'], label='Training Fold 5 loss')
ax2.legend()
plt.show()

# %%
fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt1.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[0].history['loss'], label='Train Loss Fold 1', color='black')
plt2.plot(model_history[0].history['val_loss'], label='Val Loss Fold 1', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red')
plt1.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[1].history['loss'], label='Train Loss Fold 2', color='red')
plt2.plot(model_history[1].history['val_loss'], label='Val Loss Fold 2', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green')
plt1.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[2].history['loss'], label='Train Loss Fold 3', color='green')
plt2.plot(model_history[2].history['val_loss'], label='Val Loss Fold 3', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()


fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue')
plt1.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[3].history['loss'], label='Train Loss Fold 4', color='blue')
plt2.plot(model_history[3].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='purple')
plt1.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[4].history['loss'], label='Train Loss Fold 4', color='purple')
plt2.plot(model_history[4].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

# %%
MODEL_NAME ='/content/subjek3.h5' 

#CLIP = True # if your model was trained with np.clip to clip  values
CLIP = False
CLIP_VAL = 8  # if above, what was the value +/-

model = tf.keras.models.load_model(MODEL_NAME)

VALDIR = '/content/drive/MyDrive/Colab Notebooks/subjek3tes'
ACTIONS =  ["idle","maju","kiri", "kanan"]
PRED_BATCH = 32


def get_val_data(valdir, action, batch_size):

   # argmax_dict = {0: 0, 1: 0, 2: 0,3:0}
    argmax_dict = {2: 0, 0: 0, 1: 0,3:0}
    raw_pred_dict = {0: 0, 1: 0, 2: 0,3:0}

    action_dir = os.path.join(valdir, action)
    for session_file in os.listdir(action_dir):
        filepath = os.path.join(action_dir,session_file)
        if CLIP:
            data = np.clip(np.load(filepath), -CLIP_VAL, CLIP_VAL) / CLIP_VAL
            #print(data)
        else:
            data = np.load(filepath) 
        preds = model.predict([data.reshape(-1, 16, 60,1)], batch_size=batch_size)
        
        for pred in preds:
            argmax = np.argmax(pred)
            argmax_dict[argmax] += 1
            for idx,value in enumerate(pred):
                raw_pred_dict[idx] += value
    
    argmax_pct_dict = {}
    for i in argmax_dict:
        total = 0
        correct = argmax_dict[i]
        for ii in argmax_dict:
            total += argmax_dict[ii]
        argmax_pct_dict[i] = round(correct/total, 4)
    return argmax_dict, raw_pred_dict, argmax_pct_dict


def make_conf_mat(none,left,forward, right):
    action_dict = {"idle":none,"maju": forward, "kiri": left, "kanan": right}
    action_conf_mat = pd.DataFrame(action_dict)
    actions = [i for i in action_dict]

    fig = plt.figure(figsize=(15, 6))
    ax = fig.add_subplot(111)
    ax.matshow(action_conf_mat, cmap=plt.cm.RdYlGn)
    ax.set_xticklabels([""]+actions)
    ax.set_yticklabels([""]+actions)

    for idx, i in enumerate(action_dict):
        for idx2, ii in enumerate(action_dict[i]):
            ax.text(idx, idx2, f"{round(float(action_dict[i][ii]),2)}", va='center', ha='center')
    # Rotate the tick labels and set their alignment.
    
    plt.title("Matrik data")
    plt.ylabel("Predicted Action")
    fig.tight_layout()
    plt.show()



forward_argmax_dict, forward_raw_pred_dict, forward_argmax_pct_dict = get_val_data(VALDIR, "maju", PRED_BATCH)
none_argmax_dict, none_raw_pred_dict, none_argmax_pct_dict = get_val_data(VALDIR, "idle", PRED_BATCH)
left_argmax_dict, left_raw_pred_dict, left_argmax_pct_dict = get_val_data(VALDIR, "kiri", PRED_BATCH)
right_argmax_dict, right_raw_pred_dict, right_argmax_pct_dict = get_val_data(VALDIR, "kanan", PRED_BATCH)
make_conf_mat(none_argmax_pct_dict,forward_argmax_pct_dict,left_argmax_pct_dict,  right_argmax_pct_dict)

# %%
from sklearn.metrics import roc_curve, auc
#y_score = clf.decision_function(xval)
y_score = model.predict(test_X)

#Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()


# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(test_y[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
    
    
print("roc_auc:",sum(roc_auc.values())/4)
ACTIONS =  ["idle","maju","kiri", "kanan"]
for i in range(0,4):
    plt.figure()
    fig, ax = plt.subplots(figsize=(5,5))
    plt.plot(fpr[i], tpr[i],linewidth=3)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    #plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % ACTIONS[i])
    plt.title('%s -ROC curve (area = %0.2f)' % (ACTIONS[i],roc_auc[i]))
    
    plt.legend(loc="lower right")
    plt.show()
# Out:
# roc_auc: 0.9229373333333333

# %% [markdown]
# <a href="https://colab.research.google.com/github/wedexyz/eeg-/blob/main/notesreduce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (0.17.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.18.5)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.4.1)

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM, BatchNormalization, Conv2D, Flatten, MaxPooling2D, Dropout
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.optimizers import Adam
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (20,7)
import pandas as pd
import os
import random
import time
import os
from keras.callbacks import ModelCheckpoint, EarlyStopping
#from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator

# %%
idle = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/idle/1604315006.npy")
kanan = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kanan/1604315180.npy")
kiri = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kiri/1604315126.npy")
maju = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/maju/1604315069.npy")

fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('idle')
ax1.plot(idle[0][16])
ax2.plot(idle[175])

fig, (ax3, ax4) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('kanan')
ax3.plot(kanan[0][16])
ax4.plot(kanan[175])

fig, (ax5, ax6) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('kiri')
ax5.plot(kiri[0][16])
ax6.plot(kiri[175])

fig, (ax7, ax8) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('maju')
ax7.plot(maju[0][16])
ax8.plot(maju[175])



plt.show()

# %%
ACTIONS = ["kiri", "maju","idle","kanan"]
reshape = (-1,16, 60,1)
#reshape(-1,28,28,1)

# %%
def create_data(starting_dir="=/content/drive/My Drive/Colab Notebooks/data_baru"):
    training_data = {}
    for action in ACTIONS:
        if action not in training_data:
            training_data[action] = []
        data_dir = os.path.join(starting_dir,action)
        for item in os.listdir(data_dir):
            data = np.load(os.path.join(data_dir, item))
            for item in data:
                training_data[action].append(item)

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)

    for action in ACTIONS:
        np.random.shuffle(training_data[action])  
        training_data[action] = training_data[action][:min(lengths)]

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)
    combined_data = []
    for action in ACTIONS:
        for data in training_data[action]:
            if action == "kiri":
                combined_data.append([data, [1, 0, 0,0]])
            elif action == "maju":
                combined_data.append([data, [0, 1, 0, 0]])
            elif action == "idle":
                combined_data.append([data, [0, 0, 1, 0]])
            elif action == "kanan":
                combined_data.append([data, [0, 0, 0, 1]])

    np.random.shuffle(combined_data)
    print("length:",len(combined_data))
    return combined_data

# %%
print("creating training data")
traindata = create_data(starting_dir="/content/drive/My Drive/Colab Notebooks/data_baru")
train_X = []
train_y = []
for X, y in traindata:
    train_X.append(X)
    train_y.append(y)
# Out:
# creating training data
# [1000, 1000, 1000, 1000]
# [1000, 1000, 1000, 1000]
# length: 4000

# %%
print("creating testing data")
testdata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/tes_data")
test_X = []
test_y = []

for X, y in testdata:
    test_X.append(X)
    test_y.append(y)
train_X = np.array(train_X).reshape(reshape)
test_X = np.array(test_X).reshape(reshape)

train_y = np.array(train_y)
test_y = np.array(test_y)
# Out:
# creating testing data
# [250, 250, 250, 250]
# [250, 250, 250, 250]
# length: 1000

# %%
f, ax = plt.subplots(2,4) 
f.set_size_inches(10, 10)
k = 0
for i in range(2):
    for j in range(4):
       # ax[i,j].imshow(train_X [k].reshape(28, 28) , cmap = "gray")
        ax[i,j].imshow(train_X [k].reshape(16,60)  ,cmap = "gray")
        k += 1
    plt.tight_layout()

# %%
IMAGE_SIZE = (16, 60, 1)

# %%
# With data augmentation to prevent overfitting

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(train_X)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='accuracy', patience = 5, verbose=1,factor=0.5, min_lr=0.0001)

# %%
def cnn_model(size, num_cnn_layers):
    
    NUM_FILTERS = 64
    KERNEL = (7, 7)
    #MIN_NEURONS = 20
    #MAX_NEURONS = 120

    model = Sequential()
    '''
    for i in range(1, num_cnn_layers+1):
        if i == 1:
            model.add(Conv2D(NUM_FILTERS*i, KERNEL, input_shape=train_X.shape[1:], activation='relu', padding='same'),)
        else:
            model.add(Conv2D(NUM_FILTERS*i, KERNEL, activation='relu', padding='same'))
    
    #model = Sequential()
    '''
    model.add(Conv2D(filters = 64, kernel_size = (7,7), padding = "same", activation = "relu", input_shape=train_X.shape[1:]))
    model.add(BatchNormalization())
    model.add(Conv2D(filters = 64, kernel_size = (5,5), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size = (5,5)))
    model.add(Conv2D(filters = 64, kernel_size = (3,3), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size = (3,3)))
    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(32, activation = "relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(4, activation = "sigmoid"))
    model.compile(optimizer ="adam", loss = "binary_crossentropy", metrics = ['accuracy'])
    #adam = Adam(lr = 0.001)
    
    #model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    #print(model.summary())
    
    return model

# %%
model = cnn_model(IMAGE_SIZE, 2)

# %%
model.summary()
# Out:
# Model: "sequential_48"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_240 (Conv2D)          (None, 16, 60, 64)        3200
# _________________________________________________________________
# batch_normalization_192 (Bat (None, 16, 60, 64)        256
# _________________________________________________________________
# conv2d_241 (Conv2D)          (None, 16, 60, 64)        102464
# _________________________________________________________________
# batch_normalization_193 (Bat (None, 16, 60, 64)        256
# _________________________________________________________________
# max_pooling2d_96 (MaxPooling (None, 3, 12, 64)         0
# _________________________________________________________________
# conv2d_242 (Conv2D)          (None, 3, 12, 64)         36928
# _________________________________________________________________
# batch_normalization_194 (Bat (None, 3, 12, 64)         256
# _________________________________________________________________
# max_pooling2d_97 (MaxPooling (None, 1, 4, 64)          0
# _________________________________________________________________
# flatten_48 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dropout_96 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_96 (Dense)             (None, 32)                8224
# _________________________________________________________________
# batch_normalization_195 (Bat (None, 32)                128
# _________________________________________________________________
# dropout_97 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_97 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 151,844
# Trainable params: 151,396
# Non-trainable params: 448
# _________________________________________________________________

# %%
#set early stopping criteria
pat = 5
#this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='loss', patience=pat, verbose=1)

#define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('fas_mnist_1.h5', verbose=1, save_best_only=True)

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=100, BATCH_SIZE=16):
    model = None
    model = cnn_model(IMAGE_SIZE, 2)
    #Model = model
   # results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[early_stopping, model_checkpoint], 
   #           verbose=1, validation_split=0.1) 
    results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[learning_rate_reduction,early_stopping, model_checkpoint], 
              verbose=1, validation_split=0.1)   
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs=100
batch_size=16

#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(train_X, train_y, test_size=0.1, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
   
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.7448 - accuracy: 0.2557
# Epoch 00001: val_loss improved from inf to 0.61327, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 6ms/step - loss: 0.7423 - accuracy: 0.2565 - val_loss: 0.6133 - val_accuracy: 0.2472
# Epoch 2/100
# 196/203 [===========================>..] - ETA: 0s - loss: 0.6254 - accuracy: 0.2695
# Epoch 00002: val_loss improved from 0.61327 to 0.58663, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.6252 - accuracy: 0.2673 - val_loss: 0.5866 - val_accuracy: 0.2444
# Epoch 3/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.5970 - accuracy: 0.2598
# Epoch 00003: val_loss improved from 0.58663 to 0.56133, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5974 - accuracy: 0.2586 - val_loss: 0.5613 - val_accuracy: 0.2944
# Epoch 4/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.5833 - accuracy: 0.2776
# Epoch 00004: val_loss improved from 0.56133 to 0.55799, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5835 - accuracy: 0.2769 - val_loss: 0.5580 - val_accuracy: 0.3306
# Epoch 5/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.5748 - accuracy: 0.2896
# Epoch 00005: val_loss did not improve from 0.55799
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5750 - accuracy: 0.2917 - val_loss: 0.5581 - val_accuracy: 0.3417
# Epoch 6/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.5673 - accuracy: 0.3035
# Epoch 00006: val_loss improved from 0.55799 to 0.55655, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 6ms/step - loss: 0.5672 - accuracy: 0.3040 - val_loss: 0.5565 - val_accuracy: 0.3111
# Epoch 7/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.5564 - accuracy: 0.3298
# Epoch 00007: val_loss did not improve from 0.55655
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5564 - accuracy: 0.3306 - val_loss: 0.5746 - val_accuracy: 0.2833
# Epoch 8/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.5420 - accuracy: 0.3672
# Epoch 00008: val_loss did not improve from 0.55655
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5422 - accuracy: 0.3670 - val_loss: 0.5618 - val_accuracy: 0.3139
# Epoch 9/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.5301 - accuracy: 0.4007
# Epoch 00009: val_loss improved from 0.55655 to 0.52240, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5300 - accuracy: 0.4006 - val_loss: 0.5224 - val_accuracy: 0.3500
# Epoch 10/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.5099 - accuracy: 0.4272
# Epoch 00010: val_loss did not improve from 0.52240
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5097 - accuracy: 0.4302 - val_loss: 0.5861 - val_accuracy: 0.3056
# Epoch 11/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.4900 - accuracy: 0.4631
# Epoch 00011: val_loss did not improve from 0.52240
# 203/203 [==============================] - 1s 5ms/step - loss: 0.4899 - accuracy: 0.4636 - val_loss: 0.5252 - val_accuracy: 0.3861
# Epoch 12/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.4704 - accuracy: 0.4909
# Epoch 00012: val_loss improved from 0.52240 to 0.46877, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.4705 - accuracy: 0.4914 - val_loss: 0.4688 - val_accuracy: 0.4528
# Epoch 13/100
# 192/203 [===========================>..] - ETA: 0s - loss: 0.4287 - accuracy: 0.5553
# Epoch 00013: val_loss did not improve from 0.46877
# 203/203 [==============================] - 1s 5ms/step - loss: 0.4287 - accuracy: 0.5534 - val_loss: 0.4915 - val_accuracy: 0.4694
# Epoch 14/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.4137 - accuracy: 0.5873
# Epoch 00014: val_loss improved from 0.46877 to 0.43090, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.4138 - accuracy: 0.5873 - val_loss: 0.4309 - val_accuracy: 0.5222
# Epoch 15/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.3857 - accuracy: 0.6160
# Epoch 00015: val_loss improved from 0.43090 to 0.40270, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.3854 - accuracy: 0.6164 - val_loss: 0.4027 - val_accuracy: 0.5722
# Epoch 16/100
# 196/203 [===========================>..] - ETA: 0s - loss: 0.3615 - accuracy: 0.6518
# Epoch 00016: val_loss improved from 0.40270 to 0.36160, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 6ms/step - loss: 0.3607 - accuracy: 0.6528 - val_loss: 0.3616 - val_accuracy: 0.6333
# Epoch 17/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.3495 - accuracy: 0.6590
# Epoch 00017: val_loss did not improve from 0.36160
# 203/203 [==============================] - 1s 5ms/step - loss: 0.3493 - accuracy: 0.6593 - val_loss: 0.3739 - val_accuracy: 0.5750
# Epoch 18/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.3241 - accuracy: 0.6755
# Epoch 00018: val_loss did not improve from 0.36160
# 203/203 [==============================] - 1s 6ms/step - loss: 0.3247 - accuracy: 0.6750 - val_loss: 0.4468 - val_accuracy: 0.5222
# Epoch 19/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.3039 - accuracy: 0.6913
# Epoch 00019: val_loss improved from 0.36160 to 0.35801, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.3029 - accuracy: 0.6938 - val_loss: 0.3580 - val_accuracy: 0.6083
# Epoch 20/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.2962 - accuracy: 0.7061
# Epoch 00020: val_loss improved from 0.35801 to 0.29482, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2973 - accuracy: 0.7052 - val_loss: 0.2948 - val_accuracy: 0.6806
# Epoch 21/100
# 203/203 [==============================] - ETA: 0s - loss: 0.2810 - accuracy: 0.7204
# Epoch 00021: val_loss did not improve from 0.29482
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2810 - accuracy: 0.7204 - val_loss: 0.2963 - val_accuracy: 0.6833
# Epoch 22/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.2820 - accuracy: 0.7201
# Epoch 00022: val_loss improved from 0.29482 to 0.28745, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2825 - accuracy: 0.7188 - val_loss: 0.2875 - val_accuracy: 0.7000
# Epoch 23/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.2735 - accuracy: 0.7330
# Epoch 00023: val_loss did not improve from 0.28745
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2736 - accuracy: 0.7321 - val_loss: 0.3155 - val_accuracy: 0.6472
# Epoch 24/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.2540 - accuracy: 0.7512
# Epoch 00024: val_loss did not improve from 0.28745
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2547 - accuracy: 0.7500 - val_loss: 0.3223 - val_accuracy: 0.6444
# Epoch 25/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.2495 - accuracy: 0.7465
# Epoch 00025: val_loss did not improve from 0.28745
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2486 - accuracy: 0.7481 - val_loss: 0.3094 - val_accuracy: 0.6667
# Epoch 26/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.2353 - accuracy: 0.7655
# Epoch 00026: val_loss improved from 0.28745 to 0.27811, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2373 - accuracy: 0.7633 - val_loss: 0.2781 - val_accuracy: 0.6944
# Epoch 27/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.2319 - accuracy: 0.7697
# Epoch 00027: val_loss improved from 0.27811 to 0.23704, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2330 - accuracy: 0.7691 - val_loss: 0.2370 - val_accuracy: 0.7500
# Epoch 28/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.2290 - accuracy: 0.7629
# Epoch 00028: val_loss did not improve from 0.23704
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2302 - accuracy: 0.7633 - val_loss: 0.3239 - val_accuracy: 0.6944
# Epoch 29/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.2190 - accuracy: 0.7830
# Epoch 00029: val_loss did not improve from 0.23704
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2197 - accuracy: 0.7815 - val_loss: 0.2446 - val_accuracy: 0.7361
# Epoch 30/100
# 196/203 [===========================>..] - ETA: 0s - loss: 0.2181 - accuracy: 0.7768
# Epoch 00030: val_loss did not improve from 0.23704
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2179 - accuracy: 0.7750 - val_loss: 0.2404 - val_accuracy: 0.7611
# Epoch 31/100
# 193/203 [===========================>..] - ETA: 0s - loss: 0.2133 - accuracy: 0.7869
# Epoch 00031: val_loss improved from 0.23704 to 0.22717, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2129 - accuracy: 0.7877 - val_loss: 0.2272 - val_accuracy: 0.7722
# Epoch 32/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.2115 - accuracy: 0.7838
# Epoch 00032: val_loss did not improve from 0.22717
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2106 - accuracy: 0.7861 - val_loss: 0.2485 - val_accuracy: 0.7306
# Epoch 33/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.2197 - accuracy: 0.7859
# Epoch 00033: val_loss did not improve from 0.22717
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2178 - accuracy: 0.7880 - val_loss: 0.2927 - val_accuracy: 0.7083
# Epoch 34/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.2068 - accuracy: 0.7960
# Epoch 00034: val_loss did not improve from 0.22717
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2075 - accuracy: 0.7944 - val_loss: 0.2560 - val_accuracy: 0.7222
# Epoch 35/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.2041 - accuracy: 0.7979
# Epoch 00035: val_loss did not improve from 0.22717
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2030 - accuracy: 0.7997 - val_loss: 0.3279 - val_accuracy: 0.6750
# Epoch 36/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.2042 - accuracy: 0.7906
# Epoch 00036: val_loss did not improve from 0.22717
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2047 - accuracy: 0.7898 - val_loss: 0.2328 - val_accuracy: 0.7472
# Epoch 37/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.2054 - accuracy: 0.7970
# Epoch 00037: val_loss did not improve from 0.22717
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2058 - accuracy: 0.7966 - val_loss: 0.2525 - val_accuracy: 0.7139
# Epoch 38/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.1891 - accuracy: 0.8021
# Epoch 00038: val_loss improved from 0.22717 to 0.22597, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1890 - accuracy: 0.8022 - val_loss: 0.2260 - val_accuracy: 0.7556
# Epoch 39/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.1879 - accuracy: 0.8035
# Epoch 00039: val_loss improved from 0.22597 to 0.22067, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1876 - accuracy: 0.8040 - val_loss: 0.2207 - val_accuracy: 0.7417
# Epoch 40/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.1869 - accuracy: 0.8068
# Epoch 00040: val_loss improved from 0.22067 to 0.21017, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1865 - accuracy: 0.8077 - val_loss: 0.2102 - val_accuracy: 0.7556
# Epoch 41/100
# 192/203 [===========================>..] - ETA: 0s - loss: 0.1905 - accuracy: 0.8018
# Epoch 00041: val_loss improved from 0.21017 to 0.20254, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1909 - accuracy: 0.8019 - val_loss: 0.2025 - val_accuracy: 0.7778
# Epoch 42/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.1928 - accuracy: 0.8038
# Epoch 00042: val_loss did not improve from 0.20254
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1931 - accuracy: 0.8043 - val_loss: 0.2219 - val_accuracy: 0.7528
# Epoch 43/100
# 203/203 [==============================] - ETA: 0s - loss: 0.1887 - accuracy: 0.8034
# Epoch 00043: val_loss did not improve from 0.20254
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1887 - accuracy: 0.8034 - val_loss: 0.2635 - val_accuracy: 0.7250
# Epoch 44/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.1877 - accuracy: 0.8025
# Epoch 00044: val_loss did not improve from 0.20254
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1877 - accuracy: 0.8025 - val_loss: 0.2113 - val_accuracy: 0.7667
# Epoch 45/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.1828 - accuracy: 0.8075
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00045: val_loss did not improve from 0.20254
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1826 - accuracy: 0.8074 - val_loss: 0.2268 - val_accuracy: 0.7639
# Epoch 46/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.1755 - accuracy: 0.8074
# Epoch 00046: val_loss did not improve from 0.20254
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1740 - accuracy: 0.8096 - val_loss: 0.2136 - val_accuracy: 0.7583
# Epoch 47/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.1717 - accuracy: 0.8175
# Epoch 00047: val_loss did not improve from 0.20254
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1720 - accuracy: 0.8173 - val_loss: 0.2155 - val_accuracy: 0.7667
# Epoch 48/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.1654 - accuracy: 0.8234
# Epoch 00048: val_loss did not improve from 0.20254
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1664 - accuracy: 0.8225 - val_loss: 0.2122 - val_accuracy: 0.7694
# Epoch 49/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.1665 - accuracy: 0.8163
# Epoch 00049: val_loss improved from 0.20254 to 0.19444, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1648 - accuracy: 0.8185 - val_loss: 0.1944 - val_accuracy: 0.7806
# Epoch 50/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.1669 - accuracy: 0.8176
# Epoch 00050: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1659 - accuracy: 0.8182 - val_loss: 0.1992 - val_accuracy: 0.7639
# Epoch 51/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.1653 - accuracy: 0.8249
# Epoch 00051: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1654 - accuracy: 0.8250 - val_loss: 0.2032 - val_accuracy: 0.7694
# Epoch 52/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.1684 - accuracy: 0.8160
# Epoch 00052: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1684 - accuracy: 0.8157 - val_loss: 0.2056 - val_accuracy: 0.7694
# Epoch 53/100
# 196/203 [===========================>..] - ETA: 0s - loss: 0.1693 - accuracy: 0.8166
# Epoch 00053: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1687 - accuracy: 0.8170 - val_loss: 0.1972 - val_accuracy: 0.7833
# Epoch 54/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.1714 - accuracy: 0.8169
# Epoch 00054: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1714 - accuracy: 0.8173 - val_loss: 0.1978 - val_accuracy: 0.7861
# Epoch 00054: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1936 - accuracy: 0.7850
# Val Score:  [0.19359090924263, 0.7850000262260437]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.7169 - accuracy: 0.2573
# Epoch 00001: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 6ms/step - loss: 0.7147 - accuracy: 0.2580 - val_loss: 0.6286 - val_accuracy: 0.2500
# Epoch 2/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.6116 - accuracy: 0.2627
# Epoch 00002: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.6111 - accuracy: 0.2645 - val_loss: 0.5821 - val_accuracy: 0.2444
# Epoch 3/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.5817 - accuracy: 0.2974
# Epoch 00003: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5811 - accuracy: 0.2966 - val_loss: 0.5677 - val_accuracy: 0.2583
# Epoch 4/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.5741 - accuracy: 0.3147
# Epoch 00004: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5742 - accuracy: 0.3142 - val_loss: 0.5565 - val_accuracy: 0.2833
# Epoch 5/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.5644 - accuracy: 0.3240
# Epoch 00005: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5642 - accuracy: 0.3238 - val_loss: 0.6201 - val_accuracy: 0.3306
# Epoch 6/100
# 193/203 [===========================>..] - ETA: 0s - loss: 0.5463 - accuracy: 0.3679
# Epoch 00006: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5461 - accuracy: 0.3676 - val_loss: 0.5971 - val_accuracy: 0.2861
# Epoch 7/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.5268 - accuracy: 0.4053
# Epoch 00007: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5273 - accuracy: 0.4059 - val_loss: 0.5298 - val_accuracy: 0.3889
# Epoch 8/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.5090 - accuracy: 0.4442
# Epoch 00008: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5088 - accuracy: 0.4448 - val_loss: 0.5226 - val_accuracy: 0.4306
# Epoch 9/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.4814 - accuracy: 0.4742
# Epoch 00009: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.4810 - accuracy: 0.4741 - val_loss: 0.4343 - val_accuracy: 0.5500
# Epoch 10/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.4461 - accuracy: 0.5346
# Epoch 00010: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.4452 - accuracy: 0.5361 - val_loss: 0.4664 - val_accuracy: 0.4806
# Epoch 11/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.4151 - accuracy: 0.5759
# Epoch 00011: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.4154 - accuracy: 0.5750 - val_loss: 0.4061 - val_accuracy: 0.5722
# Epoch 12/100
# 193/203 [===========================>..] - ETA: 0s - loss: 0.3853 - accuracy: 0.6120
# Epoch 00012: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.3856 - accuracy: 0.6130 - val_loss: 0.4085 - val_accuracy: 0.5778
# Epoch 13/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.3527 - accuracy: 0.6571
# Epoch 00013: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.3524 - accuracy: 0.6586 - val_loss: 0.3659 - val_accuracy: 0.6111
# Epoch 14/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.3268 - accuracy: 0.6768
# Epoch 00014: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.3273 - accuracy: 0.6765 - val_loss: 0.3564 - val_accuracy: 0.6361
# Epoch 15/100
# 193/203 [===========================>..] - ETA: 0s - loss: 0.3054 - accuracy: 0.6966
# Epoch 00015: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.3040 - accuracy: 0.6991 - val_loss: 0.2913 - val_accuracy: 0.7000
# Epoch 16/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.2982 - accuracy: 0.7094
# Epoch 00016: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2984 - accuracy: 0.7090 - val_loss: 0.3001 - val_accuracy: 0.6861
# Epoch 17/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.2795 - accuracy: 0.7232
# Epoch 00017: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2801 - accuracy: 0.7222 - val_loss: 0.2938 - val_accuracy: 0.6917
# Epoch 18/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.2597 - accuracy: 0.7487
# Epoch 00018: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2608 - accuracy: 0.7469 - val_loss: 0.2297 - val_accuracy: 0.7556
# Epoch 19/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.2446 - accuracy: 0.7619
# Epoch 00019: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2447 - accuracy: 0.7614 - val_loss: 0.2878 - val_accuracy: 0.7083
# Epoch 20/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.2523 - accuracy: 0.7491
# Epoch 00020: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2528 - accuracy: 0.7478 - val_loss: 0.2874 - val_accuracy: 0.7028
# Epoch 21/100
# 203/203 [==============================] - ETA: 0s - loss: 0.2488 - accuracy: 0.7546
# Epoch 00021: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2488 - accuracy: 0.7546 - val_loss: 0.2425 - val_accuracy: 0.7583
# Epoch 22/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.2273 - accuracy: 0.7808
# Epoch 00022: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2277 - accuracy: 0.7815 - val_loss: 0.2192 - val_accuracy: 0.7639
# Epoch 23/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.2338 - accuracy: 0.7613
# Epoch 00023: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2337 - accuracy: 0.7611 - val_loss: 0.2639 - val_accuracy: 0.7306
# Epoch 24/100
# 203/203 [==============================] - ETA: 0s - loss: 0.2301 - accuracy: 0.7744
# Epoch 00024: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2301 - accuracy: 0.7744 - val_loss: 0.2252 - val_accuracy: 0.7611
# Epoch 25/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.2340 - accuracy: 0.7622
# Epoch 00025: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2353 - accuracy: 0.7605 - val_loss: 0.2183 - val_accuracy: 0.7667
# Epoch 26/100
# 193/203 [===========================>..] - ETA: 0s - loss: 0.2144 - accuracy: 0.7834
# Epoch 00026: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2144 - accuracy: 0.7833 - val_loss: 0.2222 - val_accuracy: 0.7750
# Epoch 27/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.2155 - accuracy: 0.7847
# Epoch 00027: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2146 - accuracy: 0.7858 - val_loss: 0.2591 - val_accuracy: 0.7361
# Epoch 28/100
# 192/203 [===========================>..] - ETA: 0s - loss: 0.2159 - accuracy: 0.7751
# Epoch 00028: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2177 - accuracy: 0.7747 - val_loss: 0.2876 - val_accuracy: 0.7083
# Epoch 29/100
# 196/203 [===========================>..] - ETA: 0s - loss: 0.2141 - accuracy: 0.7832
# Epoch 00029: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2138 - accuracy: 0.7830 - val_loss: 0.3847 - val_accuracy: 0.6278
# Epoch 30/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.2035 - accuracy: 0.7919
# Epoch 00030: val_loss did not improve from 0.19444
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2043 - accuracy: 0.7910 - val_loss: 0.2013 - val_accuracy: 0.7806
# Epoch 31/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.2069 - accuracy: 0.7854
# Epoch 00031: val_loss improved from 0.19444 to 0.18999, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2063 - accuracy: 0.7861 - val_loss: 0.1900 - val_accuracy: 0.7917
# Epoch 32/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.1949 - accuracy: 0.7937
# Epoch 00032: val_loss did not improve from 0.18999
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1949 - accuracy: 0.7932 - val_loss: 0.2101 - val_accuracy: 0.7750
# Epoch 33/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.1970 - accuracy: 0.7961
# Epoch 00033: val_loss improved from 0.18999 to 0.18307, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1971 - accuracy: 0.7951 - val_loss: 0.1831 - val_accuracy: 0.7889
# Epoch 34/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.1978 - accuracy: 0.7996
# Epoch 00034: val_loss improved from 0.18307 to 0.17774, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1974 - accuracy: 0.8006 - val_loss: 0.1777 - val_accuracy: 0.7889
# Epoch 35/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.1921 - accuracy: 0.7916
# Epoch 00035: val_loss did not improve from 0.17774
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1921 - accuracy: 0.7923 - val_loss: 0.2058 - val_accuracy: 0.7861
# Epoch 36/100
# 196/203 [===========================>..] - ETA: 0s - loss: 0.1936 - accuracy: 0.7966
# Epoch 00036: val_loss did not improve from 0.17774
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1942 - accuracy: 0.7963 - val_loss: 0.1899 - val_accuracy: 0.8056
# Epoch 37/100
# 196/203 [===========================>..] - ETA: 0s - loss: 0.1860 - accuracy: 0.8071
# Epoch 00037: val_loss did not improve from 0.17774
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1879 - accuracy: 0.8052 - val_loss: 0.1908 - val_accuracy: 0.7833
# Epoch 38/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.1918 - accuracy: 0.7996
# Epoch 00038: val_loss did not improve from 0.17774
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1909 - accuracy: 0.8000 - val_loss: 0.1933 - val_accuracy: 0.7889
# Epoch 39/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.1871 - accuracy: 0.8045
# Epoch 00039: val_loss did not improve from 0.17774
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1873 - accuracy: 0.8040 - val_loss: 0.1802 - val_accuracy: 0.8000
# Epoch 40/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.1805 - accuracy: 0.8061
# Epoch 00040: val_loss improved from 0.17774 to 0.17089, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1798 - accuracy: 0.8074 - val_loss: 0.1709 - val_accuracy: 0.8028
# Epoch 41/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.1861 - accuracy: 0.8041
# Epoch 00041: val_loss did not improve from 0.17089
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1864 - accuracy: 0.8037 - val_loss: 0.1977 - val_accuracy: 0.7833
# Epoch 42/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.1877 - accuracy: 0.8019
# Epoch 00042: val_loss improved from 0.17089 to 0.16571, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1883 - accuracy: 0.8019 - val_loss: 0.1657 - val_accuracy: 0.8194
# Epoch 43/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.1806 - accuracy: 0.8091
# Epoch 00043: val_loss did not improve from 0.16571
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1805 - accuracy: 0.8093 - val_loss: 0.1810 - val_accuracy: 0.7972
# Epoch 44/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.1842 - accuracy: 0.8027
# Epoch 00044: val_loss did not improve from 0.16571
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1841 - accuracy: 0.8025 - val_loss: 0.1758 - val_accuracy: 0.8083
# Epoch 45/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.1760 - accuracy: 0.8065
# Epoch 00045: val_loss did not improve from 0.16571
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1770 - accuracy: 0.8071 - val_loss: 0.1696 - val_accuracy: 0.8111
# Epoch 46/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.1874 - accuracy: 0.8055
# Epoch 00046: val_loss did not improve from 0.16571
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1869 - accuracy: 0.8062 - val_loss: 0.1740 - val_accuracy: 0.8083
# Epoch 47/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.1855 - accuracy: 0.8018
# Epoch 00047: val_loss did not improve from 0.16571
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1852 - accuracy: 0.8022 - val_loss: 0.1987 - val_accuracy: 0.7833
# Epoch 48/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.1735 - accuracy: 0.8069
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00048: val_loss improved from 0.16571 to 0.16470, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1728 - accuracy: 0.8080 - val_loss: 0.1647 - val_accuracy: 0.8250
# Epoch 49/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.1659 - accuracy: 0.8215
# Epoch 00049: val_loss improved from 0.16470 to 0.15138, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1665 - accuracy: 0.8210 - val_loss: 0.1514 - val_accuracy: 0.8222
# Epoch 50/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.1597 - accuracy: 0.8215
# Epoch 00050: val_loss improved from 0.15138 to 0.15028, saving model to fas_mnist_1.h5
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1595 - accuracy: 0.8219 - val_loss: 0.1503 - val_accuracy: 0.8250
# Epoch 51/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.1597 - accuracy: 0.8240
# Epoch 00051: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1600 - accuracy: 0.8235 - val_loss: 0.1530 - val_accuracy: 0.8139
# Epoch 52/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.1635 - accuracy: 0.8209
# Epoch 00052: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1624 - accuracy: 0.8222 - val_loss: 0.1534 - val_accuracy: 0.8139
# Epoch 53/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.1561 - accuracy: 0.8324
# Epoch 00053: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1571 - accuracy: 0.8318 - val_loss: 0.1613 - val_accuracy: 0.8083
# Epoch 54/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.1592 - accuracy: 0.8160
# Epoch 00054: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1608 - accuracy: 0.8154 - val_loss: 0.1639 - val_accuracy: 0.8083
# Epoch 55/100
# 196/203 [===========================>..] - ETA: 0s - loss: 0.1685 - accuracy: 0.8170
# Epoch 00055: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1680 - accuracy: 0.8173 - val_loss: 0.1533 - val_accuracy: 0.8250
# Epoch 56/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.1576 - accuracy: 0.8306
# Epoch 00056: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1586 - accuracy: 0.8296 - val_loss: 0.1522 - val_accuracy: 0.8194
# Epoch 57/100
# 203/203 [==============================] - ETA: 0s - loss: 0.1628 - accuracy: 0.8176
# Epoch 00057: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1628 - accuracy: 0.8176 - val_loss: 0.1555 - val_accuracy: 0.8194
# Epoch 58/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.1634 - accuracy: 0.8172
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00058: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1642 - accuracy: 0.8164 - val_loss: 0.1540 - val_accuracy: 0.8278
# Epoch 00058: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1965 - accuracy: 0.7875
# Val Score:  [0.1964535117149353, 0.7875000238418579]
# ====================================================================================
#
#
# Training on Fold:  3
# Epoch 1/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.7179 - accuracy: 0.2599
# Epoch 00001: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.7151 - accuracy: 0.2586 - val_loss: 0.5931 - val_accuracy: 0.2194
# Epoch 2/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.6097 - accuracy: 0.2610
# Epoch 00002: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.6096 - accuracy: 0.2614 - val_loss: 0.5688 - val_accuracy: 0.2250
# Epoch 3/100
# 203/203 [==============================] - ETA: 0s - loss: 0.5847 - accuracy: 0.2642
# Epoch 00003: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5847 - accuracy: 0.2642 - val_loss: 0.5651 - val_accuracy: 0.2500
# Epoch 4/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.5786 - accuracy: 0.2849
# Epoch 00004: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5784 - accuracy: 0.2855 - val_loss: 0.5504 - val_accuracy: 0.3250
# Epoch 5/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.5620 - accuracy: 0.3218
# Epoch 00005: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5620 - accuracy: 0.3225 - val_loss: 0.5425 - val_accuracy: 0.3889
# Epoch 6/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.5565 - accuracy: 0.3261
# Epoch 00006: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5561 - accuracy: 0.3269 - val_loss: 0.5309 - val_accuracy: 0.3972
# Epoch 7/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.5440 - accuracy: 0.3607
# Epoch 00007: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5442 - accuracy: 0.3596 - val_loss: 0.5403 - val_accuracy: 0.3861
# Epoch 8/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.5299 - accuracy: 0.3854
# Epoch 00008: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5300 - accuracy: 0.3855 - val_loss: 0.5305 - val_accuracy: 0.3472
# Epoch 9/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.5075 - accuracy: 0.4356
# Epoch 00009: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5077 - accuracy: 0.4349 - val_loss: 0.5366 - val_accuracy: 0.3389
# Epoch 10/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.4980 - accuracy: 0.4574
# Epoch 00010: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.4977 - accuracy: 0.4583 - val_loss: 0.4938 - val_accuracy: 0.4472
# Epoch 11/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.4669 - accuracy: 0.4929
# Epoch 00011: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.4669 - accuracy: 0.4926 - val_loss: 0.4780 - val_accuracy: 0.4500
# Epoch 12/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.4339 - accuracy: 0.5463
# Epoch 00012: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.4343 - accuracy: 0.5466 - val_loss: 0.4625 - val_accuracy: 0.5361
# Epoch 13/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.4105 - accuracy: 0.5831
# Epoch 00013: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.4105 - accuracy: 0.5833 - val_loss: 0.5334 - val_accuracy: 0.4194
# Epoch 14/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.3805 - accuracy: 0.6176
# Epoch 00014: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.3824 - accuracy: 0.6142 - val_loss: 0.4587 - val_accuracy: 0.5139
# Epoch 15/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.3530 - accuracy: 0.6372
# Epoch 00015: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.3518 - accuracy: 0.6380 - val_loss: 0.3285 - val_accuracy: 0.6556
# Epoch 16/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.3270 - accuracy: 0.6786
# Epoch 00016: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.3285 - accuracy: 0.6753 - val_loss: 0.3377 - val_accuracy: 0.6056
# Epoch 17/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.3011 - accuracy: 0.6972
# Epoch 00017: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.3010 - accuracy: 0.6966 - val_loss: 0.3258 - val_accuracy: 0.6528
# Epoch 18/100
# 203/203 [==============================] - ETA: 0s - loss: 0.2904 - accuracy: 0.7019
# Epoch 00018: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2904 - accuracy: 0.7019 - val_loss: 0.2944 - val_accuracy: 0.6972
# Epoch 19/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.2792 - accuracy: 0.7176
# Epoch 00019: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2792 - accuracy: 0.7188 - val_loss: 0.2750 - val_accuracy: 0.7333
# Epoch 20/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.2613 - accuracy: 0.7324
# Epoch 00020: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2615 - accuracy: 0.7324 - val_loss: 0.2414 - val_accuracy: 0.7722
# Epoch 21/100
# 193/203 [===========================>..] - ETA: 0s - loss: 0.2521 - accuracy: 0.7409
# Epoch 00021: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2524 - accuracy: 0.7414 - val_loss: 0.2571 - val_accuracy: 0.7444
# Epoch 22/100
# 193/203 [===========================>..] - ETA: 0s - loss: 0.2543 - accuracy: 0.7358
# Epoch 00022: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2533 - accuracy: 0.7373 - val_loss: 0.2341 - val_accuracy: 0.7361
# Epoch 23/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.2495 - accuracy: 0.7487
# Epoch 00023: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2528 - accuracy: 0.7469 - val_loss: 0.2424 - val_accuracy: 0.7361
# Epoch 24/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.2401 - accuracy: 0.7578
# Epoch 00024: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2401 - accuracy: 0.7577 - val_loss: 0.2575 - val_accuracy: 0.7278
# Epoch 25/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.2380 - accuracy: 0.7535
# Epoch 00025: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2388 - accuracy: 0.7512 - val_loss: 0.2807 - val_accuracy: 0.7083
# Epoch 26/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.2231 - accuracy: 0.7699
# Epoch 00026: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2248 - accuracy: 0.7673 - val_loss: 0.1949 - val_accuracy: 0.8000
# Epoch 27/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.2198 - accuracy: 0.7763
# Epoch 00027: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2201 - accuracy: 0.7762 - val_loss: 0.1929 - val_accuracy: 0.7917
# Epoch 28/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.2135 - accuracy: 0.7797
# Epoch 00028: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2137 - accuracy: 0.7802 - val_loss: 0.2412 - val_accuracy: 0.7611
# Epoch 29/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.2164 - accuracy: 0.7774
# Epoch 00029: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2177 - accuracy: 0.7769 - val_loss: 0.2657 - val_accuracy: 0.7417
# Epoch 30/100
# 196/203 [===========================>..] - ETA: 0s - loss: 0.2129 - accuracy: 0.7765
# Epoch 00030: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2121 - accuracy: 0.7775 - val_loss: 0.2289 - val_accuracy: 0.7500
# Epoch 31/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.2019 - accuracy: 0.7928
# Epoch 00031: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2017 - accuracy: 0.7929 - val_loss: 0.1888 - val_accuracy: 0.7944
# Epoch 32/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.2020 - accuracy: 0.7966
# Epoch 00032: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2029 - accuracy: 0.7957 - val_loss: 0.1944 - val_accuracy: 0.7972
# Epoch 33/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.2018 - accuracy: 0.7948
# Epoch 00033: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2007 - accuracy: 0.7960 - val_loss: 0.1740 - val_accuracy: 0.8333
# Epoch 34/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.1964 - accuracy: 0.7987
# Epoch 00034: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1978 - accuracy: 0.7978 - val_loss: 0.2014 - val_accuracy: 0.7917
# Epoch 35/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.2115 - accuracy: 0.7881
# Epoch 00035: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2119 - accuracy: 0.7873 - val_loss: 0.1847 - val_accuracy: 0.8000
# Epoch 36/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.1962 - accuracy: 0.7907
# Epoch 00036: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1979 - accuracy: 0.7886 - val_loss: 0.1902 - val_accuracy: 0.7944
# Epoch 37/100
# 193/203 [===========================>..] - ETA: 0s - loss: 0.1882 - accuracy: 0.8076
# Epoch 00037: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1886 - accuracy: 0.8077 - val_loss: 0.1917 - val_accuracy: 0.7806
# Epoch 38/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.1828 - accuracy: 0.8128
# Epoch 00038: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1837 - accuracy: 0.8117 - val_loss: 0.1842 - val_accuracy: 0.8028
# Epoch 39/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.1896 - accuracy: 0.7939
# Epoch 00039: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1904 - accuracy: 0.7935 - val_loss: 0.2017 - val_accuracy: 0.7833
# Epoch 40/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.1879 - accuracy: 0.8035
# Epoch 00040: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1881 - accuracy: 0.8031 - val_loss: 0.1768 - val_accuracy: 0.8222
# Epoch 41/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.1805 - accuracy: 0.8081
# Epoch 00041: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1806 - accuracy: 0.8080 - val_loss: 0.1922 - val_accuracy: 0.8000
# Epoch 42/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.1887 - accuracy: 0.8071
# Epoch 00042: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1887 - accuracy: 0.8065 - val_loss: 0.1847 - val_accuracy: 0.8028
# Epoch 43/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.1876 - accuracy: 0.8057
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00043: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1877 - accuracy: 0.8059 - val_loss: 0.1762 - val_accuracy: 0.7944
# Epoch 44/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.1700 - accuracy: 0.8160
# Epoch 00044: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1703 - accuracy: 0.8164 - val_loss: 0.1610 - val_accuracy: 0.8333
# Epoch 45/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.1673 - accuracy: 0.8221
# Epoch 00045: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1680 - accuracy: 0.8207 - val_loss: 0.1648 - val_accuracy: 0.8000
# Epoch 46/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.1688 - accuracy: 0.8163
# Epoch 00046: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1682 - accuracy: 0.8170 - val_loss: 0.1730 - val_accuracy: 0.8083
# Epoch 47/100
# 203/203 [==============================] - ETA: 0s - loss: 0.1670 - accuracy: 0.8228
# Epoch 00047: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1670 - accuracy: 0.8228 - val_loss: 0.1648 - val_accuracy: 0.8278
# Epoch 48/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.1658 - accuracy: 0.8229
# Epoch 00048: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1653 - accuracy: 0.8241 - val_loss: 0.1638 - val_accuracy: 0.7972
# Epoch 49/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.1678 - accuracy: 0.8150
# Epoch 00049: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1678 - accuracy: 0.8151 - val_loss: 0.1618 - val_accuracy: 0.8278
# Epoch 50/100
# 203/203 [==============================] - ETA: 0s - loss: 0.1660 - accuracy: 0.8244
# Epoch 00050: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1660 - accuracy: 0.8244 - val_loss: 0.1762 - val_accuracy: 0.8139
# Epoch 51/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.1646 - accuracy: 0.8268
# Epoch 00051: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1650 - accuracy: 0.8262 - val_loss: 0.1954 - val_accuracy: 0.7972
# Epoch 52/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.1655 - accuracy: 0.8274
# Epoch 00052: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1673 - accuracy: 0.8250 - val_loss: 0.1789 - val_accuracy: 0.8111
# Epoch 53/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.1635 - accuracy: 0.8157
# Epoch 00053: val_loss did not improve from 0.15028
# ...
# Epoch 00044: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1806 - accuracy: 0.8136 - val_loss: 0.1818 - val_accuracy: 0.7861
# Epoch 45/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.1680 - accuracy: 0.8244
# Epoch 00045: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1698 - accuracy: 0.8213 - val_loss: 0.2202 - val_accuracy: 0.7667
# Epoch 46/100
# 196/203 [===========================>..] - ETA: 0s - loss: 0.1707 - accuracy: 0.8151
# Epoch 00046: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1709 - accuracy: 0.8145 - val_loss: 0.1771 - val_accuracy: 0.8000
# Epoch 47/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.1851 - accuracy: 0.8088
# Epoch 00047: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1851 - accuracy: 0.8090 - val_loss: 0.1832 - val_accuracy: 0.8000
# Epoch 48/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.1750 - accuracy: 0.8169
# Epoch 00048: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1759 - accuracy: 0.8160 - val_loss: 0.1907 - val_accuracy: 0.7889
# Epoch 49/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.1708 - accuracy: 0.8176
# Epoch 00049: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1722 - accuracy: 0.8164 - val_loss: 0.1849 - val_accuracy: 0.7944
# Epoch 50/100
# 202/203 [============================>.] - ETA: 0s - loss: 0.1762 - accuracy: 0.8082
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00050: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1759 - accuracy: 0.8086 - val_loss: 0.1698 - val_accuracy: 0.8000
# Epoch 00050: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1881 - accuracy: 0.7875
# Val Score:  [0.18812350928783417, 0.7875000238418579]
# ====================================================================================
#
#
# Training on Fold:  5
# Epoch 1/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.7099 - accuracy: 0.2649
# Epoch 00001: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.7080 - accuracy: 0.2657 - val_loss: 0.6318 - val_accuracy: 0.2333
# Epoch 2/100
# 203/203 [==============================] - ETA: 0s - loss: 0.6084 - accuracy: 0.2636
# Epoch 00002: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.6084 - accuracy: 0.2636 - val_loss: 0.5909 - val_accuracy: 0.2389
# Epoch 3/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.5872 - accuracy: 0.2624
# Epoch 00003: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5873 - accuracy: 0.2620 - val_loss: 0.5692 - val_accuracy: 0.2556
# Epoch 4/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.5747 - accuracy: 0.2891
# Epoch 00004: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5748 - accuracy: 0.2870 - val_loss: 0.5717 - val_accuracy: 0.2444
# Epoch 5/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.5602 - accuracy: 0.3326
# Epoch 00005: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.5602 - accuracy: 0.3327 - val_loss: 0.5728 - val_accuracy: 0.2528
# Epoch 6/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.5490 - accuracy: 0.3452
# Epoch 00006: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5490 - accuracy: 0.3435 - val_loss: 0.5428 - val_accuracy: 0.3583
# Epoch 7/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.5341 - accuracy: 0.3872
# Epoch 00007: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.5344 - accuracy: 0.3858 - val_loss: 0.5596 - val_accuracy: 0.3278
# Epoch 8/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.5209 - accuracy: 0.4045
# Epoch 00008: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.5212 - accuracy: 0.4049 - val_loss: 0.5217 - val_accuracy: 0.4056
# Epoch 9/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.5159 - accuracy: 0.4186
# Epoch 00009: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.5153 - accuracy: 0.4188 - val_loss: 0.5640 - val_accuracy: 0.3250
# Epoch 10/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.4988 - accuracy: 0.4501
# Epoch 00010: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.4990 - accuracy: 0.4491 - val_loss: 0.5728 - val_accuracy: 0.3389
# Epoch 11/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.4726 - accuracy: 0.5038
# Epoch 00011: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.4720 - accuracy: 0.5040 - val_loss: 0.4831 - val_accuracy: 0.4167
# Epoch 12/100
# 193/203 [===========================>..] - ETA: 0s - loss: 0.4502 - accuracy: 0.5201
# Epoch 00012: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.4492 - accuracy: 0.5228 - val_loss: 0.4761 - val_accuracy: 0.4833
# Epoch 13/100
# 196/203 [===========================>..] - ETA: 0s - loss: 0.4460 - accuracy: 0.5325
# Epoch 00013: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.4438 - accuracy: 0.5364 - val_loss: 0.4368 - val_accuracy: 0.5556
# Epoch 14/100
# 203/203 [==============================] - ETA: 0s - loss: 0.4025 - accuracy: 0.5846
# Epoch 00014: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.4025 - accuracy: 0.5846 - val_loss: 0.4818 - val_accuracy: 0.4528
# Epoch 15/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.3850 - accuracy: 0.6118
# Epoch 00015: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.3849 - accuracy: 0.6093 - val_loss: 0.3966 - val_accuracy: 0.5917
# Epoch 16/100
# 203/203 [==============================] - ETA: 0s - loss: 0.3565 - accuracy: 0.6407
# Epoch 00016: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.3565 - accuracy: 0.6407 - val_loss: 0.3338 - val_accuracy: 0.6611
# Epoch 17/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.3321 - accuracy: 0.6753
# Epoch 00017: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.3322 - accuracy: 0.6747 - val_loss: 0.3980 - val_accuracy: 0.5583
# Epoch 18/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.3148 - accuracy: 0.6807
# Epoch 00018: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.3141 - accuracy: 0.6802 - val_loss: 0.3257 - val_accuracy: 0.6639
# Epoch 19/100
# 193/203 [===========================>..] - ETA: 0s - loss: 0.2927 - accuracy: 0.7192
# Epoch 00019: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2933 - accuracy: 0.7182 - val_loss: 0.3174 - val_accuracy: 0.6417
# Epoch 20/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.2818 - accuracy: 0.7229
# Epoch 00020: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2841 - accuracy: 0.7216 - val_loss: 0.4651 - val_accuracy: 0.5194
# Epoch 21/100
# 193/203 [===========================>..] - ETA: 0s - loss: 0.2742 - accuracy: 0.7280
# Epoch 00021: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2728 - accuracy: 0.7306 - val_loss: 0.2930 - val_accuracy: 0.6833
# Epoch 22/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.2671 - accuracy: 0.7423
# Epoch 00022: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2659 - accuracy: 0.7435 - val_loss: 0.2704 - val_accuracy: 0.7028
# Epoch 23/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.2554 - accuracy: 0.7472
# Epoch 00023: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2551 - accuracy: 0.7478 - val_loss: 0.3035 - val_accuracy: 0.7139
# Epoch 24/100
# 203/203 [==============================] - ETA: 0s - loss: 0.2450 - accuracy: 0.7522
# Epoch 00024: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2450 - accuracy: 0.7522 - val_loss: 0.3038 - val_accuracy: 0.6722
# Epoch 25/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.2388 - accuracy: 0.7613
# Epoch 00025: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2378 - accuracy: 0.7627 - val_loss: 0.2569 - val_accuracy: 0.7333
# Epoch 26/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.2303 - accuracy: 0.7713
# Epoch 00026: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2312 - accuracy: 0.7701 - val_loss: 0.2750 - val_accuracy: 0.7222
# Epoch 27/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.2282 - accuracy: 0.7685
# Epoch 00027: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2278 - accuracy: 0.7694 - val_loss: 0.3027 - val_accuracy: 0.6806
# Epoch 28/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.2213 - accuracy: 0.7866
# Epoch 00028: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2210 - accuracy: 0.7870 - val_loss: 0.3808 - val_accuracy: 0.6000
# Epoch 29/100
# 203/203 [==============================] - ETA: 0s - loss: 0.2194 - accuracy: 0.7753
# Epoch 00029: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2194 - accuracy: 0.7753 - val_loss: 0.2459 - val_accuracy: 0.7389
# Epoch 30/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.2192 - accuracy: 0.7837
# Epoch 00030: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2201 - accuracy: 0.7824 - val_loss: 0.2392 - val_accuracy: 0.7556
# Epoch 31/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.2210 - accuracy: 0.7764
# Epoch 00031: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.2194 - accuracy: 0.7806 - val_loss: 0.2807 - val_accuracy: 0.6722
# Epoch 32/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.2018 - accuracy: 0.7955
# Epoch 00032: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2030 - accuracy: 0.7932 - val_loss: 0.2330 - val_accuracy: 0.7389
# Epoch 33/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.2003 - accuracy: 0.7980
# Epoch 00033: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2014 - accuracy: 0.7960 - val_loss: 0.2297 - val_accuracy: 0.7500
# Epoch 34/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.2071 - accuracy: 0.7886
# Epoch 00034: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2072 - accuracy: 0.7886 - val_loss: 0.2061 - val_accuracy: 0.7833
# Epoch 35/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.2000 - accuracy: 0.7998
# Epoch 00035: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1994 - accuracy: 0.7997 - val_loss: 0.2181 - val_accuracy: 0.7583
# Epoch 36/100
# 198/203 [============================>.] - ETA: 0s - loss: 0.1998 - accuracy: 0.7939
# Epoch 00036: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2008 - accuracy: 0.7929 - val_loss: 0.2223 - val_accuracy: 0.7556
# Epoch 37/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.1933 - accuracy: 0.7928
# Epoch 00037: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1936 - accuracy: 0.7917 - val_loss: 0.2089 - val_accuracy: 0.7694
# Epoch 38/100
# 201/203 [============================>.] - ETA: 0s - loss: 0.1841 - accuracy: 0.8044
# Epoch 00038: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1845 - accuracy: 0.8043 - val_loss: 0.2306 - val_accuracy: 0.7500
# Epoch 39/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.1851 - accuracy: 0.8163
# Epoch 00039: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1844 - accuracy: 0.8173 - val_loss: 0.2245 - val_accuracy: 0.7611
# Epoch 40/100
# 197/203 [============================>.] - ETA: 0s - loss: 0.1900 - accuracy: 0.8087
# Epoch 00040: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1920 - accuracy: 0.8068 - val_loss: 0.2665 - val_accuracy: 0.7056
# Epoch 41/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.1835 - accuracy: 0.8134
# Epoch 00041: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1827 - accuracy: 0.8142 - val_loss: 0.2123 - val_accuracy: 0.7694
# Epoch 42/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.1826 - accuracy: 0.8154
# Epoch 00042: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1812 - accuracy: 0.8179 - val_loss: 0.2068 - val_accuracy: 0.7722
# Epoch 43/100
# 194/203 [===========================>..] - ETA: 0s - loss: 0.1761 - accuracy: 0.8218
# Epoch 00043: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1760 - accuracy: 0.8216 - val_loss: 0.1986 - val_accuracy: 0.7833
# Epoch 44/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.1804 - accuracy: 0.8112
# Epoch 00044: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 6ms/step - loss: 0.1809 - accuracy: 0.8105 - val_loss: 0.2972 - val_accuracy: 0.6944
# Epoch 45/100
# 195/203 [===========================>..] - ETA: 0s - loss: 0.1868 - accuracy: 0.8032
# Epoch 00045: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1879 - accuracy: 0.8025 - val_loss: 0.2160 - val_accuracy: 0.7722
# Epoch 46/100
# 199/203 [============================>.] - ETA: 0s - loss: 0.2035 - accuracy: 0.7905
# Epoch 00046: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.2030 - accuracy: 0.7914 - val_loss: 0.2021 - val_accuracy: 0.7861
# Epoch 47/100
# 200/203 [============================>.] - ETA: 0s - loss: 0.1837 - accuracy: 0.8031
# Epoch 00047: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1838 - accuracy: 0.8028 - val_loss: 0.2112 - val_accuracy: 0.7778
# Epoch 48/100
# 203/203 [==============================] - ETA: 0s - loss: 0.1902 - accuracy: 0.8056
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00048: val_loss did not improve from 0.15028
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1902 - accuracy: 0.8056 - val_loss: 0.2072 - val_accuracy: 0.7667
# Epoch 00048: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1992 - accuracy: 0.7850
# Val Score:  [0.19921031594276428, 0.7850000262260437]
# ====================================================================================

# %%
#Load the model that was saved by ModelCheckpoint
model = load_model('fas_mnist_1.h5')

# %%
#model.evaluate(test_X, test_y)
print("Accuracy of the model is - " , model.evaluate(test_X,test_y)[1]*100 , "%")
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1423 - accuracy: 0.8320
# Accuracy of the model is -  83.20000171661377 %

# %%
fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)
#ax1.title('Accuracies vs Epochs')
ax1.plot(model_history[0].history['accuracy'], label='Training Fold 1')
ax1.plot(model_history[1].history['accuracy'], label='Training Fold 2')
ax1.plot(model_history[2].history['accuracy'], label='Training Fold 3')
ax1.plot(model_history[3].history['accuracy'], label='Training Fold 4')
ax1.plot(model_history[4].history['accuracy'], label='Training Fold 5')
ax1.legend()
ax2.plot(model_history[1].history['loss'], label='Training Fold 1')
ax2.plot(model_history[1].history['loss'], label='Training Fold 2')
ax2.plot(model_history[2].history['loss'], label='Training Fold 3')
ax2.plot(model_history[3].history['loss'], label='Training Fold 4')
ax2.plot(model_history[4].history['loss'], label='Training Fold 5')
ax2.legend()
plt.show()

# %%
plt.title('Train Accuracy vs Val Accuracy')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='orange', linestyle = "dashdot")
plt.legend()
plt.show()
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='orange', linestyle = "dashdot")
plt.legend()
plt.show()
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='orange', linestyle = "dashdot")
plt.legend()
plt.show()
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='orange', linestyle = "dashdot")
plt.legend()
plt.show()
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='brown', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='orange', linestyle = "dashdot")

plt.legend()
plt.show()

# %%
MODEL_NAME ='/content/fas_mnist_1.h5' 
CLIP = True  # if your model was trained with np.clip to clip  values
CLIP_VAL = 10  # if above, what was the value +/-

model = tf.keras.models.load_model(MODEL_NAME)

VALDIR = "/content/drive/MyDrive/Colab Notebooks/tes_data"
ACTIONS =  ["idle","maju","kiri", "kanan"]
PRED_BATCH = 16


def get_val_data(valdir, action, batch_size):

    argmax_dict = {0: 0, 1: 0, 2: 0,3:0}
    raw_pred_dict = {0: 0, 1: 0, 2: 0,3:0}

    action_dir = os.path.join(valdir, action)
    for session_file in os.listdir(action_dir):
        filepath = os.path.join(action_dir,session_file)
        if CLIP:
            data = np.clip(np.load(filepath), -CLIP_VAL, CLIP_VAL) / CLIP_VAL
        else:
            data = np.load(filepath) 
        preds = model.predict([data.reshape(-1, 16, 60,1)], batch_size=batch_size)

        for pred in preds:
            argmax = np.argmax(pred)
            argmax_dict[argmax] += 1
            for idx,value in enumerate(pred):
                raw_pred_dict[idx] += value

    argmax_pct_dict = {}
    for i in argmax_dict:
        total = 0
        correct = argmax_dict[i]
        for ii in argmax_dict:
            total += argmax_dict[ii]
        argmax_pct_dict[i] = round(correct/total, 4)
    return argmax_dict, raw_pred_dict, argmax_pct_dict


def make_conf_mat(none,left,forward,  right):
    action_dict = {"idle":none,"maju": forward, "kiri": left, "kanan": right}
    action_conf_mat = pd.DataFrame(action_dict)
    actions = [i for i in action_dict]

    fig = plt.figure(figsize=(15, 6))
   
    ax = fig.add_subplot(111)
    
    ax.matshow(action_conf_mat, cmap=plt.cm.RdYlGn)
    ax.set_xticklabels([""]+actions)
    ax.set_yticklabels([""]+actions)

    #print("__________")
    #print(action_dict)
    for idx, i in enumerate(action_dict):
        #print('tf',i)
        for idx2, ii in enumerate(action_dict[i]):
            #print(i, ii)
            #print(action_dict[i][ii])
            ax.text(idx, idx2, f"{round(float(action_dict[i][ii]),2)}", va='center', ha='center')
    # Rotate the tick labels and set their alignment.
    
    plt.title("Matrik data")
    plt.ylabel("Predicted Action")
    fig.tight_layout()
    plt.show()


left_argmax_dict, left_raw_pred_dict, left_argmax_pct_dict = get_val_data(VALDIR, "kiri", PRED_BATCH)
forward_argmax_dict, forward_raw_pred_dict, forward_argmax_pct_dict = get_val_data(VALDIR, "maju", PRED_BATCH)
none_argmax_dict, none_raw_pred_dict, none_argmax_pct_dict = get_val_data(VALDIR, "idle", PRED_BATCH)
right_argmax_dict, right_raw_pred_dict, right_argmax_pct_dict = get_val_data(VALDIR, "kanan", PRED_BATCH)
make_conf_mat(none_argmax_pct_dict,forward_argmax_pct_dict, left_argmax_pct_dict, right_argmax_pct_dict)

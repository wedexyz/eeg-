# %% [markdown]
# <a href="https://colab.research.google.com/github/wedexyz/eeg-/blob/main/CNN%2BReduceLe%2BCrossVall.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.18.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (0.17.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.4.1)

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM, BatchNormalization, Conv2D, Flatten, MaxPooling2D, Dropout
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.optimizers import Adam
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (20,7)
import pandas as pd
import os
import random
import time
import os
from keras.callbacks import ModelCheckpoint, EarlyStopping
#from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator

# %%
idle = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/idle/1604315006.npy")
kanan = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kanan/1604315180.npy")
kiri = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kiri/1604315126.npy")
maju = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/maju/1604315069.npy")

fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('idle')
ax1.plot(idle[0][16])
ax2.plot(idle[175])

fig, (ax3, ax4) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('kanan')
ax3.plot(kanan[0][16])
ax4.plot(kanan[175])

fig, (ax5, ax6) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('kiri')
ax5.plot(kiri[0][16])
ax6.plot(kiri[175])

fig, (ax7, ax8) =  plt.subplots( ncols=2, sharex=True)
fig.suptitle('maju')
ax7.plot(maju[0][16])
ax8.plot(maju[175])



plt.show()

# %%
ACTIONS = ["kiri", "maju","idle","kanan"]
reshape = (-1,16, 60,1)
#reshape(-1,28,28,1)

# %%
def create_data(starting_dir="=/content/drive/My Drive/Colab Notebooks/data_baru"):
    training_data = {}
    for action in ACTIONS:
        if action not in training_data:
            training_data[action] = []
        data_dir = os.path.join(starting_dir,action)
        for item in os.listdir(data_dir):
            data = np.load(os.path.join(data_dir, item))
            for item in data:
                training_data[action].append(item)

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)

    for action in ACTIONS:
        np.random.shuffle(training_data[action])  
        training_data[action] = training_data[action][:min(lengths)]

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)
    combined_data = []
    for action in ACTIONS:
        for data in training_data[action]:
            if action == "kiri":
                combined_data.append([data, [1, 0, 0,0]])
            elif action == "maju":
                combined_data.append([data, [0, 1, 0, 0]])
            elif action == "idle":
                combined_data.append([data, [0, 0, 1, 0]])
            elif action == "kanan":
                combined_data.append([data, [0, 0, 0, 1]])

    np.random.shuffle(combined_data)
    print("length:",len(combined_data))
    return combined_data

# %%
print("creating training data")
traindata = create_data(starting_dir="/content/drive/My Drive/Colab Notebooks/data_baru")
train_X = []
train_y = []
for X, y in traindata:
    train_X.append(X)
    train_y.append(y)
# Out:
# creating training data
# [1000, 1000, 1000, 1000]
# [1000, 1000, 1000, 1000]
# length: 4000

# %%
print("creating testing data")
testdata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/tes_data")
test_X = []
test_y = []

for X, y in testdata:
    test_X.append(X)
    test_y.append(y)
train_X = np.array(train_X).reshape(reshape)
test_X = np.array(test_X).reshape(reshape)

train_y = np.array(train_y)
test_y = np.array(test_y)
# Out:
# creating testing data
# [250, 250, 250, 250]
# [250, 250, 250, 250]
# length: 1000

# %%
f, ax = plt.subplots(2,4) 
f.set_size_inches(10, 10)
k = 0
for i in range(2):
    for j in range(4):
       # ax[i,j].imshow(train_X [k].reshape(28, 28) , cmap = "gray")
        ax[i,j].imshow(train_X [k].reshape(16,60)  ,cmap = "gray")
        k += 1
    plt.tight_layout()

# %%
IMAGE_SIZE = (16, 60, 1)

# %%
# With data augmentation to prevent overfitting

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(train_X)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1,factor=0.5, min_lr=0.0001)

# %%
def cnn_model(size, num_cnn_layers):
    

    model = Sequential()
    
    model.add(Conv2D(filters = 64, kernel_size = (7,7), padding = "same", activation = "relu", input_shape=train_X.shape[1:]))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Conv2D(filters = 64, kernel_size = (5,5), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (5,5)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Conv2D(filters = 64, kernel_size = (3,3), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (3,3)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Flatten())
    
    model.add(Dense(32, activation = "relu"))
    model.add(BatchNormalization())

    model.add(Dense(4, activation = "sigmoid"))
   
    #adam = Adam(lr = 0.001)
    model.compile(optimizer ="adam", loss = "binary_crossentropy", metrics = ['accuracy'])
    #model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
 
    
    return model

# %%
model = cnn_model(IMAGE_SIZE, 2)
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_33 (Conv2D)           (None, 16, 60, 64)        3200
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 16, 60, 64)        256
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 16, 60, 64)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 16, 60, 64)        102464
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 3, 12, 64)         0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 3, 12, 64)         0
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 3, 12, 64)         256
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 3, 12, 64)         36928
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 1, 4, 64)          0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 1, 4, 64)          0
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 1, 4, 64)          256
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 32)                8224
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 32)                128
# _________________________________________________________________
# dense_23 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 151,844
# Trainable params: 151,396
# Non-trainable params: 448
# _________________________________________________________________

# %%
#set early stopping criteria
pat = 5
#this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='loss', patience=pat, verbose=1)

#define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('fas_mnist_1.h5', verbose=1, save_best_only=True)

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=100, BATCH_SIZE=32):
    model = None
    model = cnn_model(IMAGE_SIZE, 2)
    #Model = model
   # results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[early_stopping, model_checkpoint], 
   #           verbose=1, validation_split=0.1) 
    results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[learning_rate_reduction,early_stopping, model_checkpoint], 
              verbose=1, validation_split=0.1)   
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs=100
batch_size=32

#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(train_X, train_y, test_size=0.1, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
   
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.7121 - accuracy: 0.2608
# Epoch 00001: val_loss improved from inf to 0.65264, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 9ms/step - loss: 0.7103 - accuracy: 0.2596 - val_loss: 0.6526 - val_accuracy: 0.2333
# Epoch 2/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.6190 - accuracy: 0.2733
# Epoch 00002: val_loss improved from 0.65264 to 0.59981, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.6183 - accuracy: 0.2728 - val_loss: 0.5998 - val_accuracy: 0.2333
# Epoch 3/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.5770 - accuracy: 0.2967
# Epoch 00003: val_loss improved from 0.59981 to 0.57492, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5768 - accuracy: 0.2948 - val_loss: 0.5749 - val_accuracy: 0.2333
# Epoch 4/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.5628 - accuracy: 0.3028
# Epoch 00004: val_loss improved from 0.57492 to 0.56796, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5631 - accuracy: 0.3028 - val_loss: 0.5680 - val_accuracy: 0.2333
# Epoch 5/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.5565 - accuracy: 0.3183
# Epoch 00005: val_loss did not improve from 0.56796
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5568 - accuracy: 0.3198 - val_loss: 0.5713 - val_accuracy: 0.2417
# Epoch 6/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.5474 - accuracy: 0.3357
# Epoch 00006: val_loss improved from 0.56796 to 0.56457, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5472 - accuracy: 0.3380 - val_loss: 0.5646 - val_accuracy: 0.2639
# Epoch 7/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.5388 - accuracy: 0.3657
# Epoch 00007: val_loss did not improve from 0.56457
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5394 - accuracy: 0.3639 - val_loss: 0.6126 - val_accuracy: 0.2972
# Epoch 8/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.5308 - accuracy: 0.3763
# Epoch 00008: val_loss did not improve from 0.56457
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5308 - accuracy: 0.3769 - val_loss: 0.5710 - val_accuracy: 0.3167
# Epoch 9/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.5194 - accuracy: 0.3988
# Epoch 00009: val_loss improved from 0.56457 to 0.50715, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5194 - accuracy: 0.3985 - val_loss: 0.5072 - val_accuracy: 0.4083
# Epoch 10/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.4903 - accuracy: 0.4430
# Epoch 00010: val_loss improved from 0.50715 to 0.50097, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4892 - accuracy: 0.4460 - val_loss: 0.5010 - val_accuracy: 0.4278
# Epoch 11/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.4666 - accuracy: 0.4959
# Epoch 00011: val_loss improved from 0.50097 to 0.48743, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4663 - accuracy: 0.4944 - val_loss: 0.4874 - val_accuracy: 0.4556
# Epoch 12/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.4597 - accuracy: 0.4952
# Epoch 00012: val_loss improved from 0.48743 to 0.44306, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4591 - accuracy: 0.4944 - val_loss: 0.4431 - val_accuracy: 0.5222
# Epoch 13/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.4308 - accuracy: 0.5342
# Epoch 00013: val_loss improved from 0.44306 to 0.43498, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4305 - accuracy: 0.5340 - val_loss: 0.4350 - val_accuracy: 0.5222
# Epoch 14/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.4031 - accuracy: 0.5648
# Epoch 00014: val_loss did not improve from 0.43498
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4017 - accuracy: 0.5679 - val_loss: 0.5249 - val_accuracy: 0.4306
# Epoch 15/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.3776 - accuracy: 0.6008
# Epoch 00015: val_loss improved from 0.43498 to 0.37787, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3774 - accuracy: 0.6000 - val_loss: 0.3779 - val_accuracy: 0.5917
# Epoch 16/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.3538 - accuracy: 0.6243
# Epoch 00016: val_loss improved from 0.37787 to 0.34246, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3526 - accuracy: 0.6265 - val_loss: 0.3425 - val_accuracy: 0.6528
# Epoch 17/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.3298 - accuracy: 0.6579
# Epoch 00017: val_loss did not improve from 0.34246
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3323 - accuracy: 0.6546 - val_loss: 0.3769 - val_accuracy: 0.5806
# Epoch 18/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.3199 - accuracy: 0.6585
# Epoch 00018: val_loss improved from 0.34246 to 0.30348, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3195 - accuracy: 0.6590 - val_loss: 0.3035 - val_accuracy: 0.6694
# Epoch 19/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.3064 - accuracy: 0.6740
# Epoch 00019: val_loss did not improve from 0.30348
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3060 - accuracy: 0.6731 - val_loss: 0.3225 - val_accuracy: 0.6472
# Epoch 20/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.2970 - accuracy: 0.6800
# Epoch 00020: val_loss improved from 0.30348 to 0.30303, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2963 - accuracy: 0.6815 - val_loss: 0.3030 - val_accuracy: 0.6611
# Epoch 21/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.2850 - accuracy: 0.6969
# Epoch 00021: val_loss did not improve from 0.30303
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2852 - accuracy: 0.6957 - val_loss: 0.3075 - val_accuracy: 0.6778
# Epoch 22/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2784 - accuracy: 0.7049
# Epoch 00022: val_loss improved from 0.30303 to 0.27687, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2777 - accuracy: 0.7065 - val_loss: 0.2769 - val_accuracy: 0.7083
# Epoch 23/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.2732 - accuracy: 0.7008
# Epoch 00023: val_loss improved from 0.27687 to 0.26152, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2729 - accuracy: 0.7006 - val_loss: 0.2615 - val_accuracy: 0.7194
# Epoch 24/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2707 - accuracy: 0.7097
# Epoch 00024: val_loss improved from 0.26152 to 0.23806, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2710 - accuracy: 0.7090 - val_loss: 0.2381 - val_accuracy: 0.7500
# Epoch 25/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2568 - accuracy: 0.7245
# Epoch 00025: val_loss did not improve from 0.23806
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2562 - accuracy: 0.7253 - val_loss: 0.2501 - val_accuracy: 0.7417
# Epoch 26/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2463 - accuracy: 0.7332
# Epoch 00026: val_loss did not improve from 0.23806
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2465 - accuracy: 0.7330 - val_loss: 0.2692 - val_accuracy: 0.7083
# Epoch 27/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.2530 - accuracy: 0.7309
# Epoch 00027: val_loss did not improve from 0.23806
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2547 - accuracy: 0.7272 - val_loss: 0.2500 - val_accuracy: 0.7222
# Epoch 28/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2466 - accuracy: 0.7326
# Epoch 00028: val_loss improved from 0.23806 to 0.22517, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2466 - accuracy: 0.7340 - val_loss: 0.2252 - val_accuracy: 0.7611
# Epoch 29/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2345 - accuracy: 0.7381
# Epoch 00029: val_loss did not improve from 0.22517
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2340 - accuracy: 0.7392 - val_loss: 0.2265 - val_accuracy: 0.7389
# Epoch 30/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2217 - accuracy: 0.7677
# Epoch 00030: val_loss did not improve from 0.22517
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2242 - accuracy: 0.7639 - val_loss: 0.2374 - val_accuracy: 0.7389
# Epoch 31/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.2356 - accuracy: 0.7467
# Epoch 00031: val_loss did not improve from 0.22517
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2350 - accuracy: 0.7475 - val_loss: 0.2386 - val_accuracy: 0.7278
# Epoch 32/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.2256 - accuracy: 0.7538
# Epoch 00032: val_loss did not improve from 0.22517
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2246 - accuracy: 0.7549 - val_loss: 0.2299 - val_accuracy: 0.7361
# Epoch 33/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2193 - accuracy: 0.7690
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00033: val_loss did not improve from 0.22517
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2180 - accuracy: 0.7716 - val_loss: 0.2549 - val_accuracy: 0.7111
# Epoch 34/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2116 - accuracy: 0.7706
# Epoch 00034: val_loss improved from 0.22517 to 0.21644, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2128 - accuracy: 0.7682 - val_loss: 0.2164 - val_accuracy: 0.7472
# Epoch 35/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2086 - accuracy: 0.7674
# Epoch 00035: val_loss improved from 0.21644 to 0.21328, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2090 - accuracy: 0.7660 - val_loss: 0.2133 - val_accuracy: 0.7667
# Epoch 36/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2000 - accuracy: 0.7771
# Epoch 00036: val_loss improved from 0.21328 to 0.20646, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2029 - accuracy: 0.7753 - val_loss: 0.2065 - val_accuracy: 0.7694
# Epoch 37/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1975 - accuracy: 0.7835
# Epoch 00037: val_loss improved from 0.20646 to 0.20325, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1984 - accuracy: 0.7812 - val_loss: 0.2032 - val_accuracy: 0.7861
# Epoch 38/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1989 - accuracy: 0.7800
# Epoch 00038: val_loss did not improve from 0.20325
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1986 - accuracy: 0.7818 - val_loss: 0.2063 - val_accuracy: 0.8028
# Epoch 39/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1926 - accuracy: 0.7858
# Epoch 00039: val_loss did not improve from 0.20325
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1951 - accuracy: 0.7812 - val_loss: 0.2061 - val_accuracy: 0.7750
# Epoch 40/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1938 - accuracy: 0.7832
# Epoch 00040: val_loss did not improve from 0.20325
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1943 - accuracy: 0.7836 - val_loss: 0.2152 - val_accuracy: 0.7750
# Epoch 41/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1942 - accuracy: 0.7845
# Epoch 00041: val_loss improved from 0.20325 to 0.19790, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1953 - accuracy: 0.7833 - val_loss: 0.1979 - val_accuracy: 0.7778
# Epoch 42/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1865 - accuracy: 0.7935
# Epoch 00042: val_loss did not improve from 0.19790
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1854 - accuracy: 0.7954 - val_loss: 0.2114 - val_accuracy: 0.7528
# Epoch 43/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1909 - accuracy: 0.7887
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00043: val_loss did not improve from 0.19790
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1908 - accuracy: 0.7895 - val_loss: 0.2040 - val_accuracy: 0.7722
# Epoch 44/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1785 - accuracy: 0.7993
# Epoch 00044: val_loss improved from 0.19790 to 0.19551, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1784 - accuracy: 0.7985 - val_loss: 0.1955 - val_accuracy: 0.7917
# Epoch 45/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1861 - accuracy: 0.7974
# Epoch 00045: val_loss improved from 0.19551 to 0.19429, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1846 - accuracy: 0.7991 - val_loss: 0.1943 - val_accuracy: 0.7806
# Epoch 46/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1793 - accuracy: 0.7982
# Epoch 00046: val_loss did not improve from 0.19429
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1779 - accuracy: 0.8006 - val_loss: 0.1947 - val_accuracy: 0.7778
# Epoch 47/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1799 - accuracy: 0.7949
# Epoch 00047: val_loss improved from 0.19429 to 0.19394, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1787 - accuracy: 0.7975 - val_loss: 0.1939 - val_accuracy: 0.7750
# Epoch 48/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1772 - accuracy: 0.8080
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00048: val_loss did not improve from 0.19394
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1796 - accuracy: 0.8049 - val_loss: 0.1964 - val_accuracy: 0.7833
# Epoch 49/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1736 - accuracy: 0.8064
# Epoch 00049: val_loss improved from 0.19394 to 0.19358, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1746 - accuracy: 0.8062 - val_loss: 0.1936 - val_accuracy: 0.7722
# Epoch 50/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1753 - accuracy: 0.8060
# Epoch 00050: val_loss improved from 0.19358 to 0.19352, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1748 - accuracy: 0.8074 - val_loss: 0.1935 - val_accuracy: 0.7778
# Epoch 51/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1783 - accuracy: 0.7980
# Epoch 00051: val_loss improved from 0.19352 to 0.19216, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1776 - accuracy: 0.7981 - val_loss: 0.1922 - val_accuracy: 0.7806
# Epoch 52/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1678 - accuracy: 0.8128
# Epoch 00052: val_loss improved from 0.19216 to 0.19086, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1683 - accuracy: 0.8117 - val_loss: 0.1909 - val_accuracy: 0.7861
# Epoch 53/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1713 - accuracy: 0.8080
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00053: val_loss improved from 0.19086 to 0.18836, saving model to fas_mnist_1.h5
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1718 - accuracy: 0.8074 - val_loss: 0.1884 - val_accuracy: 0.7833
# Epoch 54/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1698 - accuracy: 0.8089
# Epoch 00054: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1721 - accuracy: 0.8068 - val_loss: 0.1900 - val_accuracy: 0.7833
# Epoch 55/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1679 - accuracy: 0.8125
# Epoch 00055: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1684 - accuracy: 0.8117 - val_loss: 0.1911 - val_accuracy: 0.7806
# Epoch 56/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1712 - accuracy: 0.8125
# Epoch 00056: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1712 - accuracy: 0.8111 - val_loss: 0.1905 - val_accuracy: 0.7917
# Epoch 57/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1708 - accuracy: 0.7999
# Epoch 00057: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1698 - accuracy: 0.8012 - val_loss: 0.1893 - val_accuracy: 0.7917
# Epoch 00057: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1721 - accuracy: 0.7850
# Val Score:  [0.1721235066652298, 0.7850000262260437]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.7281 - accuracy: 0.2493
# Epoch 00001: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 8ms/step - loss: 0.7242 - accuracy: 0.2528 - val_loss: 0.6084 - val_accuracy: 0.2583
# Epoch 2/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.6219 - accuracy: 0.2639
# Epoch 00002: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.6212 - accuracy: 0.2639 - val_loss: 0.5757 - val_accuracy: 0.2528
# Epoch 3/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.5800 - accuracy: 0.2806
# Epoch 00003: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5798 - accuracy: 0.2809 - val_loss: 0.5670 - val_accuracy: 0.2333
# Epoch 4/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.5623 - accuracy: 0.2922
# Epoch 00004: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5623 - accuracy: 0.2920 - val_loss: 0.5660 - val_accuracy: 0.2667
# Epoch 5/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.5531 - accuracy: 0.3060
# Epoch 00005: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5535 - accuracy: 0.3049 - val_loss: 0.5716 - val_accuracy: 0.2833
# Epoch 6/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.5430 - accuracy: 0.3415
# Epoch 00006: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5433 - accuracy: 0.3420 - val_loss: 0.5922 - val_accuracy: 0.2417
# Epoch 7/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.5314 - accuracy: 0.3691
# Epoch 00007: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5321 - accuracy: 0.3685 - val_loss: 0.6045 - val_accuracy: 0.2389
# Epoch 8/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.5249 - accuracy: 0.3798
# Epoch 00008: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5250 - accuracy: 0.3793 - val_loss: 0.5811 - val_accuracy: 0.2722
# Epoch 9/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.5203 - accuracy: 0.4059
# Epoch 00009: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5210 - accuracy: 0.4065 - val_loss: 0.5744 - val_accuracy: 0.3111
# Epoch 10/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.5114 - accuracy: 0.4149
# Epoch 00010: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5108 - accuracy: 0.4151 - val_loss: 0.5433 - val_accuracy: 0.3944
# Epoch 11/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.4929 - accuracy: 0.4434
# Epoch 00011: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4914 - accuracy: 0.4454 - val_loss: 0.6016 - val_accuracy: 0.3389
# Epoch 12/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.4644 - accuracy: 0.4916
# Epoch 00012: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4650 - accuracy: 0.4892 - val_loss: 0.5082 - val_accuracy: 0.4194
# Epoch 13/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.4458 - accuracy: 0.5216
# Epoch 00013: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4468 - accuracy: 0.5201 - val_loss: 0.4570 - val_accuracy: 0.4917
# Epoch 14/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.4209 - accuracy: 0.5515
# Epoch 00014: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4201 - accuracy: 0.5531 - val_loss: 0.4627 - val_accuracy: 0.4722
# Epoch 15/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.3856 - accuracy: 0.5983
# Epoch 00015: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3861 - accuracy: 0.5975 - val_loss: 0.4083 - val_accuracy: 0.5444
# Epoch 16/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.3747 - accuracy: 0.6135
# Epoch 00016: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3753 - accuracy: 0.6105 - val_loss: 0.3956 - val_accuracy: 0.5806
# Epoch 17/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.3508 - accuracy: 0.6263
# Epoch 00017: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3497 - accuracy: 0.6284 - val_loss: 0.4417 - val_accuracy: 0.5167
# Epoch 18/100
#  94/102 [==========================>...] - ETA: 0s - loss: 0.3295 - accuracy: 0.6469
# Epoch 00018: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3282 - accuracy: 0.6503 - val_loss: 0.3664 - val_accuracy: 0.6028
# Epoch 19/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.3154 - accuracy: 0.6669
# Epoch 00019: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3144 - accuracy: 0.6682 - val_loss: 0.3372 - val_accuracy: 0.6222
# Epoch 20/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.3006 - accuracy: 0.6846
# Epoch 00020: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2991 - accuracy: 0.6880 - val_loss: 0.3228 - val_accuracy: 0.6472
# Epoch 21/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2917 - accuracy: 0.6891
# Epoch 00021: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2918 - accuracy: 0.6886 - val_loss: 0.3198 - val_accuracy: 0.6944
# Epoch 22/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2871 - accuracy: 0.6798
# Epoch 00022: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2872 - accuracy: 0.6799 - val_loss: 0.3181 - val_accuracy: 0.6611
# Epoch 23/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2767 - accuracy: 0.6972
# Epoch 00023: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2770 - accuracy: 0.6951 - val_loss: 0.3344 - val_accuracy: 0.6306
# Epoch 24/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2719 - accuracy: 0.7065
# Epoch 00024: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2715 - accuracy: 0.7086 - val_loss: 0.3155 - val_accuracy: 0.6333
# Epoch 25/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.2708 - accuracy: 0.7122
# Epoch 00025: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2690 - accuracy: 0.7130 - val_loss: 0.2942 - val_accuracy: 0.6722
# Epoch 26/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.2612 - accuracy: 0.7155
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00026: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2628 - accuracy: 0.7130 - val_loss: 0.2800 - val_accuracy: 0.6889
# Epoch 27/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.2466 - accuracy: 0.7272
# Epoch 00027: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2463 - accuracy: 0.7262 - val_loss: 0.2471 - val_accuracy: 0.7528
# Epoch 28/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.2384 - accuracy: 0.7360
# Epoch 00028: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2380 - accuracy: 0.7361 - val_loss: 0.2579 - val_accuracy: 0.6917
# Epoch 29/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.2281 - accuracy: 0.7500
# Epoch 00029: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2277 - accuracy: 0.7522 - val_loss: 0.2460 - val_accuracy: 0.7444
# Epoch 30/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.2272 - accuracy: 0.7533
# Epoch 00030: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2252 - accuracy: 0.7559 - val_loss: 0.2362 - val_accuracy: 0.7167
# Epoch 31/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.2255 - accuracy: 0.7563
# Epoch 00031: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2257 - accuracy: 0.7562 - val_loss: 0.2536 - val_accuracy: 0.7000
# Epoch 32/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2251 - accuracy: 0.7474
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00032: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2260 - accuracy: 0.7457 - val_loss: 0.2487 - val_accuracy: 0.7222
# Epoch 33/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.2110 - accuracy: 0.7757
# Epoch 00033: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2117 - accuracy: 0.7728 - val_loss: 0.2334 - val_accuracy: 0.7222
# Epoch 34/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2090 - accuracy: 0.7722
# Epoch 00034: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2086 - accuracy: 0.7741 - val_loss: 0.2339 - val_accuracy: 0.7611
# Epoch 35/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.2061 - accuracy: 0.7718
# Epoch 00035: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2074 - accuracy: 0.7688 - val_loss: 0.2235 - val_accuracy: 0.7667
# Epoch 36/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.2117 - accuracy: 0.7643
# Epoch 00036: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2115 - accuracy: 0.7648 - val_loss: 0.2240 - val_accuracy: 0.7417
# Epoch 37/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.2073 - accuracy: 0.7724
# Epoch 00037: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2071 - accuracy: 0.7725 - val_loss: 0.2254 - val_accuracy: 0.7333
# Epoch 38/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.2083 - accuracy: 0.7686
# Epoch 00038: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2084 - accuracy: 0.7691 - val_loss: 0.2154 - val_accuracy: 0.7444
# Epoch 39/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2026 - accuracy: 0.7725
# Epoch 00039: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2026 - accuracy: 0.7725 - val_loss: 0.2112 - val_accuracy: 0.7389
# Epoch 40/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1999 - accuracy: 0.7751
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00040: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1998 - accuracy: 0.7741 - val_loss: 0.2245 - val_accuracy: 0.7639
# Epoch 41/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.2015 - accuracy: 0.7725
# Epoch 00041: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2001 - accuracy: 0.7747 - val_loss: 0.2141 - val_accuracy: 0.7556
# Epoch 42/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1947 - accuracy: 0.7796
# Epoch 00042: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1962 - accuracy: 0.7772 - val_loss: 0.2140 - val_accuracy: 0.7917
# Epoch 43/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1934 - accuracy: 0.7874
# Epoch 00043: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1947 - accuracy: 0.7858 - val_loss: 0.2118 - val_accuracy: 0.7528
# Epoch 44/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1941 - accuracy: 0.7816
# Epoch 00044: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1931 - accuracy: 0.7824 - val_loss: 0.2118 - val_accuracy: 0.7778
# Epoch 45/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1926 - accuracy: 0.7881
# Epoch 00045: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1939 - accuracy: 0.7864 - val_loss: 0.2130 - val_accuracy: 0.7722
# Epoch 46/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1966 - accuracy: 0.7780
# Epoch 00046: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1960 - accuracy: 0.7793 - val_loss: 0.2104 - val_accuracy: 0.7778
# Epoch 47/100
# 102/102 [==============================] - ETA: 0s - loss: 0.1911 - accuracy: 0.7898
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00047: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1911 - accuracy: 0.7898 - val_loss: 0.2120 - val_accuracy: 0.7778
# Epoch 48/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1888 - accuracy: 0.7868
# Epoch 00048: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1892 - accuracy: 0.7861 - val_loss: 0.2085 - val_accuracy: 0.7778
# Epoch 49/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1883 - accuracy: 0.7904
# Epoch 00049: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1879 - accuracy: 0.7898 - val_loss: 0.2105 - val_accuracy: 0.7778
# Epoch 50/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1936 - accuracy: 0.7826
# Epoch 00050: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1954 - accuracy: 0.7815 - val_loss: 0.2092 - val_accuracy: 0.7722
# Epoch 51/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1893 - accuracy: 0.7868
# Epoch 00051: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1906 - accuracy: 0.7877 - val_loss: 0.2085 - val_accuracy: 0.7556
# Epoch 52/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1864 - accuracy: 0.7899
# Epoch 00052: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1885 - accuracy: 0.7858 - val_loss: 0.2082 - val_accuracy: 0.7750
# Epoch 53/100
# 102/102 [==============================] - ETA: 0s - loss: 0.1903 - accuracy: 0.7843
# Epoch 00053: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1903 - accuracy: 0.7843 - val_loss: 0.2080 - val_accuracy: 0.7556
# Epoch 54/100
# 102/102 [==============================] - ETA: 0s - loss: 0.1847 - accuracy: 0.7960
# Epoch 00054: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1847 - accuracy: 0.7960 - val_loss: 0.2059 - val_accuracy: 0.7583
# Epoch 55/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.1878 - accuracy: 0.7799
# Epoch 00055: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1868 - accuracy: 0.7809 - val_loss: 0.2064 - val_accuracy: 0.7833
# Epoch 56/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1880 - accuracy: 0.7832
# Epoch 00056: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1879 - accuracy: 0.7833 - val_loss: 0.2066 - val_accuracy: 0.7556
# Epoch 57/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1896 - accuracy: 0.7851
# Epoch 00057: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1896 - accuracy: 0.7852 - val_loss: 0.2063 - val_accuracy: 0.7778
# Epoch 58/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1818 - accuracy: 0.7946
# Epoch 00058: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1816 - accuracy: 0.7944 - val_loss: 0.2086 - val_accuracy: 0.7722
# Epoch 59/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1812 - accuracy: 0.7900
# Epoch 00059: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1823 - accuracy: 0.7886 - val_loss: 0.2056 - val_accuracy: 0.7694
# Epoch 60/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1800 - accuracy: 0.8035
# Epoch 00060: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1824 - accuracy: 0.7997 - val_loss: 0.2043 - val_accuracy: 0.7750
# Epoch 61/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.1805 - accuracy: 0.7964
# Epoch 00061: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1808 - accuracy: 0.7978 - val_loss: 0.2072 - val_accuracy: 0.7583
# Epoch 62/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.1877 - accuracy: 0.7973
# Epoch 00062: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1880 - accuracy: 0.7969 - val_loss: 0.2055 - val_accuracy: 0.7583
# Epoch 63/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1845 - accuracy: 0.7917
# Epoch 00063: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1849 - accuracy: 0.7904 - val_loss: 0.2046 - val_accuracy: 0.7556
# Epoch 64/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.1815 - accuracy: 0.7885
# Epoch 00064: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1816 - accuracy: 0.7898 - val_loss: 0.2047 - val_accuracy: 0.7583
# Epoch 65/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1835 - accuracy: 0.7949
# Epoch 00065: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1831 - accuracy: 0.7960 - val_loss: 0.2032 - val_accuracy: 0.7611
# Epoch 66/100
# 102/102 [==============================] - ETA: 0s - loss: 0.1808 - accuracy: 0.7985
# Epoch 00066: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1808 - accuracy: 0.7985 - val_loss: 0.2040 - val_accuracy: 0.7611
# Epoch 67/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1792 - accuracy: 0.7943
# Epoch 00067: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1812 - accuracy: 0.7944 - val_loss: 0.2030 - val_accuracy: 0.7611
# Epoch 68/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1788 - accuracy: 0.7998
# Epoch 00068: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1787 - accuracy: 0.7997 - val_loss: 0.1983 - val_accuracy: 0.7917
# Epoch 69/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1828 - accuracy: 0.7855
# Epoch 00069: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1817 - accuracy: 0.7861 - val_loss: 0.2023 - val_accuracy: 0.7583
# Epoch 70/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.1808 - accuracy: 0.7958
# Epoch 00070: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1814 - accuracy: 0.7954 - val_loss: 0.2018 - val_accuracy: 0.7583
# Epoch 71/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.1771 - accuracy: 0.8007
# Epoch 00071: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1784 - accuracy: 0.8000 - val_loss: 0.1979 - val_accuracy: 0.7639
# Epoch 72/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.1781 - accuracy: 0.8018
# Epoch 00072: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1780 - accuracy: 0.8028 - val_loss: 0.1967 - val_accuracy: 0.7722
# Epoch 73/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.1815 - accuracy: 0.7868
# Epoch 00073: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1801 - accuracy: 0.7895 - val_loss: 0.1980 - val_accuracy: 0.7667
# Epoch 74/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.1823 - accuracy: 0.7931
# Epoch 00074: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1814 - accuracy: 0.7951 - val_loss: 0.1970 - val_accuracy: 0.7611
# Epoch 75/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.1804 - accuracy: 0.7927
# Epoch 00075: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1803 - accuracy: 0.7929 - val_loss: 0.1951 - val_accuracy: 0.7694
# Epoch 76/100
#  94/102 [==========================>...] - ETA: 0s - loss: 0.1815 - accuracy: 0.7945
# Epoch 00076: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1817 - accuracy: 0.7935 - val_loss: 0.1952 - val_accuracy: 0.7667
# Epoch 77/100
# 102/102 [==============================] - ETA: 0s - loss: 0.1780 - accuracy: 0.7920
# Epoch 00077: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1780 - accuracy: 0.7920 - val_loss: 0.1947 - val_accuracy: 0.7750
# Epoch 00077: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1598 - accuracy: 0.8300
# Val Score:  [0.15981987118721008, 0.8299999833106995]
# ====================================================================================
#
#
# Training on Fold:  3
# Epoch 1/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.7225 - accuracy: 0.2734
# Epoch 00001: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 9ms/step - loss: 0.7196 - accuracy: 0.2725 - val_loss: 0.6635 - val_accuracy: 0.2111
# Epoch 2/100
#  94/102 [==========================>...] - ETA: 0s - loss: 0.6205 - accuracy: 0.2789
# Epoch 00002: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.6184 - accuracy: 0.2806 - val_loss: 0.6097 - val_accuracy: 0.2278
# Epoch 3/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.5823 - accuracy: 0.2835
# Epoch 00003: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5818 - accuracy: 0.2815 - val_loss: 0.5765 - val_accuracy: 0.2389
# Epoch 4/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.5653 - accuracy: 0.2924
# Epoch 00004: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5654 - accuracy: 0.2920 - val_loss: 0.5762 - val_accuracy: 0.2389
# Epoch 5/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.5583 - accuracy: 0.3122
# Epoch 00005: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5578 - accuracy: 0.3120 - val_loss: 0.5831 - val_accuracy: 0.2139
# Epoch 6/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.5527 - accuracy: 0.3266
# Epoch 00006: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5526 - accuracy: 0.3265 - val_loss: 0.5987 - val_accuracy: 0.2222
# Epoch 7/100
# 102/102 [==============================] - ETA: 0s - loss: 0.5422 - accuracy: 0.3512
# Epoch 00007: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5422 - accuracy: 0.3512 - val_loss: 0.5985 - val_accuracy: 0.2528
# Epoch 8/100
# 102/102 [==============================] - ETA: 0s - loss: 0.5312 - accuracy: 0.3731
# Epoch 00008: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5312 - accuracy: 0.3731 - val_loss: 0.5355 - val_accuracy: 0.3500
# Epoch 9/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.5114 - accuracy: 0.4205
# Epoch 00009: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5119 - accuracy: 0.4201 - val_loss: 0.5686 - val_accuracy: 0.2778
# Epoch 10/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.5006 - accuracy: 0.4366
# Epoch 00010: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5009 - accuracy: 0.4361 - val_loss: 0.5238 - val_accuracy: 0.4028
# Epoch 11/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.4764 - accuracy: 0.4741
# Epoch 00011: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4760 - accuracy: 0.4744 - val_loss: 0.5272 - val_accuracy: 0.3611
# Epoch 12/100
#  94/102 [==========================>...] - ETA: 0s - loss: 0.4524 - accuracy: 0.5160
# Epoch 00012: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4510 - accuracy: 0.5160 - val_loss: 0.5235 - val_accuracy: 0.3611
# Epoch 13/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.4377 - accuracy: 0.5349
# Epoch 00013: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4355 - accuracy: 0.5392 - val_loss: 0.4626 - val_accuracy: 0.4556
# Epoch 14/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.3949 - accuracy: 0.5826
# Epoch 00014: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3936 - accuracy: 0.5849 - val_loss: 0.4096 - val_accuracy: 0.5278
# Epoch 15/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.3828 - accuracy: 0.5977
# Epoch 00015: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3806 - accuracy: 0.6022 - val_loss: 0.3617 - val_accuracy: 0.6083
# Epoch 16/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.3453 - accuracy: 0.6451
# Epoch 00016: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3452 - accuracy: 0.6435 - val_loss: 0.3928 - val_accuracy: 0.5944
# Epoch 17/100
# 102/102 [==============================] - ETA: 0s - loss: 0.3454 - accuracy: 0.6432
# Epoch 00017: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3454 - accuracy: 0.6432 - val_loss: 0.3418 - val_accuracy: 0.6389
# Epoch 18/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3286 - accuracy: 0.6516
# Epoch 00018: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3292 - accuracy: 0.6509 - val_loss: 0.4222 - val_accuracy: 0.5222
# Epoch 19/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3243 - accuracy: 0.6590
# Epoch 00019: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3247 - accuracy: 0.6586 - val_loss: 0.3039 - val_accuracy: 0.6806
# Epoch 20/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.3044 - accuracy: 0.6776
# Epoch 00020: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3042 - accuracy: 0.6778 - val_loss: 0.3065 - val_accuracy: 0.6750
# Epoch 21/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2918 - accuracy: 0.6966
# Epoch 00021: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2918 - accuracy: 0.6966 - val_loss: 0.2768 - val_accuracy: 0.6917
# Epoch 22/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2909 - accuracy: 0.6978
# Epoch 00022: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2912 - accuracy: 0.6972 - val_loss: 0.3014 - val_accuracy: 0.6972
# Epoch 23/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2732 - accuracy: 0.7144
# Epoch 00023: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2734 - accuracy: 0.7139 - val_loss: 0.3378 - val_accuracy: 0.6361
# Epoch 24/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2581 - accuracy: 0.7159
# Epoch 00024: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2577 - accuracy: 0.7173 - val_loss: 0.2624 - val_accuracy: 0.7056
# Epoch 25/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2621 - accuracy: 0.7213
# Epoch 00025: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2625 - accuracy: 0.7213 - val_loss: 0.2674 - val_accuracy: 0.7444
# Epoch 26/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2464 - accuracy: 0.7327
# Epoch 00026: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2464 - accuracy: 0.7327 - val_loss: 0.2654 - val_accuracy: 0.7306
# Epoch 27/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.2480 - accuracy: 0.7386
# Epoch 00027: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2493 - accuracy: 0.7349 - val_loss: 0.2790 - val_accuracy: 0.6667
# Epoch 28/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.2445 - accuracy: 0.7365
# Epoch 00028: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2476 - accuracy: 0.7336 - val_loss: 0.2710 - val_accuracy: 0.7167
# Epoch 29/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2374 - accuracy: 0.7463
# Epoch 00029: val_loss did not improve from 0.18836
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2377 - accuracy: 0.7460 - val_loss: 0.2652 - val_accuracy: 0.7083
# Epoch 30/100
# ...
# Epoch 00063: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1980 - accuracy: 0.7600
# Val Score:  [0.1980365514755249, 0.7599999904632568]
# ====================================================================================
#
#
# Training on Fold:  5
# Epoch 1/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.7300 - accuracy: 0.2507
# Epoch 00001: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 9ms/step - loss: 0.7254 - accuracy: 0.2519 - val_loss: 0.6033 - val_accuracy: 0.2583
# Epoch 2/100
# 102/102 [==============================] - ETA: 0s - loss: 0.6112 - accuracy: 0.2645
# Epoch 00002: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.6112 - accuracy: 0.2645 - val_loss: 0.5793 - val_accuracy: 0.2444
# Epoch 3/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.5752 - accuracy: 0.2812
# Epoch 00003: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5754 - accuracy: 0.2812 - val_loss: 0.5718 - val_accuracy: 0.2444
# Epoch 4/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.5679 - accuracy: 0.2822
# Epoch 00004: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5669 - accuracy: 0.2858 - val_loss: 0.5712 - val_accuracy: 0.2389
# Epoch 5/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.5586 - accuracy: 0.3135
# Epoch 00005: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5582 - accuracy: 0.3145 - val_loss: 0.5741 - val_accuracy: 0.2361
# Epoch 6/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.5527 - accuracy: 0.3192
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5526 - accuracy: 0.3225 - val_loss: 0.5786 - val_accuracy: 0.2278
# Epoch 7/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.5427 - accuracy: 0.3355
# Epoch 00007: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5429 - accuracy: 0.3352 - val_loss: 0.5712 - val_accuracy: 0.2806
# Epoch 8/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.5359 - accuracy: 0.3611
# Epoch 00008: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5359 - accuracy: 0.3608 - val_loss: 0.5580 - val_accuracy: 0.3389
# Epoch 9/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.5253 - accuracy: 0.3815
# Epoch 00009: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5253 - accuracy: 0.3815 - val_loss: 0.5348 - val_accuracy: 0.3500
# Epoch 10/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.5096 - accuracy: 0.4222
# Epoch 00010: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5096 - accuracy: 0.4222 - val_loss: 0.5096 - val_accuracy: 0.4417
# Epoch 11/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.4886 - accuracy: 0.4528
# Epoch 00011: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4884 - accuracy: 0.4525 - val_loss: 0.5235 - val_accuracy: 0.3694
# Epoch 12/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4667 - accuracy: 0.4870
# Epoch 00012: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4667 - accuracy: 0.4870 - val_loss: 0.5275 - val_accuracy: 0.3583
# Epoch 13/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.4493 - accuracy: 0.5191
# Epoch 00013: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4492 - accuracy: 0.5191 - val_loss: 0.5858 - val_accuracy: 0.4111
# Epoch 14/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.4180 - accuracy: 0.5640
# Epoch 00014: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4180 - accuracy: 0.5642 - val_loss: 0.4816 - val_accuracy: 0.4056
# Epoch 15/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.3959 - accuracy: 0.5844
# Epoch 00015: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3970 - accuracy: 0.5827 - val_loss: 0.4165 - val_accuracy: 0.5778
# Epoch 16/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.3743 - accuracy: 0.6244
# Epoch 00016: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3749 - accuracy: 0.6222 - val_loss: 0.3577 - val_accuracy: 0.6056
# Epoch 17/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.3508 - accuracy: 0.6385
# Epoch 00017: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3505 - accuracy: 0.6395 - val_loss: 0.3928 - val_accuracy: 0.5500
# Epoch 18/100
# 102/102 [==============================] - ETA: 0s - loss: 0.3326 - accuracy: 0.6657
# Epoch 00018: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3326 - accuracy: 0.6657 - val_loss: 0.3592 - val_accuracy: 0.6083
# Epoch 19/100
# 102/102 [==============================] - ETA: 0s - loss: 0.3178 - accuracy: 0.6670
# Epoch 00019: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3178 - accuracy: 0.6670 - val_loss: 0.3386 - val_accuracy: 0.6222
# Epoch 20/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2940 - accuracy: 0.6994
# Epoch 00020: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2943 - accuracy: 0.7000 - val_loss: 0.3239 - val_accuracy: 0.6639
# Epoch 21/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2933 - accuracy: 0.6991
# Epoch 00021: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2927 - accuracy: 0.7000 - val_loss: 0.3021 - val_accuracy: 0.6750
# Epoch 22/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2774 - accuracy: 0.7091
# Epoch 00022: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2782 - accuracy: 0.7074 - val_loss: 0.2931 - val_accuracy: 0.6750
# Epoch 23/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2771 - accuracy: 0.7056
# Epoch 00023: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2767 - accuracy: 0.7065 - val_loss: 0.3001 - val_accuracy: 0.6611
# Epoch 24/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.2705 - accuracy: 0.7210
# Epoch 00024: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2696 - accuracy: 0.7228 - val_loss: 0.2704 - val_accuracy: 0.7111
# Epoch 25/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2579 - accuracy: 0.7252
# Epoch 00025: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2588 - accuracy: 0.7235 - val_loss: 0.3010 - val_accuracy: 0.6861
# Epoch 26/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2543 - accuracy: 0.7365
# Epoch 00026: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2536 - accuracy: 0.7380 - val_loss: 0.2721 - val_accuracy: 0.6972
# Epoch 27/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.2467 - accuracy: 0.7370
# Epoch 00027: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2457 - accuracy: 0.7386 - val_loss: 0.2601 - val_accuracy: 0.6944
# Epoch 28/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.2461 - accuracy: 0.7266
# Epoch 00028: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2455 - accuracy: 0.7265 - val_loss: 0.2673 - val_accuracy: 0.6972
# Epoch 29/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.2405 - accuracy: 0.7497
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00029: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2402 - accuracy: 0.7491 - val_loss: 0.2624 - val_accuracy: 0.7056
# Epoch 30/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2322 - accuracy: 0.7510
# Epoch 00030: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2328 - accuracy: 0.7515 - val_loss: 0.2489 - val_accuracy: 0.7194
# Epoch 31/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.2190 - accuracy: 0.7689
# Epoch 00031: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2189 - accuracy: 0.7691 - val_loss: 0.2429 - val_accuracy: 0.7250
# Epoch 32/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.2165 - accuracy: 0.7616
# Epoch 00032: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2170 - accuracy: 0.7611 - val_loss: 0.2571 - val_accuracy: 0.7194
# Epoch 33/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.2094 - accuracy: 0.7701
# Epoch 00033: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2096 - accuracy: 0.7694 - val_loss: 0.2457 - val_accuracy: 0.7167
# Epoch 34/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.2079 - accuracy: 0.7678
# Epoch 00034: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2064 - accuracy: 0.7707 - val_loss: 0.2386 - val_accuracy: 0.7222
# Epoch 35/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.2013 - accuracy: 0.7790
# Epoch 00035: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2028 - accuracy: 0.7781 - val_loss: 0.2397 - val_accuracy: 0.7056
# Epoch 36/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1989 - accuracy: 0.7832
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00036: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1993 - accuracy: 0.7815 - val_loss: 0.2339 - val_accuracy: 0.7194
# Epoch 37/100
# 100/102 [============================>.] - ETA: 0s - loss: 0.1964 - accuracy: 0.7791
# Epoch 00037: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1970 - accuracy: 0.7790 - val_loss: 0.2268 - val_accuracy: 0.7528
# Epoch 38/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.1933 - accuracy: 0.7816
# Epoch 00038: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1934 - accuracy: 0.7818 - val_loss: 0.2301 - val_accuracy: 0.7361
# Epoch 39/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1912 - accuracy: 0.7896
# Epoch 00039: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1923 - accuracy: 0.7877 - val_loss: 0.2242 - val_accuracy: 0.7528
# Epoch 40/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1955 - accuracy: 0.7832
# Epoch 00040: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1967 - accuracy: 0.7830 - val_loss: 0.2243 - val_accuracy: 0.7611
# Epoch 41/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.1872 - accuracy: 0.7876
# Epoch 00041: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1884 - accuracy: 0.7873 - val_loss: 0.2264 - val_accuracy: 0.7444
# Epoch 42/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.1899 - accuracy: 0.7872
# Epoch 00042: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1904 - accuracy: 0.7870 - val_loss: 0.2230 - val_accuracy: 0.7722
# Epoch 43/100
# 102/102 [==============================] - ETA: 0s - loss: 0.1874 - accuracy: 0.7932
# Epoch 00043: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1874 - accuracy: 0.7932 - val_loss: 0.2190 - val_accuracy: 0.7444
# Epoch 44/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1845 - accuracy: 0.7982
# Epoch 00044: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1848 - accuracy: 0.7985 - val_loss: 0.2226 - val_accuracy: 0.7389
# Epoch 45/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.1837 - accuracy: 0.7918
# Epoch 00045: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1840 - accuracy: 0.7910 - val_loss: 0.2199 - val_accuracy: 0.7556
# Epoch 46/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.1840 - accuracy: 0.7989
# Epoch 00046: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1836 - accuracy: 0.7988 - val_loss: 0.2211 - val_accuracy: 0.7417
# Epoch 47/100
# 101/102 [============================>.] - ETA: 0s - loss: 0.1858 - accuracy: 0.7899
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00047: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1861 - accuracy: 0.7898 - val_loss: 0.2185 - val_accuracy: 0.7472
# Epoch 48/100
#  95/102 [==========================>...] - ETA: 0s - loss: 0.1856 - accuracy: 0.7911
# Epoch 00048: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1848 - accuracy: 0.7932 - val_loss: 0.2195 - val_accuracy: 0.7417
# Epoch 49/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1784 - accuracy: 0.8038
# Epoch 00049: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1784 - accuracy: 0.8043 - val_loss: 0.2196 - val_accuracy: 0.7417
# Epoch 50/100
#  98/102 [===========================>..] - ETA: 0s - loss: 0.1847 - accuracy: 0.7924
# Epoch 00050: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1850 - accuracy: 0.7917 - val_loss: 0.2187 - val_accuracy: 0.7500
# Epoch 51/100
#  99/102 [============================>.] - ETA: 0s - loss: 0.1778 - accuracy: 0.8008
# Epoch 00051: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1785 - accuracy: 0.7997 - val_loss: 0.2188 - val_accuracy: 0.7444
# Epoch 52/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1805 - accuracy: 0.7920
# Epoch 00052: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1817 - accuracy: 0.7917 - val_loss: 0.2153 - val_accuracy: 0.7500
# Epoch 53/100
#  96/102 [===========================>..] - ETA: 0s - loss: 0.1793 - accuracy: 0.7959
# Epoch 00053: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1792 - accuracy: 0.7960 - val_loss: 0.2181 - val_accuracy: 0.7444
# Epoch 54/100
#  97/102 [===========================>..] - ETA: 0s - loss: 0.1821 - accuracy: 0.7964
# Epoch 00054: val_loss did not improve from 0.17852
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1809 - accuracy: 0.7978 - val_loss: 0.2204 - val_accuracy: 0.7361
# Epoch 00054: early stopping
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1950 - accuracy: 0.7775
# Val Score:  [0.19504453241825104, 0.7774999737739563]
# ====================================================================================

# %%
#Load the model that was saved by ModelCheckpoint
model = load_model('fas_mnist_1.h5')

# %%
model.evaluate(test_X, test_y)
#print("Accuracy of the model is - " , model.evaluate(test_X,test_y)[1]*100 , "%")
#plt.bar( model.evaluate(test_X)[1].index,  model.evaluate(test_y)[1])
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1469 - accuracy: 0.8190
# [0.14689213037490845, 0.8190000057220459]

# %%
fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)

ax1.plot(model_history[0].history['accuracy'], label='Training Fold 1 accuration')
ax1.plot(model_history[1].history['accuracy'], label='Training Fold 2 accuration')
ax1.plot(model_history[2].history['accuracy'], label='Training Fold 3 accuration')
ax1.plot(model_history[3].history['accuracy'], label='Training Fold 4 accuration')
ax1.plot(model_history[4].history['accuracy'], label='Training Fold 5 accuration')
ax1.legend()
ax2.plot(model_history[1].history['loss'], label='Training Fold 1 loss')
ax2.plot(model_history[1].history['loss'], label='Training Fold 2 loss')
ax2.plot(model_history[2].history['loss'], label='Training Fold 3 loss')
ax2.plot(model_history[3].history['loss'], label='Training Fold 4 loss ')
ax2.plot(model_history[4].history['loss'], label='Training Fold 5 loss')
ax2.legend()
plt.show()

# %%
fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt1.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[0].history['loss'], label='Train Loss Fold 1', color='black')
plt2.plot(model_history[0].history['val_loss'], label='Val Loss Fold 1', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red')
plt1.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[1].history['loss'], label='Train Loss Fold 2', color='red')
plt2.plot(model_history[1].history['val_loss'], label='Val Loss Fold 2', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green')
plt1.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[2].history['loss'], label='Train Loss Fold 3', color='green')
plt2.plot(model_history[2].history['val_loss'], label='Val Loss Fold 3', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()


fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue')
plt1.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[3].history['loss'], label='Train Loss Fold 4', color='blue')
plt2.plot(model_history[3].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='purple')
plt1.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[4].history['loss'], label='Train Loss Fold 4', color='purple')
plt2.plot(model_history[4].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

# %%
MODEL_NAME ='/content/fas_mnist_1.h5' 

#CLIP = True # if your model was trained with np.clip to clip  values
CLIP = False
CLIP_VAL = 8  # if above, what was the value +/-

model = tf.keras.models.load_model(MODEL_NAME)

VALDIR = '/content/drive/MyDrive/Colab Notebooks/data_baru'
ACTIONS =  ["idle","maju","kiri", "kanan"]
PRED_BATCH = 64


def get_val_data(valdir, action, batch_size):

   # argmax_dict = {0: 0, 1: 0, 2: 0,3:0}
    argmax_dict = {2: 0, 0: 0, 1: 0,3:0}
    raw_pred_dict = {0: 0, 1: 0, 2: 0,3:0}

    action_dir = os.path.join(valdir, action)
    for session_file in os.listdir(action_dir):
        filepath = os.path.join(action_dir,session_file)
        if CLIP:
            data = np.clip(np.load(filepath), -CLIP_VAL, CLIP_VAL) / CLIP_VAL
            #print(data)
        else:
            data = np.load(filepath) 
        preds = model.predict([data.reshape(-1, 16, 60,1)], batch_size=batch_size)
        
        for pred in preds:
            argmax = np.argmax(pred)
            argmax_dict[argmax] += 1
            for idx,value in enumerate(pred):
                raw_pred_dict[idx] += value
    
    argmax_pct_dict = {}
    for i in argmax_dict:
        total = 0
        correct = argmax_dict[i]
        for ii in argmax_dict:
            total += argmax_dict[ii]
        argmax_pct_dict[i] = round(correct/total, 4)
    return argmax_dict, raw_pred_dict, argmax_pct_dict


def make_conf_mat(none,left,forward, right):
    action_dict = {"idle":none,"maju": forward, "kiri": left, "kanan": right}
    action_conf_mat = pd.DataFrame(action_dict)
    actions = [i for i in action_dict]

    fig = plt.figure(figsize=(15, 6))
    ax = fig.add_subplot(111)
    ax.matshow(action_conf_mat, cmap=plt.cm.RdYlGn)
    ax.set_xticklabels([""]+actions)
    ax.set_yticklabels([""]+actions)

    for idx, i in enumerate(action_dict):
        for idx2, ii in enumerate(action_dict[i]):
            ax.text(idx, idx2, f"{round(float(action_dict[i][ii]),2)}", va='center', ha='center')
    # Rotate the tick labels and set their alignment.
    
    plt.title("Matrik data")
    plt.ylabel("Predicted Action")
    fig.tight_layout()
    plt.show()



forward_argmax_dict, forward_raw_pred_dict, forward_argmax_pct_dict = get_val_data(VALDIR, "maju", PRED_BATCH)
none_argmax_dict, none_raw_pred_dict, none_argmax_pct_dict = get_val_data(VALDIR, "idle", PRED_BATCH)
left_argmax_dict, left_raw_pred_dict, left_argmax_pct_dict = get_val_data(VALDIR, "kiri", PRED_BATCH)
right_argmax_dict, right_raw_pred_dict, right_argmax_pct_dict = get_val_data(VALDIR, "kanan", PRED_BATCH)

make_conf_mat(none_argmax_pct_dict,forward_argmax_pct_dict,left_argmax_pct_dict,  right_argmax_pct_dict)

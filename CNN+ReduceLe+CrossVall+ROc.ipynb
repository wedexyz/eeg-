# %% [markdown]
# <a href="https://colab.research.google.com/github/wedexyz/eeg-/blob/main/CNN%2BReduceLe%2BCrossVall%2BROc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.0.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.19.4)

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM, BatchNormalization, Conv2D, Flatten, MaxPooling2D, Dropout
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.optimizers import Adam
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
import pandas as pd
import os
import random
import time
import os
from keras.callbacks import ModelCheckpoint, EarlyStopping
#from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator

from scipy import signal
from scipy.fft import fftshift

# %%
idle = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/idle/1604315006.npy")
kanan = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kanan/1604315180.npy")
kiri = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/kiri/1604315126.npy")
maju = np.load("/content/drive/My Drive/Colab Notebooks/data_baru/maju/1604315069.npy")

kelas1=idle[0][16]
kelas2=maju[0][16]
kelas3=kanan[0][16]
kelas4=kiri[0][16]

kelas1a=idle[175]
kelas2a=maju[175]
kelas3a=kanan[175]
kelas4a=kiri[175]

#print(idlea.shape)


f1, t1,Sxx= signal.spectrogram(kelas1,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )
dbs1 = 10*np.log10(Sxx)
f2, t2,Sxx= signal.spectrogram(kelas2,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd',
                            )
dbs2 = 10*np.log10(Sxx)
f3, t3,Sxx= signal.spectrogram(kelas3,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )
dbs3 = 10*np.log10(Sxx)
f4, t4,Sxx= signal.spectrogram(kelas4,fs=120, window=('tukey', 0.25),
                             nperseg=11,
                             noverlap=10,
                             nfft=None, 
                             detrend='constant',
                             return_onesided=True, 
                             scaling='density', 
                             axis=-1,
                             mode='psd'
                            )  
dbs4 = 10*np.log10(Sxx)



fig, axs = plt.subplots(nrows=4, ncols=4)
axs = axs.flatten()

axs[0].set_title("siggle")
axs[0].plot(kelas1)

axs[1].set_title("global")
axs[1].plot(kelas1a)

axs[2].set_title("Spectogram")
axs[2].pcolormesh(t1, f1,dbs1,  
                  shading='gouraud',
                  cmap='nipy_spectral')

cwt1 = signal.cwt(kelas1,signal.ricker,widths=np.arange(1,50))
cwt2 = signal.cwt(kelas2,signal.ricker,widths=np.arange(1,50))
cwt3 = signal.cwt(kelas3,signal.ricker,widths=np.arange(1,50))
cwt4 = signal.cwt(kelas4,signal.ricker,widths=np.arange(1,50))
axs[3].set_title("wavelet")
axs[3].imshow(cwt1,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt1).max(),vmin=-abs(cwt1).max())

axs[4].plot(kelas2)
axs[5].plot(kelas2a)
axs[6].pcolormesh(t2, f2,dbs2,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[7].imshow(cwt2,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt2).max(),vmin=-abs(cwt2).max())

axs[8].plot(kelas3)
axs[9].plot(kelas3a)
axs[10].pcolormesh(t3, f3,dbs3,  
                  shading='gouraud',
                  cmap='nipy_spectral')
axs[11].imshow(cwt3,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt3).max(),vmin=-abs(cwt3).max())

axs[12].plot(kelas4)
axs[13].plot(kelas4a)
axs[14].pcolormesh(t4, f4,dbs4,  
                  shading='gouraud',
                  cmap='viridis')
axs[15].imshow(cwt4,extent=[0,16,0,60],cmap='jet',aspect='auto',vmax=abs(cwt4).max(),vmin=-abs(cwt4).max())
plt.show()

# %%
ACTIONS = ["kiri", "maju","idle","kanan"]
reshape = (-1,16, 60,1)
#reshape(-1,28,28,1)

# %%
def create_data(starting_dir="=/content/drive/My Drive/Colab Notebooks/data_baru"):
    training_data = {}
    for action in ACTIONS:
        if action not in training_data:
            training_data[action] = []
        data_dir = os.path.join(starting_dir,action)
        for item in os.listdir(data_dir):
            data = np.load(os.path.join(data_dir, item))
            for item in data:
                training_data[action].append(item)

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)

    for action in ACTIONS:
        np.random.shuffle(training_data[action])  
        training_data[action] = training_data[action][:min(lengths)]

    lengths = [len(training_data[action]) for action in ACTIONS]
    print(lengths)
    combined_data = []
    for action in ACTIONS:
        for data in training_data[action]:
            if action == "kiri":
                combined_data.append([data, [1, 0, 0,0]])
            elif action == "maju":
                combined_data.append([data, [0, 1, 0, 0]])
            elif action == "idle":
                combined_data.append([data, [0, 0, 1, 0]])
            elif action == "kanan":
                combined_data.append([data, [0, 0, 0, 1]])

    np.random.shuffle(combined_data)
    print("length:",len(combined_data))
    return combined_data

# %%
print("creating training data")
traindata = create_data(starting_dir="/content/drive/My Drive/Colab Notebooks/data_baru")
train_X = []
train_y = []
for X, y in traindata:
    train_X.append(X)
    train_y.append(y)
# Out:
# creating training data
# [1000, 1000, 1000, 1000]
# [1000, 1000, 1000, 1000]
# length: 4000

# %%
print("creating testing data")
testdata = create_data(starting_dir="/content/drive/MyDrive/Colab Notebooks/tes_data")
test_X = []
test_y = []

for X, y in testdata:
    test_X.append(X)
    test_y.append(y)
train_X = np.array(train_X).reshape(reshape)
test_X = np.array(test_X).reshape(reshape)

train_y = np.array(train_y)
test_y = np.array(test_y)
# Out:
# creating testing data
# [250, 250, 250, 250]
# [250, 250, 250, 250]
# length: 1000

# %%
import seaborn as sns
ye=pd.DataFrame(train_y)

ye.columns=["kiri", "maju","idle","kanan"]
categories = list(ye.columns.values)
sns.set(font_scale = 1)
plt.figure(figsize=(10,8))
ax= sns.barplot(categories, ye.iloc[:,0:].sum().values)
plt.title("Number of samples labeled as active (1) out of {0} length data".format((ye.shape[0])),fontsize=20)

plt.ylabel('Number of events', fontsize=18)
plt.xlabel('Event Type ', fontsize=12)
#adding the text labels
rects = ax.patches
labels = ye.iloc[:,0:].sum().values

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom', fontsize=10)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
IMAGE_SIZE = (16, 60, 1)

# %%
# With data augmentation to prevent overfitting

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(train_X)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1,factor=0.5, min_lr=0.0001)

# %%
def cnn_model(size, num_cnn_layers):
    

    model = Sequential()
    
    model.add(Conv2D(filters = 64, kernel_size = (7,7), padding = "same", activation = "relu", input_shape=train_X.shape[1:]))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Conv2D(filters = 64, kernel_size = (5,5), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (5,5)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Conv2D(filters = 64, kernel_size = (3,3), padding = "same", activation = "relu",input_shape=train_X.shape[1:]))
    model.add(MaxPooling2D(pool_size = (3,3)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())

    model.add(Flatten())
    
    model.add(Dense(32, activation = "relu"))
    model.add(BatchNormalization())

    model.add(Dense(4, activation = "sigmoid"))
   
    #adam = Adam(lr = 0.001)
    model.compile(optimizer ="adam", loss = "binary_crossentropy", metrics = ['accuracy'])
    #model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
 
    
    return model

# %%
model = cnn_model(IMAGE_SIZE, 2)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 16, 60, 64)        3200
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 60, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 60, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 60, 64)        102464
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 3, 12, 64)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 12, 64)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 3, 12, 64)         256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 12, 64)         36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 4, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 4, 64)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 4, 64)          256
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                8224
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 151,844
# Trainable params: 151,396
# Non-trainable params: 448
# _________________________________________________________________

# %%
#set early stopping criteria
pat = 5
#this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='loss', patience=pat, verbose=1)

#define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint('subjek1.h5', verbose=1, save_best_only=True)

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=100, BATCH_SIZE=32):
    model = None
    model = cnn_model(IMAGE_SIZE, 2)
    #Model = model
   # results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[early_stopping, model_checkpoint], 
   #           verbose=1, validation_split=0.1) 
    results = model.fit(t_x, t_y, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[learning_rate_reduction,early_stopping, model_checkpoint], 
              verbose=1, validation_split=0.1)   
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs=100
batch_size=32

#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(train_X, train_y, test_size=0.1, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
   
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 102/102 [==============================] - 9s 11ms/step - loss: 0.7842 - accuracy: 0.2635 - val_loss: 0.6365 - val_accuracy: 0.2278
#
# Epoch 00001: val_loss improved from inf to 0.63649, saving model to subjek1.h5
# Epoch 2/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.6389 - accuracy: 0.2576 - val_loss: 0.5874 - val_accuracy: 0.2028
#
# Epoch 00002: val_loss improved from 0.63649 to 0.58745, saving model to subjek1.h5
# Epoch 3/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5879 - accuracy: 0.2827 - val_loss: 0.5689 - val_accuracy: 0.2194
#
# Epoch 00003: val_loss improved from 0.58745 to 0.56895, saving model to subjek1.h5
# Epoch 4/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5665 - accuracy: 0.2978 - val_loss: 0.5674 - val_accuracy: 0.2278
#
# Epoch 00004: val_loss improved from 0.56895 to 0.56743, saving model to subjek1.h5
# Epoch 5/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5591 - accuracy: 0.3102 - val_loss: 0.5741 - val_accuracy: 0.2250
#
# Epoch 00005: val_loss did not improve from 0.56743
# Epoch 6/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5556 - accuracy: 0.3156 - val_loss: 0.5692 - val_accuracy: 0.2556
#
# Epoch 00006: val_loss did not improve from 0.56743
# Epoch 7/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5488 - accuracy: 0.3445 - val_loss: 0.5530 - val_accuracy: 0.3389
#
# Epoch 00007: val_loss improved from 0.56743 to 0.55303, saving model to subjek1.h5
# Epoch 8/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5421 - accuracy: 0.3543 - val_loss: 0.5491 - val_accuracy: 0.3389
#
# Epoch 00008: val_loss improved from 0.55303 to 0.54913, saving model to subjek1.h5
# Epoch 9/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5243 - accuracy: 0.3984 - val_loss: 0.5238 - val_accuracy: 0.3861
#
# Epoch 00009: val_loss improved from 0.54913 to 0.52377, saving model to subjek1.h5
# Epoch 10/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5032 - accuracy: 0.4319 - val_loss: 0.6529 - val_accuracy: 0.2778
#
# Epoch 00010: val_loss did not improve from 0.52377
# Epoch 11/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4843 - accuracy: 0.4580 - val_loss: 0.5201 - val_accuracy: 0.3806
#
# Epoch 00011: val_loss improved from 0.52377 to 0.52006, saving model to subjek1.h5
# Epoch 12/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4680 - accuracy: 0.4837 - val_loss: 0.5778 - val_accuracy: 0.3583
#
# Epoch 00012: val_loss did not improve from 0.52006
# Epoch 13/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4383 - accuracy: 0.5260 - val_loss: 0.4730 - val_accuracy: 0.5000
#
# Epoch 00013: val_loss improved from 0.52006 to 0.47299, saving model to subjek1.h5
# Epoch 14/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4115 - accuracy: 0.5660 - val_loss: 0.4250 - val_accuracy: 0.5333
#
# Epoch 00014: val_loss improved from 0.47299 to 0.42499, saving model to subjek1.h5
# Epoch 15/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3796 - accuracy: 0.5959 - val_loss: 0.4147 - val_accuracy: 0.5250
#
# Epoch 00015: val_loss improved from 0.42499 to 0.41469, saving model to subjek1.h5
# Epoch 16/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3585 - accuracy: 0.6270 - val_loss: 0.4774 - val_accuracy: 0.4861
#
# Epoch 00016: val_loss did not improve from 0.41469
# Epoch 17/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3488 - accuracy: 0.6457 - val_loss: 0.3353 - val_accuracy: 0.6611
#
# Epoch 00017: val_loss improved from 0.41469 to 0.33534, saving model to subjek1.h5
# Epoch 18/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3317 - accuracy: 0.6515 - val_loss: 0.3632 - val_accuracy: 0.6278
#
# Epoch 00018: val_loss did not improve from 0.33534
# Epoch 19/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3158 - accuracy: 0.6697 - val_loss: 0.3449 - val_accuracy: 0.6139
#
# Epoch 00019: val_loss did not improve from 0.33534
# Epoch 20/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2920 - accuracy: 0.6946 - val_loss: 0.2864 - val_accuracy: 0.7000
#
# Epoch 00020: val_loss improved from 0.33534 to 0.28638, saving model to subjek1.h5
# Epoch 21/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2910 - accuracy: 0.6886 - val_loss: 0.3862 - val_accuracy: 0.5972
#
# Epoch 00021: val_loss did not improve from 0.28638
# Epoch 22/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2771 - accuracy: 0.7062 - val_loss: 0.3332 - val_accuracy: 0.6306
#
# Epoch 00022: val_loss did not improve from 0.28638
# Epoch 23/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2881 - accuracy: 0.7011 - val_loss: 0.2866 - val_accuracy: 0.7083
#
# Epoch 00023: val_loss did not improve from 0.28638
# Epoch 24/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2628 - accuracy: 0.7300 - val_loss: 0.2746 - val_accuracy: 0.6972
#
# Epoch 00024: val_loss improved from 0.28638 to 0.27456, saving model to subjek1.h5
# Epoch 25/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2438 - accuracy: 0.7329 - val_loss: 0.2969 - val_accuracy: 0.6722
#
# Epoch 00025: val_loss did not improve from 0.27456
# Epoch 26/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2729 - accuracy: 0.7089 - val_loss: 0.3861 - val_accuracy: 0.5806
#
# Epoch 00026: val_loss did not improve from 0.27456
# Epoch 27/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2271 - accuracy: 0.7512 - val_loss: 0.2519 - val_accuracy: 0.7250
#
# Epoch 00027: val_loss improved from 0.27456 to 0.25192, saving model to subjek1.h5
# Epoch 28/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2517 - accuracy: 0.7195 - val_loss: 0.2408 - val_accuracy: 0.7361
#
# Epoch 00028: val_loss improved from 0.25192 to 0.24076, saving model to subjek1.h5
# Epoch 29/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2302 - accuracy: 0.7537 - val_loss: 0.2849 - val_accuracy: 0.6778
#
# Epoch 00029: val_loss did not improve from 0.24076
# Epoch 30/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2342 - accuracy: 0.7458 - val_loss: 0.2692 - val_accuracy: 0.7167
#
# Epoch 00030: val_loss did not improve from 0.24076
# Epoch 31/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2279 - accuracy: 0.7480 - val_loss: 0.2311 - val_accuracy: 0.7500
#
# Epoch 00031: val_loss improved from 0.24076 to 0.23106, saving model to subjek1.h5
# Epoch 32/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2150 - accuracy: 0.7694 - val_loss: 0.2388 - val_accuracy: 0.7333
#
# Epoch 00032: val_loss did not improve from 0.23106
# Epoch 33/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2246 - accuracy: 0.7556 - val_loss: 0.2192 - val_accuracy: 0.7639
#
# Epoch 00033: val_loss improved from 0.23106 to 0.21916, saving model to subjek1.h5
# Epoch 34/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2302 - accuracy: 0.7478 - val_loss: 0.2397 - val_accuracy: 0.7361
#
# Epoch 00034: val_loss did not improve from 0.21916
# Epoch 35/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.2157 - accuracy: 0.7682 - val_loss: 0.2155 - val_accuracy: 0.7528
#
# Epoch 00035: val_loss improved from 0.21916 to 0.21550, saving model to subjek1.h5
# Epoch 36/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2152 - accuracy: 0.7555 - val_loss: 0.2130 - val_accuracy: 0.7778
#
# Epoch 00036: val_loss improved from 0.21550 to 0.21301, saving model to subjek1.h5
# Epoch 37/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1996 - accuracy: 0.7720 - val_loss: 0.2424 - val_accuracy: 0.7333
#
# Epoch 00037: val_loss did not improve from 0.21301
# Epoch 38/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2147 - accuracy: 0.7723 - val_loss: 0.2489 - val_accuracy: 0.7250
#
# Epoch 00038: val_loss did not improve from 0.21301
# Epoch 39/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2181 - accuracy: 0.7613 - val_loss: 0.2192 - val_accuracy: 0.7556
#
# Epoch 00039: val_loss did not improve from 0.21301
# Epoch 40/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2034 - accuracy: 0.7733 - val_loss: 0.2309 - val_accuracy: 0.7472
#
# Epoch 00040: val_loss did not improve from 0.21301
# Epoch 41/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1924 - accuracy: 0.7876 - val_loss: 0.2295 - val_accuracy: 0.7528
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00041: val_loss did not improve from 0.21301
# Epoch 42/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1787 - accuracy: 0.8052 - val_loss: 0.2051 - val_accuracy: 0.7611
#
# Epoch 00042: val_loss improved from 0.21301 to 0.20509, saving model to subjek1.h5
# Epoch 43/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1740 - accuracy: 0.8083 - val_loss: 0.1997 - val_accuracy: 0.7750
#
# Epoch 00043: val_loss improved from 0.20509 to 0.19970, saving model to subjek1.h5
# Epoch 44/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1815 - accuracy: 0.7934 - val_loss: 0.2055 - val_accuracy: 0.7806
#
# Epoch 00044: val_loss did not improve from 0.19970
# Epoch 45/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1704 - accuracy: 0.8131 - val_loss: 0.2019 - val_accuracy: 0.7722
#
# Epoch 00045: val_loss did not improve from 0.19970
# Epoch 46/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1801 - accuracy: 0.7903 - val_loss: 0.2023 - val_accuracy: 0.7778
#
# Epoch 00046: val_loss did not improve from 0.19970
# Epoch 47/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1686 - accuracy: 0.8094 - val_loss: 0.1966 - val_accuracy: 0.7750
#
# Epoch 00047: val_loss improved from 0.19970 to 0.19659, saving model to subjek1.h5
# Epoch 48/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1784 - accuracy: 0.8067 - val_loss: 0.1999 - val_accuracy: 0.7861
#
# Epoch 00048: val_loss did not improve from 0.19659
# Epoch 49/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1781 - accuracy: 0.7958 - val_loss: 0.1971 - val_accuracy: 0.7833
#
# Epoch 00049: val_loss did not improve from 0.19659
# Epoch 50/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1737 - accuracy: 0.7960 - val_loss: 0.2024 - val_accuracy: 0.7611
#
# Epoch 00050: val_loss did not improve from 0.19659
# Epoch 51/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1749 - accuracy: 0.7964 - val_loss: 0.2010 - val_accuracy: 0.7750
#
# Epoch 00051: val_loss did not improve from 0.19659
# Epoch 52/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1793 - accuracy: 0.7872 - val_loss: 0.2045 - val_accuracy: 0.7722
#
# Epoch 00052: val_loss did not improve from 0.19659
# Epoch 53/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1761 - accuracy: 0.7976 - val_loss: 0.1974 - val_accuracy: 0.7722
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00053: val_loss did not improve from 0.19659
# Epoch 54/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1692 - accuracy: 0.7889 - val_loss: 0.1951 - val_accuracy: 0.7833
#
# Epoch 00054: val_loss improved from 0.19659 to 0.19509, saving model to subjek1.h5
# Epoch 55/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1766 - accuracy: 0.8045 - val_loss: 0.1892 - val_accuracy: 0.7639
#
# Epoch 00055: val_loss improved from 0.19509 to 0.18918, saving model to subjek1.h5
# Epoch 56/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1577 - accuracy: 0.8048 - val_loss: 0.1859 - val_accuracy: 0.7611
#
# Epoch 00056: val_loss improved from 0.18918 to 0.18594, saving model to subjek1.h5
# Epoch 57/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1689 - accuracy: 0.8090 - val_loss: 0.1839 - val_accuracy: 0.7667
#
# Epoch 00057: val_loss improved from 0.18594 to 0.18393, saving model to subjek1.h5
# Epoch 58/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1680 - accuracy: 0.8011 - val_loss: 0.1868 - val_accuracy: 0.7611
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00058: val_loss did not improve from 0.18393
# Epoch 59/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1704 - accuracy: 0.8040 - val_loss: 0.1852 - val_accuracy: 0.7778
#
# Epoch 00059: val_loss did not improve from 0.18393
# Epoch 60/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1611 - accuracy: 0.8102 - val_loss: 0.1845 - val_accuracy: 0.7889
#
# Epoch 00060: val_loss did not improve from 0.18393
# Epoch 61/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.1591 - accuracy: 0.8187 - val_loss: 0.1860 - val_accuracy: 0.7917
#
# Epoch 00061: val_loss did not improve from 0.18393
# Epoch 62/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1626 - accuracy: 0.8176 - val_loss: 0.1813 - val_accuracy: 0.7972
#
# Epoch 00062: val_loss improved from 0.18393 to 0.18127, saving model to subjek1.h5
# Epoch 63/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1603 - accuracy: 0.8134 - val_loss: 0.1814 - val_accuracy: 0.7833
#
# Epoch 00063: val_loss did not improve from 0.18127
# Epoch 64/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1569 - accuracy: 0.8207 - val_loss: 0.1813 - val_accuracy: 0.7667
#
# Epoch 00064: val_loss did not improve from 0.18127
# Epoch 65/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1634 - accuracy: 0.8101 - val_loss: 0.1828 - val_accuracy: 0.7889
#
# Epoch 00065: val_loss did not improve from 0.18127
# Epoch 66/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1565 - accuracy: 0.8151 - val_loss: 0.1809 - val_accuracy: 0.7917
#
# Epoch 00066: val_loss improved from 0.18127 to 0.18093, saving model to subjek1.h5
# Epoch 67/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1623 - accuracy: 0.8103 - val_loss: 0.1791 - val_accuracy: 0.7917
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00067: val_loss improved from 0.18093 to 0.17909, saving model to subjek1.h5
# Epoch 68/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1638 - accuracy: 0.8080 - val_loss: 0.1778 - val_accuracy: 0.7917
#
# Epoch 00068: val_loss improved from 0.17909 to 0.17781, saving model to subjek1.h5
# Epoch 69/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1577 - accuracy: 0.8125 - val_loss: 0.1798 - val_accuracy: 0.8028
#
# Epoch 00069: val_loss did not improve from 0.17781
# Epoch 70/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1605 - accuracy: 0.8074 - val_loss: 0.1789 - val_accuracy: 0.8000
#
# Epoch 00070: val_loss did not improve from 0.17781
# Epoch 71/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1657 - accuracy: 0.8048 - val_loss: 0.1810 - val_accuracy: 0.7972
#
# Epoch 00071: val_loss did not improve from 0.17781
# Epoch 00071: early stopping
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1685 - accuracy: 0.8175
# Val Score:  [0.16851863265037537, 0.8174999952316284]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/100
# 102/102 [==============================] - 2s 9ms/step - loss: 0.7790 - accuracy: 0.2378 - val_loss: 0.6281 - val_accuracy: 0.2361
#
# Epoch 00001: val_loss did not improve from 0.17781
# Epoch 2/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.6310 - accuracy: 0.2673 - val_loss: 0.5878 - val_accuracy: 0.2361
#
# Epoch 00002: val_loss did not improve from 0.17781
# Epoch 3/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5824 - accuracy: 0.2911 - val_loss: 0.5742 - val_accuracy: 0.2361
#
# Epoch 00003: val_loss did not improve from 0.17781
# Epoch 4/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5670 - accuracy: 0.2929 - val_loss: 0.5671 - val_accuracy: 0.2361
#
# Epoch 00004: val_loss did not improve from 0.17781
# Epoch 5/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5605 - accuracy: 0.2914 - val_loss: 0.5650 - val_accuracy: 0.2583
#
# Epoch 00005: val_loss did not improve from 0.17781
# Epoch 6/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5525 - accuracy: 0.3219 - val_loss: 0.5649 - val_accuracy: 0.2444
#
# Epoch 00006: val_loss did not improve from 0.17781
# Epoch 7/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5361 - accuracy: 0.3618 - val_loss: 0.5527 - val_accuracy: 0.3056
#
# Epoch 00007: val_loss did not improve from 0.17781
# Epoch 8/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5293 - accuracy: 0.3805 - val_loss: 0.5226 - val_accuracy: 0.3556
#
# Epoch 00008: val_loss did not improve from 0.17781
# Epoch 9/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5059 - accuracy: 0.4240 - val_loss: 0.5231 - val_accuracy: 0.3667
#
# Epoch 00009: val_loss did not improve from 0.17781
# Epoch 10/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4919 - accuracy: 0.4474 - val_loss: 0.6079 - val_accuracy: 0.2556
#
# Epoch 00010: val_loss did not improve from 0.17781
# Epoch 11/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4729 - accuracy: 0.4833 - val_loss: 0.4784 - val_accuracy: 0.4500
#
# Epoch 00011: val_loss did not improve from 0.17781
# Epoch 12/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4536 - accuracy: 0.4984 - val_loss: 0.5787 - val_accuracy: 0.3722
#
# Epoch 00012: val_loss did not improve from 0.17781
# Epoch 13/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4165 - accuracy: 0.5625 - val_loss: 0.4304 - val_accuracy: 0.5472
#
# Epoch 00013: val_loss did not improve from 0.17781
# Epoch 14/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4118 - accuracy: 0.5515 - val_loss: 0.3920 - val_accuracy: 0.5778
#
# Epoch 00014: val_loss did not improve from 0.17781
# Epoch 15/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3836 - accuracy: 0.5921 - val_loss: 0.5490 - val_accuracy: 0.4028
#
# Epoch 00015: val_loss did not improve from 0.17781
# Epoch 16/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3548 - accuracy: 0.6277 - val_loss: 0.4486 - val_accuracy: 0.5083
#
# Epoch 00016: val_loss did not improve from 0.17781
# Epoch 17/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3467 - accuracy: 0.6409 - val_loss: 0.3384 - val_accuracy: 0.6222
#
# Epoch 00017: val_loss did not improve from 0.17781
# Epoch 18/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3314 - accuracy: 0.6449 - val_loss: 0.4084 - val_accuracy: 0.5639
#
# Epoch 00018: val_loss did not improve from 0.17781
# Epoch 19/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3266 - accuracy: 0.6553 - val_loss: 0.3016 - val_accuracy: 0.7056
#
# Epoch 00019: val_loss did not improve from 0.17781
# Epoch 20/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3066 - accuracy: 0.6692 - val_loss: 0.2976 - val_accuracy: 0.7056
#
# Epoch 00020: val_loss did not improve from 0.17781
# Epoch 21/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2901 - accuracy: 0.6925 - val_loss: 0.2712 - val_accuracy: 0.7167
#
# Epoch 00021: val_loss did not improve from 0.17781
# Epoch 22/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2896 - accuracy: 0.6871 - val_loss: 0.2875 - val_accuracy: 0.7278
#
# Epoch 00022: val_loss did not improve from 0.17781
# Epoch 23/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2785 - accuracy: 0.6982 - val_loss: 0.2711 - val_accuracy: 0.7028
#
# Epoch 00023: val_loss did not improve from 0.17781
# Epoch 24/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2596 - accuracy: 0.7268 - val_loss: 0.2719 - val_accuracy: 0.7194
#
# Epoch 00024: val_loss did not improve from 0.17781
# Epoch 25/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2556 - accuracy: 0.7275 - val_loss: 0.2712 - val_accuracy: 0.6944
#
# Epoch 00025: val_loss did not improve from 0.17781
# Epoch 26/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2549 - accuracy: 0.7180 - val_loss: 0.2738 - val_accuracy: 0.7194
#
# Epoch 00026: val_loss did not improve from 0.17781
# Epoch 27/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2538 - accuracy: 0.7219 - val_loss: 0.2361 - val_accuracy: 0.7472
#
# Epoch 00027: val_loss did not improve from 0.17781
# Epoch 28/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2376 - accuracy: 0.7468 - val_loss: 0.2771 - val_accuracy: 0.6861
#
# Epoch 00028: val_loss did not improve from 0.17781
# Epoch 29/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2292 - accuracy: 0.7514 - val_loss: 0.2566 - val_accuracy: 0.7500
#
# Epoch 00029: val_loss did not improve from 0.17781
# Epoch 30/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2565 - accuracy: 0.7209 - val_loss: 0.2429 - val_accuracy: 0.7250
#
# Epoch 00030: val_loss did not improve from 0.17781
# Epoch 31/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2281 - accuracy: 0.7405 - val_loss: 0.2244 - val_accuracy: 0.7444
#
# Epoch 00031: val_loss did not improve from 0.17781
# Epoch 32/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2329 - accuracy: 0.7450 - val_loss: 0.2288 - val_accuracy: 0.7722
#
# Epoch 00032: val_loss did not improve from 0.17781
# Epoch 33/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2326 - accuracy: 0.7427 - val_loss: 0.2355 - val_accuracy: 0.7528
#
# Epoch 00033: val_loss did not improve from 0.17781
# Epoch 34/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2296 - accuracy: 0.7528 - val_loss: 0.2320 - val_accuracy: 0.7472
#
# Epoch 00034: val_loss did not improve from 0.17781
# Epoch 35/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2248 - accuracy: 0.7498 - val_loss: 0.2244 - val_accuracy: 0.7639
#
# Epoch 00035: val_loss did not improve from 0.17781
# Epoch 36/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2199 - accuracy: 0.7505 - val_loss: 0.2193 - val_accuracy: 0.7556
#
# Epoch 00036: val_loss did not improve from 0.17781
# Epoch 37/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2226 - accuracy: 0.7585 - val_loss: 0.2123 - val_accuracy: 0.7472
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00037: val_loss did not improve from 0.17781
# Epoch 38/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2087 - accuracy: 0.7632 - val_loss: 0.2035 - val_accuracy: 0.7500
#
# Epoch 00038: val_loss did not improve from 0.17781
# Epoch 39/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1936 - accuracy: 0.7852 - val_loss: 0.2066 - val_accuracy: 0.7556
#
# Epoch 00039: val_loss did not improve from 0.17781
# Epoch 40/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2119 - accuracy: 0.7673 - val_loss: 0.2043 - val_accuracy: 0.7500
#
# Epoch 00040: val_loss did not improve from 0.17781
# Epoch 41/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1907 - accuracy: 0.7941 - val_loss: 0.2014 - val_accuracy: 0.7472
#
# Epoch 00041: val_loss did not improve from 0.17781
# Epoch 42/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.1823 - accuracy: 0.7944 - val_loss: 0.1971 - val_accuracy: 0.7694
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00042: val_loss did not improve from 0.17781
# Epoch 43/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1964 - accuracy: 0.7741 - val_loss: 0.1972 - val_accuracy: 0.7556
#
# Epoch 00043: val_loss did not improve from 0.17781
# Epoch 44/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1889 - accuracy: 0.7844 - val_loss: 0.1969 - val_accuracy: 0.7611
#
# Epoch 00044: val_loss did not improve from 0.17781
# Epoch 45/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1733 - accuracy: 0.8066 - val_loss: 0.1950 - val_accuracy: 0.7889
#
# Epoch 00045: val_loss did not improve from 0.17781
# Epoch 46/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1738 - accuracy: 0.8077 - val_loss: 0.1933 - val_accuracy: 0.7917
#
# Epoch 00046: val_loss did not improve from 0.17781
# Epoch 47/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1898 - accuracy: 0.7745 - val_loss: 0.1990 - val_accuracy: 0.7944
#
# Epoch 00047: val_loss did not improve from 0.17781
# Epoch 48/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1757 - accuracy: 0.7936 - val_loss: 0.1955 - val_accuracy: 0.7889
#
# Epoch 00048: val_loss did not improve from 0.17781
# Epoch 49/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1756 - accuracy: 0.8005 - val_loss: 0.1896 - val_accuracy: 0.8000
#
# Epoch 00049: val_loss did not improve from 0.17781
# Epoch 50/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1704 - accuracy: 0.8076 - val_loss: 0.1947 - val_accuracy: 0.7639
#
# Epoch 00050: val_loss did not improve from 0.17781
# Epoch 51/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1820 - accuracy: 0.7891 - val_loss: 0.1922 - val_accuracy: 0.7944
#
# Epoch 00051: val_loss did not improve from 0.17781
# Epoch 52/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1768 - accuracy: 0.8027 - val_loss: 0.1950 - val_accuracy: 0.7778
#
# Epoch 00052: val_loss did not improve from 0.17781
# Epoch 53/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1854 - accuracy: 0.7966 - val_loss: 0.1922 - val_accuracy: 0.7889
#
# Epoch 00053: val_loss did not improve from 0.17781
# Epoch 00053: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1839 - accuracy: 0.7825
# Val Score:  [0.1839037388563156, 0.7825000286102295]
# ====================================================================================
#
#
# Training on Fold:  3
# Epoch 1/100
# 102/102 [==============================] - 2s 9ms/step - loss: 0.7919 - accuracy: 0.2528 - val_loss: 0.5883 - val_accuracy: 0.3111
#
# Epoch 00001: val_loss did not improve from 0.17781
# Epoch 2/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.6351 - accuracy: 0.3118 - val_loss: 0.5646 - val_accuracy: 0.2583
#
# Epoch 00002: val_loss did not improve from 0.17781
# Epoch 3/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5846 - accuracy: 0.3022 - val_loss: 0.5630 - val_accuracy: 0.2639
#
# Epoch 00003: val_loss did not improve from 0.17781
# Epoch 4/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5708 - accuracy: 0.2872 - val_loss: 0.5639 - val_accuracy: 0.2528
#
# Epoch 00004: val_loss did not improve from 0.17781
# Epoch 5/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5604 - accuracy: 0.3101 - val_loss: 0.5660 - val_accuracy: 0.2306
#
# Epoch 00005: val_loss did not improve from 0.17781
# Epoch 6/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5517 - accuracy: 0.3268 - val_loss: 0.5631 - val_accuracy: 0.2611
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.17781
# Epoch 7/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5430 - accuracy: 0.3331 - val_loss: 0.5396 - val_accuracy: 0.3917
#
# Epoch 00007: val_loss did not improve from 0.17781
# Epoch 8/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5273 - accuracy: 0.3974 - val_loss: 0.5414 - val_accuracy: 0.3861
#
# Epoch 00008: val_loss did not improve from 0.17781
# Epoch 9/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5173 - accuracy: 0.4021 - val_loss: 0.5043 - val_accuracy: 0.4306
#
# Epoch 00009: val_loss did not improve from 0.17781
# Epoch 10/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4998 - accuracy: 0.4358 - val_loss: 0.5164 - val_accuracy: 0.4111
#
# Epoch 00010: val_loss did not improve from 0.17781
# Epoch 11/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4831 - accuracy: 0.4525 - val_loss: 0.4995 - val_accuracy: 0.4694
#
# Epoch 00011: val_loss did not improve from 0.17781
# Epoch 12/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4630 - accuracy: 0.4959 - val_loss: 0.4769 - val_accuracy: 0.4556
#
# Epoch 00012: val_loss did not improve from 0.17781
# Epoch 13/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4451 - accuracy: 0.5316 - val_loss: 0.4859 - val_accuracy: 0.4194
#
# Epoch 00013: val_loss did not improve from 0.17781
# Epoch 14/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4085 - accuracy: 0.5618 - val_loss: 0.4357 - val_accuracy: 0.5472
#
# Epoch 00014: val_loss did not improve from 0.17781
# Epoch 15/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4044 - accuracy: 0.5677 - val_loss: 0.3643 - val_accuracy: 0.6417
#
# Epoch 00015: val_loss did not improve from 0.17781
# Epoch 16/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3758 - accuracy: 0.6215 - val_loss: 0.3686 - val_accuracy: 0.6083
#
# Epoch 00016: val_loss did not improve from 0.17781
# Epoch 17/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3548 - accuracy: 0.6297 - val_loss: 0.3431 - val_accuracy: 0.6444
#
# Epoch 00017: val_loss did not improve from 0.17781
# Epoch 18/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3466 - accuracy: 0.6357 - val_loss: 0.4534 - val_accuracy: 0.4750
#
# Epoch 00018: val_loss did not improve from 0.17781
# Epoch 19/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3255 - accuracy: 0.6573 - val_loss: 0.3313 - val_accuracy: 0.6250
#
# Epoch 00019: val_loss did not improve from 0.17781
# Epoch 20/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3140 - accuracy: 0.6748 - val_loss: 0.3104 - val_accuracy: 0.6694
#
# Epoch 00020: val_loss did not improve from 0.17781
# Epoch 21/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3000 - accuracy: 0.6844 - val_loss: 0.2742 - val_accuracy: 0.7250
#
# Epoch 00021: val_loss did not improve from 0.17781
# Epoch 22/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2852 - accuracy: 0.6974 - val_loss: 0.3257 - val_accuracy: 0.6583
#
# Epoch 00022: val_loss did not improve from 0.17781
# Epoch 23/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2774 - accuracy: 0.7149 - val_loss: 0.2587 - val_accuracy: 0.7417
#
# Epoch 00023: val_loss did not improve from 0.17781
# Epoch 24/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2776 - accuracy: 0.7108 - val_loss: 0.2478 - val_accuracy: 0.7528
#
# Epoch 00024: val_loss did not improve from 0.17781
# Epoch 25/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2601 - accuracy: 0.7233 - val_loss: 0.2605 - val_accuracy: 0.7278
#
# Epoch 00025: val_loss did not improve from 0.17781
# Epoch 26/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2663 - accuracy: 0.7127 - val_loss: 0.2395 - val_accuracy: 0.7500
#
# Epoch 00026: val_loss did not improve from 0.17781
# Epoch 27/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2491 - accuracy: 0.7353 - val_loss: 0.2541 - val_accuracy: 0.7389
#
# Epoch 00027: val_loss did not improve from 0.17781
# Epoch 28/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2436 - accuracy: 0.7455 - val_loss: 0.2245 - val_accuracy: 0.7639
#
# Epoch 00028: val_loss did not improve from 0.17781
# Epoch 29/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2439 - accuracy: 0.7346 - val_loss: 0.2318 - val_accuracy: 0.7500
#
# Epoch 00029: val_loss did not improve from 0.17781
# Epoch 30/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2393 - accuracy: 0.7476 - val_loss: 0.2309 - val_accuracy: 0.7389
#
# Epoch 00030: val_loss did not improve from 0.17781
# Epoch 31/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2368 - accuracy: 0.7398 - val_loss: 0.2188 - val_accuracy: 0.7639
#
# Epoch 00031: val_loss did not improve from 0.17781
# Epoch 32/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2263 - accuracy: 0.7507 - val_loss: 0.2318 - val_accuracy: 0.7500
#
# Epoch 00032: val_loss did not improve from 0.17781
# Epoch 33/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2284 - accuracy: 0.7479 - val_loss: 0.2227 - val_accuracy: 0.7500
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00033: val_loss did not improve from 0.17781
# Epoch 34/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2336 - accuracy: 0.7417 - val_loss: 0.2063 - val_accuracy: 0.7806
#
# Epoch 00034: val_loss did not improve from 0.17781
# Epoch 35/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2154 - accuracy: 0.7647 - val_loss: 0.2112 - val_accuracy: 0.7778
#
# Epoch 00035: val_loss did not improve from 0.17781
# Epoch 36/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2063 - accuracy: 0.7832 - val_loss: 0.2036 - val_accuracy: 0.7750
#
# Epoch 00036: val_loss did not improve from 0.17781
# Epoch 37/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2138 - accuracy: 0.7726 - val_loss: 0.2062 - val_accuracy: 0.7722
#
# Epoch 00037: val_loss did not improve from 0.17781
# Epoch 38/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2029 - accuracy: 0.7630 - val_loss: 0.2051 - val_accuracy: 0.7667
#
# Epoch 00038: val_loss did not improve from 0.17781
# Epoch 39/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1974 - accuracy: 0.7795 - val_loss: 0.2076 - val_accuracy: 0.7639
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00039: val_loss did not improve from 0.17781
# Epoch 40/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1938 - accuracy: 0.7850 - val_loss: 0.2002 - val_accuracy: 0.7806
#
# Epoch 00040: val_loss did not improve from 0.17781
# Epoch 41/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1975 - accuracy: 0.7797 - val_loss: 0.1990 - val_accuracy: 0.7833
#
# Epoch 00041: val_loss did not improve from 0.17781
# Epoch 42/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1833 - accuracy: 0.7959 - val_loss: 0.1974 - val_accuracy: 0.7917
#
# Epoch 00042: val_loss did not improve from 0.17781
# Epoch 43/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1905 - accuracy: 0.7897 - val_loss: 0.2020 - val_accuracy: 0.7833
#
# Epoch 00043: val_loss did not improve from 0.17781
# Epoch 44/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1870 - accuracy: 0.7929 - val_loss: 0.1927 - val_accuracy: 0.7944
#
# Epoch 00044: val_loss did not improve from 0.17781
# Epoch 45/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1795 - accuracy: 0.8011 - val_loss: 0.1934 - val_accuracy: 0.7806
#
# Epoch 00045: val_loss did not improve from 0.17781
# Epoch 46/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1831 - accuracy: 0.8037 - val_loss: 0.1894 - val_accuracy: 0.7833
#
# Epoch 00046: val_loss did not improve from 0.17781
# Epoch 47/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1765 - accuracy: 0.7998 - val_loss: 0.1900 - val_accuracy: 0.7750
#
# Epoch 00047: val_loss did not improve from 0.17781
# Epoch 48/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1810 - accuracy: 0.8013 - val_loss: 0.1913 - val_accuracy: 0.7806
#
# Epoch 00048: val_loss did not improve from 0.17781
# Epoch 49/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1888 - accuracy: 0.7871 - val_loss: 0.1906 - val_accuracy: 0.7944
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00049: val_loss did not improve from 0.17781
# Epoch 50/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1765 - accuracy: 0.8073 - val_loss: 0.1895 - val_accuracy: 0.7806
#
# Epoch 00050: val_loss did not improve from 0.17781
# Epoch 51/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1771 - accuracy: 0.8066 - val_loss: 0.1892 - val_accuracy: 0.7806
#
# Epoch 00051: val_loss did not improve from 0.17781
# Epoch 52/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1803 - accuracy: 0.7881 - val_loss: 0.1911 - val_accuracy: 0.7722
#
# Epoch 00052: val_loss did not improve from 0.17781
# Epoch 53/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1809 - accuracy: 0.7992 - val_loss: 0.1911 - val_accuracy: 0.7833
#
# Epoch 00053: val_loss did not improve from 0.17781
# Epoch 54/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1768 - accuracy: 0.7992 - val_loss: 0.1884 - val_accuracy: 0.7806
#
# Epoch 00054: val_loss did not improve from 0.17781
# Epoch 55/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1697 - accuracy: 0.8109 - val_loss: 0.1868 - val_accuracy: 0.7778
#
# Epoch 00055: val_loss did not improve from 0.17781
# Epoch 56/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1805 - accuracy: 0.7971 - val_loss: 0.1855 - val_accuracy: 0.7833
#
# Epoch 00056: val_loss did not improve from 0.17781
# Epoch 57/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1799 - accuracy: 0.7951 - val_loss: 0.1865 - val_accuracy: 0.7833
#
# Epoch 00057: val_loss did not improve from 0.17781
# Epoch 58/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1814 - accuracy: 0.8048 - val_loss: 0.1870 - val_accuracy: 0.7833
#
# Epoch 00058: val_loss did not improve from 0.17781
# Epoch 59/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1789 - accuracy: 0.7946 - val_loss: 0.1897 - val_accuracy: 0.7806
#
# Epoch 00059: val_loss did not improve from 0.17781
# Epoch 60/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1725 - accuracy: 0.8014 - val_loss: 0.1857 - val_accuracy: 0.7944
#
# Epoch 00060: val_loss did not improve from 0.17781
# Epoch 61/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1757 - accuracy: 0.7931 - val_loss: 0.1854 - val_accuracy: 0.7833
#
# Epoch 00061: val_loss did not improve from 0.17781
# Epoch 62/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1829 - accuracy: 0.7868 - val_loss: 0.1865 - val_accuracy: 0.7806
#
# Epoch 00062: val_loss did not improve from 0.17781
# Epoch 63/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1707 - accuracy: 0.8128 - val_loss: 0.1881 - val_accuracy: 0.7778
#
# Epoch 00063: val_loss did not improve from 0.17781
# Epoch 64/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1800 - accuracy: 0.7868 - val_loss: 0.1883 - val_accuracy: 0.7806
#
# Epoch 00064: val_loss did not improve from 0.17781
# Epoch 65/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1729 - accuracy: 0.8037 - val_loss: 0.1821 - val_accuracy: 0.7833
#
# Epoch 00065: val_loss did not improve from 0.17781
# Epoch 66/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1770 - accuracy: 0.7905 - val_loss: 0.1858 - val_accuracy: 0.7806
#
# Epoch 00066: val_loss did not improve from 0.17781
# Epoch 67/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1746 - accuracy: 0.7931 - val_loss: 0.1842 - val_accuracy: 0.7806
#
# Epoch 00067: val_loss did not improve from 0.17781
# Epoch 68/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1669 - accuracy: 0.8082 - val_loss: 0.1841 - val_accuracy: 0.7833
#
# Epoch 00068: val_loss did not improve from 0.17781
# Epoch 69/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1695 - accuracy: 0.8079 - val_loss: 0.1852 - val_accuracy: 0.7889
#
# Epoch 00069: val_loss did not improve from 0.17781
# Epoch 70/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1673 - accuracy: 0.8115 - val_loss: 0.1778 - val_accuracy: 0.7889
#
# Epoch 00070: val_loss improved from 0.17781 to 0.17781, saving model to subjek1.h5
# Epoch 71/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1792 - accuracy: 0.8057 - val_loss: 0.1828 - val_accuracy: 0.7833
#
# Epoch 00071: val_loss did not improve from 0.17781
# Epoch 72/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1667 - accuracy: 0.8075 - val_loss: 0.1765 - val_accuracy: 0.7917
#
# Epoch 00072: val_loss improved from 0.17781 to 0.17645, saving model to subjek1.h5
# Epoch 73/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1746 - accuracy: 0.8090 - val_loss: 0.1788 - val_accuracy: 0.7861
#
# Epoch 00073: val_loss did not improve from 0.17645
# Epoch 74/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1704 - accuracy: 0.8066 - val_loss: 0.1841 - val_accuracy: 0.7889
#
# Epoch 00074: val_loss did not improve from 0.17645
# Epoch 75/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.1719 - accuracy: 0.8005 - val_loss: 0.1808 - val_accuracy: 0.7917
#
# Epoch 00075: val_loss did not improve from 0.17645
# Epoch 76/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1714 - accuracy: 0.8008 - val_loss: 0.1772 - val_accuracy: 0.7972
#
# Epoch 00076: val_loss did not improve from 0.17645
# Epoch 77/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1595 - accuracy: 0.8209 - val_loss: 0.1748 - val_accuracy: 0.7917
#
# Epoch 00077: val_loss improved from 0.17645 to 0.17485, saving model to subjek1.h5
# Epoch 78/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1622 - accuracy: 0.8143 - val_loss: 0.1821 - val_accuracy: 0.7833
#
# Epoch 00078: val_loss did not improve from 0.17485
# Epoch 79/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1647 - accuracy: 0.8160 - val_loss: 0.1769 - val_accuracy: 0.7833
#
# Epoch 00079: val_loss did not improve from 0.17485
# Epoch 80/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1637 - accuracy: 0.8094 - val_loss: 0.1812 - val_accuracy: 0.7917
#
# Epoch 00080: val_loss did not improve from 0.17485
# Epoch 81/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1682 - accuracy: 0.8139 - val_loss: 0.1772 - val_accuracy: 0.7944
#
# Epoch 00081: val_loss did not improve from 0.17485
# Epoch 82/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1698 - accuracy: 0.8041 - val_loss: 0.1775 - val_accuracy: 0.7833
#
# Epoch 00082: val_loss did not improve from 0.17485
# Epoch 83/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1691 - accuracy: 0.8017 - val_loss: 0.1718 - val_accuracy: 0.7889
#
# Epoch 00083: val_loss improved from 0.17485 to 0.17183, saving model to subjek1.h5
# Epoch 84/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1601 - accuracy: 0.8167 - val_loss: 0.1741 - val_accuracy: 0.7944
#
# Epoch 00084: val_loss did not improve from 0.17183
# Epoch 85/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1608 - accuracy: 0.8095 - val_loss: 0.1759 - val_accuracy: 0.7917
#
# Epoch 00085: val_loss did not improve from 0.17183
# Epoch 86/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1634 - accuracy: 0.8114 - val_loss: 0.1749 - val_accuracy: 0.7917
#
# Epoch 00086: val_loss did not improve from 0.17183
# Epoch 87/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1692 - accuracy: 0.7962 - val_loss: 0.1761 - val_accuracy: 0.7889
#
# Epoch 00087: val_loss did not improve from 0.17183
# Epoch 88/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1636 - accuracy: 0.8172 - val_loss: 0.1799 - val_accuracy: 0.7889
#
# Epoch 00088: val_loss did not improve from 0.17183
# Epoch 89/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1672 - accuracy: 0.8051 - val_loss: 0.1771 - val_accuracy: 0.8111
#
# Epoch 00089: val_loss did not improve from 0.17183
# Epoch 90/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1600 - accuracy: 0.8119 - val_loss: 0.1794 - val_accuracy: 0.8056
#
# Epoch 00090: val_loss did not improve from 0.17183
# Epoch 91/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1563 - accuracy: 0.8298 - val_loss: 0.1771 - val_accuracy: 0.8167
#
# Epoch 00091: val_loss did not improve from 0.17183
# Epoch 92/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1532 - accuracy: 0.8229 - val_loss: 0.1734 - val_accuracy: 0.8000
#
# Epoch 00092: val_loss did not improve from 0.17183
# Epoch 93/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1657 - accuracy: 0.7936 - val_loss: 0.1740 - val_accuracy: 0.8083
#
# Epoch 00093: val_loss did not improve from 0.17183
# Epoch 94/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1629 - accuracy: 0.8159 - val_loss: 0.1780 - val_accuracy: 0.8111
#
# Epoch 00094: val_loss did not improve from 0.17183
# Epoch 95/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1638 - accuracy: 0.8181 - val_loss: 0.1783 - val_accuracy: 0.8139
#
# Epoch 00095: val_loss did not improve from 0.17183
# Epoch 96/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1654 - accuracy: 0.8103 - val_loss: 0.1700 - val_accuracy: 0.7972
#
# Epoch 00096: val_loss improved from 0.17183 to 0.17005, saving model to subjek1.h5
# Epoch 00096: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1706 - accuracy: 0.7875
# Val Score:  [0.1705958992242813, 0.7875000238418579]
# ====================================================================================
#
#
# Training on Fold:  4
# Epoch 1/100
# 102/102 [==============================] - 2s 9ms/step - loss: 0.7715 - accuracy: 0.2357 - val_loss: 0.6183 - val_accuracy: 0.2500
#
# Epoch 00001: val_loss did not improve from 0.17005
# Epoch 2/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.6340 - accuracy: 0.2652 - val_loss: 0.5785 - val_accuracy: 0.2361
#
# Epoch 00002: val_loss did not improve from 0.17005
# Epoch 3/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5874 - accuracy: 0.2544 - val_loss: 0.5718 - val_accuracy: 0.2306
#
# Epoch 00003: val_loss did not improve from 0.17005
# Epoch 4/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5681 - accuracy: 0.2755 - val_loss: 0.5713 - val_accuracy: 0.2250
#
# Epoch 00004: val_loss did not improve from 0.17005
# Epoch 5/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.5603 - accuracy: 0.3015 - val_loss: 0.5746 - val_accuracy: 0.2194
#
# Epoch 00005: val_loss did not improve from 0.17005
# Epoch 6/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5540 - accuracy: 0.3129 - val_loss: 0.5659 - val_accuracy: 0.2444
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.17005
# Epoch 7/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5378 - accuracy: 0.3685 - val_loss: 0.5620 - val_accuracy: 0.2500
#
# Epoch 00007: val_loss did not improve from 0.17005
# Epoch 8/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5304 - accuracy: 0.3733 - val_loss: 0.5426 - val_accuracy: 0.3361
#
# Epoch 00008: val_loss did not improve from 0.17005
# Epoch 9/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5167 - accuracy: 0.3969 - val_loss: 0.5078 - val_accuracy: 0.4361
#
# Epoch 00009: val_loss did not improve from 0.17005
# Epoch 10/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4910 - accuracy: 0.4614 - val_loss: 0.5363 - val_accuracy: 0.3806
#
# Epoch 00010: val_loss did not improve from 0.17005
# Epoch 11/100
# ...
# Epoch 65/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1698 - accuracy: 0.8087 - val_loss: 0.2025 - val_accuracy: 0.7750
#
# Epoch 00065: val_loss did not improve from 0.17005
# Epoch 66/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1750 - accuracy: 0.7995 - val_loss: 0.2056 - val_accuracy: 0.7694
#
# Epoch 00066: val_loss did not improve from 0.17005
# Epoch 67/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1625 - accuracy: 0.8138 - val_loss: 0.2037 - val_accuracy: 0.7694
#
# Epoch 00067: val_loss did not improve from 0.17005
# Epoch 68/100
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1635 - accuracy: 0.8093 - val_loss: 0.2041 - val_accuracy: 0.7750
#
# Epoch 00068: val_loss did not improve from 0.17005
# Epoch 00068: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1990 - accuracy: 0.7675
# Val Score:  [0.19904857873916626, 0.7674999833106995]
# ====================================================================================
#
#
# Training on Fold:  5
# Epoch 1/100
# 102/102 [==============================] - 2s 10ms/step - loss: 0.7835 - accuracy: 0.2350 - val_loss: 0.6632 - val_accuracy: 0.2472
#
# Epoch 00001: val_loss did not improve from 0.17005
# Epoch 2/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.6291 - accuracy: 0.2730 - val_loss: 0.5984 - val_accuracy: 0.2361
#
# Epoch 00002: val_loss did not improve from 0.17005
# Epoch 3/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5895 - accuracy: 0.2750 - val_loss: 0.5703 - val_accuracy: 0.2528
#
# Epoch 00003: val_loss did not improve from 0.17005
# Epoch 4/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5692 - accuracy: 0.2980 - val_loss: 0.5696 - val_accuracy: 0.2306
#
# Epoch 00004: val_loss did not improve from 0.17005
# Epoch 5/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5588 - accuracy: 0.3091 - val_loss: 0.5709 - val_accuracy: 0.2556
#
# Epoch 00005: val_loss did not improve from 0.17005
# Epoch 6/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5533 - accuracy: 0.3323 - val_loss: 0.5595 - val_accuracy: 0.2944
#
# Epoch 00006: val_loss did not improve from 0.17005
# Epoch 7/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5482 - accuracy: 0.3456 - val_loss: 0.5610 - val_accuracy: 0.2972
#
# Epoch 00007: val_loss did not improve from 0.17005
# Epoch 8/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5330 - accuracy: 0.3715 - val_loss: 0.5914 - val_accuracy: 0.2833
#
# Epoch 00008: val_loss did not improve from 0.17005
# Epoch 9/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5176 - accuracy: 0.4072 - val_loss: 0.5966 - val_accuracy: 0.2806
#
# Epoch 00009: val_loss did not improve from 0.17005
# Epoch 10/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.5059 - accuracy: 0.4316 - val_loss: 0.5002 - val_accuracy: 0.4500
#
# Epoch 00010: val_loss did not improve from 0.17005
# Epoch 11/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4830 - accuracy: 0.4592 - val_loss: 0.4687 - val_accuracy: 0.4722
#
# Epoch 00011: val_loss did not improve from 0.17005
# Epoch 12/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4621 - accuracy: 0.4951 - val_loss: 0.4785 - val_accuracy: 0.4639
#
# Epoch 00012: val_loss did not improve from 0.17005
# Epoch 13/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4354 - accuracy: 0.5282 - val_loss: 0.5261 - val_accuracy: 0.3417
#
# Epoch 00013: val_loss did not improve from 0.17005
# Epoch 14/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.4069 - accuracy: 0.5729 - val_loss: 0.5066 - val_accuracy: 0.3861
#
# Epoch 00014: val_loss did not improve from 0.17005
# Epoch 15/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3842 - accuracy: 0.6053 - val_loss: 0.3638 - val_accuracy: 0.6389
#
# Epoch 00015: val_loss did not improve from 0.17005
# Epoch 16/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3494 - accuracy: 0.6328 - val_loss: 0.3990 - val_accuracy: 0.5694
#
# Epoch 00016: val_loss did not improve from 0.17005
# Epoch 17/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3441 - accuracy: 0.6491 - val_loss: 0.3518 - val_accuracy: 0.6500
#
# Epoch 00017: val_loss did not improve from 0.17005
# Epoch 18/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3168 - accuracy: 0.6722 - val_loss: 0.3646 - val_accuracy: 0.6028
#
# Epoch 00018: val_loss did not improve from 0.17005
# Epoch 19/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2940 - accuracy: 0.6936 - val_loss: 0.3076 - val_accuracy: 0.6972
#
# Epoch 00019: val_loss did not improve from 0.17005
# Epoch 20/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.3094 - accuracy: 0.6772 - val_loss: 0.3282 - val_accuracy: 0.6417
#
# Epoch 00020: val_loss did not improve from 0.17005
# Epoch 21/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2956 - accuracy: 0.6811 - val_loss: 0.2924 - val_accuracy: 0.6889
#
# Epoch 00021: val_loss did not improve from 0.17005
# Epoch 22/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2723 - accuracy: 0.7130 - val_loss: 0.2718 - val_accuracy: 0.7083
#
# Epoch 00022: val_loss did not improve from 0.17005
# Epoch 23/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2858 - accuracy: 0.7091 - val_loss: 0.2676 - val_accuracy: 0.7333
#
# Epoch 00023: val_loss did not improve from 0.17005
# Epoch 24/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2654 - accuracy: 0.7147 - val_loss: 0.2528 - val_accuracy: 0.7389
#
# Epoch 00024: val_loss did not improve from 0.17005
# Epoch 25/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2724 - accuracy: 0.7079 - val_loss: 0.2274 - val_accuracy: 0.7722
#
# Epoch 00025: val_loss did not improve from 0.17005
# Epoch 26/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2571 - accuracy: 0.7210 - val_loss: 0.2390 - val_accuracy: 0.7250
#
# Epoch 00026: val_loss did not improve from 0.17005
# Epoch 27/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2610 - accuracy: 0.7002 - val_loss: 0.2459 - val_accuracy: 0.7417
#
# Epoch 00027: val_loss did not improve from 0.17005
# Epoch 28/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2423 - accuracy: 0.7408 - val_loss: 0.2399 - val_accuracy: 0.7417
#
# Epoch 00028: val_loss did not improve from 0.17005
# Epoch 29/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2508 - accuracy: 0.7317 - val_loss: 0.2337 - val_accuracy: 0.7444
#
# Epoch 00029: val_loss did not improve from 0.17005
# Epoch 30/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2287 - accuracy: 0.7598 - val_loss: 0.2205 - val_accuracy: 0.7611
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00030: val_loss did not improve from 0.17005
# Epoch 31/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.2201 - accuracy: 0.7512 - val_loss: 0.2140 - val_accuracy: 0.7528
#
# Epoch 00031: val_loss did not improve from 0.17005
# Epoch 32/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2068 - accuracy: 0.7674 - val_loss: 0.2026 - val_accuracy: 0.7778
#
# Epoch 00032: val_loss did not improve from 0.17005
# Epoch 33/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2119 - accuracy: 0.7619 - val_loss: 0.2105 - val_accuracy: 0.7639
#
# Epoch 00033: val_loss did not improve from 0.17005
# Epoch 34/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1993 - accuracy: 0.7870 - val_loss: 0.2130 - val_accuracy: 0.7639
#
# Epoch 00034: val_loss did not improve from 0.17005
# Epoch 35/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2060 - accuracy: 0.7745 - val_loss: 0.1993 - val_accuracy: 0.7833
#
# Epoch 00035: val_loss did not improve from 0.17005
# Epoch 36/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1992 - accuracy: 0.7875 - val_loss: 0.2126 - val_accuracy: 0.7639
#
# Epoch 00036: val_loss did not improve from 0.17005
# Epoch 37/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2023 - accuracy: 0.7719 - val_loss: 0.1990 - val_accuracy: 0.7861
#
# Epoch 00037: val_loss did not improve from 0.17005
# Epoch 38/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2029 - accuracy: 0.7633 - val_loss: 0.2186 - val_accuracy: 0.7500
#
# Epoch 00038: val_loss did not improve from 0.17005
# Epoch 39/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1961 - accuracy: 0.7774 - val_loss: 0.2030 - val_accuracy: 0.7750
#
# Epoch 00039: val_loss did not improve from 0.17005
# Epoch 40/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1982 - accuracy: 0.7847 - val_loss: 0.1921 - val_accuracy: 0.7889
#
# Epoch 00040: val_loss did not improve from 0.17005
# Epoch 41/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1893 - accuracy: 0.7941 - val_loss: 0.1915 - val_accuracy: 0.7944
#
# Epoch 00041: val_loss did not improve from 0.17005
# Epoch 42/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1877 - accuracy: 0.7903 - val_loss: 0.1926 - val_accuracy: 0.7944
#
# Epoch 00042: val_loss did not improve from 0.17005
# Epoch 43/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1845 - accuracy: 0.7784 - val_loss: 0.2025 - val_accuracy: 0.7556
#
# Epoch 00043: val_loss did not improve from 0.17005
# Epoch 44/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1895 - accuracy: 0.7819 - val_loss: 0.1880 - val_accuracy: 0.7917
#
# Epoch 00044: val_loss did not improve from 0.17005
# Epoch 45/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2033 - accuracy: 0.7689 - val_loss: 0.1884 - val_accuracy: 0.7917
#
# Epoch 00045: val_loss did not improve from 0.17005
# Epoch 46/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1806 - accuracy: 0.7944 - val_loss: 0.1906 - val_accuracy: 0.7972
#
# Epoch 00046: val_loss did not improve from 0.17005
# Epoch 47/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1946 - accuracy: 0.7761 - val_loss: 0.1890 - val_accuracy: 0.7972
#
# Epoch 00047: val_loss did not improve from 0.17005
# Epoch 48/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1914 - accuracy: 0.7853 - val_loss: 0.1862 - val_accuracy: 0.7861
#
# Epoch 00048: val_loss did not improve from 0.17005
# Epoch 49/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.2033 - accuracy: 0.7707 - val_loss: 0.1891 - val_accuracy: 0.7917
#
# Epoch 00049: val_loss did not improve from 0.17005
# Epoch 50/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1975 - accuracy: 0.7719 - val_loss: 0.1813 - val_accuracy: 0.7972
#
# Epoch 00050: val_loss did not improve from 0.17005
# Epoch 51/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1822 - accuracy: 0.7914 - val_loss: 0.1755 - val_accuracy: 0.8083
#
# Epoch 00051: val_loss did not improve from 0.17005
# Epoch 52/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1843 - accuracy: 0.7925 - val_loss: 0.1824 - val_accuracy: 0.8000
#
# Epoch 00052: val_loss did not improve from 0.17005
# Epoch 53/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1827 - accuracy: 0.7889 - val_loss: 0.1780 - val_accuracy: 0.8083
#
# Epoch 00053: val_loss did not improve from 0.17005
# Epoch 54/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1774 - accuracy: 0.8066 - val_loss: 0.2080 - val_accuracy: 0.7611
#
# Epoch 00054: val_loss did not improve from 0.17005
# Epoch 55/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1730 - accuracy: 0.8043 - val_loss: 0.1848 - val_accuracy: 0.7917
#
# Epoch 00055: val_loss did not improve from 0.17005
# Epoch 56/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1786 - accuracy: 0.7896 - val_loss: 0.1771 - val_accuracy: 0.7917
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00056: val_loss did not improve from 0.17005
# Epoch 57/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1720 - accuracy: 0.7989 - val_loss: 0.1741 - val_accuracy: 0.8000
#
# Epoch 00057: val_loss did not improve from 0.17005
# Epoch 58/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1728 - accuracy: 0.8030 - val_loss: 0.1723 - val_accuracy: 0.8083
#
# Epoch 00058: val_loss did not improve from 0.17005
# Epoch 59/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1777 - accuracy: 0.7964 - val_loss: 0.1721 - val_accuracy: 0.8056
#
# Epoch 00059: val_loss did not improve from 0.17005
# Epoch 60/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1737 - accuracy: 0.8030 - val_loss: 0.1718 - val_accuracy: 0.8194
#
# Epoch 00060: val_loss did not improve from 0.17005
# Epoch 61/100
# 102/102 [==============================] - 1s 9ms/step - loss: 0.1657 - accuracy: 0.8094 - val_loss: 0.1704 - val_accuracy: 0.8083
#
# Epoch 00061: val_loss did not improve from 0.17005
# Epoch 62/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1680 - accuracy: 0.8146 - val_loss: 0.1740 - val_accuracy: 0.8000
#
# Epoch 00062: val_loss did not improve from 0.17005
# Epoch 63/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1775 - accuracy: 0.7954 - val_loss: 0.1756 - val_accuracy: 0.8000
#
# Epoch 00063: val_loss did not improve from 0.17005
# Epoch 64/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1649 - accuracy: 0.8071 - val_loss: 0.1738 - val_accuracy: 0.7972
#
# Epoch 00064: val_loss did not improve from 0.17005
# Epoch 65/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1718 - accuracy: 0.7991 - val_loss: 0.1672 - val_accuracy: 0.8056
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00065: val_loss improved from 0.17005 to 0.16724, saving model to subjek1.h5
# Epoch 66/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1643 - accuracy: 0.8042 - val_loss: 0.1679 - val_accuracy: 0.7972
#
# Epoch 00066: val_loss did not improve from 0.16724
# Epoch 67/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1646 - accuracy: 0.8091 - val_loss: 0.1677 - val_accuracy: 0.8056
#
# Epoch 00067: val_loss did not improve from 0.16724
# Epoch 68/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1602 - accuracy: 0.8062 - val_loss: 0.1701 - val_accuracy: 0.7972
#
# Epoch 00068: val_loss did not improve from 0.16724
# Epoch 69/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1525 - accuracy: 0.8171 - val_loss: 0.1690 - val_accuracy: 0.7944
#
# Epoch 00069: val_loss did not improve from 0.16724
# Epoch 70/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1613 - accuracy: 0.8172 - val_loss: 0.1679 - val_accuracy: 0.8056
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00070: val_loss did not improve from 0.16724
# Epoch 71/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1632 - accuracy: 0.8134 - val_loss: 0.1667 - val_accuracy: 0.8000
#
# Epoch 00071: val_loss improved from 0.16724 to 0.16666, saving model to subjek1.h5
# Epoch 72/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1644 - accuracy: 0.7991 - val_loss: 0.1676 - val_accuracy: 0.8056
#
# Epoch 00072: val_loss did not improve from 0.16666
# Epoch 73/100
# 102/102 [==============================] - 1s 8ms/step - loss: 0.1617 - accuracy: 0.8053 - val_loss: 0.1668 - val_accuracy: 0.8083
#
# Epoch 00073: val_loss did not improve from 0.16666
# Epoch 00073: early stopping
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1991 - accuracy: 0.7800
# Val Score:  [0.1991288959980011, 0.7799999713897705]
# ====================================================================================

# %%
#Load the model that was saved by ModelCheckpoint
model = load_model('subjek1.h5')

# %%
model.evaluate(test_X, test_y)
#print("Accuracy of the model is - " , model.evaluate(test_X,test_y)[1]*100 , "%")
#plt.bar( model.evaluate(test_X)[1].index,  model.evaluate(test_y)[1])
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1468 - accuracy: 0.8130
# [0.14682291448116302, 0.8130000233650208]

# %%
fig, (ax1, ax2) =  plt.subplots( ncols=2, sharex=True)

ax1.plot(model_history[0].history['accuracy'], label='Training Fold 1 accuration')
ax1.plot(model_history[1].history['accuracy'], label='Training Fold 2 accuration')
ax1.plot(model_history[2].history['accuracy'], label='Training Fold 3 accuration')
ax1.plot(model_history[3].history['accuracy'], label='Training Fold 4 accuration')
ax1.plot(model_history[4].history['accuracy'], label='Training Fold 5 accuration')
ax1.legend()
ax2.plot(model_history[1].history['loss'], label='Training Fold 1 loss')
ax2.plot(model_history[1].history['loss'], label='Training Fold 2 loss')
ax2.plot(model_history[2].history['loss'], label='Training Fold 3 loss')
ax2.plot(model_history[3].history['loss'], label='Training Fold 4 loss ')
ax2.plot(model_history[4].history['loss'], label='Training Fold 5 loss')
ax2.legend()
plt.show()

# %%
fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[0].history['accuracy'], label='Train Accuracy Fold 1', color='black')
plt1.plot(model_history[0].history['val_accuracy'], label='Val Accuracy Fold 1', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[0].history['loss'], label='Train Loss Fold 1', color='black')
plt2.plot(model_history[0].history['val_loss'], label='Val Loss Fold 1', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[1].history['accuracy'], label='Train Accuracy Fold 2', color='red')
plt1.plot(model_history[1].history['val_accuracy'], label='Val Accuracy Fold 2', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[1].history['loss'], label='Train Loss Fold 2', color='red')
plt2.plot(model_history[1].history['val_loss'], label='Val Loss Fold 2', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[2].history['accuracy'], label='Train Accuracy Fold 3', color='green')
plt1.plot(model_history[2].history['val_accuracy'], label='Val Accuracy Fold 3', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[2].history['loss'], label='Train Loss Fold 3', color='green')
plt2.plot(model_history[2].history['val_loss'], label='Val Loss Fold 3', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()


fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[3].history['accuracy'], label='Train Accuracy Fold 4', color='blue')
plt1.plot(model_history[3].history['val_accuracy'], label='Val Accuracy Fold 4', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[3].history['loss'], label='Train Loss Fold 4', color='blue')
plt2.plot(model_history[3].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

fig, (plt1, plt2)  =  plt.subplots( ncols=2, sharex=True)
plt1.plot(model_history[4].history['accuracy'], label='Train Accuracy Fold 5', color='purple')
plt1.plot(model_history[4].history['val_accuracy'], label='Val Accuracy Fold 5', color='orange', linestyle = "dashdot")
plt1.legend()
plt2.plot(model_history[4].history['loss'], label='Train Loss Fold 4', color='purple')
plt2.plot(model_history[4].history['val_loss'], label='Val Loss Fold 4', color='orange', linestyle = "dashdot")
plt2.legend()
plt.show()

# %%
MODEL_NAME ='/content/subjek1.h5' 

#CLIP = True # if your model was trained with np.clip to clip  values
CLIP = False
CLIP_VAL = 8  # if above, what was the value +/-

model = tf.keras.models.load_model(MODEL_NAME)

VALDIR = '/content/drive/MyDrive/Colab Notebooks/tes_data'
ACTIONS =  ["idle","maju","kiri", "kanan"]
PRED_BATCH = 32


def get_val_data(valdir, action, batch_size):

   # argmax_dict = {0: 0, 1: 0, 2: 0,3:0}
    argmax_dict = {2: 0, 0: 0, 1: 0,3:0}
    raw_pred_dict = {0: 0, 1: 0, 2: 0,3:0}

    action_dir = os.path.join(valdir, action)
    for session_file in os.listdir(action_dir):
        filepath = os.path.join(action_dir,session_file)
        if CLIP:
            data = np.clip(np.load(filepath), -CLIP_VAL, CLIP_VAL) / CLIP_VAL
            #print(data)
        else:
            data = np.load(filepath) 
        preds = model.predict([data.reshape(-1, 16, 60,1)], batch_size=batch_size)
        
        for pred in preds:
            argmax = np.argmax(pred)
            argmax_dict[argmax] += 1
            for idx,value in enumerate(pred):
                raw_pred_dict[idx] += value
    
    argmax_pct_dict = {}
    for i in argmax_dict:
        total = 0
        correct = argmax_dict[i]
        for ii in argmax_dict:
            total += argmax_dict[ii]
        argmax_pct_dict[i] = round(correct/total, 4)
    return argmax_dict, raw_pred_dict, argmax_pct_dict


def make_conf_mat(none,left,forward, right):
    action_dict = {"idle":none,"maju": forward, "kiri": left, "kanan": right}
    action_conf_mat = pd.DataFrame(action_dict)
    actions = [i for i in action_dict]

    fig = plt.figure(figsize=(15, 6))
    ax = fig.add_subplot(111)
    ax.matshow(action_conf_mat, cmap=plt.cm.RdYlGn)
    ax.set_xticklabels([""]+actions)
    ax.set_yticklabels([""]+actions)

    for idx, i in enumerate(action_dict):
        for idx2, ii in enumerate(action_dict[i]):
            ax.text(idx, idx2, f"{round(float(action_dict[i][ii]),2)}", va='center', ha='center')
    # Rotate the tick labels and set their alignment.
    
    plt.title("Matrik data")
    plt.ylabel("Predicted Action")
    fig.tight_layout()
    plt.show()



forward_argmax_dict, forward_raw_pred_dict, forward_argmax_pct_dict = get_val_data(VALDIR, "maju", PRED_BATCH)
none_argmax_dict, none_raw_pred_dict, none_argmax_pct_dict = get_val_data(VALDIR, "idle", PRED_BATCH)
left_argmax_dict, left_raw_pred_dict, left_argmax_pct_dict = get_val_data(VALDIR, "kiri", PRED_BATCH)
right_argmax_dict, right_raw_pred_dict, right_argmax_pct_dict = get_val_data(VALDIR, "kanan", PRED_BATCH)
make_conf_mat(none_argmax_pct_dict,forward_argmax_pct_dict,left_argmax_pct_dict,  right_argmax_pct_dict)

# %%
from sklearn.metrics import roc_curve, auc
#y_score = clf.decision_function(xval)
y_score = model.predict(test_X)

#Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()


# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(test_y[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
    
    
print("roc_auc:",sum(roc_auc.values())/4)
ACTIONS =  ["idle","maju","kiri", "kanan"]
for i in range(0,4):
    plt.figure()
    fig, ax = plt.subplots(figsize=(5,5))
    plt.plot(fpr[i], tpr[i],linewidth=3)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    #plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % ACTIONS[i])
    plt.title('%s -ROC curve (area = %0.2f)' % (ACTIONS[i],roc_auc[i]))
    
    plt.legend(loc="lower right")
    plt.show()
# Out:
# roc_auc: 0.9716266666666666
